# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = 'TIMNET-dataset'
DATA_PATH = 'IEMOCAP'
CLASS_LABELS = Config.IEMOCAP_LABELS
k = 10

model_name = 'ablation study(remove sa)'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 200
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding=padding),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule]),
        Lambda(function=PrimaryCapssquash)
    ])
    
  def call(self, inputs):
    return self.conv(inputs)

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.cbam = CBAM(64) # sharing
    
    self.primarycap = PrimaryCap()
    self.spatial_attn = SpatialGate()
    
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    x = inputs
    
    cap = self.conv1(x)
    cap = cap + self.cbam(cap)
    cap = self.conv2(cap)
    cap = cap + self.cbam(cap)
    
    primarycaps = self.primarycap(cap)
    primarycaps = tf.expand_dims(primarycaps, axis=-1)
    primarycaps = primarycaps + self.spatial_attn(primarycaps)
    primarycaps = tf.squeeze(primarycaps, axis=-1)
    
    cap = primarycaps
    
    cap = tf.expand_dims(cap, axis=-1)
    cap = cap + self.spatial_attn(cap)
    cap = tf.squeeze(cap, axis=-1)
    
    capsule = self.capsule(cap)
    capsule = tf.expand_dims(capsule, axis=-1)
    capsule = capsule + self.spatial_attn(capsule)
    capsule = tf.squeeze(capsule, axis=-1)
    
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1416
#
#  sequential_1 (Sequential)   (None, 46, 7, 64)         37300
#
#  cbam (CBAM)                 multiple                  4294
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  spatial_gate_1 (SpatialGate  multiple                 102
#  )
#
#  attention (Attention)       multiple                  0 (unused)
#
#  layer_normalization (LayerN  multiple                 0 (unused)
#  ormalization)
#
#  lambda_1 (Lambda)           multiple                  0 (unused)
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  260
#
# =================================================================
# Total params: 93,548
# Trainable params: 92,970
# Non-trainable params: 578
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}.npy', 'rb') as f:
    x = np.load(f)
    y = np.load(f)

y = to_categorical(y,num_classes=len(CLASS_LABELS))

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, test) in tqdm(enumerate(kfold.split(x, y)), desc=f'Training {k}-Fold.....'):
    if i<4:
        continue
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = x[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_test, y_test = x[test], y[test]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_test = tf.expand_dims(x_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_test_loss = 0x3f3f3f
    best_test_acc = -1
    best_test_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        test_loss, test_acc, f1s = [], [], []
        for features, labels in batch_test:
            loss, acc, pred = test_step(model, features, labels)
            test_loss.append(loss)
            test_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(test_loss)/len(test_loss)
        val_acc = sum(test_acc)/len(test_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_test_loss:.3f}, Best accuracy:{best_test_acc:.3f}, Best F1-score:{best_test_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_test_acc < val_acc:
            best_test_acc = val_acc
            best_test_loss = val_loss
            best_test_f1 = f1_score
            model.save_weights(h5_path)
            
            
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    
    for features, labels in batch_test:
        best_pred = model(features, training=False)
        emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(labels, axis=1))
        predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
    
    
    print(f'[*] Done - acc:{best_test_acc:.3f}')
    
    plt.title(f'{i+1}-fold Loss Curve - Best acc:{best_test_acc:.3f}, Best loss:{best_test_loss:.3f}')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])

    
    save_fig_path = f'Fig/{DATA_PATH}/training/{model_name}'
    os.makedirs(save_fig_path, exist_ok=True)
    plt.savefig(f'{save_fig_path}/{i+1}-fold.PNG')
    
    plt.show()
    
    fold_acc.append(best_test_acc)
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/200 lr=0.00100 - loss:0.453, acc:42.777, val_loss:0.447, val_acc:41.628
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/200 lr=0.00100 - loss:0.441, acc:45.613, val_loss:0.449, val_acc:43.866
# Best loss:0.447, Best accuracy:41.628, Best F1-score:0.403
# 3/200 lr=0.00100 - loss:0.433, acc:46.995, val_loss:0.426, val_acc:47.512
# Best loss:0.449, Best accuracy:43.866, Best F1-score:0.413
# 4/200 lr=0.00100 - loss:0.425, acc:48.371, val_loss:0.411, val_acc:50.386
# Best loss:0.426, Best accuracy:47.512, Best F1-score:0.470
# 5/200 lr=0.00100 - loss:0.417, acc:50.970, val_loss:0.399, val_acc:51.331
# Best loss:0.411, Best accuracy:50.386, Best F1-score:0.494
# 6/200 lr=0.00100 - loss:0.413, acc:50.795, val_loss:0.411, val_acc:45.602
# Best loss:0.399, Best accuracy:51.331, Best F1-score:0.515
# 7/200 lr=0.00100 - loss:0.418, acc:50.029, val_loss:0.396, val_acc:54.919
# Best loss:0.399, Best accuracy:51.331, Best F1-score:0.515
# 8/200 lr=0.00100 - loss:0.409, acc:52.172, val_loss:0.392, val_acc:54.205
# Best loss:0.396, Best accuracy:54.919, Best F1-score:0.534
# 9/200 lr=0.00100 - loss:0.405, acc:52.477, val_loss:0.407, val_acc:49.325
# Best loss:0.396, Best accuracy:54.919, Best F1-score:0.534
# 10/200 lr=0.00100 - loss:0.405, acc:52.384, val_loss:0.390, val_acc:56.134
# Best loss:0.396, Best accuracy:54.919, Best F1-score:0.534
# 11/200 lr=0.00100 - loss:0.404, acc:52.528, val_loss:0.382, val_acc:54.919
# Best loss:0.390, Best accuracy:56.134, Best F1-score:0.556
# 12/200 lr=0.00100 - loss:0.409, acc:51.565, val_loss:0.391, val_acc:54.996
# Best loss:0.390, Best accuracy:56.134, Best F1-score:0.556
# 13/200 lr=0.00100 - loss:0.404, acc:53.343, val_loss:0.404, val_acc:53.704
# Best loss:0.390, Best accuracy:56.134, Best F1-score:0.556
# 14/200 lr=0.00100 - loss:0.402, acc:53.717, val_loss:0.385, val_acc:54.128
# Best loss:0.390, Best accuracy:56.134, Best F1-score:0.556
# 15/200 lr=0.00100 - loss:0.409, acc:51.767, val_loss:0.383, val_acc:52.836
# Best loss:0.390, Best accuracy:56.134, Best F1-score:0.556
# 16/200 lr=0.00100 - loss:0.405, acc:52.531, val_loss:0.387, val_acc:54.572
# Best loss:0.390, Best accuracy:56.134, Best F1-score:0.556
# 17/200 lr=0.00100 - loss:0.403, acc:52.985, val_loss:0.383, val_acc:55.266
# Best loss:0.390, Best accuracy:56.134, Best F1-score:0.556
# 18/200 lr=0.00100 - loss:0.401, acc:53.686, val_loss:0.376, val_acc:56.289
# Best loss:0.390, Best accuracy:56.134, Best F1-score:0.556
# 19/200 lr=0.00100 - loss:0.397, acc:53.383, val_loss:0.385, val_acc:53.260
# Best loss:0.376, Best accuracy:56.289, Best F1-score:0.558
# 20/200 lr=0.00100 - loss:0.402, acc:52.557, val_loss:0.385, val_acc:56.385
# Best loss:0.376, Best accuracy:56.289, Best F1-score:0.558
# 21/200 lr=0.00100 - loss:0.397, acc:53.917, val_loss:0.386, val_acc:55.363
# Best loss:0.385, Best accuracy:56.385, Best F1-score:0.556
# 22/200 lr=0.00100 - loss:0.391, acc:54.857, val_loss:0.375, val_acc:57.967
# Best loss:0.385, Best accuracy:56.385, Best F1-score:0.556
# 23/200 lr=0.00100 - loss:0.387, acc:55.640, val_loss:0.360, val_acc:61.188
# Best loss:0.375, Best accuracy:57.967, Best F1-score:0.571
# 24/200 lr=0.00100 - loss:0.388, acc:55.322, val_loss:0.372, val_acc:58.661
# Best loss:0.360, Best accuracy:61.188, Best F1-score:0.607
# 25/200 lr=0.00100 - loss:0.379, acc:57.350, val_loss:0.359, val_acc:59.008
# Best loss:0.360, Best accuracy:61.188, Best F1-score:0.607
# 26/200 lr=0.00100 - loss:0.378, acc:57.890, val_loss:0.357, val_acc:58.661
# Best loss:0.360, Best accuracy:61.188, Best F1-score:0.607
# 27/200 lr=0.00100 - loss:0.372, acc:58.164, val_loss:0.349, val_acc:60.571
# Best loss:0.360, Best accuracy:61.188, Best F1-score:0.607
# 28/200 lr=0.00100 - loss:0.372, acc:58.801, val_loss:0.364, val_acc:59.703
# Best loss:0.360, Best accuracy:61.188, Best F1-score:0.607
# 29/200 lr=0.00100 - loss:0.375, acc:58.309, val_loss:0.347, val_acc:61.883
# Best loss:0.360, Best accuracy:61.188, Best F1-score:0.607
# 30/200 lr=0.00100 - loss:0.366, acc:59.967, val_loss:0.337, val_acc:61.265
# Best loss:0.347, Best accuracy:61.883, Best F1-score:0.610
# 31/200 lr=0.00100 - loss:0.367, acc:59.502, val_loss:0.341, val_acc:60.475
# Best loss:0.347, Best accuracy:61.883, Best F1-score:0.610
# 32/200 lr=0.00100 - loss:0.363, acc:59.631, val_loss:0.341, val_acc:61.265
# Best loss:0.347, Best accuracy:61.883, Best F1-score:0.610
# 33/200 lr=0.00100 - loss:0.365, acc:60.107, val_loss:0.335, val_acc:62.481
# Best loss:0.347, Best accuracy:61.883, Best F1-score:0.610
# 34/200 lr=0.00100 - loss:0.363, acc:59.851, val_loss:0.345, val_acc:62.307
# Best loss:0.335, Best accuracy:62.481, Best F1-score:0.615
# 35/200 lr=0.00100 - loss:0.362, acc:60.290, val_loss:0.339, val_acc:62.133
# Best loss:0.335, Best accuracy:62.481, Best F1-score:0.615
# 36/200 lr=0.00100 - loss:0.355, acc:61.454, val_loss:0.328, val_acc:63.522
# Best loss:0.335, Best accuracy:62.481, Best F1-score:0.615
# 37/200 lr=0.00100 - loss:0.356, acc:61.280, val_loss:0.331, val_acc:61.863
# Best loss:0.328, Best accuracy:63.522, Best F1-score:0.630
# 38/200 lr=0.00100 - loss:0.353, acc:61.149, val_loss:0.336, val_acc:61.613
# Best loss:0.328, Best accuracy:63.522, Best F1-score:0.630
# 39/200 lr=0.00100 - loss:0.348, acc:62.671, val_loss:0.325, val_acc:63.600
# Best loss:0.328, Best accuracy:63.522, Best F1-score:0.630
# 40/200 lr=0.00100 - loss:0.354, acc:62.006, val_loss:0.351, val_acc:60.320
# Best loss:0.325, Best accuracy:63.600, Best F1-score:0.639
# 41/200 lr=0.00100 - loss:0.346, acc:62.836, val_loss:0.319, val_acc:64.140
# Best loss:0.325, Best accuracy:63.600, Best F1-score:0.639
# 42/200 lr=0.00100 - loss:0.344, acc:63.283, val_loss:0.330, val_acc:64.043
# Best loss:0.319, Best accuracy:64.140, Best F1-score:0.639
# 43/200 lr=0.00100 - loss:0.345, acc:63.032, val_loss:0.344, val_acc:60.050
# Best loss:0.319, Best accuracy:64.140, Best F1-score:0.639
# 44/200 lr=0.00100 - loss:0.350, acc:61.812, val_loss:0.334, val_acc:60.995
# Best loss:0.319, Best accuracy:64.140, Best F1-score:0.639
# 45/200 lr=0.00100 - loss:0.346, acc:63.032, val_loss:0.317, val_acc:64.487
# Best loss:0.319, Best accuracy:64.140, Best F1-score:0.639
# 46/200 lr=0.00100 - loss:0.347, acc:63.003, val_loss:0.324, val_acc:61.767
# Best loss:0.317, Best accuracy:64.487, Best F1-score:0.643
# 47/200 lr=0.00100 - loss:0.337, acc:64.846, val_loss:0.311, val_acc:66.570
# Best loss:0.317, Best accuracy:64.487, Best F1-score:0.643
# 48/200 lr=0.00100 - loss:0.337, acc:64.899, val_loss:0.319, val_acc:66.474
# Best loss:0.311, Best accuracy:66.570, Best F1-score:0.663
# 49/200 lr=0.00100 - loss:0.334, acc:65.213, val_loss:0.317, val_acc:64.043
# Best loss:0.311, Best accuracy:66.570, Best F1-score:0.663
# 50/200 lr=0.00100 - loss:0.329, acc:65.507, val_loss:0.313, val_acc:64.217
# Best loss:0.311, Best accuracy:66.570, Best F1-score:0.663
# 51/200 lr=0.00100 - loss:0.331, acc:65.701, val_loss:0.309, val_acc:65.085
# Best loss:0.311, Best accuracy:66.570, Best F1-score:0.663
# 52/200 lr=0.00100 - loss:0.326, acc:65.952, val_loss:0.320, val_acc:64.583
# Best loss:0.311, Best accuracy:66.570, Best F1-score:0.663
# 53/200 lr=0.00100 - loss:0.331, acc:65.389, val_loss:0.309, val_acc:65.702
# Best loss:0.311, Best accuracy:66.570, Best F1-score:0.663
# 54/200 lr=0.00100 - loss:0.327, acc:66.092, val_loss:0.314, val_acc:66.127
# Best loss:0.311, Best accuracy:66.570, Best F1-score:0.663
# 55/200 lr=0.00100 - loss:0.323, acc:66.337, val_loss:0.306, val_acc:64.660
# Best loss:0.311, Best accuracy:66.570, Best F1-score:0.663
# 56/200 lr=0.00100 - loss:0.325, acc:66.253, val_loss:0.314, val_acc:64.564
# Best loss:0.311, Best accuracy:66.570, Best F1-score:0.663
# 57/200 lr=0.00100 - loss:0.325, acc:66.288, val_loss:0.316, val_acc:65.104
# Best loss:0.311, Best accuracy:66.570, Best F1-score:0.663
# 58/200 lr=0.00100 - loss:0.323, acc:67.263, val_loss:0.306, val_acc:65.625
# Best loss:0.311, Best accuracy:66.570, Best F1-score:0.663
# 59/200 lr=0.00100 - loss:0.319, acc:67.321, val_loss:0.304, val_acc:63.966
# Best loss:0.311, Best accuracy:66.570, Best F1-score:0.663
# 60/200 lr=0.00100 - loss:0.321, acc:67.105, val_loss:0.306, val_acc:67.535
# Best loss:0.311, Best accuracy:66.570, Best F1-score:0.663
# 61/200 lr=0.00100 - loss:0.319, acc:67.283, val_loss:0.303, val_acc:65.181
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 62/200 lr=0.00086 - loss:0.315, acc:68.381, val_loss:0.303, val_acc:66.049
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 63/200 lr=0.00086 - loss:0.311, acc:68.797, val_loss:0.320, val_acc:64.371
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 64/200 lr=0.00086 - loss:0.310, acc:69.222, val_loss:0.306, val_acc:67.438
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 65/200 lr=0.00086 - loss:0.310, acc:68.697, val_loss:0.317, val_acc:63.889
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 66/200 lr=0.00086 - loss:0.312, acc:68.300, val_loss:0.299, val_acc:66.570
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 67/200 lr=0.00086 - loss:0.304, acc:69.367, val_loss:0.311, val_acc:65.606
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 68/200 lr=0.00086 - loss:0.303, acc:69.253, val_loss:0.297, val_acc:67.438
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 69/200 lr=0.00086 - loss:0.301, acc:69.968, val_loss:0.300, val_acc:65.953
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 70/200 lr=0.00086 - loss:0.301, acc:69.827, val_loss:0.317, val_acc:64.660
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 71/200 lr=0.00086 - loss:0.308, acc:68.864, val_loss:0.313, val_acc:63.619
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 72/200 lr=0.00086 - loss:0.304, acc:69.727, val_loss:0.312, val_acc:64.931
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 73/200 lr=0.00086 - loss:0.302, acc:69.965, val_loss:0.310, val_acc:66.570
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 74/200 lr=0.00086 - loss:0.300, acc:70.297, val_loss:0.307, val_acc:63.966
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 75/200 lr=0.00086 - loss:0.300, acc:70.373, val_loss:0.313, val_acc:66.223
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 76/200 lr=0.00086 - loss:0.302, acc:69.923, val_loss:0.313, val_acc:63.522
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 77/200 lr=0.00086 - loss:0.295, acc:71.339, val_loss:0.309, val_acc:64.834
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 78/200 lr=0.00086 - loss:0.296, acc:71.071, val_loss:0.299, val_acc:66.049
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 79/200 lr=0.00086 - loss:0.292, acc:71.454, val_loss:0.304, val_acc:64.487
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 80/200 lr=0.00086 - loss:0.290, acc:71.581, val_loss:0.298, val_acc:65.876
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 81/200 lr=0.00086 - loss:0.293, acc:70.971, val_loss:0.304, val_acc:63.870
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 82/200 lr=0.00074 - loss:0.292, acc:72.062, val_loss:0.319, val_acc:65.972
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 83/200 lr=0.00074 - loss:0.284, acc:72.394, val_loss:0.306, val_acc:66.744
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 84/200 lr=0.00074 - loss:0.284, acc:72.523, val_loss:0.316, val_acc:63.792
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 85/200 lr=0.00074 - loss:0.284, acc:72.903, val_loss:0.299, val_acc:66.744
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 86/200 lr=0.00074 - loss:0.279, acc:73.751, val_loss:0.307, val_acc:63.349
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 87/200 lr=0.00074 - loss:0.277, acc:74.350, val_loss:0.302, val_acc:67.785
# Best loss:0.306, Best accuracy:67.535, Best F1-score:0.672
# 88/200 lr=0.00074 - loss:0.282, acc:73.353, val_loss:0.300, val_acc:66.493
# Best loss:0.302, Best accuracy:67.785, Best F1-score:0.674
# 89/200 lr=0.00074 - loss:0.280, acc:73.188, val_loss:0.292, val_acc:67.959
# Best loss:0.302, Best accuracy:67.785, Best F1-score:0.674
# 90/200 lr=0.00074 - loss:0.278, acc:73.805, val_loss:0.302, val_acc:66.744
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 91/200 lr=0.00074 - loss:0.280, acc:73.780, val_loss:0.310, val_acc:65.008
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 92/200 lr=0.00074 - loss:0.279, acc:73.340, val_loss:0.312, val_acc:64.564
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 93/200 lr=0.00074 - loss:0.280, acc:73.182, val_loss:0.305, val_acc:66.223
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 94/200 lr=0.00074 - loss:0.278, acc:73.404, val_loss:0.304, val_acc:64.140
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 95/200 lr=0.00074 - loss:0.271, acc:74.942, val_loss:0.296, val_acc:66.821
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 96/200 lr=0.00074 - loss:0.273, acc:74.245, val_loss:0.297, val_acc:65.606
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 97/200 lr=0.00074 - loss:0.275, acc:74.208, val_loss:0.296, val_acc:66.744
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 98/200 lr=0.00074 - loss:0.273, acc:74.898, val_loss:0.298, val_acc:66.917
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 99/200 lr=0.00074 - loss:0.272, acc:74.457, val_loss:0.295, val_acc:67.265
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 100/200 lr=0.00074 - loss:0.264, acc:75.968, val_loss:0.301, val_acc:64.738
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 101/200 lr=0.00074 - loss:0.269, acc:74.826, val_loss:0.317, val_acc:64.140
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 102/200 lr=0.00064 - loss:0.272, acc:74.334, val_loss:0.300, val_acc:64.911
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 103/200 lr=0.00064 - loss:0.267, acc:75.398, val_loss:0.301, val_acc:65.355
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 104/200 lr=0.00064 - loss:0.261, acc:76.616, val_loss:0.299, val_acc:66.744
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 105/200 lr=0.00064 - loss:0.261, acc:75.844, val_loss:0.299, val_acc:66.493
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 106/200 lr=0.00064 - loss:0.262, acc:76.108, val_loss:0.294, val_acc:67.438
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 107/200 lr=0.00064 - loss:0.257, acc:77.092, val_loss:0.296, val_acc:66.570
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 108/200 lr=0.00064 - loss:0.258, acc:76.765, val_loss:0.304, val_acc:65.085
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 109/200 lr=0.00064 - loss:0.263, acc:75.663, val_loss:0.307, val_acc:66.223
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 110/200 lr=0.00064 - loss:0.260, acc:76.264, val_loss:0.304, val_acc:67.438
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 111/200 lr=0.00064 - loss:0.256, acc:77.181, val_loss:0.305, val_acc:65.876
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 112/200 lr=0.00064 - loss:0.261, acc:76.460, val_loss:0.308, val_acc:65.181
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 113/200 lr=0.00064 - loss:0.253, acc:77.306, val_loss:0.304, val_acc:65.702
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 114/200 lr=0.00064 - loss:0.253, acc:77.942, val_loss:0.308, val_acc:65.876
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 115/200 lr=0.00064 - loss:0.256, acc:76.810, val_loss:0.309, val_acc:64.487
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 116/200 lr=0.00064 - loss:0.253, acc:77.166, val_loss:0.297, val_acc:67.091
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 117/200 lr=0.00064 - loss:0.255, acc:77.433, val_loss:0.305, val_acc:63.870
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 118/200 lr=0.00064 - loss:0.257, acc:76.631, val_loss:0.295, val_acc:65.355
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 119/200 lr=0.00064 - loss:0.250, acc:78.624, val_loss:0.316, val_acc:65.008
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 120/200 lr=0.00064 - loss:0.253, acc:77.310, val_loss:0.313, val_acc:64.140
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 121/200 lr=0.00064 - loss:0.254, acc:77.237, val_loss:0.303, val_acc:66.397
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 122/200 lr=0.00055 - loss:0.250, acc:77.727, val_loss:0.307, val_acc:65.432
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 123/200 lr=0.00055 - loss:0.251, acc:77.896, val_loss:0.308, val_acc:64.834
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 124/200 lr=0.00055 - loss:0.249, acc:78.047, val_loss:0.307, val_acc:64.834
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 125/200 lr=0.00055 - loss:0.251, acc:77.281, val_loss:0.323, val_acc:63.792
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 126/200 lr=0.00055 - loss:0.248, acc:78.474, val_loss:0.304, val_acc:66.300
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 127/200 lr=0.00055 - loss:0.247, acc:78.098, val_loss:0.308, val_acc:65.529
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 128/200 lr=0.00055 - loss:0.247, acc:78.154, val_loss:0.305, val_acc:65.432
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 129/200 lr=0.00055 - loss:0.250, acc:78.040, val_loss:0.301, val_acc:67.612
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 130/200 lr=0.00055 - loss:0.244, acc:78.463, val_loss:0.301, val_acc:66.917
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 131/200 lr=0.00055 - loss:0.247, acc:77.827, val_loss:0.322, val_acc:66.049
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 132/200 lr=0.00055 - loss:0.241, acc:78.940, val_loss:0.305, val_acc:66.570
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 133/200 lr=0.00055 - loss:0.247, acc:78.187, val_loss:0.300, val_acc:66.744
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 134/200 lr=0.00055 - loss:0.242, acc:79.156, val_loss:0.317, val_acc:64.140
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 135/200 lr=0.00055 - loss:0.243, acc:78.920, val_loss:0.314, val_acc:63.272
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 136/200 lr=0.00055 - loss:0.239, acc:79.645, val_loss:0.311, val_acc:65.606
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 137/200 lr=0.00055 - loss:0.239, acc:78.880, val_loss:0.312, val_acc:65.008
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 138/200 lr=0.00055 - loss:0.236, acc:80.277, val_loss:0.310, val_acc:65.779
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 139/200 lr=0.00055 - loss:0.239, acc:79.534, val_loss:0.308, val_acc:67.168
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 140/200 lr=0.00055 - loss:0.236, acc:79.932, val_loss:0.308, val_acc:65.702
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 141/200 lr=0.00055 - loss:0.237, acc:79.641, val_loss:0.310, val_acc:64.834
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 142/200 lr=0.00047 - loss:0.233, acc:80.366, val_loss:0.308, val_acc:65.702
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 143/200 lr=0.00047 - loss:0.235, acc:79.730, val_loss:0.304, val_acc:66.397
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 144/200 lr=0.00047 - loss:0.234, acc:80.402, val_loss:0.316, val_acc:62.751
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 145/200 lr=0.00047 - loss:0.230, acc:80.807, val_loss:0.308, val_acc:64.738
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 146/200 lr=0.00047 - loss:0.231, acc:80.658, val_loss:0.310, val_acc:65.606
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 147/200 lr=0.00047 - loss:0.235, acc:79.939, val_loss:0.318, val_acc:63.426
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 148/200 lr=0.00047 - loss:0.230, acc:80.876, val_loss:0.322, val_acc:63.966
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 149/200 lr=0.00047 - loss:0.235, acc:80.070, val_loss:0.318, val_acc:65.355
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 150/200 lr=0.00047 - loss:0.230, acc:80.353, val_loss:0.309, val_acc:65.008
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 151/200 lr=0.00047 - loss:0.224, acc:82.054, val_loss:0.321, val_acc:64.140
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 152/200 lr=0.00047 - loss:0.236, acc:79.955, val_loss:0.327, val_acc:63.349
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 153/200 lr=0.00047 - loss:0.228, acc:80.698, val_loss:0.308, val_acc:66.223
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 154/200 lr=0.00047 - loss:0.227, acc:81.499, val_loss:0.314, val_acc:65.008
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 155/200 lr=0.00047 - loss:0.228, acc:81.348, val_loss:0.317, val_acc:64.390
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 156/200 lr=0.00047 - loss:0.228, acc:81.644, val_loss:0.320, val_acc:64.313
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 157/200 lr=0.00047 - loss:0.229, acc:81.297, val_loss:0.316, val_acc:64.564
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 158/200 lr=0.00047 - loss:0.225, acc:81.312, val_loss:0.306, val_acc:65.683
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 159/200 lr=0.00047 - loss:0.225, acc:81.404, val_loss:0.304, val_acc:66.049
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 160/200 lr=0.00047 - loss:0.229, acc:80.763, val_loss:0.308, val_acc:66.223
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 161/200 lr=0.00047 - loss:0.228, acc:80.987, val_loss:0.311, val_acc:65.779
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 162/200 lr=0.00041 - loss:0.227, acc:81.152, val_loss:0.315, val_acc:63.522
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 163/200 lr=0.00041 - loss:0.224, acc:81.604, val_loss:0.305, val_acc:66.917
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 164/200 lr=0.00041 - loss:0.219, acc:81.873, val_loss:0.309, val_acc:66.821
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 165/200 lr=0.00041 - loss:0.219, acc:82.212, val_loss:0.312, val_acc:67.265
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 166/200 lr=0.00041 - loss:0.223, acc:82.005, val_loss:0.302, val_acc:66.030
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 167/200 lr=0.00041 - loss:0.222, acc:81.809, val_loss:0.312, val_acc:64.545
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 168/200 lr=0.00041 - loss:0.218, acc:82.229, val_loss:0.313, val_acc:64.371
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 169/200 lr=0.00041 - loss:0.216, acc:82.971, val_loss:0.316, val_acc:65.953
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 170/200 lr=0.00041 - loss:0.220, acc:82.285, val_loss:0.313, val_acc:65.181
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 171/200 lr=0.00041 - loss:0.216, acc:83.002, val_loss:0.319, val_acc:65.258
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 172/200 lr=0.00041 - loss:0.215, acc:82.646, val_loss:0.322, val_acc:65.355
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 173/200 lr=0.00041 - loss:0.218, acc:82.525, val_loss:0.305, val_acc:65.509
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 174/200 lr=0.00041 - loss:0.215, acc:82.759, val_loss:0.314, val_acc:66.030
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 175/200 lr=0.00041 - loss:0.224, acc:82.372, val_loss:0.318, val_acc:64.043
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 176/200 lr=0.00041 - loss:0.219, acc:82.129, val_loss:0.312, val_acc:65.432
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 177/200 lr=0.00041 - loss:0.215, acc:82.581, val_loss:0.314, val_acc:65.239
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 178/200 lr=0.00041 - loss:0.218, acc:82.336, val_loss:0.317, val_acc:65.355
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 179/200 lr=0.00041 - loss:0.218, acc:82.154, val_loss:0.322, val_acc:63.503
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 180/200 lr=0.00041 - loss:0.214, acc:83.322, val_loss:0.315, val_acc:66.146
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 181/200 lr=0.00041 - loss:0.217, acc:82.434, val_loss:0.322, val_acc:64.834
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 182/200 lr=0.00035 - loss:0.219, acc:82.085, val_loss:0.309, val_acc:65.529
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 183/200 lr=0.00035 - loss:0.215, acc:82.835, val_loss:0.313, val_acc:65.529
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 184/200 lr=0.00035 - loss:0.211, acc:83.603, val_loss:0.301, val_acc:67.785
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 185/200 lr=0.00035 - loss:0.211, acc:83.282, val_loss:0.310, val_acc:67.708
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 186/200 lr=0.00035 - loss:0.212, acc:83.538, val_loss:0.311, val_acc:66.667
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 187/200 lr=0.00035 - loss:0.216, acc:82.681, val_loss:0.316, val_acc:66.127
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 188/200 lr=0.00035 - loss:0.213, acc:83.120, val_loss:0.298, val_acc:65.856
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 189/200 lr=0.00035 - loss:0.206, acc:84.324, val_loss:0.309, val_acc:66.744
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 190/200 lr=0.00035 - loss:0.208, acc:83.683, val_loss:0.298, val_acc:67.072
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 191/200 lr=0.00035 - loss:0.212, acc:83.238, val_loss:0.319, val_acc:63.156
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 192/200 lr=0.00035 - loss:0.209, acc:83.992, val_loss:0.314, val_acc:65.606
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 193/200 lr=0.00035 - loss:0.211, acc:83.531, val_loss:0.310, val_acc:63.696
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 194/200 lr=0.00035 - loss:0.211, acc:83.202, val_loss:0.311, val_acc:64.468
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 195/200 lr=0.00035 - loss:0.206, acc:84.235, val_loss:0.312, val_acc:64.564
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 196/200 lr=0.00035 - loss:0.212, acc:82.979, val_loss:0.323, val_acc:63.426
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 197/200 lr=0.00035 - loss:0.208, acc:83.856, val_loss:0.317, val_acc:64.911
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 198/200 lr=0.00035 - loss:0.209, acc:83.747, val_loss:0.320, val_acc:64.217
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 199/200 lr=0.00035 - loss:0.210, acc:83.948, val_loss:0.320, val_acc:64.294
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# 200/200 lr=0.00035 - loss:0.208, acc:83.663, val_loss:0.318, val_acc:63.850
# Best loss:0.292, Best accuracy:67.959, Best F1-score:0.672
# [*] Done - acc:67.959
# A Jupyter Widget
# 1/200 lr=0.00100 - loss:0.448, acc:43.864, val_loss:0.448, val_acc:42.033
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/200 lr=0.00100 - loss:0.431, acc:47.641, val_loss:0.440, val_acc:45.351
# Best loss:0.448, Best accuracy:42.033, Best F1-score:0.375
# 3/200 lr=0.00100 - loss:0.424, acc:49.170, val_loss:0.416, val_acc:50.135
# Best loss:0.440, Best accuracy:45.351, Best F1-score:0.429
# 4/200 lr=0.00100 - loss:0.414, acc:50.761, val_loss:0.412, val_acc:51.620
# Best loss:0.416, Best accuracy:50.135, Best F1-score:0.501
# 5/200 lr=0.00100 - loss:0.416, acc:51.478, val_loss:0.416, val_acc:48.302
# Best loss:0.412, Best accuracy:51.620, Best F1-score:0.515
# 6/200 lr=0.00100 - loss:0.410, acc:51.447, val_loss:0.412, val_acc:48.129
# Best loss:0.412, Best accuracy:51.620, Best F1-score:0.515
# 7/200 lr=0.00100 - loss:0.417, acc:51.013, val_loss:0.412, val_acc:50.039
# Best loss:0.412, Best accuracy:51.620, Best F1-score:0.515
# 8/200 lr=0.00100 - loss:0.414, acc:50.748, val_loss:0.413, val_acc:49.691
# Best loss:0.412, Best accuracy:51.620, Best F1-score:0.515
# 9/200 lr=0.00100 - loss:0.406, acc:52.813, val_loss:0.412, val_acc:48.650
# Best loss:0.412, Best accuracy:51.620, Best F1-score:0.515
# 10/200 lr=0.00100 - loss:0.408, acc:51.669, val_loss:0.418, val_acc:50.058
# Best loss:0.412, Best accuracy:51.620, Best F1-score:0.515
# 11/200 lr=0.00100 - loss:0.407, acc:51.567, val_loss:0.408, val_acc:51.254
# Best loss:0.412, Best accuracy:51.620, Best F1-score:0.515
# 12/200 lr=0.00100 - loss:0.404, acc:53.154, val_loss:0.409, val_acc:49.788
# Best loss:0.412, Best accuracy:51.620, Best F1-score:0.515
# 13/200 lr=0.00100 - loss:0.403, acc:52.934, val_loss:0.412, val_acc:47.955
# Best loss:0.412, Best accuracy:51.620, Best F1-score:0.515
# 14/200 lr=0.00100 - loss:0.402, acc:53.040, val_loss:0.396, val_acc:52.739
# Best loss:0.412, Best accuracy:51.620, Best F1-score:0.515
# 15/200 lr=0.00100 - loss:0.396, acc:54.149, val_loss:0.399, val_acc:51.080
# Best loss:0.396, Best accuracy:52.739, Best F1-score:0.517
# 16/200 lr=0.00100 - loss:0.402, acc:53.356, val_loss:0.401, val_acc:50.386
# Best loss:0.396, Best accuracy:52.739, Best F1-score:0.517
# 17/200 lr=0.00100 - loss:0.404, acc:52.609, val_loss:0.398, val_acc:53.356
# Best loss:0.396, Best accuracy:52.739, Best F1-score:0.517
# 18/200 lr=0.00100 - loss:0.398, acc:53.955, val_loss:0.388, val_acc:53.704
# Best loss:0.398, Best accuracy:53.356, Best F1-score:0.534
# 19/200 lr=0.00100 - loss:0.399, acc:53.466, val_loss:0.402, val_acc:49.961
# Best loss:0.388, Best accuracy:53.704, Best F1-score:0.537
# 20/200 lr=0.00100 - loss:0.400, acc:53.285, val_loss:0.392, val_acc:51.968
# Best loss:0.388, Best accuracy:53.704, Best F1-score:0.537
# 21/200 lr=0.00100 - loss:0.398, acc:54.554, val_loss:0.393, val_acc:53.607
# Best loss:0.388, Best accuracy:53.704, Best F1-score:0.537
# 22/200 lr=0.00100 - loss:0.393, acc:54.412, val_loss:0.396, val_acc:51.447
# Best loss:0.388, Best accuracy:53.704, Best F1-score:0.537
# 23/200 lr=0.00100 - loss:0.389, acc:56.165, val_loss:0.395, val_acc:51.968
# Best loss:0.388, Best accuracy:53.704, Best F1-score:0.537
# 24/200 lr=0.00100 - loss:0.391, acc:55.362, val_loss:0.386, val_acc:52.836
# Best loss:0.388, Best accuracy:53.704, Best F1-score:0.537
# 25/200 lr=0.00100 - loss:0.392, acc:55.415, val_loss:0.386, val_acc:52.392
# Best loss:0.388, Best accuracy:53.704, Best F1-score:0.537
# 26/200 lr=0.00100 - loss:0.390, acc:55.019, val_loss:0.395, val_acc:51.678
# Best loss:0.388, Best accuracy:53.704, Best F1-score:0.537
# 27/200 lr=0.00100 - loss:0.385, acc:56.417, val_loss:0.383, val_acc:55.093
# Best loss:0.388, Best accuracy:53.704, Best F1-score:0.537
# 28/200 lr=0.00100 - loss:0.382, acc:57.327, val_loss:0.390, val_acc:53.954
# Best loss:0.383, Best accuracy:55.093, Best F1-score:0.555
# 29/200 lr=0.00100 - loss:0.381, acc:56.626, val_loss:0.375, val_acc:56.231
# Best loss:0.383, Best accuracy:55.093, Best F1-score:0.555
# 30/200 lr=0.00100 - loss:0.378, acc:57.256, val_loss:0.384, val_acc:53.781
# Best loss:0.375, Best accuracy:56.231, Best F1-score:0.565
# 31/200 lr=0.00100 - loss:0.378, acc:58.053, val_loss:0.386, val_acc:53.511
# Best loss:0.375, Best accuracy:56.231, Best F1-score:0.565
# 32/200 lr=0.00100 - loss:0.375, acc:58.258, val_loss:0.371, val_acc:55.170
# Best loss:0.375, Best accuracy:56.231, Best F1-score:0.565
# 33/200 lr=0.00100 - loss:0.375, acc:58.738, val_loss:0.375, val_acc:54.745
# Best loss:0.375, Best accuracy:56.231, Best F1-score:0.565
# 34/200 lr=0.00100 - loss:0.368, acc:59.566, val_loss:0.369, val_acc:56.308
# Best loss:0.375, Best accuracy:56.231, Best F1-score:0.565
# 35/200 lr=0.00100 - loss:0.367, acc:59.533, val_loss:0.375, val_acc:54.225
# Best loss:0.369, Best accuracy:56.308, Best F1-score:0.563
# 36/200 lr=0.00100 - loss:0.371, acc:58.941, val_loss:0.372, val_acc:56.481
# Best loss:0.369, Best accuracy:56.308, Best F1-score:0.563
# 37/200 lr=0.00100 - loss:0.369, acc:59.371, val_loss:0.367, val_acc:55.440
# Best loss:0.372, Best accuracy:56.481, Best F1-score:0.556
# 38/200 lr=0.00100 - loss:0.367, acc:59.190, val_loss:0.366, val_acc:57.002
# Best loss:0.372, Best accuracy:56.481, Best F1-score:0.556
# 39/200 lr=0.00100 - loss:0.357, acc:61.812, val_loss:0.370, val_acc:55.961
# Best loss:0.366, Best accuracy:57.002, Best F1-score:0.563
# 40/200 lr=0.00100 - loss:0.358, acc:61.258, val_loss:0.359, val_acc:58.044
# Best loss:0.366, Best accuracy:57.002, Best F1-score:0.563
# 41/200 lr=0.00100 - loss:0.361, acc:60.679, val_loss:0.376, val_acc:54.649
# Best loss:0.359, Best accuracy:58.044, Best F1-score:0.575
# 42/200 lr=0.00100 - loss:0.358, acc:61.200, val_loss:0.361, val_acc:57.697
# Best loss:0.359, Best accuracy:58.044, Best F1-score:0.575
# 43/200 lr=0.00100 - loss:0.355, acc:61.826, val_loss:0.356, val_acc:57.774
# Best loss:0.359, Best accuracy:58.044, Best F1-score:0.575
# 44/200 lr=0.00100 - loss:0.353, acc:61.799, val_loss:0.353, val_acc:58.218
# Best loss:0.359, Best accuracy:58.044, Best F1-score:0.575
# 45/200 lr=0.00100 - loss:0.351, acc:62.551, val_loss:0.358, val_acc:58.565
# Best loss:0.353, Best accuracy:58.218, Best F1-score:0.575
# 46/200 lr=0.00100 - loss:0.350, acc:62.162, val_loss:0.355, val_acc:58.218
# Best loss:0.358, Best accuracy:58.565, Best F1-score:0.584
# 47/200 lr=0.00100 - loss:0.351, acc:61.745, val_loss:0.358, val_acc:57.350
# Best loss:0.358, Best accuracy:58.565, Best F1-score:0.584
# 48/200 lr=0.00100 - loss:0.350, acc:62.656, val_loss:0.365, val_acc:56.559
# Best loss:0.358, Best accuracy:58.565, Best F1-score:0.584
# 49/200 lr=0.00100 - loss:0.345, acc:63.622, val_loss:0.351, val_acc:59.529
# Best loss:0.358, Best accuracy:58.565, Best F1-score:0.584
# 50/200 lr=0.00100 - loss:0.339, acc:64.205, val_loss:0.356, val_acc:57.079
# Best loss:0.351, Best accuracy:59.529, Best F1-score:0.592
# 51/200 lr=0.00100 - loss:0.343, acc:64.094, val_loss:0.358, val_acc:57.600
# Best loss:0.351, Best accuracy:59.529, Best F1-score:0.592
# 52/200 lr=0.00100 - loss:0.339, acc:64.109, val_loss:0.345, val_acc:60.147
# Best loss:0.351, Best accuracy:59.529, Best F1-score:0.592
# 53/200 lr=0.00100 - loss:0.341, acc:64.209, val_loss:0.384, val_acc:52.296
# Best loss:0.345, Best accuracy:60.147, Best F1-score:0.602
# 54/200 lr=0.00100 - loss:0.346, acc:63.726, val_loss:0.357, val_acc:57.079
# Best loss:0.345, Best accuracy:60.147, Best F1-score:0.602
# 55/200 lr=0.00100 - loss:0.338, acc:64.777, val_loss:0.346, val_acc:57.774
# Best loss:0.345, Best accuracy:60.147, Best F1-score:0.602
# 56/200 lr=0.00100 - loss:0.337, acc:64.657, val_loss:0.357, val_acc:57.253
# Best loss:0.345, Best accuracy:60.147, Best F1-score:0.602
# 57/200 lr=0.00100 - loss:0.336, acc:65.055, val_loss:0.355, val_acc:58.044
# Best loss:0.345, Best accuracy:60.147, Best F1-score:0.602
# 58/200 lr=0.00100 - loss:0.336, acc:64.370, val_loss:0.353, val_acc:57.697
# Best loss:0.345, Best accuracy:60.147, Best F1-score:0.602
# 59/200 lr=0.00100 - loss:0.330, acc:65.674, val_loss:0.350, val_acc:58.121
# Best loss:0.345, Best accuracy:60.147, Best F1-score:0.602
# 60/200 lr=0.00100 - loss:0.328, acc:66.382, val_loss:0.355, val_acc:58.140
# Best loss:0.345, Best accuracy:60.147, Best F1-score:0.602
# 61/200 lr=0.00100 - loss:0.329, acc:65.681, val_loss:0.354, val_acc:56.732
# Best loss:0.345, Best accuracy:60.147, Best F1-score:0.602
# 62/200 lr=0.00086 - loss:0.322, acc:67.334, val_loss:0.353, val_acc:60.320
# Best loss:0.345, Best accuracy:60.147, Best F1-score:0.602
# 63/200 lr=0.00086 - loss:0.326, acc:66.542, val_loss:0.347, val_acc:58.295
# Best loss:0.353, Best accuracy:60.320, Best F1-score:0.601
# 64/200 lr=0.00086 - loss:0.324, acc:66.400, val_loss:0.350, val_acc:56.559
# Best loss:0.353, Best accuracy:60.320, Best F1-score:0.601
# 65/200 lr=0.00086 - loss:0.321, acc:66.707, val_loss:0.347, val_acc:57.427
# Best loss:0.353, Best accuracy:60.320, Best F1-score:0.601
# 66/200 lr=0.00086 - loss:0.323, acc:66.411, val_loss:0.342, val_acc:59.259
# Best loss:0.353, Best accuracy:60.320, Best F1-score:0.601
# 67/200 lr=0.00086 - loss:0.323, acc:66.633, val_loss:0.350, val_acc:58.912
# Best loss:0.353, Best accuracy:60.320, Best F1-score:0.601
# 68/200 lr=0.00086 - loss:0.313, acc:68.899, val_loss:0.350, val_acc:56.732
# Best loss:0.353, Best accuracy:60.320, Best F1-score:0.601
# 69/200 lr=0.00086 - loss:0.311, acc:68.993, val_loss:0.356, val_acc:59.626
# Best loss:0.353, Best accuracy:60.320, Best F1-score:0.601
# 70/200 lr=0.00086 - loss:0.316, acc:67.791, val_loss:0.345, val_acc:56.983
# Best loss:0.353, Best accuracy:60.320, Best F1-score:0.601
# 71/200 lr=0.00086 - loss:0.313, acc:67.940, val_loss:0.342, val_acc:60.648
# Best loss:0.353, Best accuracy:60.320, Best F1-score:0.601
# 72/200 lr=0.00086 - loss:0.317, acc:67.871, val_loss:0.340, val_acc:60.822
# Best loss:0.342, Best accuracy:60.648, Best F1-score:0.609
# 73/200 lr=0.00086 - loss:0.308, acc:69.562, val_loss:0.353, val_acc:56.462
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 74/200 lr=0.00086 - loss:0.304, acc:69.738, val_loss:0.339, val_acc:58.565
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 75/200 lr=0.00086 - loss:0.303, acc:69.444, val_loss:0.341, val_acc:57.099
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 76/200 lr=0.00086 - loss:0.306, acc:69.197, val_loss:0.345, val_acc:58.661
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 77/200 lr=0.00086 - loss:0.304, acc:69.658, val_loss:0.345, val_acc:58.488
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 78/200 lr=0.00086 - loss:0.304, acc:69.667, val_loss:0.346, val_acc:59.954
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 79/200 lr=0.00086 - loss:0.302, acc:69.994, val_loss:0.341, val_acc:59.703
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 80/200 lr=0.00086 - loss:0.296, acc:71.472, val_loss:0.353, val_acc:57.697
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 81/200 lr=0.00086 - loss:0.298, acc:71.136, val_loss:0.343, val_acc:58.835
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 82/200 lr=0.00074 - loss:0.295, acc:70.831, val_loss:0.338, val_acc:58.912
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 83/200 lr=0.00074 - loss:0.295, acc:70.544, val_loss:0.344, val_acc:58.391
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 84/200 lr=0.00074 - loss:0.298, acc:70.540, val_loss:0.350, val_acc:58.912
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 85/200 lr=0.00074 - loss:0.290, acc:71.412, val_loss:0.339, val_acc:58.391
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 86/200 lr=0.00074 - loss:0.290, acc:71.866, val_loss:0.340, val_acc:58.835
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 87/200 lr=0.00074 - loss:0.296, acc:70.780, val_loss:0.345, val_acc:57.620
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 88/200 lr=0.00074 - loss:0.290, acc:71.893, val_loss:0.349, val_acc:57.099
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 89/200 lr=0.00074 - loss:0.291, acc:71.686, val_loss:0.348, val_acc:58.314
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 90/200 lr=0.00074 - loss:0.288, acc:72.589, val_loss:0.344, val_acc:61.188
# Best loss:0.340, Best accuracy:60.822, Best F1-score:0.603
# 91/200 lr=0.00074 - loss:0.286, acc:72.634, val_loss:0.336, val_acc:60.822
# Best loss:0.344, Best accuracy:61.188, Best F1-score:0.605
# 92/200 lr=0.00074 - loss:0.287, acc:72.362, val_loss:0.349, val_acc:60.475
# Best loss:0.344, Best accuracy:61.188, Best F1-score:0.605
# 93/200 lr=0.00074 - loss:0.286, acc:72.073, val_loss:0.334, val_acc:61.188
# Best loss:0.344, Best accuracy:61.188, Best F1-score:0.605
# 94/200 lr=0.00074 - loss:0.284, acc:72.454, val_loss:0.330, val_acc:61.786
# Best loss:0.344, Best accuracy:61.188, Best F1-score:0.605
# 95/200 lr=0.00074 - loss:0.284, acc:72.403, val_loss:0.343, val_acc:59.877
# Best loss:0.330, Best accuracy:61.786, Best F1-score:0.616
# 96/200 lr=0.00074 - loss:0.279, acc:73.288, val_loss:0.349, val_acc:60.301
# Best loss:0.330, Best accuracy:61.786, Best F1-score:0.616
# 97/200 lr=0.00074 - loss:0.288, acc:71.813, val_loss:0.332, val_acc:60.127
# Best loss:0.330, Best accuracy:61.786, Best F1-score:0.616
# 98/200 lr=0.00074 - loss:0.279, acc:73.008, val_loss:0.343, val_acc:61.516
# Best loss:0.330, Best accuracy:61.786, Best F1-score:0.616
# 99/200 lr=0.00074 - loss:0.280, acc:73.099, val_loss:0.348, val_acc:60.147
# Best loss:0.330, Best accuracy:61.786, Best F1-score:0.616
# 100/200 lr=0.00074 - loss:0.275, acc:74.067, val_loss:0.343, val_acc:59.259
# Best loss:0.330, Best accuracy:61.786, Best F1-score:0.616
# 101/200 lr=0.00074 - loss:0.271, acc:75.298, val_loss:0.333, val_acc:62.905
# Best loss:0.330, Best accuracy:61.786, Best F1-score:0.616
# 102/200 lr=0.00064 - loss:0.278, acc:73.860, val_loss:0.332, val_acc:61.863
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 103/200 lr=0.00064 - loss:0.275, acc:74.397, val_loss:0.340, val_acc:60.745
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 104/200 lr=0.00064 - loss:0.271, acc:74.432, val_loss:0.346, val_acc:59.954
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 105/200 lr=0.00064 - loss:0.269, acc:74.617, val_loss:0.355, val_acc:58.912
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 106/200 lr=0.00064 - loss:0.272, acc:74.381, val_loss:0.339, val_acc:61.960
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 107/200 lr=0.00064 - loss:0.267, acc:75.312, val_loss:0.348, val_acc:58.738
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 108/200 lr=0.00064 - loss:0.265, acc:75.699, val_loss:0.355, val_acc:59.954
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 109/200 lr=0.00064 - loss:0.264, acc:76.024, val_loss:0.341, val_acc:60.918
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 110/200 lr=0.00064 - loss:0.271, acc:75.036, val_loss:0.343, val_acc:60.745
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 111/200 lr=0.00064 - loss:0.271, acc:74.441, val_loss:0.342, val_acc:60.301
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 112/200 lr=0.00064 - loss:0.266, acc:75.804, val_loss:0.342, val_acc:60.822
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 113/200 lr=0.00064 - loss:0.262, acc:76.204, val_loss:0.339, val_acc:61.439
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 114/200 lr=0.00064 - loss:0.260, acc:76.440, val_loss:0.352, val_acc:57.427
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 115/200 lr=0.00064 - loss:0.264, acc:75.621, val_loss:0.347, val_acc:60.127
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 116/200 lr=0.00064 - loss:0.257, acc:77.135, val_loss:0.342, val_acc:59.606
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 117/200 lr=0.00064 - loss:0.265, acc:75.427, val_loss:0.349, val_acc:60.571
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 118/200 lr=0.00064 - loss:0.264, acc:75.748, val_loss:0.343, val_acc:60.745
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 119/200 lr=0.00064 - loss:0.258, acc:76.694, val_loss:0.357, val_acc:60.050
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 120/200 lr=0.00064 - loss:0.260, acc:76.349, val_loss:0.341, val_acc:62.384
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 121/200 lr=0.00064 - loss:0.257, acc:76.790, val_loss:0.345, val_acc:61.786
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 122/200 lr=0.00055 - loss:0.262, acc:75.904, val_loss:0.345, val_acc:60.995
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 123/200 lr=0.00055 - loss:0.259, acc:76.349, val_loss:0.349, val_acc:62.211
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 124/200 lr=0.00055 - loss:0.251, acc:77.902, val_loss:0.342, val_acc:59.954
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 125/200 lr=0.00055 - loss:0.252, acc:77.110, val_loss:0.348, val_acc:59.606
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 126/200 lr=0.00055 - loss:0.256, acc:76.765, val_loss:0.342, val_acc:59.954
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 127/200 lr=0.00055 - loss:0.255, acc:76.549, val_loss:0.352, val_acc:58.835
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 128/200 lr=0.00055 - loss:0.252, acc:77.707, val_loss:0.343, val_acc:60.745
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 129/200 lr=0.00055 - loss:0.252, acc:77.473, val_loss:0.345, val_acc:61.265
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 130/200 lr=0.00055 - loss:0.258, acc:76.309, val_loss:0.348, val_acc:61.439
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 131/200 lr=0.00055 - loss:0.254, acc:77.112, val_loss:0.341, val_acc:59.086
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 132/200 lr=0.00055 - loss:0.246, acc:78.759, val_loss:0.347, val_acc:59.606
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 133/200 lr=0.00055 - loss:0.249, acc:78.187, val_loss:0.344, val_acc:59.510
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 134/200 lr=0.00055 - loss:0.248, acc:78.410, val_loss:0.348, val_acc:59.259
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 135/200 lr=0.00055 - loss:0.249, acc:77.887, val_loss:0.351, val_acc:60.301
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 136/200 lr=0.00055 - loss:0.250, acc:78.412, val_loss:0.346, val_acc:58.816
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 137/200 lr=0.00055 - loss:0.243, acc:78.196, val_loss:0.345, val_acc:61.863
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 138/200 lr=0.00055 - loss:0.247, acc:77.528, val_loss:0.343, val_acc:61.960
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 139/200 lr=0.00055 - loss:0.242, acc:78.543, val_loss:0.347, val_acc:60.301
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 140/200 lr=0.00055 - loss:0.241, acc:79.405, val_loss:0.348, val_acc:59.606
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 141/200 lr=0.00055 - loss:0.243, acc:79.156, val_loss:0.355, val_acc:59.163
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 142/200 lr=0.00047 - loss:0.242, acc:79.080, val_loss:0.354, val_acc:60.378
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 143/200 lr=0.00047 - loss:0.235, acc:80.406, val_loss:0.347, val_acc:59.684
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 144/200 lr=0.00047 - loss:0.239, acc:79.376, val_loss:0.350, val_acc:61.169
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 145/200 lr=0.00047 - loss:0.240, acc:79.265, val_loss:0.346, val_acc:60.899
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 146/200 lr=0.00047 - loss:0.237, acc:79.345, val_loss:0.353, val_acc:58.044
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 147/200 lr=0.00047 - loss:0.233, acc:79.910, val_loss:0.343, val_acc:60.822
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 148/200 lr=0.00047 - loss:0.232, acc:80.616, val_loss:0.356, val_acc:59.684
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 149/200 lr=0.00047 - loss:0.240, acc:78.563, val_loss:0.349, val_acc:60.050
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 150/200 lr=0.00047 - loss:0.235, acc:79.665, val_loss:0.346, val_acc:60.301
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 151/200 lr=0.00047 - loss:0.232, acc:80.297, val_loss:0.356, val_acc:59.163
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 152/200 lr=0.00047 - loss:0.226, acc:81.317, val_loss:0.349, val_acc:59.780
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 153/200 lr=0.00047 - loss:0.233, acc:80.302, val_loss:0.345, val_acc:62.037
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 154/200 lr=0.00047 - loss:0.234, acc:79.857, val_loss:0.344, val_acc:60.899
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 155/200 lr=0.00047 - loss:0.237, acc:79.846, val_loss:0.348, val_acc:61.960
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# 156/200 lr=0.00047 - loss:0.234, acc:80.106, val_loss:0.356, val_acc:59.954
# Best loss:0.333, Best accuracy:62.905, Best F1-score:0.628
# ...
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 83/200 lr=0.00074 - loss:0.296, acc:70.555, val_loss:0.313, val_acc:61.883
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 84/200 lr=0.00074 - loss:0.293, acc:72.233, val_loss:0.322, val_acc:64.487
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 85/200 lr=0.00074 - loss:0.294, acc:71.410, val_loss:0.302, val_acc:65.972
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 86/200 lr=0.00074 - loss:0.288, acc:72.233, val_loss:0.300, val_acc:65.278
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 87/200 lr=0.00074 - loss:0.292, acc:72.093, val_loss:0.311, val_acc:63.175
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 88/200 lr=0.00074 - loss:0.289, acc:72.120, val_loss:0.306, val_acc:65.008
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 89/200 lr=0.00074 - loss:0.289, acc:71.548, val_loss:0.310, val_acc:63.619
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 90/200 lr=0.00074 - loss:0.292, acc:71.635, val_loss:0.312, val_acc:64.931
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 91/200 lr=0.00074 - loss:0.286, acc:72.685, val_loss:0.305, val_acc:65.104
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 92/200 lr=0.00074 - loss:0.285, acc:72.523, val_loss:0.302, val_acc:65.972
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 93/200 lr=0.00074 - loss:0.289, acc:71.877, val_loss:0.306, val_acc:65.278
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 94/200 lr=0.00074 - loss:0.286, acc:72.603, val_loss:0.329, val_acc:61.786
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 95/200 lr=0.00074 - loss:0.287, acc:72.407, val_loss:0.305, val_acc:65.008
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 96/200 lr=0.00074 - loss:0.287, acc:72.627, val_loss:0.304, val_acc:64.834
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 97/200 lr=0.00074 - loss:0.280, acc:73.079, val_loss:0.300, val_acc:64.313
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 98/200 lr=0.00074 - loss:0.280, acc:73.725, val_loss:0.303, val_acc:66.667
# Best loss:0.302, Best accuracy:66.146, Best F1-score:0.661
# 99/200 lr=0.00074 - loss:0.280, acc:73.567, val_loss:0.307, val_acc:64.834
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 100/200 lr=0.00074 - loss:0.286, acc:72.799, val_loss:0.310, val_acc:64.140
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 101/200 lr=0.00074 - loss:0.277, acc:74.101, val_loss:0.309, val_acc:65.008
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 102/200 lr=0.00064 - loss:0.279, acc:73.644, val_loss:0.302, val_acc:65.451
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 103/200 lr=0.00064 - loss:0.276, acc:74.717, val_loss:0.300, val_acc:65.625
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 104/200 lr=0.00064 - loss:0.276, acc:74.010, val_loss:0.317, val_acc:62.751
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 105/200 lr=0.00064 - loss:0.274, acc:74.637, val_loss:0.303, val_acc:65.104
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 106/200 lr=0.00064 - loss:0.270, acc:75.053, val_loss:0.307, val_acc:65.008
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 107/200 lr=0.00064 - loss:0.270, acc:74.953, val_loss:0.309, val_acc:63.272
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 108/200 lr=0.00064 - loss:0.270, acc:74.697, val_loss:0.310, val_acc:66.397
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 109/200 lr=0.00064 - loss:0.274, acc:74.691, val_loss:0.328, val_acc:66.049
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 110/200 lr=0.00064 - loss:0.269, acc:75.036, val_loss:0.313, val_acc:62.905
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 111/200 lr=0.00064 - loss:0.267, acc:75.198, val_loss:0.304, val_acc:65.258
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 112/200 lr=0.00064 - loss:0.268, acc:75.314, val_loss:0.311, val_acc:63.792
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 113/200 lr=0.00064 - loss:0.273, acc:74.426, val_loss:0.308, val_acc:66.493
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 114/200 lr=0.00064 - loss:0.272, acc:74.648, val_loss:0.319, val_acc:62.577
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 115/200 lr=0.00064 - loss:0.271, acc:74.953, val_loss:0.304, val_acc:65.529
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 116/200 lr=0.00064 - loss:0.269, acc:75.058, val_loss:0.319, val_acc:63.098
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 117/200 lr=0.00064 - loss:0.272, acc:74.613, val_loss:0.305, val_acc:66.917
# Best loss:0.303, Best accuracy:66.667, Best F1-score:0.669
# 118/200 lr=0.00064 - loss:0.267, acc:75.071, val_loss:0.304, val_acc:67.014
# Best loss:0.305, Best accuracy:66.917, Best F1-score:0.669
# 119/200 lr=0.00064 - loss:0.259, acc:76.456, val_loss:0.305, val_acc:65.278
# Best loss:0.304, Best accuracy:67.014, Best F1-score:0.671
# 120/200 lr=0.00064 - loss:0.262, acc:75.795, val_loss:0.317, val_acc:64.313
# Best loss:0.304, Best accuracy:67.014, Best F1-score:0.671
# 121/200 lr=0.00064 - loss:0.262, acc:75.799, val_loss:0.303, val_acc:65.529
# Best loss:0.304, Best accuracy:67.014, Best F1-score:0.671
# 122/200 lr=0.00055 - loss:0.261, acc:76.320, val_loss:0.309, val_acc:65.606
# Best loss:0.304, Best accuracy:67.014, Best F1-score:0.671
# 123/200 lr=0.00055 - loss:0.260, acc:76.244, val_loss:0.312, val_acc:65.008
# Best loss:0.304, Best accuracy:67.014, Best F1-score:0.671
# 124/200 lr=0.00055 - loss:0.262, acc:75.650, val_loss:0.318, val_acc:61.786
# Best loss:0.304, Best accuracy:67.014, Best F1-score:0.671
# 125/200 lr=0.00055 - loss:0.259, acc:76.536, val_loss:0.305, val_acc:66.917
# Best loss:0.304, Best accuracy:67.014, Best F1-score:0.671
# 126/200 lr=0.00055 - loss:0.258, acc:76.705, val_loss:0.311, val_acc:63.522
# Best loss:0.304, Best accuracy:67.014, Best F1-score:0.671
# 127/200 lr=0.00055 - loss:0.259, acc:76.852, val_loss:0.308, val_acc:65.972
# Best loss:0.304, Best accuracy:67.014, Best F1-score:0.671
# 128/200 lr=0.00055 - loss:0.255, acc:77.426, val_loss:0.302, val_acc:67.188
# Best loss:0.304, Best accuracy:67.014, Best F1-score:0.671
# 129/200 lr=0.00055 - loss:0.256, acc:77.230, val_loss:0.318, val_acc:63.619
# Best loss:0.302, Best accuracy:67.188, Best F1-score:0.673
# 130/200 lr=0.00055 - loss:0.255, acc:77.382, val_loss:0.308, val_acc:66.049
# Best loss:0.302, Best accuracy:67.188, Best F1-score:0.673
# 131/200 lr=0.00055 - loss:0.252, acc:77.593, val_loss:0.309, val_acc:64.043
# Best loss:0.302, Best accuracy:67.188, Best F1-score:0.673
# 132/200 lr=0.00055 - loss:0.254, acc:77.086, val_loss:0.308, val_acc:65.529
# Best loss:0.302, Best accuracy:67.188, Best F1-score:0.673
# 133/200 lr=0.00055 - loss:0.257, acc:77.081, val_loss:0.309, val_acc:67.612
# Best loss:0.302, Best accuracy:67.188, Best F1-score:0.673
# 134/200 lr=0.00055 - loss:0.256, acc:76.945, val_loss:0.312, val_acc:63.792
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 135/200 lr=0.00055 - loss:0.251, acc:78.049, val_loss:0.306, val_acc:66.570
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 136/200 lr=0.00055 - loss:0.252, acc:77.651, val_loss:0.302, val_acc:66.146
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 137/200 lr=0.00055 - loss:0.249, acc:78.192, val_loss:0.324, val_acc:62.751
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 138/200 lr=0.00055 - loss:0.251, acc:77.782, val_loss:0.301, val_acc:65.625
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 139/200 lr=0.00055 - loss:0.247, acc:78.759, val_loss:0.313, val_acc:65.278
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 140/200 lr=0.00055 - loss:0.247, acc:77.767, val_loss:0.304, val_acc:66.049
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 141/200 lr=0.00055 - loss:0.249, acc:77.983, val_loss:0.316, val_acc:64.757
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 142/200 lr=0.00047 - loss:0.242, acc:79.251, val_loss:0.314, val_acc:65.876
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 143/200 lr=0.00047 - loss:0.245, acc:78.428, val_loss:0.311, val_acc:65.008
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 144/200 lr=0.00047 - loss:0.246, acc:78.263, val_loss:0.314, val_acc:64.911
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 145/200 lr=0.00047 - loss:0.242, acc:78.835, val_loss:0.322, val_acc:62.654
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 146/200 lr=0.00047 - loss:0.240, acc:79.440, val_loss:0.309, val_acc:65.799
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 147/200 lr=0.00047 - loss:0.242, acc:79.100, val_loss:0.320, val_acc:63.870
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 148/200 lr=0.00047 - loss:0.248, acc:78.314, val_loss:0.303, val_acc:65.876
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 149/200 lr=0.00047 - loss:0.242, acc:79.193, val_loss:0.319, val_acc:65.972
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 150/200 lr=0.00047 - loss:0.238, acc:79.436, val_loss:0.311, val_acc:65.181
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 151/200 lr=0.00047 - loss:0.238, acc:79.790, val_loss:0.308, val_acc:65.606
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 152/200 lr=0.00047 - loss:0.239, acc:79.601, val_loss:0.313, val_acc:65.702
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 153/200 lr=0.00047 - loss:0.239, acc:79.975, val_loss:0.305, val_acc:65.085
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 154/200 lr=0.00047 - loss:0.239, acc:79.358, val_loss:0.309, val_acc:66.840
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 155/200 lr=0.00047 - loss:0.233, acc:80.406, val_loss:0.303, val_acc:68.056
# Best loss:0.309, Best accuracy:67.612, Best F1-score:0.674
# 156/200 lr=0.00047 - loss:0.240, acc:79.665, val_loss:0.311, val_acc:67.091
# Best loss:0.303, Best accuracy:68.056, Best F1-score:0.684
# 157/200 lr=0.00047 - loss:0.236, acc:80.077, val_loss:0.306, val_acc:66.840
# Best loss:0.303, Best accuracy:68.056, Best F1-score:0.684
# 158/200 lr=0.00047 - loss:0.237, acc:79.596, val_loss:0.313, val_acc:63.619
# Best loss:0.303, Best accuracy:68.056, Best F1-score:0.684
# 159/200 lr=0.00047 - loss:0.238, acc:79.425, val_loss:0.316, val_acc:66.493
# Best loss:0.303, Best accuracy:68.056, Best F1-score:0.684
# 160/200 lr=0.00047 - loss:0.236, acc:79.167, val_loss:0.314, val_acc:64.660
# Best loss:0.303, Best accuracy:68.056, Best F1-score:0.684
# 161/200 lr=0.00047 - loss:0.237, acc:80.360, val_loss:0.318, val_acc:64.911
# Best loss:0.303, Best accuracy:68.056, Best F1-score:0.684
# 162/200 lr=0.00041 - loss:0.236, acc:79.714, val_loss:0.309, val_acc:65.529
# Best loss:0.303, Best accuracy:68.056, Best F1-score:0.684
# 163/200 lr=0.00041 - loss:0.239, acc:79.565, val_loss:0.306, val_acc:65.702
# Best loss:0.303, Best accuracy:68.056, Best F1-score:0.684
# 164/200 lr=0.00041 - loss:0.234, acc:80.177, val_loss:0.299, val_acc:69.097
# Best loss:0.303, Best accuracy:68.056, Best F1-score:0.684
# 165/200 lr=0.00041 - loss:0.231, acc:80.458, val_loss:0.313, val_acc:66.223
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 166/200 lr=0.00041 - loss:0.232, acc:80.451, val_loss:0.304, val_acc:65.529
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 167/200 lr=0.00041 - loss:0.230, acc:80.847, val_loss:0.310, val_acc:66.319
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 168/200 lr=0.00041 - loss:0.233, acc:80.280, val_loss:0.309, val_acc:65.432
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 169/200 lr=0.00041 - loss:0.225, acc:81.308, val_loss:0.312, val_acc:64.660
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 170/200 lr=0.00041 - loss:0.229, acc:80.987, val_loss:0.311, val_acc:67.438
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 171/200 lr=0.00041 - loss:0.227, acc:80.974, val_loss:0.313, val_acc:67.882
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 172/200 lr=0.00041 - loss:0.227, acc:81.493, val_loss:0.313, val_acc:66.493
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 173/200 lr=0.00041 - loss:0.229, acc:81.248, val_loss:0.310, val_acc:65.702
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 174/200 lr=0.00041 - loss:0.228, acc:81.399, val_loss:0.311, val_acc:65.181
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 175/200 lr=0.00041 - loss:0.230, acc:80.538, val_loss:0.304, val_acc:67.612
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 176/200 lr=0.00041 - loss:0.225, acc:81.884, val_loss:0.317, val_acc:65.876
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 177/200 lr=0.00041 - loss:0.226, acc:81.617, val_loss:0.305, val_acc:65.008
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 178/200 lr=0.00041 - loss:0.226, acc:81.401, val_loss:0.303, val_acc:67.265
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 179/200 lr=0.00041 - loss:0.224, acc:81.464, val_loss:0.307, val_acc:66.840
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 180/200 lr=0.00041 - loss:0.225, acc:81.869, val_loss:0.330, val_acc:61.439
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 181/200 lr=0.00041 - loss:0.228, acc:80.647, val_loss:0.307, val_acc:66.647
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 182/200 lr=0.00035 - loss:0.222, acc:82.125, val_loss:0.315, val_acc:67.014
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 183/200 lr=0.00035 - loss:0.225, acc:81.795, val_loss:0.311, val_acc:66.049
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 184/200 lr=0.00035 - loss:0.223, acc:82.441, val_loss:0.312, val_acc:66.744
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 185/200 lr=0.00035 - loss:0.220, acc:82.577, val_loss:0.308, val_acc:66.570
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 186/200 lr=0.00035 - loss:0.217, acc:82.581, val_loss:0.308, val_acc:65.779
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 187/200 lr=0.00035 - loss:0.222, acc:81.944, val_loss:0.312, val_acc:66.917
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 188/200 lr=0.00035 - loss:0.218, acc:82.657, val_loss:0.305, val_acc:66.917
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 189/200 lr=0.00035 - loss:0.223, acc:81.755, val_loss:0.312, val_acc:66.223
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 190/200 lr=0.00035 - loss:0.217, acc:82.421, val_loss:0.311, val_acc:66.570
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 191/200 lr=0.00035 - loss:0.220, acc:82.136, val_loss:0.310, val_acc:66.917
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 192/200 lr=0.00035 - loss:0.219, acc:82.196, val_loss:0.316, val_acc:64.911
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 193/200 lr=0.00035 - loss:0.217, acc:82.781, val_loss:0.313, val_acc:65.876
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 194/200 lr=0.00035 - loss:0.219, acc:82.712, val_loss:0.312, val_acc:66.744
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 195/200 lr=0.00035 - loss:0.217, acc:82.537, val_loss:0.308, val_acc:65.355
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 196/200 lr=0.00035 - loss:0.216, acc:82.926, val_loss:0.316, val_acc:65.529
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 197/200 lr=0.00035 - loss:0.216, acc:82.859, val_loss:0.311, val_acc:66.917
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 198/200 lr=0.00035 - loss:0.215, acc:82.797, val_loss:0.311, val_acc:68.750
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 199/200 lr=0.00035 - loss:0.214, acc:82.766, val_loss:0.310, val_acc:68.229
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# 200/200 lr=0.00035 - loss:0.218, acc:82.189, val_loss:0.308, val_acc:67.438
# Best loss:0.299, Best accuracy:69.097, Best F1-score:0.692
# [*] Done - acc:69.097

# %%
end()

# %%
print(f'max:{max(fold_acc)}, min:{min(fold_acc)}, average:{sum(fold_acc)/len(fold_acc)}')
# Out:
# max:69.09722222222223, min:62.905092702971565, average:66.57343112208225

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
# Out:
# WAR(Weighted Average Recall)   : 66.84%
# UAR(Unweighted Average Recall) : 66.84%
