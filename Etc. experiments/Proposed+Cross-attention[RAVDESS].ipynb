# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = 'TIMNET-dataset'
DATA_PATH = 'RAVDESS'
CLASS_LABELS = Config.RAVDESS_LABELS
k = 10

# No-reverse : (196,39,1)  ## CA: Channel-attention    ## SA : Self-attention 
model_name = 'exp1'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, dilation_rate=(2,2)),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule]),
        Lambda(function=PrimaryCapssquash)
    ])
    
  def call(self, inputs):
    return self.conv(inputs)

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.conv3 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
  
    # Q, V, K
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.cbam = CBAM(64) # sharing
    self.reshape = Reshape(target_shape=[-1, 64])
    
    self.conv4 = PrimaryCap()
    self.spatial_attn = SpatialGate()
  
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    x = inputs
    forward = x
    backward = tf.reverse(inputs, axis=[2])
    
    fx = self.conv1(forward)
    fx += self.cbam(fx)
    bx = self.conv2(backward)
    bx += self.cbam(bx)
    cross_attn_out = self.attention([fx, bx, bx]) # Q, K==V
    fx += cross_attn_out
    
    fx = self.conv3(fx)
    fx += self.cbam(fx)
    
    cap = self.conv4(fx)
    cap = tf.expand_dims(cap, axis=-1)
    cap += self.spatial_attn(cap)
    cap = tf.squeeze(cap, axis=-1)
    
    sa = self.attention([cap, cap, cap])
    sa = self.LN(sa)
    
    sa = self.lamb([cap, sa])
    sa = tf.expand_dims(sa, axis=-1)
    sa += self.spatial_attn(sa)
    cap = tf.squeeze(sa, axis=-1)
    
    capsule = self.capsule(cap)
    
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1416
#
#  sequential_1 (Sequential)   (None, 97, 18, 64)        1416
#
#  sequential_2 (Sequential)   (None, 46, 7, 64)         37300
#
#  attention (Attention)       multiple                  1
#
#  layer_normalization (LayerN  multiple                 128
#  ormalization)
#
#  lambda (Lambda)             multiple                  0
#
#  cbam (CBAM)                 multiple                  4294
#
#  reshape (Reshape)           multiple                  0 (unused)
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  spatial_gate_1 (SpatialGate  multiple                 102
#  )
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  520
#
# =================================================================
# Total params: 95,353
# Trainable params: 94,387
# Non-trainable params: 966
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}.npy', 'rb') as f:
    x = np.load(f)
    y = np.load(f)

y = to_categorical(y,num_classes=len(CLASS_LABELS))

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, test) in tqdm(enumerate(kfold.split(x, y)), desc=f'Training {k}-Fold.....'):
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = x[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_test, y_test = x[test], y[test]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_test = tf.expand_dims(x_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_test_loss = 0x3f3f3f
    best_test_acc = -1
    best_test_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        test_loss, test_acc, f1s = [], [], []
        for features, labels in batch_test:
            loss, acc, pred = test_step(model, features, labels)
            test_loss.append(loss)
            test_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(test_loss)/len(test_loss)
        val_acc = sum(test_acc)/len(test_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_test_loss:.3f}, Best accuracy:{best_test_acc:.3f}, Best F1-score:{best_test_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_test_acc < val_acc:
            best_test_acc = val_acc
            best_test_loss = val_loss
            best_test_f1 = f1_score
            model.save_weights(h5_path)
            
            
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    
    for features, labels in batch_test:
        best_pred = model(features, training=False)
        emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(labels, axis=1))
        predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
    
    
    print(f'[*] Done - acc:{best_test_acc:.3f}')
    
    plt.title(f'{i+1}-fold Loss Curve - Best acc:{best_test_acc:.3f}, Best loss:{best_test_loss:.3f}')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])

    
    save_fig_path = f'Fig/{DATA_PATH}/training/{model_name}'
    os.makedirs(save_fig_path, exist_ok=True)
    plt.savefig(f'{save_fig_path}/{i+1}-fold.PNG')
    
    plt.show()
    
    fold_acc.append(best_test_acc)
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.630, acc:18.140, val_loss:0.630, val_acc:21.250
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.614, acc:23.476, val_loss:0.613, val_acc:24.375
# Best loss:0.630, Best accuracy:21.250, Best F1-score:0.137
# 3/300 lr=0.00100 - loss:0.598, acc:27.058, val_loss:0.609, val_acc:22.500
# Best loss:0.613, Best accuracy:24.375, Best F1-score:0.171
# 4/300 lr=0.00100 - loss:0.596, acc:27.363, val_loss:0.596, val_acc:28.125
# Best loss:0.613, Best accuracy:24.375, Best F1-score:0.171
# 5/300 lr=0.00100 - loss:0.583, acc:30.716, val_loss:0.588, val_acc:28.750
# Best loss:0.596, Best accuracy:28.125, Best F1-score:0.212
# 6/300 lr=0.00100 - loss:0.574, acc:32.774, val_loss:0.576, val_acc:33.750
# Best loss:0.588, Best accuracy:28.750, Best F1-score:0.246
# 7/300 lr=0.00100 - loss:0.567, acc:33.841, val_loss:0.576, val_acc:33.750
# Best loss:0.576, Best accuracy:33.750, Best F1-score:0.304
# 8/300 lr=0.00100 - loss:0.559, acc:35.366, val_loss:0.551, val_acc:34.375
# Best loss:0.576, Best accuracy:33.750, Best F1-score:0.304
# 9/300 lr=0.00100 - loss:0.551, acc:36.814, val_loss:0.547, val_acc:36.250
# Best loss:0.551, Best accuracy:34.375, Best F1-score:0.320
# 10/300 lr=0.00100 - loss:0.542, acc:38.796, val_loss:0.542, val_acc:36.250
# Best loss:0.547, Best accuracy:36.250, Best F1-score:0.314
# 11/300 lr=0.00100 - loss:0.547, acc:36.433, val_loss:0.529, val_acc:39.375
# Best loss:0.547, Best accuracy:36.250, Best F1-score:0.314
# 12/300 lr=0.00100 - loss:0.538, acc:38.415, val_loss:0.528, val_acc:34.375
# Best loss:0.529, Best accuracy:39.375, Best F1-score:0.351
# 13/300 lr=0.00100 - loss:0.526, acc:39.634, val_loss:0.517, val_acc:41.250
# Best loss:0.529, Best accuracy:39.375, Best F1-score:0.351
# 14/300 lr=0.00100 - loss:0.516, acc:42.912, val_loss:0.505, val_acc:40.625
# Best loss:0.517, Best accuracy:41.250, Best F1-score:0.387
# 15/300 lr=0.00100 - loss:0.507, acc:43.826, val_loss:0.509, val_acc:37.500
# Best loss:0.517, Best accuracy:41.250, Best F1-score:0.387
# 16/300 lr=0.00100 - loss:0.498, acc:43.064, val_loss:0.484, val_acc:44.375
# Best loss:0.517, Best accuracy:41.250, Best F1-score:0.387
# 17/300 lr=0.00100 - loss:0.496, acc:45.198, val_loss:0.481, val_acc:43.125
# Best loss:0.484, Best accuracy:44.375, Best F1-score:0.413
# 18/300 lr=0.00100 - loss:0.485, acc:45.884, val_loss:0.463, val_acc:48.750
# Best loss:0.484, Best accuracy:44.375, Best F1-score:0.413
# 19/300 lr=0.00100 - loss:0.485, acc:45.655, val_loss:0.447, val_acc:51.875
# Best loss:0.463, Best accuracy:48.750, Best F1-score:0.473
# 20/300 lr=0.00100 - loss:0.478, acc:46.570, val_loss:0.441, val_acc:56.875
# Best loss:0.447, Best accuracy:51.875, Best F1-score:0.509
# 21/300 lr=0.00100 - loss:0.467, acc:49.085, val_loss:0.425, val_acc:55.625
# Best loss:0.441, Best accuracy:56.875, Best F1-score:0.553
# 22/300 lr=0.00100 - loss:0.457, acc:51.982, val_loss:0.416, val_acc:53.750
# Best loss:0.441, Best accuracy:56.875, Best F1-score:0.553
# 23/300 lr=0.00100 - loss:0.455, acc:52.668, val_loss:0.412, val_acc:55.625
# Best loss:0.441, Best accuracy:56.875, Best F1-score:0.553
# 24/300 lr=0.00100 - loss:0.452, acc:51.296, val_loss:0.398, val_acc:57.500
# Best loss:0.441, Best accuracy:56.875, Best F1-score:0.553
# 25/300 lr=0.00100 - loss:0.443, acc:53.659, val_loss:0.398, val_acc:55.625
# Best loss:0.398, Best accuracy:57.500, Best F1-score:0.569
# 26/300 lr=0.00100 - loss:0.440, acc:54.040, val_loss:0.393, val_acc:57.500
# Best loss:0.398, Best accuracy:57.500, Best F1-score:0.569
# 27/300 lr=0.00100 - loss:0.430, acc:55.793, val_loss:0.407, val_acc:53.750
# Best loss:0.398, Best accuracy:57.500, Best F1-score:0.569
# 28/300 lr=0.00100 - loss:0.426, acc:54.802, val_loss:0.412, val_acc:53.750
# Best loss:0.398, Best accuracy:57.500, Best F1-score:0.569
# 29/300 lr=0.00100 - loss:0.426, acc:55.564, val_loss:0.372, val_acc:58.750
# Best loss:0.398, Best accuracy:57.500, Best F1-score:0.569
# 30/300 lr=0.00100 - loss:0.421, acc:56.098, val_loss:0.398, val_acc:54.375
# Best loss:0.372, Best accuracy:58.750, Best F1-score:0.564
# 31/300 lr=0.00100 - loss:0.409, acc:57.774, val_loss:0.376, val_acc:60.000
# Best loss:0.372, Best accuracy:58.750, Best F1-score:0.564
# 32/300 lr=0.00100 - loss:0.416, acc:56.098, val_loss:0.380, val_acc:58.750
# Best loss:0.376, Best accuracy:60.000, Best F1-score:0.579
# 33/300 lr=0.00100 - loss:0.409, acc:57.470, val_loss:0.363, val_acc:59.375
# Best loss:0.376, Best accuracy:60.000, Best F1-score:0.579
# 34/300 lr=0.00100 - loss:0.411, acc:57.241, val_loss:0.353, val_acc:63.125
# Best loss:0.376, Best accuracy:60.000, Best F1-score:0.579
# 35/300 lr=0.00100 - loss:0.401, acc:58.613, val_loss:0.355, val_acc:57.500
# Best loss:0.353, Best accuracy:63.125, Best F1-score:0.619
# 36/300 lr=0.00100 - loss:0.403, acc:58.003, val_loss:0.333, val_acc:64.375
# Best loss:0.353, Best accuracy:63.125, Best F1-score:0.619
# 37/300 lr=0.00100 - loss:0.401, acc:57.927, val_loss:0.346, val_acc:62.500
# Best loss:0.333, Best accuracy:64.375, Best F1-score:0.631
# 38/300 lr=0.00100 - loss:0.404, acc:56.860, val_loss:0.363, val_acc:57.500
# Best loss:0.333, Best accuracy:64.375, Best F1-score:0.631
# 39/300 lr=0.00100 - loss:0.392, acc:60.442, val_loss:0.365, val_acc:59.375
# Best loss:0.333, Best accuracy:64.375, Best F1-score:0.631
# 40/300 lr=0.00100 - loss:0.399, acc:58.232, val_loss:0.354, val_acc:61.875
# Best loss:0.333, Best accuracy:64.375, Best F1-score:0.631
# 41/300 lr=0.00100 - loss:0.397, acc:58.994, val_loss:0.369, val_acc:56.875
# Best loss:0.333, Best accuracy:64.375, Best F1-score:0.631
# 42/300 lr=0.00100 - loss:0.388, acc:61.052, val_loss:0.374, val_acc:59.375
# Best loss:0.333, Best accuracy:64.375, Best F1-score:0.631
# 43/300 lr=0.00100 - loss:0.378, acc:61.585, val_loss:0.363, val_acc:60.000
# Best loss:0.333, Best accuracy:64.375, Best F1-score:0.631
# 44/300 lr=0.00100 - loss:0.383, acc:61.204, val_loss:0.332, val_acc:65.000
# Best loss:0.333, Best accuracy:64.375, Best F1-score:0.631
# 45/300 lr=0.00100 - loss:0.380, acc:61.052, val_loss:0.330, val_acc:65.000
# Best loss:0.332, Best accuracy:65.000, Best F1-score:0.650
# 46/300 lr=0.00100 - loss:0.372, acc:63.491, val_loss:0.327, val_acc:62.500
# Best loss:0.332, Best accuracy:65.000, Best F1-score:0.650
# 47/300 lr=0.00100 - loss:0.380, acc:60.747, val_loss:0.336, val_acc:60.000
# Best loss:0.332, Best accuracy:65.000, Best F1-score:0.650
# 48/300 lr=0.00100 - loss:0.370, acc:63.491, val_loss:0.316, val_acc:65.625
# Best loss:0.332, Best accuracy:65.000, Best F1-score:0.650
# 49/300 lr=0.00100 - loss:0.358, acc:63.567, val_loss:0.315, val_acc:62.500
# Best loss:0.316, Best accuracy:65.625, Best F1-score:0.647
# 50/300 lr=0.00100 - loss:0.360, acc:64.634, val_loss:0.305, val_acc:68.125
# Best loss:0.316, Best accuracy:65.625, Best F1-score:0.647
# 51/300 lr=0.00100 - loss:0.364, acc:63.415, val_loss:0.306, val_acc:66.875
# Best loss:0.305, Best accuracy:68.125, Best F1-score:0.673
# 52/300 lr=0.00100 - loss:0.347, acc:67.226, val_loss:0.301, val_acc:70.000
# Best loss:0.305, Best accuracy:68.125, Best F1-score:0.673
# 53/300 lr=0.00100 - loss:0.357, acc:64.787, val_loss:0.289, val_acc:68.750
# Best loss:0.301, Best accuracy:70.000, Best F1-score:0.697
# 54/300 lr=0.00100 - loss:0.353, acc:65.015, val_loss:0.282, val_acc:70.625
# Best loss:0.301, Best accuracy:70.000, Best F1-score:0.697
# 55/300 lr=0.00100 - loss:0.330, acc:67.607, val_loss:0.304, val_acc:68.125
# Best loss:0.282, Best accuracy:70.625, Best F1-score:0.708
# 56/300 lr=0.00100 - loss:0.346, acc:66.616, val_loss:0.291, val_acc:66.250
# Best loss:0.282, Best accuracy:70.625, Best F1-score:0.708
# 57/300 lr=0.00100 - loss:0.344, acc:67.302, val_loss:0.297, val_acc:69.375
# Best loss:0.282, Best accuracy:70.625, Best F1-score:0.708
# 58/300 lr=0.00100 - loss:0.333, acc:68.979, val_loss:0.280, val_acc:70.625
# Best loss:0.282, Best accuracy:70.625, Best F1-score:0.708
# 59/300 lr=0.00100 - loss:0.332, acc:66.845, val_loss:0.279, val_acc:67.500
# Best loss:0.282, Best accuracy:70.625, Best F1-score:0.708
# 60/300 lr=0.00100 - loss:0.328, acc:69.131, val_loss:0.287, val_acc:66.250
# Best loss:0.282, Best accuracy:70.625, Best F1-score:0.708
# 61/300 lr=0.00100 - loss:0.329, acc:68.521, val_loss:0.262, val_acc:76.250
# Best loss:0.282, Best accuracy:70.625, Best F1-score:0.708
# 62/300 lr=0.00086 - loss:0.329, acc:68.598, val_loss:0.283, val_acc:69.375
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 63/300 lr=0.00086 - loss:0.324, acc:69.970, val_loss:0.262, val_acc:71.875
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 64/300 lr=0.00086 - loss:0.314, acc:71.189, val_loss:0.267, val_acc:68.750
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 65/300 lr=0.00086 - loss:0.319, acc:69.970, val_loss:0.296, val_acc:66.250
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 66/300 lr=0.00086 - loss:0.327, acc:69.436, val_loss:0.265, val_acc:70.625
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 67/300 lr=0.00086 - loss:0.319, acc:70.274, val_loss:0.273, val_acc:70.625
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 68/300 lr=0.00086 - loss:0.313, acc:70.960, val_loss:0.301, val_acc:65.625
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 69/300 lr=0.00086 - loss:0.308, acc:71.723, val_loss:0.287, val_acc:66.875
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 70/300 lr=0.00086 - loss:0.310, acc:70.960, val_loss:0.266, val_acc:70.625
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 71/300 lr=0.00086 - loss:0.310, acc:71.037, val_loss:0.271, val_acc:68.750
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 72/300 lr=0.00086 - loss:0.305, acc:71.951, val_loss:0.275, val_acc:70.625
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 73/300 lr=0.00086 - loss:0.309, acc:71.646, val_loss:0.273, val_acc:69.375
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 74/300 lr=0.00086 - loss:0.308, acc:71.570, val_loss:0.276, val_acc:70.625
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 75/300 lr=0.00086 - loss:0.301, acc:73.095, val_loss:0.271, val_acc:68.125
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 76/300 lr=0.00086 - loss:0.296, acc:73.552, val_loss:0.285, val_acc:68.750
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 77/300 lr=0.00086 - loss:0.291, acc:74.314, val_loss:0.246, val_acc:73.125
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 78/300 lr=0.00086 - loss:0.296, acc:72.713, val_loss:0.268, val_acc:69.375
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 79/300 lr=0.00086 - loss:0.307, acc:71.646, val_loss:0.248, val_acc:71.875
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 80/300 lr=0.00086 - loss:0.290, acc:73.247, val_loss:0.243, val_acc:74.375
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 81/300 lr=0.00086 - loss:0.294, acc:73.628, val_loss:0.244, val_acc:73.750
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 82/300 lr=0.00074 - loss:0.283, acc:75.915, val_loss:0.277, val_acc:71.875
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 83/300 lr=0.00074 - loss:0.284, acc:75.000, val_loss:0.248, val_acc:74.375
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 84/300 lr=0.00074 - loss:0.279, acc:74.848, val_loss:0.239, val_acc:73.750
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 85/300 lr=0.00074 - loss:0.269, acc:76.448, val_loss:0.253, val_acc:69.375
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 86/300 lr=0.00074 - loss:0.271, acc:77.439, val_loss:0.223, val_acc:78.750
# Best loss:0.262, Best accuracy:76.250, Best F1-score:0.764
# 87/300 lr=0.00074 - loss:0.277, acc:75.381, val_loss:0.232, val_acc:76.250
# Best loss:0.223, Best accuracy:78.750, Best F1-score:0.791
# 88/300 lr=0.00074 - loss:0.269, acc:76.905, val_loss:0.248, val_acc:70.625
# Best loss:0.223, Best accuracy:78.750, Best F1-score:0.791
# 89/300 lr=0.00074 - loss:0.266, acc:77.287, val_loss:0.238, val_acc:74.375
# Best loss:0.223, Best accuracy:78.750, Best F1-score:0.791
# 90/300 lr=0.00074 - loss:0.254, acc:78.735, val_loss:0.237, val_acc:74.375
# Best loss:0.223, Best accuracy:78.750, Best F1-score:0.791
# 91/300 lr=0.00074 - loss:0.259, acc:77.973, val_loss:0.229, val_acc:74.375
# Best loss:0.223, Best accuracy:78.750, Best F1-score:0.791
# 92/300 lr=0.00074 - loss:0.268, acc:76.220, val_loss:0.257, val_acc:70.625
# Best loss:0.223, Best accuracy:78.750, Best F1-score:0.791
# 93/300 lr=0.00074 - loss:0.274, acc:76.448, val_loss:0.243, val_acc:75.000
# Best loss:0.223, Best accuracy:78.750, Best F1-score:0.791
# 94/300 lr=0.00074 - loss:0.279, acc:74.314, val_loss:0.267, val_acc:70.000
# Best loss:0.223, Best accuracy:78.750, Best F1-score:0.791
# 95/300 lr=0.00074 - loss:0.267, acc:76.905, val_loss:0.252, val_acc:71.250
# Best loss:0.223, Best accuracy:78.750, Best F1-score:0.791
# 96/300 lr=0.00074 - loss:0.258, acc:79.268, val_loss:0.233, val_acc:73.125
# Best loss:0.223, Best accuracy:78.750, Best F1-score:0.791
# 97/300 lr=0.00074 - loss:0.254, acc:79.268, val_loss:0.225, val_acc:75.625
# Best loss:0.223, Best accuracy:78.750, Best F1-score:0.791
# 98/300 lr=0.00074 - loss:0.265, acc:77.134, val_loss:0.234, val_acc:72.500
# Best loss:0.223, Best accuracy:78.750, Best F1-score:0.791
# 99/300 lr=0.00074 - loss:0.255, acc:79.726, val_loss:0.209, val_acc:80.625
# Best loss:0.223, Best accuracy:78.750, Best F1-score:0.791
# 100/300 lr=0.00074 - loss:0.254, acc:78.735, val_loss:0.225, val_acc:76.875
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 101/300 lr=0.00074 - loss:0.248, acc:79.878, val_loss:0.211, val_acc:77.500
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 102/300 lr=0.00064 - loss:0.240, acc:81.402, val_loss:0.218, val_acc:74.375
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 103/300 lr=0.00064 - loss:0.247, acc:80.183, val_loss:0.215, val_acc:75.000
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 104/300 lr=0.00064 - loss:0.236, acc:81.784, val_loss:0.221, val_acc:77.500
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 105/300 lr=0.00064 - loss:0.248, acc:79.268, val_loss:0.218, val_acc:79.375
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 106/300 lr=0.00064 - loss:0.233, acc:81.631, val_loss:0.219, val_acc:72.500
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 107/300 lr=0.00064 - loss:0.231, acc:82.851, val_loss:0.225, val_acc:73.125
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 108/300 lr=0.00064 - loss:0.236, acc:81.936, val_loss:0.199, val_acc:77.500
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 109/300 lr=0.00064 - loss:0.239, acc:80.716, val_loss:0.218, val_acc:75.000
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 110/300 lr=0.00064 - loss:0.230, acc:82.622, val_loss:0.230, val_acc:77.500
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 111/300 lr=0.00064 - loss:0.235, acc:81.021, val_loss:0.212, val_acc:77.500
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 112/300 lr=0.00064 - loss:0.220, acc:84.223, val_loss:0.237, val_acc:71.250
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 113/300 lr=0.00064 - loss:0.228, acc:83.232, val_loss:0.212, val_acc:74.375
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 114/300 lr=0.00064 - loss:0.218, acc:84.451, val_loss:0.199, val_acc:76.250
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 115/300 lr=0.00064 - loss:0.217, acc:83.765, val_loss:0.220, val_acc:77.500
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 116/300 lr=0.00064 - loss:0.219, acc:83.841, val_loss:0.213, val_acc:76.250
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 117/300 lr=0.00064 - loss:0.222, acc:83.460, val_loss:0.202, val_acc:78.750
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 118/300 lr=0.00064 - loss:0.223, acc:82.698, val_loss:0.202, val_acc:77.500
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 119/300 lr=0.00064 - loss:0.215, acc:85.518, val_loss:0.201, val_acc:77.500
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 120/300 lr=0.00064 - loss:0.214, acc:84.680, val_loss:0.203, val_acc:75.625
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 121/300 lr=0.00064 - loss:0.216, acc:84.451, val_loss:0.230, val_acc:73.125
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 122/300 lr=0.00055 - loss:0.216, acc:83.613, val_loss:0.209, val_acc:75.000
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 123/300 lr=0.00055 - loss:0.211, acc:85.671, val_loss:0.188, val_acc:79.375
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 124/300 lr=0.00055 - loss:0.196, acc:87.271, val_loss:0.199, val_acc:76.875
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 125/300 lr=0.00055 - loss:0.206, acc:86.357, val_loss:0.180, val_acc:80.000
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 126/300 lr=0.00055 - loss:0.211, acc:84.985, val_loss:0.199, val_acc:75.000
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 127/300 lr=0.00055 - loss:0.211, acc:84.909, val_loss:0.201, val_acc:80.625
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 128/300 lr=0.00055 - loss:0.196, acc:87.119, val_loss:0.204, val_acc:77.500
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 129/300 lr=0.00055 - loss:0.212, acc:85.518, val_loss:0.200, val_acc:78.125
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 130/300 lr=0.00055 - loss:0.199, acc:86.814, val_loss:0.197, val_acc:77.500
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 131/300 lr=0.00055 - loss:0.199, acc:87.043, val_loss:0.186, val_acc:80.000
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 132/300 lr=0.00055 - loss:0.201, acc:87.119, val_loss:0.173, val_acc:83.750
# Best loss:0.209, Best accuracy:80.625, Best F1-score:0.814
# 133/300 lr=0.00055 - loss:0.206, acc:86.662, val_loss:0.184, val_acc:81.875
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 134/300 lr=0.00055 - loss:0.204, acc:85.823, val_loss:0.202, val_acc:76.875
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 135/300 lr=0.00055 - loss:0.199, acc:87.195, val_loss:0.192, val_acc:76.875
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 136/300 lr=0.00055 - loss:0.193, acc:88.338, val_loss:0.186, val_acc:77.500
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 137/300 lr=0.00055 - loss:0.196, acc:87.119, val_loss:0.176, val_acc:79.375
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 138/300 lr=0.00055 - loss:0.183, acc:90.091, val_loss:0.181, val_acc:79.375
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 139/300 lr=0.00055 - loss:0.188, acc:88.186, val_loss:0.186, val_acc:81.250
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 140/300 lr=0.00055 - loss:0.187, acc:88.872, val_loss:0.170, val_acc:81.875
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 141/300 lr=0.00055 - loss:0.192, acc:87.729, val_loss:0.217, val_acc:75.000
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 142/300 lr=0.00047 - loss:0.192, acc:87.271, val_loss:0.186, val_acc:80.625
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 143/300 lr=0.00047 - loss:0.187, acc:88.110, val_loss:0.165, val_acc:81.875
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 144/300 lr=0.00047 - loss:0.190, acc:87.881, val_loss:0.186, val_acc:78.125
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 145/300 lr=0.00047 - loss:0.199, acc:86.890, val_loss:0.189, val_acc:75.625
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 146/300 lr=0.00047 - loss:0.199, acc:86.433, val_loss:0.204, val_acc:76.875
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 147/300 lr=0.00047 - loss:0.190, acc:87.881, val_loss:0.194, val_acc:76.875
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 148/300 lr=0.00047 - loss:0.190, acc:87.805, val_loss:0.176, val_acc:79.375
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 149/300 lr=0.00047 - loss:0.184, acc:88.338, val_loss:0.181, val_acc:79.375
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 150/300 lr=0.00047 - loss:0.183, acc:89.787, val_loss:0.189, val_acc:79.375
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 151/300 lr=0.00047 - loss:0.180, acc:89.482, val_loss:0.201, val_acc:78.750
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 152/300 lr=0.00047 - loss:0.181, acc:88.872, val_loss:0.196, val_acc:78.750
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 153/300 lr=0.00047 - loss:0.183, acc:88.948, val_loss:0.183, val_acc:78.750
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 154/300 lr=0.00047 - loss:0.181, acc:89.024, val_loss:0.188, val_acc:77.500
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 155/300 lr=0.00047 - loss:0.182, acc:89.405, val_loss:0.163, val_acc:85.000
# Best loss:0.173, Best accuracy:83.750, Best F1-score:0.843
# 156/300 lr=0.00047 - loss:0.178, acc:90.091, val_loss:0.162, val_acc:85.000
# Best loss:0.163, Best accuracy:85.000, Best F1-score:0.847
# 157/300 lr=0.00047 - loss:0.176, acc:90.473, val_loss:0.173, val_acc:82.500
# Best loss:0.163, Best accuracy:85.000, Best F1-score:0.847
# 158/300 lr=0.00047 - loss:0.179, acc:89.863, val_loss:0.197, val_acc:76.250
# Best loss:0.163, Best accuracy:85.000, Best F1-score:0.847
# 159/300 lr=0.00047 - loss:0.184, acc:88.186, val_loss:0.185, val_acc:80.625
# Best loss:0.163, Best accuracy:85.000, Best F1-score:0.847
# 160/300 lr=0.00047 - loss:0.178, acc:90.015, val_loss:0.184, val_acc:81.250
# Best loss:0.163, Best accuracy:85.000, Best F1-score:0.847
# 161/300 lr=0.00047 - loss:0.175, acc:90.091, val_loss:0.166, val_acc:81.875
# Best loss:0.163, Best accuracy:85.000, Best F1-score:0.847
# 162/300 lr=0.00041 - loss:0.177, acc:90.091, val_loss:0.174, val_acc:80.000
# Best loss:0.163, Best accuracy:85.000, Best F1-score:0.847
# 163/300 lr=0.00041 - loss:0.166, acc:91.845, val_loss:0.177, val_acc:80.000
# Best loss:0.163, Best accuracy:85.000, Best F1-score:0.847
# 164/300 lr=0.00041 - loss:0.163, acc:91.921, val_loss:0.179, val_acc:79.375
# Best loss:0.163, Best accuracy:85.000, Best F1-score:0.847
# 165/300 lr=0.00041 - loss:0.165, acc:91.997, val_loss:0.188, val_acc:78.750
# Best loss:0.163, Best accuracy:85.000, Best F1-score:0.847
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 247/300 lr=0.00022 - loss:0.135, acc:94.665, val_loss:0.153, val_acc:82.500
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 248/300 lr=0.00022 - loss:0.137, acc:95.274, val_loss:0.149, val_acc:85.625
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 249/300 lr=0.00022 - loss:0.135, acc:95.732, val_loss:0.150, val_acc:81.875
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 250/300 lr=0.00022 - loss:0.135, acc:95.808, val_loss:0.152, val_acc:82.500
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 251/300 lr=0.00022 - loss:0.132, acc:96.189, val_loss:0.153, val_acc:82.500
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 252/300 lr=0.00022 - loss:0.129, acc:96.570, val_loss:0.164, val_acc:83.125
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 253/300 lr=0.00022 - loss:0.134, acc:95.503, val_loss:0.153, val_acc:84.375
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 254/300 lr=0.00022 - loss:0.130, acc:96.341, val_loss:0.151, val_acc:83.125
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 255/300 lr=0.00022 - loss:0.136, acc:95.427, val_loss:0.160, val_acc:81.875
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 256/300 lr=0.00022 - loss:0.135, acc:95.122, val_loss:0.154, val_acc:81.875
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 257/300 lr=0.00022 - loss:0.137, acc:95.046, val_loss:0.161, val_acc:83.125
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 258/300 lr=0.00022 - loss:0.134, acc:95.351, val_loss:0.163, val_acc:82.500
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 259/300 lr=0.00022 - loss:0.136, acc:95.122, val_loss:0.145, val_acc:83.750
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 260/300 lr=0.00022 - loss:0.133, acc:95.732, val_loss:0.154, val_acc:85.000
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 261/300 lr=0.00022 - loss:0.134, acc:95.808, val_loss:0.154, val_acc:83.125
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 262/300 lr=0.00019 - loss:0.133, acc:95.579, val_loss:0.154, val_acc:84.375
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 263/300 lr=0.00019 - loss:0.133, acc:95.274, val_loss:0.147, val_acc:85.000
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 264/300 lr=0.00019 - loss:0.133, acc:96.113, val_loss:0.146, val_acc:85.000
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 265/300 lr=0.00019 - loss:0.134, acc:95.579, val_loss:0.164, val_acc:82.500
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 266/300 lr=0.00019 - loss:0.129, acc:96.799, val_loss:0.154, val_acc:84.375
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 267/300 lr=0.00019 - loss:0.128, acc:96.875, val_loss:0.154, val_acc:85.000
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 268/300 lr=0.00019 - loss:0.130, acc:97.104, val_loss:0.152, val_acc:83.750
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 269/300 lr=0.00019 - loss:0.129, acc:96.265, val_loss:0.152, val_acc:83.125
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 270/300 lr=0.00019 - loss:0.133, acc:95.808, val_loss:0.145, val_acc:84.375
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 271/300 lr=0.00019 - loss:0.130, acc:96.570, val_loss:0.162, val_acc:83.125
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 272/300 lr=0.00019 - loss:0.129, acc:96.418, val_loss:0.157, val_acc:81.875
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 273/300 lr=0.00019 - loss:0.131, acc:96.570, val_loss:0.156, val_acc:83.750
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 274/300 lr=0.00019 - loss:0.137, acc:94.817, val_loss:0.158, val_acc:83.750
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 275/300 lr=0.00019 - loss:0.129, acc:96.418, val_loss:0.152, val_acc:84.375
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 276/300 lr=0.00019 - loss:0.128, acc:96.646, val_loss:0.147, val_acc:82.500
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 277/300 lr=0.00019 - loss:0.130, acc:96.875, val_loss:0.151, val_acc:85.000
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 278/300 lr=0.00019 - loss:0.130, acc:96.418, val_loss:0.154, val_acc:82.500
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 279/300 lr=0.00019 - loss:0.130, acc:96.646, val_loss:0.158, val_acc:83.750
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 280/300 lr=0.00019 - loss:0.129, acc:96.646, val_loss:0.142, val_acc:84.375
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 281/300 lr=0.00019 - loss:0.129, acc:96.418, val_loss:0.158, val_acc:83.750
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 282/300 lr=0.00017 - loss:0.125, acc:97.104, val_loss:0.152, val_acc:82.500
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 283/300 lr=0.00017 - loss:0.131, acc:96.189, val_loss:0.153, val_acc:84.375
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 284/300 lr=0.00017 - loss:0.127, acc:96.951, val_loss:0.165, val_acc:78.750
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 285/300 lr=0.00017 - loss:0.129, acc:96.723, val_loss:0.153, val_acc:84.375
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 286/300 lr=0.00017 - loss:0.131, acc:95.732, val_loss:0.155, val_acc:82.500
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 287/300 lr=0.00017 - loss:0.127, acc:96.951, val_loss:0.160, val_acc:83.125
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 288/300 lr=0.00017 - loss:0.131, acc:95.960, val_loss:0.158, val_acc:82.500
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 289/300 lr=0.00017 - loss:0.124, acc:97.104, val_loss:0.161, val_acc:82.500
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 290/300 lr=0.00017 - loss:0.127, acc:96.951, val_loss:0.145, val_acc:83.750
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 291/300 lr=0.00017 - loss:0.128, acc:96.951, val_loss:0.161, val_acc:81.875
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 292/300 lr=0.00017 - loss:0.127, acc:96.494, val_loss:0.158, val_acc:83.125
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 293/300 lr=0.00017 - loss:0.125, acc:97.409, val_loss:0.156, val_acc:84.375
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 294/300 lr=0.00017 - loss:0.124, acc:97.256, val_loss:0.169, val_acc:80.625
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 295/300 lr=0.00017 - loss:0.127, acc:97.027, val_loss:0.149, val_acc:84.375
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 296/300 lr=0.00017 - loss:0.128, acc:96.570, val_loss:0.157, val_acc:81.875
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 297/300 lr=0.00017 - loss:0.126, acc:96.875, val_loss:0.158, val_acc:79.375
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 298/300 lr=0.00017 - loss:0.124, acc:96.951, val_loss:0.152, val_acc:83.750
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 299/300 lr=0.00017 - loss:0.125, acc:97.104, val_loss:0.154, val_acc:83.125
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# 300/300 lr=0.00017 - loss:0.125, acc:97.180, val_loss:0.155, val_acc:83.125
# Best loss:0.144, Best accuracy:86.875, Best F1-score:0.871
# [*] Done - acc:86.875
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.630, acc:17.607, val_loss:0.639, val_acc:23.750
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.618, acc:21.951, val_loss:0.622, val_acc:28.125
# Best loss:0.639, Best accuracy:23.750, Best F1-score:0.144
# 3/300 lr=0.00100 - loss:0.604, acc:25.915, val_loss:0.609, val_acc:30.000
# Best loss:0.622, Best accuracy:28.125, Best F1-score:0.196
# 4/300 lr=0.00100 - loss:0.596, acc:28.277, val_loss:0.596, val_acc:30.625
# Best loss:0.609, Best accuracy:30.000, Best F1-score:0.211
# 5/300 lr=0.00100 - loss:0.589, acc:27.668, val_loss:0.581, val_acc:31.875
# Best loss:0.596, Best accuracy:30.625, Best F1-score:0.238
# 6/300 lr=0.00100 - loss:0.587, acc:27.820, val_loss:0.582, val_acc:31.250
# Best loss:0.581, Best accuracy:31.875, Best F1-score:0.256
# 7/300 lr=0.00100 - loss:0.580, acc:30.107, val_loss:0.589, val_acc:23.750
# Best loss:0.581, Best accuracy:31.875, Best F1-score:0.256
# 8/300 lr=0.00100 - loss:0.569, acc:32.470, val_loss:0.588, val_acc:28.125
# Best loss:0.581, Best accuracy:31.875, Best F1-score:0.256
# 9/300 lr=0.00100 - loss:0.560, acc:33.460, val_loss:0.579, val_acc:27.500
# Best loss:0.581, Best accuracy:31.875, Best F1-score:0.256
# 10/300 lr=0.00100 - loss:0.554, acc:36.128, val_loss:0.546, val_acc:36.875
# Best loss:0.581, Best accuracy:31.875, Best F1-score:0.256
# 11/300 lr=0.00100 - loss:0.546, acc:37.957, val_loss:0.589, val_acc:28.125
# Best loss:0.546, Best accuracy:36.875, Best F1-score:0.321
# 12/300 lr=0.00100 - loss:0.536, acc:38.948, val_loss:0.547, val_acc:38.125
# Best loss:0.546, Best accuracy:36.875, Best F1-score:0.321
# 13/300 lr=0.00100 - loss:0.537, acc:37.652, val_loss:0.534, val_acc:36.875
# Best loss:0.547, Best accuracy:38.125, Best F1-score:0.307
# 14/300 lr=0.00100 - loss:0.533, acc:39.329, val_loss:0.543, val_acc:37.500
# Best loss:0.547, Best accuracy:38.125, Best F1-score:0.307
# 15/300 lr=0.00100 - loss:0.516, acc:42.912, val_loss:0.534, val_acc:36.875
# Best loss:0.547, Best accuracy:38.125, Best F1-score:0.307
# 16/300 lr=0.00100 - loss:0.502, acc:45.655, val_loss:0.508, val_acc:42.500
# Best loss:0.547, Best accuracy:38.125, Best F1-score:0.307
# 17/300 lr=0.00100 - loss:0.496, acc:45.503, val_loss:0.486, val_acc:44.375
# Best loss:0.508, Best accuracy:42.500, Best F1-score:0.352
# 18/300 lr=0.00100 - loss:0.491, acc:46.723, val_loss:0.512, val_acc:41.250
# Best loss:0.486, Best accuracy:44.375, Best F1-score:0.385
# 19/300 lr=0.00100 - loss:0.489, acc:46.494, val_loss:0.486, val_acc:44.375
# Best loss:0.486, Best accuracy:44.375, Best F1-score:0.385
# 20/300 lr=0.00100 - loss:0.480, acc:46.341, val_loss:0.495, val_acc:41.875
# Best loss:0.486, Best accuracy:44.375, Best F1-score:0.385
# 21/300 lr=0.00100 - loss:0.479, acc:48.171, val_loss:0.455, val_acc:49.375
# Best loss:0.486, Best accuracy:44.375, Best F1-score:0.385
# 22/300 lr=0.00100 - loss:0.458, acc:50.915, val_loss:0.456, val_acc:46.875
# Best loss:0.455, Best accuracy:49.375, Best F1-score:0.437
# 23/300 lr=0.00100 - loss:0.455, acc:50.534, val_loss:0.455, val_acc:49.375
# Best loss:0.455, Best accuracy:49.375, Best F1-score:0.437
# 24/300 lr=0.00100 - loss:0.455, acc:50.457, val_loss:0.426, val_acc:50.000
# Best loss:0.455, Best accuracy:49.375, Best F1-score:0.437
# 25/300 lr=0.00100 - loss:0.441, acc:55.107, val_loss:0.440, val_acc:48.125
# Best loss:0.426, Best accuracy:50.000, Best F1-score:0.445
# 26/300 lr=0.00100 - loss:0.444, acc:52.287, val_loss:0.498, val_acc:36.250
# Best loss:0.426, Best accuracy:50.000, Best F1-score:0.445
# 27/300 lr=0.00100 - loss:0.438, acc:53.582, val_loss:0.456, val_acc:46.250
# Best loss:0.426, Best accuracy:50.000, Best F1-score:0.445
# 28/300 lr=0.00100 - loss:0.444, acc:53.049, val_loss:0.434, val_acc:48.125
# Best loss:0.426, Best accuracy:50.000, Best F1-score:0.445
# 29/300 lr=0.00100 - loss:0.428, acc:54.802, val_loss:0.404, val_acc:48.750
# Best loss:0.426, Best accuracy:50.000, Best F1-score:0.445
# 30/300 lr=0.00100 - loss:0.415, acc:56.707, val_loss:0.423, val_acc:51.250
# Best loss:0.426, Best accuracy:50.000, Best F1-score:0.445
# 31/300 lr=0.00100 - loss:0.417, acc:56.631, val_loss:0.435, val_acc:47.500
# Best loss:0.423, Best accuracy:51.250, Best F1-score:0.460
# 32/300 lr=0.00100 - loss:0.410, acc:57.317, val_loss:0.405, val_acc:52.500
# Best loss:0.423, Best accuracy:51.250, Best F1-score:0.460
# 33/300 lr=0.00100 - loss:0.406, acc:59.223, val_loss:0.398, val_acc:53.125
# Best loss:0.405, Best accuracy:52.500, Best F1-score:0.476
# 34/300 lr=0.00100 - loss:0.407, acc:58.460, val_loss:0.450, val_acc:45.000
# Best loss:0.398, Best accuracy:53.125, Best F1-score:0.489
# 35/300 lr=0.00100 - loss:0.408, acc:58.003, val_loss:0.459, val_acc:46.875
# Best loss:0.398, Best accuracy:53.125, Best F1-score:0.489
# 36/300 lr=0.00100 - loss:0.399, acc:59.527, val_loss:0.426, val_acc:50.000
# Best loss:0.398, Best accuracy:53.125, Best F1-score:0.489
# 37/300 lr=0.00100 - loss:0.398, acc:59.527, val_loss:0.422, val_acc:50.000
# Best loss:0.398, Best accuracy:53.125, Best F1-score:0.489
# 38/300 lr=0.00100 - loss:0.389, acc:60.366, val_loss:0.397, val_acc:53.125
# Best loss:0.398, Best accuracy:53.125, Best F1-score:0.489
# 39/300 lr=0.00100 - loss:0.386, acc:61.890, val_loss:0.411, val_acc:50.625
# Best loss:0.398, Best accuracy:53.125, Best F1-score:0.489
# 40/300 lr=0.00100 - loss:0.379, acc:62.195, val_loss:0.403, val_acc:50.000
# Best loss:0.398, Best accuracy:53.125, Best F1-score:0.489
# 41/300 lr=0.00100 - loss:0.397, acc:58.918, val_loss:0.381, val_acc:55.000
# Best loss:0.398, Best accuracy:53.125, Best F1-score:0.489
# 42/300 lr=0.00100 - loss:0.396, acc:58.765, val_loss:0.414, val_acc:50.000
# Best loss:0.381, Best accuracy:55.000, Best F1-score:0.521
# 43/300 lr=0.00100 - loss:0.373, acc:62.652, val_loss:0.377, val_acc:55.000
# Best loss:0.381, Best accuracy:55.000, Best F1-score:0.521
# 44/300 lr=0.00100 - loss:0.366, acc:63.262, val_loss:0.398, val_acc:54.375
# Best loss:0.381, Best accuracy:55.000, Best F1-score:0.521
# 45/300 lr=0.00100 - loss:0.370, acc:63.643, val_loss:0.364, val_acc:59.375
# Best loss:0.381, Best accuracy:55.000, Best F1-score:0.521
# 46/300 lr=0.00100 - loss:0.362, acc:63.720, val_loss:0.374, val_acc:58.125
# Best loss:0.364, Best accuracy:59.375, Best F1-score:0.560
# 47/300 lr=0.00100 - loss:0.351, acc:64.558, val_loss:0.374, val_acc:57.500
# Best loss:0.364, Best accuracy:59.375, Best F1-score:0.560
# 48/300 lr=0.00100 - loss:0.345, acc:67.226, val_loss:0.375, val_acc:55.625
# Best loss:0.364, Best accuracy:59.375, Best F1-score:0.560
# 49/300 lr=0.00100 - loss:0.342, acc:67.226, val_loss:0.334, val_acc:62.500
# Best loss:0.364, Best accuracy:59.375, Best F1-score:0.560
# 50/300 lr=0.00100 - loss:0.342, acc:65.549, val_loss:0.345, val_acc:61.250
# Best loss:0.334, Best accuracy:62.500, Best F1-score:0.590
# 51/300 lr=0.00100 - loss:0.348, acc:64.634, val_loss:0.361, val_acc:58.750
# Best loss:0.334, Best accuracy:62.500, Best F1-score:0.590
# 52/300 lr=0.00100 - loss:0.336, acc:67.759, val_loss:0.354, val_acc:59.375
# Best loss:0.334, Best accuracy:62.500, Best F1-score:0.590
# 53/300 lr=0.00100 - loss:0.340, acc:67.149, val_loss:0.361, val_acc:58.750
# Best loss:0.334, Best accuracy:62.500, Best F1-score:0.590
# 54/300 lr=0.00100 - loss:0.337, acc:69.360, val_loss:0.375, val_acc:56.250
# Best loss:0.334, Best accuracy:62.500, Best F1-score:0.590
# 55/300 lr=0.00100 - loss:0.325, acc:70.884, val_loss:0.345, val_acc:58.125
# Best loss:0.334, Best accuracy:62.500, Best F1-score:0.590
# 56/300 lr=0.00100 - loss:0.330, acc:69.665, val_loss:0.335, val_acc:61.875
# Best loss:0.334, Best accuracy:62.500, Best F1-score:0.590
# ...
# 183/300 lr=0.00035 - loss:0.145, acc:93.826, val_loss:0.181, val_acc:78.125
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 184/300 lr=0.00035 - loss:0.142, acc:94.588, val_loss:0.185, val_acc:78.750
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 185/300 lr=0.00035 - loss:0.146, acc:94.131, val_loss:0.166, val_acc:81.250
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 186/300 lr=0.00035 - loss:0.138, acc:95.198, val_loss:0.164, val_acc:82.500
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 187/300 lr=0.00035 - loss:0.146, acc:94.360, val_loss:0.157, val_acc:83.750
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 188/300 lr=0.00035 - loss:0.142, acc:94.588, val_loss:0.159, val_acc:83.125
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 189/300 lr=0.00035 - loss:0.138, acc:95.274, val_loss:0.170, val_acc:79.375
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 190/300 lr=0.00035 - loss:0.139, acc:95.198, val_loss:0.173, val_acc:80.000
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 191/300 lr=0.00035 - loss:0.139, acc:94.893, val_loss:0.160, val_acc:81.875
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 192/300 lr=0.00035 - loss:0.135, acc:95.732, val_loss:0.163, val_acc:81.250
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 193/300 lr=0.00035 - loss:0.135, acc:96.113, val_loss:0.174, val_acc:80.625
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 194/300 lr=0.00035 - loss:0.140, acc:94.893, val_loss:0.176, val_acc:79.375
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 195/300 lr=0.00035 - loss:0.141, acc:94.284, val_loss:0.154, val_acc:80.625
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 196/300 lr=0.00035 - loss:0.136, acc:96.494, val_loss:0.178, val_acc:78.750
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 197/300 lr=0.00035 - loss:0.142, acc:94.665, val_loss:0.176, val_acc:80.000
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 198/300 lr=0.00035 - loss:0.135, acc:95.808, val_loss:0.152, val_acc:82.500
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 199/300 lr=0.00035 - loss:0.133, acc:96.037, val_loss:0.168, val_acc:82.500
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 200/300 lr=0.00035 - loss:0.137, acc:95.579, val_loss:0.176, val_acc:79.375
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 201/300 lr=0.00035 - loss:0.141, acc:94.970, val_loss:0.163, val_acc:83.125
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 202/300 lr=0.00030 - loss:0.135, acc:96.189, val_loss:0.164, val_acc:80.000
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 203/300 lr=0.00030 - loss:0.127, acc:97.409, val_loss:0.179, val_acc:79.375
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 204/300 lr=0.00030 - loss:0.130, acc:96.570, val_loss:0.156, val_acc:83.750
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 205/300 lr=0.00030 - loss:0.127, acc:96.646, val_loss:0.175, val_acc:76.875
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 206/300 lr=0.00030 - loss:0.129, acc:96.570, val_loss:0.166, val_acc:81.250
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 207/300 lr=0.00030 - loss:0.134, acc:96.037, val_loss:0.167, val_acc:78.750
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 208/300 lr=0.00030 - loss:0.136, acc:95.122, val_loss:0.157, val_acc:83.750
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 209/300 lr=0.00030 - loss:0.131, acc:96.113, val_loss:0.156, val_acc:81.250
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 210/300 lr=0.00030 - loss:0.131, acc:95.960, val_loss:0.146, val_acc:85.000
# Best loss:0.159, Best accuracy:83.750, Best F1-score:0.854
# 211/300 lr=0.00030 - loss:0.131, acc:96.113, val_loss:0.156, val_acc:85.000
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 212/300 lr=0.00030 - loss:0.130, acc:96.113, val_loss:0.159, val_acc:81.875
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 213/300 lr=0.00030 - loss:0.129, acc:96.570, val_loss:0.167, val_acc:79.375
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
#
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 280/300 lr=0.00019 - loss:0.120, acc:97.485, val_loss:0.160, val_acc:83.125
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 281/300 lr=0.00019 - loss:0.118, acc:98.095, val_loss:0.164, val_acc:80.000
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 282/300 lr=0.00017 - loss:0.117, acc:98.095, val_loss:0.153, val_acc:80.000
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 283/300 lr=0.00017 - loss:0.120, acc:97.866, val_loss:0.163, val_acc:82.500
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 284/300 lr=0.00017 - loss:0.118, acc:98.171, val_loss:0.160, val_acc:81.875
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 285/300 lr=0.00017 - loss:0.118, acc:98.018, val_loss:0.150, val_acc:83.125
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 286/300 lr=0.00017 - loss:0.117, acc:98.247, val_loss:0.161, val_acc:80.625
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 287/300 lr=0.00017 - loss:0.118, acc:98.247, val_loss:0.161, val_acc:81.250
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 288/300 lr=0.00017 - loss:0.119, acc:97.866, val_loss:0.147, val_acc:83.750
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 289/300 lr=0.00017 - loss:0.117, acc:98.399, val_loss:0.153, val_acc:83.750
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 290/300 lr=0.00017 - loss:0.117, acc:97.942, val_loss:0.163, val_acc:81.250
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 291/300 lr=0.00017 - loss:0.116, acc:98.399, val_loss:0.166, val_acc:80.000
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 292/300 lr=0.00017 - loss:0.116, acc:98.476, val_loss:0.146, val_acc:81.875
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 293/300 lr=0.00017 - loss:0.118, acc:97.790, val_loss:0.148, val_acc:82.500
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 294/300 lr=0.00017 - loss:0.118, acc:97.942, val_loss:0.152, val_acc:84.375
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 295/300 lr=0.00017 - loss:0.118, acc:98.171, val_loss:0.159, val_acc:81.875
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 296/300 lr=0.00017 - loss:0.119, acc:98.095, val_loss:0.154, val_acc:81.875
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 297/300 lr=0.00017 - loss:0.117, acc:98.247, val_loss:0.159, val_acc:81.250
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 298/300 lr=0.00017 - loss:0.121, acc:97.713, val_loss:0.154, val_acc:83.750
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 299/300 lr=0.00017 - loss:0.115, acc:98.628, val_loss:0.153, val_acc:80.625
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# 300/300 lr=0.00017 - loss:0.115, acc:98.476, val_loss:0.147, val_acc:82.500
# Best loss:0.146, Best accuracy:85.000, Best F1-score:0.852
# [*] Done - acc:85.000

# %%
end()

# %%
print(f'max:{max(fold_acc)}, min:{min(fold_acc)}, average:{sum(fold_acc)/len(fold_acc)}')
# Out:
# max:87.5, min:81.25, average:84.4375

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
# Out:
# WAR(Weighted Average Recall)   : 83.92%
# UAR(Unweighted Average Recall) : 83.92%
