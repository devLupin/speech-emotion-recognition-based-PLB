# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = 'TIMNET-dataset'
DATA_PATH = 'IEMOCAP'
CLASS_LABELS = Config.IEMOCAP_LABELS
k = 10

# No-reverse : (196,39,1)  ## CA: Channel-attention    ## SA : Self-attention 
model_name = 'exp1'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, dilation_rate=(2,2)),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule]),
        Lambda(function=PrimaryCapssquash)
    ])
    
  def call(self, inputs):
    return self.conv(inputs)

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.conv3 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
  
    # Q, V, K
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.cbam = CBAM(64) # sharing
    self.reshape = Reshape(target_shape=[-1, 64])
    
    self.conv4 = PrimaryCap()
    self.spatial_attn = SpatialGate()
  
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    x = inputs
    forward = x
    backward = tf.reverse(inputs, axis=[2])
    
    fx = self.conv1(forward)
    fx += self.cbam(fx)
    bx = self.conv2(backward)
    bx += self.cbam(bx)
    cross_attn_out = self.attention([fx, bx, bx]) # Q, K==V
    fx += cross_attn_out
    
    fx = self.conv3(fx)
    fx += self.cbam(fx)
    
    cap = self.conv4(fx)
    cap = tf.expand_dims(cap, axis=-1)
    cap += self.spatial_attn(cap)
    cap = tf.squeeze(cap, axis=-1)
    
    sa = self.attention([cap, cap, cap])
    sa = self.LN(sa)
    
    sa = self.lamb([cap, sa])
    sa = tf.expand_dims(sa, axis=-1)
    sa += self.spatial_attn(sa)
    cap = tf.squeeze(sa, axis=-1)
    
    capsule = self.capsule(cap)
    
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1416
#
#  sequential_1 (Sequential)   (None, 97, 18, 64)        1416
#
#  sequential_2 (Sequential)   (None, 46, 7, 64)         37300
#
#  attention (Attention)       multiple                  1
#
#  layer_normalization (LayerN  multiple                 128
#  ormalization)
#
#  lambda (Lambda)             multiple                  0
#
#  cbam (CBAM)                 multiple                  4294
#
#  reshape (Reshape)           multiple                  0 (unused)
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  spatial_gate_1 (SpatialGate  multiple                 102
#  )
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  260
#
# =================================================================
# Total params: 95,093
# Trainable params: 94,127
# Non-trainable params: 966
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}.npy', 'rb') as f:
    x = np.load(f)
    y = np.load(f)

y = to_categorical(y,num_classes=len(CLASS_LABELS))

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, test) in tqdm(enumerate(kfold.split(x, y)), desc=f'Training {k}-Fold.....'):
    if i != 9:
        continue
    
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = x[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_test, y_test = x[test], y[test]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_test = tf.expand_dims(x_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_test_loss = 0x3f3f3f
    best_test_acc = -1
    best_test_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        test_loss, test_acc, f1s = [], [], []
        for features, labels in batch_test:
            loss, acc, pred = test_step(model, features, labels)
            test_loss.append(loss)
            test_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(test_loss)/len(test_loss)
        val_acc = sum(test_acc)/len(test_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_test_loss:.3f}, Best accuracy:{best_test_acc:.3f}, Best F1-score:{best_test_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_test_acc < val_acc:
            best_test_acc = val_acc
            best_test_loss = val_loss
            best_test_f1 = f1_score
            model.save_weights(h5_path)
            
            
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    
    for features, labels in batch_test:
        best_pred = model(features, training=False)
        emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(labels, axis=1))
        predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
    
    
    print(f'[*] Done - acc:{best_test_acc:.3f}')
    
    plt.title(f'{i+1}-fold Loss Curve - Best acc:{best_test_acc:.3f}, Best loss:{best_test_loss:.3f}')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])

    
    save_fig_path = f'Fig/{DATA_PATH}/training/{model_name}'
    os.makedirs(save_fig_path, exist_ok=True)
    plt.savefig(f'{save_fig_path}/{i+1}-fold.PNG')
    
    plt.show()
    
    fold_acc.append(best_test_acc)
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.458, acc:42.475, val_loss:0.412, val_acc:49.865
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.427, acc:47.830, val_loss:0.395, val_acc:52.913
# Best loss:0.412, Best accuracy:49.865, Best F1-score:0.486
# 3/300 lr=0.00100 - loss:0.424, acc:48.745, val_loss:0.399, val_acc:52.566
# Best loss:0.395, Best accuracy:52.913, Best F1-score:0.527
# 4/300 lr=0.00100 - loss:0.418, acc:49.915, val_loss:0.380, val_acc:55.170
# Best loss:0.395, Best accuracy:52.913, Best F1-score:0.527
# 5/300 lr=0.00100 - loss:0.417, acc:50.532, val_loss:0.382, val_acc:54.475
# Best loss:0.380, Best accuracy:55.170, Best F1-score:0.561
# 6/300 lr=0.00100 - loss:0.411, acc:50.775, val_loss:0.370, val_acc:56.134
# Best loss:0.380, Best accuracy:55.170, Best F1-score:0.561
# 7/300 lr=0.00100 - loss:0.402, acc:52.925, val_loss:0.365, val_acc:56.308
# Best loss:0.370, Best accuracy:56.134, Best F1-score:0.567
# 8/300 lr=0.00100 - loss:0.398, acc:53.136, val_loss:0.377, val_acc:55.787
# Best loss:0.365, Best accuracy:56.308, Best F1-score:0.569
# 9/300 lr=0.00100 - loss:0.396, acc:54.329, val_loss:0.374, val_acc:56.134
# Best loss:0.365, Best accuracy:56.308, Best F1-score:0.569
# 10/300 lr=0.00100 - loss:0.394, acc:54.009, val_loss:0.360, val_acc:57.350
# Best loss:0.365, Best accuracy:56.308, Best F1-score:0.569
# 11/300 lr=0.00100 - loss:0.392, acc:54.503, val_loss:0.353, val_acc:59.259
# Best loss:0.360, Best accuracy:57.350, Best F1-score:0.574
# 12/300 lr=0.00100 - loss:0.389, acc:55.099, val_loss:0.345, val_acc:60.050
# Best loss:0.353, Best accuracy:59.259, Best F1-score:0.599
# 13/300 lr=0.00100 - loss:0.386, acc:56.312, val_loss:0.363, val_acc:55.787
# Best loss:0.345, Best accuracy:60.050, Best F1-score:0.599
# 14/300 lr=0.00100 - loss:0.382, acc:56.246, val_loss:0.354, val_acc:59.954
# Best loss:0.345, Best accuracy:60.050, Best F1-score:0.599
# 15/300 lr=0.00100 - loss:0.382, acc:56.640, val_loss:0.352, val_acc:59.703
# Best loss:0.345, Best accuracy:60.050, Best F1-score:0.599
# 16/300 lr=0.00100 - loss:0.378, acc:57.450, val_loss:0.338, val_acc:61.709
# Best loss:0.345, Best accuracy:60.050, Best F1-score:0.599
# 17/300 lr=0.00100 - loss:0.380, acc:56.882, val_loss:0.341, val_acc:60.475
# Best loss:0.338, Best accuracy:61.709, Best F1-score:0.618
# 18/300 lr=0.00100 - loss:0.379, acc:57.336, val_loss:0.346, val_acc:59.954
# Best loss:0.338, Best accuracy:61.709, Best F1-score:0.618
# 19/300 lr=0.00100 - loss:0.379, acc:57.608, val_loss:0.339, val_acc:61.343
# Best loss:0.338, Best accuracy:61.709, Best F1-score:0.618
# 20/300 lr=0.00100 - loss:0.374, acc:58.356, val_loss:0.346, val_acc:59.529
# Best loss:0.338, Best accuracy:61.709, Best F1-score:0.618
# 21/300 lr=0.00100 - loss:0.374, acc:57.895, val_loss:0.344, val_acc:61.883
# Best loss:0.338, Best accuracy:61.709, Best F1-score:0.618
# 22/300 lr=0.00100 - loss:0.371, acc:58.474, val_loss:0.345, val_acc:62.307
# Best loss:0.344, Best accuracy:61.883, Best F1-score:0.618
# 23/300 lr=0.00100 - loss:0.366, acc:59.647, val_loss:0.335, val_acc:61.015
# Best loss:0.345, Best accuracy:62.307, Best F1-score:0.621
# 24/300 lr=0.00100 - loss:0.367, acc:59.270, val_loss:0.331, val_acc:63.272
# Best loss:0.345, Best accuracy:62.307, Best F1-score:0.621
# 25/300 lr=0.00100 - loss:0.362, acc:59.526, val_loss:0.335, val_acc:61.535
# Best loss:0.331, Best accuracy:63.272, Best F1-score:0.632
# 26/300 lr=0.00100 - loss:0.359, acc:60.922, val_loss:0.335, val_acc:60.841
# Best loss:0.331, Best accuracy:63.272, Best F1-score:0.632
# 27/300 lr=0.00100 - loss:0.357, acc:60.782, val_loss:0.329, val_acc:61.960
# Best loss:0.331, Best accuracy:63.272, Best F1-score:0.632
# 28/300 lr=0.00100 - loss:0.357, acc:61.234, val_loss:0.331, val_acc:61.015
# Best loss:0.331, Best accuracy:63.272, Best F1-score:0.632
# 29/300 lr=0.00100 - loss:0.357, acc:60.655, val_loss:0.330, val_acc:62.056
# Best loss:0.331, Best accuracy:63.272, Best F1-score:0.632
# 30/300 lr=0.00100 - loss:0.353, acc:61.594, val_loss:0.323, val_acc:61.883
# Best loss:0.331, Best accuracy:63.272, Best F1-score:0.632
# 31/300 lr=0.00100 - loss:0.350, acc:62.634, val_loss:0.332, val_acc:60.320
# Best loss:0.331, Best accuracy:63.272, Best F1-score:0.632
# 32/300 lr=0.00100 - loss:0.355, acc:61.109, val_loss:0.326, val_acc:62.307
# Best loss:0.331, Best accuracy:63.272, Best F1-score:0.632
# 33/300 lr=0.00100 - loss:0.349, acc:62.006, val_loss:0.323, val_acc:62.056
# Best loss:0.331, Best accuracy:63.272, Best F1-score:0.632
# 34/300 lr=0.00100 - loss:0.346, acc:63.012, val_loss:0.320, val_acc:63.349
# Best loss:0.331, Best accuracy:63.272, Best F1-score:0.632
# 35/300 lr=0.00100 - loss:0.347, acc:62.547, val_loss:0.321, val_acc:62.751
# Best loss:0.320, Best accuracy:63.349, Best F1-score:0.629
# 36/300 lr=0.00100 - loss:0.342, acc:63.404, val_loss:0.317, val_acc:63.445
# Best loss:0.320, Best accuracy:63.349, Best F1-score:0.629
# 37/300 lr=0.00100 - loss:0.341, acc:63.573, val_loss:0.318, val_acc:61.535
# Best loss:0.317, Best accuracy:63.445, Best F1-score:0.635
# 38/300 lr=0.00100 - loss:0.340, acc:63.206, val_loss:0.321, val_acc:62.924
# Best loss:0.317, Best accuracy:63.445, Best F1-score:0.635
# 39/300 lr=0.00100 - loss:0.341, acc:64.185, val_loss:0.333, val_acc:60.667
# Best loss:0.317, Best accuracy:63.445, Best F1-score:0.635
# 40/300 lr=0.00100 - loss:0.345, acc:62.758, val_loss:0.327, val_acc:62.230
# Best loss:0.317, Best accuracy:63.445, Best F1-score:0.635
# 41/300 lr=0.00100 - loss:0.338, acc:64.432, val_loss:0.324, val_acc:63.445
# Best loss:0.317, Best accuracy:63.445, Best F1-score:0.635
# 42/300 lr=0.00100 - loss:0.340, acc:63.929, val_loss:0.330, val_acc:63.445
# Best loss:0.317, Best accuracy:63.445, Best F1-score:0.635
# 43/300 lr=0.00100 - loss:0.342, acc:63.633, val_loss:0.321, val_acc:63.792
# Best loss:0.317, Best accuracy:63.445, Best F1-score:0.635
# 44/300 lr=0.00100 - loss:0.334, acc:64.959, val_loss:0.317, val_acc:63.368
# Best loss:0.321, Best accuracy:63.792, Best F1-score:0.636
# 45/300 lr=0.00100 - loss:0.330, acc:65.496, val_loss:0.329, val_acc:61.883
# Best loss:0.321, Best accuracy:63.792, Best F1-score:0.636
# 46/300 lr=0.00100 - loss:0.331, acc:65.859, val_loss:0.321, val_acc:64.313
# Best loss:0.321, Best accuracy:63.792, Best F1-score:0.636
# 47/300 lr=0.00100 - loss:0.328, acc:64.839, val_loss:0.320, val_acc:64.410
# Best loss:0.321, Best accuracy:64.313, Best F1-score:0.641
# 48/300 lr=0.00100 - loss:0.336, acc:64.054, val_loss:0.340, val_acc:60.224
# Best loss:0.320, Best accuracy:64.410, Best F1-score:0.641
# 49/300 lr=0.00100 - loss:0.328, acc:65.485, val_loss:0.323, val_acc:62.751
# Best loss:0.320, Best accuracy:64.410, Best F1-score:0.641
# 50/300 lr=0.00100 - loss:0.322, acc:67.094, val_loss:0.311, val_acc:64.757
# Best loss:0.320, Best accuracy:64.410, Best F1-score:0.641
# 51/300 lr=0.00100 - loss:0.326, acc:66.629, val_loss:0.311, val_acc:66.146
# Best loss:0.311, Best accuracy:64.757, Best F1-score:0.647
# 52/300 lr=0.00100 - loss:0.320, acc:66.874, val_loss:0.314, val_acc:64.660
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 53/300 lr=0.00100 - loss:0.321, acc:66.693, val_loss:0.318, val_acc:62.847
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 54/300 lr=0.00100 - loss:0.321, acc:67.190, val_loss:0.316, val_acc:63.445
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 55/300 lr=0.00100 - loss:0.317, acc:66.976, val_loss:0.311, val_acc:63.792
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 56/300 lr=0.00100 - loss:0.318, acc:67.274, val_loss:0.332, val_acc:62.056
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 57/300 lr=0.00100 - loss:0.321, acc:67.050, val_loss:0.318, val_acc:64.062
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 58/300 lr=0.00100 - loss:0.318, acc:67.679, val_loss:0.311, val_acc:64.757
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 59/300 lr=0.00100 - loss:0.313, acc:68.416, val_loss:0.314, val_acc:63.542
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 60/300 lr=0.00100 - loss:0.312, acc:68.690, val_loss:0.313, val_acc:63.194
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 61/300 lr=0.00100 - loss:0.315, acc:67.628, val_loss:0.307, val_acc:64.236
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 62/300 lr=0.00086 - loss:0.310, acc:69.182, val_loss:0.309, val_acc:65.451
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 63/300 lr=0.00086 - loss:0.304, acc:69.447, val_loss:0.329, val_acc:62.500
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 64/300 lr=0.00086 - loss:0.308, acc:68.812, val_loss:0.309, val_acc:64.410
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 65/300 lr=0.00086 - loss:0.306, acc:69.367, val_loss:0.311, val_acc:64.931
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 66/300 lr=0.00086 - loss:0.304, acc:69.999, val_loss:0.313, val_acc:63.619
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 67/300 lr=0.00086 - loss:0.308, acc:68.897, val_loss:0.310, val_acc:62.847
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 68/300 lr=0.00086 - loss:0.305, acc:70.259, val_loss:0.306, val_acc:65.451
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 69/300 lr=0.00086 - loss:0.303, acc:70.199, val_loss:0.324, val_acc:62.847
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 70/300 lr=0.00086 - loss:0.302, acc:69.480, val_loss:0.319, val_acc:63.715
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 71/300 lr=0.00086 - loss:0.303, acc:70.154, val_loss:0.321, val_acc:63.194
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 72/300 lr=0.00086 - loss:0.299, acc:70.640, val_loss:0.320, val_acc:62.500
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 73/300 lr=0.00086 - loss:0.295, acc:70.615, val_loss:0.326, val_acc:61.806
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 74/300 lr=0.00086 - loss:0.295, acc:71.076, val_loss:0.326, val_acc:61.285
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 75/300 lr=0.00086 - loss:0.295, acc:71.145, val_loss:0.314, val_acc:64.757
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 76/300 lr=0.00086 - loss:0.288, acc:72.084, val_loss:0.316, val_acc:63.021
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 77/300 lr=0.00086 - loss:0.288, acc:72.458, val_loss:0.321, val_acc:64.757
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 78/300 lr=0.00086 - loss:0.290, acc:71.937, val_loss:0.312, val_acc:64.583
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 79/300 lr=0.00086 - loss:0.286, acc:72.022, val_loss:0.316, val_acc:64.410
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 80/300 lr=0.00086 - loss:0.287, acc:71.857, val_loss:0.314, val_acc:64.583
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 81/300 lr=0.00086 - loss:0.287, acc:72.167, val_loss:0.313, val_acc:63.542
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 82/300 lr=0.00074 - loss:0.276, acc:73.823, val_loss:0.316, val_acc:64.583
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 83/300 lr=0.00074 - loss:0.277, acc:73.805, val_loss:0.319, val_acc:64.062
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 84/300 lr=0.00074 - loss:0.282, acc:73.141, val_loss:0.322, val_acc:62.847
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 85/300 lr=0.00074 - loss:0.279, acc:72.970, val_loss:0.322, val_acc:63.889
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 86/300 lr=0.00074 - loss:0.279, acc:73.124, val_loss:0.324, val_acc:63.542
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 87/300 lr=0.00074 - loss:0.279, acc:73.620, val_loss:0.320, val_acc:62.674
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 88/300 lr=0.00074 - loss:0.275, acc:73.905, val_loss:0.323, val_acc:63.715
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 89/300 lr=0.00074 - loss:0.272, acc:74.786, val_loss:0.323, val_acc:62.500
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 90/300 lr=0.00074 - loss:0.275, acc:73.820, val_loss:0.316, val_acc:65.799
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 91/300 lr=0.00074 - loss:0.273, acc:74.842, val_loss:0.319, val_acc:63.194
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 92/300 lr=0.00074 - loss:0.270, acc:74.922, val_loss:0.334, val_acc:61.806
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 93/300 lr=0.00074 - loss:0.277, acc:73.244, val_loss:0.319, val_acc:63.542
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 94/300 lr=0.00074 - loss:0.266, acc:75.519, val_loss:0.313, val_acc:64.236
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 95/300 lr=0.00074 - loss:0.267, acc:75.100, val_loss:0.320, val_acc:63.368
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 96/300 lr=0.00074 - loss:0.262, acc:75.559, val_loss:0.320, val_acc:63.542
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 97/300 lr=0.00074 - loss:0.262, acc:75.926, val_loss:0.321, val_acc:63.889
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 98/300 lr=0.00074 - loss:0.263, acc:76.280, val_loss:0.332, val_acc:60.841
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 99/300 lr=0.00074 - loss:0.268, acc:75.703, val_loss:0.352, val_acc:60.938
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 100/300 lr=0.00074 - loss:0.263, acc:75.812, val_loss:0.327, val_acc:64.062
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 101/300 lr=0.00074 - loss:0.257, acc:76.080, val_loss:0.326, val_acc:62.674
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 102/300 lr=0.00064 - loss:0.257, acc:76.565, val_loss:0.343, val_acc:60.590
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 103/300 lr=0.00064 - loss:0.252, acc:77.862, val_loss:0.321, val_acc:63.021
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 104/300 lr=0.00064 - loss:0.248, acc:78.339, val_loss:0.317, val_acc:65.625
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 105/300 lr=0.00064 - loss:0.251, acc:77.918, val_loss:0.326, val_acc:62.674
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 106/300 lr=0.00064 - loss:0.253, acc:77.622, val_loss:0.325, val_acc:62.847
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 107/300 lr=0.00064 - loss:0.255, acc:77.221, val_loss:0.321, val_acc:63.889
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 108/300 lr=0.00064 - loss:0.252, acc:77.646, val_loss:0.332, val_acc:63.021
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 109/300 lr=0.00064 - loss:0.250, acc:77.971, val_loss:0.325, val_acc:63.542
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 110/300 lr=0.00064 - loss:0.249, acc:78.343, val_loss:0.342, val_acc:59.549
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 111/300 lr=0.00064 - loss:0.246, acc:78.319, val_loss:0.318, val_acc:65.278
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 112/300 lr=0.00064 - loss:0.248, acc:78.114, val_loss:0.327, val_acc:63.368
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
#
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 147/300 lr=0.00047 - loss:0.218, acc:82.289, val_loss:0.359, val_acc:60.841
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 148/300 lr=0.00047 - loss:0.212, acc:83.137, val_loss:0.369, val_acc:60.417
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 149/300 lr=0.00047 - loss:0.208, acc:83.932, val_loss:0.375, val_acc:59.973
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 150/300 lr=0.00047 - loss:0.207, acc:84.123, val_loss:0.369, val_acc:59.028
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 151/300 lr=0.00047 - loss:0.208, acc:83.861, val_loss:0.353, val_acc:61.979
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 152/300 lr=0.00047 - loss:0.203, acc:84.620, val_loss:0.364, val_acc:60.764
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 153/300 lr=0.00047 - loss:0.206, acc:83.939, val_loss:0.367, val_acc:58.063
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 154/300 lr=0.00047 - loss:0.204, acc:84.288, val_loss:0.371, val_acc:59.877
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 155/300 lr=0.00047 - loss:0.209, acc:83.667, val_loss:0.362, val_acc:60.667
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 156/300 lr=0.00047 - loss:0.202, acc:84.591, val_loss:0.371, val_acc:57.793
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 157/300 lr=0.00047 - loss:0.204, acc:84.284, val_loss:0.361, val_acc:60.050
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 158/300 lr=0.00047 - loss:0.204, acc:84.172, val_loss:0.362, val_acc:60.938
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 159/300 lr=0.00047 - loss:0.202, acc:84.428, val_loss:0.358, val_acc:60.320
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 160/300 lr=0.00047 - loss:0.202, acc:84.529, val_loss:0.364, val_acc:59.452
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 161/300 lr=0.00047 - loss:0.198, acc:85.637, val_loss:0.372, val_acc:59.452
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 162/300 lr=0.00041 - loss:0.204, acc:84.373, val_loss:0.364, val_acc:59.973
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 163/300 lr=0.00041 - loss:0.202, acc:84.820, val_loss:0.373, val_acc:60.147
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 164/300 lr=0.00041 - loss:0.198, acc:85.245, val_loss:0.375, val_acc:59.182
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 165/300 lr=0.00041 - loss:0.199, acc:85.334, val_loss:0.379, val_acc:58.140
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 166/300 lr=0.00041 - loss:0.196, acc:85.490, val_loss:0.375, val_acc:58.410
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 167/300 lr=0.00041 - loss:0.195, acc:85.550, val_loss:0.371, val_acc:59.973
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 168/300 lr=0.00041 - loss:0.193, acc:85.946, val_loss:0.386, val_acc:58.488
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 169/300 lr=0.00041 - loss:0.195, acc:85.628, val_loss:0.372, val_acc:59.626
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 170/300 lr=0.00041 - loss:0.191, acc:85.906, val_loss:0.377, val_acc:60.069
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 171/300 lr=0.00041 - loss:0.194, acc:86.171, val_loss:0.370, val_acc:59.799
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 172/300 lr=0.00041 - loss:0.195, acc:85.394, val_loss:0.376, val_acc:58.584
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 173/300 lr=0.00041 - loss:0.195, acc:85.210, val_loss:0.376, val_acc:58.140
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 174/300 lr=0.00041 - loss:0.194, acc:86.285, val_loss:0.373, val_acc:57.986
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 175/300 lr=0.00041 - loss:0.191, acc:85.846, val_loss:0.377, val_acc:58.661
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 176/300 lr=0.00041 - loss:0.193, acc:86.171, val_loss:0.370, val_acc:59.973
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 177/300 lr=0.00041 - loss:0.190, acc:86.467, val_loss:0.372, val_acc:59.279
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 178/300 lr=0.00041 - loss:0.187, acc:86.777, val_loss:0.372, val_acc:58.758
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 179/300 lr=0.00041 - loss:0.191, acc:86.576, val_loss:0.368, val_acc:58.584
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 180/300 lr=0.00041 - loss:0.190, acc:86.527, val_loss:0.379, val_acc:58.160
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 181/300 lr=0.00041 - loss:0.189, acc:86.512, val_loss:0.367, val_acc:58.758
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 182/300 lr=0.00035 - loss:0.185, acc:86.652, val_loss:0.374, val_acc:58.584
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 183/300 lr=0.00035 - loss:0.183, acc:87.237, val_loss:0.378, val_acc:58.410
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 184/300 lr=0.00035 - loss:0.187, acc:86.765, val_loss:0.375, val_acc:58.661
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 185/300 lr=0.00035 - loss:0.182, acc:87.384, val_loss:0.380, val_acc:57.967
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 186/300 lr=0.00035 - loss:0.188, acc:86.868, val_loss:0.366, val_acc:60.050
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 187/300 lr=0.00035 - loss:0.186, acc:86.857, val_loss:0.382, val_acc:59.799
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 188/300 lr=0.00035 - loss:0.185, acc:87.422, val_loss:0.381, val_acc:58.410
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 189/300 lr=0.00035 - loss:0.183, acc:87.745, val_loss:0.392, val_acc:57.542
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 190/300 lr=0.00035 - loss:0.186, acc:87.008, val_loss:0.383, val_acc:58.237
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 191/300 lr=0.00035 - loss:0.182, acc:87.344, val_loss:0.383, val_acc:57.716
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 192/300 lr=0.00035 - loss:0.180, acc:87.562, val_loss:0.393, val_acc:57.716
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 193/300 lr=0.00035 - loss:0.184, acc:87.048, val_loss:0.392, val_acc:55.633
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 194/300 lr=0.00035 - loss:0.179, acc:87.861, val_loss:0.387, val_acc:58.584
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 195/300 lr=0.00035 - loss:0.180, acc:87.894, val_loss:0.394, val_acc:58.931
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 196/300 lr=0.00035 - loss:0.178, acc:87.553, val_loss:0.399, val_acc:56.327
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 197/300 lr=0.00035 - loss:0.181, acc:87.645, val_loss:0.392, val_acc:57.542
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 198/300 lr=0.00035 - loss:0.182, acc:87.400, val_loss:0.392, val_acc:56.674
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 199/300 lr=0.00035 - loss:0.178, acc:88.125, val_loss:0.395, val_acc:57.446
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 200/300 lr=0.00035 - loss:0.181, acc:87.233, val_loss:0.395, val_acc:57.446
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 201/300 lr=0.00035 - loss:0.181, acc:87.765, val_loss:0.387, val_acc:57.967
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 202/300 lr=0.00030 - loss:0.178, acc:88.130, val_loss:0.390, val_acc:57.195
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 203/300 lr=0.00030 - loss:0.179, acc:87.765, val_loss:0.390, val_acc:58.063
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 204/300 lr=0.00030 - loss:0.174, acc:88.907, val_loss:0.388, val_acc:57.022
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 205/300 lr=0.00030 - loss:0.174, acc:88.504, val_loss:0.408, val_acc:57.369
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 206/300 lr=0.00030 - loss:0.182, acc:87.248, val_loss:0.395, val_acc:57.369
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 207/300 lr=0.00030 - loss:0.176, acc:88.455, val_loss:0.398, val_acc:57.542
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 208/300 lr=0.00030 - loss:0.174, acc:88.379, val_loss:0.397, val_acc:57.099
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 209/300 lr=0.00030 - loss:0.175, acc:88.506, val_loss:0.391, val_acc:57.967
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 210/300 lr=0.00030 - loss:0.171, acc:89.232, val_loss:0.397, val_acc:57.272
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 211/300 lr=0.00030 - loss:0.175, acc:88.366, val_loss:0.400, val_acc:57.369
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 212/300 lr=0.00030 - loss:0.173, acc:88.646, val_loss:0.402, val_acc:56.057
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
#
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 280/300 lr=0.00019 - loss:0.156, acc:90.690, val_loss:0.414, val_acc:56.752
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 281/300 lr=0.00019 - loss:0.157, acc:90.694, val_loss:0.416, val_acc:55.883
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 282/300 lr=0.00017 - loss:0.150, acc:91.851, val_loss:0.416, val_acc:56.057
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 283/300 lr=0.00017 - loss:0.155, acc:91.126, val_loss:0.414, val_acc:57.195
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 284/300 lr=0.00017 - loss:0.154, acc:91.364, val_loss:0.408, val_acc:57.272
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 285/300 lr=0.00017 - loss:0.152, acc:91.255, val_loss:0.408, val_acc:57.890
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 286/300 lr=0.00017 - loss:0.153, acc:91.765, val_loss:0.419, val_acc:57.446
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 287/300 lr=0.00017 - loss:0.153, acc:91.186, val_loss:0.414, val_acc:57.099
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 288/300 lr=0.00017 - loss:0.153, acc:91.700, val_loss:0.411, val_acc:56.578
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 289/300 lr=0.00017 - loss:0.151, acc:91.756, val_loss:0.414, val_acc:56.057
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 290/300 lr=0.00017 - loss:0.155, acc:91.175, val_loss:0.406, val_acc:57.099
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 291/300 lr=0.00017 - loss:0.153, acc:91.130, val_loss:0.413, val_acc:56.057
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 292/300 lr=0.00017 - loss:0.153, acc:91.086, val_loss:0.403, val_acc:57.272
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 293/300 lr=0.00017 - loss:0.149, acc:91.871, val_loss:0.414, val_acc:56.578
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 294/300 lr=0.00017 - loss:0.159, acc:90.518, val_loss:0.413, val_acc:57.446
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 295/300 lr=0.00017 - loss:0.158, acc:90.805, val_loss:0.409, val_acc:56.752
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 296/300 lr=0.00017 - loss:0.152, acc:91.691, val_loss:0.409, val_acc:57.793
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 297/300 lr=0.00017 - loss:0.151, acc:91.671, val_loss:0.410, val_acc:57.793
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 298/300 lr=0.00017 - loss:0.153, acc:91.716, val_loss:0.418, val_acc:55.883
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 299/300 lr=0.00017 - loss:0.155, acc:91.030, val_loss:0.411, val_acc:57.542
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# 300/300 lr=0.00017 - loss:0.153, acc:91.375, val_loss:0.411, val_acc:56.752
# Best loss:0.311, Best accuracy:66.146, Best F1-score:0.659
# [*] Done - acc:66.146

# %%
end()

# %%
print(f'max:{max(fold_acc)}, min:{min(fold_acc)}, average:{sum(fold_acc)/len(fold_acc)}')
# Out:
# max:66.14583333333333, min:66.14583333333333, average:66.14583333333333

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
# Out:
# WAR(Weighted Average Recall)   : 66.00%
# UAR(Unweighted Average Recall) : 66.00%
