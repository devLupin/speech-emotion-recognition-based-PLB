# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = 'TIMNET-dataset'
DATA_PATH = 'IEMOCAP'
CLASS_LABELS = Config.IEMOCAP_LABELS
k = 10

# 64-CNN * 2(Last CNN dilation=2) - CBAM - Depthwise-seperable - Reshape - Spatial-attention - Self-attention - Capsule
# Deltas : (196,39,1)
model_name = 'RoutingConvNet(64 CNN, Last dilated)+CBAM+Depthwise-separable-Caps+SpatialAttn'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 150
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding=padding),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule], name='primarycap_reshape'),
        Lambda(function=PrimaryCapssquash, name='primarycap_squash')
    ])
    
  def call(self, inputs):
    x = self.conv(inputs)
    return x

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.cbam = CBAM(64) # sharing
    
    self.primarycap = PrimaryCap()
    self.spatial_attn = SpatialGate()
    
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    x = inputs
    
    cap = self.conv1(x)
    cap = cap + self.cbam(cap)
    cap = self.conv2(cap)
    cap = cap + self.cbam(cap)
    
    primarycaps = self.primarycap(cap)
    primarycaps = tf.expand_dims(primarycaps, axis=-1)
    primarycaps = primarycaps + self.spatial_attn(primarycaps)
    primarycaps = tf.squeeze(primarycaps, axis=-1)
    
    cap = primarycaps
    
    sa = self.attention([primarycaps, primarycaps, primarycaps])
    sa = self.LN(sa)
    
    cap = self.lamb([cap, sa])
    
    capsule = self.capsule(cap)
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1416
#
#  sequential_1 (Sequential)   (None, 46, 7, 64)         37300
#
#  cbam (CBAM)                 multiple                  4294
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  spatial_gate_1 (SpatialGate  multiple                 102
#  )
#
#  attention (Attention)       multiple                  1
#
#  layer_normalization (LayerN  multiple                 128
#  ormalization)
#
#  lambda (Lambda)             multiple                  0
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  260
#
# =================================================================
# Total params: 93,677
# Trainable params: 93,099
# Non-trainable params: 578
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}.npy', 'rb') as f:
    x = np.load(f)
    y = np.load(f)

y = to_categorical(y,num_classes=len(CLASS_LABELS))

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

# %%
import tensorflow_addons as tfa

for i, (train, test) in tqdm(enumerate(kfold.split(x, y)), desc=f'Training {k}-Fold.....'):
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = x[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_test, y_test = x[test], y[test]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_test = tf.expand_dims(x_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_test_loss = 0x3f3f3f
    best_test_acc = -1
    best_test_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        test_loss, test_acc, f1s = [], [], []
        for features, labels in batch_test:
            loss, acc, pred = test_step(model, features, labels)
            test_loss.append(loss)
            test_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(test_loss)/len(test_loss)
        val_acc = sum(test_acc)/len(test_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_test_loss:.3f}, Best accuracy:{best_test_acc:.3f}, Best F1-score:{best_test_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_test_acc < val_acc:
            best_test_acc = val_acc
            best_test_loss = val_loss
            best_test_f1 = f1_score
            model.save_weights(h5_path)
            
    
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    
    for features, labels in batch_test:
        best_pred = model(features, training=False)
        emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(labels, axis=1))
        predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
            
    
    print(f'[*] Done - acc:{best_test_acc:.3f}')
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    fold_acc.append(best_test_acc)
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/150 lr=0.00100 - loss:0.461, acc:41.265, val_loss:0.440, val_acc:45.139
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/150 lr=0.00100 - loss:0.433, acc:46.345, val_loss:0.433, val_acc:46.250
# Best loss:0.440, Best accuracy:45.139, Best F1-score:0.459
# 3/150 lr=0.00100 - loss:0.423, acc:48.452, val_loss:0.430, val_acc:43.264
# Best loss:0.433, Best accuracy:46.250, Best F1-score:0.452
# 4/150 lr=0.00100 - loss:0.424, acc:48.156, val_loss:0.410, val_acc:49.549
# Best loss:0.433, Best accuracy:46.250, Best F1-score:0.452
# 5/150 lr=0.00100 - loss:0.415, acc:50.057, val_loss:0.405, val_acc:48.056
# Best loss:0.410, Best accuracy:49.549, Best F1-score:0.501
# 6/150 lr=0.00100 - loss:0.408, acc:51.844, val_loss:0.414, val_acc:48.160
# Best loss:0.410, Best accuracy:49.549, Best F1-score:0.501
# 7/150 lr=0.00100 - loss:0.410, acc:51.461, val_loss:0.405, val_acc:49.444
# Best loss:0.410, Best accuracy:49.549, Best F1-score:0.501
# 8/150 lr=0.00100 - loss:0.403, acc:52.420, val_loss:0.398, val_acc:50.590
# Best loss:0.410, Best accuracy:49.549, Best F1-score:0.501
# 9/150 lr=0.00100 - loss:0.404, acc:52.478, val_loss:0.397, val_acc:49.653
# Best loss:0.398, Best accuracy:50.590, Best F1-score:0.496
# 10/150 lr=0.00100 - loss:0.396, acc:54.286, val_loss:0.391, val_acc:53.646
# Best loss:0.398, Best accuracy:50.590, Best F1-score:0.496
# 11/150 lr=0.00100 - loss:0.392, acc:55.187, val_loss:0.383, val_acc:53.646
# Best loss:0.391, Best accuracy:53.646, Best F1-score:0.541
# 12/150 lr=0.00100 - loss:0.392, acc:55.189, val_loss:0.385, val_acc:53.333
# Best loss:0.391, Best accuracy:53.646, Best F1-score:0.541
# 13/150 lr=0.00100 - loss:0.389, acc:54.753, val_loss:0.390, val_acc:53.125
# Best loss:0.391, Best accuracy:53.646, Best F1-score:0.541
# 14/150 lr=0.00100 - loss:0.387, acc:55.528, val_loss:0.396, val_acc:50.729
# Best loss:0.391, Best accuracy:53.646, Best F1-score:0.541
# 15/150 lr=0.00100 - loss:0.384, acc:56.124, val_loss:0.382, val_acc:55.243
# Best loss:0.391, Best accuracy:53.646, Best F1-score:0.541
# 16/150 lr=0.00100 - loss:0.383, acc:56.351, val_loss:0.376, val_acc:56.389
# Best loss:0.382, Best accuracy:55.243, Best F1-score:0.551
# 17/150 lr=0.00100 - loss:0.381, acc:57.616, val_loss:0.381, val_acc:53.958
# Best loss:0.376, Best accuracy:56.389, Best F1-score:0.572
# 18/150 lr=0.00100 - loss:0.380, acc:57.649, val_loss:0.381, val_acc:56.076
# Best loss:0.376, Best accuracy:56.389, Best F1-score:0.572
# 19/150 lr=0.00100 - loss:0.377, acc:58.324, val_loss:0.375, val_acc:55.764
# Best loss:0.376, Best accuracy:56.389, Best F1-score:0.572
# 20/150 lr=0.00100 - loss:0.373, acc:59.304, val_loss:0.378, val_acc:55.417
# Best loss:0.376, Best accuracy:56.389, Best F1-score:0.572
# 21/150 lr=0.00100 - loss:0.373, acc:58.234, val_loss:0.370, val_acc:56.285
# Best loss:0.376, Best accuracy:56.389, Best F1-score:0.572
# 22/150 lr=0.00100 - loss:0.375, acc:57.691, val_loss:0.382, val_acc:54.688
# Best loss:0.376, Best accuracy:56.389, Best F1-score:0.572
# 23/150 lr=0.00100 - loss:0.369, acc:59.870, val_loss:0.372, val_acc:56.146
# Best loss:0.376, Best accuracy:56.389, Best F1-score:0.572
# 24/150 lr=0.00100 - loss:0.369, acc:59.174, val_loss:0.375, val_acc:57.292
# Best loss:0.376, Best accuracy:56.389, Best F1-score:0.572
# 25/150 lr=0.00100 - loss:0.368, acc:58.978, val_loss:0.372, val_acc:54.583
# Best loss:0.375, Best accuracy:57.292, Best F1-score:0.569
# 26/150 lr=0.00100 - loss:0.369, acc:58.946, val_loss:0.371, val_acc:55.139
# Best loss:0.375, Best accuracy:57.292, Best F1-score:0.569
# 27/150 lr=0.00100 - loss:0.368, acc:58.878, val_loss:0.379, val_acc:54.722
# Best loss:0.375, Best accuracy:57.292, Best F1-score:0.569
# 28/150 lr=0.00100 - loss:0.365, acc:58.931, val_loss:0.364, val_acc:57.396
# Best loss:0.375, Best accuracy:57.292, Best F1-score:0.569
# 29/150 lr=0.00100 - loss:0.361, acc:60.075, val_loss:0.367, val_acc:57.951
# Best loss:0.364, Best accuracy:57.396, Best F1-score:0.579
# 30/150 lr=0.00100 - loss:0.361, acc:60.714, val_loss:0.379, val_acc:54.028
# Best loss:0.367, Best accuracy:57.951, Best F1-score:0.577
# 31/150 lr=0.00100 - loss:0.359, acc:60.939, val_loss:0.360, val_acc:58.681
# Best loss:0.367, Best accuracy:57.951, Best F1-score:0.577
# 32/150 lr=0.00100 - loss:0.356, acc:61.009, val_loss:0.361, val_acc:57.986
# Best loss:0.360, Best accuracy:58.681, Best F1-score:0.587
# 33/150 lr=0.00100 - loss:0.353, acc:61.827, val_loss:0.358, val_acc:56.597
# Best loss:0.360, Best accuracy:58.681, Best F1-score:0.587
# 34/150 lr=0.00100 - loss:0.355, acc:62.271, val_loss:0.364, val_acc:57.500
# Best loss:0.360, Best accuracy:58.681, Best F1-score:0.587
# 35/150 lr=0.00100 - loss:0.360, acc:60.836, val_loss:0.356, val_acc:57.153
# Best loss:0.360, Best accuracy:58.681, Best F1-score:0.587
# 36/150 lr=0.00100 - loss:0.358, acc:60.549, val_loss:0.369, val_acc:56.111
# Best loss:0.360, Best accuracy:58.681, Best F1-score:0.587
# 37/150 lr=0.00100 - loss:0.351, acc:61.866, val_loss:0.351, val_acc:58.368
# Best loss:0.360, Best accuracy:58.681, Best F1-score:0.587
# 38/150 lr=0.00100 - loss:0.351, acc:62.261, val_loss:0.357, val_acc:57.292
# Best loss:0.360, Best accuracy:58.681, Best F1-score:0.587
# 39/150 lr=0.00100 - loss:0.350, acc:62.196, val_loss:0.352, val_acc:59.618
# Best loss:0.360, Best accuracy:58.681, Best F1-score:0.587
# 40/150 lr=0.00100 - loss:0.352, acc:61.771, val_loss:0.356, val_acc:58.785
# Best loss:0.352, Best accuracy:59.618, Best F1-score:0.589
# 41/150 lr=0.00100 - loss:0.347, acc:62.113, val_loss:0.363, val_acc:57.639
# Best loss:0.352, Best accuracy:59.618, Best F1-score:0.589
# 42/150 lr=0.00100 - loss:0.348, acc:62.514, val_loss:0.353, val_acc:59.236
# Best loss:0.352, Best accuracy:59.618, Best F1-score:0.589
# 43/150 lr=0.00100 - loss:0.342, acc:63.191, val_loss:0.351, val_acc:57.986
# Best loss:0.352, Best accuracy:59.618, Best F1-score:0.589
# 44/150 lr=0.00100 - loss:0.342, acc:63.701, val_loss:0.348, val_acc:59.757
# Best loss:0.352, Best accuracy:59.618, Best F1-score:0.589
# 45/150 lr=0.00100 - loss:0.346, acc:61.996, val_loss:0.360, val_acc:58.021
# Best loss:0.348, Best accuracy:59.757, Best F1-score:0.604
# 46/150 lr=0.00100 - loss:0.348, acc:61.996, val_loss:0.353, val_acc:56.944
# Best loss:0.348, Best accuracy:59.757, Best F1-score:0.604
# 47/150 lr=0.00100 - loss:0.341, acc:63.487, val_loss:0.338, val_acc:60.486
# Best loss:0.348, Best accuracy:59.757, Best F1-score:0.604
# 48/150 lr=0.00100 - loss:0.339, acc:63.916, val_loss:0.344, val_acc:59.722
# Best loss:0.338, Best accuracy:60.486, Best F1-score:0.603
# 49/150 lr=0.00100 - loss:0.342, acc:64.081, val_loss:0.345, val_acc:59.653
# Best loss:0.338, Best accuracy:60.486, Best F1-score:0.603
# 50/150 lr=0.00100 - loss:0.338, acc:63.979, val_loss:0.356, val_acc:58.368
# Best loss:0.338, Best accuracy:60.486, Best F1-score:0.603
# 51/150 lr=0.00100 - loss:0.340, acc:63.967, val_loss:0.340, val_acc:59.444
# Best loss:0.338, Best accuracy:60.486, Best F1-score:0.603
# 52/150 lr=0.00100 - loss:0.336, acc:64.633, val_loss:0.342, val_acc:59.722
# Best loss:0.338, Best accuracy:60.486, Best F1-score:0.603
# 53/150 lr=0.00100 - loss:0.331, acc:65.697, val_loss:0.348, val_acc:59.132
# Best loss:0.338, Best accuracy:60.486, Best F1-score:0.603
# 54/150 lr=0.00100 - loss:0.342, acc:63.861, val_loss:0.361, val_acc:56.285
# Best loss:0.338, Best accuracy:60.486, Best F1-score:0.603
# 55/150 lr=0.00100 - loss:0.333, acc:64.590, val_loss:0.336, val_acc:59.757
# Best loss:0.338, Best accuracy:60.486, Best F1-score:0.603
# 56/150 lr=0.00100 - loss:0.329, acc:66.543, val_loss:0.344, val_acc:59.618
# Best loss:0.338, Best accuracy:60.486, Best F1-score:0.603
# 57/150 lr=0.00100 - loss:0.333, acc:64.557, val_loss:0.358, val_acc:56.146
# Best loss:0.338, Best accuracy:60.486, Best F1-score:0.603
# 58/150 lr=0.00100 - loss:0.339, acc:63.578, val_loss:0.341, val_acc:58.194
# Best loss:0.338, Best accuracy:60.486, Best F1-score:0.603
# 59/150 lr=0.00100 - loss:0.334, acc:64.896, val_loss:0.339, val_acc:60.625
# Best loss:0.338, Best accuracy:60.486, Best F1-score:0.603
# 60/150 lr=0.00100 - loss:0.325, acc:66.378, val_loss:0.350, val_acc:59.618
# Best loss:0.339, Best accuracy:60.625, Best F1-score:0.598
# 61/150 lr=0.00100 - loss:0.325, acc:66.283, val_loss:0.337, val_acc:59.410
# Best loss:0.339, Best accuracy:60.625, Best F1-score:0.598
# 62/150 lr=0.00086 - loss:0.325, acc:66.285, val_loss:0.347, val_acc:58.368
# Best loss:0.339, Best accuracy:60.625, Best F1-score:0.598
# 63/150 lr=0.00086 - loss:0.323, acc:67.159, val_loss:0.354, val_acc:57.847
# Best loss:0.339, Best accuracy:60.625, Best F1-score:0.598
# 64/150 lr=0.00086 - loss:0.327, acc:66.278, val_loss:0.334, val_acc:60.799
# Best loss:0.339, Best accuracy:60.625, Best F1-score:0.598
# 65/150 lr=0.00086 - loss:0.321, acc:66.964, val_loss:0.325, val_acc:60.972
# Best loss:0.334, Best accuracy:60.799, Best F1-score:0.599
# 66/150 lr=0.00086 - loss:0.315, acc:67.833, val_loss:0.327, val_acc:61.840
# Best loss:0.325, Best accuracy:60.972, Best F1-score:0.610
# 67/150 lr=0.00086 - loss:0.321, acc:66.836, val_loss:0.338, val_acc:59.618
# Best loss:0.327, Best accuracy:61.840, Best F1-score:0.615
# 68/150 lr=0.00086 - loss:0.317, acc:67.725, val_loss:0.327, val_acc:63.819
# Best loss:0.327, Best accuracy:61.840, Best F1-score:0.615
# 69/150 lr=0.00086 - loss:0.317, acc:67.019, val_loss:0.324, val_acc:62.361
# Best loss:0.327, Best accuracy:63.819, Best F1-score:0.634
# 70/150 lr=0.00086 - loss:0.313, acc:68.566, val_loss:0.322, val_acc:62.083
# Best loss:0.327, Best accuracy:63.819, Best F1-score:0.634
# 71/150 lr=0.00086 - loss:0.314, acc:68.125, val_loss:0.331, val_acc:61.528
# Best loss:0.327, Best accuracy:63.819, Best F1-score:0.634
# 72/150 lr=0.00086 - loss:0.313, acc:68.138, val_loss:0.324, val_acc:61.319
# Best loss:0.327, Best accuracy:63.819, Best F1-score:0.634
# 73/150 lr=0.00086 - loss:0.316, acc:67.750, val_loss:0.323, val_acc:62.569
# Best loss:0.327, Best accuracy:63.819, Best F1-score:0.634
# 74/150 lr=0.00086 - loss:0.315, acc:68.008, val_loss:0.337, val_acc:59.931
# Best loss:0.327, Best accuracy:63.819, Best F1-score:0.634
# 75/150 lr=0.00086 - loss:0.309, acc:68.902, val_loss:0.323, val_acc:62.778
# Best loss:0.327, Best accuracy:63.819, Best F1-score:0.634
# 76/150 lr=0.00086 - loss:0.310, acc:68.882, val_loss:0.336, val_acc:59.444
# Best loss:0.327, Best accuracy:63.819, Best F1-score:0.634
# 77/150 lr=0.00086 - loss:0.310, acc:68.642, val_loss:0.320, val_acc:62.396
# Best loss:0.327, Best accuracy:63.819, Best F1-score:0.634
# 78/150 lr=0.00086 - loss:0.310, acc:68.900, val_loss:0.322, val_acc:61.528
# Best loss:0.327, Best accuracy:63.819, Best F1-score:0.634
# 79/150 lr=0.00086 - loss:0.311, acc:68.437, val_loss:0.329, val_acc:61.389
# Best loss:0.327, Best accuracy:63.819, Best F1-score:0.634
# 80/150 lr=0.00086 - loss:0.305, acc:69.423, val_loss:0.318, val_acc:63.090
# Best loss:0.327, Best accuracy:63.819, Best F1-score:0.634
# 81/150 lr=0.00086 - loss:0.305, acc:69.240, val_loss:0.325, val_acc:61.007
# Best loss:0.327, Best accuracy:63.819, Best F1-score:0.634
# 82/150 lr=0.00074 - loss:0.302, acc:70.146, val_loss:0.323, val_acc:63.576
# Best loss:0.327, Best accuracy:63.819, Best F1-score:0.634
# 83/150 lr=0.00074 - loss:0.295, acc:70.602, val_loss:0.313, val_acc:65.417
# Best loss:0.327, Best accuracy:63.819, Best F1-score:0.634
# 84/150 lr=0.00074 - loss:0.302, acc:70.307, val_loss:0.316, val_acc:63.264
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 85/150 lr=0.00074 - loss:0.299, acc:69.748, val_loss:0.315, val_acc:62.882
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 86/150 lr=0.00074 - loss:0.291, acc:71.606, val_loss:0.327, val_acc:61.667
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 87/150 lr=0.00074 - loss:0.302, acc:69.598, val_loss:0.329, val_acc:63.472
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 88/150 lr=0.00074 - loss:0.299, acc:70.387, val_loss:0.326, val_acc:61.146
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 89/150 lr=0.00074 - loss:0.298, acc:70.139, val_loss:0.324, val_acc:63.611
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 90/150 lr=0.00074 - loss:0.299, acc:70.184, val_loss:0.315, val_acc:63.437
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 91/150 lr=0.00074 - loss:0.291, acc:70.988, val_loss:0.321, val_acc:62.743
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 92/150 lr=0.00074 - loss:0.292, acc:71.519, val_loss:0.325, val_acc:63.264
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 93/150 lr=0.00074 - loss:0.295, acc:71.128, val_loss:0.321, val_acc:62.049
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 94/150 lr=0.00074 - loss:0.293, acc:71.444, val_loss:0.314, val_acc:63.264
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 95/150 lr=0.00074 - loss:0.297, acc:70.598, val_loss:0.321, val_acc:62.014
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 96/150 lr=0.00074 - loss:0.288, acc:71.945, val_loss:0.316, val_acc:62.743
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 97/150 lr=0.00074 - loss:0.290, acc:71.395, val_loss:0.317, val_acc:62.917
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 98/150 lr=0.00074 - loss:0.288, acc:72.270, val_loss:0.315, val_acc:63.611
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 99/150 lr=0.00074 - loss:0.289, acc:71.784, val_loss:0.316, val_acc:61.701
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 100/150 lr=0.00074 - loss:0.294, acc:70.832, val_loss:0.340, val_acc:58.924
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 101/150 lr=0.00074 - loss:0.291, acc:72.398, val_loss:0.322, val_acc:62.535
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 102/150 lr=0.00064 - loss:0.290, acc:71.771, val_loss:0.323, val_acc:61.875
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 103/150 lr=0.00064 - loss:0.285, acc:72.568, val_loss:0.310, val_acc:64.167
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 104/150 lr=0.00064 - loss:0.280, acc:73.469, val_loss:0.315, val_acc:62.569
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 105/150 lr=0.00064 - loss:0.280, acc:73.207, val_loss:0.320, val_acc:64.688
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 106/150 lr=0.00064 - loss:0.280, acc:73.732, val_loss:0.322, val_acc:63.056
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 107/150 lr=0.00064 - loss:0.286, acc:72.045, val_loss:0.313, val_acc:64.340
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 108/150 lr=0.00064 - loss:0.276, acc:73.783, val_loss:0.311, val_acc:63.090
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 109/150 lr=0.00064 - loss:0.272, acc:74.155, val_loss:0.311, val_acc:64.028
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 110/150 lr=0.00064 - loss:0.273, acc:74.636, val_loss:0.316, val_acc:61.146
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 111/150 lr=0.00064 - loss:0.277, acc:73.577, val_loss:0.324, val_acc:61.493
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 112/150 lr=0.00064 - loss:0.276, acc:74.273, val_loss:0.314, val_acc:65.729
# Best loss:0.313, Best accuracy:65.417, Best F1-score:0.650
# 113/150 lr=0.00064 - loss:0.276, acc:73.351, val_loss:0.307, val_acc:66.111
# Best loss:0.314, Best accuracy:65.729, Best F1-score:0.657
# 114/150 lr=0.00064 - loss:0.274, acc:73.963, val_loss:0.317, val_acc:65.278
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 115/150 lr=0.00064 - loss:0.274, acc:74.070, val_loss:0.316, val_acc:63.819
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 116/150 lr=0.00064 - loss:0.270, acc:74.571, val_loss:0.315, val_acc:61.701
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 117/150 lr=0.00064 - loss:0.269, acc:75.305, val_loss:0.317, val_acc:62.674
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 118/150 lr=0.00064 - loss:0.268, acc:75.105, val_loss:0.310, val_acc:63.299
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 119/150 lr=0.00064 - loss:0.276, acc:73.757, val_loss:0.334, val_acc:59.167
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 120/150 lr=0.00064 - loss:0.273, acc:74.326, val_loss:0.327, val_acc:62.396
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 121/150 lr=0.00064 - loss:0.269, acc:74.822, val_loss:0.314, val_acc:62.569
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 122/150 lr=0.00055 - loss:0.264, acc:75.973, val_loss:0.308, val_acc:62.604
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 123/150 lr=0.00055 - loss:0.269, acc:74.749, val_loss:0.320, val_acc:62.604
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 124/150 lr=0.00055 - loss:0.267, acc:74.909, val_loss:0.319, val_acc:62.014
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 125/150 lr=0.00055 - loss:0.264, acc:75.891, val_loss:0.318, val_acc:64.340
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 126/150 lr=0.00055 - loss:0.262, acc:76.487, val_loss:0.318, val_acc:63.819
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 127/150 lr=0.00055 - loss:0.265, acc:75.470, val_loss:0.311, val_acc:63.611
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 128/150 lr=0.00055 - loss:0.260, acc:76.269, val_loss:0.313, val_acc:64.097
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 129/150 lr=0.00055 - loss:0.261, acc:76.201, val_loss:0.322, val_acc:61.910
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 130/150 lr=0.00055 - loss:0.262, acc:75.951, val_loss:0.318, val_acc:63.090
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 131/150 lr=0.00055 - loss:0.261, acc:75.873, val_loss:0.326, val_acc:61.875
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 132/150 lr=0.00055 - loss:0.263, acc:75.570, val_loss:0.319, val_acc:62.222
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 133/150 lr=0.00055 - loss:0.258, acc:76.750, val_loss:0.323, val_acc:63.090
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 134/150 lr=0.00055 - loss:0.262, acc:75.675, val_loss:0.316, val_acc:63.819
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 135/150 lr=0.00055 - loss:0.263, acc:75.548, val_loss:0.316, val_acc:62.604
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 136/150 lr=0.00055 - loss:0.253, acc:77.393, val_loss:0.311, val_acc:63.264
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 137/150 lr=0.00055 - loss:0.260, acc:76.307, val_loss:0.312, val_acc:63.646
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 138/150 lr=0.00055 - loss:0.254, acc:76.973, val_loss:0.320, val_acc:62.535
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 139/150 lr=0.00055 - loss:0.260, acc:76.011, val_loss:0.311, val_acc:64.514
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 140/150 lr=0.00055 - loss:0.257, acc:76.654, val_loss:0.324, val_acc:62.569
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 141/150 lr=0.00055 - loss:0.251, acc:77.300, val_loss:0.310, val_acc:63.299
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 142/150 lr=0.00047 - loss:0.249, acc:77.553, val_loss:0.318, val_acc:63.090
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 143/150 lr=0.00047 - loss:0.249, acc:77.803, val_loss:0.319, val_acc:62.917
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 144/150 lr=0.00047 - loss:0.245, acc:78.490, val_loss:0.314, val_acc:64.479
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 145/150 lr=0.00047 - loss:0.247, acc:78.335, val_loss:0.307, val_acc:64.514
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 146/150 lr=0.00047 - loss:0.247, acc:78.130, val_loss:0.317, val_acc:64.688
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 147/150 lr=0.00047 - loss:0.247, acc:77.854, val_loss:0.316, val_acc:63.090
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 148/150 lr=0.00047 - loss:0.247, acc:78.395, val_loss:0.310, val_acc:63.125
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 149/150 lr=0.00047 - loss:0.248, acc:78.187, val_loss:0.316, val_acc:64.479
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# 150/150 lr=0.00047 - loss:0.242, acc:78.973, val_loss:0.317, val_acc:62.361
# Best loss:0.307, Best accuracy:66.111, Best F1-score:0.658
# [*] Done - acc:66.111
# A Jupyter Widget
# 1/150 lr=0.00100 - loss:0.457, acc:42.760, val_loss:0.460, val_acc:41.975
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/150 lr=0.00100 - loss:0.433, acc:47.358, val_loss:0.433, val_acc:48.322
# Best loss:0.460, Best accuracy:41.975, Best F1-score:0.389
# 3/150 lr=0.00100 - loss:0.432, acc:46.345, val_loss:0.428, val_acc:47.010
# Best loss:0.433, Best accuracy:48.322, Best F1-score:0.466
# 4/150 lr=0.00100 - loss:0.421, acc:48.856, val_loss:0.420, val_acc:48.573
# Best loss:0.433, Best accuracy:48.322, Best F1-score:0.466
# 5/150 lr=0.00100 - loss:0.411, acc:51.315, val_loss:0.410, val_acc:51.003
# Best loss:0.420, Best accuracy:48.573, Best F1-score:0.478
# 6/150 lr=0.00100 - loss:0.407, acc:52.406, val_loss:0.404, val_acc:51.620
# Best loss:0.410, Best accuracy:51.003, Best F1-score:0.503
# 7/150 lr=0.00100 - loss:0.407, acc:51.482, val_loss:0.411, val_acc:50.039
# Best loss:0.404, Best accuracy:51.620, Best F1-score:0.515
# 8/150 lr=0.00100 - loss:0.402, acc:53.190, val_loss:0.403, val_acc:49.614
# Best loss:0.404, Best accuracy:51.620, Best F1-score:0.515
# 9/150 lr=0.00100 - loss:0.398, acc:54.607, val_loss:0.392, val_acc:54.051
# Best loss:0.404, Best accuracy:51.620, Best F1-score:0.515
# 10/150 lr=0.00100 - loss:0.393, acc:55.522, val_loss:0.387, val_acc:52.913
# Best loss:0.392, Best accuracy:54.051, Best F1-score:0.543
# 11/150 lr=0.00100 - loss:0.393, acc:54.823, val_loss:0.394, val_acc:53.530
# Best loss:0.392, Best accuracy:54.051, Best F1-score:0.543
# 12/150 lr=0.00100 - loss:0.393, acc:54.763, val_loss:0.394, val_acc:50.733
# Best loss:0.392, Best accuracy:54.051, Best F1-score:0.543
# 13/150 lr=0.00100 - loss:0.390, acc:55.662, val_loss:0.380, val_acc:56.829
# Best loss:0.392, Best accuracy:54.051, Best F1-score:0.543
# 14/150 lr=0.00100 - loss:0.387, acc:56.241, val_loss:0.385, val_acc:54.302
# Best loss:0.380, Best accuracy:56.829, Best F1-score:0.563
# 15/150 lr=0.00100 - loss:0.389, acc:55.124, val_loss:0.383, val_acc:52.739
# Best loss:0.380, Best accuracy:56.829, Best F1-score:0.563
# 16/150 lr=0.00100 - loss:0.380, acc:57.779, val_loss:0.384, val_acc:53.356
# Best loss:0.380, Best accuracy:56.829, Best F1-score:0.563
# 17/150 lr=0.00100 - loss:0.386, acc:56.172, val_loss:0.377, val_acc:55.883
# Best loss:0.380, Best accuracy:56.829, Best F1-score:0.563
# 18/150 lr=0.00100 - loss:0.383, acc:56.542, val_loss:0.372, val_acc:57.967
# Best loss:0.380, Best accuracy:56.829, Best F1-score:0.563
# 19/150 lr=0.00100 - loss:0.376, acc:58.120, val_loss:0.362, val_acc:59.529
# Best loss:0.372, Best accuracy:57.967, Best F1-score:0.582
# 20/150 lr=0.00100 - loss:0.377, acc:58.273, val_loss:0.366, val_acc:57.022
# Best loss:0.362, Best accuracy:59.529, Best F1-score:0.600
# 21/150 lr=0.00100 - loss:0.373, acc:58.745, val_loss:0.374, val_acc:56.134
# Best loss:0.362, Best accuracy:59.529, Best F1-score:0.600
# 22/150 lr=0.00100 - loss:0.377, acc:57.668, val_loss:0.368, val_acc:55.150
# Best loss:0.362, Best accuracy:59.529, Best F1-score:0.600
# 23/150 lr=0.00100 - loss:0.374, acc:58.609, val_loss:0.380, val_acc:54.475
# Best loss:0.362, Best accuracy:59.529, Best F1-score:0.600
# 24/150 lr=0.00100 - loss:0.378, acc:57.837, val_loss:0.387, val_acc:54.147
# Best loss:0.362, Best accuracy:59.529, Best F1-score:0.600
# 25/150 lr=0.00100 - loss:0.371, acc:58.709, val_loss:0.362, val_acc:58.565
# Best loss:0.362, Best accuracy:59.529, Best F1-score:0.600
# 26/150 lr=0.00100 - loss:0.366, acc:60.058, val_loss:0.378, val_acc:56.578
# Best loss:0.362, Best accuracy:59.529, Best F1-score:0.600
# 27/150 lr=0.00100 - loss:0.367, acc:58.870, val_loss:0.360, val_acc:56.829
# Best loss:0.362, Best accuracy:59.529, Best F1-score:0.600
# 28/150 lr=0.00100 - loss:0.370, acc:59.052, val_loss:0.357, val_acc:58.738
# Best loss:0.362, Best accuracy:59.529, Best F1-score:0.600
# 29/150 lr=0.00100 - loss:0.365, acc:59.126, val_loss:0.361, val_acc:58.391
# Best loss:0.362, Best accuracy:59.529, Best F1-score:0.600
# 30/150 lr=0.00100 - loss:0.361, acc:60.210, val_loss:0.353, val_acc:59.008
# Best loss:0.362, Best accuracy:59.529, Best F1-score:0.600
# 31/150 lr=0.00100 - loss:0.360, acc:60.835, val_loss:0.348, val_acc:60.475
# Best loss:0.362, Best accuracy:59.529, Best F1-score:0.600
# 32/150 lr=0.00100 - loss:0.357, acc:61.282, val_loss:0.340, val_acc:62.481
# Best loss:0.348, Best accuracy:60.475, Best F1-score:0.614
# 33/150 lr=0.00100 - loss:0.355, acc:62.275, val_loss:0.368, val_acc:56.308
# Best loss:0.340, Best accuracy:62.481, Best F1-score:0.626
# 34/150 lr=0.00100 - loss:0.363, acc:60.452, val_loss:0.359, val_acc:58.912
# Best loss:0.340, Best accuracy:62.481, Best F1-score:0.626
# 35/150 lr=0.00100 - loss:0.361, acc:60.853, val_loss:0.357, val_acc:58.025
# Best loss:0.340, Best accuracy:62.481, Best F1-score:0.626
# 36/150 lr=0.00100 - loss:0.356, acc:62.531, val_loss:0.349, val_acc:60.995
# Best loss:0.340, Best accuracy:62.481, Best F1-score:0.626
# 37/150 lr=0.00100 - loss:0.351, acc:62.295, val_loss:0.341, val_acc:62.731
# Best loss:0.340, Best accuracy:62.481, Best F1-score:0.626
# 38/150 lr=0.00100 - loss:0.355, acc:61.852, val_loss:0.345, val_acc:61.420
# Best loss:0.341, Best accuracy:62.731, Best F1-score:0.631
# 39/150 lr=0.00100 - loss:0.357, acc:61.418, val_loss:0.356, val_acc:59.684
# Best loss:0.341, Best accuracy:62.731, Best F1-score:0.631
# 40/150 lr=0.00100 - loss:0.359, acc:60.893, val_loss:0.352, val_acc:58.025
# Best loss:0.341, Best accuracy:62.731, Best F1-score:0.631
# 41/150 lr=0.00100 - loss:0.348, acc:62.253, val_loss:0.345, val_acc:60.301
# Best loss:0.341, Best accuracy:62.731, Best F1-score:0.631
# 42/150 lr=0.00100 - loss:0.345, acc:62.731, val_loss:0.340, val_acc:62.384
# Best loss:0.341, Best accuracy:62.731, Best F1-score:0.631
# 43/150 lr=0.00100 - loss:0.347, acc:62.816, val_loss:0.354, val_acc:58.546
# Best loss:0.341, Best accuracy:62.731, Best F1-score:0.631
# 44/150 lr=0.00100 - loss:0.347, acc:62.271, val_loss:0.343, val_acc:59.491
# Best loss:0.341, Best accuracy:62.731, Best F1-score:0.631
# 45/150 lr=0.00100 - loss:0.341, acc:63.651, val_loss:0.357, val_acc:58.218
# Best loss:0.341, Best accuracy:62.731, Best F1-score:0.631
# 46/150 lr=0.00100 - loss:0.350, acc:62.137, val_loss:0.344, val_acc:61.343
# Best loss:0.341, Best accuracy:62.731, Best F1-score:0.631
# 47/150 lr=0.00100 - loss:0.342, acc:63.588, val_loss:0.349, val_acc:60.475
# Best loss:0.341, Best accuracy:62.731, Best F1-score:0.631
# 48/150 lr=0.00100 - loss:0.341, acc:64.109, val_loss:0.330, val_acc:63.156
# Best loss:0.341, Best accuracy:62.731, Best F1-score:0.631
# 49/150 lr=0.00100 - loss:0.341, acc:63.904, val_loss:0.329, val_acc:63.349
# Best loss:0.330, Best accuracy:63.156, Best F1-score:0.637
# 50/150 lr=0.00100 - loss:0.334, acc:64.902, val_loss:0.336, val_acc:61.593
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 51/150 lr=0.00100 - loss:0.337, acc:64.174, val_loss:0.345, val_acc:61.786
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 52/150 lr=0.00100 - loss:0.342, acc:63.956, val_loss:0.336, val_acc:62.307
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 53/150 lr=0.00100 - loss:0.341, acc:63.261, val_loss:0.340, val_acc:60.224
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 54/150 lr=0.00100 - loss:0.339, acc:64.069, val_loss:0.352, val_acc:59.606
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 55/150 lr=0.00100 - loss:0.336, acc:64.579, val_loss:0.334, val_acc:60.995
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 56/150 lr=0.00100 - loss:0.332, acc:65.086, val_loss:0.335, val_acc:60.899
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 57/150 lr=0.00100 - loss:0.334, acc:65.803, val_loss:0.334, val_acc:59.684
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 58/150 lr=0.00100 - loss:0.333, acc:65.411, val_loss:0.337, val_acc:61.092
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 59/150 lr=0.00100 - loss:0.329, acc:65.543, val_loss:0.341, val_acc:60.301
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 60/150 lr=0.00100 - loss:0.332, acc:65.558, val_loss:0.329, val_acc:59.240
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 61/150 lr=0.00100 - loss:0.329, acc:66.037, val_loss:0.345, val_acc:59.587
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 62/150 lr=0.00086 - loss:0.328, acc:65.841, val_loss:0.335, val_acc:59.684
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 63/150 lr=0.00086 - loss:0.326, acc:66.373, val_loss:0.327, val_acc:62.114
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 64/150 lr=0.00086 - loss:0.325, acc:66.157, val_loss:0.334, val_acc:62.654
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 65/150 lr=0.00086 - loss:0.321, acc:67.679, val_loss:0.326, val_acc:63.002
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 66/150 lr=0.00086 - loss:0.323, acc:67.374, val_loss:0.333, val_acc:60.629
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 67/150 lr=0.00086 - loss:0.321, acc:67.297, val_loss:0.332, val_acc:60.899
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 68/150 lr=0.00086 - loss:0.322, acc:66.896, val_loss:0.322, val_acc:61.420
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 69/150 lr=0.00086 - loss:0.317, acc:68.076, val_loss:0.334, val_acc:60.822
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 70/150 lr=0.00086 - loss:0.314, acc:68.797, val_loss:0.331, val_acc:61.420
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 71/150 lr=0.00086 - loss:0.316, acc:68.189, val_loss:0.328, val_acc:61.863
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 72/150 lr=0.00086 - loss:0.320, acc:67.935, val_loss:0.332, val_acc:61.150
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 73/150 lr=0.00086 - loss:0.322, acc:67.065, val_loss:0.329, val_acc:60.455
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 74/150 lr=0.00086 - loss:0.318, acc:67.183, val_loss:0.331, val_acc:62.211
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 75/150 lr=0.00086 - loss:0.314, acc:68.757, val_loss:0.341, val_acc:59.240
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 76/150 lr=0.00086 - loss:0.314, acc:68.316, val_loss:0.336, val_acc:61.420
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 77/150 lr=0.00086 - loss:0.320, acc:67.439, val_loss:0.314, val_acc:62.114
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 78/150 lr=0.00086 - loss:0.311, acc:69.010, val_loss:0.321, val_acc:63.329
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 79/150 lr=0.00086 - loss:0.310, acc:68.151, val_loss:0.353, val_acc:60.918
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 80/150 lr=0.00086 - loss:0.307, acc:69.522, val_loss:0.320, val_acc:63.329
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 81/150 lr=0.00086 - loss:0.315, acc:68.612, val_loss:0.327, val_acc:61.420
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 82/150 lr=0.00074 - loss:0.312, acc:68.516, val_loss:0.338, val_acc:59.857
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 83/150 lr=0.00074 - loss:0.308, acc:68.872, val_loss:0.335, val_acc:59.857
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 84/150 lr=0.00074 - loss:0.301, acc:70.264, val_loss:0.320, val_acc:62.731
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 85/150 lr=0.00074 - loss:0.304, acc:69.749, val_loss:0.330, val_acc:62.037
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 86/150 lr=0.00074 - loss:0.303, acc:69.453, val_loss:0.325, val_acc:62.635
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 87/150 lr=0.00074 - loss:0.301, acc:70.455, val_loss:0.325, val_acc:63.870
# Best loss:0.329, Best accuracy:63.349, Best F1-score:0.634
# 88/150 lr=0.00074 - loss:0.302, acc:70.335, val_loss:0.327, val_acc:63.079
# Best loss:0.325, Best accuracy:63.870, Best F1-score:0.638
# 89/150 lr=0.00074 - loss:0.302, acc:70.170, val_loss:0.325, val_acc:61.420
# Best loss:0.325, Best accuracy:63.870, Best F1-score:0.638
# 90/150 lr=0.00074 - loss:0.300, acc:70.804, val_loss:0.316, val_acc:65.162
# Best loss:0.325, Best accuracy:63.870, Best F1-score:0.638
# 91/150 lr=0.00074 - loss:0.297, acc:70.713, val_loss:0.323, val_acc:61.593
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 92/150 lr=0.00074 - loss:0.302, acc:70.168, val_loss:0.326, val_acc:59.857
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 93/150 lr=0.00074 - loss:0.305, acc:68.877, val_loss:0.317, val_acc:62.809
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 94/150 lr=0.00074 - loss:0.304, acc:69.433, val_loss:0.316, val_acc:62.809
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 95/150 lr=0.00074 - loss:0.300, acc:69.923, val_loss:0.319, val_acc:62.809
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 96/150 lr=0.00074 - loss:0.298, acc:71.049, val_loss:0.328, val_acc:61.246
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 97/150 lr=0.00074 - loss:0.293, acc:71.031, val_loss:0.325, val_acc:62.114
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 98/150 lr=0.00074 - loss:0.290, acc:71.775, val_loss:0.320, val_acc:62.114
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 99/150 lr=0.00074 - loss:0.300, acc:70.464, val_loss:0.316, val_acc:61.073
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 100/150 lr=0.00074 - loss:0.294, acc:71.833, val_loss:0.329, val_acc:62.114
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 101/150 lr=0.00074 - loss:0.295, acc:70.493, val_loss:0.319, val_acc:62.114
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 102/150 lr=0.00064 - loss:0.296, acc:70.626, val_loss:0.335, val_acc:60.725
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 103/150 lr=0.00064 - loss:0.290, acc:71.330, val_loss:0.323, val_acc:61.941
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 104/150 lr=0.00064 - loss:0.289, acc:71.882, val_loss:0.313, val_acc:63.947
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 105/150 lr=0.00064 - loss:0.286, acc:72.683, val_loss:0.320, val_acc:63.677
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 106/150 lr=0.00064 - loss:0.291, acc:72.009, val_loss:0.326, val_acc:60.725
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 107/150 lr=0.00064 - loss:0.284, acc:72.983, val_loss:0.319, val_acc:62.288
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 108/150 lr=0.00064 - loss:0.281, acc:73.952, val_loss:0.328, val_acc:60.899
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 109/150 lr=0.00064 - loss:0.286, acc:72.574, val_loss:0.331, val_acc:61.420
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 110/150 lr=0.00064 - loss:0.288, acc:72.443, val_loss:0.332, val_acc:62.037
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 111/150 lr=0.00064 - loss:0.290, acc:72.273, val_loss:0.341, val_acc:62.114
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 112/150 lr=0.00064 - loss:0.284, acc:72.959, val_loss:0.324, val_acc:63.522
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 113/150 lr=0.00064 - loss:0.280, acc:73.360, val_loss:0.330, val_acc:61.941
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 114/150 lr=0.00064 - loss:0.287, acc:72.278, val_loss:0.331, val_acc:63.002
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 115/150 lr=0.00064 - loss:0.281, acc:73.462, val_loss:0.317, val_acc:63.677
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 116/150 lr=0.00064 - loss:0.285, acc:72.719, val_loss:0.351, val_acc:62.481
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 117/150 lr=0.00064 - loss:0.282, acc:73.308, val_loss:0.333, val_acc:60.378
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 118/150 lr=0.00064 - loss:0.279, acc:73.976, val_loss:0.343, val_acc:58.893
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 119/150 lr=0.00064 - loss:0.277, acc:74.101, val_loss:0.330, val_acc:63.002
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 120/150 lr=0.00064 - loss:0.282, acc:73.380, val_loss:0.328, val_acc:61.420
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 121/150 lr=0.00064 - loss:0.285, acc:72.650, val_loss:0.325, val_acc:62.461
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 122/150 lr=0.00055 - loss:0.277, acc:73.745, val_loss:0.325, val_acc:61.420
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 123/150 lr=0.00055 - loss:0.278, acc:73.914, val_loss:0.337, val_acc:62.384
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 124/150 lr=0.00055 - loss:0.272, acc:74.726, val_loss:0.323, val_acc:62.288
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 125/150 lr=0.00055 - loss:0.270, acc:75.452, val_loss:0.336, val_acc:61.690
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 126/150 lr=0.00055 - loss:0.269, acc:74.898, val_loss:0.333, val_acc:62.211
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 127/150 lr=0.00055 - loss:0.269, acc:75.127, val_loss:0.329, val_acc:62.558
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 128/150 lr=0.00055 - loss:0.267, acc:75.884, val_loss:0.334, val_acc:60.552
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 129/150 lr=0.00055 - loss:0.271, acc:75.387, val_loss:0.324, val_acc:64.043
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 130/150 lr=0.00055 - loss:0.270, acc:75.069, val_loss:0.317, val_acc:63.156
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 131/150 lr=0.00055 - loss:0.269, acc:75.194, val_loss:0.333, val_acc:61.246
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 132/150 lr=0.00055 - loss:0.269, acc:75.329, val_loss:0.347, val_acc:60.725
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 133/150 lr=0.00055 - loss:0.275, acc:73.811, val_loss:0.325, val_acc:63.426
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 134/150 lr=0.00055 - loss:0.265, acc:75.659, val_loss:0.323, val_acc:63.947
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 135/150 lr=0.00055 - loss:0.263, acc:76.460, val_loss:0.321, val_acc:64.815
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 136/150 lr=0.00055 - loss:0.266, acc:75.209, val_loss:0.314, val_acc:65.336
# Best loss:0.316, Best accuracy:65.162, Best F1-score:0.658
# 137/150 lr=0.00055 - loss:0.261, acc:76.075, val_loss:0.345, val_acc:59.857
# Best loss:0.314, Best accuracy:65.336, Best F1-score:0.659
# 138/150 lr=0.00055 - loss:0.265, acc:75.093, val_loss:0.330, val_acc:62.905
# Best loss:0.314, Best accuracy:65.336, Best F1-score:0.659
# 139/150 lr=0.00055 - loss:0.262, acc:76.580, val_loss:0.325, val_acc:62.905
# Best loss:0.314, Best accuracy:65.336, Best F1-score:0.659
# 140/150 lr=0.00055 - loss:0.261, acc:75.643, val_loss:0.329, val_acc:63.503
# Best loss:0.314, Best accuracy:65.336, Best F1-score:0.659
# 141/150 lr=0.00055 - loss:0.263, acc:76.309, val_loss:0.335, val_acc:63.156
# Best loss:0.314, Best accuracy:65.336, Best F1-score:0.659
# 142/150 lr=0.00047 - loss:0.260, acc:76.611, val_loss:0.319, val_acc:63.850
# Best loss:0.314, Best accuracy:65.336, Best F1-score:0.659
# 143/150 lr=0.00047 - loss:0.257, acc:76.896, val_loss:0.333, val_acc:61.593
# Best loss:0.314, Best accuracy:65.336, Best F1-score:0.659
# 144/150 lr=0.00047 - loss:0.257, acc:76.676, val_loss:0.330, val_acc:63.850
# Best loss:0.314, Best accuracy:65.336, Best F1-score:0.659
# 145/150 lr=0.00047 - loss:0.259, acc:76.870, val_loss:0.330, val_acc:63.870
# Best loss:0.314, Best accuracy:65.336, Best F1-score:0.659
# 146/150 lr=0.00047 - loss:0.255, acc:77.032, val_loss:0.327, val_acc:63.600
# Best loss:0.314, Best accuracy:65.336, Best F1-score:0.659
# 147/150 lr=0.00047 - loss:0.259, acc:76.805, val_loss:0.322, val_acc:64.120
# Best loss:0.314, Best accuracy:65.336, Best F1-score:0.659
# 148/150 lr=0.00047 - loss:0.260, acc:76.100, val_loss:0.348, val_acc:60.475
# Best loss:0.314, Best accuracy:65.336, Best F1-score:0.659
# 149/150 lr=0.00047 - loss:0.257, acc:77.099, val_loss:0.340, val_acc:61.941
# Best loss:0.314, Best accuracy:65.336, Best F1-score:0.659
# 150/150 lr=0.00047 - loss:0.256, acc:76.956, val_loss:0.327, val_acc:63.426
# Best loss:0.314, Best accuracy:65.336, Best F1-score:0.659
# [*] Done - acc:65.336
# A Jupyter Widget
# 1/150 lr=0.00100 - loss:0.471, acc:39.267, val_loss:0.459, val_acc:43.634
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/150 lr=0.00100 - loss:0.442, acc:44.932, val_loss:0.414, val_acc:49.518
# Best loss:0.459, Best accuracy:43.634, Best F1-score:0.395
# 3/150 lr=0.00100 - loss:0.429, acc:47.685, val_loss:0.403, val_acc:52.392
# Best loss:0.414, Best accuracy:49.518, Best F1-score:0.475
# 4/150 lr=0.00100 - loss:0.422, acc:48.954, val_loss:0.399, val_acc:51.698
# Best loss:0.403, Best accuracy:52.392, Best F1-score:0.520
# 5/150 lr=0.00100 - loss:0.413, acc:50.859, val_loss:0.396, val_acc:52.566
# Best loss:0.403, Best accuracy:52.392, Best F1-score:0.520
# 6/150 lr=0.00100 - loss:0.411, acc:50.944, val_loss:0.386, val_acc:54.032
# Best loss:0.396, Best accuracy:52.566, Best F1-score:0.519
# 7/150 lr=0.00100 - loss:0.400, acc:53.421, val_loss:0.390, val_acc:54.823
# Best loss:0.386, Best accuracy:54.032, Best F1-score:0.530
# 8/150 lr=0.00100 - loss:0.399, acc:53.470, val_loss:0.390, val_acc:53.762
# Best loss:0.390, Best accuracy:54.823, Best F1-score:0.545
# 9/150 lr=0.00100 - loss:0.398, acc:53.457, val_loss:0.379, val_acc:54.032
# Best loss:0.390, Best accuracy:54.823, Best F1-score:0.545
# 10/150 lr=0.00100 - loss:0.393, acc:54.979, val_loss:0.379, val_acc:54.726
# Best loss:0.390, Best accuracy:54.823, Best F1-score:0.545
# 11/150 lr=0.00100 - loss:0.392, acc:54.667, val_loss:0.374, val_acc:56.559
# Best loss:0.390, Best accuracy:54.823, Best F1-score:0.545
# 12/150 lr=0.00100 - loss:0.388, acc:56.152, val_loss:0.366, val_acc:57.079
# Best loss:0.374, Best accuracy:56.559, Best F1-score:0.553
# 13/150 lr=0.00100 - loss:0.385, acc:56.502, val_loss:0.362, val_acc:58.989
# Best loss:0.366, Best accuracy:57.079, Best F1-score:0.564
# 14/150 lr=0.00100 - loss:0.384, acc:56.479, val_loss:0.365, val_acc:58.816
# Best loss:0.362, Best accuracy:58.989, Best F1-score:0.581
# 15/150 lr=0.00100 - loss:0.383, acc:56.862, val_loss:0.372, val_acc:55.864
# Best loss:0.362, Best accuracy:58.989, Best F1-score:0.581
# 16/150 lr=0.00100 - loss:0.389, acc:54.567, val_loss:0.364, val_acc:58.372
# Best loss:0.362, Best accuracy:58.989, Best F1-score:0.581
# 17/150 lr=0.00100 - loss:0.378, acc:58.536, val_loss:0.366, val_acc:56.559
# Best loss:0.362, Best accuracy:58.989, Best F1-score:0.581
# 18/150 lr=0.00100 - loss:0.382, acc:56.802, val_loss:0.365, val_acc:59.780
# Best loss:0.362, Best accuracy:58.989, Best F1-score:0.581
# 19/150 lr=0.00100 - loss:0.378, acc:58.064, val_loss:0.360, val_acc:58.738
# Best loss:0.365, Best accuracy:59.780, Best F1-score:0.599
# 20/150 lr=0.00100 - loss:0.375, acc:58.253, val_loss:0.386, val_acc:53.935
# Best loss:0.365, Best accuracy:59.780, Best F1-score:0.599
# 21/150 lr=0.00100 - loss:0.383, acc:56.749, val_loss:0.367, val_acc:57.427
# Best loss:0.365, Best accuracy:59.780, Best F1-score:0.599
# 22/150 lr=0.00100 - loss:0.375, acc:58.531, val_loss:0.392, val_acc:52.643
# Best loss:0.365, Best accuracy:59.780, Best F1-score:0.599
# 23/150 lr=0.00100 - loss:0.380, acc:56.537, val_loss:0.362, val_acc:56.481
# Best loss:0.365, Best accuracy:59.780, Best F1-score:0.599
# 24/150 lr=0.00100 - loss:0.372, acc:58.333, val_loss:0.375, val_acc:56.211
# Best loss:0.365, Best accuracy:59.780, Best F1-score:0.599
# 25/150 lr=0.00100 - loss:0.368, acc:59.451, val_loss:0.361, val_acc:58.912
# Best loss:0.365, Best accuracy:59.780, Best F1-score:0.599
# 26/150 lr=0.00100 - loss:0.368, acc:59.322, val_loss:0.359, val_acc:60.224
# Best loss:0.365, Best accuracy:59.780, Best F1-score:0.599
# 27/150 lr=0.00100 - loss:0.366, acc:59.662, val_loss:0.356, val_acc:59.163
# Best loss:0.359, Best accuracy:60.224, Best F1-score:0.599
# 28/150 lr=0.00100 - loss:0.363, acc:60.619, val_loss:0.356, val_acc:58.391
# Best loss:0.359, Best accuracy:60.224, Best F1-score:0.599
# 29/150 lr=0.00100 - loss:0.364, acc:60.112, val_loss:0.346, val_acc:60.571
# Best loss:0.359, Best accuracy:60.224, Best F1-score:0.599
# 30/150 lr=0.00100 - loss:0.360, acc:60.710, val_loss:0.367, val_acc:57.523
# Best loss:0.346, Best accuracy:60.571, Best F1-score:0.603
# 31/150 lr=0.00100 - loss:0.367, acc:59.511, val_loss:0.350, val_acc:59.606
# Best loss:0.346, Best accuracy:60.571, Best F1-score:0.603
# 32/150 lr=0.00100 - loss:0.366, acc:59.682, val_loss:0.349, val_acc:58.488
# Best loss:0.346, Best accuracy:60.571, Best F1-score:0.603
# 33/150 lr=0.00100 - loss:0.357, acc:60.915, val_loss:0.354, val_acc:60.050
# Best loss:0.346, Best accuracy:60.571, Best F1-score:0.603
# 34/150 lr=0.00100 - loss:0.359, acc:60.508, val_loss:0.356, val_acc:59.780
# Best loss:0.346, Best accuracy:60.571, Best F1-score:0.603
# 35/150 lr=0.00100 - loss:0.354, acc:62.035, val_loss:0.345, val_acc:60.745
# Best loss:0.346, Best accuracy:60.571, Best F1-score:0.603
# 36/150 lr=0.00100 - loss:0.354, acc:61.574, val_loss:0.358, val_acc:60.050
# Best loss:0.345, Best accuracy:60.745, Best F1-score:0.605
# 37/150 lr=0.00100 - loss:0.352, acc:61.730, val_loss:0.349, val_acc:60.995
# Best loss:0.345, Best accuracy:60.745, Best F1-score:0.605
# 38/150 lr=0.00100 - loss:0.353, acc:61.668, val_loss:0.350, val_acc:59.780
# Best loss:0.349, Best accuracy:60.995, Best F1-score:0.611
# 39/150 lr=0.00100 - loss:0.346, acc:62.747, val_loss:0.341, val_acc:61.265
# Best loss:0.349, Best accuracy:60.995, Best F1-score:0.611
# 40/150 lr=0.00100 - loss:0.348, acc:63.221, val_loss:0.345, val_acc:60.301
# Best loss:0.341, Best accuracy:61.265, Best F1-score:0.610
# 41/150 lr=0.00100 - loss:0.341, acc:64.414, val_loss:0.358, val_acc:58.391
# Best loss:0.341, Best accuracy:61.265, Best F1-score:0.610
# 42/150 lr=0.00100 - loss:0.341, acc:64.305, val_loss:0.342, val_acc:59.433
# Best loss:0.341, Best accuracy:61.265, Best F1-score:0.610
# 43/150 lr=0.00100 - loss:0.349, acc:63.433, val_loss:0.363, val_acc:57.079
# Best loss:0.341, Best accuracy:61.265, Best F1-score:0.610
# 44/150 lr=0.00100 - loss:0.341, acc:64.134, val_loss:0.359, val_acc:57.870
# Best loss:0.341, Best accuracy:61.265, Best F1-score:0.610
# 45/150 lr=0.00100 - loss:0.344, acc:64.022, val_loss:0.343, val_acc:62.307
# Best loss:0.341, Best accuracy:61.265, Best F1-score:0.610
# 46/150 lr=0.00100 - loss:0.345, acc:63.237, val_loss:0.362, val_acc:57.350
# Best loss:0.343, Best accuracy:62.307, Best F1-score:0.618
# 47/150 lr=0.00100 - loss:0.346, acc:62.959, val_loss:0.356, val_acc:58.121
# Best loss:0.343, Best accuracy:62.307, Best F1-score:0.618
# 48/150 lr=0.00100 - loss:0.346, acc:63.007, val_loss:0.334, val_acc:62.384
# Best loss:0.343, Best accuracy:62.307, Best F1-score:0.618
# 49/150 lr=0.00100 - loss:0.337, acc:64.610, val_loss:0.356, val_acc:59.086
# Best loss:0.334, Best accuracy:62.384, Best F1-score:0.621
# 50/150 lr=0.00100 - loss:0.343, acc:63.649, val_loss:0.332, val_acc:61.343
# Best loss:0.334, Best accuracy:62.384, Best F1-score:0.621
# 51/150 lr=0.00100 - loss:0.341, acc:63.693, val_loss:0.336, val_acc:61.613
# Best loss:0.334, Best accuracy:62.384, Best F1-score:0.621
# 52/150 lr=0.00100 - loss:0.337, acc:64.445, val_loss:0.340, val_acc:61.265
# Best loss:0.334, Best accuracy:62.384, Best F1-score:0.621
# 53/150 lr=0.00100 - loss:0.335, acc:64.490, val_loss:0.345, val_acc:60.301
# Best loss:0.334, Best accuracy:62.384, Best F1-score:0.621
# 54/150 lr=0.00100 - loss:0.334, acc:64.939, val_loss:0.339, val_acc:61.613
# Best loss:0.334, Best accuracy:62.384, Best F1-score:0.621
# 55/150 lr=0.00100 - loss:0.337, acc:63.938, val_loss:0.334, val_acc:61.169
# Best loss:0.334, Best accuracy:62.384, Best F1-score:0.621
# 56/150 lr=0.00100 - loss:0.334, acc:64.855, val_loss:0.343, val_acc:61.613
# Best loss:0.334, Best accuracy:62.384, Best F1-score:0.621
# 57/150 lr=0.00100 - loss:0.333, acc:65.135, val_loss:0.335, val_acc:61.613
# ...
# Best loss:0.330, Best accuracy:63.542, Best F1-score:0.634
# 33/150 lr=0.00100 - loss:0.364, acc:60.016, val_loss:0.332, val_acc:61.806
# Best loss:0.330, Best accuracy:63.542, Best F1-score:0.634
# 34/150 lr=0.00100 - loss:0.365, acc:59.831, val_loss:0.346, val_acc:58.218
# Best loss:0.330, Best accuracy:63.542, Best F1-score:0.634
# 35/150 lr=0.00100 - loss:0.363, acc:60.136, val_loss:0.339, val_acc:58.931
# Best loss:0.330, Best accuracy:63.542, Best F1-score:0.634
# 36/150 lr=0.00100 - loss:0.364, acc:60.081, val_loss:0.331, val_acc:60.494
# Best loss:0.330, Best accuracy:63.542, Best F1-score:0.634
# 37/150 lr=0.00100 - loss:0.361, acc:60.497, val_loss:0.328, val_acc:61.362
# Best loss:0.330, Best accuracy:63.542, Best F1-score:0.634
# 38/150 lr=0.00100 - loss:0.360, acc:60.889, val_loss:0.333, val_acc:61.015
# Best loss:0.330, Best accuracy:63.542, Best F1-score:0.634
# 39/150 lr=0.00100 - loss:0.356, acc:61.436, val_loss:0.342, val_acc:60.243
# Best loss:0.330, Best accuracy:63.542, Best F1-score:0.634
# 40/150 lr=0.00100 - loss:0.357, acc:60.822, val_loss:0.319, val_acc:62.924
# Best loss:0.330, Best accuracy:63.542, Best F1-score:0.634
# 41/150 lr=0.00100 - loss:0.355, acc:61.930, val_loss:0.323, val_acc:63.619
# Best loss:0.330, Best accuracy:63.542, Best F1-score:0.634
# 42/150 lr=0.00100 - loss:0.348, acc:62.447, val_loss:0.326, val_acc:61.883
# Best loss:0.323, Best accuracy:63.619, Best F1-score:0.640
# 43/150 lr=0.00100 - loss:0.348, acc:62.607, val_loss:0.328, val_acc:61.806
# Best loss:0.323, Best accuracy:63.619, Best F1-score:0.640
# 44/150 lr=0.00100 - loss:0.350, acc:62.656, val_loss:0.317, val_acc:64.660
# Best loss:0.323, Best accuracy:63.619, Best F1-score:0.640
# 45/150 lr=0.00100 - loss:0.349, acc:62.816, val_loss:0.322, val_acc:63.715
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 46/150 lr=0.00100 - loss:0.350, acc:62.346, val_loss:0.319, val_acc:62.577
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 47/150 lr=0.00100 - loss:0.348, acc:62.035, val_loss:0.325, val_acc:61.015
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 48/150 lr=0.00100 - loss:0.346, acc:63.039, val_loss:0.318, val_acc:63.889
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 49/150 lr=0.00100 - loss:0.346, acc:63.268, val_loss:0.319, val_acc:61.883
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 50/150 lr=0.00100 - loss:0.343, acc:63.357, val_loss:0.321, val_acc:63.445
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 51/150 lr=0.00100 - loss:0.343, acc:63.048, val_loss:0.317, val_acc:62.924
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 52/150 lr=0.00100 - loss:0.346, acc:62.415, val_loss:0.333, val_acc:60.667
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 53/150 lr=0.00100 - loss:0.342, acc:62.852, val_loss:0.331, val_acc:58.931
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 54/150 lr=0.00100 - loss:0.338, acc:64.116, val_loss:0.317, val_acc:63.715
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 55/150 lr=0.00100 - loss:0.337, acc:64.227, val_loss:0.311, val_acc:64.313
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 56/150 lr=0.00100 - loss:0.331, acc:64.953, val_loss:0.317, val_acc:63.619
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 57/150 lr=0.00100 - loss:0.334, acc:64.786, val_loss:0.334, val_acc:60.147
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 58/150 lr=0.00100 - loss:0.331, acc:65.999, val_loss:0.318, val_acc:63.002
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 59/150 lr=0.00100 - loss:0.331, acc:65.496, val_loss:0.307, val_acc:63.792
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 60/150 lr=0.00100 - loss:0.333, acc:64.842, val_loss:0.309, val_acc:63.792
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 61/150 lr=0.00100 - loss:0.331, acc:65.507, val_loss:0.309, val_acc:64.217
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 62/150 lr=0.00086 - loss:0.327, acc:65.641, val_loss:0.308, val_acc:63.619
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 63/150 lr=0.00086 - loss:0.325, acc:66.718, val_loss:0.307, val_acc:65.625
# Best loss:0.317, Best accuracy:64.660, Best F1-score:0.644
# 64/150 lr=0.00086 - loss:0.325, acc:66.112, val_loss:0.303, val_acc:64.583
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 65/150 lr=0.00086 - loss:0.324, acc:66.765, val_loss:0.314, val_acc:62.924
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 66/150 lr=0.00086 - loss:0.325, acc:66.132, val_loss:0.314, val_acc:64.410
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 67/150 lr=0.00086 - loss:0.322, acc:66.533, val_loss:0.309, val_acc:63.445
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 68/150 lr=0.00086 - loss:0.327, acc:65.841, val_loss:0.327, val_acc:62.133
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 69/150 lr=0.00086 - loss:0.316, acc:67.802, val_loss:0.309, val_acc:64.236
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 70/150 lr=0.00086 - loss:0.315, acc:67.686, val_loss:0.306, val_acc:63.272
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 71/150 lr=0.00086 - loss:0.317, acc:67.555, val_loss:0.310, val_acc:62.924
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 72/150 lr=0.00086 - loss:0.313, acc:68.187, val_loss:0.305, val_acc:65.278
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 73/150 lr=0.00086 - loss:0.311, acc:68.109, val_loss:0.312, val_acc:63.194
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 74/150 lr=0.00086 - loss:0.319, acc:67.288, val_loss:0.306, val_acc:63.966
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 75/150 lr=0.00086 - loss:0.319, acc:67.388, val_loss:0.321, val_acc:61.265
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 76/150 lr=0.00086 - loss:0.314, acc:67.635, val_loss:0.302, val_acc:65.278
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 77/150 lr=0.00086 - loss:0.313, acc:68.360, val_loss:0.305, val_acc:64.236
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 78/150 lr=0.00086 - loss:0.307, acc:68.953, val_loss:0.306, val_acc:64.757
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 79/150 lr=0.00086 - loss:0.304, acc:70.034, val_loss:0.318, val_acc:61.786
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 80/150 lr=0.00086 - loss:0.307, acc:69.082, val_loss:0.311, val_acc:66.319
# Best loss:0.307, Best accuracy:65.625, Best F1-score:0.657
# 81/150 lr=0.00086 - loss:0.311, acc:67.964, val_loss:0.315, val_acc:60.918
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 82/150 lr=0.00074 - loss:0.302, acc:69.814, val_loss:0.305, val_acc:65.181
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 83/150 lr=0.00074 - loss:0.302, acc:70.239, val_loss:0.307, val_acc:64.062
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 84/150 lr=0.00074 - loss:0.298, acc:70.706, val_loss:0.305, val_acc:65.104
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 85/150 lr=0.00074 - loss:0.301, acc:70.223, val_loss:0.309, val_acc:64.410
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 86/150 lr=0.00074 - loss:0.303, acc:69.778, val_loss:0.323, val_acc:60.841
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 87/150 lr=0.00074 - loss:0.310, acc:68.452, val_loss:0.316, val_acc:63.715
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 88/150 lr=0.00074 - loss:0.301, acc:70.074, val_loss:0.303, val_acc:65.278
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 89/150 lr=0.00074 - loss:0.298, acc:70.375, val_loss:0.306, val_acc:63.792
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 90/150 lr=0.00074 - loss:0.296, acc:71.539, val_loss:0.298, val_acc:66.319
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 91/150 lr=0.00074 - loss:0.294, acc:71.236, val_loss:0.310, val_acc:65.451
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 92/150 lr=0.00074 - loss:0.296, acc:70.439, val_loss:0.305, val_acc:66.146
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 93/150 lr=0.00074 - loss:0.297, acc:70.495, val_loss:0.297, val_acc:65.702
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 94/150 lr=0.00074 - loss:0.298, acc:70.359, val_loss:0.303, val_acc:65.104
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 95/150 lr=0.00074 - loss:0.293, acc:70.591, val_loss:0.299, val_acc:66.146
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 96/150 lr=0.00074 - loss:0.293, acc:71.666, val_loss:0.301, val_acc:65.972
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 97/150 lr=0.00074 - loss:0.293, acc:70.644, val_loss:0.302, val_acc:64.236
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 98/150 lr=0.00074 - loss:0.285, acc:72.774, val_loss:0.305, val_acc:64.834
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 99/150 lr=0.00074 - loss:0.293, acc:71.107, val_loss:0.307, val_acc:64.931
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 100/150 lr=0.00074 - loss:0.290, acc:71.968, val_loss:0.309, val_acc:65.355
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 101/150 lr=0.00074 - loss:0.293, acc:71.586, val_loss:0.302, val_acc:65.008
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 102/150 lr=0.00064 - loss:0.287, acc:72.594, val_loss:0.305, val_acc:64.583
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 103/150 lr=0.00064 - loss:0.283, acc:72.701, val_loss:0.307, val_acc:65.278
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 104/150 lr=0.00064 - loss:0.282, acc:73.244, val_loss:0.303, val_acc:65.625
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 105/150 lr=0.00064 - loss:0.282, acc:72.819, val_loss:0.306, val_acc:63.175
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 106/150 lr=0.00064 - loss:0.279, acc:73.440, val_loss:0.310, val_acc:63.272
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 107/150 lr=0.00064 - loss:0.283, acc:72.952, val_loss:0.305, val_acc:64.757
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 108/150 lr=0.00064 - loss:0.281, acc:72.814, val_loss:0.306, val_acc:64.583
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 109/150 lr=0.00064 - loss:0.284, acc:72.398, val_loss:0.312, val_acc:62.481
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 110/150 lr=0.00064 - loss:0.278, acc:73.656, val_loss:0.297, val_acc:66.319
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 111/150 lr=0.00064 - loss:0.279, acc:73.070, val_loss:0.300, val_acc:64.236
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 112/150 lr=0.00064 - loss:0.277, acc:73.571, val_loss:0.302, val_acc:66.146
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 113/150 lr=0.00064 - loss:0.279, acc:72.888, val_loss:0.311, val_acc:63.966
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 114/150 lr=0.00064 - loss:0.275, acc:73.820, val_loss:0.300, val_acc:66.667
# Best loss:0.311, Best accuracy:66.319, Best F1-score:0.659
# 115/150 lr=0.00064 - loss:0.277, acc:74.092, val_loss:0.298, val_acc:65.876
# Best loss:0.300, Best accuracy:66.667, Best F1-score:0.664
# 116/150 lr=0.00064 - loss:0.275, acc:73.800, val_loss:0.303, val_acc:64.313
# Best loss:0.300, Best accuracy:66.667, Best F1-score:0.664
# 117/150 lr=0.00064 - loss:0.275, acc:74.121, val_loss:0.310, val_acc:64.757
# Best loss:0.300, Best accuracy:66.667, Best F1-score:0.664
# 118/150 lr=0.00064 - loss:0.271, acc:74.733, val_loss:0.291, val_acc:67.882
# Best loss:0.300, Best accuracy:66.667, Best F1-score:0.664
# 119/150 lr=0.00064 - loss:0.274, acc:74.397, val_loss:0.304, val_acc:65.104
# Best loss:0.291, Best accuracy:67.882, Best F1-score:0.680
# 120/150 lr=0.00064 - loss:0.270, acc:74.838, val_loss:0.312, val_acc:63.002
# Best loss:0.291, Best accuracy:67.882, Best F1-score:0.680
# 121/150 lr=0.00064 - loss:0.271, acc:74.466, val_loss:0.305, val_acc:65.451
# Best loss:0.291, Best accuracy:67.882, Best F1-score:0.680
# 122/150 lr=0.00055 - loss:0.264, acc:75.583, val_loss:0.298, val_acc:68.056
# Best loss:0.291, Best accuracy:67.882, Best F1-score:0.680
# 123/150 lr=0.00055 - loss:0.269, acc:74.967, val_loss:0.303, val_acc:67.014
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 124/150 lr=0.00055 - loss:0.262, acc:76.084, val_loss:0.299, val_acc:65.972
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 125/150 lr=0.00055 - loss:0.266, acc:75.523, val_loss:0.299, val_acc:66.146
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 126/150 lr=0.00055 - loss:0.263, acc:75.906, val_loss:0.301, val_acc:64.390
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 127/150 lr=0.00055 - loss:0.264, acc:75.312, val_loss:0.303, val_acc:66.049
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 128/150 lr=0.00055 - loss:0.267, acc:74.953, val_loss:0.296, val_acc:67.091
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 129/150 lr=0.00055 - loss:0.263, acc:76.226, val_loss:0.298, val_acc:65.529
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 130/150 lr=0.00055 - loss:0.263, acc:75.588, val_loss:0.305, val_acc:66.840
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 131/150 lr=0.00055 - loss:0.260, acc:76.596, val_loss:0.297, val_acc:65.278
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 132/150 lr=0.00055 - loss:0.257, acc:76.384, val_loss:0.309, val_acc:62.751
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 133/150 lr=0.00055 - loss:0.259, acc:75.959, val_loss:0.295, val_acc:67.188
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 134/150 lr=0.00055 - loss:0.258, acc:76.068, val_loss:0.311, val_acc:63.966
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 135/150 lr=0.00055 - loss:0.272, acc:74.170, val_loss:0.302, val_acc:64.487
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 136/150 lr=0.00055 - loss:0.259, acc:76.498, val_loss:0.304, val_acc:63.098
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 137/150 lr=0.00055 - loss:0.258, acc:76.861, val_loss:0.302, val_acc:65.355
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 138/150 lr=0.00055 - loss:0.258, acc:76.585, val_loss:0.301, val_acc:66.917
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 139/150 lr=0.00055 - loss:0.256, acc:76.729, val_loss:0.307, val_acc:66.493
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 140/150 lr=0.00055 - loss:0.258, acc:76.191, val_loss:0.305, val_acc:65.355
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 141/150 lr=0.00055 - loss:0.257, acc:76.496, val_loss:0.310, val_acc:65.181
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 142/150 lr=0.00047 - loss:0.254, acc:77.226, val_loss:0.303, val_acc:65.625
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 143/150 lr=0.00047 - loss:0.252, acc:77.687, val_loss:0.299, val_acc:67.438
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 144/150 lr=0.00047 - loss:0.250, acc:77.802, val_loss:0.307, val_acc:64.062
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 145/150 lr=0.00047 - loss:0.252, acc:77.301, val_loss:0.302, val_acc:64.140
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 146/150 lr=0.00047 - loss:0.247, acc:77.858, val_loss:0.298, val_acc:65.625
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 147/150 lr=0.00047 - loss:0.250, acc:77.778, val_loss:0.303, val_acc:65.972
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 148/150 lr=0.00047 - loss:0.256, acc:76.631, val_loss:0.297, val_acc:65.451
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 149/150 lr=0.00047 - loss:0.247, acc:77.983, val_loss:0.299, val_acc:66.319
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# 150/150 lr=0.00047 - loss:0.246, acc:77.938, val_loss:0.300, val_acc:67.188
# Best loss:0.298, Best accuracy:68.056, Best F1-score:0.681
# [*] Done - acc:68.056

# %%
# end()

# %%
print(f'max:{max(fold_acc)}, min:{min(fold_acc)}, average:{sum(fold_acc)/len(fold_acc)}')
# Out:
# max:69.42515439457364, min:64.39043217235141, average:66.8194444808695

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
# Out:
# WAR(Weighted Average Recall)   : 67.06%
# UAR(Unweighted Average Recall) : 67.06%
