# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = '10-Fold dataset'
DATA_PATH = 'RAVDESS'
CLASS_LABELS = Config.RAVDESS_LABELS
k = 10

# reverse : (196,39,1)  ## CA: Channel-attention    ## SA : Self-attention 
model_name = '10-Fold-CV+Reverse(CNN+dilated)+CBAM+DSC+CA+SA+CA+Capsule+CA'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding=padding),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule]),
        Lambda(function=PrimaryCapssquash)
    ])
    
  def call(self, inputs):
    return self.conv(inputs)

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.cbam = CBAM(64) # sharing
    
    self.primarycap = PrimaryCap()
    self.spatial_attn = SpatialGate()
    
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    forward = inputs
    backward =tf.reverse(inputs, axis=[2])
    
    x = tf.concat([forward, backward], axis=-1)   # channel concat
    
    cap = self.conv1(x)
    cap = cap + self.cbam(cap)
    cap = self.conv2(cap)
    cap = cap + self.cbam(cap)
    
    primarycaps = self.primarycap(cap)
    primarycaps = tf.expand_dims(primarycaps, axis=-1)
    primarycaps = primarycaps + self.spatial_attn(primarycaps)
    primarycaps = tf.squeeze(primarycaps, axis=-1)
    
    cap = primarycaps
    
    sa = self.attention([primarycaps, primarycaps, primarycaps])
    sa = self.LN(sa)
    
    sa = tf.expand_dims(sa, axis=-1)
    sa = sa + self.spatial_attn(sa)
    sa = tf.squeeze(sa, axis=-1)
    
    cap = self.lamb([cap, sa])
    cap = tf.expand_dims(cap, axis=-1)
    cap = cap + self.spatial_attn(cap)
    cap = tf.squeeze(cap, axis=-1)
    
    capsule = self.capsule(cap)
    capsule = tf.expand_dims(capsule, axis=-1)
    capsule = capsule + self.spatial_attn(capsule)
    capsule = tf.squeeze(capsule, axis=-1)
    
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1992
#
#  sequential_1 (Sequential)   (None, 46, 7, 64)         37300
#
#  cbam (CBAM)                 multiple                  4294
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  spatial_gate_1 (SpatialGate  multiple                 102
#  )
#
#  attention (Attention)       multiple                  1
#
#  layer_normalization (LayerN  multiple                 128
#  ormalization)
#
#  lambda_1 (Lambda)           multiple                  0
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  520
#
# =================================================================
# Total params: 94,513
# Trainable params: 93,935
# Non-trainable params: 578
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}_train.npy', 'rb') as f:
    X = np.load(f)
    y = np.load(f)
y = to_categorical(y,num_classes=len(CLASS_LABELS))

with open(f'{DATA_ROOT}/{DATA_PATH}_test.npy', 'rb') as f:
    X_test = np.load(f)
    y_test = np.load(f)
y_test = to_categorical(y_test,num_classes=len(CLASS_LABELS))
    
print(X.shape, y.shape, X_test.shape, y_test.shape)
# Out:
# (1296, 196, 39) (1296, 8) (144, 196, 39) (144, 8)

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_val_acc = []
fold_test_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, val) in tqdm(enumerate(kfold.split(X, y)), desc=f'Training {k}-Fold.....'):
    # if i < 7: continue
    
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = X[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_val, y_val = X[val], y[val]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_val = tf.expand_dims(x_val, axis=-1)
    x_test = tf.expand_dims(X_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_val_loss = 0x3f3f3f
    best_val_acc = -1
    best_val_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_val = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        val_loss, val_acc, f1s = [], [], []
        for features, labels in batch_val:
            loss, acc, pred = test_step(model, features, labels)
            val_loss.append(loss)
            val_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1*100)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(val_loss)/len(val_loss)
        val_acc = sum(val_acc)/len(val_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_val_loss:.3f}, Best accuracy:{best_val_acc:.3f}, Best F1-score:{best_val_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_val_loss > val_loss:
            best_val_acc = val_acc
            best_val_loss = val_loss
            best_val_f1 = f1_score
            model.save_weights(h5_path)
            
            
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    
    test_acc, test_f1 = [], []
    for features, labels in batch_test:
        best_pred = model(features, training=False)
        emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(labels, axis=1))
        predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
        
        acc = tf.keras.metrics.CategoricalAccuracy()
        acc.update_state(labels, best_pred)
        accuracy = acc.result().numpy()
        test_acc.append(accuracy*100)
        
        f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
        f1_metric.update_state(labels, best_pred)
        f1 = f1_metric.result().numpy()
        test_f1.append(f1*100)
        
        
        
        
    print('*' * 80)
    print(f'[*] Done Fold-{i+1}')
    print(f'best_val_loss:{best_val_loss:.3f}, best_val_acc:{best_val_acc:.3f}, best_val_f1:{best_val_f1:.3f}')
    print(f'test_acc:{(sum(test_acc)/len(test_acc)):.3f}, test_f1:{(sum(test_f1)/len(test_f1)):.3f}')
    print('*' * 80)
    
    plt.title(f'Fold-{i+1} Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    fold_val_acc.append(best_val_acc)
    fold_test_acc.append((sum(test_acc)/len(test_acc)))
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.631, acc:17.049, val_loss:0.616, val_acc:35.625
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.614, acc:23.021, val_loss:0.604, val_acc:38.125
# Best loss:0.616, Best accuracy:35.625, Best F1-score:31.085
# 3/300 lr=0.00100 - loss:0.605, acc:24.928, val_loss:0.585, val_acc:38.125
# Best loss:0.604, Best accuracy:38.125, Best F1-score:33.303
# 4/300 lr=0.00100 - loss:0.594, acc:27.510, val_loss:0.593, val_acc:28.125
# Best loss:0.585, Best accuracy:38.125, Best F1-score:33.560
# 5/300 lr=0.00100 - loss:0.584, acc:28.909, val_loss:0.569, val_acc:38.750
# Best loss:0.585, Best accuracy:38.125, Best F1-score:33.560
# 6/300 lr=0.00100 - loss:0.577, acc:29.911, val_loss:0.575, val_acc:29.375
# Best loss:0.569, Best accuracy:38.750, Best F1-score:35.629
# 7/300 lr=0.00100 - loss:0.571, acc:30.550, val_loss:0.542, val_acc:41.250
# Best loss:0.569, Best accuracy:38.750, Best F1-score:35.629
# 8/300 lr=0.00100 - loss:0.567, acc:33.084, val_loss:0.590, val_acc:21.875
# Best loss:0.542, Best accuracy:41.250, Best F1-score:38.617
# 9/300 lr=0.00100 - loss:0.561, acc:33.892, val_loss:0.529, val_acc:35.000
# Best loss:0.542, Best accuracy:41.250, Best F1-score:38.617
# 10/300 lr=0.00100 - loss:0.551, acc:35.594, val_loss:0.574, val_acc:20.000
# Best loss:0.529, Best accuracy:35.000, Best F1-score:34.867
# 11/300 lr=0.00100 - loss:0.558, acc:32.022, val_loss:0.544, val_acc:36.250
# Best loss:0.529, Best accuracy:35.000, Best F1-score:34.867
# 12/300 lr=0.00100 - loss:0.552, acc:33.723, val_loss:0.559, val_acc:23.125
# Best loss:0.529, Best accuracy:35.000, Best F1-score:34.867
# 13/300 lr=0.00100 - loss:0.541, acc:37.584, val_loss:0.576, val_acc:16.875
# Best loss:0.529, Best accuracy:35.000, Best F1-score:34.867
# 14/300 lr=0.00100 - loss:0.540, acc:37.416, val_loss:0.530, val_acc:23.125
# Best loss:0.529, Best accuracy:35.000, Best F1-score:34.867
# 15/300 lr=0.00100 - loss:0.539, acc:36.680, val_loss:0.480, val_acc:51.875
# Best loss:0.529, Best accuracy:35.000, Best F1-score:34.867
# 16/300 lr=0.00100 - loss:0.529, acc:39.117, val_loss:0.482, val_acc:48.750
# Best loss:0.480, Best accuracy:51.875, Best F1-score:49.390
# 17/300 lr=0.00100 - loss:0.516, acc:41.168, val_loss:0.506, val_acc:37.500
# Best loss:0.480, Best accuracy:51.875, Best F1-score:49.390
# 18/300 lr=0.00100 - loss:0.509, acc:43.050, val_loss:0.536, val_acc:28.750
# Best loss:0.480, Best accuracy:51.875, Best F1-score:49.390
# 19/300 lr=0.00100 - loss:0.507, acc:41.699, val_loss:0.510, val_acc:31.250
# Best loss:0.480, Best accuracy:51.875, Best F1-score:49.390
# 20/300 lr=0.00100 - loss:0.500, acc:43.388, val_loss:0.504, val_acc:33.125
# Best loss:0.480, Best accuracy:51.875, Best F1-score:49.390
# 21/300 lr=0.00100 - loss:0.490, acc:45.572, val_loss:0.461, val_acc:55.000
# Best loss:0.480, Best accuracy:51.875, Best F1-score:49.390
# 22/300 lr=0.00100 - loss:0.485, acc:46.453, val_loss:0.449, val_acc:54.375
# Best loss:0.461, Best accuracy:55.000, Best F1-score:51.894
# 23/300 lr=0.00100 - loss:0.482, acc:46.030, val_loss:0.499, val_acc:29.375
# Best loss:0.449, Best accuracy:54.375, Best F1-score:52.013
# 24/300 lr=0.00100 - loss:0.474, acc:47.153, val_loss:0.492, val_acc:38.125
# Best loss:0.449, Best accuracy:54.375, Best F1-score:52.013
# 25/300 lr=0.00100 - loss:0.468, acc:48.226, val_loss:0.420, val_acc:56.250
# Best loss:0.449, Best accuracy:54.375, Best F1-score:52.013
# 26/300 lr=0.00100 - loss:0.456, acc:49.059, val_loss:0.383, val_acc:58.750
# Best loss:0.420, Best accuracy:56.250, Best F1-score:53.005
# 27/300 lr=0.00100 - loss:0.462, acc:50.531, val_loss:0.401, val_acc:56.250
# Best loss:0.383, Best accuracy:58.750, Best F1-score:56.809
# 28/300 lr=0.00100 - loss:0.454, acc:50.507, val_loss:0.408, val_acc:57.500
# Best loss:0.383, Best accuracy:58.750, Best F1-score:56.809
# 29/300 lr=0.00100 - loss:0.446, acc:50.627, val_loss:0.416, val_acc:58.125
# Best loss:0.383, Best accuracy:58.750, Best F1-score:56.809
# 30/300 lr=0.00100 - loss:0.450, acc:49.807, val_loss:0.392, val_acc:55.625
# Best loss:0.383, Best accuracy:58.750, Best F1-score:56.809
# 31/300 lr=0.00100 - loss:0.446, acc:51.134, val_loss:0.351, val_acc:60.000
# Best loss:0.383, Best accuracy:58.750, Best F1-score:56.809
# 32/300 lr=0.00100 - loss:0.452, acc:48.202, val_loss:0.363, val_acc:60.625
# Best loss:0.351, Best accuracy:60.000, Best F1-score:59.151
# 33/300 lr=0.00100 - loss:0.439, acc:52.534, val_loss:0.361, val_acc:60.000
# Best loss:0.351, Best accuracy:60.000, Best F1-score:59.151
# 34/300 lr=0.00100 - loss:0.427, acc:55.502, val_loss:0.369, val_acc:58.750
# Best loss:0.351, Best accuracy:60.000, Best F1-score:59.151
# 35/300 lr=0.00100 - loss:0.421, acc:54.488, val_loss:0.436, val_acc:46.250
# Best loss:0.351, Best accuracy:60.000, Best F1-score:59.151
# 36/300 lr=0.00100 - loss:0.435, acc:53.752, val_loss:0.428, val_acc:43.125
# Best loss:0.351, Best accuracy:60.000, Best F1-score:59.151
# 37/300 lr=0.00100 - loss:0.428, acc:53.282, val_loss:0.355, val_acc:63.750
# Best loss:0.351, Best accuracy:60.000, Best F1-score:59.151
# 38/300 lr=0.00100 - loss:0.418, acc:54.766, val_loss:0.343, val_acc:63.125
# Best loss:0.351, Best accuracy:60.000, Best F1-score:59.151
# 39/300 lr=0.00100 - loss:0.409, acc:58.048, val_loss:0.411, val_acc:51.875
# Best loss:0.343, Best accuracy:63.125, Best F1-score:59.683
# 40/300 lr=0.00100 - loss:0.413, acc:54.923, val_loss:0.375, val_acc:58.125
# Best loss:0.343, Best accuracy:63.125, Best F1-score:59.683
# 41/300 lr=0.00100 - loss:0.399, acc:58.699, val_loss:0.326, val_acc:65.000
# Best loss:0.343, Best accuracy:63.125, Best F1-score:59.683
# 42/300 lr=0.00100 - loss:0.408, acc:57.070, val_loss:0.316, val_acc:66.250
# Best loss:0.326, Best accuracy:65.000, Best F1-score:63.844
# 43/300 lr=0.00100 - loss:0.395, acc:59.472, val_loss:0.377, val_acc:61.875
# Best loss:0.316, Best accuracy:66.250, Best F1-score:63.841
# 44/300 lr=0.00100 - loss:0.383, acc:60.437, val_loss:0.336, val_acc:65.625
# Best loss:0.316, Best accuracy:66.250, Best F1-score:63.841
# 45/300 lr=0.00100 - loss:0.397, acc:58.856, val_loss:0.351, val_acc:55.000
# Best loss:0.316, Best accuracy:66.250, Best F1-score:63.841
# 46/300 lr=0.00100 - loss:0.401, acc:56.926, val_loss:0.335, val_acc:65.625
# Best loss:0.316, Best accuracy:66.250, Best F1-score:63.841
# 47/300 lr=0.00100 - loss:0.390, acc:59.833, val_loss:0.343, val_acc:60.625
# Best loss:0.316, Best accuracy:66.250, Best F1-score:63.841
# 48/300 lr=0.00100 - loss:0.390, acc:59.677, val_loss:0.337, val_acc:60.000
# Best loss:0.316, Best accuracy:66.250, Best F1-score:63.841
# 49/300 lr=0.00100 - loss:0.377, acc:60.750, val_loss:0.289, val_acc:69.375
# Best loss:0.316, Best accuracy:66.250, Best F1-score:63.841
# 50/300 lr=0.00100 - loss:0.380, acc:60.859, val_loss:0.301, val_acc:66.875
# Best loss:0.289, Best accuracy:69.375, Best F1-score:68.076
# 51/300 lr=0.00100 - loss:0.370, acc:60.859, val_loss:0.368, val_acc:51.875
# Best loss:0.289, Best accuracy:69.375, Best F1-score:68.076
# 52/300 lr=0.00100 - loss:0.362, acc:63.863, val_loss:0.306, val_acc:66.250
# Best loss:0.289, Best accuracy:69.375, Best F1-score:68.076
# 53/300 lr=0.00100 - loss:0.361, acc:63.682, val_loss:0.296, val_acc:68.125
# Best loss:0.289, Best accuracy:69.375, Best F1-score:68.076
# 54/300 lr=0.00100 - loss:0.361, acc:64.443, val_loss:0.299, val_acc:70.625
# Best loss:0.289, Best accuracy:69.375, Best F1-score:68.076
# 55/300 lr=0.00100 - loss:0.349, acc:65.372, val_loss:0.269, val_acc:70.000
# Best loss:0.222, Best accuracy:76.250, Best F1-score:75.754
# 75/300 lr=0.00086 - loss:0.297, acc:73.830, val_loss:0.258, val_acc:68.125
# Best loss:0.222, Best accuracy:76.250, Best F1-score:75.754
# 76/300 lr=0.00086 - loss:0.291, acc:73.781, val_loss:0.218, val_acc:75.000
# Best loss:0.222, Best accuracy:76.250, Best F1-score:75.754
# 77/300 lr=0.00086 - loss:0.297, acc:72.153, val_loss:0.244, val_acc:73.125
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 78/300 lr=0.00086 - loss:0.291, acc:73.830, val_loss:0.295, val_acc:65.625
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 79/300 lr=0.00086 - loss:0.288, acc:73.914, val_loss:0.250, val_acc:71.875
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 80/300 lr=0.00086 - loss:0.275, acc:76.303, val_loss:0.247, val_acc:73.750
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 81/300 lr=0.00086 - loss:0.288, acc:74.312, val_loss:0.238, val_acc:73.750
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 82/300 lr=0.00074 - loss:0.281, acc:73.938, val_loss:0.245, val_acc:73.750
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 83/300 lr=0.00074 - loss:0.274, acc:76.762, val_loss:0.218, val_acc:73.750
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 84/300 lr=0.00074 - loss:0.279, acc:75.772, val_loss:0.225, val_acc:73.125
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 85/300 lr=0.00074 - loss:0.270, acc:76.750, val_loss:0.254, val_acc:71.250
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 86/300 lr=0.00074 - loss:0.270, acc:76.146, val_loss:0.302, val_acc:65.625
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 87/300 lr=0.00074 - loss:0.269, acc:76.339, val_loss:0.267, val_acc:70.000
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 88/300 lr=0.00074 - loss:0.271, acc:76.834, val_loss:0.240, val_acc:71.250
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 89/300 lr=0.00074 - loss:0.270, acc:76.110, val_loss:0.236, val_acc:73.125
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 90/300 lr=0.00074 - loss:0.277, acc:74.674, val_loss:0.249, val_acc:72.500
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 91/300 lr=0.00074 - loss:0.276, acc:75.808, val_loss:0.278, val_acc:66.875
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 92/300 lr=0.00074 - loss:0.268, acc:77.896, val_loss:0.258, val_acc:67.500
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 93/300 lr=0.00074 - loss:0.259, acc:78.535, val_loss:0.211, val_acc:76.875
# Best loss:0.218, Best accuracy:75.000, Best F1-score:73.716
# 94/300 lr=0.00074 - loss:0.257, acc:78.764, val_loss:0.237, val_acc:71.250
# Best loss:0.211, Best accuracy:76.875, Best F1-score:77.088
# 95/300 lr=0.00074 - loss:0.248, acc:78.813, val_loss:0.226, val_acc:70.625
# Best loss:0.211, Best accuracy:76.875, Best F1-score:77.088
# 96/300 lr=0.00074 - loss:0.238, acc:82.239, val_loss:0.228, val_acc:70.625
# Best loss:0.211, Best accuracy:76.875, Best F1-score:77.088
# 97/300 lr=0.00074 - loss:0.245, acc:79.730, val_loss:0.264, val_acc:70.625
# Best loss:0.211, Best accuracy:76.875, Best F1-score:77.088
# 98/300 lr=0.00074 - loss:0.253, acc:78.752, val_loss:0.258, val_acc:69.375
# Best loss:0.211, Best accuracy:76.875, Best F1-score:77.088
# 99/300 lr=0.00074 - loss:0.242, acc:80.056, val_loss:0.212, val_acc:75.625
# Best loss:0.211, Best accuracy:76.875, Best F1-score:77.088
# 100/300 lr=0.00074 - loss:0.248, acc:80.454, val_loss:0.235, val_acc:73.750
# Best loss:0.211, Best accuracy:76.875, Best F1-score:77.088
# 101/300 lr=0.00074 - loss:0.242, acc:80.357, val_loss:0.229, val_acc:74.375
# Best loss:0.211, Best accuracy:76.875, Best F1-score:77.088
# 102/300 lr=0.00064 - loss:0.239, acc:82.408, val_loss:0.237, val_acc:73.125
# Best loss:0.211, Best accuracy:76.875, Best F1-score:77.088
# 103/300 lr=0.00064 - loss:0.228, acc:82.758, val_loss:0.222, val_acc:75.625
# Best loss:0.211, Best accuracy:76.875, Best F1-score:77.088
# 104/300 lr=0.00064 - loss:0.226, acc:81.769, val_loss:0.207, val_acc:75.625
# Best loss:0.211, Best accuracy:76.875, Best F1-score:77.088
# 105/300 lr=0.00064 - loss:0.221, acc:83.325, val_loss:0.220, val_acc:73.125
# Best loss:0.207, Best accuracy:75.625, Best F1-score:73.743
# 106/300 lr=0.00064 - loss:0.226, acc:83.796, val_loss:0.215, val_acc:75.000
# Best loss:0.207, Best accuracy:75.625, Best F1-score:73.743
# 107/300 lr=0.00064 - loss:0.224, acc:83.530, val_loss:0.211, val_acc:75.000
# Best loss:0.207, Best accuracy:75.625, Best F1-score:73.743
# 108/300 lr=0.00064 - loss:0.226, acc:83.253, val_loss:0.196, val_acc:77.500
# Best loss:0.207, Best accuracy:75.625, Best F1-score:73.743
# 109/300 lr=0.00064 - loss:0.229, acc:82.529, val_loss:0.219, val_acc:75.000
# Best loss:0.196, Best accuracy:77.500, Best F1-score:76.445
# 110/300 lr=0.00064 - loss:0.222, acc:82.831, val_loss:0.222, val_acc:75.000
# Best loss:0.196, Best accuracy:77.500, Best F1-score:76.445
# 111/300 lr=0.00064 - loss:0.213, acc:85.787, val_loss:0.209, val_acc:75.625
# Best loss:0.196, Best accuracy:77.500, Best F1-score:76.445
# 112/300 lr=0.00064 - loss:0.212, acc:85.063, val_loss:0.212, val_acc:75.000
# Best loss:0.196, Best accuracy:77.500, Best F1-score:76.445
# 113/300 lr=0.00064 - loss:0.214, acc:84.761, val_loss:0.235, val_acc:71.875
# Best loss:0.196, Best accuracy:77.500, Best F1-score:76.445
# 114/300 lr=0.00064 - loss:0.219, acc:83.398, val_loss:0.229, val_acc:71.875
# Best loss:0.196, Best accuracy:77.500, Best F1-score:76.445
# 115/300 lr=0.00064 - loss:0.213, acc:85.280, val_loss:0.220, val_acc:73.125
# Best loss:0.196, Best accuracy:77.500, Best F1-score:76.445
# 116/300 lr=0.00064 - loss:0.214, acc:83.904, val_loss:0.216, val_acc:75.000
# Best loss:0.196, Best accuracy:77.500, Best F1-score:76.445
# 117/300 lr=0.00064 - loss:0.217, acc:83.542, val_loss:0.222, val_acc:75.625
# Best loss:0.196, Best accuracy:77.500, Best F1-score:76.445
# 118/300 lr=0.00064 - loss:0.204, acc:86.378, val_loss:0.243, val_acc:74.375
# Best loss:0.196, Best accuracy:77.500, Best F1-score:76.445
# 119/300 lr=0.00064 - loss:0.214, acc:84.073, val_loss:0.222, val_acc:74.375
# Best loss:0.196, Best accuracy:77.500, Best F1-score:76.445
# 120/300 lr=0.00064 - loss:0.215, acc:84.689, val_loss:0.211, val_acc:76.250
# Best loss:0.196, Best accuracy:77.500, Best F1-score:76.445
# 121/300 lr=0.00064 - loss:0.203, acc:86.583, val_loss:0.195, val_acc:77.500
# Best loss:0.196, Best accuracy:77.500, Best F1-score:76.445
# 122/300 lr=0.00055 - loss:0.197, acc:86.523, val_loss:0.200, val_acc:77.500
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 123/300 lr=0.00055 - loss:0.211, acc:85.002, val_loss:0.246, val_acc:72.500
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 124/300 lr=0.00055 - loss:0.204, acc:86.330, val_loss:0.215, val_acc:75.625
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 125/300 lr=0.00055 - loss:0.199, acc:87.669, val_loss:0.212, val_acc:76.250
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 126/300 lr=0.00055 - loss:0.205, acc:85.871, val_loss:0.209, val_acc:75.000
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 127/300 lr=0.00055 - loss:0.196, acc:86.330, val_loss:0.215, val_acc:75.000
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 128/300 lr=0.00055 - loss:0.191, acc:88.574, val_loss:0.209, val_acc:75.625
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 129/300 lr=0.00055 - loss:0.187, acc:87.621, val_loss:0.208, val_acc:74.375
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 130/300 lr=0.00055 - loss:0.191, acc:87.669, val_loss:0.238, val_acc:73.750
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 131/300 lr=0.00055 - loss:0.184, acc:89.841, val_loss:0.220, val_acc:74.375
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 132/300 lr=0.00055 - loss:0.185, acc:89.443, val_loss:0.208, val_acc:78.125
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 133/300 lr=0.00055 - loss:0.190, acc:86.921, val_loss:0.231, val_acc:74.375
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 134/300 lr=0.00055 - loss:0.180, acc:90.323, val_loss:0.209, val_acc:75.625
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 135/300 lr=0.00055 - loss:0.182, acc:89.081, val_loss:0.202, val_acc:77.500
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 136/300 lr=0.00055 - loss:0.189, acc:88.260, val_loss:0.218, val_acc:76.250
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 137/300 lr=0.00055 - loss:0.183, acc:88.851, val_loss:0.201, val_acc:77.500
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 138/300 lr=0.00055 - loss:0.181, acc:89.382, val_loss:0.213, val_acc:75.000
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 139/300 lr=0.00055 - loss:0.179, acc:90.541, val_loss:0.217, val_acc:76.250
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 140/300 lr=0.00055 - loss:0.182, acc:89.611, val_loss:0.218, val_acc:73.125
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 141/300 lr=0.00055 - loss:0.189, acc:88.103, val_loss:0.192, val_acc:78.125
# Best loss:0.195, Best accuracy:77.500, Best F1-score:76.008
# 142/300 lr=0.00047 - loss:0.183, acc:89.189, val_loss:0.194, val_acc:79.375
# Best loss:0.192, Best accuracy:78.125, Best F1-score:77.255
# 143/300 lr=0.00047 - loss:0.180, acc:89.225, val_loss:0.211, val_acc:76.250
# Best loss:0.192, Best accuracy:78.125, Best F1-score:77.255
# 144/300 lr=0.00047 - loss:0.176, acc:90.118, val_loss:0.201, val_acc:79.375
# Best loss:0.192, Best accuracy:78.125, Best F1-score:77.255
# 145/300 lr=0.00047 - loss:0.181, acc:89.949, val_loss:0.189, val_acc:80.625
# Best loss:0.192, Best accuracy:78.125, Best F1-score:77.255
# 146/300 lr=0.00047 - loss:0.178, acc:89.925, val_loss:0.187, val_acc:80.625
# Best loss:0.189, Best accuracy:80.625, Best F1-score:79.620
# 147/300 lr=0.00047 - loss:0.172, acc:90.553, val_loss:0.188, val_acc:77.500
# Best loss:0.187, Best accuracy:80.625, Best F1-score:80.087
# 148/300 lr=0.00047 - loss:0.173, acc:90.661, val_loss:0.202, val_acc:75.625
# Best loss:0.187, Best accuracy:80.625, Best F1-score:80.087
# 149/300 lr=0.00047 - loss:0.167, acc:90.890, val_loss:0.190, val_acc:77.500
# Best loss:0.187, Best accuracy:80.625, Best F1-score:80.087
# 150/300 lr=0.00047 - loss:0.170, acc:90.094, val_loss:0.203, val_acc:76.875
# Best loss:0.187, Best accuracy:80.625, Best F1-score:80.087
# 189/300 lr=0.00035 - loss:0.141, acc:94.908, val_loss:0.198, val_acc:78.750
# Best loss:0.173, Best accuracy:81.250, Best F1-score:80.403
# 190/300 lr=0.00035 - loss:0.140, acc:95.608, val_loss:0.197, val_acc:76.875
# Best loss:0.173, Best accuracy:81.250, Best F1-score:80.403
# 191/300 lr=0.00035 - loss:0.135, acc:95.693, val_loss:0.220, val_acc:70.000
# Best loss:0.173, Best accuracy:81.250, Best F1-score:80.403
# 192/300 lr=0.00035 - loss:0.142, acc:94.908, val_loss:0.177, val_acc:81.875
# Best loss:0.173, Best accuracy:81.250, Best F1-score:80.403
# 193/300 lr=0.00035 - loss:0.147, acc:93.955, val_loss:0.197, val_acc:76.250
# Best loss:0.173, Best accuracy:81.250, Best F1-score:80.403
# 194/300 lr=0.00035 - loss:0.141, acc:94.655, val_loss:0.184, val_acc:81.250
# Best loss:0.173, Best accuracy:81.250, Best F1-score:80.403
# 195/300 lr=0.00035 - loss:0.145, acc:94.317, val_loss:0.173, val_acc:80.625
# Best loss:0.173, Best accuracy:81.250, Best F1-score:80.403
# 196/300 lr=0.00035 - loss:0.139, acc:95.101, val_loss:0.195, val_acc:79.375
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 197/300 lr=0.00035 - loss:0.142, acc:94.172, val_loss:0.183, val_acc:80.000
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 198/300 lr=0.00035 - loss:0.141, acc:94.522, val_loss:0.191, val_acc:81.250
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 199/300 lr=0.00035 - loss:0.142, acc:94.341, val_loss:0.208, val_acc:76.250
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 200/300 lr=0.00035 - loss:0.149, acc:93.086, val_loss:0.173, val_acc:81.250
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 201/300 lr=0.00035 - loss:0.140, acc:94.715, val_loss:0.201, val_acc:81.250
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 202/300 lr=0.00030 - loss:0.149, acc:93.195, val_loss:0.210, val_acc:75.000
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 203/300 lr=0.00030 - loss:0.142, acc:94.317, val_loss:0.196, val_acc:75.625
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 204/300 lr=0.00030 - loss:0.135, acc:95.524, val_loss:0.186, val_acc:79.375
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 205/300 lr=0.00030 - loss:0.143, acc:93.653, val_loss:0.189, val_acc:78.750
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 206/300 lr=0.00030 - loss:0.138, acc:95.017, val_loss:0.189, val_acc:80.000
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 207/300 lr=0.00030 - loss:0.142, acc:93.750, val_loss:0.216, val_acc:76.875
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 208/300 lr=0.00030 - loss:0.142, acc:94.715, val_loss:0.193, val_acc:78.125
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 209/300 lr=0.00030 - loss:0.142, acc:94.341, val_loss:0.207, val_acc:78.125
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 210/300 lr=0.00030 - loss:0.138, acc:95.186, val_loss:0.196, val_acc:77.500
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 211/300 lr=0.00030 - loss:0.133, acc:95.693, val_loss:0.193, val_acc:79.375
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 212/300 lr=0.00030 - loss:0.146, acc:93.847, val_loss:0.204, val_acc:78.125
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 213/300 lr=0.00030 - loss:0.136, acc:96.091, val_loss:0.191, val_acc:80.625
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 214/300 lr=0.00030 - loss:0.137, acc:95.162, val_loss:0.188, val_acc:78.125
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 215/300 lr=0.00030 - loss:0.137, acc:95.415, val_loss:0.197, val_acc:77.500
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
#
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 248/300 lr=0.00022 - loss:0.127, acc:96.368, val_loss:0.182, val_acc:80.000
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 249/300 lr=0.00022 - loss:0.126, acc:96.537, val_loss:0.208, val_acc:78.125
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 250/300 lr=0.00022 - loss:0.129, acc:96.622, val_loss:0.192, val_acc:79.375
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 251/300 lr=0.00022 - loss:0.127, acc:96.935, val_loss:0.204, val_acc:78.125
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 252/300 lr=0.00022 - loss:0.130, acc:96.091, val_loss:0.184, val_acc:80.000
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 253/300 lr=0.00022 - loss:0.129, acc:96.006, val_loss:0.212, val_acc:70.000
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 254/300 lr=0.00022 - loss:0.128, acc:96.320, val_loss:0.218, val_acc:76.875
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 255/300 lr=0.00022 - loss:0.126, acc:96.597, val_loss:0.193, val_acc:80.000
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 256/300 lr=0.00022 - loss:0.127, acc:96.766, val_loss:0.196, val_acc:79.375
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 257/300 lr=0.00022 - loss:0.127, acc:96.368, val_loss:0.187, val_acc:81.250
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 258/300 lr=0.00022 - loss:0.125, acc:96.537, val_loss:0.182, val_acc:80.625
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 259/300 lr=0.00022 - loss:0.123, acc:97.382, val_loss:0.207, val_acc:77.500
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 260/300 lr=0.00022 - loss:0.123, acc:97.551, val_loss:0.187, val_acc:79.375
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 261/300 lr=0.00022 - loss:0.124, acc:96.622, val_loss:0.207, val_acc:79.375
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 262/300 lr=0.00019 - loss:0.121, acc:97.466, val_loss:0.189, val_acc:77.500
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 263/300 lr=0.00019 - loss:0.122, acc:97.551, val_loss:0.197, val_acc:78.750
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 264/300 lr=0.00019 - loss:0.125, acc:96.706, val_loss:0.204, val_acc:76.875
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 265/300 lr=0.00019 - loss:0.118, acc:97.720, val_loss:0.200, val_acc:78.125
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 266/300 lr=0.00019 - loss:0.120, acc:97.382, val_loss:0.203, val_acc:76.875
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 267/300 lr=0.00019 - loss:0.126, acc:97.358, val_loss:0.194, val_acc:77.500
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 268/300 lr=0.00019 - loss:0.122, acc:97.382, val_loss:0.189, val_acc:79.375
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 269/300 lr=0.00019 - loss:0.125, acc:96.682, val_loss:0.189, val_acc:78.750
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 270/300 lr=0.00019 - loss:0.127, acc:96.682, val_loss:0.197, val_acc:78.750
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 271/300 lr=0.00019 - loss:0.126, acc:96.622, val_loss:0.184, val_acc:78.750
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 272/300 lr=0.00019 - loss:0.122, acc:97.551, val_loss:0.183, val_acc:79.375
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 273/300 lr=0.00019 - loss:0.121, acc:97.466, val_loss:0.189, val_acc:78.750
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 274/300 lr=0.00019 - loss:0.124, acc:96.875, val_loss:0.188, val_acc:78.750
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 275/300 lr=0.00019 - loss:0.125, acc:97.044, val_loss:0.189, val_acc:78.750
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 276/300 lr=0.00019 - loss:0.118, acc:98.311, val_loss:0.175, val_acc:80.000
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 277/300 lr=0.00019 - loss:0.122, acc:97.358, val_loss:0.206, val_acc:75.000
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 278/300 lr=0.00019 - loss:0.122, acc:97.213, val_loss:0.172, val_acc:82.500
# Best loss:0.173, Best accuracy:80.625, Best F1-score:80.463
# 279/300 lr=0.00019 - loss:0.119, acc:98.118, val_loss:0.185, val_acc:80.625
# Best loss:0.172, Best accuracy:82.500, Best F1-score:82.266
# 280/300 lr=0.00019 - loss:0.119, acc:97.720, val_loss:0.198, val_acc:79.375
# Best loss:0.172, Best accuracy:82.500, Best F1-score:82.266
# 281/300 lr=0.00019 - loss:0.119, acc:97.611, val_loss:0.195, val_acc:78.750
# Best loss:0.172, Best accuracy:82.500, Best F1-score:82.266
# 282/300 lr=0.00017 - loss:0.120, acc:97.949, val_loss:0.172, val_acc:79.375
# Best loss:0.172, Best accuracy:82.500, Best F1-score:82.266
# 283/300 lr=0.00017 - loss:0.121, acc:97.889, val_loss:0.185, val_acc:78.125
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 284/300 lr=0.00017 - loss:0.119, acc:97.466, val_loss:0.181, val_acc:78.750
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 285/300 lr=0.00017 - loss:0.123, acc:96.851, val_loss:0.173, val_acc:81.250
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 286/300 lr=0.00017 - loss:0.120, acc:97.551, val_loss:0.178, val_acc:78.750
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 287/300 lr=0.00017 - loss:0.120, acc:97.358, val_loss:0.186, val_acc:80.000
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 288/300 lr=0.00017 - loss:0.120, acc:97.780, val_loss:0.187, val_acc:80.000
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 289/300 lr=0.00017 - loss:0.121, acc:97.466, val_loss:0.173, val_acc:80.000
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 290/300 lr=0.00017 - loss:0.117, acc:97.973, val_loss:0.179, val_acc:80.000
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 291/300 lr=0.00017 - loss:0.119, acc:97.973, val_loss:0.178, val_acc:81.875
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 292/300 lr=0.00017 - loss:0.126, acc:97.104, val_loss:0.201, val_acc:78.750
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 293/300 lr=0.00017 - loss:0.121, acc:97.889, val_loss:0.191, val_acc:80.625
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 294/300 lr=0.00017 - loss:0.116, acc:98.202, val_loss:0.185, val_acc:78.125
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 295/300 lr=0.00017 - loss:0.116, acc:98.709, val_loss:0.182, val_acc:80.625
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 296/300 lr=0.00017 - loss:0.115, acc:98.480, val_loss:0.183, val_acc:78.125
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 297/300 lr=0.00017 - loss:0.120, acc:97.128, val_loss:0.179, val_acc:80.000
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 298/300 lr=0.00017 - loss:0.118, acc:98.649, val_loss:0.184, val_acc:79.375
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 299/300 lr=0.00017 - loss:0.116, acc:98.033, val_loss:0.167, val_acc:80.000
# Best loss:0.172, Best accuracy:79.375, Best F1-score:79.606
# 300/300 lr=0.00017 - loss:0.116, acc:98.287, val_loss:0.187, val_acc:78.750
# Best loss:0.167, Best accuracy:80.000, Best F1-score:80.105
# ********************************************************************************
# [*] Done Fold-1
# best_val_loss:0.167, best_val_acc:80.000, best_val_f1:80.105
# test_acc:84.375, test_f1:83.937
# ********************************************************************************
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.630, acc:17.507, val_loss:0.604, val_acc:26.875
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.615, acc:20.910, val_loss:0.583, val_acc:39.375
# Best loss:0.604, Best accuracy:26.875, Best F1-score:22.312
# 3/300 lr=0.00100 - loss:0.601, acc:26.918, val_loss:0.571, val_acc:43.750
# Best loss:0.583, Best accuracy:39.375, Best F1-score:35.638
# 4/300 lr=0.00100 - loss:0.591, acc:28.849, val_loss:0.568, val_acc:34.375
# Best loss:0.571, Best accuracy:43.750, Best F1-score:38.270
# 5/300 lr=0.00100 - loss:0.591, acc:28.028, val_loss:0.562, val_acc:30.000
# Best loss:0.568, Best accuracy:34.375, Best F1-score:30.765
# 6/300 lr=0.00100 - loss:0.584, acc:30.068, val_loss:0.558, val_acc:31.250
# Best loss:0.562, Best accuracy:30.000, Best F1-score:28.103
# 7/300 lr=0.00100 - loss:0.576, acc:30.393, val_loss:0.559, val_acc:33.125
# Best loss:0.558, Best accuracy:31.250, Best F1-score:26.899
# 8/300 lr=0.00100 - loss:0.568, acc:31.455, val_loss:0.524, val_acc:37.500
# Best loss:0.558, Best accuracy:31.250, Best F1-score:26.899
# 9/300 lr=0.00100 - loss:0.563, acc:33.036, val_loss:0.518, val_acc:38.750
# Best loss:0.524, Best accuracy:37.500, Best F1-score:33.195
# 10/300 lr=0.00100 - loss:0.551, acc:36.016, val_loss:0.514, val_acc:38.750
# Best loss:0.518, Best accuracy:38.750, Best F1-score:35.035
# 11/300 lr=0.00100 - loss:0.543, acc:36.209, val_loss:0.500, val_acc:41.875
# Best loss:0.514, Best accuracy:38.750, Best F1-score:35.840
# 12/300 lr=0.00100 - loss:0.536, acc:37.753, val_loss:0.480, val_acc:51.875
# Best loss:0.500, Best accuracy:41.875, Best F1-score:37.208
# 13/300 lr=0.00100 - loss:0.530, acc:39.394, val_loss:0.515, val_acc:40.000
# Best loss:0.480, Best accuracy:51.875, Best F1-score:49.494
# 14/300 lr=0.00100 - loss:0.526, acc:38.417, val_loss:0.462, val_acc:53.750
# Best loss:0.480, Best accuracy:51.875, Best F1-score:49.494
# 15/300 lr=0.00100 - loss:0.524, acc:39.117, val_loss:0.441, val_acc:53.750
# Best loss:0.462, Best accuracy:53.750, Best F1-score:52.413
# 16/300 lr=0.00100 - loss:0.510, acc:41.071, val_loss:0.443, val_acc:54.375
# Best loss:0.441, Best accuracy:53.750, Best F1-score:49.781
# 17/300 lr=0.00100 - loss:0.500, acc:43.026, val_loss:0.421, val_acc:55.625
# Best loss:0.441, Best accuracy:53.750, Best F1-score:49.781
# 18/300 lr=0.00100 - loss:0.501, acc:42.435, val_loss:0.446, val_acc:42.500
# Best loss:0.421, Best accuracy:55.625, Best F1-score:52.032
# 19/300 lr=0.00100 - loss:0.487, acc:46.754, val_loss:0.469, val_acc:31.875
# Best loss:0.421, Best accuracy:55.625, Best F1-score:52.032
# 20/300 lr=0.00100 - loss:0.483, acc:45.463, val_loss:0.416, val_acc:48.125
# Best loss:0.421, Best accuracy:55.625, Best F1-score:52.032
# 21/300 lr=0.00100 - loss:0.478, acc:47.418, val_loss:0.413, val_acc:56.250
# Best loss:0.416, Best accuracy:48.125, Best F1-score:46.722
# 22/300 lr=0.00100 - loss:0.472, acc:46.260, val_loss:0.399, val_acc:60.000
# Best loss:0.413, Best accuracy:56.250, Best F1-score:52.668
# 23/300 lr=0.00100 - loss:0.471, acc:47.925, val_loss:0.448, val_acc:51.250
# Best loss:0.399, Best accuracy:60.000, Best F1-score:57.738
# 24/300 lr=0.00100 - loss:0.480, acc:46.984, val_loss:0.420, val_acc:46.875
# Best loss:0.399, Best accuracy:60.000, Best F1-score:57.738
# 25/300 lr=0.00100 - loss:0.476, acc:45.512, val_loss:0.407, val_acc:46.250
# Best loss:0.399, Best accuracy:60.000, Best F1-score:57.738
# 26/300 lr=0.00100 - loss:0.457, acc:51.194, val_loss:0.377, val_acc:62.500
# Best loss:0.399, Best accuracy:60.000, Best F1-score:57.738
# 27/300 lr=0.00100 - loss:0.452, acc:51.351, val_loss:0.347, val_acc:66.250
# Best loss:0.377, Best accuracy:62.500, Best F1-score:60.412
# 28/300 lr=0.00100 - loss:0.450, acc:50.048, val_loss:0.398, val_acc:51.250
# Best loss:0.347, Best accuracy:66.250, Best F1-score:63.426
# 29/300 lr=0.00100 - loss:0.446, acc:50.905, val_loss:0.369, val_acc:62.500
# Best loss:0.347, Best accuracy:66.250, Best F1-score:63.426
# 30/300 lr=0.00100 - loss:0.440, acc:52.280, val_loss:0.360, val_acc:56.250
# Best loss:0.347, Best accuracy:66.250, Best F1-score:63.426
# 31/300 lr=0.00100 - loss:0.441, acc:50.820, val_loss:0.330, val_acc:70.000
# Best loss:0.347, Best accuracy:66.250, Best F1-score:63.426
# 32/300 lr=0.00100 - loss:0.441, acc:51.050, val_loss:0.402, val_acc:54.375
# Best loss:0.330, Best accuracy:70.000, Best F1-score:69.329
# 33/300 lr=0.00100 - loss:0.430, acc:54.730, val_loss:0.347, val_acc:65.625
# Best loss:0.330, Best accuracy:70.000, Best F1-score:69.329
# 34/300 lr=0.00100 - loss:0.431, acc:52.534, val_loss:0.351, val_acc:68.750
# Best loss:0.330, Best accuracy:70.000, Best F1-score:69.329
# 35/300 lr=0.00100 - loss:0.425, acc:55.212, val_loss:0.408, val_acc:38.750
# Best loss:0.330, Best accuracy:70.000, Best F1-score:69.329
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 283/300 lr=0.00017 - loss:0.124, acc:97.297, val_loss:0.345, val_acc:65.000
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 284/300 lr=0.00017 - loss:0.122, acc:97.635, val_loss:0.362, val_acc:65.000
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 285/300 lr=0.00017 - loss:0.123, acc:97.213, val_loss:0.354, val_acc:63.125
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 286/300 lr=0.00017 - loss:0.124, acc:97.128, val_loss:0.370, val_acc:63.125
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 287/300 lr=0.00017 - loss:0.120, acc:97.624, val_loss:0.376, val_acc:65.000
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 288/300 lr=0.00017 - loss:0.120, acc:97.877, val_loss:0.360, val_acc:66.250
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 289/300 lr=0.00017 - loss:0.121, acc:97.213, val_loss:0.375, val_acc:63.125
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 290/300 lr=0.00017 - loss:0.125, acc:97.202, val_loss:0.364, val_acc:65.000
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 291/300 lr=0.00017 - loss:0.123, acc:97.033, val_loss:0.382, val_acc:64.375
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 292/300 lr=0.00017 - loss:0.121, acc:97.359, val_loss:0.370, val_acc:64.375
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 293/300 lr=0.00017 - loss:0.120, acc:97.708, val_loss:0.377, val_acc:61.250
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 294/300 lr=0.00017 - loss:0.120, acc:97.720, val_loss:0.349, val_acc:63.125
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 295/300 lr=0.00017 - loss:0.118, acc:97.635, val_loss:0.372, val_acc:65.000
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 296/300 lr=0.00017 - loss:0.120, acc:97.782, val_loss:0.385, val_acc:63.750
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 297/300 lr=0.00017 - loss:0.119, acc:97.889, val_loss:0.373, val_acc:63.125
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 298/300 lr=0.00017 - loss:0.122, acc:97.551, val_loss:0.388, val_acc:63.750
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579
# 299/300 lr=0.00017 - loss:0.120, acc:97.613, val_loss:0.362, val_acc:67.500
# Best loss:0.300, Best accuracy:57.500, Best F1-score:56.579

# %%
end()

# %%
print('*' * 80)
print('[*] validation accuracy')
for i, val_acc in enumerate(fold_val_acc):
    print(f'    Fold-{i+1} : {val_acc}')
print(f'max:{max(fold_val_acc)}, min:{min(fold_val_acc)}, average:{sum(fold_val_acc)/len(fold_val_acc)}')
print('*' * 80)
print()

print('*' * 80)
print('[*] test accuracy')
for i, test_acc in enumerate(fold_test_acc):
    print(f'    Fold-{i+1} : {test_acc}')
print(f'max:{max(fold_test_acc)}, min:{min(fold_test_acc)}, average:{sum(fold_test_acc)/len(fold_test_acc)}')
print('*' * 80)
print()

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
