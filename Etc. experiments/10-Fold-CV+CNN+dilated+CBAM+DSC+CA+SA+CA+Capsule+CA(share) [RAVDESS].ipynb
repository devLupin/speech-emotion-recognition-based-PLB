# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = '10-Fold dataset'
DATA_PATH = 'RAVDESS'
CLASS_LABELS = Config.RAVDESS_LABELS
k = 10

# No-reverse : (196,39,1)  ## CA: Channel-attention    ## SA : Self-attention 
# DSC : Depthwise-seperable CNN
model_name = '10-Fold-CV+CNN+dilated+CBAM+DSC+CA+SA+CA+Capsule+CA(share)'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding=padding),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule]),
        Lambda(function=PrimaryCapssquash)
    ])
    
  def call(self, inputs):
    return self.conv(inputs)

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.channel_attn = ChannelGate(64)
    self.spatial_attn = SpatialGate()
    
    self.primarycap = PrimaryCap()
    
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    x = inputs
    
    ## channel -> spatial
    cap = self.conv1(x)
    tmp = self.channel_attn(cap)
    tmp = self.spatial_attn(tmp)
    cap = cap + tmp
    
    cap = self.conv2(cap)
    tmp = self.channel_attn(cap)
    tmp = self.spatial_attn(tmp)
    cap = cap + tmp
    
    tmp = self.channel_attn(cap)
    tmp = self.spatial_attn(tmp)
    cap = cap + tmp
    
    
    primarycaps = self.primarycap(cap)
    primarycaps = tf.expand_dims(primarycaps, axis=-1)
    primarycaps = primarycaps + self.spatial_attn(primarycaps)
    primarycaps = tf.squeeze(primarycaps, axis=-1)
    
    cap = primarycaps
    
    sa = self.attention([primarycaps, primarycaps, primarycaps])
    sa = self.LN(sa)
    
    sa = tf.expand_dims(sa, axis=-1)
    sa = sa + self.spatial_attn(sa)
    sa = tf.squeeze(sa, axis=-1)
    
    cap = self.lamb([cap, sa])
    cap = tf.expand_dims(cap, axis=-1)
    cap = cap + self.spatial_attn(cap)
    cap = tf.squeeze(cap, axis=-1)
    
    capsule = self.capsule(cap)
    capsule = tf.expand_dims(capsule, axis=-1)
    capsule = capsule + self.spatial_attn(capsule)
    capsule = tf.squeeze(capsule, axis=-1)
    
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1416
#
#  sequential_1 (Sequential)   (None, 46, 7, 64)         37300
#
#  channel_gate (ChannelGate)  multiple                  4192
#
#  spatial_gate (SpatialGate)  multiple                  102
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  attention (Attention)       multiple                  1
#
#  layer_normalization (LayerN  multiple                 128
#  ormalization)
#
#  lambda_1 (Lambda)           multiple                  0
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  520
#
# =================================================================
# Total params: 93,835
# Trainable params: 93,259
# Non-trainable params: 576
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}_train.npy', 'rb') as f:
    X = np.load(f)
    y = np.load(f)
y = to_categorical(y,num_classes=len(CLASS_LABELS))

with open(f'{DATA_ROOT}/{DATA_PATH}_test.npy', 'rb') as f:
    X_test = np.load(f)
    y_test = np.load(f)
y_test = to_categorical(y_test,num_classes=len(CLASS_LABELS))
    
print(X.shape, y.shape, X_test.shape, y_test.shape)
# Out:
# (1296, 196, 39) (1296, 8) (144, 196, 39) (144, 8)

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_val_acc = []
fold_test_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, val) in tqdm(enumerate(kfold.split(X, y)), desc=f'Training {k}-Fold.....'):
    if i < 7: continue
    
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = X[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_val, y_val = X[val], y[val]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_val = tf.expand_dims(x_val, axis=-1)
    x_test = tf.expand_dims(X_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_val_loss = 0x3f3f3f
    best_val_acc = -1
    best_val_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_val = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        val_loss, val_acc, f1s = [], [], []
        for features, labels in batch_val:
            loss, acc, pred = test_step(model, features, labels)
            val_loss.append(loss)
            val_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1*100)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(val_loss)/len(val_loss)
        val_acc = sum(val_acc)/len(val_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_val_loss:.3f}, Best accuracy:{best_val_acc:.3f}, Best F1-score:{best_val_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_val_loss > val_loss:
            best_val_acc = val_acc
            best_val_loss = val_loss
            best_val_f1 = f1_score
            model.save_weights(h5_path)
            
            
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    
    test_acc, test_f1 = [], []
    for features, labels in batch_test:
        best_pred = model(features, training=False)
        emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(labels, axis=1))
        predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
        
        acc = tf.keras.metrics.CategoricalAccuracy()
        acc.update_state(labels, best_pred)
        accuracy = acc.result().numpy()
        test_acc.append(accuracy*100)
        
        f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
        f1_metric.update_state(labels, best_pred)
        f1 = f1_metric.result().numpy()
        test_f1.append(f1*100)
        
        
        
        
    print('*' * 80)
    print(f'[*] Done Fold-{i+1}')
    print(f'best_val_loss:{best_val_loss:.3f}, best_val_acc:{best_val_acc:.3f}, best_val_f1:{best_val_f1:.3f}')
    print(f'test_acc:{(sum(test_acc)/len(test_acc)):.3f}, test_f1:{(sum(test_f1)/len(test_f1)):.3f}')
    print('*' * 80)
    
    plt.title(f'Fold-{i+1} Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    fold_val_acc.append(best_val_acc)
    fold_test_acc.append((sum(test_acc)/len(test_acc)))
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.631, acc:16.795, val_loss:0.609, val_acc:33.125
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.619, acc:21.947, val_loss:0.604, val_acc:36.250
# Best loss:0.609, Best accuracy:33.125, Best F1-score:29.240
# 3/300 lr=0.00100 - loss:0.610, acc:23.419, val_loss:0.596, val_acc:38.750
# Best loss:0.604, Best accuracy:36.250, Best F1-score:32.500
# 4/300 lr=0.00100 - loss:0.600, acc:26.786, val_loss:0.594, val_acc:38.750
# Best loss:0.596, Best accuracy:38.750, Best F1-score:35.844
# 5/300 lr=0.00100 - loss:0.589, acc:27.679, val_loss:0.574, val_acc:37.500
# Best loss:0.594, Best accuracy:38.750, Best F1-score:34.663
# 6/300 lr=0.00100 - loss:0.582, acc:30.297, val_loss:0.561, val_acc:29.375
# Best loss:0.574, Best accuracy:37.500, Best F1-score:34.390
# 7/300 lr=0.00100 - loss:0.567, acc:34.375, val_loss:0.537, val_acc:44.375
# Best loss:0.561, Best accuracy:29.375, Best F1-score:28.702
# 8/300 lr=0.00100 - loss:0.564, acc:33.325, val_loss:0.533, val_acc:42.500
# Best loss:0.537, Best accuracy:44.375, Best F1-score:41.065
# 9/300 lr=0.00100 - loss:0.550, acc:37.452, val_loss:0.491, val_acc:48.750
# Best loss:0.533, Best accuracy:42.500, Best F1-score:40.233
# 10/300 lr=0.00100 - loss:0.540, acc:37.005, val_loss:0.489, val_acc:48.750
# Best loss:0.491, Best accuracy:48.750, Best F1-score:45.680
# 11/300 lr=0.00100 - loss:0.541, acc:37.307, val_loss:0.478, val_acc:51.250
# Best loss:0.489, Best accuracy:48.750, Best F1-score:45.731
# 12/300 lr=0.00100 - loss:0.534, acc:39.117, val_loss:0.497, val_acc:47.500
# Best loss:0.478, Best accuracy:51.250, Best F1-score:48.951
# 13/300 lr=0.00100 - loss:0.530, acc:38.888, val_loss:0.502, val_acc:25.625
# Best loss:0.478, Best accuracy:51.250, Best F1-score:48.951
# 14/300 lr=0.00100 - loss:0.527, acc:37.729, val_loss:0.450, val_acc:51.250
# Best loss:0.478, Best accuracy:51.250, Best F1-score:48.951
# 15/300 lr=0.00100 - loss:0.526, acc:38.417, val_loss:0.467, val_acc:46.250
# Best loss:0.450, Best accuracy:51.250, Best F1-score:48.294
# 16/300 lr=0.00100 - loss:0.520, acc:39.286, val_loss:0.425, val_acc:52.500
# Best loss:0.450, Best accuracy:51.250, Best F1-score:48.294
# 17/300 lr=0.00100 - loss:0.506, acc:42.833, val_loss:0.482, val_acc:45.625
# Best loss:0.425, Best accuracy:52.500, Best F1-score:49.527
# 18/300 lr=0.00100 - loss:0.503, acc:41.856, val_loss:0.437, val_acc:53.750
# Best loss:0.425, Best accuracy:52.500, Best F1-score:49.527
# 19/300 lr=0.00100 - loss:0.499, acc:43.810, val_loss:0.461, val_acc:41.875
# Best loss:0.425, Best accuracy:52.500, Best F1-score:49.527
# 20/300 lr=0.00100 - loss:0.486, acc:45.391, val_loss:0.427, val_acc:53.125
# Best loss:0.425, Best accuracy:52.500, Best F1-score:49.527
# 21/300 lr=0.00100 - loss:0.480, acc:45.705, val_loss:0.400, val_acc:60.000
# Best loss:0.425, Best accuracy:52.500, Best F1-score:49.527
# 22/300 lr=0.00100 - loss:0.477, acc:47.297, val_loss:0.403, val_acc:55.000
# Best loss:0.400, Best accuracy:60.000, Best F1-score:59.680
# 23/300 lr=0.00100 - loss:0.479, acc:44.631, val_loss:0.433, val_acc:46.250
# Best loss:0.400, Best accuracy:60.000, Best F1-score:59.680
# 24/300 lr=0.00100 - loss:0.472, acc:48.419, val_loss:0.410, val_acc:57.500
# Best loss:0.400, Best accuracy:60.000, Best F1-score:59.680
# 25/300 lr=0.00100 - loss:0.464, acc:48.082, val_loss:0.385, val_acc:55.625
# Best loss:0.400, Best accuracy:60.000, Best F1-score:59.680
# 26/300 lr=0.00100 - loss:0.453, acc:50.072, val_loss:0.360, val_acc:61.250
# Best loss:0.385, Best accuracy:55.625, Best F1-score:53.376
# 27/300 lr=0.00100 - loss:0.456, acc:49.807, val_loss:0.379, val_acc:60.000
# Best loss:0.360, Best accuracy:61.250, Best F1-score:59.705
# 28/300 lr=0.00100 - loss:0.455, acc:49.276, val_loss:0.400, val_acc:61.250
# Best loss:0.360, Best accuracy:61.250, Best F1-score:59.705
# 29/300 lr=0.00100 - loss:0.447, acc:51.388, val_loss:0.346, val_acc:61.250
# Best loss:0.360, Best accuracy:61.250, Best F1-score:59.705
# 30/300 lr=0.00100 - loss:0.438, acc:53.246, val_loss:0.331, val_acc:63.750
# Best loss:0.346, Best accuracy:61.250, Best F1-score:59.462
# 31/300 lr=0.00100 - loss:0.436, acc:52.546, val_loss:0.331, val_acc:64.375
# Best loss:0.331, Best accuracy:63.750, Best F1-score:62.288
# 32/300 lr=0.00100 - loss:0.437, acc:53.656, val_loss:0.345, val_acc:61.875
# Best loss:0.331, Best accuracy:64.375, Best F1-score:62.799
# 33/300 lr=0.00100 - loss:0.428, acc:53.740, val_loss:0.334, val_acc:62.500
# Best loss:0.331, Best accuracy:64.375, Best F1-score:62.799
# 34/300 lr=0.00100 - loss:0.426, acc:53.982, val_loss:0.323, val_acc:62.500
# Best loss:0.331, Best accuracy:64.375, Best F1-score:62.799
# 35/300 lr=0.00100 - loss:0.417, acc:55.140, val_loss:0.327, val_acc:66.250
# Best loss:0.323, Best accuracy:62.500, Best F1-score:60.781
# 36/300 lr=0.00100 - loss:0.416, acc:56.057, val_loss:0.340, val_acc:60.625
# Best loss:0.323, Best accuracy:62.500, Best F1-score:60.781
# 37/300 lr=0.00100 - loss:0.429, acc:53.632, val_loss:0.347, val_acc:63.125
# Best loss:0.323, Best accuracy:62.500, Best F1-score:60.781
# 38/300 lr=0.00100 - loss:0.417, acc:56.081, val_loss:0.337, val_acc:65.000
# Best loss:0.323, Best accuracy:62.500, Best F1-score:60.781
# 39/300 lr=0.00100 - loss:0.411, acc:55.936, val_loss:0.298, val_acc:68.125
# Best loss:0.323, Best accuracy:62.500, Best F1-score:60.781
# 40/300 lr=0.00100 - loss:0.405, acc:57.565, val_loss:0.344, val_acc:61.875
# Best loss:0.298, Best accuracy:68.125, Best F1-score:66.513
# 41/300 lr=0.00100 - loss:0.403, acc:57.444, val_loss:0.305, val_acc:68.125
# Best loss:0.298, Best accuracy:68.125, Best F1-score:66.513
# 42/300 lr=0.00100 - loss:0.400, acc:57.686, val_loss:0.335, val_acc:58.750
# Best loss:0.298, Best accuracy:68.125, Best F1-score:66.513
# 43/300 lr=0.00100 - loss:0.420, acc:56.359, val_loss:0.333, val_acc:61.875
# Best loss:0.298, Best accuracy:68.125, Best F1-score:66.513
# 44/300 lr=0.00100 - loss:0.413, acc:54.669, val_loss:0.314, val_acc:66.250
# Best loss:0.298, Best accuracy:68.125, Best F1-score:66.513
# 45/300 lr=0.00100 - loss:0.391, acc:60.232, val_loss:0.277, val_acc:69.375
# Best loss:0.298, Best accuracy:68.125, Best F1-score:66.513
# 46/300 lr=0.00100 - loss:0.390, acc:60.183, val_loss:0.307, val_acc:65.000
# Best loss:0.277, Best accuracy:69.375, Best F1-score:66.988
# 47/300 lr=0.00100 - loss:0.387, acc:59.689, val_loss:0.315, val_acc:68.750
# Best loss:0.277, Best accuracy:69.375, Best F1-score:66.988
# 48/300 lr=0.00100 - loss:0.386, acc:61.414, val_loss:0.277, val_acc:71.250
# Best loss:0.277, Best accuracy:69.375, Best F1-score:66.988
# 49/300 lr=0.00100 - loss:0.380, acc:60.666, val_loss:0.267, val_acc:71.250
# Best loss:0.277, Best accuracy:71.250, Best F1-score:68.656
# 50/300 lr=0.00100 - loss:0.377, acc:61.486, val_loss:0.268, val_acc:70.625
# Best loss:0.267, Best accuracy:71.250, Best F1-score:70.188
# 51/300 lr=0.00100 - loss:0.372, acc:62.488, val_loss:0.252, val_acc:72.500
# Best loss:0.267, Best accuracy:71.250, Best F1-score:70.188
# 52/300 lr=0.00100 - loss:0.380, acc:59.882, val_loss:0.291, val_acc:68.125
# Best loss:0.252, Best accuracy:72.500, Best F1-score:71.108
# 53/300 lr=0.00100 - loss:0.361, acc:63.091, val_loss:0.246, val_acc:72.500
# Best loss:0.252, Best accuracy:72.500, Best F1-score:71.108
# 54/300 lr=0.00100 - loss:0.349, acc:65.842, val_loss:0.262, val_acc:71.250
# Best loss:0.246, Best accuracy:72.500, Best F1-score:71.386
# 55/300 lr=0.00100 - loss:0.343, acc:66.590, val_loss:0.246, val_acc:71.875
# Best loss:0.246, Best accuracy:72.500, Best F1-score:71.386
# 56/300 lr=0.00100 - loss:0.354, acc:64.624, val_loss:0.244, val_acc:72.500
# Best loss:0.246, Best accuracy:71.875, Best F1-score:70.376
# 57/300 lr=0.00100 - loss:0.343, acc:66.783, val_loss:0.258, val_acc:74.375
# Best loss:0.244, Best accuracy:72.500, Best F1-score:71.151
# 58/300 lr=0.00100 - loss:0.351, acc:64.177, val_loss:0.271, val_acc:71.250
# Best loss:0.214, Best accuracy:75.625, Best F1-score:74.295
# 79/300 lr=0.00086 - loss:0.294, acc:72.985, val_loss:0.207, val_acc:76.250
# Best loss:0.209, Best accuracy:78.125, Best F1-score:77.541
# 80/300 lr=0.00086 - loss:0.272, acc:74.759, val_loss:0.218, val_acc:74.375
# Best loss:0.207, Best accuracy:76.250, Best F1-score:75.021
# 81/300 lr=0.00086 - loss:0.277, acc:76.677, val_loss:0.235, val_acc:73.125
# Best loss:0.207, Best accuracy:76.250, Best F1-score:75.021
# 82/300 lr=0.00074 - loss:0.279, acc:76.074, val_loss:0.221, val_acc:73.125
# Best loss:0.207, Best accuracy:76.250, Best F1-score:75.021
# 83/300 lr=0.00074 - loss:0.284, acc:75.579, val_loss:0.211, val_acc:75.625
# Best loss:0.207, Best accuracy:76.250, Best F1-score:75.021
# 84/300 lr=0.00074 - loss:0.276, acc:76.194, val_loss:0.212, val_acc:76.250
# Best loss:0.207, Best accuracy:76.250, Best F1-score:75.021
# 85/300 lr=0.00074 - loss:0.266, acc:77.063, val_loss:0.225, val_acc:75.625
# Best loss:0.207, Best accuracy:76.250, Best F1-score:75.021
# 86/300 lr=0.00074 - loss:0.271, acc:75.639, val_loss:0.210, val_acc:75.625
# Best loss:0.207, Best accuracy:76.250, Best F1-score:75.021
# 87/300 lr=0.00074 - loss:0.271, acc:76.629, val_loss:0.207, val_acc:79.375
# Best loss:0.207, Best accuracy:76.250, Best F1-score:75.021
# 88/300 lr=0.00074 - loss:0.272, acc:76.653, val_loss:0.234, val_acc:73.750
# Best loss:0.207, Best accuracy:76.250, Best F1-score:75.021
# 89/300 lr=0.00074 - loss:0.272, acc:76.750, val_loss:0.221, val_acc:75.625
# Best loss:0.207, Best accuracy:76.250, Best F1-score:75.021
# 90/300 lr=0.00074 - loss:0.269, acc:76.194, val_loss:0.241, val_acc:70.000
# Best loss:0.207, Best accuracy:76.250, Best F1-score:75.021
# 91/300 lr=0.00074 - loss:0.286, acc:74.843, val_loss:0.245, val_acc:74.375
# Best loss:0.207, Best accuracy:76.250, Best F1-score:75.021
# 92/300 lr=0.00074 - loss:0.272, acc:76.026, val_loss:0.226, val_acc:75.625
# Best loss:0.207, Best accuracy:76.250, Best F1-score:75.021
# 93/300 lr=0.00074 - loss:0.268, acc:77.039, val_loss:0.200, val_acc:75.625
# Best loss:0.207, Best accuracy:76.250, Best F1-score:75.021
# 94/300 lr=0.00074 - loss:0.258, acc:78.559, val_loss:0.220, val_acc:75.000
# Best loss:0.200, Best accuracy:75.625, Best F1-score:74.830
# 95/300 lr=0.00074 - loss:0.266, acc:77.546, val_loss:0.217, val_acc:74.375
# Best loss:0.200, Best accuracy:75.625, Best F1-score:74.830
# 96/300 lr=0.00074 - loss:0.264, acc:77.039, val_loss:0.206, val_acc:76.250
# Best loss:0.200, Best accuracy:75.625, Best F1-score:74.830
# 97/300 lr=0.00074 - loss:0.259, acc:77.823, val_loss:0.206, val_acc:76.875
# Best loss:0.200, Best accuracy:75.625, Best F1-score:74.830
# Best loss:0.180, Best accuracy:78.125, Best F1-score:78.027
# 118/300 lr=0.00064 - loss:0.220, acc:83.736, val_loss:0.193, val_acc:78.125
# Best loss:0.180, Best accuracy:78.125, Best F1-score:78.027
# 119/300 lr=0.00064 - loss:0.221, acc:82.927, val_loss:0.203, val_acc:76.250
# Best loss:0.180, Best accuracy:78.125, Best F1-score:78.027
# 120/300 lr=0.00064 - loss:0.226, acc:82.734, val_loss:0.188, val_acc:78.750
# Best loss:0.180, Best accuracy:78.125, Best F1-score:78.027
# 121/300 lr=0.00064 - loss:0.211, acc:85.147, val_loss:0.187, val_acc:78.125
# Best loss:0.180, Best accuracy:78.125, Best F1-score:78.027
# 122/300 lr=0.00055 - loss:0.211, acc:85.364, val_loss:0.181, val_acc:78.125
# Best loss:0.180, Best accuracy:78.125, Best F1-score:78.027
# 123/300 lr=0.00055 - loss:0.206, acc:84.809, val_loss:0.178, val_acc:78.750
# Best loss:0.180, Best accuracy:78.125, Best F1-score:78.027
# 124/300 lr=0.00055 - loss:0.209, acc:85.292, val_loss:0.162, val_acc:83.750
# Best loss:0.178, Best accuracy:78.750, Best F1-score:78.554
# 125/300 lr=0.00055 - loss:0.210, acc:85.051, val_loss:0.191, val_acc:76.250
# Best loss:0.162, Best accuracy:83.750, Best F1-score:83.446
# 126/300 lr=0.00055 - loss:0.203, acc:86.462, val_loss:0.162, val_acc:82.500
# Best loss:0.162, Best accuracy:83.750, Best F1-score:83.446
# 127/300 lr=0.00055 - loss:0.201, acc:86.523, val_loss:0.188, val_acc:77.500
# Best loss:0.162, Best accuracy:82.500, Best F1-score:82.113
# 128/300 lr=0.00055 - loss:0.210, acc:85.171, val_loss:0.194, val_acc:76.250
# Best loss:0.162, Best accuracy:82.500, Best F1-score:82.113
# 129/300 lr=0.00055 - loss:0.200, acc:87.367, val_loss:0.164, val_acc:78.750
# Best loss:0.162, Best accuracy:82.500, Best F1-score:82.113
# 130/300 lr=0.00055 - loss:0.205, acc:86.269, val_loss:0.179, val_acc:77.500
# Best loss:0.162, Best accuracy:82.500, Best F1-score:82.113
# 131/300 lr=0.00055 - loss:0.187, acc:88.996, val_loss:0.173, val_acc:80.625
# Best loss:0.162, Best accuracy:82.500, Best F1-score:82.113
# 132/300 lr=0.00055 - loss:0.188, acc:87.669, val_loss:0.190, val_acc:79.375
# Best loss:0.162, Best accuracy:82.500, Best F1-score:82.113
# 133/300 lr=0.00055 - loss:0.197, acc:86.076, val_loss:0.173, val_acc:78.750
# Best loss:0.162, Best accuracy:82.500, Best F1-score:82.113
# 134/300 lr=0.00055 - loss:0.193, acc:87.319, val_loss:0.180, val_acc:78.750
# Best loss:0.162, Best accuracy:82.500, Best F1-score:82.113
# 135/300 lr=0.00055 - loss:0.193, acc:87.343, val_loss:0.185, val_acc:78.125
# Best loss:0.162, Best accuracy:82.500, Best F1-score:82.113
# 136/300 lr=0.00055 - loss:0.196, acc:86.523, val_loss:0.203, val_acc:76.250
# Best loss:0.162, Best accuracy:82.500, Best F1-score:82.113
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 236/300 lr=0.00026 - loss:0.141, acc:94.631, val_loss:0.159, val_acc:82.500
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 237/300 lr=0.00026 - loss:0.141, acc:94.824, val_loss:0.168, val_acc:79.375
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 238/300 lr=0.00026 - loss:0.142, acc:94.015, val_loss:0.157, val_acc:83.750
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 239/300 lr=0.00026 - loss:0.139, acc:95.101, val_loss:0.158, val_acc:81.250
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 240/300 lr=0.00026 - loss:0.137, acc:95.439, val_loss:0.176, val_acc:77.500
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 241/300 lr=0.00026 - loss:0.136, acc:95.584, val_loss:0.163, val_acc:80.625
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 242/300 lr=0.00022 - loss:0.134, acc:96.030, val_loss:0.167, val_acc:80.625
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 243/300 lr=0.00022 - loss:0.141, acc:94.570, val_loss:0.150, val_acc:81.875
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 244/300 lr=0.00022 - loss:0.133, acc:96.344, val_loss:0.149, val_acc:81.875
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 245/300 lr=0.00022 - loss:0.135, acc:95.813, val_loss:0.154, val_acc:81.875
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 246/300 lr=0.00022 - loss:0.129, acc:96.875, val_loss:0.167, val_acc:78.750
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 247/300 lr=0.00022 - loss:0.129, acc:96.706, val_loss:0.177, val_acc:78.750
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 248/300 lr=0.00022 - loss:0.134, acc:95.693, val_loss:0.161, val_acc:80.000
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 249/300 lr=0.00022 - loss:0.137, acc:95.162, val_loss:0.150, val_acc:80.625
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 250/300 lr=0.00022 - loss:0.136, acc:95.439, val_loss:0.160, val_acc:79.375
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 251/300 lr=0.00022 - loss:0.134, acc:95.391, val_loss:0.162, val_acc:79.375
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 252/300 lr=0.00022 - loss:0.132, acc:95.837, val_loss:0.153, val_acc:80.625
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 253/300 lr=0.00022 - loss:0.134, acc:95.524, val_loss:0.155, val_acc:81.250
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 254/300 lr=0.00022 - loss:0.131, acc:96.260, val_loss:0.144, val_acc:83.750
# Best loss:0.145, Best accuracy:85.625, Best F1-score:85.148
# 255/300 lr=0.00022 - loss:0.134, acc:95.946, val_loss:0.156, val_acc:80.000
# Best loss:0.144, Best accuracy:83.750, Best F1-score:83.133
# 256/300 lr=0.00022 - loss:0.133, acc:95.837, val_loss:0.161, val_acc:80.625
# Best loss:0.144, Best accuracy:83.750, Best F1-score:83.133
# 257/300 lr=0.00022 - loss:0.131, acc:96.284, val_loss:0.155, val_acc:82.500
# Best loss:0.144, Best accuracy:83.750, Best F1-score:83.133
# 258/300 lr=0.00022 - loss:0.130, acc:96.175, val_loss:0.151, val_acc:82.500
# Best loss:0.144, Best accuracy:83.750, Best F1-score:83.133
# 259/300 lr=0.00022 - loss:0.131, acc:96.115, val_loss:0.158, val_acc:80.625
# Best loss:0.144, Best accuracy:83.750, Best F1-score:83.133
# 260/300 lr=0.00022 - loss:0.134, acc:95.693, val_loss:0.139, val_acc:81.250
# Best loss:0.144, Best accuracy:83.750, Best F1-score:83.133
# 261/300 lr=0.00022 - loss:0.135, acc:95.693, val_loss:0.167, val_acc:82.500
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 262/300 lr=0.00019 - loss:0.128, acc:96.284, val_loss:0.149, val_acc:83.750
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 283/300 lr=0.00017 - loss:0.127, acc:96.742, val_loss:0.167, val_acc:78.750
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 284/300 lr=0.00017 - loss:0.128, acc:96.791, val_loss:0.160, val_acc:81.250
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 285/300 lr=0.00017 - loss:0.127, acc:97.128, val_loss:0.160, val_acc:80.625
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 286/300 lr=0.00017 - loss:0.132, acc:95.837, val_loss:0.158, val_acc:80.625
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 287/300 lr=0.00017 - loss:0.125, acc:97.466, val_loss:0.172, val_acc:81.875
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 288/300 lr=0.00017 - loss:0.128, acc:96.284, val_loss:0.169, val_acc:79.375
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 289/300 lr=0.00017 - loss:0.130, acc:96.537, val_loss:0.152, val_acc:83.125
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 290/300 lr=0.00017 - loss:0.129, acc:96.706, val_loss:0.162, val_acc:78.125
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 291/300 lr=0.00017 - loss:0.123, acc:97.382, val_loss:0.151, val_acc:82.500
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 292/300 lr=0.00017 - loss:0.124, acc:97.804, val_loss:0.179, val_acc:79.375
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 293/300 lr=0.00017 - loss:0.128, acc:96.622, val_loss:0.159, val_acc:80.625
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 294/300 lr=0.00017 - loss:0.127, acc:97.189, val_loss:0.180, val_acc:78.125
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 295/300 lr=0.00017 - loss:0.132, acc:96.284, val_loss:0.173, val_acc:80.000
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 296/300 lr=0.00017 - loss:0.127, acc:96.706, val_loss:0.170, val_acc:79.375
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 297/300 lr=0.00017 - loss:0.123, acc:97.213, val_loss:0.160, val_acc:80.625
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 298/300 lr=0.00017 - loss:0.122, acc:97.466, val_loss:0.158, val_acc:81.875
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 299/300 lr=0.00017 - loss:0.126, acc:96.911, val_loss:0.166, val_acc:81.875
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# 300/300 lr=0.00017 - loss:0.126, acc:96.513, val_loss:0.169, val_acc:78.125
# Best loss:0.139, Best accuracy:81.250, Best F1-score:80.634
# ********************************************************************************
# [*] Done Fold-1
# best_val_loss:0.139, best_val_acc:81.250, best_val_f1:80.634
# test_acc:85.625, test_f1:84.868
# ********************************************************************************
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.631, acc:18.871, val_loss:0.617, val_acc:30.625
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.616, acc:21.284, val_loss:0.596, val_acc:28.125
# Best loss:0.617, Best accuracy:30.625, Best F1-score:25.087
# 3/300 lr=0.00100 - loss:0.605, acc:25.036, val_loss:0.583, val_acc:41.250
# Best loss:0.596, Best accuracy:28.125, Best F1-score:24.406
# 4/300 lr=0.00100 - loss:0.596, acc:27.377, val_loss:0.565, val_acc:42.500
# Best loss:0.583, Best accuracy:41.250, Best F1-score:38.762
# 5/300 lr=0.00100 - loss:0.590, acc:28.161, val_loss:0.562, val_acc:42.500
# Best loss:0.565, Best accuracy:42.500, Best F1-score:39.660
# 6/300 lr=0.00100 - loss:0.578, acc:30.526, val_loss:0.527, val_acc:47.500
# Best loss:0.562, Best accuracy:42.500, Best F1-score:39.181
# 7/300 lr=0.00100 - loss:0.573, acc:32.505, val_loss:0.557, val_acc:43.750
# Best loss:0.527, Best accuracy:47.500, Best F1-score:43.659
# 8/300 lr=0.00100 - loss:0.566, acc:32.046, val_loss:0.521, val_acc:48.750
# Best loss:0.527, Best accuracy:47.500, Best F1-score:43.659
# 9/300 lr=0.00100 - loss:0.558, acc:34.833, val_loss:0.503, val_acc:51.250
# Best loss:0.521, Best accuracy:48.750, Best F1-score:42.199
# 10/300 lr=0.00100 - loss:0.540, acc:37.307, val_loss:0.487, val_acc:45.000
# Best loss:0.503, Best accuracy:51.250, Best F1-score:46.141
# 11/300 lr=0.00100 - loss:0.531, acc:38.127, val_loss:0.465, val_acc:55.000
# Best loss:0.487, Best accuracy:45.000, Best F1-score:41.352
# 12/300 lr=0.00100 - loss:0.517, acc:40.758, val_loss:0.460, val_acc:55.625
# Best loss:0.465, Best accuracy:55.000, Best F1-score:51.747
# 13/300 lr=0.00100 - loss:0.520, acc:39.479, val_loss:0.442, val_acc:48.750
# Best loss:0.460, Best accuracy:55.625, Best F1-score:54.716
# 14/300 lr=0.00100 - loss:0.519, acc:39.913, val_loss:0.460, val_acc:45.000
# Best loss:0.442, Best accuracy:48.750, Best F1-score:46.654
# 15/300 lr=0.00100 - loss:0.509, acc:41.554, val_loss:0.428, val_acc:55.000
# Best loss:0.442, Best accuracy:48.750, Best F1-score:46.654
# 16/300 lr=0.00100 - loss:0.495, acc:42.942, val_loss:0.435, val_acc:50.625
# Best loss:0.428, Best accuracy:55.000, Best F1-score:53.743
# 17/300 lr=0.00100 - loss:0.493, acc:43.967, val_loss:0.426, val_acc:54.375
# Best loss:0.428, Best accuracy:55.000, Best F1-score:53.743
# 18/300 lr=0.00100 - loss:0.482, acc:44.932, val_loss:0.425, val_acc:60.625
# Best loss:0.426, Best accuracy:54.375, Best F1-score:52.220
# 19/300 lr=0.00100 - loss:0.475, acc:47.237, val_loss:0.393, val_acc:60.000
# Best loss:0.425, Best accuracy:60.625, Best F1-score:59.485
# 20/300 lr=0.00100 - loss:0.466, acc:49.288, val_loss:0.409, val_acc:51.875
# Best loss:0.393, Best accuracy:60.000, Best F1-score:59.952
# 21/300 lr=0.00100 - loss:0.465, acc:48.516, val_loss:0.405, val_acc:48.750
# Best loss:0.393, Best accuracy:60.000, Best F1-score:59.952
# 22/300 lr=0.00100 - loss:0.465, acc:47.889, val_loss:0.404, val_acc:51.875
# Best loss:0.393, Best accuracy:60.000, Best F1-score:59.952
# 23/300 lr=0.00100 - loss:0.458, acc:50.627, val_loss:0.371, val_acc:66.875
# Best loss:0.393, Best accuracy:60.000, Best F1-score:59.952
# 24/300 lr=0.00100 - loss:0.448, acc:51.882, val_loss:0.382, val_acc:55.625
# Best loss:0.371, Best accuracy:66.875, Best F1-score:65.359
# 25/300 lr=0.00100 - loss:0.455, acc:48.685, val_loss:0.394, val_acc:51.250
# Best loss:0.371, Best accuracy:66.875, Best F1-score:65.359
# 26/300 lr=0.00100 - loss:0.439, acc:52.522, val_loss:0.380, val_acc:51.250
# Best loss:0.371, Best accuracy:66.875, Best F1-score:65.359
# 27/300 lr=0.00100 - loss:0.444, acc:51.194, val_loss:0.352, val_acc:63.750
# Best loss:0.371, Best accuracy:66.875, Best F1-score:65.359
# 28/300 lr=0.00100 - loss:0.441, acc:53.330, val_loss:0.371, val_acc:55.000
# Best loss:0.352, Best accuracy:63.750, Best F1-score:63.093
# 29/300 lr=0.00100 - loss:0.433, acc:53.849, val_loss:0.346, val_acc:55.625
# Best loss:0.352, Best accuracy:63.750, Best F1-score:63.093
# 30/300 lr=0.00100 - loss:0.442, acc:52.425, val_loss:0.406, val_acc:54.375
# Best loss:0.346, Best accuracy:55.625, Best F1-score:55.444
# 31/300 lr=0.00100 - loss:0.424, acc:55.357, val_loss:0.373, val_acc:55.625
# Best loss:0.346, Best accuracy:55.625, Best F1-score:55.444
# 32/300 lr=0.00100 - loss:0.423, acc:55.188, val_loss:0.394, val_acc:51.875
# Best loss:0.346, Best accuracy:55.625, Best F1-score:55.444
# 33/300 lr=0.00100 - loss:0.419, acc:55.212, val_loss:0.331, val_acc:66.875
# Best loss:0.346, Best accuracy:55.625, Best F1-score:55.444
# 34/300 lr=0.00100 - loss:0.418, acc:55.236, val_loss:0.347, val_acc:56.250
# Best loss:0.331, Best accuracy:66.875, Best F1-score:65.234
# 35/300 lr=0.00100 - loss:0.421, acc:54.500, val_loss:0.433, val_acc:41.875
# Best loss:0.331, Best accuracy:66.875, Best F1-score:65.234
# 36/300 lr=0.00100 - loss:0.432, acc:53.318, val_loss:0.375, val_acc:55.000
# Best loss:0.331, Best accuracy:66.875, Best F1-score:65.234
# 37/300 lr=0.00100 - loss:0.417, acc:54.223, val_loss:0.361, val_acc:58.750
# Best loss:0.331, Best accuracy:66.875, Best F1-score:65.234
# 38/300 lr=0.00100 - loss:0.401, acc:58.579, val_loss:0.345, val_acc:58.750
# Best loss:0.331, Best accuracy:66.875, Best F1-score:65.234
# 39/300 lr=0.00100 - loss:0.396, acc:59.025, val_loss:0.327, val_acc:55.000
# Best loss:0.331, Best accuracy:66.875, Best F1-score:65.234
# 40/300 lr=0.00100 - loss:0.393, acc:59.001, val_loss:0.411, val_acc:54.375
# Best loss:0.327, Best accuracy:55.000, Best F1-score:53.264
# 41/300 lr=0.00100 - loss:0.398, acc:58.820, val_loss:0.319, val_acc:66.875
# Best loss:0.327, Best accuracy:55.000, Best F1-score:53.264
# 42/300 lr=0.00100 - loss:0.386, acc:61.643, val_loss:0.292, val_acc:70.625
# Best loss:0.319, Best accuracy:66.875, Best F1-score:65.493
# 43/300 lr=0.00100 - loss:0.390, acc:59.146, val_loss:0.308, val_acc:66.250
# Best loss:0.292, Best accuracy:70.625, Best F1-score:70.115
# 44/300 lr=0.00100 - loss:0.397, acc:58.856, val_loss:0.347, val_acc:54.375
# Best loss:0.292, Best accuracy:70.625, Best F1-score:70.115
# 45/300 lr=0.00100 - loss:0.384, acc:59.484, val_loss:0.348, val_acc:56.250
# Best loss:0.292, Best accuracy:70.625, Best F1-score:70.115
# 46/300 lr=0.00100 - loss:0.388, acc:60.075, val_loss:0.314, val_acc:58.125
# Best loss:0.292, Best accuracy:70.625, Best F1-score:70.115
# 47/300 lr=0.00100 - loss:0.374, acc:60.944, val_loss:0.341, val_acc:54.375
# Best loss:0.292, Best accuracy:70.625, Best F1-score:70.115
# 48/300 lr=0.00100 - loss:0.376, acc:60.883, val_loss:0.307, val_acc:60.000
# Best loss:0.292, Best accuracy:70.625, Best F1-score:70.115
# 49/300 lr=0.00100 - loss:0.365, acc:62.464, val_loss:0.316, val_acc:58.750
# Best loss:0.292, Best accuracy:70.625, Best F1-score:70.115
# 50/300 lr=0.00100 - loss:0.371, acc:64.141, val_loss:0.333, val_acc:58.125
# Best loss:0.292, Best accuracy:70.625, Best F1-score:70.115
# 51/300 lr=0.00100 - loss:0.364, acc:63.875, val_loss:0.316, val_acc:63.125
# Best loss:0.292, Best accuracy:70.625, Best F1-score:70.115
# 52/300 lr=0.00100 - loss:0.364, acc:62.633, val_loss:0.345, val_acc:58.750
# ...
# 269/300 lr=0.00019 - loss:0.129, acc:96.959, val_loss:0.311, val_acc:63.125
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 270/300 lr=0.00019 - loss:0.130, acc:96.273, val_loss:0.369, val_acc:61.875
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 271/300 lr=0.00019 - loss:0.132, acc:96.695, val_loss:0.227, val_acc:64.375
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 272/300 lr=0.00019 - loss:0.130, acc:96.706, val_loss:0.331, val_acc:63.125
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 273/300 lr=0.00019 - loss:0.123, acc:97.044, val_loss:0.304, val_acc:63.750
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 274/300 lr=0.00019 - loss:0.128, acc:96.875, val_loss:0.348, val_acc:66.250
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 275/300 lr=0.00019 - loss:0.123, acc:97.202, val_loss:0.313, val_acc:65.625
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 276/300 lr=0.00019 - loss:0.127, acc:97.128, val_loss:0.367, val_acc:59.375
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 277/300 lr=0.00019 - loss:0.130, acc:96.537, val_loss:0.331, val_acc:63.750
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 278/300 lr=0.00019 - loss:0.127, acc:96.177, val_loss:0.302, val_acc:60.625
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 279/300 lr=0.00019 - loss:0.123, acc:97.213, val_loss:0.339, val_acc:63.125
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 280/300 lr=0.00019 - loss:0.125, acc:97.286, val_loss:0.342, val_acc:64.375
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 281/300 lr=0.00019 - loss:0.128, acc:96.622, val_loss:0.363, val_acc:64.375
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 282/300 lr=0.00017 - loss:0.125, acc:96.948, val_loss:0.333, val_acc:64.375
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 283/300 lr=0.00017 - loss:0.127, acc:97.297, val_loss:0.296, val_acc:63.750
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 284/300 lr=0.00017 - loss:0.130, acc:96.199, val_loss:0.279, val_acc:63.750
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 285/300 lr=0.00017 - loss:0.124, acc:97.455, val_loss:0.288, val_acc:66.875
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 286/300 lr=0.00017 - loss:0.128, acc:97.213, val_loss:0.342, val_acc:65.000
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 287/300 lr=0.00017 - loss:0.121, acc:96.959, val_loss:0.317, val_acc:65.625
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 288/300 lr=0.00017 - loss:0.126, acc:96.875, val_loss:0.353, val_acc:65.625
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 289/300 lr=0.00017 - loss:0.129, acc:96.503, val_loss:0.330, val_acc:65.625
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 290/300 lr=0.00017 - loss:0.120, acc:97.551, val_loss:0.359, val_acc:63.750
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 291/300 lr=0.00017 - loss:0.125, acc:96.875, val_loss:0.288, val_acc:65.625
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 292/300 lr=0.00017 - loss:0.130, acc:96.368, val_loss:0.374, val_acc:63.125
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 293/300 lr=0.00017 - loss:0.124, acc:97.128, val_loss:0.340, val_acc:65.625
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 294/300 lr=0.00017 - loss:0.124, acc:97.539, val_loss:0.339, val_acc:65.625
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 295/300 lr=0.00017 - loss:0.124, acc:97.466, val_loss:0.348, val_acc:65.625
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 296/300 lr=0.00017 - loss:0.125, acc:97.213, val_loss:0.339, val_acc:65.000
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 297/300 lr=0.00017 - loss:0.123, acc:96.695, val_loss:0.333, val_acc:66.875
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 298/300 lr=0.00017 - loss:0.123, acc:97.213, val_loss:0.372, val_acc:63.750
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 299/300 lr=0.00017 - loss:0.122, acc:97.635, val_loss:0.324, val_acc:62.500
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# 300/300 lr=0.00017 - loss:0.124, acc:97.202, val_loss:0.341, val_acc:63.750
# Best loss:0.153, Best accuracy:83.125, Best F1-score:83.045
# ********************************************************************************
# [*] Done Fold-7
# best_val_loss:0.153, best_val_acc:83.125, best_val_f1:83.045
# test_acc:84.375, test_f1:84.068
# ********************************************************************************
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.634, acc:15.310, val_loss:0.633, val_acc:20.000
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.618, acc:21.898, val_loss:0.600, val_acc:41.875
# Best loss:0.633, Best accuracy:20.000, Best F1-score:14.208
# 3/300 lr=0.00100 - loss:0.609, acc:23.367, val_loss:0.597, val_acc:26.250
# Best loss:0.600, Best accuracy:41.875, Best F1-score:35.775
# 4/300 lr=0.00100 - loss:0.595, acc:28.446, val_loss:0.580, val_acc:27.500
# Best loss:0.597, Best accuracy:26.250, Best F1-score:21.751
# 5/300 lr=0.00100 - loss:0.589, acc:27.370, val_loss:0.570, val_acc:21.250
# Best loss:0.580, Best accuracy:27.500, Best F1-score:19.901
# 6/300 lr=0.00100 - loss:0.581, acc:29.234, val_loss:0.559, val_acc:27.500
# Best loss:0.570, Best accuracy:21.250, Best F1-score:14.715
# 7/300 lr=0.00100 - loss:0.565, acc:34.223, val_loss:0.555, val_acc:46.250
# Best loss:0.559, Best accuracy:27.500, Best F1-score:22.974
# 8/300 lr=0.00100 - loss:0.559, acc:33.829, val_loss:0.516, val_acc:49.375
# Best loss:0.555, Best accuracy:46.250, Best F1-score:42.768
# 9/300 lr=0.00100 - loss:0.556, acc:35.034, val_loss:0.511, val_acc:50.000
# Best loss:0.516, Best accuracy:49.375, Best F1-score:43.361
# 10/300 lr=0.00100 - loss:0.548, acc:36.819, val_loss:0.562, val_acc:29.375
# Best loss:0.511, Best accuracy:50.000, Best F1-score:46.590
# 11/300 lr=0.00100 - loss:0.547, acc:35.372, val_loss:0.483, val_acc:51.875
# Best loss:0.511, Best accuracy:50.000, Best F1-score:46.590
# 12/300 lr=0.00100 - loss:0.537, acc:37.145, val_loss:0.504, val_acc:50.000
# Best loss:0.483, Best accuracy:51.875, Best F1-score:49.128
# 13/300 lr=0.00100 - loss:0.527, acc:39.510, val_loss:0.442, val_acc:51.250
# Best loss:0.483, Best accuracy:51.875, Best F1-score:49.128
# 14/300 lr=0.00100 - loss:0.516, acc:40.293, val_loss:0.447, val_acc:51.250
# Best loss:0.442, Best accuracy:51.250, Best F1-score:47.397
# 35/300 lr=0.00100 - loss:0.421, acc:55.456, val_loss:0.319, val_acc:61.250
# Best loss:0.321, Best accuracy:65.000, Best F1-score:63.217
# 36/300 lr=0.00100 - loss:0.419, acc:55.158, val_loss:0.372, val_acc:56.250
# Best loss:0.319, Best accuracy:61.250, Best F1-score:60.985
# 37/300 lr=0.00100 - loss:0.439, acc:53.035, val_loss:0.339, val_acc:61.250
# Best loss:0.319, Best accuracy:61.250, Best F1-score:60.985
# 38/300 lr=0.00100 - loss:0.427, acc:53.542, val_loss:0.307, val_acc:65.625
# Best loss:0.319, Best accuracy:61.250, Best F1-score:60.985
# 39/300 lr=0.00100 - loss:0.409, acc:57.511, val_loss:0.340, val_acc:64.375
# Best loss:0.307, Best accuracy:65.625, Best F1-score:63.011
# 40/300 lr=0.00100 - loss:0.402, acc:57.669, val_loss:0.296, val_acc:69.375
# Best loss:0.307, Best accuracy:65.625, Best F1-score:63.011
# 41/300 lr=0.00100 - loss:0.385, acc:61.588, val_loss:0.327, val_acc:68.750
# Best loss:0.296, Best accuracy:69.375, Best F1-score:68.760
# 42/300 lr=0.00100 - loss:0.396, acc:58.474, val_loss:0.347, val_acc:65.625
# Best loss:0.296, Best accuracy:69.375, Best F1-score:68.760
# 43/300 lr=0.00100 - loss:0.400, acc:57.995, val_loss:0.437, val_acc:43.750
# Best loss:0.296, Best accuracy:69.375, Best F1-score:68.760
# 44/300 lr=0.00100 - loss:0.387, acc:60.659, val_loss:0.307, val_acc:64.375
# Best loss:0.296, Best accuracy:69.375, Best F1-score:68.760
# 45/300 lr=0.00100 - loss:0.385, acc:60.079, val_loss:0.305, val_acc:63.750
# Best loss:0.296, Best accuracy:69.375, Best F1-score:68.760
# 46/300 lr=0.00100 - loss:0.379, acc:61.453, val_loss:0.295, val_acc:68.125
# Best loss:0.296, Best accuracy:69.375, Best F1-score:68.760
# 47/300 lr=0.00100 - loss:0.380, acc:60.698, val_loss:0.302, val_acc:65.625
# Best loss:0.295, Best accuracy:68.125, Best F1-score:65.952
# 48/300 lr=0.00100 - loss:0.374, acc:62.337, val_loss:0.298, val_acc:67.500
# Best loss:0.295, Best accuracy:68.125, Best F1-score:65.952
# 49/300 lr=0.00100 - loss:0.362, acc:63.953, val_loss:0.270, val_acc:70.000
# Best loss:0.295, Best accuracy:68.125, Best F1-score:65.952
# 50/300 lr=0.00100 - loss:0.371, acc:63.131, val_loss:0.265, val_acc:75.000
# Best loss:0.270, Best accuracy:70.000, Best F1-score:69.777
# 51/300 lr=0.00100 - loss:0.363, acc:62.624, val_loss:0.291, val_acc:70.625
# Best loss:0.265, Best accuracy:75.000, Best F1-score:74.179
# 52/300 lr=0.00100 - loss:0.358, acc:63.699, val_loss:0.310, val_acc:67.500
# Best loss:0.265, Best accuracy:75.000, Best F1-score:74.179
# 53/300 lr=0.00100 - loss:0.352, acc:65.231, val_loss:0.287, val_acc:70.625
# Best loss:0.265, Best accuracy:75.000, Best F1-score:74.179
# 54/300 lr=0.00100 - loss:0.353, acc:65.411, val_loss:0.321, val_acc:51.250
# 74/300 lr=0.00086 - loss:0.292, acc:73.001, val_loss:0.251, val_acc:77.500
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.580
# 75/300 lr=0.00086 - loss:0.294, acc:73.086, val_loss:0.250, val_acc:75.000
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.580
# 76/300 lr=0.00086 - loss:0.283, acc:75.158, val_loss:0.329, val_acc:55.000
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.580
# 77/300 lr=0.00086 - loss:0.278, acc:76.149, val_loss:0.338, val_acc:51.875
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.580
# 78/300 lr=0.00086 - loss:0.287, acc:73.964, val_loss:0.236, val_acc:76.250
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.580
# 79/300 lr=0.00086 - loss:0.285, acc:75.726, val_loss:0.214, val_acc:76.875
# Best loss:0.236, Best accuracy:76.250, Best F1-score:75.971
# 80/300 lr=0.00086 - loss:0.278, acc:75.800, val_loss:0.265, val_acc:76.250
# Best loss:0.214, Best accuracy:76.875, Best F1-score:77.324
# 81/300 lr=0.00086 - loss:0.279, acc:75.135, val_loss:0.274, val_acc:75.625
# Best loss:0.214, Best accuracy:76.875, Best F1-score:77.324
# 82/300 lr=0.00074 - loss:0.273, acc:74.617, val_loss:0.213, val_acc:76.250
# Best loss:0.214, Best accuracy:76.875, Best F1-score:77.324
# 83/300 lr=0.00074 - loss:0.281, acc:74.966, val_loss:0.232, val_acc:71.250
# Best loss:0.213, Best accuracy:76.250, Best F1-score:76.631
# 84/300 lr=0.00074 - loss:0.290, acc:73.508, val_loss:0.263, val_acc:72.500
# Best loss:0.213, Best accuracy:76.250, Best F1-score:76.631

# %%
end()

# %%
print('*' * 80)
print('[*] validation accuracy')
for i, val_acc in enumerate(fold_val_acc):
    print(f'    Fold-{i+1} : {val_acc}')
print(f'max:{max(fold_val_acc)}, min:{min(fold_val_acc)}, average:{sum(fold_val_acc)/len(fold_val_acc)}')
print('*' * 80)
print()

print('*' * 80)
print('[*] test accuracy')
for i, test_acc in enumerate(fold_test_acc):
    print(f'    Fold-{i+1} : {test_acc}')
print(f'max:{max(fold_test_acc)}, min:{min(fold_test_acc)}, average:{sum(fold_test_acc)/len(fold_test_acc)}')
print('*' * 80)
print()

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
