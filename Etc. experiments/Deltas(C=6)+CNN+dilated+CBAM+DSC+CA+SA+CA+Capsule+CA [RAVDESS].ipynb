# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = 'TIMNET-dataset'
DATA_PATH = 'RAVDESS_deltas'
CLASS_LABELS = Config.RAVDESS_LABELS
k = 10

# (196,39,6)  ## CA: Channel-attention    ## SA : Self-attention 
# DSC : Depthwise-seperable CNN
model_name = 'Deltas(C=6)+CNN+dilated+CBAM+DSC+CA+SA+CA+Capsule+CA'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding=padding),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule]),
        Lambda(function=PrimaryCapssquash)
    ])
    
  def call(self, inputs):
    return self.conv(inputs)

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.cbam = CBAM(64) # sharing
    
    self.primarycap = PrimaryCap()
    self.spatial_attn = SpatialGate()
    
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    x = inputs
    
    cap = self.conv1(x)
    cap = cap + self.cbam(cap)
    cap = self.conv2(cap)
    cap = cap + self.cbam(cap)
    
    primarycaps = self.primarycap(cap)
    primarycaps = tf.expand_dims(primarycaps, axis=-1)
    primarycaps = primarycaps + self.spatial_attn(primarycaps)
    primarycaps = tf.squeeze(primarycaps, axis=-1)
    
    cap = primarycaps
    
    sa = self.attention([primarycaps, primarycaps, primarycaps])
    sa = self.LN(sa)
    
    sa = tf.expand_dims(sa, axis=-1)
    sa = sa + self.spatial_attn(sa)
    sa = tf.squeeze(sa, axis=-1)
    
    cap = self.lamb([cap, sa])
    cap = tf.expand_dims(cap, axis=-1)
    cap = cap + self.spatial_attn(cap)
    cap = tf.squeeze(cap, axis=-1)
    
    capsule = self.capsule(cap)
    capsule = tf.expand_dims(capsule, axis=-1)
    capsule = capsule + self.spatial_attn(capsule)
    capsule = tf.squeeze(capsule, axis=-1)
    
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1416
#
#  sequential_1 (Sequential)   (None, 46, 7, 64)         37300
#
#  cbam (CBAM)                 multiple                  4294
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  spatial_gate_1 (SpatialGate  multiple                 102
#  )
#
#  attention (Attention)       multiple                  1
#
#  layer_normalization (LayerN  multiple                 128
#  ormalization)
#
#  lambda_1 (Lambda)           multiple                  0
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  520
#
# =================================================================
# Total params: 93,937
# Trainable params: 93,359
# Non-trainable params: 578
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}.npy', 'rb') as f:
    X = np.load(f)
    y = np.load(f)
y = to_categorical(y,num_classes=len(CLASS_LABELS))
    
print(X.shape, y.shape)
# Out:
# (1440, 196, 39, 6) (1440, 8)

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_val_acc = []
fold_test_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, val) in tqdm(enumerate(kfold.split(X, y)), desc=f'Training {k}-Fold.....'):
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = X[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_val, y_val = X[val], y[val]
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_val_loss = 0x3f3f3f
    best_val_acc = -1
    best_val_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_val = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        val_loss, val_acc, f1s = [], [], []
        for features, labels in batch_val:
            loss, acc, pred = test_step(model, features, labels)
            val_loss.append(loss)
            val_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1*100)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(val_loss)/len(val_loss)
        val_acc = sum(val_acc)/len(val_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_val_loss:.3f}, Best accuracy:{best_val_acc:.3f}, Best F1-score:{best_val_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_val_loss > val_loss:
            best_val_acc = val_acc
            best_val_loss = val_loss
            best_val_f1 = f1_score
            model.save_weights(h5_path)
            
    
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    
    test_acc, test_f1 = [], []
    for features, labels in batch_val:
        best_pred = model(features, training=False)
        emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(labels, axis=1))
        predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
        
        acc = tf.keras.metrics.CategoricalAccuracy()
        acc.update_state(labels, best_pred)
        accuracy = acc.result().numpy()
        test_acc.append(accuracy*100)
        
        f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
        f1_metric.update_state(labels, best_pred)
        f1 = f1_metric.result().numpy()
        test_f1.append(f1*100)
        
        
        
        
    print('*' * 80)
    print(f'[*] Done Fold-{i+1}')
    print(f'best_val_loss:{best_val_loss:.3f}, best_val_acc:{best_val_acc:.3f}, best_val_f1:{best_val_f1:.3f}')
    print(f'test_acc:{(sum(test_acc)/len(test_acc)):.3f}, test_f1:{(sum(test_f1)/len(test_f1)):.3f}')
    print('*' * 80)
    
    plt.title(f'Fold-{i+1} Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    fold_val_acc.append(best_val_acc)
    fold_test_acc.append((sum(test_acc)/len(test_acc)))
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.629, acc:17.226, val_loss:0.631, val_acc:18.750
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.613, acc:23.018, val_loss:0.621, val_acc:22.500
# Best loss:0.631, Best accuracy:18.750, Best F1-score:12.473
# 3/300 lr=0.00100 - loss:0.598, acc:27.515, val_loss:0.629, val_acc:20.000
# Best loss:0.621, Best accuracy:22.500, Best F1-score:17.426
# 4/300 lr=0.00100 - loss:0.594, acc:25.762, val_loss:0.600, val_acc:27.500
# Best loss:0.621, Best accuracy:22.500, Best F1-score:17.426
# 5/300 lr=0.00100 - loss:0.585, acc:30.107, val_loss:0.590, val_acc:25.625
# Best loss:0.600, Best accuracy:27.500, Best F1-score:23.133
# 6/300 lr=0.00100 - loss:0.576, acc:29.802, val_loss:0.572, val_acc:28.125
# Best loss:0.590, Best accuracy:25.625, Best F1-score:20.954
# 7/300 lr=0.00100 - loss:0.565, acc:32.317, val_loss:0.553, val_acc:34.375
# Best loss:0.572, Best accuracy:28.125, Best F1-score:23.738
# 8/300 lr=0.00100 - loss:0.557, acc:34.680, val_loss:0.562, val_acc:27.500
# Best loss:0.553, Best accuracy:34.375, Best F1-score:28.644
# 9/300 lr=0.00100 - loss:0.549, acc:34.909, val_loss:0.539, val_acc:33.125
# Best loss:0.553, Best accuracy:34.375, Best F1-score:28.644
# 10/300 lr=0.00100 - loss:0.538, acc:36.280, val_loss:0.535, val_acc:37.500
# Best loss:0.539, Best accuracy:33.125, Best F1-score:25.312
# 11/300 lr=0.00100 - loss:0.537, acc:38.034, val_loss:0.548, val_acc:32.500
# Best loss:0.535, Best accuracy:37.500, Best F1-score:33.382
# 12/300 lr=0.00100 - loss:0.533, acc:37.119, val_loss:0.529, val_acc:38.125
# Best loss:0.535, Best accuracy:37.500, Best F1-score:33.382
# 13/300 lr=0.00100 - loss:0.520, acc:40.473, val_loss:0.533, val_acc:39.375
# Best loss:0.529, Best accuracy:38.125, Best F1-score:30.647
# 14/300 lr=0.00100 - loss:0.510, acc:40.625, val_loss:0.518, val_acc:40.000
# Best loss:0.529, Best accuracy:38.125, Best F1-score:30.647
# 15/300 lr=0.00100 - loss:0.510, acc:42.302, val_loss:0.522, val_acc:38.750
# Best loss:0.518, Best accuracy:40.000, Best F1-score:35.410
# 16/300 lr=0.00100 - loss:0.512, acc:42.530, val_loss:0.487, val_acc:41.875
# Best loss:0.518, Best accuracy:40.000, Best F1-score:35.410
# 17/300 lr=0.00100 - loss:0.507, acc:42.302, val_loss:0.498, val_acc:41.875
# Best loss:0.487, Best accuracy:41.875, Best F1-score:37.261
# 18/300 lr=0.00100 - loss:0.492, acc:44.970, val_loss:0.473, val_acc:43.750
# Best loss:0.487, Best accuracy:41.875, Best F1-score:37.261
# 19/300 lr=0.00100 - loss:0.477, acc:48.171, val_loss:0.481, val_acc:41.875
# Best loss:0.473, Best accuracy:43.750, Best F1-score:36.973
# 20/300 lr=0.00100 - loss:0.474, acc:47.104, val_loss:0.484, val_acc:41.250
# Best loss:0.473, Best accuracy:43.750, Best F1-score:36.973
# 21/300 lr=0.00100 - loss:0.472, acc:48.171, val_loss:0.468, val_acc:45.000
# Best loss:0.473, Best accuracy:43.750, Best F1-score:36.973
# 22/300 lr=0.00100 - loss:0.472, acc:47.180, val_loss:0.477, val_acc:43.750
# Best loss:0.468, Best accuracy:45.000, Best F1-score:39.858
# 23/300 lr=0.00100 - loss:0.463, acc:48.857, val_loss:0.472, val_acc:41.875
# Best loss:0.468, Best accuracy:45.000, Best F1-score:39.858
# 24/300 lr=0.00100 - loss:0.458, acc:47.866, val_loss:0.461, val_acc:45.625
# Best loss:0.468, Best accuracy:45.000, Best F1-score:39.858
# 25/300 lr=0.00100 - loss:0.452, acc:51.220, val_loss:0.509, val_acc:41.250
# Best loss:0.461, Best accuracy:45.625, Best F1-score:39.672
# 26/300 lr=0.00100 - loss:0.452, acc:49.848, val_loss:0.435, val_acc:46.250
# Best loss:0.461, Best accuracy:45.625, Best F1-score:39.672
# 27/300 lr=0.00100 - loss:0.443, acc:50.457, val_loss:0.469, val_acc:44.375
# Best loss:0.435, Best accuracy:46.250, Best F1-score:42.959
# 28/300 lr=0.00100 - loss:0.434, acc:52.210, val_loss:0.427, val_acc:48.750
# Best loss:0.435, Best accuracy:46.250, Best F1-score:42.959
# 29/300 lr=0.00100 - loss:0.432, acc:52.439, val_loss:0.445, val_acc:46.875
# Best loss:0.427, Best accuracy:48.750, Best F1-score:47.466
# 30/300 lr=0.00100 - loss:0.436, acc:52.210, val_loss:0.399, val_acc:54.375
# Best loss:0.427, Best accuracy:48.750, Best F1-score:47.466
# 31/300 lr=0.00100 - loss:0.430, acc:54.345, val_loss:0.417, val_acc:53.125
# Best loss:0.399, Best accuracy:54.375, Best F1-score:51.197
# 32/300 lr=0.00100 - loss:0.419, acc:54.649, val_loss:0.453, val_acc:48.125
# Best loss:0.399, Best accuracy:54.375, Best F1-score:51.197
# 33/300 lr=0.00100 - loss:0.413, acc:56.860, val_loss:0.408, val_acc:52.500
# Best loss:0.399, Best accuracy:54.375, Best F1-score:51.197
# 34/300 lr=0.00100 - loss:0.415, acc:55.183, val_loss:0.397, val_acc:53.125
# Best loss:0.399, Best accuracy:54.375, Best F1-score:51.197
# 35/300 lr=0.00100 - loss:0.402, acc:58.079, val_loss:0.437, val_acc:48.750
# Best loss:0.397, Best accuracy:53.125, Best F1-score:50.107
# 36/300 lr=0.00100 - loss:0.407, acc:57.012, val_loss:0.394, val_acc:52.500
# Best loss:0.397, Best accuracy:53.125, Best F1-score:50.107
# 37/300 lr=0.00100 - loss:0.404, acc:57.317, val_loss:0.387, val_acc:55.625
# Best loss:0.394, Best accuracy:52.500, Best F1-score:50.517
# 38/300 lr=0.00100 - loss:0.409, acc:56.402, val_loss:0.392, val_acc:56.875
# Best loss:0.387, Best accuracy:55.625, Best F1-score:54.130
# 39/300 lr=0.00100 - loss:0.396, acc:57.851, val_loss:0.395, val_acc:53.750
# Best loss:0.387, Best accuracy:55.625, Best F1-score:54.130
# 40/300 lr=0.00100 - loss:0.382, acc:61.662, val_loss:0.368, val_acc:58.125
# Best loss:0.387, Best accuracy:55.625, Best F1-score:54.130
# 41/300 lr=0.00100 - loss:0.388, acc:59.604, val_loss:0.389, val_acc:55.625
# Best loss:0.368, Best accuracy:58.125, Best F1-score:56.351
# 42/300 lr=0.00100 - loss:0.395, acc:59.223, val_loss:0.381, val_acc:52.500
# Best loss:0.368, Best accuracy:58.125, Best F1-score:56.351
# 43/300 lr=0.00100 - loss:0.375, acc:61.890, val_loss:0.361, val_acc:58.125
# Best loss:0.368, Best accuracy:58.125, Best F1-score:56.351
# 44/300 lr=0.00100 - loss:0.368, acc:62.652, val_loss:0.345, val_acc:58.750
# Best loss:0.361, Best accuracy:58.125, Best F1-score:55.005
# 45/300 lr=0.00100 - loss:0.365, acc:62.652, val_loss:0.390, val_acc:54.375
# Best loss:0.345, Best accuracy:58.750, Best F1-score:56.078
# 46/300 lr=0.00100 - loss:0.353, acc:64.863, val_loss:0.349, val_acc:60.625
# Best loss:0.345, Best accuracy:58.750, Best F1-score:56.078
# 47/300 lr=0.00100 - loss:0.371, acc:62.348, val_loss:0.358, val_acc:56.250
# Best loss:0.345, Best accuracy:58.750, Best F1-score:56.078
# 48/300 lr=0.00100 - loss:0.370, acc:62.271, val_loss:0.344, val_acc:58.125
# Best loss:0.345, Best accuracy:58.750, Best F1-score:56.078
# 49/300 lr=0.00100 - loss:0.367, acc:62.500, val_loss:0.360, val_acc:55.000
# Best loss:0.344, Best accuracy:58.125, Best F1-score:55.846
# 50/300 lr=0.00100 - loss:0.375, acc:61.814, val_loss:0.347, val_acc:58.125
# Best loss:0.344, Best accuracy:58.125, Best F1-score:55.846
# 51/300 lr=0.00100 - loss:0.352, acc:65.168, val_loss:0.329, val_acc:61.875
# Best loss:0.344, Best accuracy:58.125, Best F1-score:55.846
# 52/300 lr=0.00100 - loss:0.351, acc:66.006, val_loss:0.339, val_acc:63.125
# Best loss:0.329, Best accuracy:61.875, Best F1-score:59.631
# 53/300 lr=0.00100 - loss:0.342, acc:66.159, val_loss:0.305, val_acc:65.625
# Best loss:0.329, Best accuracy:61.875, Best F1-score:59.631
# 54/300 lr=0.00100 - loss:0.335, acc:66.921, val_loss:0.294, val_acc:67.500
# Best loss:0.305, Best accuracy:65.625, Best F1-score:62.864
# 55/300 lr=0.00100 - loss:0.334, acc:68.369, val_loss:0.333, val_acc:63.125
# Best loss:0.294, Best accuracy:67.500, Best F1-score:67.002
# 56/300 lr=0.00100 - loss:0.344, acc:66.692, val_loss:0.338, val_acc:61.875
# Best loss:0.294, Best accuracy:67.500, Best F1-score:67.002
# 57/300 lr=0.00100 - loss:0.337, acc:67.226, val_loss:0.322, val_acc:62.500
# Best loss:0.294, Best accuracy:67.500, Best F1-score:67.002
# 58/300 lr=0.00100 - loss:0.341, acc:66.387, val_loss:0.314, val_acc:65.000
# Best loss:0.294, Best accuracy:67.500, Best F1-score:67.002
# 59/300 lr=0.00100 - loss:0.322, acc:69.436, val_loss:0.327, val_acc:61.875
# Best loss:0.294, Best accuracy:67.500, Best F1-score:67.002
# 60/300 lr=0.00100 - loss:0.322, acc:70.884, val_loss:0.332, val_acc:60.625
# Best loss:0.294, Best accuracy:67.500, Best F1-score:67.002
# 61/300 lr=0.00100 - loss:0.316, acc:69.970, val_loss:0.305, val_acc:63.750
# Best loss:0.294, Best accuracy:67.500, Best F1-score:67.002
# 62/300 lr=0.00086 - loss:0.303, acc:72.027, val_loss:0.294, val_acc:66.250
# Best loss:0.294, Best accuracy:67.500, Best F1-score:67.002
# 63/300 lr=0.00086 - loss:0.308, acc:72.561, val_loss:0.282, val_acc:65.000
# Best loss:0.294, Best accuracy:67.500, Best F1-score:67.002
# 64/300 lr=0.00086 - loss:0.302, acc:73.552, val_loss:0.286, val_acc:65.625
# Best loss:0.282, Best accuracy:65.000, Best F1-score:62.927
# 65/300 lr=0.00086 - loss:0.296, acc:73.780, val_loss:0.278, val_acc:66.875
# Best loss:0.282, Best accuracy:65.000, Best F1-score:62.927
# 66/300 lr=0.00086 - loss:0.303, acc:72.485, val_loss:0.298, val_acc:64.375
# Best loss:0.278, Best accuracy:66.875, Best F1-score:65.333
# 67/300 lr=0.00086 - loss:0.284, acc:75.457, val_loss:0.264, val_acc:71.250
# Best loss:0.278, Best accuracy:66.875, Best F1-score:65.333
# 68/300 lr=0.00086 - loss:0.292, acc:74.619, val_loss:0.288, val_acc:66.250
# Best loss:0.264, Best accuracy:71.250, Best F1-score:70.701
# 69/300 lr=0.00086 - loss:0.280, acc:75.686, val_loss:0.293, val_acc:63.750
# Best loss:0.264, Best accuracy:71.250, Best F1-score:70.701
# 70/300 lr=0.00086 - loss:0.289, acc:74.009, val_loss:0.254, val_acc:71.250
# Best loss:0.264, Best accuracy:71.250, Best F1-score:70.701
# 71/300 lr=0.00086 - loss:0.289, acc:73.704, val_loss:0.242, val_acc:73.125
# Best loss:0.254, Best accuracy:71.250, Best F1-score:69.961
# 72/300 lr=0.00086 - loss:0.282, acc:75.457, val_loss:0.280, val_acc:65.000
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 73/300 lr=0.00086 - loss:0.287, acc:75.381, val_loss:0.265, val_acc:70.000
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 74/300 lr=0.00086 - loss:0.286, acc:73.780, val_loss:0.259, val_acc:69.375
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 75/300 lr=0.00086 - loss:0.284, acc:75.305, val_loss:0.256, val_acc:70.000
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 76/300 lr=0.00086 - loss:0.273, acc:76.448, val_loss:0.281, val_acc:66.250
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 77/300 lr=0.00086 - loss:0.267, acc:77.363, val_loss:0.249, val_acc:71.875
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 78/300 lr=0.00086 - loss:0.264, acc:78.125, val_loss:0.271, val_acc:67.500
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 79/300 lr=0.00086 - loss:0.262, acc:77.134, val_loss:0.273, val_acc:65.625
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 80/300 lr=0.00086 - loss:0.281, acc:76.601, val_loss:0.301, val_acc:66.875
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 81/300 lr=0.00086 - loss:0.280, acc:75.457, val_loss:0.275, val_acc:68.750
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 82/300 lr=0.00074 - loss:0.271, acc:76.448, val_loss:0.246, val_acc:71.875
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 83/300 lr=0.00074 - loss:0.256, acc:78.811, val_loss:0.251, val_acc:69.375
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 84/300 lr=0.00074 - loss:0.250, acc:80.488, val_loss:0.242, val_acc:73.125
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 85/300 lr=0.00074 - loss:0.246, acc:80.640, val_loss:0.248, val_acc:68.125
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 86/300 lr=0.00074 - loss:0.246, acc:80.030, val_loss:0.268, val_acc:66.250
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 87/300 lr=0.00074 - loss:0.251, acc:79.421, val_loss:0.252, val_acc:70.000
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 88/300 lr=0.00074 - loss:0.245, acc:79.649, val_loss:0.241, val_acc:72.500
# Best loss:0.242, Best accuracy:73.125, Best F1-score:72.983
# 89/300 lr=0.00074 - loss:0.246, acc:80.183, val_loss:0.239, val_acc:75.000
# Best loss:0.241, Best accuracy:72.500, Best F1-score:72.968
# 90/300 lr=0.00074 - loss:0.246, acc:80.335, val_loss:0.233, val_acc:73.125
# Best loss:0.239, Best accuracy:75.000, Best F1-score:74.880
# 91/300 lr=0.00074 - loss:0.256, acc:79.268, val_loss:0.257, val_acc:68.750
# Best loss:0.233, Best accuracy:73.125, Best F1-score:72.964
# 92/300 lr=0.00074 - loss:0.260, acc:77.058, val_loss:0.269, val_acc:67.500
# Best loss:0.233, Best accuracy:73.125, Best F1-score:72.964
# 93/300 lr=0.00074 - loss:0.237, acc:81.707, val_loss:0.288, val_acc:68.750
# Best loss:0.233, Best accuracy:73.125, Best F1-score:72.964
# 94/300 lr=0.00074 - loss:0.252, acc:79.421, val_loss:0.277, val_acc:65.625
# Best loss:0.233, Best accuracy:73.125, Best F1-score:72.964
# 95/300 lr=0.00074 - loss:0.250, acc:79.497, val_loss:0.259, val_acc:67.500
# Best loss:0.233, Best accuracy:73.125, Best F1-score:72.964
# 96/300 lr=0.00074 - loss:0.236, acc:81.402, val_loss:0.222, val_acc:73.125
# Best loss:0.233, Best accuracy:73.125, Best F1-score:72.964
# 97/300 lr=0.00074 - loss:0.233, acc:81.402, val_loss:0.217, val_acc:75.000
# Best loss:0.222, Best accuracy:73.125, Best F1-score:72.803
# 98/300 lr=0.00074 - loss:0.225, acc:83.003, val_loss:0.245, val_acc:70.625
# Best loss:0.217, Best accuracy:75.000, Best F1-score:75.467
# 99/300 lr=0.00074 - loss:0.231, acc:83.155, val_loss:0.223, val_acc:71.875
# Best loss:0.217, Best accuracy:75.000, Best F1-score:75.467
# 100/300 lr=0.00074 - loss:0.220, acc:84.223, val_loss:0.240, val_acc:71.250
# Best loss:0.217, Best accuracy:75.000, Best F1-score:75.467
# 101/300 lr=0.00074 - loss:0.221, acc:83.003, val_loss:0.246, val_acc:69.375
# Best loss:0.217, Best accuracy:75.000, Best F1-score:75.467
# 102/300 lr=0.00064 - loss:0.220, acc:83.841, val_loss:0.266, val_acc:66.875
# Best loss:0.217, Best accuracy:75.000, Best F1-score:75.467
# 103/300 lr=0.00064 - loss:0.216, acc:85.137, val_loss:0.213, val_acc:73.125
# Best loss:0.217, Best accuracy:75.000, Best F1-score:75.467
# 104/300 lr=0.00064 - loss:0.212, acc:85.366, val_loss:0.221, val_acc:75.000
# Best loss:0.213, Best accuracy:73.125, Best F1-score:71.497
# 105/300 lr=0.00064 - loss:0.214, acc:84.756, val_loss:0.236, val_acc:71.250
# Best loss:0.213, Best accuracy:73.125, Best F1-score:71.497
# 106/300 lr=0.00064 - loss:0.214, acc:85.442, val_loss:0.230, val_acc:72.500
# Best loss:0.213, Best accuracy:73.125, Best F1-score:71.497
# 107/300 lr=0.00064 - loss:0.206, acc:86.890, val_loss:0.215, val_acc:75.625
# Best loss:0.213, Best accuracy:73.125, Best F1-score:71.497
# 108/300 lr=0.00064 - loss:0.198, acc:86.890, val_loss:0.227, val_acc:73.125
# Best loss:0.213, Best accuracy:73.125, Best F1-score:71.497
# 109/300 lr=0.00064 - loss:0.202, acc:85.671, val_loss:0.218, val_acc:70.625
# Best loss:0.213, Best accuracy:73.125, Best F1-score:71.497
# 110/300 lr=0.00064 - loss:0.201, acc:86.204, val_loss:0.208, val_acc:73.125
# Best loss:0.213, Best accuracy:73.125, Best F1-score:71.497
# 111/300 lr=0.00064 - loss:0.198, acc:86.662, val_loss:0.215, val_acc:73.125
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 112/300 lr=0.00064 - loss:0.198, acc:87.424, val_loss:0.212, val_acc:75.000
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 113/300 lr=0.00064 - loss:0.195, acc:87.119, val_loss:0.217, val_acc:74.375
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 114/300 lr=0.00064 - loss:0.198, acc:86.433, val_loss:0.235, val_acc:72.500
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 115/300 lr=0.00064 - loss:0.204, acc:86.357, val_loss:0.245, val_acc:73.125
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 116/300 lr=0.00064 - loss:0.199, acc:86.662, val_loss:0.230, val_acc:73.125
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 117/300 lr=0.00064 - loss:0.205, acc:85.290, val_loss:0.208, val_acc:76.250
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 118/300 lr=0.00064 - loss:0.204, acc:85.671, val_loss:0.225, val_acc:72.500
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 119/300 lr=0.00064 - loss:0.209, acc:84.756, val_loss:0.220, val_acc:75.000
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 120/300 lr=0.00064 - loss:0.211, acc:84.604, val_loss:0.234, val_acc:75.000
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 121/300 lr=0.00064 - loss:0.200, acc:86.738, val_loss:0.234, val_acc:73.750
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 122/300 lr=0.00055 - loss:0.193, acc:87.271, val_loss:0.249, val_acc:71.250
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 123/300 lr=0.00055 - loss:0.186, acc:88.338, val_loss:0.234, val_acc:70.625
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 124/300 lr=0.00055 - loss:0.183, acc:88.262, val_loss:0.233, val_acc:74.375
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 125/300 lr=0.00055 - loss:0.183, acc:88.567, val_loss:0.211, val_acc:76.250
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 126/300 lr=0.00055 - loss:0.175, acc:91.006, val_loss:0.213, val_acc:76.250
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 127/300 lr=0.00055 - loss:0.173, acc:90.168, val_loss:0.224, val_acc:74.375
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 128/300 lr=0.00055 - loss:0.174, acc:90.549, val_loss:0.209, val_acc:78.125
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 129/300 lr=0.00055 - loss:0.184, acc:89.101, val_loss:0.201, val_acc:77.500
# Best loss:0.208, Best accuracy:73.125, Best F1-score:73.181
# 130/300 lr=0.00055 - loss:0.181, acc:89.558, val_loss:0.209, val_acc:78.125
# Best loss:0.201, Best accuracy:77.500, Best F1-score:77.106
# 131/300 lr=0.00055 - loss:0.171, acc:91.159, val_loss:0.193, val_acc:77.500
# Best loss:0.201, Best accuracy:77.500, Best F1-score:77.106
# 132/300 lr=0.00055 - loss:0.176, acc:89.101, val_loss:0.212, val_acc:76.875
# Best loss:0.193, Best accuracy:77.500, Best F1-score:77.597
# 133/300 lr=0.00055 - loss:0.177, acc:89.787, val_loss:0.217, val_acc:73.750
# Best loss:0.193, Best accuracy:77.500, Best F1-score:77.597
# 134/300 lr=0.00055 - loss:0.177, acc:90.015, val_loss:0.206, val_acc:76.250
# Best loss:0.193, Best accuracy:77.500, Best F1-score:77.597
# 135/300 lr=0.00055 - loss:0.174, acc:89.863, val_loss:0.198, val_acc:76.875
# Best loss:0.193, Best accuracy:77.500, Best F1-score:77.597
# 136/300 lr=0.00055 - loss:0.170, acc:91.159, val_loss:0.214, val_acc:76.250
# Best loss:0.193, Best accuracy:77.500, Best F1-score:77.597
# 137/300 lr=0.00055 - loss:0.163, acc:92.226, val_loss:0.211, val_acc:77.500
# Best loss:0.193, Best accuracy:77.500, Best F1-score:77.597
# 138/300 lr=0.00055 - loss:0.173, acc:89.710, val_loss:0.192, val_acc:77.500
# Best loss:0.193, Best accuracy:77.500, Best F1-score:77.597
# 139/300 lr=0.00055 - loss:0.167, acc:90.854, val_loss:0.201, val_acc:75.625
# Best loss:0.192, Best accuracy:77.500, Best F1-score:77.275
# 140/300 lr=0.00055 - loss:0.172, acc:90.168, val_loss:0.208, val_acc:75.625
# Best loss:0.192, Best accuracy:77.500, Best F1-score:77.275
# 141/300 lr=0.00055 - loss:0.172, acc:90.701, val_loss:0.229, val_acc:74.375
# Best loss:0.192, Best accuracy:77.500, Best F1-score:77.275
# 142/300 lr=0.00047 - loss:0.164, acc:91.311, val_loss:0.215, val_acc:76.875
# Best loss:0.192, Best accuracy:77.500, Best F1-score:77.275
# 143/300 lr=0.00047 - loss:0.171, acc:90.396, val_loss:0.202, val_acc:72.500
# Best loss:0.192, Best accuracy:77.500, Best F1-score:77.275
# 144/300 lr=0.00047 - loss:0.166, acc:91.311, val_loss:0.207, val_acc:75.625
# Best loss:0.192, Best accuracy:77.500, Best F1-score:77.275
# 145/300 lr=0.00047 - loss:0.161, acc:92.073, val_loss:0.205, val_acc:77.500
# Best loss:0.192, Best accuracy:77.500, Best F1-score:77.275
# 146/300 lr=0.00047 - loss:0.165, acc:91.540, val_loss:0.203, val_acc:76.250
# Best loss:0.192, Best accuracy:77.500, Best F1-score:77.275
# 147/300 lr=0.00047 - loss:0.157, acc:92.226, val_loss:0.211, val_acc:75.000
# Best loss:0.192, Best accuracy:77.500, Best F1-score:77.275
# 148/300 lr=0.00047 - loss:0.165, acc:91.921, val_loss:0.246, val_acc:71.875
# Best loss:0.192, Best accuracy:77.500, Best F1-score:77.275
# 149/300 lr=0.00047 - loss:0.154, acc:93.293, val_loss:0.214, val_acc:77.500
# Best loss:0.192, Best accuracy:77.500, Best F1-score:77.275
# 150/300 lr=0.00047 - loss:0.152, acc:92.988, val_loss:0.187, val_acc:76.250
# Best loss:0.192, Best accuracy:77.500, Best F1-score:77.275
# 151/300 lr=0.00047 - loss:0.154, acc:93.064, val_loss:0.205, val_acc:73.750
# Best loss:0.187, Best accuracy:76.250, Best F1-score:75.743
# 152/300 lr=0.00047 - loss:0.158, acc:92.378, val_loss:0.204, val_acc:75.625
# Best loss:0.187, Best accuracy:76.250, Best F1-score:75.743
# 153/300 lr=0.00047 - loss:0.156, acc:92.683, val_loss:0.194, val_acc:79.375
# Best loss:0.187, Best accuracy:76.250, Best F1-score:75.743
# 154/300 lr=0.00047 - loss:0.166, acc:90.473, val_loss:0.227, val_acc:75.000
# Best loss:0.187, Best accuracy:76.250, Best F1-score:75.743
# 155/300 lr=0.00047 - loss:0.153, acc:93.521, val_loss:0.213, val_acc:75.000
# Best loss:0.187, Best accuracy:76.250, Best F1-score:75.743
# 156/300 lr=0.00047 - loss:0.156, acc:92.073, val_loss:0.220, val_acc:75.000
# Best loss:0.187, Best accuracy:76.250, Best F1-score:75.743
# 157/300 lr=0.00047 - loss:0.154, acc:92.988, val_loss:0.187, val_acc:79.375
# Best loss:0.187, Best accuracy:76.250, Best F1-score:75.743
# 158/300 lr=0.00047 - loss:0.156, acc:92.607, val_loss:0.243, val_acc:70.625
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 159/300 lr=0.00047 - loss:0.163, acc:91.768, val_loss:0.213, val_acc:74.375
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 160/300 lr=0.00047 - loss:0.148, acc:93.598, val_loss:0.194, val_acc:78.750
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 161/300 lr=0.00047 - loss:0.155, acc:92.683, val_loss:0.236, val_acc:72.500
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 162/300 lr=0.00041 - loss:0.152, acc:93.750, val_loss:0.222, val_acc:75.000
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 163/300 lr=0.00041 - loss:0.152, acc:93.369, val_loss:0.201, val_acc:78.125
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 164/300 lr=0.00041 - loss:0.154, acc:93.293, val_loss:0.216, val_acc:73.750
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 165/300 lr=0.00041 - loss:0.153, acc:92.759, val_loss:0.206, val_acc:76.875
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 166/300 lr=0.00041 - loss:0.148, acc:94.207, val_loss:0.198, val_acc:80.000
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 167/300 lr=0.00041 - loss:0.145, acc:94.207, val_loss:0.221, val_acc:74.375
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 168/300 lr=0.00041 - loss:0.143, acc:93.979, val_loss:0.218, val_acc:75.000
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 169/300 lr=0.00041 - loss:0.141, acc:94.588, val_loss:0.199, val_acc:75.625
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 170/300 lr=0.00041 - loss:0.143, acc:94.360, val_loss:0.216, val_acc:73.750
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 171/300 lr=0.00041 - loss:0.146, acc:93.826, val_loss:0.242, val_acc:72.500
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 172/300 lr=0.00041 - loss:0.147, acc:93.674, val_loss:0.219, val_acc:75.000
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 173/300 lr=0.00041 - loss:0.139, acc:94.970, val_loss:0.196, val_acc:76.250
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 174/300 lr=0.00041 - loss:0.135, acc:95.579, val_loss:0.224, val_acc:75.000
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 175/300 lr=0.00041 - loss:0.141, acc:94.360, val_loss:0.215, val_acc:76.250
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 176/300 lr=0.00041 - loss:0.145, acc:93.750, val_loss:0.221, val_acc:75.625
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 177/300 lr=0.00041 - loss:0.152, acc:93.140, val_loss:0.204, val_acc:76.875
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 178/300 lr=0.00041 - loss:0.144, acc:94.207, val_loss:0.193, val_acc:77.500
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 179/300 lr=0.00041 - loss:0.144, acc:94.055, val_loss:0.206, val_acc:78.125
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 180/300 lr=0.00041 - loss:0.142, acc:94.512, val_loss:0.215, val_acc:78.125
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 181/300 lr=0.00041 - loss:0.140, acc:94.893, val_loss:0.198, val_acc:76.250
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 182/300 lr=0.00035 - loss:0.145, acc:93.521, val_loss:0.209, val_acc:73.750
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 183/300 lr=0.00035 - loss:0.142, acc:94.360, val_loss:0.214, val_acc:76.875
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 184/300 lr=0.00035 - loss:0.139, acc:94.512, val_loss:0.205, val_acc:75.000
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 185/300 lr=0.00035 - loss:0.142, acc:94.512, val_loss:0.223, val_acc:76.250
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 186/300 lr=0.00035 - loss:0.131, acc:96.189, val_loss:0.223, val_acc:76.875
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 187/300 lr=0.00035 - loss:0.134, acc:96.265, val_loss:0.207, val_acc:76.250
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 188/300 lr=0.00035 - loss:0.141, acc:94.741, val_loss:0.255, val_acc:70.625
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 189/300 lr=0.00035 - loss:0.138, acc:95.427, val_loss:0.228, val_acc:75.000
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 190/300 lr=0.00035 - loss:0.139, acc:94.588, val_loss:0.215, val_acc:75.625
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 191/300 lr=0.00035 - loss:0.138, acc:95.198, val_loss:0.224, val_acc:73.750
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 192/300 lr=0.00035 - loss:0.140, acc:95.198, val_loss:0.226, val_acc:74.375
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 193/300 lr=0.00035 - loss:0.140, acc:94.893, val_loss:0.208, val_acc:78.125
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 194/300 lr=0.00035 - loss:0.139, acc:95.351, val_loss:0.208, val_acc:76.875
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 195/300 lr=0.00035 - loss:0.134, acc:96.037, val_loss:0.201, val_acc:76.875
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 196/300 lr=0.00035 - loss:0.129, acc:96.646, val_loss:0.184, val_acc:77.500
# Best loss:0.187, Best accuracy:79.375, Best F1-score:78.454
# 197/300 lr=0.00035 - loss:0.134, acc:95.884, val_loss:0.220, val_acc:73.750
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 198/300 lr=0.00035 - loss:0.133, acc:95.808, val_loss:0.211, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 199/300 lr=0.00035 - loss:0.132, acc:96.418, val_loss:0.218, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 200/300 lr=0.00035 - loss:0.127, acc:96.799, val_loss:0.198, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 201/300 lr=0.00035 - loss:0.134, acc:95.884, val_loss:0.202, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 202/300 lr=0.00030 - loss:0.139, acc:94.893, val_loss:0.205, val_acc:76.250
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 203/300 lr=0.00030 - loss:0.130, acc:96.341, val_loss:0.210, val_acc:76.250
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 204/300 lr=0.00030 - loss:0.139, acc:94.817, val_loss:0.201, val_acc:78.125
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 205/300 lr=0.00030 - loss:0.132, acc:95.427, val_loss:0.220, val_acc:75.000
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 206/300 lr=0.00030 - loss:0.128, acc:96.189, val_loss:0.219, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 207/300 lr=0.00030 - loss:0.137, acc:95.427, val_loss:0.228, val_acc:75.625
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 208/300 lr=0.00030 - loss:0.132, acc:95.960, val_loss:0.209, val_acc:76.250
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 209/300 lr=0.00030 - loss:0.130, acc:96.646, val_loss:0.196, val_acc:75.000
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 210/300 lr=0.00030 - loss:0.127, acc:96.646, val_loss:0.212, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 211/300 lr=0.00030 - loss:0.125, acc:96.875, val_loss:0.212, val_acc:75.625
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 212/300 lr=0.00030 - loss:0.127, acc:96.723, val_loss:0.218, val_acc:74.375
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 213/300 lr=0.00030 - loss:0.127, acc:96.570, val_loss:0.221, val_acc:75.625
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 214/300 lr=0.00030 - loss:0.124, acc:96.951, val_loss:0.217, val_acc:75.000
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 215/300 lr=0.00030 - loss:0.124, acc:97.256, val_loss:0.212, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 216/300 lr=0.00030 - loss:0.125, acc:96.951, val_loss:0.210, val_acc:76.250
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 217/300 lr=0.00030 - loss:0.119, acc:97.866, val_loss:0.215, val_acc:77.500
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 218/300 lr=0.00030 - loss:0.130, acc:96.189, val_loss:0.203, val_acc:76.250
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 219/300 lr=0.00030 - loss:0.127, acc:97.104, val_loss:0.210, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 220/300 lr=0.00030 - loss:0.126, acc:96.646, val_loss:0.223, val_acc:76.250
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 221/300 lr=0.00030 - loss:0.130, acc:96.037, val_loss:0.221, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 222/300 lr=0.00026 - loss:0.131, acc:95.655, val_loss:0.217, val_acc:74.375
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 223/300 lr=0.00026 - loss:0.130, acc:96.113, val_loss:0.219, val_acc:75.000
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 224/300 lr=0.00026 - loss:0.129, acc:96.341, val_loss:0.189, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 225/300 lr=0.00026 - loss:0.126, acc:96.875, val_loss:0.222, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 226/300 lr=0.00026 - loss:0.123, acc:96.951, val_loss:0.203, val_acc:77.500
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 227/300 lr=0.00026 - loss:0.121, acc:97.561, val_loss:0.216, val_acc:76.250
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 228/300 lr=0.00026 - loss:0.122, acc:97.409, val_loss:0.217, val_acc:77.500
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 229/300 lr=0.00026 - loss:0.124, acc:97.180, val_loss:0.198, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 230/300 lr=0.00026 - loss:0.124, acc:97.027, val_loss:0.189, val_acc:78.125
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 231/300 lr=0.00026 - loss:0.126, acc:96.723, val_loss:0.227, val_acc:74.375
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 232/300 lr=0.00026 - loss:0.127, acc:96.418, val_loss:0.211, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 233/300 lr=0.00026 - loss:0.120, acc:97.637, val_loss:0.195, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 234/300 lr=0.00026 - loss:0.125, acc:97.104, val_loss:0.222, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 235/300 lr=0.00026 - loss:0.123, acc:97.027, val_loss:0.213, val_acc:75.000
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 236/300 lr=0.00026 - loss:0.121, acc:97.713, val_loss:0.205, val_acc:75.000
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 237/300 lr=0.00026 - loss:0.127, acc:97.104, val_loss:0.220, val_acc:75.625
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 238/300 lr=0.00026 - loss:0.127, acc:96.341, val_loss:0.209, val_acc:76.250
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 239/300 lr=0.00026 - loss:0.123, acc:97.485, val_loss:0.198, val_acc:76.250
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 240/300 lr=0.00026 - loss:0.119, acc:97.637, val_loss:0.202, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 241/300 lr=0.00026 - loss:0.120, acc:97.790, val_loss:0.210, val_acc:76.875
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 242/300 lr=0.00022 - loss:0.119, acc:97.942, val_loss:0.214, val_acc:75.625
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 243/300 lr=0.00022 - loss:0.121, acc:97.256, val_loss:0.213, val_acc:75.625
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 244/300 lr=0.00022 - loss:0.119, acc:97.561, val_loss:0.223, val_acc:75.000
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 245/300 lr=0.00022 - loss:0.121, acc:97.180, val_loss:0.210, val_acc:75.625
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 246/300 lr=0.00022 - loss:0.118, acc:98.018, val_loss:0.201, val_acc:78.125
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 247/300 lr=0.00022 - loss:0.118, acc:98.018, val_loss:0.228, val_acc:75.000
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 248/300 lr=0.00022 - loss:0.120, acc:97.332, val_loss:0.201, val_acc:76.250
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 249/300 lr=0.00022 - loss:0.120, acc:97.409, val_loss:0.230, val_acc:75.000
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 250/300 lr=0.00022 - loss:0.120, acc:97.409, val_loss:0.176, val_acc:80.625
# Best loss:0.184, Best accuracy:77.500, Best F1-score:77.100
# 251/300 lr=0.00022 - loss:0.121, acc:97.485, val_loss:0.208, val_acc:76.875
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 252/300 lr=0.00022 - loss:0.120, acc:97.866, val_loss:0.211, val_acc:75.000
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 253/300 lr=0.00022 - loss:0.120, acc:97.561, val_loss:0.191, val_acc:76.875
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 254/300 lr=0.00022 - loss:0.121, acc:97.256, val_loss:0.235, val_acc:74.375
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 255/300 lr=0.00022 - loss:0.125, acc:96.875, val_loss:0.199, val_acc:75.625
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 256/300 lr=0.00022 - loss:0.125, acc:96.875, val_loss:0.219, val_acc:76.250
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 257/300 lr=0.00022 - loss:0.126, acc:96.875, val_loss:0.193, val_acc:79.375
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 258/300 lr=0.00022 - loss:0.124, acc:97.256, val_loss:0.224, val_acc:74.375
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 259/300 lr=0.00022 - loss:0.119, acc:98.095, val_loss:0.193, val_acc:77.500
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 260/300 lr=0.00022 - loss:0.119, acc:98.018, val_loss:0.243, val_acc:73.750
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 261/300 lr=0.00022 - loss:0.120, acc:97.332, val_loss:0.214, val_acc:75.000
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 262/300 lr=0.00019 - loss:0.120, acc:97.561, val_loss:0.211, val_acc:75.000
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 263/300 lr=0.00019 - loss:0.120, acc:97.256, val_loss:0.219, val_acc:74.375
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 264/300 lr=0.00019 - loss:0.116, acc:98.171, val_loss:0.204, val_acc:76.875
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 265/300 lr=0.00019 - loss:0.117, acc:98.171, val_loss:0.211, val_acc:74.375
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 266/300 lr=0.00019 - loss:0.116, acc:98.552, val_loss:0.196, val_acc:78.750
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 267/300 lr=0.00019 - loss:0.117, acc:98.095, val_loss:0.215, val_acc:75.000
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 268/300 lr=0.00019 - loss:0.115, acc:98.399, val_loss:0.212, val_acc:78.125
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 269/300 lr=0.00019 - loss:0.116, acc:97.942, val_loss:0.217, val_acc:75.625
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 270/300 lr=0.00019 - loss:0.120, acc:97.409, val_loss:0.188, val_acc:78.750
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 271/300 lr=0.00019 - loss:0.115, acc:98.399, val_loss:0.242, val_acc:73.750
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 272/300 lr=0.00019 - loss:0.115, acc:98.476, val_loss:0.208, val_acc:75.625
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 273/300 lr=0.00019 - loss:0.114, acc:98.247, val_loss:0.210, val_acc:73.750
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 274/300 lr=0.00019 - loss:0.117, acc:98.171, val_loss:0.206, val_acc:76.250
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 275/300 lr=0.00019 - loss:0.115, acc:98.247, val_loss:0.207, val_acc:75.625
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 276/300 lr=0.00019 - loss:0.116, acc:97.942, val_loss:0.207, val_acc:76.875
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 277/300 lr=0.00019 - loss:0.118, acc:97.713, val_loss:0.205, val_acc:75.000
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 278/300 lr=0.00019 - loss:0.113, acc:98.780, val_loss:0.224, val_acc:75.000
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 279/300 lr=0.00019 - loss:0.118, acc:97.637, val_loss:0.197, val_acc:76.250
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 280/300 lr=0.00019 - loss:0.116, acc:97.866, val_loss:0.182, val_acc:76.250
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 281/300 lr=0.00019 - loss:0.119, acc:97.256, val_loss:0.214, val_acc:75.625
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 282/300 lr=0.00017 - loss:0.114, acc:98.399, val_loss:0.209, val_acc:76.250
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 283/300 lr=0.00017 - loss:0.115, acc:98.399, val_loss:0.191, val_acc:77.500
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 284/300 lr=0.00017 - loss:0.114, acc:98.476, val_loss:0.196, val_acc:77.500
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 285/300 lr=0.00017 - loss:0.117, acc:97.713, val_loss:0.194, val_acc:76.250
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 286/300 lr=0.00017 - loss:0.114, acc:98.323, val_loss:0.201, val_acc:76.875
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 287/300 lr=0.00017 - loss:0.117, acc:97.485, val_loss:0.206, val_acc:75.625
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 288/300 lr=0.00017 - loss:0.117, acc:98.095, val_loss:0.216, val_acc:74.375
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 289/300 lr=0.00017 - loss:0.119, acc:97.790, val_loss:0.212, val_acc:78.125
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 290/300 lr=0.00017 - loss:0.120, acc:97.561, val_loss:0.195, val_acc:78.750
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 291/300 lr=0.00017 - loss:0.115, acc:98.628, val_loss:0.208, val_acc:76.250
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 292/300 lr=0.00017 - loss:0.115, acc:98.323, val_loss:0.200, val_acc:75.000
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 293/300 lr=0.00017 - loss:0.118, acc:97.942, val_loss:0.233, val_acc:73.750
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 294/300 lr=0.00017 - loss:0.118, acc:97.637, val_loss:0.196, val_acc:78.125
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 295/300 lr=0.00017 - loss:0.118, acc:97.942, val_loss:0.221, val_acc:75.000
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 296/300 lr=0.00017 - loss:0.117, acc:98.247, val_loss:0.213, val_acc:76.250
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 297/300 lr=0.00017 - loss:0.113, acc:98.704, val_loss:0.218, val_acc:75.000
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 298/300 lr=0.00017 - loss:0.115, acc:98.018, val_loss:0.213, val_acc:75.000
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 299/300 lr=0.00017 - loss:0.114, acc:98.628, val_loss:0.217, val_acc:76.250
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# 300/300 lr=0.00017 - loss:0.112, acc:99.009, val_loss:0.206, val_acc:75.625
# Best loss:0.176, Best accuracy:80.625, Best F1-score:79.789
# ********************************************************************************
# [*] Done Fold-1
# best_val_loss:0.176, best_val_acc:80.625, best_val_f1:79.789
# test_acc:80.625, test_f1:79.789
# ********************************************************************************
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.631, acc:17.530, val_loss:0.634, val_acc:28.125
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.613, acc:23.704, val_loss:0.618, val_acc:26.875
# Best loss:0.634, Best accuracy:28.125, Best F1-score:19.709
# 3/300 lr=0.00100 - loss:0.601, acc:25.838, val_loss:0.603, val_acc:31.250
# Best loss:0.618, Best accuracy:26.875, Best F1-score:17.792
# 4/300 lr=0.00100 - loss:0.590, acc:28.354, val_loss:0.602, val_acc:28.125
# Best loss:0.603, Best accuracy:31.250, Best F1-score:23.371
# 5/300 lr=0.00100 - loss:0.583, acc:29.497, val_loss:0.570, val_acc:32.500
# Best loss:0.602, Best accuracy:28.125, Best F1-score:19.017
# 6/300 lr=0.00100 - loss:0.575, acc:29.421, val_loss:0.568, val_acc:33.750
# Best loss:0.570, Best accuracy:32.500, Best F1-score:25.359
# 7/300 lr=0.00100 - loss:0.573, acc:30.640, val_loss:0.556, val_acc:36.875
# Best loss:0.568, Best accuracy:33.750, Best F1-score:26.085
# 8/300 lr=0.00100 - loss:0.562, acc:33.079, val_loss:0.543, val_acc:32.500
# Best loss:0.556, Best accuracy:36.875, Best F1-score:29.954
# 9/300 lr=0.00100 - loss:0.559, acc:32.241, val_loss:0.586, val_acc:23.750
# Best loss:0.543, Best accuracy:32.500, Best F1-score:26.001
# 10/300 lr=0.00100 - loss:0.556, acc:35.061, val_loss:0.554, val_acc:33.125
# Best loss:0.543, Best accuracy:32.500, Best F1-score:26.001
# 11/300 lr=0.00100 - loss:0.553, acc:33.765, val_loss:0.553, val_acc:34.375
# Best loss:0.543, Best accuracy:32.500, Best F1-score:26.001
# 12/300 lr=0.00100 - loss:0.559, acc:32.393, val_loss:0.562, val_acc:26.875
# Best loss:0.543, Best accuracy:32.500, Best F1-score:26.001
# 13/300 lr=0.00100 - loss:0.537, acc:38.872, val_loss:0.550, val_acc:30.625
# Best loss:0.543, Best accuracy:32.500, Best F1-score:26.001
# 14/300 lr=0.00100 - loss:0.533, acc:37.043, val_loss:0.557, val_acc:27.500
# Best loss:0.543, Best accuracy:32.500, Best F1-score:26.001
# 15/300 lr=0.00100 - loss:0.531, acc:38.338, val_loss:0.571, val_acc:29.375
# Best loss:0.543, Best accuracy:32.500, Best F1-score:26.001
# 16/300 lr=0.00100 - loss:0.517, acc:39.405, val_loss:0.535, val_acc:33.750
# Best loss:0.543, Best accuracy:32.500, Best F1-score:26.001
# 17/300 lr=0.00100 - loss:0.508, acc:42.226, val_loss:0.523, val_acc:36.250
# Best loss:0.535, Best accuracy:33.750, Best F1-score:29.499
# 18/300 lr=0.00100 - loss:0.512, acc:42.683, val_loss:0.501, val_acc:38.750
# Best loss:0.523, Best accuracy:36.250, Best F1-score:33.985
# 19/300 lr=0.00100 - loss:0.504, acc:43.064, val_loss:0.538, val_acc:32.500
# Best loss:0.501, Best accuracy:38.750, Best F1-score:34.304
# 20/300 lr=0.00100 - loss:0.493, acc:44.207, val_loss:0.489, val_acc:43.125
# Best loss:0.501, Best accuracy:38.750, Best F1-score:34.304
# 21/300 lr=0.00100 - loss:0.498, acc:42.607, val_loss:0.492, val_acc:43.750
# Best loss:0.489, Best accuracy:43.125, Best F1-score:37.192
# 22/300 lr=0.00100 - loss:0.483, acc:46.494, val_loss:0.490, val_acc:43.125
# Best loss:0.489, Best accuracy:43.125, Best F1-score:37.192
# 23/300 lr=0.00100 - loss:0.480, acc:46.951, val_loss:0.489, val_acc:44.375
# Best loss:0.489, Best accuracy:43.125, Best F1-score:37.192
# 24/300 lr=0.00100 - loss:0.470, acc:47.027, val_loss:0.518, val_acc:35.000
# Best loss:0.489, Best accuracy:44.375, Best F1-score:40.742
# 25/300 lr=0.00100 - loss:0.470, acc:48.857, val_loss:0.492, val_acc:40.625
# Best loss:0.489, Best accuracy:44.375, Best F1-score:40.742
# 26/300 lr=0.00100 - loss:0.466, acc:48.933, val_loss:0.478, val_acc:41.875
# Best loss:0.489, Best accuracy:44.375, Best F1-score:40.742
# 27/300 lr=0.00100 - loss:0.451, acc:51.220, val_loss:0.444, val_acc:45.000
# Best loss:0.478, Best accuracy:41.875, Best F1-score:38.960
# 28/300 lr=0.00100 - loss:0.453, acc:50.152, val_loss:0.461, val_acc:46.875
# Best loss:0.444, Best accuracy:45.000, Best F1-score:43.231
# 29/300 lr=0.00100 - loss:0.460, acc:49.619, val_loss:0.514, val_acc:38.750
# Best loss:0.444, Best accuracy:45.000, Best F1-score:43.231
# 30/300 lr=0.00100 - loss:0.441, acc:51.982, val_loss:0.469, val_acc:44.375
# Best loss:0.444, Best accuracy:45.000, Best F1-score:43.231
# 31/300 lr=0.00100 - loss:0.438, acc:52.287, val_loss:0.472, val_acc:41.250
# Best loss:0.444, Best accuracy:45.000, Best F1-score:43.231
# 32/300 lr=0.00100 - loss:0.438, acc:52.668, val_loss:0.437, val_acc:46.250
# Best loss:0.444, Best accuracy:45.000, Best F1-score:43.231
# 33/300 lr=0.00100 - loss:0.438, acc:53.659, val_loss:0.418, val_acc:53.125
# Best loss:0.437, Best accuracy:46.250, Best F1-score:44.430
# 34/300 lr=0.00100 - loss:0.449, acc:51.220, val_loss:0.511, val_acc:40.625
# Best loss:0.418, Best accuracy:53.125, Best F1-score:51.612
# 35/300 lr=0.00100 - loss:0.447, acc:51.143, val_loss:0.461, val_acc:44.375
# Best loss:0.418, Best accuracy:53.125, Best F1-score:51.612
# 36/300 lr=0.00100 - loss:0.434, acc:53.430, val_loss:0.527, val_acc:30.625
# Best loss:0.418, Best accuracy:53.125, Best F1-score:51.612
# 37/300 lr=0.00100 - loss:0.415, acc:56.021, val_loss:0.402, val_acc:52.500
# Best loss:0.418, Best accuracy:53.125, Best F1-score:51.612
# 38/300 lr=0.00100 - loss:0.412, acc:57.927, val_loss:0.416, val_acc:51.875
# Best loss:0.402, Best accuracy:52.500, Best F1-score:50.449
# 39/300 lr=0.00100 - loss:0.410, acc:56.936, val_loss:0.407, val_acc:53.750
# Best loss:0.402, Best accuracy:52.500, Best F1-score:50.449
# 40/300 lr=0.00100 - loss:0.417, acc:57.012, val_loss:0.393, val_acc:55.000
# Best loss:0.402, Best accuracy:52.500, Best F1-score:50.449
# 41/300 lr=0.00100 - loss:0.398, acc:59.375, val_loss:0.505, val_acc:36.250
# Best loss:0.393, Best accuracy:55.000, Best F1-score:54.379
# 42/300 lr=0.00100 - loss:0.396, acc:58.003, val_loss:0.413, val_acc:50.000
# Best loss:0.393, Best accuracy:55.000, Best F1-score:54.379
# 43/300 lr=0.00100 - loss:0.390, acc:60.290, val_loss:0.414, val_acc:48.750
# Best loss:0.393, Best accuracy:55.000, Best F1-score:54.379
# 44/300 lr=0.00100 - loss:0.386, acc:60.671, val_loss:0.389, val_acc:55.000
# Best loss:0.393, Best accuracy:55.000, Best F1-score:54.379
# 45/300 lr=0.00100 - loss:0.380, acc:62.348, val_loss:0.398, val_acc:51.875
# Best loss:0.389, Best accuracy:55.000, Best F1-score:52.783
# 46/300 lr=0.00100 - loss:0.377, acc:63.491, val_loss:0.386, val_acc:53.750
# Best loss:0.389, Best accuracy:55.000, Best F1-score:52.783
# 47/300 lr=0.00100 - loss:0.369, acc:63.338, val_loss:0.439, val_acc:45.000
# Best loss:0.386, Best accuracy:53.750, Best F1-score:50.939
# 48/300 lr=0.00100 - loss:0.365, acc:64.482, val_loss:0.418, val_acc:46.875
# Best loss:0.386, Best accuracy:53.750, Best F1-score:50.939
# 49/300 lr=0.00100 - loss:0.378, acc:60.747, val_loss:0.393, val_acc:52.500
# Best loss:0.386, Best accuracy:53.750, Best F1-score:50.939
# 50/300 lr=0.00100 - loss:0.366, acc:62.576, val_loss:0.371, val_acc:55.625
# Best loss:0.386, Best accuracy:53.750, Best F1-score:50.939
# 51/300 lr=0.00100 - loss:0.362, acc:63.338, val_loss:0.364, val_acc:53.750
# Best loss:0.371, Best accuracy:55.625, Best F1-score:55.081
# 52/300 lr=0.00100 - loss:0.349, acc:65.320, val_loss:0.376, val_acc:54.375
# ...
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 186/300 lr=0.00035 - loss:0.148, acc:93.750, val_loss:0.190, val_acc:76.250
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 187/300 lr=0.00035 - loss:0.149, acc:93.521, val_loss:0.190, val_acc:76.875
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 188/300 lr=0.00035 - loss:0.142, acc:94.512, val_loss:0.198, val_acc:77.500
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 189/300 lr=0.00035 - loss:0.148, acc:94.131, val_loss:0.203, val_acc:75.000
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 190/300 lr=0.00035 - loss:0.141, acc:94.741, val_loss:0.225, val_acc:73.750
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 191/300 lr=0.00035 - loss:0.143, acc:94.817, val_loss:0.243, val_acc:72.500
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 192/300 lr=0.00035 - loss:0.143, acc:94.817, val_loss:0.207, val_acc:75.000
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 193/300 lr=0.00035 - loss:0.147, acc:94.207, val_loss:0.222, val_acc:73.750
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 194/300 lr=0.00035 - loss:0.144, acc:94.741, val_loss:0.221, val_acc:75.000
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 195/300 lr=0.00035 - loss:0.144, acc:94.817, val_loss:0.182, val_acc:80.000
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 196/300 lr=0.00035 - loss:0.137, acc:95.884, val_loss:0.184, val_acc:76.875
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 197/300 lr=0.00035 - loss:0.146, acc:94.131, val_loss:0.221, val_acc:75.625
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 198/300 lr=0.00035 - loss:0.143, acc:95.122, val_loss:0.217, val_acc:74.375
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 199/300 lr=0.00035 - loss:0.138, acc:95.274, val_loss:0.212, val_acc:76.250
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 200/300 lr=0.00035 - loss:0.145, acc:94.055, val_loss:0.199, val_acc:77.500
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 201/300 lr=0.00035 - loss:0.141, acc:94.588, val_loss:0.214, val_acc:75.000
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 202/300 lr=0.00030 - loss:0.144, acc:94.284, val_loss:0.193, val_acc:77.500
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 203/300 lr=0.00030 - loss:0.135, acc:95.122, val_loss:0.202, val_acc:76.875
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 204/300 lr=0.00030 - loss:0.140, acc:95.351, val_loss:0.214, val_acc:71.875
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 205/300 lr=0.00030 - loss:0.140, acc:94.893, val_loss:0.211, val_acc:78.125
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 206/300 lr=0.00030 - loss:0.138, acc:95.503, val_loss:0.177, val_acc:81.875
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 207/300 lr=0.00030 - loss:0.144, acc:94.207, val_loss:0.167, val_acc:82.500
# Best loss:0.176, Best accuracy:80.000, Best F1-score:78.942
# 208/300 lr=0.00030 - loss:0.130, acc:96.494, val_loss:0.191, val_acc:78.750
# Best loss:0.167, Best accuracy:82.500, Best F1-score:81.989
# 209/300 lr=0.00030 - loss:0.140, acc:94.817, val_loss:0.208, val_acc:73.750
# Best loss:0.167, Best accuracy:82.500, Best F1-score:81.989
# 210/300 lr=0.00030 - loss:0.140, acc:95.046, val_loss:0.187, val_acc:78.125
# Best loss:0.167, Best accuracy:82.500, Best F1-score:81.989
# 211/300 lr=0.00030 - loss:0.137, acc:95.046, val_loss:0.183, val_acc:78.125
# Best loss:0.167, Best accuracy:82.500, Best F1-score:81.989
# 212/300 lr=0.00030 - loss:0.134, acc:96.037, val_loss:0.193, val_acc:79.375
# Best loss:0.167, Best accuracy:82.500, Best F1-score:81.989
# 213/300 lr=0.00030 - loss:0.135, acc:95.503, val_loss:0.165, val_acc:80.000
# Best loss:0.167, Best accuracy:82.500, Best F1-score:81.989
# 214/300 lr=0.00030 - loss:0.140, acc:94.665, val_loss:0.198, val_acc:78.125
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 215/300 lr=0.00030 - loss:0.138, acc:94.817, val_loss:0.214, val_acc:73.125
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 216/300 lr=0.00030 - loss:0.142, acc:94.131, val_loss:0.177, val_acc:81.875
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 217/300 lr=0.00030 - loss:0.139, acc:95.198, val_loss:0.182, val_acc:80.000
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 218/300 lr=0.00030 - loss:0.137, acc:95.351, val_loss:0.190, val_acc:80.000
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 219/300 lr=0.00030 - loss:0.138, acc:95.351, val_loss:0.229, val_acc:73.750
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 220/300 lr=0.00030 - loss:0.136, acc:95.351, val_loss:0.210, val_acc:75.625
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 221/300 lr=0.00030 - loss:0.144, acc:94.665, val_loss:0.199, val_acc:76.250
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 222/300 lr=0.00026 - loss:0.132, acc:95.884, val_loss:0.190, val_acc:78.125
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 223/300 lr=0.00026 - loss:0.132, acc:96.265, val_loss:0.204, val_acc:78.125
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 224/300 lr=0.00026 - loss:0.131, acc:96.265, val_loss:0.216, val_acc:73.125
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 225/300 lr=0.00026 - loss:0.126, acc:97.104, val_loss:0.203, val_acc:76.250
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 226/300 lr=0.00026 - loss:0.130, acc:95.960, val_loss:0.198, val_acc:76.875
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 227/300 lr=0.00026 - loss:0.132, acc:96.113, val_loss:0.193, val_acc:78.125
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 228/300 lr=0.00026 - loss:0.125, acc:97.332, val_loss:0.184, val_acc:78.125
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 229/300 lr=0.00026 - loss:0.135, acc:95.427, val_loss:0.192, val_acc:79.375
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 230/300 lr=0.00026 - loss:0.129, acc:96.646, val_loss:0.183, val_acc:77.500
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 231/300 lr=0.00026 - loss:0.127, acc:97.104, val_loss:0.169, val_acc:81.875
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 232/300 lr=0.00026 - loss:0.130, acc:96.570, val_loss:0.187, val_acc:77.500
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 233/300 lr=0.00026 - loss:0.132, acc:95.884, val_loss:0.188, val_acc:81.250
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 234/300 lr=0.00026 - loss:0.133, acc:95.732, val_loss:0.165, val_acc:80.625
# Best loss:0.165, Best accuracy:80.000, Best F1-score:79.019
# 235/300 lr=0.00026 - loss:0.130, acc:96.113, val_loss:0.170, val_acc:81.875
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 236/300 lr=0.00026 - loss:0.130, acc:96.265, val_loss:0.180, val_acc:81.250
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 237/300 lr=0.00026 - loss:0.123, acc:97.180, val_loss:0.183, val_acc:80.000
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 238/300 lr=0.00026 - loss:0.127, acc:96.341, val_loss:0.186, val_acc:78.750
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 239/300 lr=0.00026 - loss:0.125, acc:96.799, val_loss:0.185, val_acc:79.375
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 240/300 lr=0.00026 - loss:0.128, acc:97.104, val_loss:0.191, val_acc:81.250
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 241/300 lr=0.00026 - loss:0.129, acc:96.341, val_loss:0.166, val_acc:80.625
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 242/300 lr=0.00022 - loss:0.127, acc:97.027, val_loss:0.205, val_acc:76.875
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 243/300 lr=0.00022 - loss:0.129, acc:96.189, val_loss:0.170, val_acc:81.250
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 244/300 lr=0.00022 - loss:0.124, acc:96.875, val_loss:0.201, val_acc:74.375
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 245/300 lr=0.00022 - loss:0.123, acc:97.256, val_loss:0.196, val_acc:78.750
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 246/300 lr=0.00022 - loss:0.125, acc:97.027, val_loss:0.178, val_acc:80.000
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 247/300 lr=0.00022 - loss:0.127, acc:96.799, val_loss:0.178, val_acc:78.125
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 248/300 lr=0.00022 - loss:0.125, acc:97.180, val_loss:0.178, val_acc:79.375
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 249/300 lr=0.00022 - loss:0.129, acc:96.265, val_loss:0.186, val_acc:76.875
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 250/300 lr=0.00022 - loss:0.127, acc:97.027, val_loss:0.196, val_acc:78.125
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 251/300 lr=0.00022 - loss:0.124, acc:97.561, val_loss:0.192, val_acc:78.750
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 252/300 lr=0.00022 - loss:0.126, acc:96.799, val_loss:0.183, val_acc:78.750
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 253/300 lr=0.00022 - loss:0.125, acc:97.332, val_loss:0.176, val_acc:80.000
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 254/300 lr=0.00022 - loss:0.125, acc:96.799, val_loss:0.202, val_acc:78.125
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 255/300 lr=0.00022 - loss:0.125, acc:97.027, val_loss:0.188, val_acc:78.750
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 256/300 lr=0.00022 - loss:0.124, acc:97.485, val_loss:0.166, val_acc:81.250
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 257/300 lr=0.00022 - loss:0.126, acc:96.875, val_loss:0.172, val_acc:79.375
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 258/300 lr=0.00022 - loss:0.127, acc:96.189, val_loss:0.187, val_acc:79.375
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 259/300 lr=0.00022 - loss:0.125, acc:96.799, val_loss:0.165, val_acc:82.500
# Best loss:0.165, Best accuracy:80.625, Best F1-score:80.256
# 260/300 lr=0.00022 - loss:0.122, acc:97.027, val_loss:0.173, val_acc:80.625
# Best loss:0.165, Best accuracy:82.500, Best F1-score:81.279
# 261/300 lr=0.00022 - loss:0.125, acc:97.104, val_loss:0.199, val_acc:77.500
# Best loss:0.165, Best accuracy:82.500, Best F1-score:81.279
# 262/300 lr=0.00019 - loss:0.124, acc:96.799, val_loss:0.172, val_acc:80.000
# Best loss:0.165, Best accuracy:82.500, Best F1-score:81.279
# 263/300 lr=0.00019 - loss:0.119, acc:98.095, val_loss:0.189, val_acc:78.750
# Best loss:0.165, Best accuracy:82.500, Best F1-score:81.279
# 264/300 lr=0.00019 - loss:0.123, acc:97.409, val_loss:0.191, val_acc:78.750
# Best loss:0.165, Best accuracy:82.500, Best F1-score:81.279
# 265/300 lr=0.00019 - loss:0.123, acc:96.646, val_loss:0.164, val_acc:81.875
# Best loss:0.165, Best accuracy:82.500, Best F1-score:81.279
# 266/300 lr=0.00019 - loss:0.122, acc:96.951, val_loss:0.187, val_acc:78.125
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 267/300 lr=0.00019 - loss:0.123, acc:97.180, val_loss:0.186, val_acc:77.500
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 268/300 lr=0.00019 - loss:0.123, acc:97.027, val_loss:0.174, val_acc:80.625
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 269/300 lr=0.00019 - loss:0.122, acc:97.713, val_loss:0.187, val_acc:79.375
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 270/300 lr=0.00019 - loss:0.125, acc:96.646, val_loss:0.184, val_acc:78.125
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 271/300 lr=0.00019 - loss:0.120, acc:97.561, val_loss:0.178, val_acc:78.125
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 272/300 lr=0.00019 - loss:0.119, acc:97.637, val_loss:0.174, val_acc:81.875
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 273/300 lr=0.00019 - loss:0.122, acc:97.485, val_loss:0.184, val_acc:78.125
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 274/300 lr=0.00019 - loss:0.120, acc:97.561, val_loss:0.191, val_acc:78.750
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 275/300 lr=0.00019 - loss:0.122, acc:97.561, val_loss:0.190, val_acc:80.000
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 276/300 lr=0.00019 - loss:0.122, acc:97.713, val_loss:0.184, val_acc:79.375
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 277/300 lr=0.00019 - loss:0.122, acc:97.485, val_loss:0.185, val_acc:80.625
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 278/300 lr=0.00019 - loss:0.118, acc:97.713, val_loss:0.181, val_acc:78.125
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 279/300 lr=0.00019 - loss:0.120, acc:97.942, val_loss:0.191, val_acc:76.250
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 280/300 lr=0.00019 - loss:0.123, acc:97.409, val_loss:0.203, val_acc:75.625
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 281/300 lr=0.00019 - loss:0.119, acc:98.171, val_loss:0.176, val_acc:80.625
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 282/300 lr=0.00017 - loss:0.125, acc:96.875, val_loss:0.198, val_acc:76.875
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 283/300 lr=0.00017 - loss:0.119, acc:97.866, val_loss:0.191, val_acc:76.250
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 284/300 lr=0.00017 - loss:0.119, acc:97.790, val_loss:0.190, val_acc:78.125
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 285/300 lr=0.00017 - loss:0.122, acc:97.332, val_loss:0.186, val_acc:75.625
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 286/300 lr=0.00017 - loss:0.121, acc:97.637, val_loss:0.180, val_acc:77.500
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 287/300 lr=0.00017 - loss:0.119, acc:97.637, val_loss:0.193, val_acc:76.875
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 288/300 lr=0.00017 - loss:0.119, acc:97.790, val_loss:0.194, val_acc:76.250
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 289/300 lr=0.00017 - loss:0.119, acc:97.942, val_loss:0.163, val_acc:83.125
# Best loss:0.164, Best accuracy:81.875, Best F1-score:80.924
# 290/300 lr=0.00017 - loss:0.119, acc:97.713, val_loss:0.199, val_acc:75.000
# Best loss:0.163, Best accuracy:83.125, Best F1-score:82.602
# 291/300 lr=0.00017 - loss:0.118, acc:98.095, val_loss:0.183, val_acc:77.500
# Best loss:0.163, Best accuracy:83.125, Best F1-score:82.602
# 292/300 lr=0.00017 - loss:0.117, acc:98.552, val_loss:0.182, val_acc:77.500
# Best loss:0.163, Best accuracy:83.125, Best F1-score:82.602
# 293/300 lr=0.00017 - loss:0.115, acc:98.399, val_loss:0.204, val_acc:76.875
# Best loss:0.163, Best accuracy:83.125, Best F1-score:82.602
# 294/300 lr=0.00017 - loss:0.120, acc:97.485, val_loss:0.181, val_acc:79.375
# Best loss:0.163, Best accuracy:83.125, Best F1-score:82.602
# 295/300 lr=0.00017 - loss:0.116, acc:98.018, val_loss:0.186, val_acc:76.875
# Best loss:0.163, Best accuracy:83.125, Best F1-score:82.602
# 296/300 lr=0.00017 - loss:0.116, acc:98.323, val_loss:0.187, val_acc:78.125
# Best loss:0.163, Best accuracy:83.125, Best F1-score:82.602
# 297/300 lr=0.00017 - loss:0.117, acc:98.323, val_loss:0.193, val_acc:75.625
# Best loss:0.163, Best accuracy:83.125, Best F1-score:82.602
# 298/300 lr=0.00017 - loss:0.115, acc:98.476, val_loss:0.162, val_acc:80.000
# Best loss:0.163, Best accuracy:83.125, Best F1-score:82.602
# 299/300 lr=0.00017 - loss:0.116, acc:98.323, val_loss:0.190, val_acc:77.500
# Best loss:0.162, Best accuracy:80.000, Best F1-score:79.259
# 300/300 lr=0.00017 - loss:0.120, acc:97.637, val_loss:0.183, val_acc:78.125
# Best loss:0.162, Best accuracy:80.000, Best F1-score:79.259
# ********************************************************************************
# [*] Done Fold-10
# best_val_loss:0.162, best_val_acc:80.000, best_val_f1:79.259
# test_acc:80.000, test_f1:79.259
# ********************************************************************************

# %%
end()

# %%
print('*' * 80)
print('[*] validation accuracy')
for i, val_acc in enumerate(fold_val_acc):
    print(f'    Fold-{i+1} : {val_acc}')
print(f'max:{max(fold_val_acc)}, min:{min(fold_val_acc)}, average:{sum(fold_val_acc)/len(fold_val_acc)}')
print('*' * 80)
print()

print('*' * 80)
print('[*] test accuracy')
for i, test_acc in enumerate(fold_test_acc):
    print(f'    Fold-{i+1} : {test_acc}')
print(f'max:{max(fold_test_acc)}, min:{min(fold_test_acc)}, average:{sum(fold_test_acc)/len(fold_test_acc)}')
print('*' * 80)
print()
# Out:
# ********************************************************************************
# [*] validation accuracy
#     Fold-1 : 80.625
#     Fold-2 : 80.625
#     Fold-3 : 85.625
#     Fold-4 : 85.0
#     Fold-5 : 84.375
#     Fold-6 : 86.25
#     Fold-7 : 90.625
#     Fold-8 : 81.875
#     Fold-9 : 85.0
#     Fold-10 : 80.0
# max:90.625, min:80.0, average:84.0
# ********************************************************************************
#
# ********************************************************************************
# [*] test accuracy
#     Fold-1 : 80.625
#     Fold-2 : 80.625
#     Fold-3 : 85.625
#     Fold-4 : 85.0
#     Fold-5 : 84.375
#     Fold-6 : 86.25
#     Fold-7 : 90.625
#     Fold-8 : 81.875
#     Fold-9 : 85.0
#     Fold-10 : 80.0
# max:90.625, min:80.0, average:84.0
# ********************************************************************************

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
# Out:
# WAR(Weighted Average Recall)   : 83.40%
# UAR(Unweighted Average Recall) : 83.40%
