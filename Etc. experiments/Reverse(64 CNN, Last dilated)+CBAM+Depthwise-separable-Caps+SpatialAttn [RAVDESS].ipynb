# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = 'TIMNET-dataset'
DATA_PATH = 'RAVDESS'
CLASS_LABELS = Config.RAVDESS_LABELS
k = 10

# 64-CNN * 2(Last CNN dilation=2) - CBAM - Depthwise-seperable - Reshape - Spatial-attention - Self-attention - Capsule
# Deltas : (196,39,6)
model_name = 'Reverse-RoutingConvNet(64 CNN, Last dilated)+CBAM+Depthwise-separable-Caps+SpatialAttn'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding=padding),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule], name='primarycap_reshape'),
        Lambda(function=PrimaryCapssquash, name='primarycap_squash')
    ])
    
  def call(self, inputs):
    x = self.conv(inputs)
    return x

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.cbam = CBAM(64) # sharing
    
    self.primarycap = PrimaryCap()
    self.spatial_attn = SpatialGate()
    
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    forward = inputs
    backward =tf.reverse(inputs, axis=[2])
    
    x = tf.concat([forward, backward], axis=-1)   # channel concat
    
    cap = self.conv1(x)
    cap = cap + self.cbam(cap)
    cap = self.conv2(cap)
    cap = cap + self.cbam(cap)
    
    primarycaps = self.primarycap(cap)
    primarycaps = tf.expand_dims(primarycaps, axis=-1)
    primarycaps = primarycaps + self.spatial_attn(primarycaps)
    primarycaps = tf.squeeze(primarycaps, axis=-1)
    
    cap = primarycaps
    
    sa = self.attention([primarycaps, primarycaps, primarycaps])
    sa = self.LN(sa)
    
    cap = self.lamb([cap, sa])
    
    capsule = self.capsule(cap)
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1992
#
#  sequential_1 (Sequential)   (None, 46, 7, 64)         37300
#
#  cbam (CBAM)                 multiple                  4294
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  spatial_gate_1 (SpatialGate  multiple                 102
#  )
#
#  attention (Attention)       multiple                  1
#
#  layer_normalization (LayerN  multiple                 128
#  ormalization)
#
#  lambda (Lambda)             multiple                  0
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  520
#
# =================================================================
# Total params: 94,513
# Trainable params: 93,935
# Non-trainable params: 578
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}.npy', 'rb') as f:
    x = np.load(f)
    y = np.load(f)

y = to_categorical(y,num_classes=len(CLASS_LABELS))

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, test) in tqdm(enumerate(kfold.split(x, y)), desc=f'Training {k}-Fold.....'):
    if i < 6:
        continue
    
    now_time = datetime.now().strftime("%m-%d-%H%M%S")
    
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = x[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_test, y_test = x[test], y[test]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_test = tf.expand_dims(x_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_test_loss = 0x3f3f3f
    best_test_acc = -1
    best_test_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        test_loss, test_acc, f1s = [], [], []
        for features, labels in batch_test:
            loss, acc, pred = test_step(model, features, labels)
            test_loss.append(loss)
            test_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(test_loss)/len(test_loss)
        val_acc = sum(test_acc)/len(test_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_test_loss:.3f}, Best accuracy:{best_test_acc:.3f}, Best F1-score:{best_test_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_test_acc < val_acc:
            best_test_acc = val_acc
            best_test_loss = val_loss
            best_test_f1 = f1_score
            model.save_weights(h5_path)
            
            
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    best_pred = model(x_test, training=False)
    emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(y_test, axis=1))
    predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
    
    
    print(f'[*] Done - acc:{best_test_acc:.3f}')
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    fold_acc.append(best_test_acc)
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.632, acc:15.091, val_loss:0.635, val_acc:22.500
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.622, acc:23.247, val_loss:0.626, val_acc:17.500
# Best loss:0.635, Best accuracy:22.500, Best F1-score:0.152
# 3/300 lr=0.00100 - loss:0.611, acc:23.780, val_loss:0.615, val_acc:23.750
# Best loss:0.635, Best accuracy:22.500, Best F1-score:0.152
# 4/300 lr=0.00100 - loss:0.602, acc:27.210, val_loss:0.608, val_acc:27.500
# Best loss:0.615, Best accuracy:23.750, Best F1-score:0.171
# 5/300 lr=0.00100 - loss:0.594, acc:28.201, val_loss:0.591, val_acc:29.375
# Best loss:0.608, Best accuracy:27.500, Best F1-score:0.230
# 6/300 lr=0.00100 - loss:0.589, acc:29.573, val_loss:0.615, val_acc:21.250
# Best loss:0.591, Best accuracy:29.375, Best F1-score:0.252
# 7/300 lr=0.00100 - loss:0.590, acc:28.811, val_loss:0.609, val_acc:21.875
# Best loss:0.591, Best accuracy:29.375, Best F1-score:0.252
# 8/300 lr=0.00100 - loss:0.592, acc:28.430, val_loss:0.574, val_acc:32.500
# Best loss:0.591, Best accuracy:29.375, Best F1-score:0.252
# 9/300 lr=0.00100 - loss:0.580, acc:29.573, val_loss:0.556, val_acc:35.625
# Best loss:0.574, Best accuracy:32.500, Best F1-score:0.272
# 10/300 lr=0.00100 - loss:0.572, acc:32.774, val_loss:0.550, val_acc:36.875
# Best loss:0.556, Best accuracy:35.625, Best F1-score:0.310
# 11/300 lr=0.00100 - loss:0.567, acc:31.555, val_loss:0.547, val_acc:36.250
# Best loss:0.550, Best accuracy:36.875, Best F1-score:0.312
# 12/300 lr=0.00100 - loss:0.571, acc:31.631, val_loss:0.533, val_acc:38.750
# Best loss:0.550, Best accuracy:36.875, Best F1-score:0.312
# 13/300 lr=0.00100 - loss:0.557, acc:34.451, val_loss:0.516, val_acc:43.750
# Best loss:0.533, Best accuracy:38.750, Best F1-score:0.301
# 14/300 lr=0.00100 - loss:0.547, acc:35.442, val_loss:0.516, val_acc:43.750
# Best loss:0.516, Best accuracy:43.750, Best F1-score:0.400
# 15/300 lr=0.00100 - loss:0.539, acc:38.720, val_loss:0.540, val_acc:34.375
# Best loss:0.516, Best accuracy:43.750, Best F1-score:0.400
# 16/300 lr=0.00100 - loss:0.537, acc:37.881, val_loss:0.504, val_acc:43.125
# Best loss:0.516, Best accuracy:43.750, Best F1-score:0.400
# 17/300 lr=0.00100 - loss:0.529, acc:39.634, val_loss:0.487, val_acc:44.375
# Best loss:0.516, Best accuracy:43.750, Best F1-score:0.400
# 18/300 lr=0.00100 - loss:0.524, acc:39.253, val_loss:0.481, val_acc:47.500
# Best loss:0.487, Best accuracy:44.375, Best F1-score:0.428
# 19/300 lr=0.00100 - loss:0.509, acc:43.293, val_loss:0.465, val_acc:52.500
# Best loss:0.481, Best accuracy:47.500, Best F1-score:0.456
# 20/300 lr=0.00100 - loss:0.501, acc:44.817, val_loss:0.478, val_acc:46.875
# Best loss:0.465, Best accuracy:52.500, Best F1-score:0.493
# 21/300 lr=0.00100 - loss:0.503, acc:43.064, val_loss:0.470, val_acc:45.625
# Best loss:0.465, Best accuracy:52.500, Best F1-score:0.493
# 22/300 lr=0.00100 - loss:0.499, acc:42.683, val_loss:0.479, val_acc:41.875
# Best loss:0.465, Best accuracy:52.500, Best F1-score:0.493
# 23/300 lr=0.00100 - loss:0.494, acc:44.131, val_loss:0.458, val_acc:46.250
# Best loss:0.465, Best accuracy:52.500, Best F1-score:0.493
# 24/300 lr=0.00100 - loss:0.485, acc:48.323, val_loss:0.453, val_acc:45.625
# Best loss:0.465, Best accuracy:52.500, Best F1-score:0.493
# 25/300 lr=0.00100 - loss:0.480, acc:46.951, val_loss:0.430, val_acc:52.500
# Best loss:0.465, Best accuracy:52.500, Best F1-score:0.493
# 26/300 lr=0.00100 - loss:0.475, acc:48.323, val_loss:0.447, val_acc:46.875
# Best loss:0.465, Best accuracy:52.500, Best F1-score:0.493
# 27/300 lr=0.00100 - loss:0.469, acc:49.085, val_loss:0.420, val_acc:51.875
# Best loss:0.465, Best accuracy:52.500, Best F1-score:0.493
# 28/300 lr=0.00100 - loss:0.460, acc:48.476, val_loss:0.434, val_acc:52.500
# Best loss:0.465, Best accuracy:52.500, Best F1-score:0.493
# 29/300 lr=0.00100 - loss:0.465, acc:49.162, val_loss:0.429, val_acc:51.875
# Best loss:0.465, Best accuracy:52.500, Best F1-score:0.493
# 30/300 lr=0.00100 - loss:0.456, acc:50.534, val_loss:0.421, val_acc:55.000
# Best loss:0.465, Best accuracy:52.500, Best F1-score:0.493
# 31/300 lr=0.00100 - loss:0.446, acc:52.134, val_loss:0.405, val_acc:51.250
# Best loss:0.421, Best accuracy:55.000, Best F1-score:0.512
# 32/300 lr=0.00100 - loss:0.444, acc:53.354, val_loss:0.396, val_acc:52.500
# Best loss:0.421, Best accuracy:55.000, Best F1-score:0.512
# 33/300 lr=0.00100 - loss:0.450, acc:51.982, val_loss:0.420, val_acc:48.750
# Best loss:0.421, Best accuracy:55.000, Best F1-score:0.512
# 34/300 lr=0.00100 - loss:0.452, acc:51.524, val_loss:0.433, val_acc:48.125
# Best loss:0.421, Best accuracy:55.000, Best F1-score:0.512
# 35/300 lr=0.00100 - loss:0.450, acc:51.296, val_loss:0.403, val_acc:51.250
# Best loss:0.421, Best accuracy:55.000, Best F1-score:0.512
# 36/300 lr=0.00100 - loss:0.432, acc:54.116, val_loss:0.382, val_acc:57.500
# Best loss:0.421, Best accuracy:55.000, Best F1-score:0.512
# 37/300 lr=0.00100 - loss:0.420, acc:56.174, val_loss:0.387, val_acc:55.625
# Best loss:0.382, Best accuracy:57.500, Best F1-score:0.551
# 38/300 lr=0.00100 - loss:0.421, acc:56.631, val_loss:0.382, val_acc:55.000
# Best loss:0.382, Best accuracy:57.500, Best F1-score:0.551
# 39/300 lr=0.00100 - loss:0.417, acc:56.631, val_loss:0.373, val_acc:58.125
# Best loss:0.382, Best accuracy:57.500, Best F1-score:0.551
# 40/300 lr=0.00100 - loss:0.410, acc:57.088, val_loss:0.373, val_acc:56.250
# Best loss:0.373, Best accuracy:58.125, Best F1-score:0.541
# 41/300 lr=0.00100 - loss:0.406, acc:57.622, val_loss:0.393, val_acc:51.875
# Best loss:0.373, Best accuracy:58.125, Best F1-score:0.541
# 42/300 lr=0.00100 - loss:0.417, acc:55.335, val_loss:0.360, val_acc:60.000
# Best loss:0.373, Best accuracy:58.125, Best F1-score:0.541
# 43/300 lr=0.00100 - loss:0.419, acc:55.335, val_loss:0.379, val_acc:57.500
# Best loss:0.360, Best accuracy:60.000, Best F1-score:0.578
# 44/300 lr=0.00100 - loss:0.410, acc:56.784, val_loss:0.378, val_acc:55.625
# Best loss:0.360, Best accuracy:60.000, Best F1-score:0.578
# 45/300 lr=0.00100 - loss:0.417, acc:55.793, val_loss:0.411, val_acc:47.500
# Best loss:0.360, Best accuracy:60.000, Best F1-score:0.578
# 46/300 lr=0.00100 - loss:0.404, acc:57.393, val_loss:0.372, val_acc:58.125
# Best loss:0.360, Best accuracy:60.000, Best F1-score:0.578
# 47/300 lr=0.00100 - loss:0.398, acc:59.451, val_loss:0.383, val_acc:52.500
# Best loss:0.360, Best accuracy:60.000, Best F1-score:0.578
# 48/300 lr=0.00100 - loss:0.395, acc:59.451, val_loss:0.348, val_acc:60.625
# Best loss:0.360, Best accuracy:60.000, Best F1-score:0.578
# 49/300 lr=0.00100 - loss:0.398, acc:57.927, val_loss:0.345, val_acc:62.500
# Best loss:0.348, Best accuracy:60.625, Best F1-score:0.598
# 50/300 lr=0.00100 - loss:0.388, acc:60.290, val_loss:0.338, val_acc:60.000
# Best loss:0.345, Best accuracy:62.500, Best F1-score:0.604
# 51/300 lr=0.00100 - loss:0.381, acc:61.280, val_loss:0.349, val_acc:59.375
# Best loss:0.345, Best accuracy:62.500, Best F1-score:0.604
# 52/300 lr=0.00100 - loss:0.386, acc:61.128, val_loss:0.371, val_acc:53.750
# Best loss:0.345, Best accuracy:62.500, Best F1-score:0.604
# 53/300 lr=0.00100 - loss:0.386, acc:59.375, val_loss:0.335, val_acc:57.500
# Best loss:0.345, Best accuracy:62.500, Best F1-score:0.604
# 54/300 lr=0.00100 - loss:0.378, acc:61.966, val_loss:0.335, val_acc:61.250
# Best loss:0.345, Best accuracy:62.500, Best F1-score:0.604
# 55/300 lr=0.00100 - loss:0.377, acc:62.119, val_loss:0.350, val_acc:56.250
# Best loss:0.345, Best accuracy:62.500, Best F1-score:0.604
# 56/300 lr=0.00100 - loss:0.379, acc:61.204, val_loss:0.338, val_acc:61.250
# Best loss:0.345, Best accuracy:62.500, Best F1-score:0.604
# 57/300 lr=0.00100 - loss:0.376, acc:61.204, val_loss:0.328, val_acc:59.375
# Best loss:0.345, Best accuracy:62.500, Best F1-score:0.604
# 58/300 lr=0.00100 - loss:0.359, acc:63.872, val_loss:0.339, val_acc:60.000
# Best loss:0.345, Best accuracy:62.500, Best F1-score:0.604
# 59/300 lr=0.00100 - loss:0.350, acc:66.235, val_loss:0.315, val_acc:64.375
# Best loss:0.345, Best accuracy:62.500, Best F1-score:0.604
# 60/300 lr=0.00100 - loss:0.360, acc:63.948, val_loss:0.318, val_acc:63.125
# Best loss:0.315, Best accuracy:64.375, Best F1-score:0.619
# 61/300 lr=0.00100 - loss:0.348, acc:66.082, val_loss:0.314, val_acc:60.625
# Best loss:0.315, Best accuracy:64.375, Best F1-score:0.619
# 62/300 lr=0.00086 - loss:0.353, acc:65.091, val_loss:0.331, val_acc:61.875
# Best loss:0.315, Best accuracy:64.375, Best F1-score:0.619
# 63/300 lr=0.00086 - loss:0.349, acc:65.320, val_loss:0.308, val_acc:66.250
# Best loss:0.315, Best accuracy:64.375, Best F1-score:0.619
# 64/300 lr=0.00086 - loss:0.350, acc:65.777, val_loss:0.304, val_acc:63.125
# Best loss:0.308, Best accuracy:66.250, Best F1-score:0.639
# 65/300 lr=0.00086 - loss:0.333, acc:68.902, val_loss:0.296, val_acc:66.875
# Best loss:0.308, Best accuracy:66.250, Best F1-score:0.639
# 66/300 lr=0.00086 - loss:0.337, acc:67.683, val_loss:0.303, val_acc:61.250
# Best loss:0.296, Best accuracy:66.875, Best F1-score:0.654
# 67/300 lr=0.00086 - loss:0.328, acc:69.588, val_loss:0.331, val_acc:61.875
# Best loss:0.296, Best accuracy:66.875, Best F1-score:0.654
# 68/300 lr=0.00086 - loss:0.327, acc:68.598, val_loss:0.278, val_acc:63.750
# Best loss:0.296, Best accuracy:66.875, Best F1-score:0.654
# 69/300 lr=0.00086 - loss:0.327, acc:69.055, val_loss:0.292, val_acc:66.250
# Best loss:0.296, Best accuracy:66.875, Best F1-score:0.654
# 70/300 lr=0.00086 - loss:0.325, acc:69.512, val_loss:0.302, val_acc:64.375
# Best loss:0.296, Best accuracy:66.875, Best F1-score:0.654
# 71/300 lr=0.00086 - loss:0.316, acc:71.037, val_loss:0.310, val_acc:61.875
# Best loss:0.296, Best accuracy:66.875, Best F1-score:0.654
# 72/300 lr=0.00086 - loss:0.322, acc:69.360, val_loss:0.298, val_acc:59.375
# Best loss:0.296, Best accuracy:66.875, Best F1-score:0.654
# 73/300 lr=0.00086 - loss:0.318, acc:70.503, val_loss:0.292, val_acc:64.375
# Best loss:0.296, Best accuracy:66.875, Best F1-score:0.654
# 74/300 lr=0.00086 - loss:0.318, acc:69.588, val_loss:0.276, val_acc:68.125
# Best loss:0.296, Best accuracy:66.875, Best F1-score:0.654
# 75/300 lr=0.00086 - loss:0.318, acc:69.817, val_loss:0.271, val_acc:68.750
# Best loss:0.276, Best accuracy:68.125, Best F1-score:0.662
# 76/300 lr=0.00086 - loss:0.324, acc:70.046, val_loss:0.280, val_acc:65.625
# Best loss:0.271, Best accuracy:68.750, Best F1-score:0.679
# 77/300 lr=0.00086 - loss:0.323, acc:69.741, val_loss:0.304, val_acc:63.125
# Best loss:0.271, Best accuracy:68.750, Best F1-score:0.679
# 78/300 lr=0.00086 - loss:0.316, acc:71.113, val_loss:0.296, val_acc:60.000
# Best loss:0.271, Best accuracy:68.750, Best F1-score:0.679
# 79/300 lr=0.00086 - loss:0.305, acc:72.790, val_loss:0.302, val_acc:61.875
# Best loss:0.271, Best accuracy:68.750, Best F1-score:0.679
# 80/300 lr=0.00086 - loss:0.299, acc:73.628, val_loss:0.274, val_acc:66.250
# Best loss:0.271, Best accuracy:68.750, Best F1-score:0.679
# 81/300 lr=0.00086 - loss:0.296, acc:73.552, val_loss:0.256, val_acc:69.375
# Best loss:0.271, Best accuracy:68.750, Best F1-score:0.679
# 82/300 lr=0.00074 - loss:0.306, acc:70.732, val_loss:0.281, val_acc:68.125
# Best loss:0.256, Best accuracy:69.375, Best F1-score:0.689
# 83/300 lr=0.00074 - loss:0.305, acc:71.418, val_loss:0.271, val_acc:65.625
# Best loss:0.256, Best accuracy:69.375, Best F1-score:0.689
# 84/300 lr=0.00074 - loss:0.290, acc:74.238, val_loss:0.262, val_acc:71.250
# Best loss:0.256, Best accuracy:69.375, Best F1-score:0.689
# 85/300 lr=0.00074 - loss:0.287, acc:74.543, val_loss:0.254, val_acc:69.375
# Best loss:0.262, Best accuracy:71.250, Best F1-score:0.701
# 86/300 lr=0.00074 - loss:0.284, acc:74.619, val_loss:0.263, val_acc:69.375
# Best loss:0.262, Best accuracy:71.250, Best F1-score:0.701
# 87/300 lr=0.00074 - loss:0.279, acc:75.610, val_loss:0.263, val_acc:67.500
# Best loss:0.262, Best accuracy:71.250, Best F1-score:0.701
# 88/300 lr=0.00074 - loss:0.289, acc:73.857, val_loss:0.245, val_acc:69.375
# Best loss:0.262, Best accuracy:71.250, Best F1-score:0.701
# 89/300 lr=0.00074 - loss:0.273, acc:76.524, val_loss:0.252, val_acc:71.250
# Best loss:0.262, Best accuracy:71.250, Best F1-score:0.701
# 90/300 lr=0.00074 - loss:0.276, acc:75.534, val_loss:0.247, val_acc:73.125
# Best loss:0.262, Best accuracy:71.250, Best F1-score:0.701
# 91/300 lr=0.00074 - loss:0.265, acc:77.515, val_loss:0.249, val_acc:69.375
# Best loss:0.247, Best accuracy:73.125, Best F1-score:0.725
# 92/300 lr=0.00074 - loss:0.272, acc:77.134, val_loss:0.246, val_acc:70.625
# Best loss:0.247, Best accuracy:73.125, Best F1-score:0.725
# 93/300 lr=0.00074 - loss:0.275, acc:76.067, val_loss:0.243, val_acc:71.875
# Best loss:0.247, Best accuracy:73.125, Best F1-score:0.725
# 94/300 lr=0.00074 - loss:0.262, acc:78.506, val_loss:0.242, val_acc:71.250
# Best loss:0.247, Best accuracy:73.125, Best F1-score:0.725
# 95/300 lr=0.00074 - loss:0.269, acc:77.210, val_loss:0.232, val_acc:71.875
# Best loss:0.247, Best accuracy:73.125, Best F1-score:0.725
# 96/300 lr=0.00074 - loss:0.254, acc:78.811, val_loss:0.229, val_acc:73.750
# Best loss:0.247, Best accuracy:73.125, Best F1-score:0.725
# 97/300 lr=0.00074 - loss:0.252, acc:79.726, val_loss:0.230, val_acc:70.625
# Best loss:0.229, Best accuracy:73.750, Best F1-score:0.732
# 98/300 lr=0.00074 - loss:0.260, acc:78.582, val_loss:0.271, val_acc:66.250
# Best loss:0.229, Best accuracy:73.750, Best F1-score:0.732
# 99/300 lr=0.00074 - loss:0.264, acc:77.744, val_loss:0.260, val_acc:69.375
# Best loss:0.229, Best accuracy:73.750, Best F1-score:0.732
# 100/300 lr=0.00074 - loss:0.263, acc:79.192, val_loss:0.234, val_acc:70.625
# Best loss:0.229, Best accuracy:73.750, Best F1-score:0.732
# 101/300 lr=0.00074 - loss:0.262, acc:76.677, val_loss:0.219, val_acc:73.750
# Best loss:0.229, Best accuracy:73.750, Best F1-score:0.732
# 102/300 lr=0.00064 - loss:0.264, acc:77.591, val_loss:0.212, val_acc:73.125
# Best loss:0.229, Best accuracy:73.750, Best F1-score:0.732
# 103/300 lr=0.00064 - loss:0.263, acc:77.134, val_loss:0.240, val_acc:71.250
# Best loss:0.229, Best accuracy:73.750, Best F1-score:0.732
# 104/300 lr=0.00064 - loss:0.254, acc:80.030, val_loss:0.236, val_acc:71.250
# Best loss:0.229, Best accuracy:73.750, Best F1-score:0.732
# 105/300 lr=0.00064 - loss:0.256, acc:78.277, val_loss:0.233, val_acc:71.250
# Best loss:0.229, Best accuracy:73.750, Best F1-score:0.732
# 106/300 lr=0.00064 - loss:0.246, acc:79.878, val_loss:0.215, val_acc:76.250
# Best loss:0.229, Best accuracy:73.750, Best F1-score:0.732
# 107/300 lr=0.00064 - loss:0.238, acc:81.402, val_loss:0.192, val_acc:76.250
# Best loss:0.215, Best accuracy:76.250, Best F1-score:0.765
# 108/300 lr=0.00064 - loss:0.245, acc:80.640, val_loss:0.206, val_acc:77.500
# Best loss:0.215, Best accuracy:76.250, Best F1-score:0.765
# 109/300 lr=0.00064 - loss:0.239, acc:81.326, val_loss:0.231, val_acc:72.500
# Best loss:0.206, Best accuracy:77.500, Best F1-score:0.780
# 110/300 lr=0.00064 - loss:0.224, acc:83.460, val_loss:0.222, val_acc:75.000
# Best loss:0.206, Best accuracy:77.500, Best F1-score:0.780
# 111/300 lr=0.00064 - loss:0.240, acc:81.555, val_loss:0.211, val_acc:73.125
# Best loss:0.206, Best accuracy:77.500, Best F1-score:0.780
# 112/300 lr=0.00064 - loss:0.233, acc:82.088, val_loss:0.207, val_acc:73.125
# Best loss:0.206, Best accuracy:77.500, Best F1-score:0.780
# 113/300 lr=0.00064 - loss:0.245, acc:79.954, val_loss:0.204, val_acc:75.625
# Best loss:0.206, Best accuracy:77.500, Best F1-score:0.780
# 114/300 lr=0.00064 - loss:0.233, acc:82.470, val_loss:0.215, val_acc:76.875
# Best loss:0.206, Best accuracy:77.500, Best F1-score:0.780
# 115/300 lr=0.00064 - loss:0.238, acc:80.869, val_loss:0.228, val_acc:71.875
# Best loss:0.206, Best accuracy:77.500, Best F1-score:0.780
# 116/300 lr=0.00064 - loss:0.229, acc:83.308, val_loss:0.225, val_acc:71.875
# Best loss:0.206, Best accuracy:77.500, Best F1-score:0.780
# 117/300 lr=0.00064 - loss:0.234, acc:81.936, val_loss:0.210, val_acc:74.375
# Best loss:0.206, Best accuracy:77.500, Best F1-score:0.780
# 118/300 lr=0.00064 - loss:0.246, acc:78.659, val_loss:0.196, val_acc:76.250
# Best loss:0.206, Best accuracy:77.500, Best F1-score:0.780
# 119/300 lr=0.00064 - loss:0.238, acc:81.021, val_loss:0.215, val_acc:73.750
# Best loss:0.206, Best accuracy:77.500, Best F1-score:0.780
# 120/300 lr=0.00064 - loss:0.222, acc:82.546, val_loss:0.194, val_acc:78.125
# Best loss:0.206, Best accuracy:77.500, Best F1-score:0.780
# 121/300 lr=0.00064 - loss:0.224, acc:82.698, val_loss:0.190, val_acc:78.125
# Best loss:0.194, Best accuracy:78.125, Best F1-score:0.783
# 122/300 lr=0.00055 - loss:0.226, acc:83.918, val_loss:0.179, val_acc:77.500
# Best loss:0.194, Best accuracy:78.125, Best F1-score:0.783
# 123/300 lr=0.00055 - loss:0.224, acc:83.308, val_loss:0.176, val_acc:80.000
# Best loss:0.194, Best accuracy:78.125, Best F1-score:0.783
# 124/300 lr=0.00055 - loss:0.221, acc:83.918, val_loss:0.193, val_acc:76.875
# Best loss:0.176, Best accuracy:80.000, Best F1-score:0.805
# 125/300 lr=0.00055 - loss:0.223, acc:83.384, val_loss:0.222, val_acc:73.125
# Best loss:0.176, Best accuracy:80.000, Best F1-score:0.805
# 126/300 lr=0.00055 - loss:0.215, acc:84.909, val_loss:0.202, val_acc:78.125
# Best loss:0.176, Best accuracy:80.000, Best F1-score:0.805
# 127/300 lr=0.00055 - loss:0.214, acc:84.146, val_loss:0.213, val_acc:75.000
# Best loss:0.176, Best accuracy:80.000, Best F1-score:0.805
# 128/300 lr=0.00055 - loss:0.210, acc:85.061, val_loss:0.192, val_acc:80.625
# Best loss:0.176, Best accuracy:80.000, Best F1-score:0.805
# 129/300 lr=0.00055 - loss:0.217, acc:84.299, val_loss:0.189, val_acc:80.625
# Best loss:0.192, Best accuracy:80.625, Best F1-score:0.806
# 130/300 lr=0.00055 - loss:0.201, acc:86.738, val_loss:0.193, val_acc:78.750
# Best loss:0.192, Best accuracy:80.625, Best F1-score:0.806
# 131/300 lr=0.00055 - loss:0.220, acc:83.994, val_loss:0.188, val_acc:80.000
# Best loss:0.192, Best accuracy:80.625, Best F1-score:0.806
# 132/300 lr=0.00055 - loss:0.220, acc:83.841, val_loss:0.215, val_acc:75.000
# Best loss:0.192, Best accuracy:80.625, Best F1-score:0.806
# 133/300 lr=0.00055 - loss:0.213, acc:84.223, val_loss:0.181, val_acc:81.250
# Best loss:0.192, Best accuracy:80.625, Best F1-score:0.806
# 134/300 lr=0.00055 - loss:0.210, acc:85.976, val_loss:0.209, val_acc:76.250
# Best loss:0.181, Best accuracy:81.250, Best F1-score:0.815
# 135/300 lr=0.00055 - loss:0.212, acc:85.366, val_loss:0.231, val_acc:75.625
# Best loss:0.181, Best accuracy:81.250, Best F1-score:0.815
# 136/300 lr=0.00055 - loss:0.208, acc:85.671, val_loss:0.211, val_acc:77.500
# Best loss:0.181, Best accuracy:81.250, Best F1-score:0.815
# 137/300 lr=0.00055 - loss:0.207, acc:86.128, val_loss:0.214, val_acc:75.000
# Best loss:0.181, Best accuracy:81.250, Best F1-score:0.815
# 138/300 lr=0.00055 - loss:0.218, acc:84.451, val_loss:0.184, val_acc:80.000
# Best loss:0.181, Best accuracy:81.250, Best F1-score:0.815
# 139/300 lr=0.00055 - loss:0.208, acc:85.213, val_loss:0.158, val_acc:81.875
# Best loss:0.181, Best accuracy:81.250, Best F1-score:0.815
# 140/300 lr=0.00055 - loss:0.210, acc:83.918, val_loss:0.168, val_acc:78.750
# Best loss:0.158, Best accuracy:81.875, Best F1-score:0.818
# 141/300 lr=0.00055 - loss:0.202, acc:86.128, val_loss:0.151, val_acc:84.375
# Best loss:0.158, Best accuracy:81.875, Best F1-score:0.818
# 142/300 lr=0.00047 - loss:0.192, acc:88.110, val_loss:0.181, val_acc:76.250
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 143/300 lr=0.00047 - loss:0.198, acc:86.662, val_loss:0.171, val_acc:80.000
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 144/300 lr=0.00047 - loss:0.193, acc:88.110, val_loss:0.176, val_acc:79.375
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 145/300 lr=0.00047 - loss:0.191, acc:88.338, val_loss:0.169, val_acc:82.500
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 146/300 lr=0.00047 - loss:0.198, acc:86.814, val_loss:0.163, val_acc:81.250
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 147/300 lr=0.00047 - loss:0.196, acc:87.119, val_loss:0.187, val_acc:79.375
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 148/300 lr=0.00047 - loss:0.183, acc:89.024, val_loss:0.170, val_acc:81.250
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 149/300 lr=0.00047 - loss:0.186, acc:89.710, val_loss:0.177, val_acc:80.000
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 150/300 lr=0.00047 - loss:0.189, acc:87.500, val_loss:0.163, val_acc:81.250
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 151/300 lr=0.00047 - loss:0.188, acc:89.787, val_loss:0.172, val_acc:82.500
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 152/300 lr=0.00047 - loss:0.193, acc:87.805, val_loss:0.185, val_acc:80.000
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 153/300 lr=0.00047 - loss:0.183, acc:89.253, val_loss:0.182, val_acc:78.750
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 154/300 lr=0.00047 - loss:0.183, acc:89.253, val_loss:0.156, val_acc:81.875
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 155/300 lr=0.00047 - loss:0.190, acc:87.271, val_loss:0.167, val_acc:83.750
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 156/300 lr=0.00047 - loss:0.191, acc:87.500, val_loss:0.168, val_acc:78.750
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 157/300 lr=0.00047 - loss:0.182, acc:89.710, val_loss:0.166, val_acc:80.000
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 158/300 lr=0.00047 - loss:0.182, acc:89.787, val_loss:0.163, val_acc:80.625
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 159/300 lr=0.00047 - loss:0.186, acc:88.567, val_loss:0.183, val_acc:76.875
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 160/300 lr=0.00047 - loss:0.188, acc:88.415, val_loss:0.206, val_acc:75.625
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 161/300 lr=0.00047 - loss:0.188, acc:88.720, val_loss:0.194, val_acc:78.125
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 162/300 lr=0.00041 - loss:0.174, acc:90.625, val_loss:0.193, val_acc:80.625
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 163/300 lr=0.00041 - loss:0.179, acc:89.482, val_loss:0.171, val_acc:81.250
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 164/300 lr=0.00041 - loss:0.175, acc:90.549, val_loss:0.167, val_acc:81.875
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 165/300 lr=0.00041 - loss:0.173, acc:90.320, val_loss:0.183, val_acc:79.375
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 166/300 lr=0.00041 - loss:0.173, acc:89.710, val_loss:0.164, val_acc:80.000
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 167/300 lr=0.00041 - loss:0.174, acc:90.625, val_loss:0.185, val_acc:79.375
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 168/300 lr=0.00041 - loss:0.185, acc:88.262, val_loss:0.158, val_acc:85.000
# Best loss:0.151, Best accuracy:84.375, Best F1-score:0.843
# 169/300 lr=0.00041 - loss:0.177, acc:90.396, val_loss:0.152, val_acc:80.625
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 170/300 lr=0.00041 - loss:0.169, acc:91.311, val_loss:0.174, val_acc:79.375
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 171/300 lr=0.00041 - loss:0.184, acc:89.329, val_loss:0.164, val_acc:79.375
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 172/300 lr=0.00041 - loss:0.180, acc:89.329, val_loss:0.170, val_acc:81.250
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 173/300 lr=0.00041 - loss:0.175, acc:89.939, val_loss:0.155, val_acc:82.500
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 174/300 lr=0.00041 - loss:0.176, acc:90.015, val_loss:0.188, val_acc:75.625
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 175/300 lr=0.00041 - loss:0.174, acc:91.082, val_loss:0.165, val_acc:81.875
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 176/300 lr=0.00041 - loss:0.170, acc:91.692, val_loss:0.170, val_acc:81.250
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 177/300 lr=0.00041 - loss:0.171, acc:90.625, val_loss:0.171, val_acc:83.125
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 178/300 lr=0.00041 - loss:0.170, acc:90.930, val_loss:0.164, val_acc:81.250
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 179/300 lr=0.00041 - loss:0.170, acc:90.930, val_loss:0.190, val_acc:81.250
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 180/300 lr=0.00041 - loss:0.165, acc:91.616, val_loss:0.158, val_acc:84.375
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 181/300 lr=0.00041 - loss:0.173, acc:90.701, val_loss:0.162, val_acc:80.625
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 182/300 lr=0.00035 - loss:0.167, acc:91.845, val_loss:0.164, val_acc:80.625
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 183/300 lr=0.00035 - loss:0.161, acc:91.997, val_loss:0.150, val_acc:84.375
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 184/300 lr=0.00035 - loss:0.162, acc:92.530, val_loss:0.164, val_acc:83.750
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 185/300 lr=0.00035 - loss:0.164, acc:91.768, val_loss:0.157, val_acc:81.250
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 186/300 lr=0.00035 - loss:0.166, acc:91.006, val_loss:0.150, val_acc:80.625
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 187/300 lr=0.00035 - loss:0.169, acc:90.244, val_loss:0.164, val_acc:81.875
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 188/300 lr=0.00035 - loss:0.165, acc:91.845, val_loss:0.149, val_acc:80.625
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 189/300 lr=0.00035 - loss:0.169, acc:91.082, val_loss:0.144, val_acc:83.750
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 190/300 lr=0.00035 - loss:0.164, acc:91.463, val_loss:0.153, val_acc:85.000
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 191/300 lr=0.00035 - loss:0.159, acc:92.454, val_loss:0.178, val_acc:79.375
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 192/300 lr=0.00035 - loss:0.158, acc:92.226, val_loss:0.154, val_acc:83.125
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 193/300 lr=0.00035 - loss:0.159, acc:92.302, val_loss:0.165, val_acc:85.625
# Best loss:0.158, Best accuracy:85.000, Best F1-score:0.848
# 194/300 lr=0.00035 - loss:0.161, acc:92.454, val_loss:0.177, val_acc:81.875
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 195/300 lr=0.00035 - loss:0.164, acc:91.921, val_loss:0.154, val_acc:82.500
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 196/300 lr=0.00035 - loss:0.159, acc:92.149, val_loss:0.165, val_acc:81.250
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 197/300 lr=0.00035 - loss:0.161, acc:92.226, val_loss:0.160, val_acc:81.250
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 198/300 lr=0.00035 - loss:0.163, acc:92.073, val_loss:0.186, val_acc:81.250
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 199/300 lr=0.00035 - loss:0.156, acc:93.369, val_loss:0.163, val_acc:83.125
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 200/300 lr=0.00035 - loss:0.161, acc:91.921, val_loss:0.164, val_acc:82.500
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 201/300 lr=0.00035 - loss:0.158, acc:92.302, val_loss:0.153, val_acc:81.250
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 202/300 lr=0.00030 - loss:0.164, acc:91.082, val_loss:0.142, val_acc:84.375
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 203/300 lr=0.00030 - loss:0.166, acc:91.616, val_loss:0.157, val_acc:83.750
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 204/300 lr=0.00030 - loss:0.161, acc:92.149, val_loss:0.170, val_acc:80.625
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 205/300 lr=0.00030 - loss:0.161, acc:92.378, val_loss:0.141, val_acc:85.000
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 206/300 lr=0.00030 - loss:0.150, acc:94.131, val_loss:0.143, val_acc:85.000
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 207/300 lr=0.00030 - loss:0.153, acc:93.521, val_loss:0.156, val_acc:82.500
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 208/300 lr=0.00030 - loss:0.143, acc:94.817, val_loss:0.149, val_acc:83.750
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 209/300 lr=0.00030 - loss:0.149, acc:94.131, val_loss:0.151, val_acc:84.375
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 210/300 lr=0.00030 - loss:0.153, acc:92.988, val_loss:0.143, val_acc:84.375
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 211/300 lr=0.00030 - loss:0.149, acc:93.521, val_loss:0.153, val_acc:83.750
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 212/300 lr=0.00030 - loss:0.150, acc:93.216, val_loss:0.162, val_acc:82.500
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 213/300 lr=0.00030 - loss:0.156, acc:92.454, val_loss:0.148, val_acc:83.125
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 214/300 lr=0.00030 - loss:0.146, acc:94.588, val_loss:0.130, val_acc:85.625
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 215/300 lr=0.00030 - loss:0.153, acc:92.912, val_loss:0.158, val_acc:83.125
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 216/300 lr=0.00030 - loss:0.153, acc:93.140, val_loss:0.152, val_acc:83.750
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 217/300 lr=0.00030 - loss:0.150, acc:93.902, val_loss:0.139, val_acc:86.875
# Best loss:0.165, Best accuracy:85.625, Best F1-score:0.856
# 218/300 lr=0.00030 - loss:0.149, acc:94.055, val_loss:0.163, val_acc:83.125
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 219/300 lr=0.00030 - loss:0.149, acc:93.979, val_loss:0.161, val_acc:81.250
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 220/300 lr=0.00030 - loss:0.156, acc:92.149, val_loss:0.163, val_acc:81.875
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 221/300 lr=0.00030 - loss:0.152, acc:93.598, val_loss:0.163, val_acc:83.125
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 222/300 lr=0.00026 - loss:0.147, acc:94.207, val_loss:0.152, val_acc:85.000
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 223/300 lr=0.00026 - loss:0.147, acc:94.360, val_loss:0.142, val_acc:84.375
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 224/300 lr=0.00026 - loss:0.142, acc:95.122, val_loss:0.159, val_acc:81.250
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 225/300 lr=0.00026 - loss:0.147, acc:93.674, val_loss:0.157, val_acc:83.125
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 226/300 lr=0.00026 - loss:0.142, acc:95.122, val_loss:0.146, val_acc:83.125
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 227/300 lr=0.00026 - loss:0.149, acc:94.131, val_loss:0.157, val_acc:82.500
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 228/300 lr=0.00026 - loss:0.152, acc:93.369, val_loss:0.145, val_acc:83.750
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 229/300 lr=0.00026 - loss:0.147, acc:93.902, val_loss:0.144, val_acc:85.000
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 230/300 lr=0.00026 - loss:0.148, acc:93.598, val_loss:0.148, val_acc:82.500
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 231/300 lr=0.00026 - loss:0.149, acc:92.988, val_loss:0.140, val_acc:85.625
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 232/300 lr=0.00026 - loss:0.143, acc:94.665, val_loss:0.162, val_acc:81.875
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 233/300 lr=0.00026 - loss:0.147, acc:93.902, val_loss:0.150, val_acc:81.875
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 234/300 lr=0.00026 - loss:0.149, acc:93.369, val_loss:0.156, val_acc:81.875
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 235/300 lr=0.00026 - loss:0.140, acc:94.970, val_loss:0.153, val_acc:81.250
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 236/300 lr=0.00026 - loss:0.146, acc:94.360, val_loss:0.154, val_acc:81.250
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 237/300 lr=0.00026 - loss:0.151, acc:93.216, val_loss:0.172, val_acc:80.625
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 238/300 lr=0.00026 - loss:0.159, acc:92.530, val_loss:0.152, val_acc:85.625
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 239/300 lr=0.00026 - loss:0.149, acc:93.826, val_loss:0.158, val_acc:81.250
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 240/300 lr=0.00026 - loss:0.155, acc:93.064, val_loss:0.154, val_acc:83.750
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 241/300 lr=0.00026 - loss:0.140, acc:95.351, val_loss:0.148, val_acc:84.375
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 242/300 lr=0.00022 - loss:0.144, acc:93.902, val_loss:0.147, val_acc:81.250
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 243/300 lr=0.00022 - loss:0.143, acc:94.741, val_loss:0.144, val_acc:83.125
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 244/300 lr=0.00022 - loss:0.140, acc:94.588, val_loss:0.145, val_acc:83.750
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 245/300 lr=0.00022 - loss:0.142, acc:94.436, val_loss:0.138, val_acc:85.000
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 246/300 lr=0.00022 - loss:0.137, acc:95.503, val_loss:0.159, val_acc:82.500
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 247/300 lr=0.00022 - loss:0.141, acc:95.274, val_loss:0.141, val_acc:84.375
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 248/300 lr=0.00022 - loss:0.142, acc:94.893, val_loss:0.148, val_acc:83.750
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 249/300 lr=0.00022 - loss:0.137, acc:95.427, val_loss:0.141, val_acc:83.750
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 250/300 lr=0.00022 - loss:0.139, acc:95.579, val_loss:0.154, val_acc:81.875
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 251/300 lr=0.00022 - loss:0.143, acc:94.436, val_loss:0.155, val_acc:83.125
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 252/300 lr=0.00022 - loss:0.139, acc:94.970, val_loss:0.141, val_acc:84.375
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 253/300 lr=0.00022 - loss:0.135, acc:96.570, val_loss:0.142, val_acc:83.125
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 254/300 lr=0.00022 - loss:0.136, acc:95.884, val_loss:0.161, val_acc:81.250
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 255/300 lr=0.00022 - loss:0.139, acc:95.046, val_loss:0.143, val_acc:83.750
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 256/300 lr=0.00022 - loss:0.139, acc:95.351, val_loss:0.142, val_acc:86.875
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 257/300 lr=0.00022 - loss:0.141, acc:94.970, val_loss:0.147, val_acc:85.625
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 258/300 lr=0.00022 - loss:0.137, acc:95.808, val_loss:0.131, val_acc:86.875
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 259/300 lr=0.00022 - loss:0.144, acc:94.284, val_loss:0.153, val_acc:81.250
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 260/300 lr=0.00022 - loss:0.141, acc:94.893, val_loss:0.139, val_acc:83.125
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 261/300 lr=0.00022 - loss:0.140, acc:94.588, val_loss:0.150, val_acc:83.750
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 262/300 lr=0.00019 - loss:0.139, acc:94.970, val_loss:0.142, val_acc:85.625
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 263/300 lr=0.00019 - loss:0.137, acc:95.351, val_loss:0.156, val_acc:83.750
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 264/300 lr=0.00019 - loss:0.136, acc:95.427, val_loss:0.138, val_acc:85.625
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 265/300 lr=0.00019 - loss:0.134, acc:96.265, val_loss:0.161, val_acc:81.875
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 266/300 lr=0.00019 - loss:0.133, acc:95.579, val_loss:0.128, val_acc:84.375
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 267/300 lr=0.00019 - loss:0.137, acc:95.122, val_loss:0.147, val_acc:83.125
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 268/300 lr=0.00019 - loss:0.135, acc:95.655, val_loss:0.139, val_acc:85.625
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 269/300 lr=0.00019 - loss:0.133, acc:95.960, val_loss:0.151, val_acc:84.375
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 270/300 lr=0.00019 - loss:0.136, acc:95.351, val_loss:0.132, val_acc:83.750
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 271/300 lr=0.00019 - loss:0.136, acc:94.970, val_loss:0.154, val_acc:84.375
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 272/300 lr=0.00019 - loss:0.134, acc:95.732, val_loss:0.143, val_acc:84.375
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 273/300 lr=0.00019 - loss:0.137, acc:95.351, val_loss:0.157, val_acc:83.750
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 274/300 lr=0.00019 - loss:0.138, acc:95.427, val_loss:0.131, val_acc:85.000
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 275/300 lr=0.00019 - loss:0.139, acc:94.893, val_loss:0.144, val_acc:83.750
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 276/300 lr=0.00019 - loss:0.132, acc:95.884, val_loss:0.140, val_acc:83.750
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 277/300 lr=0.00019 - loss:0.131, acc:96.646, val_loss:0.152, val_acc:81.250
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 278/300 lr=0.00019 - loss:0.138, acc:95.046, val_loss:0.143, val_acc:84.375
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 279/300 lr=0.00019 - loss:0.138, acc:94.970, val_loss:0.154, val_acc:84.375
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 280/300 lr=0.00019 - loss:0.134, acc:95.655, val_loss:0.158, val_acc:85.000
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 281/300 lr=0.00019 - loss:0.139, acc:95.351, val_loss:0.141, val_acc:83.750
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 282/300 lr=0.00017 - loss:0.137, acc:95.351, val_loss:0.157, val_acc:80.625
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 283/300 lr=0.00017 - loss:0.133, acc:96.494, val_loss:0.150, val_acc:81.875
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 284/300 lr=0.00017 - loss:0.134, acc:96.113, val_loss:0.138, val_acc:83.750
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 285/300 lr=0.00017 - loss:0.132, acc:96.341, val_loss:0.139, val_acc:82.500
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 286/300 lr=0.00017 - loss:0.132, acc:95.960, val_loss:0.141, val_acc:83.125
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 287/300 lr=0.00017 - loss:0.138, acc:94.741, val_loss:0.143, val_acc:84.375
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 288/300 lr=0.00017 - loss:0.136, acc:95.427, val_loss:0.145, val_acc:83.125
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 289/300 lr=0.00017 - loss:0.135, acc:96.037, val_loss:0.131, val_acc:83.750
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 290/300 lr=0.00017 - loss:0.132, acc:96.341, val_loss:0.145, val_acc:82.500
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 291/300 lr=0.00017 - loss:0.133, acc:95.808, val_loss:0.157, val_acc:81.250
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 292/300 lr=0.00017 - loss:0.130, acc:96.570, val_loss:0.138, val_acc:85.625
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 293/300 lr=0.00017 - loss:0.133, acc:96.265, val_loss:0.155, val_acc:83.125
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 294/300 lr=0.00017 - loss:0.129, acc:96.570, val_loss:0.152, val_acc:83.125
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 295/300 lr=0.00017 - loss:0.132, acc:96.037, val_loss:0.140, val_acc:84.375
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 296/300 lr=0.00017 - loss:0.130, acc:96.951, val_loss:0.137, val_acc:85.000
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 297/300 lr=0.00017 - loss:0.134, acc:95.732, val_loss:0.156, val_acc:82.500
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 298/300 lr=0.00017 - loss:0.129, acc:96.646, val_loss:0.150, val_acc:84.375
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 299/300 lr=0.00017 - loss:0.129, acc:97.104, val_loss:0.136, val_acc:83.125
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# 300/300 lr=0.00017 - loss:0.130, acc:96.189, val_loss:0.155, val_acc:83.750
# Best loss:0.139, Best accuracy:86.875, Best F1-score:0.876
# [*] Done - acc:86.875
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.631, acc:17.073, val_loss:0.625, val_acc:22.500
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.618, acc:22.866, val_loss:0.613, val_acc:23.750
# Best loss:0.625, Best accuracy:22.500, Best F1-score:0.150
# 3/300 lr=0.00100 - loss:0.606, acc:25.381, val_loss:0.602, val_acc:23.750
# Best loss:0.613, Best accuracy:23.750, Best F1-score:0.165
# 4/300 lr=0.00100 - loss:0.602, acc:25.610, val_loss:0.601, val_acc:22.500
# Best loss:0.613, Best accuracy:23.750, Best F1-score:0.165
# 5/300 lr=0.00100 - loss:0.590, acc:29.726, val_loss:0.594, val_acc:23.125
# Best loss:0.613, Best accuracy:23.750, Best F1-score:0.165
# 6/300 lr=0.00100 - loss:0.587, acc:28.125, val_loss:0.571, val_acc:31.250
# Best loss:0.613, Best accuracy:23.750, Best F1-score:0.165
# 7/300 lr=0.00100 - loss:0.575, acc:31.555, val_loss:0.571, val_acc:30.625
# Best loss:0.571, Best accuracy:31.250, Best F1-score:0.243
# 8/300 lr=0.00100 - loss:0.574, acc:31.174, val_loss:0.559, val_acc:31.875
# Best loss:0.571, Best accuracy:31.250, Best F1-score:0.243
# 9/300 lr=0.00100 - loss:0.573, acc:32.165, val_loss:0.560, val_acc:30.000
# Best loss:0.559, Best accuracy:31.875, Best F1-score:0.260
# 10/300 lr=0.00100 - loss:0.576, acc:31.479, val_loss:0.564, val_acc:34.375
# Best loss:0.559, Best accuracy:31.875, Best F1-score:0.260
# 11/300 lr=0.00100 - loss:0.575, acc:30.412, val_loss:0.544, val_acc:34.375
# Best loss:0.564, Best accuracy:34.375, Best F1-score:0.260
# 12/300 lr=0.00100 - loss:0.561, acc:33.613, val_loss:0.551, val_acc:33.750
# Best loss:0.564, Best accuracy:34.375, Best F1-score:0.260
# 13/300 lr=0.00100 - loss:0.546, acc:36.052, val_loss:0.519, val_acc:42.500
# Best loss:0.564, Best accuracy:34.375, Best F1-score:0.260
# 14/300 lr=0.00100 - loss:0.535, acc:39.253, val_loss:0.502, val_acc:44.375
# Best loss:0.519, Best accuracy:42.500, Best F1-score:0.377
# 15/300 lr=0.00100 - loss:0.531, acc:39.710, val_loss:0.498, val_acc:41.875
# Best loss:0.502, Best accuracy:44.375, Best F1-score:0.398
# 16/300 lr=0.00100 - loss:0.526, acc:41.006, val_loss:0.489, val_acc:41.875
# Best loss:0.502, Best accuracy:44.375, Best F1-score:0.398
# 17/300 lr=0.00100 - loss:0.520, acc:40.244, val_loss:0.518, val_acc:33.125
# Best loss:0.502, Best accuracy:44.375, Best F1-score:0.398
# 18/300 lr=0.00100 - loss:0.510, acc:41.235, val_loss:0.506, val_acc:37.500
# Best loss:0.502, Best accuracy:44.375, Best F1-score:0.398
# 19/300 lr=0.00100 - loss:0.502, acc:43.674, val_loss:0.495, val_acc:42.500
# Best loss:0.502, Best accuracy:44.375, Best F1-score:0.398
# 20/300 lr=0.00100 - loss:0.497, acc:43.826, val_loss:0.479, val_acc:45.000
# Best loss:0.502, Best accuracy:44.375, Best F1-score:0.398
# 21/300 lr=0.00100 - loss:0.503, acc:41.692, val_loss:0.495, val_acc:41.875
# Best loss:0.479, Best accuracy:45.000, Best F1-score:0.425
# 22/300 lr=0.00100 - loss:0.492, acc:45.122, val_loss:0.464, val_acc:42.500
# Best loss:0.479, Best accuracy:45.000, Best F1-score:0.425
# 23/300 lr=0.00100 - loss:0.486, acc:45.274, val_loss:0.448, val_acc:48.125
# Best loss:0.479, Best accuracy:45.000, Best F1-score:0.425
# 24/300 lr=0.00100 - loss:0.476, acc:47.104, val_loss:0.439, val_acc:47.500
# Best loss:0.448, Best accuracy:48.125, Best F1-score:0.431
# 25/300 lr=0.00100 - loss:0.478, acc:46.799, val_loss:0.447, val_acc:50.625
# Best loss:0.448, Best accuracy:48.125, Best F1-score:0.431
# 26/300 lr=0.00100 - loss:0.474, acc:47.713, val_loss:0.425, val_acc:48.125
# Best loss:0.447, Best accuracy:50.625, Best F1-score:0.471
# 27/300 lr=0.00100 - loss:0.464, acc:48.552, val_loss:0.460, val_acc:45.000
# Best loss:0.447, Best accuracy:50.625, Best F1-score:0.471
# 28/300 lr=0.00100 - loss:0.460, acc:49.390, val_loss:0.413, val_acc:52.500
# Best loss:0.447, Best accuracy:50.625, Best F1-score:0.471
# 29/300 lr=0.00100 - loss:0.454, acc:50.534, val_loss:0.421, val_acc:48.750
# Best loss:0.413, Best accuracy:52.500, Best F1-score:0.499
# 30/300 lr=0.00100 - loss:0.447, acc:52.058, val_loss:0.420, val_acc:51.250
# Best loss:0.413, Best accuracy:52.500, Best F1-score:0.499
# 31/300 lr=0.00100 - loss:0.442, acc:50.991, val_loss:0.414, val_acc:59.375
# Best loss:0.413, Best accuracy:52.500, Best F1-score:0.499
# 32/300 lr=0.00100 - loss:0.441, acc:51.829, val_loss:0.401, val_acc:52.500
# Best loss:0.414, Best accuracy:59.375, Best F1-score:0.566
# 33/300 lr=0.00100 - loss:0.431, acc:54.726, val_loss:0.407, val_acc:53.125
# Best loss:0.414, Best accuracy:59.375, Best F1-score:0.566
# 34/300 lr=0.00100 - loss:0.431, acc:54.649, val_loss:0.406, val_acc:52.500
# Best loss:0.414, Best accuracy:59.375, Best F1-score:0.566
# 35/300 lr=0.00100 - loss:0.428, acc:53.354, val_loss:0.383, val_acc:60.000
# Best loss:0.414, Best accuracy:59.375, Best F1-score:0.566
# 36/300 lr=0.00100 - loss:0.416, acc:55.488, val_loss:0.428, val_acc:49.375
# Best loss:0.383, Best accuracy:60.000, Best F1-score:0.593
# 37/300 lr=0.00100 - loss:0.436, acc:53.354, val_loss:0.377, val_acc:58.750
# Best loss:0.383, Best accuracy:60.000, Best F1-score:0.593
# 38/300 lr=0.00100 - loss:0.416, acc:55.716, val_loss:0.377, val_acc:59.375
# Best loss:0.383, Best accuracy:60.000, Best F1-score:0.593
# 39/300 lr=0.00100 - loss:0.409, acc:57.698, val_loss:0.395, val_acc:52.500
# Best loss:0.383, Best accuracy:60.000, Best F1-score:0.593
# 40/300 lr=0.00100 - loss:0.412, acc:57.470, val_loss:0.417, val_acc:54.375
# Best loss:0.383, Best accuracy:60.000, Best F1-score:0.593
# 41/300 lr=0.00100 - loss:0.414, acc:55.793, val_loss:0.411, val_acc:55.625
# Best loss:0.383, Best accuracy:60.000, Best F1-score:0.593
# 42/300 lr=0.00100 - loss:0.400, acc:59.451, val_loss:0.400, val_acc:52.500
# Best loss:0.383, Best accuracy:60.000, Best F1-score:0.593
# 43/300 lr=0.00100 - loss:0.394, acc:58.613, val_loss:0.404, val_acc:50.000
# Best loss:0.383, Best accuracy:60.000, Best F1-score:0.593
# 44/300 lr=0.00100 - loss:0.407, acc:56.631, val_loss:0.390, val_acc:54.375
# Best loss:0.383, Best accuracy:60.000, Best F1-score:0.593
# 45/300 lr=0.00100 - loss:0.410, acc:56.707, val_loss:0.371, val_acc:59.375
# Best loss:0.383, Best accuracy:60.000, Best F1-score:0.593
# 46/300 lr=0.00100 - loss:0.394, acc:59.375, val_loss:0.373, val_acc:58.750
# Best loss:0.383, Best accuracy:60.000, Best F1-score:0.593
# 47/300 lr=0.00100 - loss:0.394, acc:58.308, val_loss:0.347, val_acc:61.875
# Best loss:0.383, Best accuracy:60.000, Best F1-score:0.593
# 48/300 lr=0.00100 - loss:0.392, acc:60.213, val_loss:0.337, val_acc:65.625
# Best loss:0.347, Best accuracy:61.875, Best F1-score:0.615
# 49/300 lr=0.00100 - loss:0.377, acc:60.823, val_loss:0.381, val_acc:58.125
# Best loss:0.337, Best accuracy:65.625, Best F1-score:0.651
# 50/300 lr=0.00100 - loss:0.375, acc:62.500, val_loss:0.353, val_acc:61.250
# Best loss:0.337, Best accuracy:65.625, Best F1-score:0.651
# 51/300 lr=0.00100 - loss:0.376, acc:62.348, val_loss:0.333, val_acc:59.375
# Best loss:0.337, Best accuracy:65.625, Best F1-score:0.651
# 52/300 lr=0.00100 - loss:0.367, acc:63.338, val_loss:0.354, val_acc:56.875
# Best loss:0.337, Best accuracy:65.625, Best F1-score:0.651
# 53/300 lr=0.00100 - loss:0.365, acc:64.253, val_loss:0.329, val_acc:67.500
# Best loss:0.337, Best accuracy:65.625, Best F1-score:0.651
# 54/300 lr=0.00100 - loss:0.369, acc:63.262, val_loss:0.356, val_acc:58.125
# Best loss:0.329, Best accuracy:67.500, Best F1-score:0.672
# 55/300 lr=0.00100 - loss:0.363, acc:64.405, val_loss:0.346, val_acc:61.250
# Best loss:0.329, Best accuracy:67.500, Best F1-score:0.672
# 56/300 lr=0.00100 - loss:0.372, acc:62.500, val_loss:0.342, val_acc:59.375
# Best loss:0.329, Best accuracy:67.500, Best F1-score:0.672
# ...
# 183/300 lr=0.00035 - loss:0.155, acc:92.759, val_loss:0.211, val_acc:73.750
# Best loss:0.176, Best accuracy:80.625, Best F1-score:0.805
# 184/300 lr=0.00035 - loss:0.160, acc:92.073, val_loss:0.206, val_acc:77.500
# Best loss:0.176, Best accuracy:80.625, Best F1-score:0.805
# 185/300 lr=0.00035 - loss:0.155, acc:92.912, val_loss:0.203, val_acc:77.500
# Best loss:0.176, Best accuracy:80.625, Best F1-score:0.805
# 186/300 lr=0.00035 - loss:0.155, acc:92.912, val_loss:0.182, val_acc:80.000
# Best loss:0.176, Best accuracy:80.625, Best F1-score:0.805
# 187/300 lr=0.00035 - loss:0.158, acc:93.064, val_loss:0.186, val_acc:80.625
# Best loss:0.176, Best accuracy:80.625, Best F1-score:0.805
# 188/300 lr=0.00035 - loss:0.157, acc:92.912, val_loss:0.201, val_acc:75.000
# Best loss:0.176, Best accuracy:80.625, Best F1-score:0.805
# 189/300 lr=0.00035 - loss:0.159, acc:92.302, val_loss:0.182, val_acc:75.625
# Best loss:0.176, Best accuracy:80.625, Best F1-score:0.805
# 190/300 lr=0.00035 - loss:0.158, acc:92.226, val_loss:0.185, val_acc:80.625
# Best loss:0.176, Best accuracy:80.625, Best F1-score:0.805
# 191/300 lr=0.00035 - loss:0.159, acc:92.378, val_loss:0.182, val_acc:79.375
# Best loss:0.176, Best accuracy:80.625, Best F1-score:0.805
# 192/300 lr=0.00035 - loss:0.153, acc:93.750, val_loss:0.195, val_acc:76.875
# Best loss:0.176, Best accuracy:80.625, Best F1-score:0.805
# 193/300 lr=0.00035 - loss:0.155, acc:92.149, val_loss:0.199, val_acc:78.125
# Best loss:0.176, Best accuracy:80.625, Best F1-score:0.805
# 194/300 lr=0.00035 - loss:0.151, acc:94.207, val_loss:0.180, val_acc:79.375
# Best loss:0.176, Best accuracy:80.625, Best F1-score:0.805
# 195/300 lr=0.00035 - loss:0.150, acc:93.140, val_loss:0.172, val_acc:81.875
# Best loss:0.176, Best accuracy:80.625, Best F1-score:0.805
# 196/300 lr=0.00035 - loss:0.154, acc:92.683, val_loss:0.187, val_acc:80.000
# Best loss:0.172, Best accuracy:81.875, Best F1-score:0.811
# 197/300 lr=0.00035 - loss:0.149, acc:94.665, val_loss:0.178, val_acc:78.125
# Best loss:0.172, Best accuracy:81.875, Best F1-score:0.811
# 198/300 lr=0.00035 - loss:0.149, acc:93.826, val_loss:0.171, val_acc:83.125
# Best loss:0.172, Best accuracy:81.875, Best F1-score:0.811
# 199/300 lr=0.00035 - loss:0.145, acc:94.970, val_loss:0.168, val_acc:80.000
# Best loss:0.171, Best accuracy:83.125, Best F1-score:0.826
# 200/300 lr=0.00035 - loss:0.149, acc:93.979, val_loss:0.173, val_acc:78.125
# Best loss:0.171, Best accuracy:83.125, Best F1-score:0.826
# 201/300 lr=0.00035 - loss:0.148, acc:94.131, val_loss:0.172, val_acc:76.875
# Best loss:0.171, Best accuracy:83.125, Best F1-score:0.826
# 202/300 lr=0.00030 - loss:0.149, acc:94.055, val_loss:0.183, val_acc:78.750
# Best loss:0.171, Best accuracy:83.125, Best F1-score:0.826
# 203/300 lr=0.00030 - loss:0.148, acc:93.902, val_loss:0.160, val_acc:83.750
# Best loss:0.171, Best accuracy:83.125, Best F1-score:0.826
# 204/300 lr=0.00030 - loss:0.145, acc:94.893, val_loss:0.176, val_acc:79.375
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 205/300 lr=0.00030 - loss:0.153, acc:93.064, val_loss:0.204, val_acc:73.750
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 206/300 lr=0.00030 - loss:0.152, acc:93.674, val_loss:0.173, val_acc:78.125
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 207/300 lr=0.00030 - loss:0.149, acc:93.445, val_loss:0.179, val_acc:78.750
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 208/300 lr=0.00030 - loss:0.150, acc:93.293, val_loss:0.167, val_acc:80.625
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 209/300 lr=0.00030 - loss:0.148, acc:93.902, val_loss:0.161, val_acc:80.000
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 210/300 lr=0.00030 - loss:0.142, acc:95.198, val_loss:0.180, val_acc:80.000
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 211/300 lr=0.00030 - loss:0.137, acc:95.808, val_loss:0.164, val_acc:79.375
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 212/300 lr=0.00030 - loss:0.140, acc:95.198, val_loss:0.167, val_acc:81.250
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 213/300 lr=0.00030 - loss:0.142, acc:95.351, val_loss:0.187, val_acc:79.375
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 214/300 lr=0.00030 - loss:0.139, acc:95.274, val_loss:0.178, val_acc:78.750
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 215/300 lr=0.00030 - loss:0.143, acc:94.512, val_loss:0.185, val_acc:78.750
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 216/300 lr=0.00030 - loss:0.145, acc:94.131, val_loss:0.193, val_acc:80.000
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 217/300 lr=0.00030 - loss:0.141, acc:94.893, val_loss:0.172, val_acc:79.375
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 218/300 lr=0.00030 - loss:0.143, acc:94.360, val_loss:0.175, val_acc:79.375
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 219/300 lr=0.00030 - loss:0.147, acc:93.826, val_loss:0.195, val_acc:79.375
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 220/300 lr=0.00030 - loss:0.144, acc:94.131, val_loss:0.176, val_acc:79.375
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 221/300 lr=0.00030 - loss:0.143, acc:94.284, val_loss:0.162, val_acc:80.625
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 222/300 lr=0.00026 - loss:0.139, acc:95.427, val_loss:0.162, val_acc:79.375
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 223/300 lr=0.00026 - loss:0.138, acc:95.427, val_loss:0.163, val_acc:80.625
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 224/300 lr=0.00026 - loss:0.141, acc:95.122, val_loss:0.192, val_acc:77.500
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 225/300 lr=0.00026 - loss:0.140, acc:95.274, val_loss:0.194, val_acc:76.875
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 226/300 lr=0.00026 - loss:0.144, acc:94.131, val_loss:0.166, val_acc:80.000
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 227/300 lr=0.00026 - loss:0.140, acc:94.588, val_loss:0.170, val_acc:80.000
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 228/300 lr=0.00026 - loss:0.144, acc:94.665, val_loss:0.177, val_acc:78.750
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 229/300 lr=0.00026 - loss:0.145, acc:94.055, val_loss:0.158, val_acc:82.500
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 230/300 lr=0.00026 - loss:0.139, acc:95.427, val_loss:0.164, val_acc:78.125
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 231/300 lr=0.00026 - loss:0.139, acc:94.893, val_loss:0.176, val_acc:79.375
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 232/300 lr=0.00026 - loss:0.133, acc:96.494, val_loss:0.180, val_acc:78.750
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 233/300 lr=0.00026 - loss:0.134, acc:95.732, val_loss:0.171, val_acc:78.750
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 234/300 lr=0.00026 - loss:0.138, acc:94.893, val_loss:0.157, val_acc:82.500
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 235/300 lr=0.00026 - loss:0.137, acc:94.970, val_loss:0.152, val_acc:82.500
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 236/300 lr=0.00026 - loss:0.132, acc:96.570, val_loss:0.180, val_acc:77.500
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 237/300 lr=0.00026 - loss:0.138, acc:94.741, val_loss:0.172, val_acc:78.125
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 238/300 lr=0.00026 - loss:0.140, acc:94.284, val_loss:0.167, val_acc:81.250
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 239/300 lr=0.00026 - loss:0.135, acc:95.732, val_loss:0.150, val_acc:83.125
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 240/300 lr=0.00026 - loss:0.135, acc:95.503, val_loss:0.157, val_acc:81.875
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 241/300 lr=0.00026 - loss:0.135, acc:95.655, val_loss:0.161, val_acc:80.625
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 242/300 lr=0.00022 - loss:0.132, acc:96.265, val_loss:0.195, val_acc:76.875
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 243/300 lr=0.00022 - loss:0.131, acc:96.646, val_loss:0.169, val_acc:81.875
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 244/300 lr=0.00022 - loss:0.134, acc:96.037, val_loss:0.174, val_acc:77.500
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 245/300 lr=0.00022 - loss:0.137, acc:95.046, val_loss:0.164, val_acc:81.250
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 246/300 lr=0.00022 - loss:0.131, acc:96.341, val_loss:0.145, val_acc:85.625
# Best loss:0.160, Best accuracy:83.750, Best F1-score:0.833
# 247/300 lr=0.00022 - loss:0.126, acc:97.332, val_loss:0.153, val_acc:81.250
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 248/300 lr=0.00022 - loss:0.134, acc:95.655, val_loss:0.139, val_acc:85.000
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 249/300 lr=0.00022 - loss:0.128, acc:96.875, val_loss:0.160, val_acc:80.625
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 250/300 lr=0.00022 - loss:0.128, acc:97.104, val_loss:0.140, val_acc:85.000
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 251/300 lr=0.00022 - loss:0.130, acc:95.579, val_loss:0.144, val_acc:81.875
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 252/300 lr=0.00022 - loss:0.136, acc:94.893, val_loss:0.168, val_acc:81.250
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 253/300 lr=0.00022 - loss:0.140, acc:95.046, val_loss:0.156, val_acc:78.750
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 254/300 lr=0.00022 - loss:0.136, acc:95.579, val_loss:0.158, val_acc:80.625
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 255/300 lr=0.00022 - loss:0.129, acc:96.799, val_loss:0.164, val_acc:80.625
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 256/300 lr=0.00022 - loss:0.132, acc:95.960, val_loss:0.168, val_acc:81.250
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 257/300 lr=0.00022 - loss:0.129, acc:96.723, val_loss:0.150, val_acc:83.750
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 258/300 lr=0.00022 - loss:0.137, acc:94.741, val_loss:0.145, val_acc:81.250
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 259/300 lr=0.00022 - loss:0.126, acc:96.265, val_loss:0.169, val_acc:81.250
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 260/300 lr=0.00022 - loss:0.130, acc:96.113, val_loss:0.162, val_acc:82.500
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 261/300 lr=0.00022 - loss:0.130, acc:96.113, val_loss:0.163, val_acc:81.875
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 262/300 lr=0.00019 - loss:0.133, acc:95.579, val_loss:0.164, val_acc:80.000
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 263/300 lr=0.00019 - loss:0.128, acc:96.723, val_loss:0.173, val_acc:79.375
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 264/300 lr=0.00019 - loss:0.135, acc:95.808, val_loss:0.161, val_acc:81.250
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 265/300 lr=0.00019 - loss:0.135, acc:96.113, val_loss:0.166, val_acc:82.500
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 266/300 lr=0.00019 - loss:0.129, acc:96.494, val_loss:0.159, val_acc:78.750
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 267/300 lr=0.00019 - loss:0.129, acc:96.875, val_loss:0.152, val_acc:80.625
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 268/300 lr=0.00019 - loss:0.126, acc:97.256, val_loss:0.164, val_acc:80.625
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 269/300 lr=0.00019 - loss:0.128, acc:97.104, val_loss:0.156, val_acc:83.750
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 270/300 lr=0.00019 - loss:0.125, acc:97.104, val_loss:0.161, val_acc:80.625
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 271/300 lr=0.00019 - loss:0.128, acc:96.570, val_loss:0.160, val_acc:80.625
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 272/300 lr=0.00019 - loss:0.129, acc:96.265, val_loss:0.147, val_acc:81.875
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 273/300 lr=0.00019 - loss:0.125, acc:96.494, val_loss:0.153, val_acc:83.125
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 274/300 lr=0.00019 - loss:0.132, acc:96.265, val_loss:0.159, val_acc:81.875
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 275/300 lr=0.00019 - loss:0.123, acc:97.104, val_loss:0.150, val_acc:81.875
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 276/300 lr=0.00019 - loss:0.129, acc:96.189, val_loss:0.160, val_acc:81.875
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 277/300 lr=0.00019 - loss:0.124, acc:97.561, val_loss:0.162, val_acc:80.000
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 278/300 lr=0.00019 - loss:0.121, acc:97.637, val_loss:0.161, val_acc:81.875
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 279/300 lr=0.00019 - loss:0.125, acc:97.104, val_loss:0.157, val_acc:80.625
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 280/300 lr=0.00019 - loss:0.129, acc:96.418, val_loss:0.170, val_acc:81.875
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 281/300 lr=0.00019 - loss:0.125, acc:97.027, val_loss:0.161, val_acc:81.250
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 282/300 lr=0.00017 - loss:0.127, acc:97.027, val_loss:0.147, val_acc:83.750
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 283/300 lr=0.00017 - loss:0.125, acc:96.723, val_loss:0.156, val_acc:83.750
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 284/300 lr=0.00017 - loss:0.125, acc:97.332, val_loss:0.146, val_acc:82.500
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 285/300 lr=0.00017 - loss:0.125, acc:97.104, val_loss:0.144, val_acc:83.125
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 286/300 lr=0.00017 - loss:0.126, acc:97.027, val_loss:0.153, val_acc:81.875
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 287/300 lr=0.00017 - loss:0.125, acc:97.104, val_loss:0.139, val_acc:83.750
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 288/300 lr=0.00017 - loss:0.122, acc:97.485, val_loss:0.151, val_acc:80.625
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 289/300 lr=0.00017 - loss:0.125, acc:96.875, val_loss:0.155, val_acc:81.875
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 290/300 lr=0.00017 - loss:0.124, acc:97.027, val_loss:0.144, val_acc:83.125
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 291/300 lr=0.00017 - loss:0.128, acc:96.646, val_loss:0.151, val_acc:81.250
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 292/300 lr=0.00017 - loss:0.122, acc:97.027, val_loss:0.146, val_acc:81.250
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 293/300 lr=0.00017 - loss:0.126, acc:97.027, val_loss:0.163, val_acc:78.750
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 294/300 lr=0.00017 - loss:0.124, acc:97.027, val_loss:0.168, val_acc:81.875
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 295/300 lr=0.00017 - loss:0.126, acc:96.799, val_loss:0.152, val_acc:80.625
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 296/300 lr=0.00017 - loss:0.121, acc:97.942, val_loss:0.146, val_acc:83.125
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 297/300 lr=0.00017 - loss:0.124, acc:96.875, val_loss:0.146, val_acc:82.500
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 298/300 lr=0.00017 - loss:0.122, acc:97.637, val_loss:0.144, val_acc:82.500
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 299/300 lr=0.00017 - loss:0.122, acc:97.256, val_loss:0.149, val_acc:82.500
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# 300/300 lr=0.00017 - loss:0.120, acc:97.942, val_loss:0.160, val_acc:81.875
# Best loss:0.145, Best accuracy:85.625, Best F1-score:0.853
# [*] Done - acc:85.625

# %%
end()

# %%
print(f'max:{max(fold_acc)}, min:{min(fold_acc)}, average:{sum(fold_acc)/len(fold_acc)}')
# Out:
# max:86.875, min:83.125, average:85.46875

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
# Out:
# WAR(Weighted Average Recall)   : 84.73%
# UAR(Unweighted Average Recall) : 84.73%
