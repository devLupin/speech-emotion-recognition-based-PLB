# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = '10-Fold dataset'
DATA_PATH = 'EMODB'
CLASS_LABELS = Config.EMODB_LABELS
k = 10

# reverse : (196,39,1)  ## CA: Channel-attention    ## SA : Self-attention 
model_name = '10-Fold-CV+Reverse(CNN+dilated)+CBAM+DSC+CA+SA+CA+Capsule+CA'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding=padding),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule]),
        Lambda(function=PrimaryCapssquash)
    ])
    
  def call(self, inputs):
    return self.conv(inputs)

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.cbam = CBAM(64) # sharing
    
    self.primarycap = PrimaryCap()
    self.spatial_attn = SpatialGate()
    
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    forward = inputs
    backward =tf.reverse(inputs, axis=[2])
    
    x = tf.concat([forward, backward], axis=-1)   # channel concat
    
    cap = self.conv1(x)
    cap = cap + self.cbam(cap)
    cap = self.conv2(cap)
    cap = cap + self.cbam(cap)
    
    primarycaps = self.primarycap(cap)
    primarycaps = tf.expand_dims(primarycaps, axis=-1)
    primarycaps = primarycaps + self.spatial_attn(primarycaps)
    primarycaps = tf.squeeze(primarycaps, axis=-1)
    
    cap = primarycaps
    
    sa = self.attention([primarycaps, primarycaps, primarycaps])
    sa = self.LN(sa)
    
    sa = tf.expand_dims(sa, axis=-1)
    sa = sa + self.spatial_attn(sa)
    sa = tf.squeeze(sa, axis=-1)
    
    cap = self.lamb([cap, sa])
    cap = tf.expand_dims(cap, axis=-1)
    cap = cap + self.spatial_attn(cap)
    cap = tf.squeeze(cap, axis=-1)
    
    capsule = self.capsule(cap)
    capsule = tf.expand_dims(capsule, axis=-1)
    capsule = capsule + self.spatial_attn(capsule)
    capsule = tf.squeeze(capsule, axis=-1)
    
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1992
#
#  sequential_1 (Sequential)   (None, 46, 7, 64)         37300
#
#  cbam (CBAM)                 multiple                  4294
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  spatial_gate_1 (SpatialGate  multiple                 102
#  )
#
#  attention (Attention)       multiple                  1
#
#  layer_normalization (LayerN  multiple                 128
#  ormalization)
#
#  lambda_1 (Lambda)           multiple                  0
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  455
#
# =================================================================
# Total params: 94,448
# Trainable params: 93,870
# Non-trainable params: 578
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}_train.npy', 'rb') as f:
    X = np.load(f)
    y = np.load(f)
y = to_categorical(y,num_classes=len(CLASS_LABELS))

with open(f'{DATA_ROOT}/{DATA_PATH}_test.npy', 'rb') as f:
    X_test = np.load(f)
    y_test = np.load(f)
y_test = to_categorical(y_test,num_classes=len(CLASS_LABELS))
    
print(X.shape, y.shape, X_test.shape, y_test.shape)
# Out:
# (482, 196, 39) (482, 7) (53, 196, 39) (53, 7)

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_val_acc = []
fold_test_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, val) in tqdm(enumerate(kfold.split(X, y)), desc=f'Training {k}-Fold.....'):
    # if i < 7: continue
    
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = X[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_val, y_val = X[val], y[val]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_val = tf.expand_dims(x_val, axis=-1)
    x_test = tf.expand_dims(X_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_val_loss = 0x3f3f3f
    best_val_acc = -1
    best_val_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_val = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        val_loss, val_acc, f1s = [], [], []
        for features, labels in batch_val:
            loss, acc, pred = test_step(model, features, labels)
            val_loss.append(loss)
            val_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1*100)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(val_loss)/len(val_loss)
        val_acc = sum(val_acc)/len(val_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_val_loss:.3f}, Best accuracy:{best_val_acc:.3f}, Best F1-score:{best_val_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_val_loss > val_loss:
            best_val_acc = val_acc
            best_val_loss = val_loss
            best_val_f1 = f1_score
            model.save_weights(h5_path)
            
            
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    
    test_acc, test_f1 = [], []
    for features, labels in batch_test:
        best_pred = model(features, training=False)
        emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(labels, axis=1))
        predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
        
        acc = tf.keras.metrics.CategoricalAccuracy()
        acc.update_state(labels, best_pred)
        accuracy = acc.result().numpy()
        test_acc.append(accuracy*100)
        
        f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
        f1_metric.update_state(labels, best_pred)
        f1 = f1_metric.result().numpy()
        test_f1.append(f1*100)
        
        
        
        
    print('*' * 80)
    print(f'[*] Done Fold-{i+1}')
    print(f'best_val_loss:{best_val_loss:.3f}, best_val_acc:{best_val_acc:.3f}, best_val_f1:{best_val_f1:.3f}')
    print(f'test_acc:{(sum(test_acc)/len(test_acc)):.3f}, test_f1:{(sum(test_f1)/len(test_f1)):.3f}')
    print('*' * 80)
    
    plt.title(f'Fold-{i+1} Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    fold_val_acc.append(best_val_acc)
    fold_test_acc.append((sum(test_acc)/len(test_acc)))
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.588, acc:28.637, val_loss:0.558, val_acc:39.338
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.541, acc:39.154, val_loss:0.513, val_acc:44.026
# Best loss:0.558, Best accuracy:39.338, Best F1-score:24.983
# 3/300 lr=0.00100 - loss:0.506, acc:46.442, val_loss:0.515, val_acc:47.151
# Best loss:0.513, Best accuracy:44.026, Best F1-score:29.349
# 4/300 lr=0.00100 - loss:0.487, acc:44.879, val_loss:0.468, val_acc:50.276
# Best loss:0.513, Best accuracy:44.026, Best F1-score:29.349
# 5/300 lr=0.00100 - loss:0.470, acc:48.372, val_loss:0.465, val_acc:48.713
# Best loss:0.468, Best accuracy:50.276, Best F1-score:39.579
# 6/300 lr=0.00100 - loss:0.461, acc:47.216, val_loss:0.459, val_acc:42.463
# Best loss:0.465, Best accuracy:48.713, Best F1-score:35.336
# 7/300 lr=0.00100 - loss:0.455, acc:47.755, val_loss:0.435, val_acc:43.842
# Best loss:0.459, Best accuracy:42.463, Best F1-score:30.243
# 8/300 lr=0.00100 - loss:0.451, acc:51.457, val_loss:0.462, val_acc:48.713
# Best loss:0.435, Best accuracy:43.842, Best F1-score:33.936
# 9/300 lr=0.00100 - loss:0.429, acc:53.558, val_loss:0.431, val_acc:42.279
# Best loss:0.435, Best accuracy:43.842, Best F1-score:33.936
# 10/300 lr=0.00100 - loss:0.429, acc:54.372, val_loss:0.431, val_acc:42.463
# Best loss:0.431, Best accuracy:42.279, Best F1-score:36.017
# 11/300 lr=0.00100 - loss:0.420, acc:53.676, val_loss:0.435, val_acc:48.713
# Best loss:0.431, Best accuracy:42.463, Best F1-score:32.649
# 12/300 lr=0.00100 - loss:0.411, acc:54.648, val_loss:0.425, val_acc:42.279
# Best loss:0.431, Best accuracy:42.463, Best F1-score:32.649
# 13/300 lr=0.00100 - loss:0.425, acc:52.665, val_loss:0.407, val_acc:50.092
# Best loss:0.425, Best accuracy:42.279, Best F1-score:38.560
# 14/300 lr=0.00100 - loss:0.411, acc:53.191, val_loss:0.418, val_acc:48.713
# Best loss:0.407, Best accuracy:50.092, Best F1-score:42.830
# 15/300 lr=0.00100 - loss:0.399, acc:55.541, val_loss:0.419, val_acc:39.338
# Best loss:0.407, Best accuracy:50.092, Best F1-score:42.830
# 16/300 lr=0.00100 - loss:0.402, acc:56.710, val_loss:0.405, val_acc:50.092
# Best loss:0.407, Best accuracy:50.092, Best F1-score:42.830
# 17/300 lr=0.00100 - loss:0.388, acc:57.996, val_loss:0.391, val_acc:54.596
# Best loss:0.405, Best accuracy:50.092, Best F1-score:42.233
# 18/300 lr=0.00100 - loss:0.373, acc:61.712, val_loss:0.387, val_acc:51.471
# Best loss:0.391, Best accuracy:54.596, Best F1-score:49.291
# 19/300 lr=0.00100 - loss:0.378, acc:59.808, val_loss:0.378, val_acc:51.471
# Best loss:0.387, Best accuracy:51.471, Best F1-score:45.626
# 20/300 lr=0.00100 - loss:0.372, acc:61.397, val_loss:0.371, val_acc:53.033
# Best loss:0.378, Best accuracy:51.471, Best F1-score:46.139
# 21/300 lr=0.00100 - loss:0.367, acc:60.872, val_loss:0.378, val_acc:55.974
# Best loss:0.371, Best accuracy:53.033, Best F1-score:48.133
# 22/300 lr=0.00100 - loss:0.358, acc:63.078, val_loss:0.369, val_acc:53.033
# Best loss:0.371, Best accuracy:53.033, Best F1-score:48.133
# 23/300 lr=0.00100 - loss:0.357, acc:64.837, val_loss:0.369, val_acc:51.471
# Best loss:0.369, Best accuracy:53.033, Best F1-score:48.238
# 24/300 lr=0.00100 - loss:0.352, acc:64.811, val_loss:0.350, val_acc:60.478
# Best loss:0.369, Best accuracy:53.033, Best F1-score:48.238
# 25/300 lr=0.00100 - loss:0.344, acc:65.113, val_loss:0.348, val_acc:57.537
# Best loss:0.350, Best accuracy:60.478, Best F1-score:57.505
# 26/300 lr=0.00100 - loss:0.342, acc:65.507, val_loss:0.357, val_acc:48.346
# Best loss:0.348, Best accuracy:57.537, Best F1-score:53.216
# 27/300 lr=0.00100 - loss:0.338, acc:66.649, val_loss:0.340, val_acc:58.915
# Best loss:0.348, Best accuracy:57.537, Best F1-score:53.216
# 28/300 lr=0.00100 - loss:0.332, acc:67.345, val_loss:0.333, val_acc:61.857
# Best loss:0.340, Best accuracy:58.915, Best F1-score:53.701
# 29/300 lr=0.00100 - loss:0.331, acc:68.015, val_loss:0.322, val_acc:60.478
# Best loss:0.333, Best accuracy:61.857, Best F1-score:57.836
# 30/300 lr=0.00100 - loss:0.318, acc:68.212, val_loss:0.292, val_acc:68.107
# Best loss:0.322, Best accuracy:60.478, Best F1-score:55.649
# 31/300 lr=0.00100 - loss:0.314, acc:68.684, val_loss:0.302, val_acc:58.915
# Best loss:0.292, Best accuracy:68.107, Best F1-score:63.503
# 32/300 lr=0.00100 - loss:0.320, acc:69.301, val_loss:0.312, val_acc:64.798
# Best loss:0.292, Best accuracy:68.107, Best F1-score:63.503
# 33/300 lr=0.00100 - loss:0.311, acc:70.890, val_loss:0.289, val_acc:63.603
# Best loss:0.292, Best accuracy:68.107, Best F1-score:63.503
# 34/300 lr=0.00100 - loss:0.306, acc:72.203, val_loss:0.281, val_acc:69.485
# Best loss:0.289, Best accuracy:63.603, Best F1-score:59.005
# 35/300 lr=0.00100 - loss:0.304, acc:71.113, val_loss:0.270, val_acc:72.794
# Best loss:0.281, Best accuracy:69.485, Best F1-score:64.385
# 36/300 lr=0.00100 - loss:0.289, acc:73.792, val_loss:0.244, val_acc:72.610
# Best loss:0.270, Best accuracy:72.794, Best F1-score:69.031
# 37/300 lr=0.00100 - loss:0.280, acc:75.053, val_loss:0.243, val_acc:77.114
# Best loss:0.244, Best accuracy:72.610, Best F1-score:68.818
# 38/300 lr=0.00100 - loss:0.263, acc:79.937, val_loss:0.243, val_acc:73.989
# Best loss:0.243, Best accuracy:77.114, Best F1-score:74.014
# 39/300 lr=0.00100 - loss:0.267, acc:76.720, val_loss:0.232, val_acc:78.860
# Best loss:0.243, Best accuracy:77.114, Best F1-score:74.014
# 40/300 lr=0.00100 - loss:0.270, acc:76.838, val_loss:0.253, val_acc:74.173
# Best loss:0.232, Best accuracy:78.860, Best F1-score:75.520
# 41/300 lr=0.00100 - loss:0.259, acc:78.309, val_loss:0.237, val_acc:75.735
# Best loss:0.232, Best accuracy:78.860, Best F1-score:75.520
# 42/300 lr=0.00100 - loss:0.262, acc:78.230, val_loss:0.208, val_acc:75.735
# Best loss:0.232, Best accuracy:78.860, Best F1-score:75.520
# 43/300 lr=0.00100 - loss:0.266, acc:75.630, val_loss:0.243, val_acc:75.551
# Best loss:0.208, Best accuracy:75.735, Best F1-score:73.509
# 44/300 lr=0.00100 - loss:0.264, acc:76.024, val_loss:0.232, val_acc:77.298
# Best loss:0.208, Best accuracy:75.735, Best F1-score:73.509
# 45/300 lr=0.00100 - loss:0.263, acc:75.853, val_loss:0.242, val_acc:72.610
# Best loss:0.208, Best accuracy:75.735, Best F1-score:73.509
# 46/300 lr=0.00100 - loss:0.266, acc:76.024, val_loss:0.227, val_acc:77.298
# Best loss:0.208, Best accuracy:75.735, Best F1-score:73.509
# 47/300 lr=0.00100 - loss:0.250, acc:79.622, val_loss:0.220, val_acc:68.107
# Best loss:0.208, Best accuracy:75.735, Best F1-score:73.509
# 48/300 lr=0.00100 - loss:0.264, acc:76.471, val_loss:0.254, val_acc:69.669
# Best loss:0.208, Best accuracy:75.735, Best F1-score:73.509
# 49/300 lr=0.00100 - loss:0.248, acc:77.757, val_loss:0.196, val_acc:81.801
# Best loss:0.208, Best accuracy:75.735, Best F1-score:73.509
# 50/300 lr=0.00100 - loss:0.237, acc:82.445, val_loss:0.195, val_acc:80.423
# Best loss:0.196, Best accuracy:81.801, Best F1-score:78.361
# 51/300 lr=0.00100 - loss:0.234, acc:81.132, val_loss:0.198, val_acc:78.676
# Best loss:0.195, Best accuracy:80.423, Best F1-score:77.107
# 52/300 lr=0.00100 - loss:0.224, acc:83.338, val_loss:0.207, val_acc:77.114
# Best loss:0.195, Best accuracy:80.423, Best F1-score:77.107
# 53/300 lr=0.00100 - loss:0.241, acc:78.230, val_loss:0.204, val_acc:74.357
# Best loss:0.195, Best accuracy:80.423, Best F1-score:77.107
# 54/300 lr=0.00100 - loss:0.230, acc:80.685, val_loss:0.227, val_acc:75.551
# Best loss:0.195, Best accuracy:80.423, Best F1-score:77.107
# 55/300 lr=0.00100 - loss:0.238, acc:79.793, val_loss:0.194, val_acc:80.239
# Best loss:0.195, Best accuracy:80.423, Best F1-score:77.107
# 56/300 lr=0.00100 - loss:0.234, acc:80.633, val_loss:0.206, val_acc:78.676
# Best loss:0.136, Best accuracy:86.305, Best F1-score:84.034
# 287/300 lr=0.00017 - loss:0.105, acc:99.107, val_loss:0.178, val_acc:81.801
# Best loss:0.136, Best accuracy:86.305, Best F1-score:84.034
# 288/300 lr=0.00017 - loss:0.107, acc:99.107, val_loss:0.163, val_acc:83.364
# Best loss:0.136, Best accuracy:86.305, Best F1-score:84.034
# 289/300 lr=0.00017 - loss:0.105, acc:98.910, val_loss:0.166, val_acc:81.801
# Best loss:0.136, Best accuracy:86.305, Best F1-score:84.034
# 290/300 lr=0.00017 - loss:0.106, acc:99.107, val_loss:0.176, val_acc:80.239
# Best loss:0.136, Best accuracy:86.305, Best F1-score:84.034
# 291/300 lr=0.00017 - loss:0.105, acc:99.107, val_loss:0.189, val_acc:78.676
# Best loss:0.136, Best accuracy:86.305, Best F1-score:84.034
# 292/300 lr=0.00017 - loss:0.113, acc:97.991, val_loss:0.181, val_acc:80.239
# Best loss:0.136, Best accuracy:86.305, Best F1-score:84.034
# 293/300 lr=0.00017 - loss:0.108, acc:98.661, val_loss:0.149, val_acc:84.743
# Best loss:0.136, Best accuracy:86.305, Best F1-score:84.034
# 294/300 lr=0.00017 - loss:0.105, acc:99.330, val_loss:0.156, val_acc:83.364
# Best loss:0.136, Best accuracy:86.305, Best F1-score:84.034
# 295/300 lr=0.00017 - loss:0.106, acc:98.661, val_loss:0.172, val_acc:83.364
# Best loss:0.136, Best accuracy:86.305, Best F1-score:84.034
# 296/300 lr=0.00017 - loss:0.101, acc:99.554, val_loss:0.181, val_acc:80.239
# Best loss:0.136, Best accuracy:86.305, Best F1-score:84.034
# 297/300 lr=0.00017 - loss:0.103, acc:99.330, val_loss:0.178, val_acc:81.801
# Best loss:0.136, Best accuracy:86.305, Best F1-score:84.034
# 298/300 lr=0.00017 - loss:0.105, acc:98.464, val_loss:0.165, val_acc:83.364
# Best loss:0.136, Best accuracy:86.305, Best F1-score:84.034
# 299/300 lr=0.00017 - loss:0.108, acc:98.661, val_loss:0.157, val_acc:83.364
# Best loss:0.136, Best accuracy:86.305, Best F1-score:84.034
# 300/300 lr=0.00017 - loss:0.101, acc:99.554, val_loss:0.165, val_acc:81.801
# Best loss:0.136, Best accuracy:86.305, Best F1-score:84.034
# ********************************************************************************
# [*] Done Fold-1
# best_val_loss:0.136, best_val_acc:86.305, best_val_f1:84.034
# test_acc:92.113, test_f1:91.649
# ********************************************************************************
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.584, acc:30.423, val_loss:0.579, val_acc:30.515
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.539, acc:40.940, val_loss:0.553, val_acc:36.765
# Best loss:0.579, Best accuracy:30.515, Best F1-score:18.349
# 3/300 lr=0.00100 - loss:0.509, acc:43.566, val_loss:0.555, val_acc:35.202
# Best loss:0.553, Best accuracy:36.765, Best F1-score:26.539
# 4/300 lr=0.00100 - loss:0.481, acc:51.103, val_loss:0.510, val_acc:47.151
# Best loss:0.553, Best accuracy:36.765, Best F1-score:26.539
# 5/300 lr=0.00100 - loss:0.460, acc:50.013, val_loss:0.497, val_acc:44.210
# Best loss:0.510, Best accuracy:47.151, Best F1-score:40.961
# 6/300 lr=0.00100 - loss:0.444, acc:52.048, val_loss:0.493, val_acc:42.647
# Best loss:0.497, Best accuracy:44.210, Best F1-score:39.436
# 7/300 lr=0.00100 - loss:0.437, acc:52.048, val_loss:0.470, val_acc:51.838
# Best loss:0.493, Best accuracy:42.647, Best F1-score:39.765
# 8/300 lr=0.00100 - loss:0.421, acc:52.468, val_loss:0.480, val_acc:47.151
# Best loss:0.470, Best accuracy:51.838, Best F1-score:45.922
# 9/300 lr=0.00100 - loss:0.412, acc:55.265, val_loss:0.458, val_acc:48.713
# Best loss:0.470, Best accuracy:51.838, Best F1-score:45.922
# 10/300 lr=0.00100 - loss:0.410, acc:54.228, val_loss:0.445, val_acc:47.335
# Best loss:0.458, Best accuracy:48.713, Best F1-score:46.211
# 11/300 lr=0.00100 - loss:0.406, acc:53.611, val_loss:0.462, val_acc:42.831
# Best loss:0.445, Best accuracy:47.335, Best F1-score:43.174
# 12/300 lr=0.00100 - loss:0.402, acc:54.504, val_loss:0.439, val_acc:41.268
# Best loss:0.445, Best accuracy:47.335, Best F1-score:43.174
# 13/300 lr=0.00100 - loss:0.396, acc:54.254, val_loss:0.424, val_acc:54.779
# Best loss:0.439, Best accuracy:41.268, Best F1-score:34.256
# 14/300 lr=0.00100 - loss:0.395, acc:56.683, val_loss:0.425, val_acc:56.342
# Best loss:0.424, Best accuracy:54.779, Best F1-score:50.581
# 15/300 lr=0.00100 - loss:0.384, acc:56.907, val_loss:0.423, val_acc:54.779
# Best loss:0.424, Best accuracy:54.779, Best F1-score:50.581
# 16/300 lr=0.00100 - loss:0.395, acc:55.003, val_loss:0.442, val_acc:39.706
# Best loss:0.423, Best accuracy:54.779, Best F1-score:50.581
# 17/300 lr=0.00100 - loss:0.390, acc:56.184, val_loss:0.419, val_acc:47.335
# Best loss:0.423, Best accuracy:54.779, Best F1-score:50.581
# 18/300 lr=0.00100 - loss:0.386, acc:58.718, val_loss:0.450, val_acc:51.838
# Best loss:0.419, Best accuracy:47.335, Best F1-score:43.100
# 19/300 lr=0.00100 - loss:0.377, acc:59.139, val_loss:0.434, val_acc:50.276
# Best loss:0.419, Best accuracy:47.335, Best F1-score:43.100
# 20/300 lr=0.00100 - loss:0.380, acc:59.835, val_loss:0.419, val_acc:48.897
# Best loss:0.419, Best accuracy:47.335, Best F1-score:43.100
# 21/300 lr=0.00100 - loss:0.364, acc:61.712, val_loss:0.428, val_acc:45.956
# Best loss:0.419, Best accuracy:47.335, Best F1-score:43.100
# 22/300 lr=0.00100 - loss:0.355, acc:61.870, val_loss:0.414, val_acc:53.401
# Best loss:0.419, Best accuracy:47.335, Best F1-score:43.100
# 23/300 lr=0.00100 - loss:0.359, acc:63.524, val_loss:0.414, val_acc:53.401
# Best loss:0.414, Best accuracy:53.401, Best F1-score:51.868
# 24/300 lr=0.00100 - loss:0.357, acc:63.997, val_loss:0.404, val_acc:44.577
# Best loss:0.414, Best accuracy:53.401, Best F1-score:51.831
# 25/300 lr=0.00100 - loss:0.351, acc:63.524, val_loss:0.416, val_acc:50.276
# Best loss:0.404, Best accuracy:44.577, Best F1-score:41.145
# 26/300 lr=0.00100 - loss:0.342, acc:63.971, val_loss:0.404, val_acc:54.963
# Best loss:0.404, Best accuracy:44.577, Best F1-score:41.145
# 27/300 lr=0.00100 - loss:0.344, acc:63.577, val_loss:0.400, val_acc:59.467
# Best loss:0.404, Best accuracy:54.963, Best F1-score:52.181
# 28/300 lr=0.00100 - loss:0.340, acc:65.835, val_loss:0.394, val_acc:54.963
# Best loss:0.400, Best accuracy:59.467, Best F1-score:56.789
# 29/300 lr=0.00100 - loss:0.332, acc:68.632, val_loss:0.380, val_acc:54.963
# Best loss:0.394, Best accuracy:54.963, Best F1-score:53.645
# 30/300 lr=0.00100 - loss:0.332, acc:64.863, val_loss:0.347, val_acc:58.088
# Best loss:0.380, Best accuracy:54.963, Best F1-score:51.476
# 31/300 lr=0.00100 - loss:0.324, acc:68.881, val_loss:0.398, val_acc:56.342
# Best loss:0.347, Best accuracy:58.088, Best F1-score:56.077
# 32/300 lr=0.00100 - loss:0.311, acc:71.113, val_loss:0.348, val_acc:61.213
# Best loss:0.347, Best accuracy:58.088, Best F1-score:56.077
# 33/300 lr=0.00100 - loss:0.310, acc:70.194, val_loss:0.359, val_acc:62.408
# Best loss:0.347, Best accuracy:58.088, Best F1-score:56.077
# 34/300 lr=0.00100 - loss:0.303, acc:73.319, val_loss:0.343, val_acc:57.904
# Best loss:0.347, Best accuracy:58.088, Best F1-score:56.077
# 35/300 lr=0.00100 - loss:0.296, acc:71.061, val_loss:0.315, val_acc:62.592
# Best loss:0.343, Best accuracy:57.904, Best F1-score:55.901
# 36/300 lr=0.00100 - loss:0.301, acc:71.113, val_loss:0.318, val_acc:62.408
# Best loss:0.315, Best accuracy:62.592, Best F1-score:61.741
# 37/300 lr=0.00100 - loss:0.293, acc:75.026, val_loss:0.324, val_acc:56.710
# Best loss:0.315, Best accuracy:62.592, Best F1-score:61.741
# 38/300 lr=0.00100 - loss:0.285, acc:72.899, val_loss:0.314, val_acc:64.154
# Best loss:0.315, Best accuracy:62.592, Best F1-score:61.741
# 39/300 lr=0.00100 - loss:0.291, acc:74.068, val_loss:0.337, val_acc:54.963
# Best loss:0.314, Best accuracy:64.154, Best F1-score:62.065
# 40/300 lr=0.00100 - loss:0.295, acc:74.041, val_loss:0.322, val_acc:53.585
# Best loss:0.314, Best accuracy:64.154, Best F1-score:62.065
# 41/300 lr=0.00100 - loss:0.285, acc:72.728, val_loss:0.269, val_acc:70.037
# Best loss:0.314, Best accuracy:64.154, Best F1-score:62.065
# 42/300 lr=0.00100 - loss:0.281, acc:75.276, val_loss:0.321, val_acc:59.467
# Best loss:0.269, Best accuracy:70.037, Best F1-score:67.609
# 43/300 lr=0.00100 - loss:0.278, acc:75.328, val_loss:0.291, val_acc:61.029
# Best loss:0.269, Best accuracy:70.037, Best F1-score:67.609
# 44/300 lr=0.00100 - loss:0.276, acc:73.792, val_loss:0.303, val_acc:67.096
# Best loss:0.269, Best accuracy:70.037, Best F1-score:67.609
# 45/300 lr=0.00100 - loss:0.261, acc:76.641, val_loss:0.264, val_acc:66.912
# Best loss:0.269, Best accuracy:70.037, Best F1-score:67.609
# 46/300 lr=0.00100 - loss:0.261, acc:75.998, val_loss:0.251, val_acc:71.415
# Best loss:0.264, Best accuracy:66.912, Best F1-score:64.139
# 47/300 lr=0.00100 - loss:0.261, acc:75.972, val_loss:0.275, val_acc:67.096
# Best loss:0.251, Best accuracy:71.415, Best F1-score:66.943
# 48/300 lr=0.00100 - loss:0.261, acc:73.871, val_loss:0.279, val_acc:59.651
# Best loss:0.251, Best accuracy:71.415, Best F1-score:66.943
# Best loss:0.199, Best accuracy:79.688, Best F1-score:79.875
# 297/300 lr=0.00017 - loss:0.104, acc:99.157, val_loss:0.219, val_acc:76.562
# Best loss:0.199, Best accuracy:79.688, Best F1-score:79.875
# 298/300 lr=0.00017 - loss:0.104, acc:99.330, val_loss:0.231, val_acc:73.438
# Best loss:0.199, Best accuracy:79.688, Best F1-score:79.875
# 299/300 lr=0.00017 - loss:0.108, acc:99.107, val_loss:0.236, val_acc:75.000
# Best loss:0.199, Best accuracy:79.688, Best F1-score:79.875
# 300/300 lr=0.00017 - loss:0.106, acc:99.330, val_loss:0.230, val_acc:75.000
# Best loss:0.199, Best accuracy:79.688, Best F1-score:79.875
# ********************************************************************************
# [*] Done Fold-10
# best_val_loss:0.199, best_val_acc:79.688, best_val_f1:79.875
# test_acc:92.113, test_f1:91.808
# ********************************************************************************

# %%
end()

# %%
print('*' * 80)
print('[*] validation accuracy')
for i, val_acc in enumerate(fold_val_acc):
    print(f'    Fold-{i+1} : {val_acc}')
print(f'max:{max(fold_val_acc)}, min:{min(fold_val_acc)}, average:{sum(fold_val_acc)/len(fold_val_acc)}')
print('*' * 80)
print()

print('*' * 80)
print('[*] test accuracy')
for i, test_acc in enumerate(fold_test_acc):
    print(f'    Fold-{i+1} : {test_acc}')
print(f'max:{max(fold_test_acc)}, min:{min(fold_test_acc)}, average:{sum(fold_test_acc)/len(fold_test_acc)}')
print('*' * 80)
print()
# Out:
# ********************************************************************************
# [*] validation accuracy
#     Fold-1 : 86.30514740943909
#     Fold-2 : 87.68382370471954
#     Fold-3 : 89.0625
#     Fold-4 : 81.25
#     Fold-5 : 84.375
#     Fold-6 : 90.625
#     Fold-7 : 85.9375
#     Fold-8 : 89.0625
#     Fold-9 : 85.9375
#     Fold-10 : 79.6875
# max:90.625, min:79.6875, average:85.99264711141586
# ********************************************************************************
#
# ********************************************************************************
# [*] test accuracy
#     Fold-1 : 92.11309552192688
#     Fold-2 : 85.04464328289032
#     Fold-3 : 92.11309552192688
#     Fold-4 : 92.11309552192688
#     Fold-5 : 88.98809552192688
#     Fold-6 : 89.73214328289032
#     Fold-7 : 89.73214328289032
#     Fold-8 : 85.78869104385376
#     Fold-9 : 90.55059552192688
#     Fold-10 : 92.11309552192688
# max:92.11309552192688, min:85.04464328289032, average:89.8288694024086
# ********************************************************************************

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
# Out:
# WAR(Weighted Average Recall)   : 88.15%
# UAR(Unweighted Average Recall) : 88.15%
