# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = 'TIMNET-dataset'
DATA_PATH = 'EMODB'
CLASS_LABELS = Config.EMODB_LABELS
k = 10

# No-reverse : (196,39,1)  ## CA: Channel-attention    ## SA : Self-attention 
model_name = 'exp1'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, dilation_rate=(2,2)),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule]),
        Lambda(function=PrimaryCapssquash)
    ])
    
  def call(self, inputs):
    return self.conv(inputs)

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.conv3 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
  
    # Q, V, K
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.cbam = CBAM(64) # sharing
    self.reshape = Reshape(target_shape=[-1, 64])
    
    self.conv4 = PrimaryCap()
    self.spatial_attn = SpatialGate()
  
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    x = inputs
    forward = x
    backward = tf.reverse(inputs, axis=[2])
    
    fx = self.conv1(forward)
    fx += self.cbam(fx)
    bx = self.conv2(backward)
    bx += self.cbam(bx)
    cross_attn_out = self.attention([fx, bx, bx]) # Q, K==V
    fx += cross_attn_out
    
    fx = self.conv3(fx)
    fx += self.cbam(fx)
    
    cap = self.conv4(fx)
    cap = tf.expand_dims(cap, axis=-1)
    cap += self.spatial_attn(cap)
    cap = tf.squeeze(cap, axis=-1)
    
    sa = self.attention([cap, cap, cap])
    sa = self.LN(sa)
    
    sa = self.lamb([cap, sa])
    sa = tf.expand_dims(sa, axis=-1)
    sa += self.spatial_attn(sa)
    cap = tf.squeeze(sa, axis=-1)
    
    capsule = self.capsule(cap)
    
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1416
#
#  sequential_1 (Sequential)   (None, 97, 18, 64)        1416
#
#  sequential_2 (Sequential)   (None, 46, 7, 64)         37300
#
#  attention (Attention)       multiple                  1
#
#  layer_normalization (LayerN  multiple                 128
#  ormalization)
#
#  lambda (Lambda)             multiple                  0
#
#  cbam (CBAM)                 multiple                  4294
#
#  reshape (Reshape)           multiple                  0 (unused)
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  spatial_gate_1 (SpatialGate  multiple                 102
#  )
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  455
#
# =================================================================
# Total params: 95,288
# Trainable params: 94,322
# Non-trainable params: 966
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}.npy', 'rb') as f:
    x = np.load(f)
    y = np.load(f)

y = to_categorical(y,num_classes=len(CLASS_LABELS))

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, test) in tqdm(enumerate(kfold.split(x, y)), desc=f'Training {k}-Fold.....'):
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = x[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_test, y_test = x[test], y[test]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_test = tf.expand_dims(x_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_test_loss = 0x3f3f3f
    best_test_acc = -1
    best_test_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        test_loss, test_acc, f1s = [], [], []
        for features, labels in batch_test:
            loss, acc, pred = test_step(model, features, labels)
            test_loss.append(loss)
            test_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(test_loss)/len(test_loss)
        val_acc = sum(test_acc)/len(test_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_test_loss:.3f}, Best accuracy:{best_test_acc:.3f}, Best F1-score:{best_test_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_test_acc < val_acc:
            best_test_acc = val_acc
            best_test_loss = val_loss
            best_test_f1 = f1_score
            model.save_weights(h5_path)
            
            
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    
    for features, labels in batch_test:
        best_pred = model(features, training=False)
        emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(labels, axis=1))
        predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
    
    
    print(f'[*] Done - acc:{best_test_acc:.3f}')
    
    plt.title(f'{i+1}-fold Loss Curve - Best acc:{best_test_acc:.3f}, Best loss:{best_test_loss:.3f}')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])

    
    save_fig_path = f'Fig/{DATA_PATH}/training/{model_name}'
    os.makedirs(save_fig_path, exist_ok=True)
    plt.savefig(f'{save_fig_path}/{i+1}-fold.PNG')
    
    plt.show()
    
    fold_acc.append(best_test_acc)
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.596, acc:23.828, val_loss:0.572, val_acc:42.188
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.568, acc:34.766, val_loss:0.531, val_acc:43.750
# Best loss:0.572, Best accuracy:42.188, Best F1-score:0.281
# 3/300 lr=0.00100 - loss:0.535, acc:42.773, val_loss:0.506, val_acc:51.420
# Best loss:0.531, Best accuracy:43.750, Best F1-score:0.297
# 4/300 lr=0.00100 - loss:0.509, acc:45.117, val_loss:0.486, val_acc:51.420
# Best loss:0.506, Best accuracy:51.420, Best F1-score:0.389
# 5/300 lr=0.00100 - loss:0.505, acc:45.117, val_loss:0.466, val_acc:50.000
# Best loss:0.506, Best accuracy:51.420, Best F1-score:0.389
# 6/300 lr=0.00100 - loss:0.482, acc:53.320, val_loss:0.452, val_acc:51.562
# Best loss:0.506, Best accuracy:51.420, Best F1-score:0.389
# 7/300 lr=0.00100 - loss:0.466, acc:54.297, val_loss:0.438, val_acc:54.688
# Best loss:0.452, Best accuracy:51.562, Best F1-score:0.457
# 8/300 lr=0.00100 - loss:0.443, acc:52.930, val_loss:0.425, val_acc:51.705
# Best loss:0.438, Best accuracy:54.688, Best F1-score:0.472
# 9/300 lr=0.00100 - loss:0.468, acc:47.070, val_loss:0.419, val_acc:52.415
# Best loss:0.438, Best accuracy:54.688, Best F1-score:0.472
# 10/300 lr=0.00100 - loss:0.451, acc:55.078, val_loss:0.404, val_acc:58.523
# Best loss:0.438, Best accuracy:54.688, Best F1-score:0.472
# 11/300 lr=0.00100 - loss:0.464, acc:49.609, val_loss:0.396, val_acc:50.852
# Best loss:0.404, Best accuracy:58.523, Best F1-score:0.535
# 12/300 lr=0.00100 - loss:0.454, acc:48.242, val_loss:0.409, val_acc:48.438
# Best loss:0.404, Best accuracy:58.523, Best F1-score:0.535
# 13/300 lr=0.00100 - loss:0.417, acc:56.836, val_loss:0.397, val_acc:56.960
# Best loss:0.404, Best accuracy:58.523, Best F1-score:0.535
# 14/300 lr=0.00100 - loss:0.421, acc:56.641, val_loss:0.399, val_acc:53.835
# Best loss:0.404, Best accuracy:58.523, Best F1-score:0.535
# 15/300 lr=0.00100 - loss:0.427, acc:55.469, val_loss:0.411, val_acc:52.273
# Best loss:0.404, Best accuracy:58.523, Best F1-score:0.535
# 16/300 lr=0.00100 - loss:0.401, acc:58.203, val_loss:0.373, val_acc:55.540
# Best loss:0.404, Best accuracy:58.523, Best F1-score:0.535
# 17/300 lr=0.00100 - loss:0.400, acc:59.766, val_loss:0.405, val_acc:49.290
# Best loss:0.404, Best accuracy:58.523, Best F1-score:0.535
# 18/300 lr=0.00100 - loss:0.416, acc:52.344, val_loss:0.367, val_acc:62.358
# Best loss:0.404, Best accuracy:58.523, Best F1-score:0.535
# 19/300 lr=0.00100 - loss:0.388, acc:58.984, val_loss:0.389, val_acc:52.983
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 20/300 lr=0.00100 - loss:0.404, acc:58.008, val_loss:0.362, val_acc:60.653
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 21/300 lr=0.00100 - loss:0.394, acc:61.133, val_loss:0.370, val_acc:53.835
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 22/300 lr=0.00100 - loss:0.381, acc:58.203, val_loss:0.369, val_acc:53.835
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 23/300 lr=0.00100 - loss:0.371, acc:60.547, val_loss:0.374, val_acc:53.835
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 24/300 lr=0.00100 - loss:0.394, acc:55.078, val_loss:0.373, val_acc:55.256
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 25/300 lr=0.00100 - loss:0.387, acc:57.227, val_loss:0.342, val_acc:62.358
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 26/300 lr=0.00100 - loss:0.395, acc:57.422, val_loss:0.384, val_acc:50.000
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 27/300 lr=0.00100 - loss:0.386, acc:55.664, val_loss:0.381, val_acc:53.125
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 28/300 lr=0.00100 - loss:0.418, acc:54.883, val_loss:0.377, val_acc:52.415
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 29/300 lr=0.00100 - loss:0.386, acc:59.375, val_loss:0.373, val_acc:58.523
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 30/300 lr=0.00100 - loss:0.359, acc:63.867, val_loss:0.351, val_acc:62.216
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 31/300 lr=0.00100 - loss:0.354, acc:66.602, val_loss:0.376, val_acc:57.670
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 32/300 lr=0.00100 - loss:0.388, acc:57.227, val_loss:0.335, val_acc:60.795
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 33/300 lr=0.00100 - loss:0.362, acc:65.430, val_loss:0.381, val_acc:50.000
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 34/300 lr=0.00100 - loss:0.367, acc:59.570, val_loss:0.346, val_acc:58.523
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 35/300 lr=0.00100 - loss:0.347, acc:64.453, val_loss:0.348, val_acc:53.835
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 36/300 lr=0.00100 - loss:0.357, acc:64.844, val_loss:0.347, val_acc:59.233
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 37/300 lr=0.00100 - loss:0.343, acc:63.281, val_loss:0.334, val_acc:59.233
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 38/300 lr=0.00100 - loss:0.374, acc:59.961, val_loss:0.330, val_acc:65.341
# Best loss:0.367, Best accuracy:62.358, Best F1-score:0.555
# 39/300 lr=0.00100 - loss:0.350, acc:68.945, val_loss:0.301, val_acc:73.011
# Best loss:0.330, Best accuracy:65.341, Best F1-score:0.638
# 40/300 lr=0.00100 - loss:0.374, acc:63.086, val_loss:0.336, val_acc:58.381
# Best loss:0.301, Best accuracy:73.011, Best F1-score:0.719
# 41/300 lr=0.00100 - loss:0.363, acc:63.281, val_loss:0.310, val_acc:59.233
# Best loss:0.301, Best accuracy:73.011, Best F1-score:0.719
# 42/300 lr=0.00100 - loss:0.322, acc:69.531, val_loss:0.292, val_acc:69.886
# Best loss:0.301, Best accuracy:73.011, Best F1-score:0.719
# 43/300 lr=0.00100 - loss:0.368, acc:63.672, val_loss:0.311, val_acc:65.341
# Best loss:0.301, Best accuracy:73.011, Best F1-score:0.719
# 44/300 lr=0.00100 - loss:0.318, acc:68.750, val_loss:0.277, val_acc:71.591
# Best loss:0.301, Best accuracy:73.011, Best F1-score:0.719
# 45/300 lr=0.00100 - loss:0.316, acc:70.898, val_loss:0.301, val_acc:62.926
# Best loss:0.301, Best accuracy:73.011, Best F1-score:0.719
# 46/300 lr=0.00100 - loss:0.328, acc:65.430, val_loss:0.286, val_acc:66.193
# Best loss:0.301, Best accuracy:73.011, Best F1-score:0.719
# 47/300 lr=0.00100 - loss:0.300, acc:70.117, val_loss:0.321, val_acc:62.358
# Best loss:0.301, Best accuracy:73.011, Best F1-score:0.719
# 48/300 lr=0.00100 - loss:0.330, acc:67.578, val_loss:0.297, val_acc:69.886
# Best loss:0.301, Best accuracy:73.011, Best F1-score:0.719
# 49/300 lr=0.00100 - loss:0.337, acc:67.383, val_loss:0.293, val_acc:71.449
# Best loss:0.301, Best accuracy:73.011, Best F1-score:0.719
# 50/300 lr=0.00100 - loss:0.326, acc:67.578, val_loss:0.282, val_acc:71.449
# Best loss:0.301, Best accuracy:73.011, Best F1-score:0.719
# 51/300 lr=0.00100 - loss:0.343, acc:66.406, val_loss:0.249, val_acc:73.011
# Best loss:0.301, Best accuracy:73.011, Best F1-score:0.719
# 52/300 lr=0.00100 - loss:0.311, acc:71.289, val_loss:0.314, val_acc:64.631
# Best loss:0.301, Best accuracy:73.011, Best F1-score:0.719
# 53/300 lr=0.00100 - loss:0.306, acc:66.797, val_loss:0.263, val_acc:75.426
# Best loss:0.301, Best accuracy:73.011, Best F1-score:0.719
# 54/300 lr=0.00100 - loss:0.295, acc:73.633, val_loss:0.271, val_acc:66.335
# Best loss:0.263, Best accuracy:75.426, Best F1-score:0.750
# 55/300 lr=0.00100 - loss:0.332, acc:66.211, val_loss:0.311, val_acc:66.193
# Best loss:0.263, Best accuracy:75.426, Best F1-score:0.750
# 56/300 lr=0.00100 - loss:0.296, acc:72.656, val_loss:0.275, val_acc:69.176
# Best loss:0.263, Best accuracy:75.426, Best F1-score:0.750
# 57/300 lr=0.00100 - loss:0.291, acc:73.438, val_loss:0.264, val_acc:76.136
# Best loss:0.263, Best accuracy:75.426, Best F1-score:0.750
# 58/300 lr=0.00100 - loss:0.298, acc:75.781, val_loss:0.268, val_acc:75.284
# Best loss:0.264, Best accuracy:76.136, Best F1-score:0.765
# 59/300 lr=0.00100 - loss:0.282, acc:74.219, val_loss:0.259, val_acc:71.591
# Best loss:0.264, Best accuracy:76.136, Best F1-score:0.765
# 60/300 lr=0.00100 - loss:0.279, acc:75.586, val_loss:0.251, val_acc:71.591
# Best loss:0.264, Best accuracy:76.136, Best F1-score:0.765
# 61/300 lr=0.00100 - loss:0.284, acc:76.367, val_loss:0.289, val_acc:66.903
# Best loss:0.264, Best accuracy:76.136, Best F1-score:0.765
# 62/300 lr=0.00086 - loss:0.265, acc:76.758, val_loss:0.269, val_acc:70.028
# Best loss:0.264, Best accuracy:76.136, Best F1-score:0.765
# 63/300 lr=0.00086 - loss:0.268, acc:76.367, val_loss:0.247, val_acc:74.574
# Best loss:0.264, Best accuracy:76.136, Best F1-score:0.765
# 64/300 lr=0.00086 - loss:0.273, acc:76.562, val_loss:0.233, val_acc:71.591
# Best loss:0.264, Best accuracy:76.136, Best F1-score:0.765
# 65/300 lr=0.00086 - loss:0.265, acc:77.539, val_loss:0.257, val_acc:73.011
# Best loss:0.264, Best accuracy:76.136, Best F1-score:0.765
# 66/300 lr=0.00086 - loss:0.278, acc:74.609, val_loss:0.226, val_acc:77.557
# Best loss:0.264, Best accuracy:76.136, Best F1-score:0.765
# 67/300 lr=0.00086 - loss:0.265, acc:78.320, val_loss:0.235, val_acc:79.830
# Best loss:0.226, Best accuracy:77.557, Best F1-score:0.777
# 68/300 lr=0.00086 - loss:0.255, acc:80.078, val_loss:0.219, val_acc:78.551
# Best loss:0.235, Best accuracy:79.830, Best F1-score:0.802
# 69/300 lr=0.00086 - loss:0.278, acc:73.242, val_loss:0.232, val_acc:77.699
# Best loss:0.235, Best accuracy:79.830, Best F1-score:0.802
# 70/300 lr=0.00086 - loss:0.256, acc:79.883, val_loss:0.249, val_acc:71.591
# Best loss:0.235, Best accuracy:79.830, Best F1-score:0.802
# 71/300 lr=0.00086 - loss:0.263, acc:79.102, val_loss:0.222, val_acc:79.261
# Best loss:0.235, Best accuracy:79.830, Best F1-score:0.802
# 72/300 lr=0.00086 - loss:0.271, acc:73.633, val_loss:0.202, val_acc:80.824
# Best loss:0.235, Best accuracy:79.830, Best F1-score:0.802
# 73/300 lr=0.00086 - loss:0.272, acc:73.438, val_loss:0.230, val_acc:75.426
# Best loss:0.202, Best accuracy:80.824, Best F1-score:0.818
# 74/300 lr=0.00086 - loss:0.247, acc:80.469, val_loss:0.237, val_acc:75.994
# Best loss:0.202, Best accuracy:80.824, Best F1-score:0.818
# 75/300 lr=0.00086 - loss:0.256, acc:79.688, val_loss:0.234, val_acc:75.284
# Best loss:0.202, Best accuracy:80.824, Best F1-score:0.818
# 76/300 lr=0.00086 - loss:0.280, acc:74.023, val_loss:0.229, val_acc:71.591
# Best loss:0.202, Best accuracy:80.824, Best F1-score:0.818
# 77/300 lr=0.00086 - loss:0.248, acc:79.883, val_loss:0.256, val_acc:70.881
# Best loss:0.202, Best accuracy:80.824, Best F1-score:0.818
# 78/300 lr=0.00086 - loss:0.245, acc:80.469, val_loss:0.209, val_acc:77.841
# Best loss:0.202, Best accuracy:80.824, Best F1-score:0.818
# 79/300 lr=0.00086 - loss:0.246, acc:81.250, val_loss:0.201, val_acc:78.551
# Best loss:0.202, Best accuracy:80.824, Best F1-score:0.818
# 80/300 lr=0.00086 - loss:0.247, acc:82.227, val_loss:0.244, val_acc:74.574
# Best loss:0.202, Best accuracy:80.824, Best F1-score:0.818
# 81/300 lr=0.00086 - loss:0.242, acc:79.883, val_loss:0.223, val_acc:73.011
# Best loss:0.202, Best accuracy:80.824, Best F1-score:0.818
# 82/300 lr=0.00074 - loss:0.244, acc:81.055, val_loss:0.191, val_acc:86.222
# Best loss:0.202, Best accuracy:80.824, Best F1-score:0.818
# 83/300 lr=0.00074 - loss:0.285, acc:74.609, val_loss:0.221, val_acc:73.864
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 84/300 lr=0.00074 - loss:0.257, acc:80.078, val_loss:0.264, val_acc:69.176
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 85/300 lr=0.00074 - loss:0.237, acc:80.078, val_loss:0.199, val_acc:79.261
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 86/300 lr=0.00074 - loss:0.229, acc:81.641, val_loss:0.186, val_acc:81.534
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 87/300 lr=0.00074 - loss:0.220, acc:83.008, val_loss:0.197, val_acc:76.847
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 88/300 lr=0.00074 - loss:0.236, acc:83.398, val_loss:0.194, val_acc:79.972
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 89/300 lr=0.00074 - loss:0.231, acc:82.422, val_loss:0.178, val_acc:82.244
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 90/300 lr=0.00074 - loss:0.219, acc:82.617, val_loss:0.189, val_acc:79.972
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 91/300 lr=0.00074 - loss:0.216, acc:83.789, val_loss:0.212, val_acc:76.136
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 92/300 lr=0.00074 - loss:0.227, acc:83.203, val_loss:0.180, val_acc:84.517
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 93/300 lr=0.00074 - loss:0.220, acc:82.617, val_loss:0.184, val_acc:76.136
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 94/300 lr=0.00074 - loss:0.205, acc:85.156, val_loss:0.184, val_acc:83.807
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 95/300 lr=0.00074 - loss:0.221, acc:83.984, val_loss:0.183, val_acc:81.534
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 96/300 lr=0.00074 - loss:0.208, acc:83.984, val_loss:0.171, val_acc:83.807
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 97/300 lr=0.00074 - loss:0.219, acc:84.766, val_loss:0.161, val_acc:86.080
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 98/300 lr=0.00074 - loss:0.201, acc:85.742, val_loss:0.174, val_acc:84.517
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 99/300 lr=0.00074 - loss:0.221, acc:83.398, val_loss:0.175, val_acc:81.534
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 100/300 lr=0.00074 - loss:0.204, acc:86.328, val_loss:0.193, val_acc:81.392
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 101/300 lr=0.00074 - loss:0.248, acc:77.344, val_loss:0.167, val_acc:80.682
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 102/300 lr=0.00064 - loss:0.219, acc:85.938, val_loss:0.190, val_acc:82.102
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# 103/300 lr=0.00064 - loss:0.197, acc:86.328, val_loss:0.181, val_acc:79.119
# Best loss:0.191, Best accuracy:86.222, Best F1-score:0.858
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 200/300 lr=0.00035 - loss:0.139, acc:94.727, val_loss:0.151, val_acc:81.534
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 201/300 lr=0.00035 - loss:0.135, acc:94.727, val_loss:0.148, val_acc:82.955
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 202/300 lr=0.00030 - loss:0.127, acc:96.289, val_loss:0.152, val_acc:79.830
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 203/300 lr=0.00030 - loss:0.150, acc:94.727, val_loss:0.163, val_acc:79.830
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 204/300 lr=0.00030 - loss:0.131, acc:96.094, val_loss:0.142, val_acc:82.955
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 205/300 lr=0.00030 - loss:0.130, acc:95.312, val_loss:0.139, val_acc:86.080
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 206/300 lr=0.00030 - loss:0.133, acc:95.898, val_loss:0.152, val_acc:82.955
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 207/300 lr=0.00030 - loss:0.132, acc:96.094, val_loss:0.141, val_acc:80.682
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 208/300 lr=0.00030 - loss:0.139, acc:95.312, val_loss:0.155, val_acc:79.119
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 209/300 lr=0.00030 - loss:0.134, acc:96.289, val_loss:0.166, val_acc:81.392
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 210/300 lr=0.00030 - loss:0.130, acc:96.484, val_loss:0.166, val_acc:79.830
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 211/300 lr=0.00030 - loss:0.130, acc:95.898, val_loss:0.166, val_acc:80.682
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 212/300 lr=0.00030 - loss:0.129, acc:96.289, val_loss:0.151, val_acc:80.682
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 213/300 lr=0.00030 - loss:0.131, acc:95.117, val_loss:0.180, val_acc:79.972
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 214/300 lr=0.00030 - loss:0.133, acc:95.508, val_loss:0.162, val_acc:79.972
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 215/300 lr=0.00030 - loss:0.123, acc:96.484, val_loss:0.159, val_acc:82.955
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 216/300 lr=0.00030 - loss:0.129, acc:96.289, val_loss:0.161, val_acc:80.682
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 217/300 lr=0.00030 - loss:0.124, acc:96.289, val_loss:0.167, val_acc:79.119
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 218/300 lr=0.00030 - loss:0.123, acc:96.875, val_loss:0.160, val_acc:82.955
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 219/300 lr=0.00030 - loss:0.124, acc:97.266, val_loss:0.166, val_acc:79.830
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 220/300 lr=0.00030 - loss:0.119, acc:97.461, val_loss:0.158, val_acc:81.392
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 221/300 lr=0.00030 - loss:0.122, acc:97.266, val_loss:0.164, val_acc:83.807
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 222/300 lr=0.00026 - loss:0.123, acc:96.875, val_loss:0.149, val_acc:85.369
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 223/300 lr=0.00026 - loss:0.123, acc:97.266, val_loss:0.161, val_acc:80.682
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 224/300 lr=0.00026 - loss:0.127, acc:97.266, val_loss:0.145, val_acc:82.244
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 225/300 lr=0.00026 - loss:0.129, acc:96.289, val_loss:0.165, val_acc:79.119
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 226/300 lr=0.00026 - loss:0.117, acc:97.656, val_loss:0.167, val_acc:78.267
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 227/300 lr=0.00026 - loss:0.123, acc:97.266, val_loss:0.143, val_acc:81.392
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 228/300 lr=0.00026 - loss:0.121, acc:97.070, val_loss:0.157, val_acc:79.830
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 229/300 lr=0.00026 - loss:0.128, acc:98.242, val_loss:0.147, val_acc:81.392
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 230/300 lr=0.00026 - loss:0.121, acc:96.680, val_loss:0.168, val_acc:81.392
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 231/300 lr=0.00026 - loss:0.120, acc:97.461, val_loss:0.171, val_acc:79.830
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 232/300 lr=0.00026 - loss:0.120, acc:97.461, val_loss:0.144, val_acc:84.517
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
#
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 265/300 lr=0.00019 - loss:0.115, acc:97.852, val_loss:0.138, val_acc:87.642
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 266/300 lr=0.00019 - loss:0.116, acc:97.852, val_loss:0.152, val_acc:83.807
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 267/300 lr=0.00019 - loss:0.123, acc:98.047, val_loss:0.163, val_acc:82.244
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 268/300 lr=0.00019 - loss:0.115, acc:98.047, val_loss:0.164, val_acc:77.557
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 269/300 lr=0.00019 - loss:0.115, acc:97.656, val_loss:0.176, val_acc:78.267
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 270/300 lr=0.00019 - loss:0.118, acc:97.266, val_loss:0.152, val_acc:81.392
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 271/300 lr=0.00019 - loss:0.120, acc:97.266, val_loss:0.144, val_acc:83.807
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 272/300 lr=0.00019 - loss:0.120, acc:96.484, val_loss:0.155, val_acc:83.807
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 273/300 lr=0.00019 - loss:0.117, acc:97.266, val_loss:0.175, val_acc:75.994
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 274/300 lr=0.00019 - loss:0.111, acc:98.438, val_loss:0.144, val_acc:83.097
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 275/300 lr=0.00019 - loss:0.117, acc:97.656, val_loss:0.152, val_acc:81.534
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 276/300 lr=0.00019 - loss:0.116, acc:98.633, val_loss:0.171, val_acc:78.267
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 277/300 lr=0.00019 - loss:0.119, acc:97.070, val_loss:0.168, val_acc:78.267
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 278/300 lr=0.00019 - loss:0.138, acc:96.094, val_loss:0.158, val_acc:81.392
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 279/300 lr=0.00019 - loss:0.117, acc:97.070, val_loss:0.161, val_acc:77.557
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 280/300 lr=0.00019 - loss:0.114, acc:98.633, val_loss:0.181, val_acc:77.557
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 281/300 lr=0.00019 - loss:0.113, acc:98.633, val_loss:0.172, val_acc:80.682
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 282/300 lr=0.00017 - loss:0.115, acc:97.656, val_loss:0.175, val_acc:77.557
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 283/300 lr=0.00017 - loss:0.114, acc:98.047, val_loss:0.154, val_acc:79.972
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 284/300 lr=0.00017 - loss:0.111, acc:98.047, val_loss:0.139, val_acc:87.642
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 285/300 lr=0.00017 - loss:0.117, acc:98.633, val_loss:0.136, val_acc:84.517
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 286/300 lr=0.00017 - loss:0.122, acc:97.070, val_loss:0.166, val_acc:81.392
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 287/300 lr=0.00017 - loss:0.110, acc:98.633, val_loss:0.152, val_acc:82.955
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 288/300 lr=0.00017 - loss:0.122, acc:92.969, val_loss:0.164, val_acc:79.972
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 289/300 lr=0.00017 - loss:0.112, acc:99.023, val_loss:0.171, val_acc:78.409
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 290/300 lr=0.00017 - loss:0.119, acc:97.070, val_loss:0.172, val_acc:79.119
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 291/300 lr=0.00017 - loss:0.120, acc:97.070, val_loss:0.169, val_acc:79.972
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 292/300 lr=0.00017 - loss:0.109, acc:98.828, val_loss:0.159, val_acc:82.244
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 293/300 lr=0.00017 - loss:0.116, acc:97.656, val_loss:0.162, val_acc:86.080
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 294/300 lr=0.00017 - loss:0.106, acc:99.023, val_loss:0.161, val_acc:82.244
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 295/300 lr=0.00017 - loss:0.111, acc:99.023, val_loss:0.171, val_acc:82.244
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 296/300 lr=0.00017 - loss:0.110, acc:98.828, val_loss:0.174, val_acc:80.682
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 297/300 lr=0.00017 - loss:0.108, acc:99.023, val_loss:0.170, val_acc:78.409
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 298/300 lr=0.00017 - loss:0.122, acc:96.680, val_loss:0.180, val_acc:75.994
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 299/300 lr=0.00017 - loss:0.111, acc:98.438, val_loss:0.155, val_acc:81.392
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# 300/300 lr=0.00017 - loss:0.113, acc:97.461, val_loss:0.162, val_acc:81.392
# Best loss:0.139, Best accuracy:90.767, Best F1-score:0.913
# [*] Done - acc:90.767
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.594, acc:29.688, val_loss:0.577, val_acc:30.682
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.567, acc:35.742, val_loss:0.546, val_acc:47.727
# Best loss:0.577, Best accuracy:30.682, Best F1-score:0.163
# 3/300 lr=0.00100 - loss:0.554, acc:38.281, val_loss:0.535, val_acc:35.369
# Best loss:0.546, Best accuracy:47.727, Best F1-score:0.340
# 4/300 lr=0.00100 - loss:0.518, acc:42.773, val_loss:0.505, val_acc:50.852
# Best loss:0.546, Best accuracy:47.727, Best F1-score:0.340
# 5/300 lr=0.00100 - loss:0.522, acc:39.258, val_loss:0.503, val_acc:50.852
# Best loss:0.505, Best accuracy:50.852, Best F1-score:0.375
# 6/300 lr=0.00100 - loss:0.514, acc:44.531, val_loss:0.464, val_acc:52.415
# Best loss:0.505, Best accuracy:50.852, Best F1-score:0.375
# 7/300 lr=0.00100 - loss:0.499, acc:45.703, val_loss:0.462, val_acc:49.290
# Best loss:0.464, Best accuracy:52.415, Best F1-score:0.392
# 8/300 lr=0.00100 - loss:0.474, acc:47.852, val_loss:0.434, val_acc:56.960
# Best loss:0.464, Best accuracy:52.415, Best F1-score:0.392
# 9/300 lr=0.00100 - loss:0.464, acc:53.516, val_loss:0.449, val_acc:50.852
# Best loss:0.434, Best accuracy:56.960, Best F1-score:0.463
# 10/300 lr=0.00100 - loss:0.455, acc:54.297, val_loss:0.425, val_acc:56.960
# Best loss:0.434, Best accuracy:56.960, Best F1-score:0.463
# 11/300 lr=0.00100 - loss:0.432, acc:54.297, val_loss:0.412, val_acc:57.812
# Best loss:0.434, Best accuracy:56.960, Best F1-score:0.463
# 12/300 lr=0.00100 - loss:0.414, acc:57.031, val_loss:0.423, val_acc:56.250
# Best loss:0.412, Best accuracy:57.812, Best F1-score:0.499
# 13/300 lr=0.00100 - loss:0.418, acc:55.078, val_loss:0.403, val_acc:50.852
# Best loss:0.412, Best accuracy:57.812, Best F1-score:0.499
# 14/300 lr=0.00100 - loss:0.436, acc:50.391, val_loss:0.406, val_acc:55.398
# Best loss:0.412, Best accuracy:57.812, Best F1-score:0.499
# 15/300 lr=0.00100 - loss:0.430, acc:52.539, val_loss:0.387, val_acc:54.688
# Best loss:0.412, Best accuracy:57.812, Best F1-score:0.499
# 16/300 lr=0.00100 - loss:0.413, acc:57.227, val_loss:0.387, val_acc:55.398
# Best loss:0.412, Best accuracy:57.812, Best F1-score:0.499
# 17/300 lr=0.00100 - loss:0.388, acc:60.156, val_loss:0.387, val_acc:50.142
# Best loss:0.412, Best accuracy:57.812, Best F1-score:0.499
# 18/300 lr=0.00100 - loss:0.417, acc:58.984, val_loss:0.390, val_acc:58.523
# Best loss:0.412, Best accuracy:57.812, Best F1-score:0.499
# 19/300 lr=0.00100 - loss:0.412, acc:59.375, val_loss:0.381, val_acc:53.125
# Best loss:0.390, Best accuracy:58.523, Best F1-score:0.518
# 20/300 lr=0.00100 - loss:0.399, acc:57.422, val_loss:0.387, val_acc:50.852
# Best loss:0.390, Best accuracy:58.523, Best F1-score:0.518
# 21/300 lr=0.00100 - loss:0.428, acc:51.758, val_loss:0.378, val_acc:55.398
# Best loss:0.390, Best accuracy:58.523, Best F1-score:0.518
# 22/300 lr=0.00100 - loss:0.370, acc:62.891, val_loss:0.377, val_acc:56.960
# Best loss:0.390, Best accuracy:58.523, Best F1-score:0.518
# 23/300 lr=0.00100 - loss:0.385, acc:61.133, val_loss:0.361, val_acc:58.523
# Best loss:0.390, Best accuracy:58.523, Best F1-score:0.518
# 24/300 lr=0.00100 - loss:0.373, acc:61.328, val_loss:0.375, val_acc:53.125
# Best loss:0.390, Best accuracy:58.523, Best F1-score:0.518
# 25/300 lr=0.00100 - loss:0.390, acc:55.078, val_loss:0.366, val_acc:58.523
# Best loss:0.390, Best accuracy:58.523, Best F1-score:0.518
# 26/300 lr=0.00100 - loss:0.370, acc:60.938, val_loss:0.357, val_acc:57.812
# Best loss:0.390, Best accuracy:58.523, Best F1-score:0.518
# 27/300 lr=0.00100 - loss:0.375, acc:60.742, val_loss:0.366, val_acc:53.125
# Best loss:0.390, Best accuracy:58.523, Best F1-score:0.518
# 28/300 lr=0.00100 - loss:0.384, acc:55.469, val_loss:0.362, val_acc:51.705
# Best loss:0.390, Best accuracy:58.523, Best F1-score:0.518
# 29/300 lr=0.00100 - loss:0.386, acc:56.641, val_loss:0.354, val_acc:61.648
# Best loss:0.390, Best accuracy:58.523, Best F1-score:0.518
# 30/300 lr=0.00100 - loss:0.353, acc:63.867, val_loss:0.358, val_acc:60.795
# Best loss:0.354, Best accuracy:61.648, Best F1-score:0.596
# 31/300 lr=0.00100 - loss:0.385, acc:56.836, val_loss:0.348, val_acc:59.233
# Best loss:0.354, Best accuracy:61.648, Best F1-score:0.596
# 32/300 lr=0.00100 - loss:0.366, acc:62.891, val_loss:0.346, val_acc:60.085
# Best loss:0.354, Best accuracy:61.648, Best F1-score:0.596
# 33/300 lr=0.00100 - loss:0.349, acc:65.234, val_loss:0.338, val_acc:56.960
# Best loss:0.354, Best accuracy:61.648, Best F1-score:0.596
# 34/300 lr=0.00100 - loss:0.365, acc:63.477, val_loss:0.340, val_acc:62.358
# Best loss:0.354, Best accuracy:61.648, Best F1-score:0.596
# 35/300 lr=0.00100 - loss:0.365, acc:64.844, val_loss:0.329, val_acc:66.903
# Best loss:0.340, Best accuracy:62.358, Best F1-score:0.604
# 36/300 lr=0.00100 - loss:0.378, acc:59.961, val_loss:0.334, val_acc:60.085
# Best loss:0.329, Best accuracy:66.903, Best F1-score:0.654
# 37/300 lr=0.00100 - loss:0.375, acc:59.961, val_loss:0.327, val_acc:62.358
# Best loss:0.329, Best accuracy:66.903, Best F1-score:0.654
# 38/300 lr=0.00100 - loss:0.343, acc:67.383, val_loss:0.330, val_acc:62.358
# Best loss:0.329, Best accuracy:66.903, Best F1-score:0.654
# 39/300 lr=0.00100 - loss:0.336, acc:66.992, val_loss:0.317, val_acc:67.756
# Best loss:0.329, Best accuracy:66.903, Best F1-score:0.654
# 40/300 lr=0.00100 - loss:0.345, acc:64.844, val_loss:0.322, val_acc:58.523
# Best loss:0.317, Best accuracy:67.756, Best F1-score:0.673
# 41/300 lr=0.00100 - loss:0.334, acc:65.820, val_loss:0.340, val_acc:54.688
# Best loss:0.317, Best accuracy:67.756, Best F1-score:0.673
# 42/300 lr=0.00100 - loss:0.333, acc:67.383, val_loss:0.320, val_acc:60.795
# Best loss:0.317, Best accuracy:67.756, Best F1-score:0.673
# 43/300 lr=0.00100 - loss:0.346, acc:64.062, val_loss:0.314, val_acc:56.250
# Best loss:0.317, Best accuracy:67.756, Best F1-score:0.673
# 44/300 lr=0.00100 - loss:0.345, acc:63.867, val_loss:0.338, val_acc:58.665
# Best loss:0.317, Best accuracy:67.756, Best F1-score:0.673
# 45/300 lr=0.00100 - loss:0.337, acc:69.141, val_loss:0.325, val_acc:63.210
# Best loss:0.317, Best accuracy:67.756, Best F1-score:0.673
# 46/300 lr=0.00100 - loss:0.361, acc:59.961, val_loss:0.310, val_acc:69.318
# Best loss:0.317, Best accuracy:67.756, Best F1-score:0.673
# 47/300 lr=0.00100 - loss:0.341, acc:68.750, val_loss:0.311, val_acc:73.153
# Best loss:0.310, Best accuracy:69.318, Best F1-score:0.688
# 48/300 lr=0.00100 - loss:0.339, acc:64.844, val_loss:0.334, val_acc:68.608
# Best loss:0.311, Best accuracy:73.153, Best F1-score:0.717
# 49/300 lr=0.00100 - loss:0.331, acc:70.703, val_loss:0.304, val_acc:60.795
# Best loss:0.311, Best accuracy:73.153, Best F1-score:0.717
# 50/300 lr=0.00100 - loss:0.338, acc:63.086, val_loss:0.286, val_acc:76.136
# Best loss:0.311, Best accuracy:73.153, Best F1-score:0.717
# 51/300 lr=0.00100 - loss:0.323, acc:70.312, val_loss:0.305, val_acc:67.756
# Best loss:0.286, Best accuracy:76.136, Best F1-score:0.756
# 52/300 lr=0.00100 - loss:0.317, acc:69.727, val_loss:0.303, val_acc:67.045
# Best loss:0.286, Best accuracy:76.136, Best F1-score:0.756
# 53/300 lr=0.00100 - loss:0.314, acc:71.875, val_loss:0.279, val_acc:68.608
# Best loss:0.286, Best accuracy:76.136, Best F1-score:0.756
# 54/300 lr=0.00100 - loss:0.322, acc:66.016, val_loss:0.278, val_acc:67.756
# Best loss:0.286, Best accuracy:76.136, Best F1-score:0.756
# 55/300 lr=0.00100 - loss:0.321, acc:67.578, val_loss:0.293, val_acc:69.318
# Best loss:0.286, Best accuracy:76.136, Best F1-score:0.756
# 56/300 lr=0.00100 - loss:0.313, acc:72.852, val_loss:0.284, val_acc:70.028
# Best loss:0.286, Best accuracy:76.136, Best F1-score:0.756
# ...
# 183/300 lr=0.00035 - loss:0.131, acc:96.094, val_loss:0.156, val_acc:81.101
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 184/300 lr=0.00035 - loss:0.125, acc:96.680, val_loss:0.160, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 185/300 lr=0.00035 - loss:0.124, acc:96.680, val_loss:0.159, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 186/300 lr=0.00035 - loss:0.124, acc:96.289, val_loss:0.144, val_acc:77.902
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 187/300 lr=0.00035 - loss:0.131, acc:95.703, val_loss:0.145, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 188/300 lr=0.00035 - loss:0.124, acc:96.484, val_loss:0.164, val_acc:77.158
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 189/300 lr=0.00035 - loss:0.130, acc:96.289, val_loss:0.165, val_acc:77.158
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 190/300 lr=0.00035 - loss:0.124, acc:96.289, val_loss:0.154, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 191/300 lr=0.00035 - loss:0.123, acc:96.875, val_loss:0.157, val_acc:82.664
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 192/300 lr=0.00035 - loss:0.124, acc:96.875, val_loss:0.173, val_acc:79.539
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 193/300 lr=0.00035 - loss:0.123, acc:97.266, val_loss:0.165, val_acc:80.283
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 194/300 lr=0.00035 - loss:0.126, acc:96.875, val_loss:0.154, val_acc:77.902
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 195/300 lr=0.00035 - loss:0.123, acc:98.047, val_loss:0.163, val_acc:80.283
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 196/300 lr=0.00035 - loss:0.128, acc:96.289, val_loss:0.140, val_acc:79.539
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 197/300 lr=0.00035 - loss:0.126, acc:96.680, val_loss:0.144, val_acc:87.426
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 198/300 lr=0.00035 - loss:0.138, acc:92.383, val_loss:0.137, val_acc:82.664
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 199/300 lr=0.00035 - loss:0.124, acc:96.289, val_loss:0.149, val_acc:75.521
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 200/300 lr=0.00035 - loss:0.126, acc:97.070, val_loss:0.160, val_acc:80.283
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 201/300 lr=0.00035 - loss:0.126, acc:96.289, val_loss:0.157, val_acc:80.283
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 202/300 lr=0.00030 - loss:0.128, acc:97.070, val_loss:0.151, val_acc:79.464
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 203/300 lr=0.00030 - loss:0.123, acc:97.461, val_loss:0.136, val_acc:85.789
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 204/300 lr=0.00030 - loss:0.124, acc:96.484, val_loss:0.146, val_acc:83.482
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 205/300 lr=0.00030 - loss:0.129, acc:96.484, val_loss:0.168, val_acc:77.158
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 206/300 lr=0.00030 - loss:0.124, acc:96.875, val_loss:0.147, val_acc:81.101
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 207/300 lr=0.00030 - loss:0.125, acc:97.266, val_loss:0.161, val_acc:82.664
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 208/300 lr=0.00030 - loss:0.124, acc:96.484, val_loss:0.157, val_acc:84.226
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 209/300 lr=0.00030 - loss:0.118, acc:97.656, val_loss:0.159, val_acc:74.777
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 210/300 lr=0.00030 - loss:0.136, acc:96.289, val_loss:0.167, val_acc:77.158
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 211/300 lr=0.00030 - loss:0.121, acc:96.875, val_loss:0.146, val_acc:85.789
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 212/300 lr=0.00030 - loss:0.129, acc:95.508, val_loss:0.157, val_acc:80.283
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 213/300 lr=0.00030 - loss:0.124, acc:97.461, val_loss:0.167, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 214/300 lr=0.00030 - loss:0.132, acc:96.094, val_loss:0.156, val_acc:80.283
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 215/300 lr=0.00030 - loss:0.118, acc:98.047, val_loss:0.133, val_acc:80.283
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
#
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 248/300 lr=0.00022 - loss:0.117, acc:97.656, val_loss:0.170, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 249/300 lr=0.00022 - loss:0.126, acc:96.094, val_loss:0.170, val_acc:79.539
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 250/300 lr=0.00022 - loss:0.115, acc:97.266, val_loss:0.155, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 251/300 lr=0.00022 - loss:0.123, acc:96.875, val_loss:0.144, val_acc:80.283
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 252/300 lr=0.00022 - loss:0.141, acc:94.922, val_loss:0.162, val_acc:77.158
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 253/300 lr=0.00022 - loss:0.113, acc:98.633, val_loss:0.157, val_acc:81.101
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 254/300 lr=0.00022 - loss:0.116, acc:96.875, val_loss:0.164, val_acc:81.101
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 255/300 lr=0.00022 - loss:0.119, acc:98.242, val_loss:0.187, val_acc:76.339
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 256/300 lr=0.00022 - loss:0.113, acc:98.242, val_loss:0.168, val_acc:81.101
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 257/300 lr=0.00022 - loss:0.116, acc:98.047, val_loss:0.154, val_acc:81.101
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 258/300 lr=0.00022 - loss:0.113, acc:98.438, val_loss:0.161, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 259/300 lr=0.00022 - loss:0.114, acc:98.047, val_loss:0.157, val_acc:81.101
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 260/300 lr=0.00022 - loss:0.114, acc:98.438, val_loss:0.149, val_acc:80.283
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 261/300 lr=0.00022 - loss:0.118, acc:98.242, val_loss:0.150, val_acc:80.283
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 262/300 lr=0.00019 - loss:0.114, acc:98.242, val_loss:0.147, val_acc:82.664
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 263/300 lr=0.00019 - loss:0.113, acc:98.242, val_loss:0.143, val_acc:83.482
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 264/300 lr=0.00019 - loss:0.120, acc:98.047, val_loss:0.153, val_acc:81.101
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 265/300 lr=0.00019 - loss:0.113, acc:98.242, val_loss:0.181, val_acc:76.339
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 266/300 lr=0.00019 - loss:0.115, acc:98.633, val_loss:0.191, val_acc:73.214
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 267/300 lr=0.00019 - loss:0.111, acc:98.828, val_loss:0.178, val_acc:74.777
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 268/300 lr=0.00019 - loss:0.117, acc:97.656, val_loss:0.173, val_acc:76.339
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 269/300 lr=0.00019 - loss:0.116, acc:98.047, val_loss:0.188, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 270/300 lr=0.00019 - loss:0.117, acc:97.266, val_loss:0.195, val_acc:79.539
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 271/300 lr=0.00019 - loss:0.144, acc:91.797, val_loss:0.171, val_acc:74.777
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 272/300 lr=0.00019 - loss:0.115, acc:97.656, val_loss:0.162, val_acc:76.339
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 273/300 lr=0.00019 - loss:0.112, acc:98.047, val_loss:0.154, val_acc:81.101
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 274/300 lr=0.00019 - loss:0.119, acc:98.242, val_loss:0.158, val_acc:82.664
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 275/300 lr=0.00019 - loss:0.120, acc:96.094, val_loss:0.177, val_acc:80.283
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 276/300 lr=0.00019 - loss:0.112, acc:98.828, val_loss:0.182, val_acc:76.339
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 277/300 lr=0.00019 - loss:0.115, acc:97.656, val_loss:0.176, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 278/300 lr=0.00019 - loss:0.108, acc:98.828, val_loss:0.170, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 279/300 lr=0.00019 - loss:0.111, acc:98.242, val_loss:0.162, val_acc:76.339
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 280/300 lr=0.00019 - loss:0.118, acc:97.070, val_loss:0.171, val_acc:77.902
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 281/300 lr=0.00019 - loss:0.113, acc:98.047, val_loss:0.166, val_acc:76.339
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 282/300 lr=0.00017 - loss:0.109, acc:98.828, val_loss:0.170, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 283/300 lr=0.00017 - loss:0.111, acc:99.219, val_loss:0.172, val_acc:76.339
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 284/300 lr=0.00017 - loss:0.116, acc:99.023, val_loss:0.165, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 285/300 lr=0.00017 - loss:0.123, acc:95.508, val_loss:0.177, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 286/300 lr=0.00017 - loss:0.115, acc:97.656, val_loss:0.177, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 287/300 lr=0.00017 - loss:0.111, acc:98.047, val_loss:0.183, val_acc:74.777
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 288/300 lr=0.00017 - loss:0.112, acc:97.656, val_loss:0.176, val_acc:77.158
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 289/300 lr=0.00017 - loss:0.116, acc:97.852, val_loss:0.175, val_acc:74.777
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 290/300 lr=0.00017 - loss:0.113, acc:98.633, val_loss:0.171, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 291/300 lr=0.00017 - loss:0.111, acc:98.633, val_loss:0.167, val_acc:80.283
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 292/300 lr=0.00017 - loss:0.110, acc:98.633, val_loss:0.170, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 293/300 lr=0.00017 - loss:0.110, acc:98.828, val_loss:0.185, val_acc:78.720
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 294/300 lr=0.00017 - loss:0.110, acc:98.438, val_loss:0.199, val_acc:74.777
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 295/300 lr=0.00017 - loss:0.110, acc:98.242, val_loss:0.174, val_acc:76.339
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 296/300 lr=0.00017 - loss:0.114, acc:98.047, val_loss:0.166, val_acc:73.958
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 297/300 lr=0.00017 - loss:0.111, acc:99.023, val_loss:0.174, val_acc:76.339
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 298/300 lr=0.00017 - loss:0.114, acc:97.656, val_loss:0.188, val_acc:74.777
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 299/300 lr=0.00017 - loss:0.114, acc:98.438, val_loss:0.184, val_acc:74.777
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# 300/300 lr=0.00017 - loss:0.121, acc:98.438, val_loss:0.179, val_acc:81.101
# Best loss:0.153, Best accuracy:88.170, Best F1-score:0.887
# [*] Done - acc:88.170

# %%
end()

# %%
print(f'max:{max(fold_acc)}, min:{min(fold_acc)}, average:{sum(fold_acc)/len(fold_acc)}')
# Out:
# max:90.76704680919647, min:85.11904776096344, average:88.18655341863632

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
# Out:
# WAR(Weighted Average Recall)   : 87.45%
# UAR(Unweighted Average Recall) : 87.45%
