# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = 'TIMNET-dataset'
DATA_PATH = 'RAVDESS'
CLASS_LABELS = Config.RAVDESS_LABELS
k = 10

model_name = 'ablation study(remove sa)'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding=padding),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule]),
        Lambda(function=PrimaryCapssquash)
    ])
    
  def call(self, inputs):
    return self.conv(inputs)

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.cbam = CBAM(64) # sharing
    
    self.primarycap = PrimaryCap()
    self.spatial_attn = SpatialGate()
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    x = inputs
    
    cap = self.conv1(x)
    cap = cap + self.cbam(cap)
    cap = self.conv2(cap)
    cap = cap + self.cbam(cap)
    
    primarycaps = self.primarycap(cap)
    primarycaps = tf.expand_dims(primarycaps, axis=-1)
    primarycaps = primarycaps + self.spatial_attn(primarycaps)
    primarycaps = tf.squeeze(primarycaps, axis=-1)
    
    cap = primarycaps
    cap = tf.expand_dims(cap, axis=-1)
    cap = cap + self.spatial_attn(cap)
    cap = tf.squeeze(cap, axis=-1)
    
    capsule = self.capsule(cap)
    capsule = tf.expand_dims(capsule, axis=-1)
    capsule = capsule + self.spatial_attn(capsule)
    capsule = tf.squeeze(capsule, axis=-1)
    
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1416
#
#  sequential_1 (Sequential)   (None, 46, 7, 64)         37300
#
#  cbam (CBAM)                 multiple                  4294
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  spatial_gate_1 (SpatialGate  multiple                 102
#  )
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  520
#
# =================================================================
# Total params: 93,808
# Trainable params: 93,230
# Non-trainable params: 578
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}.npy', 'rb') as f:
    x = np.load(f)
    y = np.load(f)

y = to_categorical(y,num_classes=len(CLASS_LABELS))

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, test) in tqdm(enumerate(kfold.split(x, y)), desc=f'Training {k}-Fold.....'):
    if i < 9: continue
    
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = x[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_test, y_test = x[test], y[test]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_test = tf.expand_dims(x_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_test_loss = 0x3f3f3f
    best_test_acc = -1
    best_test_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        test_loss, test_acc, f1s = [], [], []
        for features, labels in batch_test:
            loss, acc, pred = test_step(model, features, labels)
            test_loss.append(loss)
            test_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(test_loss)/len(test_loss)
        val_acc = sum(test_acc)/len(test_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_test_loss:.3f}, Best accuracy:{best_test_acc:.3f}, Best F1-score:{best_test_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_test_acc < val_acc:
            best_test_acc = val_acc
            best_test_loss = val_loss
            best_test_f1 = f1_score
            model.save_weights(h5_path)
            
            
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    
    for features, labels in batch_test:
        best_pred = model(features, training=False)
        emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(labels, axis=1))
        predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
    
    
    print(f'[*] Done - acc:{best_test_acc:.3f}')
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    fold_acc.append(best_test_acc)
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.628, acc:17.835, val_loss:0.607, val_acc:26.875
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.607, acc:24.771, val_loss:0.595, val_acc:23.750
# Best loss:0.607, Best accuracy:26.875, Best F1-score:0.201
# 3/300 lr=0.00100 - loss:0.600, acc:25.152, val_loss:0.587, val_acc:28.750
# Best loss:0.607, Best accuracy:26.875, Best F1-score:0.201
# 4/300 lr=0.00100 - loss:0.592, acc:28.735, val_loss:0.573, val_acc:34.375
# Best loss:0.587, Best accuracy:28.750, Best F1-score:0.224
# 5/300 lr=0.00100 - loss:0.584, acc:29.040, val_loss:0.562, val_acc:40.625
# Best loss:0.573, Best accuracy:34.375, Best F1-score:0.305
# 6/300 lr=0.00100 - loss:0.583, acc:29.192, val_loss:0.570, val_acc:35.625
# Best loss:0.562, Best accuracy:40.625, Best F1-score:0.323
# 7/300 lr=0.00100 - loss:0.575, acc:31.555, val_loss:0.550, val_acc:36.875
# Best loss:0.562, Best accuracy:40.625, Best F1-score:0.323
# 8/300 lr=0.00100 - loss:0.568, acc:32.012, val_loss:0.539, val_acc:39.375
# Best loss:0.562, Best accuracy:40.625, Best F1-score:0.323
# 9/300 lr=0.00100 - loss:0.558, acc:34.527, val_loss:0.519, val_acc:38.750
# Best loss:0.562, Best accuracy:40.625, Best F1-score:0.323
# 10/300 lr=0.00100 - loss:0.552, acc:34.375, val_loss:0.531, val_acc:38.750
# Best loss:0.562, Best accuracy:40.625, Best F1-score:0.323
# 11/300 lr=0.00100 - loss:0.543, acc:36.509, val_loss:0.505, val_acc:42.500
# Best loss:0.562, Best accuracy:40.625, Best F1-score:0.323
# 12/300 lr=0.00100 - loss:0.543, acc:36.357, val_loss:0.507, val_acc:40.000
# Best loss:0.505, Best accuracy:42.500, Best F1-score:0.365
# 13/300 lr=0.00100 - loss:0.535, acc:37.424, val_loss:0.484, val_acc:41.875
# Best loss:0.505, Best accuracy:42.500, Best F1-score:0.365
# 14/300 lr=0.00100 - loss:0.529, acc:38.796, val_loss:0.487, val_acc:42.500
# Best loss:0.505, Best accuracy:42.500, Best F1-score:0.365
# 15/300 lr=0.00100 - loss:0.519, acc:39.710, val_loss:0.478, val_acc:44.375
# Best loss:0.505, Best accuracy:42.500, Best F1-score:0.365
# 16/300 lr=0.00100 - loss:0.516, acc:41.006, val_loss:0.466, val_acc:46.250
# Best loss:0.478, Best accuracy:44.375, Best F1-score:0.396
# 17/300 lr=0.00100 - loss:0.502, acc:41.997, val_loss:0.458, val_acc:45.625
# Best loss:0.466, Best accuracy:46.250, Best F1-score:0.420
# 18/300 lr=0.00100 - loss:0.517, acc:40.854, val_loss:0.469, val_acc:43.125
# Best loss:0.466, Best accuracy:46.250, Best F1-score:0.420
# 19/300 lr=0.00100 - loss:0.518, acc:39.558, val_loss:0.497, val_acc:38.125
# Best loss:0.466, Best accuracy:46.250, Best F1-score:0.420
# 20/300 lr=0.00100 - loss:0.509, acc:42.226, val_loss:0.464, val_acc:42.500
# Best loss:0.466, Best accuracy:46.250, Best F1-score:0.420
# 21/300 lr=0.00100 - loss:0.497, acc:42.226, val_loss:0.452, val_acc:46.875
# Best loss:0.466, Best accuracy:46.250, Best F1-score:0.420
# 22/300 lr=0.00100 - loss:0.487, acc:44.436, val_loss:0.443, val_acc:51.250
# Best loss:0.452, Best accuracy:46.875, Best F1-score:0.415
# 23/300 lr=0.00100 - loss:0.491, acc:44.588, val_loss:0.469, val_acc:41.875
# Best loss:0.443, Best accuracy:51.250, Best F1-score:0.480
# 24/300 lr=0.00100 - loss:0.483, acc:45.274, val_loss:0.437, val_acc:48.125
# Best loss:0.443, Best accuracy:51.250, Best F1-score:0.480
# 25/300 lr=0.00100 - loss:0.480, acc:46.265, val_loss:0.452, val_acc:44.375
# Best loss:0.443, Best accuracy:51.250, Best F1-score:0.480
# 26/300 lr=0.00100 - loss:0.479, acc:44.817, val_loss:0.429, val_acc:49.375
# Best loss:0.443, Best accuracy:51.250, Best F1-score:0.480
# 27/300 lr=0.00100 - loss:0.469, acc:47.409, val_loss:0.413, val_acc:53.750
# Best loss:0.443, Best accuracy:51.250, Best F1-score:0.480
# 28/300 lr=0.00100 - loss:0.463, acc:47.561, val_loss:0.422, val_acc:50.625
# Best loss:0.413, Best accuracy:53.750, Best F1-score:0.512
# 29/300 lr=0.00100 - loss:0.465, acc:49.543, val_loss:0.429, val_acc:51.250
# Best loss:0.413, Best accuracy:53.750, Best F1-score:0.512
# 30/300 lr=0.00100 - loss:0.466, acc:48.247, val_loss:0.417, val_acc:51.250
# Best loss:0.413, Best accuracy:53.750, Best F1-score:0.512
# 31/300 lr=0.00100 - loss:0.441, acc:50.762, val_loss:0.389, val_acc:56.875
# Best loss:0.413, Best accuracy:53.750, Best F1-score:0.512
# 32/300 lr=0.00100 - loss:0.441, acc:52.134, val_loss:0.390, val_acc:54.375
# Best loss:0.389, Best accuracy:56.875, Best F1-score:0.555
# 33/300 lr=0.00100 - loss:0.434, acc:53.354, val_loss:0.378, val_acc:56.250
# Best loss:0.389, Best accuracy:56.875, Best F1-score:0.555
# 34/300 lr=0.00100 - loss:0.429, acc:53.354, val_loss:0.392, val_acc:51.875
# Best loss:0.389, Best accuracy:56.875, Best F1-score:0.555
# 35/300 lr=0.00100 - loss:0.431, acc:54.040, val_loss:0.392, val_acc:54.375
# Best loss:0.389, Best accuracy:56.875, Best F1-score:0.555
# 36/300 lr=0.00100 - loss:0.422, acc:54.040, val_loss:0.401, val_acc:52.500
# Best loss:0.389, Best accuracy:56.875, Best F1-score:0.555
# 37/300 lr=0.00100 - loss:0.427, acc:53.811, val_loss:0.383, val_acc:56.875
# Best loss:0.389, Best accuracy:56.875, Best F1-score:0.555
# 38/300 lr=0.00100 - loss:0.427, acc:53.811, val_loss:0.383, val_acc:55.625
# Best loss:0.389, Best accuracy:56.875, Best F1-score:0.555
# 39/300 lr=0.00100 - loss:0.428, acc:54.421, val_loss:0.403, val_acc:49.375
# Best loss:0.389, Best accuracy:56.875, Best F1-score:0.555
# 40/300 lr=0.00100 - loss:0.417, acc:55.945, val_loss:0.373, val_acc:59.375
# Best loss:0.389, Best accuracy:56.875, Best F1-score:0.555
# 41/300 lr=0.00100 - loss:0.419, acc:55.412, val_loss:0.362, val_acc:58.750
# Best loss:0.373, Best accuracy:59.375, Best F1-score:0.575
# 42/300 lr=0.00100 - loss:0.395, acc:59.451, val_loss:0.362, val_acc:56.250
# Best loss:0.373, Best accuracy:59.375, Best F1-score:0.575
# 43/300 lr=0.00100 - loss:0.405, acc:57.165, val_loss:0.393, val_acc:50.625
# Best loss:0.373, Best accuracy:59.375, Best F1-score:0.575
# 44/300 lr=0.00100 - loss:0.398, acc:57.698, val_loss:0.372, val_acc:56.250
# Best loss:0.373, Best accuracy:59.375, Best F1-score:0.575
# 45/300 lr=0.00100 - loss:0.411, acc:55.640, val_loss:0.383, val_acc:56.250
# Best loss:0.373, Best accuracy:59.375, Best F1-score:0.575
# 46/300 lr=0.00100 - loss:0.404, acc:56.936, val_loss:0.344, val_acc:60.000
# Best loss:0.373, Best accuracy:59.375, Best F1-score:0.575
# 47/300 lr=0.00100 - loss:0.398, acc:58.460, val_loss:0.332, val_acc:62.500
# Best loss:0.344, Best accuracy:60.000, Best F1-score:0.579
# 48/300 lr=0.00100 - loss:0.403, acc:57.851, val_loss:0.397, val_acc:58.125
# Best loss:0.332, Best accuracy:62.500, Best F1-score:0.610
# 49/300 lr=0.00100 - loss:0.400, acc:57.774, val_loss:0.361, val_acc:59.375
# Best loss:0.332, Best accuracy:62.500, Best F1-score:0.610
# 50/300 lr=0.00100 - loss:0.397, acc:57.774, val_loss:0.392, val_acc:51.875
# Best loss:0.332, Best accuracy:62.500, Best F1-score:0.610
# 51/300 lr=0.00100 - loss:0.389, acc:60.137, val_loss:0.331, val_acc:63.125
# Best loss:0.332, Best accuracy:62.500, Best F1-score:0.610
# 52/300 lr=0.00100 - loss:0.381, acc:61.128, val_loss:0.389, val_acc:56.250
# Best loss:0.331, Best accuracy:63.125, Best F1-score:0.601
# 53/300 lr=0.00100 - loss:0.380, acc:61.128, val_loss:0.343, val_acc:58.125
# Best loss:0.331, Best accuracy:63.125, Best F1-score:0.601
# 54/300 lr=0.00100 - loss:0.377, acc:61.738, val_loss:0.362, val_acc:56.250
# Best loss:0.331, Best accuracy:63.125, Best F1-score:0.601
# 55/300 lr=0.00100 - loss:0.380, acc:59.756, val_loss:0.340, val_acc:59.375
# Best loss:0.331, Best accuracy:63.125, Best F1-score:0.601
# 56/300 lr=0.00100 - loss:0.372, acc:62.348, val_loss:0.344, val_acc:60.625
# Best loss:0.331, Best accuracy:63.125, Best F1-score:0.601
# 57/300 lr=0.00100 - loss:0.368, acc:63.110, val_loss:0.331, val_acc:61.875
# Best loss:0.331, Best accuracy:63.125, Best F1-score:0.601
# 58/300 lr=0.00100 - loss:0.358, acc:62.957, val_loss:0.325, val_acc:63.125
# Best loss:0.331, Best accuracy:63.125, Best F1-score:0.601
# 59/300 lr=0.00100 - loss:0.368, acc:62.576, val_loss:0.364, val_acc:58.750
# Best loss:0.331, Best accuracy:63.125, Best F1-score:0.601
# 60/300 lr=0.00100 - loss:0.354, acc:65.244, val_loss:0.352, val_acc:60.000
# Best loss:0.331, Best accuracy:63.125, Best F1-score:0.601
# 61/300 lr=0.00100 - loss:0.353, acc:65.015, val_loss:0.331, val_acc:61.250
# Best loss:0.331, Best accuracy:63.125, Best F1-score:0.601
# 62/300 lr=0.00086 - loss:0.352, acc:65.244, val_loss:0.324, val_acc:61.250
# Best loss:0.331, Best accuracy:63.125, Best F1-score:0.601
# 63/300 lr=0.00086 - loss:0.349, acc:65.091, val_loss:0.301, val_acc:66.875
# Best loss:0.331, Best accuracy:63.125, Best F1-score:0.601
# 64/300 lr=0.00086 - loss:0.347, acc:65.930, val_loss:0.311, val_acc:64.375
# Best loss:0.301, Best accuracy:66.875, Best F1-score:0.653
# 65/300 lr=0.00086 - loss:0.335, acc:65.854, val_loss:0.304, val_acc:66.875
# Best loss:0.301, Best accuracy:66.875, Best F1-score:0.653
# 66/300 lr=0.00086 - loss:0.345, acc:66.463, val_loss:0.333, val_acc:58.750
# Best loss:0.301, Best accuracy:66.875, Best F1-score:0.653
# 67/300 lr=0.00086 - loss:0.350, acc:65.015, val_loss:0.327, val_acc:66.250
# Best loss:0.301, Best accuracy:66.875, Best F1-score:0.653
# 68/300 lr=0.00086 - loss:0.336, acc:67.988, val_loss:0.317, val_acc:63.125
# Best loss:0.301, Best accuracy:66.875, Best F1-score:0.653
# 69/300 lr=0.00086 - loss:0.329, acc:67.683, val_loss:0.325, val_acc:67.500
# Best loss:0.301, Best accuracy:66.875, Best F1-score:0.653
# 70/300 lr=0.00086 - loss:0.326, acc:67.683, val_loss:0.329, val_acc:61.250
# Best loss:0.325, Best accuracy:67.500, Best F1-score:0.633
# 71/300 lr=0.00086 - loss:0.321, acc:70.427, val_loss:0.293, val_acc:68.750
# Best loss:0.325, Best accuracy:67.500, Best F1-score:0.633
# 72/300 lr=0.00086 - loss:0.343, acc:65.549, val_loss:0.297, val_acc:65.000
# Best loss:0.293, Best accuracy:68.750, Best F1-score:0.677
# 73/300 lr=0.00086 - loss:0.337, acc:67.226, val_loss:0.317, val_acc:63.750
# Best loss:0.293, Best accuracy:68.750, Best F1-score:0.677
# 74/300 lr=0.00086 - loss:0.322, acc:69.741, val_loss:0.301, val_acc:65.000
# Best loss:0.293, Best accuracy:68.750, Best F1-score:0.677
# 75/300 lr=0.00086 - loss:0.320, acc:69.817, val_loss:0.319, val_acc:63.750
# Best loss:0.293, Best accuracy:68.750, Best F1-score:0.677
# 76/300 lr=0.00086 - loss:0.316, acc:69.207, val_loss:0.337, val_acc:63.750
# Best loss:0.293, Best accuracy:68.750, Best F1-score:0.677
# 77/300 lr=0.00086 - loss:0.312, acc:70.732, val_loss:0.320, val_acc:64.375
# Best loss:0.293, Best accuracy:68.750, Best F1-score:0.677
# 78/300 lr=0.00086 - loss:0.324, acc:67.912, val_loss:0.271, val_acc:69.375
# Best loss:0.293, Best accuracy:68.750, Best F1-score:0.677
# 79/300 lr=0.00086 - loss:0.310, acc:70.503, val_loss:0.284, val_acc:66.250
# Best loss:0.271, Best accuracy:69.375, Best F1-score:0.690
# 80/300 lr=0.00086 - loss:0.312, acc:71.570, val_loss:0.315, val_acc:63.750
# Best loss:0.271, Best accuracy:69.375, Best F1-score:0.690
# 81/300 lr=0.00086 - loss:0.310, acc:71.418, val_loss:0.304, val_acc:66.875
# Best loss:0.271, Best accuracy:69.375, Best F1-score:0.690
# 82/300 lr=0.00074 - loss:0.300, acc:72.332, val_loss:0.291, val_acc:66.875
# Best loss:0.271, Best accuracy:69.375, Best F1-score:0.690
# 83/300 lr=0.00074 - loss:0.293, acc:74.238, val_loss:0.274, val_acc:68.750
# Best loss:0.271, Best accuracy:69.375, Best F1-score:0.690
# 84/300 lr=0.00074 - loss:0.282, acc:75.915, val_loss:0.329, val_acc:61.875
# Best loss:0.271, Best accuracy:69.375, Best F1-score:0.690
# 85/300 lr=0.00074 - loss:0.294, acc:73.857, val_loss:0.313, val_acc:61.250
# Best loss:0.271, Best accuracy:69.375, Best F1-score:0.690
# 86/300 lr=0.00074 - loss:0.289, acc:75.076, val_loss:0.286, val_acc:66.250
# Best loss:0.271, Best accuracy:69.375, Best F1-score:0.690
# 87/300 lr=0.00074 - loss:0.286, acc:73.857, val_loss:0.267, val_acc:67.500
# Best loss:0.271, Best accuracy:69.375, Best F1-score:0.690
# 88/300 lr=0.00074 - loss:0.264, acc:77.896, val_loss:0.283, val_acc:70.625
# Best loss:0.271, Best accuracy:69.375, Best F1-score:0.690
# 89/300 lr=0.00074 - loss:0.266, acc:77.287, val_loss:0.281, val_acc:69.375
# Best loss:0.283, Best accuracy:70.625, Best F1-score:0.680
# 90/300 lr=0.00074 - loss:0.264, acc:78.582, val_loss:0.274, val_acc:69.375
# Best loss:0.283, Best accuracy:70.625, Best F1-score:0.680
# 91/300 lr=0.00074 - loss:0.268, acc:77.058, val_loss:0.248, val_acc:72.500
# Best loss:0.283, Best accuracy:70.625, Best F1-score:0.680
# 92/300 lr=0.00074 - loss:0.269, acc:76.905, val_loss:0.278, val_acc:70.625
# Best loss:0.248, Best accuracy:72.500, Best F1-score:0.714
# 93/300 lr=0.00074 - loss:0.261, acc:77.210, val_loss:0.253, val_acc:71.250
# Best loss:0.248, Best accuracy:72.500, Best F1-score:0.714
# 94/300 lr=0.00074 - loss:0.254, acc:79.116, val_loss:0.283, val_acc:69.375
# Best loss:0.248, Best accuracy:72.500, Best F1-score:0.714
# 95/300 lr=0.00074 - loss:0.259, acc:78.354, val_loss:0.268, val_acc:70.000
# Best loss:0.248, Best accuracy:72.500, Best F1-score:0.714
# 96/300 lr=0.00074 - loss:0.260, acc:78.201, val_loss:0.278, val_acc:68.125
# Best loss:0.248, Best accuracy:72.500, Best F1-score:0.714
# 97/300 lr=0.00074 - loss:0.249, acc:80.564, val_loss:0.247, val_acc:75.625
# Best loss:0.248, Best accuracy:72.500, Best F1-score:0.714
# 98/300 lr=0.00074 - loss:0.254, acc:78.887, val_loss:0.264, val_acc:71.875
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 99/300 lr=0.00074 - loss:0.252, acc:78.887, val_loss:0.244, val_acc:71.250
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 100/300 lr=0.00074 - loss:0.258, acc:79.268, val_loss:0.260, val_acc:69.375
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 101/300 lr=0.00074 - loss:0.249, acc:79.649, val_loss:0.282, val_acc:71.875
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 102/300 lr=0.00064 - loss:0.246, acc:80.412, val_loss:0.290, val_acc:67.500
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 103/300 lr=0.00064 - loss:0.253, acc:78.582, val_loss:0.240, val_acc:73.125
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 104/300 lr=0.00064 - loss:0.263, acc:77.210, val_loss:0.242, val_acc:73.125
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 105/300 lr=0.00064 - loss:0.242, acc:80.564, val_loss:0.245, val_acc:73.750
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 106/300 lr=0.00064 - loss:0.234, acc:82.622, val_loss:0.267, val_acc:73.125
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 107/300 lr=0.00064 - loss:0.235, acc:81.631, val_loss:0.244, val_acc:72.500
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 108/300 lr=0.00064 - loss:0.242, acc:80.335, val_loss:0.238, val_acc:73.125
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 109/300 lr=0.00064 - loss:0.233, acc:82.393, val_loss:0.248, val_acc:75.625
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 110/300 lr=0.00064 - loss:0.227, acc:82.851, val_loss:0.255, val_acc:72.500
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 111/300 lr=0.00064 - loss:0.231, acc:83.155, val_loss:0.271, val_acc:71.250
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 112/300 lr=0.00064 - loss:0.227, acc:83.308, val_loss:0.283, val_acc:67.500
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 113/300 lr=0.00064 - loss:0.224, acc:83.689, val_loss:0.247, val_acc:71.875
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 114/300 lr=0.00064 - loss:0.218, acc:84.680, val_loss:0.230, val_acc:70.000
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 115/300 lr=0.00064 - loss:0.214, acc:84.604, val_loss:0.237, val_acc:74.375
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 116/300 lr=0.00064 - loss:0.219, acc:84.375, val_loss:0.246, val_acc:71.875
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 117/300 lr=0.00064 - loss:0.217, acc:84.299, val_loss:0.244, val_acc:74.375
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 118/300 lr=0.00064 - loss:0.207, acc:86.280, val_loss:0.234, val_acc:76.250
# Best loss:0.247, Best accuracy:75.625, Best F1-score:0.738
# 119/300 lr=0.00064 - loss:0.207, acc:86.509, val_loss:0.236, val_acc:73.750
# Best loss:0.234, Best accuracy:76.250, Best F1-score:0.744
# 120/300 lr=0.00064 - loss:0.214, acc:83.765, val_loss:0.233, val_acc:72.500
# Best loss:0.234, Best accuracy:76.250, Best F1-score:0.744
# 121/300 lr=0.00064 - loss:0.212, acc:84.375, val_loss:0.219, val_acc:77.500
# Best loss:0.234, Best accuracy:76.250, Best F1-score:0.744
# 122/300 lr=0.00055 - loss:0.209, acc:85.747, val_loss:0.262, val_acc:71.250
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 123/300 lr=0.00055 - loss:0.206, acc:86.509, val_loss:0.229, val_acc:74.375
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 124/300 lr=0.00055 - loss:0.203, acc:86.357, val_loss:0.236, val_acc:73.125
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 125/300 lr=0.00055 - loss:0.213, acc:84.909, val_loss:0.254, val_acc:70.000
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 126/300 lr=0.00055 - loss:0.211, acc:85.823, val_loss:0.275, val_acc:69.375
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 127/300 lr=0.00055 - loss:0.225, acc:83.003, val_loss:0.262, val_acc:68.125
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 128/300 lr=0.00055 - loss:0.204, acc:87.195, val_loss:0.252, val_acc:70.000
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 129/300 lr=0.00055 - loss:0.209, acc:85.671, val_loss:0.267, val_acc:71.875
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 130/300 lr=0.00055 - loss:0.211, acc:84.756, val_loss:0.237, val_acc:73.125
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 131/300 lr=0.00055 - loss:0.202, acc:86.280, val_loss:0.226, val_acc:73.125
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 132/300 lr=0.00055 - loss:0.207, acc:85.518, val_loss:0.242, val_acc:75.000
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 133/300 lr=0.00055 - loss:0.222, acc:82.927, val_loss:0.245, val_acc:73.125
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 134/300 lr=0.00055 - loss:0.215, acc:84.299, val_loss:0.255, val_acc:71.875
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 135/300 lr=0.00055 - loss:0.203, acc:86.280, val_loss:0.282, val_acc:70.625
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 136/300 lr=0.00055 - loss:0.202, acc:86.357, val_loss:0.260, val_acc:71.875
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 137/300 lr=0.00055 - loss:0.200, acc:87.195, val_loss:0.254, val_acc:71.250
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 138/300 lr=0.00055 - loss:0.200, acc:86.280, val_loss:0.236, val_acc:74.375
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 139/300 lr=0.00055 - loss:0.192, acc:88.491, val_loss:0.232, val_acc:73.125
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 140/300 lr=0.00055 - loss:0.196, acc:86.357, val_loss:0.213, val_acc:74.375
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 141/300 lr=0.00055 - loss:0.188, acc:88.796, val_loss:0.205, val_acc:78.750
# Best loss:0.219, Best accuracy:77.500, Best F1-score:0.775
# 142/300 lr=0.00047 - loss:0.187, acc:88.567, val_loss:0.204, val_acc:79.375
# Best loss:0.205, Best accuracy:78.750, Best F1-score:0.772
# 143/300 lr=0.00047 - loss:0.175, acc:90.777, val_loss:0.207, val_acc:76.875
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 144/300 lr=0.00047 - loss:0.188, acc:87.957, val_loss:0.230, val_acc:76.875
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 145/300 lr=0.00047 - loss:0.177, acc:90.625, val_loss:0.201, val_acc:78.750
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 146/300 lr=0.00047 - loss:0.183, acc:89.024, val_loss:0.223, val_acc:76.250
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 147/300 lr=0.00047 - loss:0.188, acc:88.720, val_loss:0.219, val_acc:76.875
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 148/300 lr=0.00047 - loss:0.185, acc:89.101, val_loss:0.231, val_acc:77.500
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 149/300 lr=0.00047 - loss:0.180, acc:90.320, val_loss:0.224, val_acc:75.000
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 150/300 lr=0.00047 - loss:0.190, acc:88.415, val_loss:0.229, val_acc:75.625
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 151/300 lr=0.00047 - loss:0.176, acc:90.320, val_loss:0.240, val_acc:72.500
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 152/300 lr=0.00047 - loss:0.175, acc:90.244, val_loss:0.230, val_acc:73.125
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 153/300 lr=0.00047 - loss:0.178, acc:89.939, val_loss:0.210, val_acc:78.750
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 154/300 lr=0.00047 - loss:0.180, acc:89.405, val_loss:0.215, val_acc:75.625
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 155/300 lr=0.00047 - loss:0.170, acc:91.463, val_loss:0.203, val_acc:74.375
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 156/300 lr=0.00047 - loss:0.177, acc:89.710, val_loss:0.205, val_acc:78.125
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 157/300 lr=0.00047 - loss:0.182, acc:89.101, val_loss:0.212, val_acc:76.875
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 158/300 lr=0.00047 - loss:0.182, acc:89.101, val_loss:0.240, val_acc:73.125
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 159/300 lr=0.00047 - loss:0.192, acc:88.034, val_loss:0.227, val_acc:75.625
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 160/300 lr=0.00047 - loss:0.177, acc:90.244, val_loss:0.201, val_acc:78.750
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 161/300 lr=0.00047 - loss:0.169, acc:92.073, val_loss:0.204, val_acc:76.250
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 162/300 lr=0.00041 - loss:0.172, acc:90.930, val_loss:0.211, val_acc:77.500
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 163/300 lr=0.00041 - loss:0.171, acc:91.159, val_loss:0.188, val_acc:78.750
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 164/300 lr=0.00041 - loss:0.177, acc:89.787, val_loss:0.205, val_acc:77.500
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 165/300 lr=0.00041 - loss:0.177, acc:89.787, val_loss:0.238, val_acc:76.250
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 166/300 lr=0.00041 - loss:0.167, acc:91.616, val_loss:0.236, val_acc:75.625
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 167/300 lr=0.00041 - loss:0.168, acc:91.311, val_loss:0.237, val_acc:73.125
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 168/300 lr=0.00041 - loss:0.170, acc:91.159, val_loss:0.216, val_acc:76.250
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 169/300 lr=0.00041 - loss:0.162, acc:92.302, val_loss:0.213, val_acc:77.500
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 170/300 lr=0.00041 - loss:0.162, acc:92.226, val_loss:0.236, val_acc:71.875
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 171/300 lr=0.00041 - loss:0.167, acc:91.921, val_loss:0.215, val_acc:75.625
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 172/300 lr=0.00041 - loss:0.165, acc:91.387, val_loss:0.215, val_acc:75.625
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 173/300 lr=0.00041 - loss:0.161, acc:92.302, val_loss:0.210, val_acc:76.875
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 174/300 lr=0.00041 - loss:0.159, acc:93.064, val_loss:0.233, val_acc:73.125
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 175/300 lr=0.00041 - loss:0.163, acc:91.387, val_loss:0.233, val_acc:71.875
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 176/300 lr=0.00041 - loss:0.160, acc:91.997, val_loss:0.199, val_acc:78.750
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 177/300 lr=0.00041 - loss:0.159, acc:92.073, val_loss:0.210, val_acc:76.875
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 178/300 lr=0.00041 - loss:0.167, acc:90.930, val_loss:0.216, val_acc:75.625
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 179/300 lr=0.00041 - loss:0.161, acc:92.073, val_loss:0.235, val_acc:73.125
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 180/300 lr=0.00041 - loss:0.161, acc:92.226, val_loss:0.188, val_acc:78.125
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 181/300 lr=0.00041 - loss:0.159, acc:92.454, val_loss:0.225, val_acc:76.250
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 182/300 lr=0.00035 - loss:0.154, acc:92.912, val_loss:0.205, val_acc:78.125
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 183/300 lr=0.00035 - loss:0.156, acc:93.369, val_loss:0.215, val_acc:76.875
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 184/300 lr=0.00035 - loss:0.154, acc:93.598, val_loss:0.200, val_acc:78.125
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 185/300 lr=0.00035 - loss:0.153, acc:93.064, val_loss:0.206, val_acc:76.875
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 186/300 lr=0.00035 - loss:0.160, acc:92.073, val_loss:0.213, val_acc:78.750
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 187/300 lr=0.00035 - loss:0.166, acc:90.930, val_loss:0.202, val_acc:77.500
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 188/300 lr=0.00035 - loss:0.158, acc:92.530, val_loss:0.214, val_acc:75.000
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 189/300 lr=0.00035 - loss:0.163, acc:91.845, val_loss:0.191, val_acc:79.375
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 190/300 lr=0.00035 - loss:0.154, acc:93.064, val_loss:0.203, val_acc:78.125
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 191/300 lr=0.00035 - loss:0.152, acc:93.674, val_loss:0.203, val_acc:77.500
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 192/300 lr=0.00035 - loss:0.146, acc:94.284, val_loss:0.196, val_acc:79.375
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 193/300 lr=0.00035 - loss:0.141, acc:95.122, val_loss:0.204, val_acc:78.750
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 194/300 lr=0.00035 - loss:0.144, acc:94.360, val_loss:0.220, val_acc:76.250
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 195/300 lr=0.00035 - loss:0.146, acc:94.436, val_loss:0.213, val_acc:76.250
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 196/300 lr=0.00035 - loss:0.148, acc:93.750, val_loss:0.186, val_acc:77.500
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 197/300 lr=0.00035 - loss:0.152, acc:93.369, val_loss:0.210, val_acc:78.125
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 198/300 lr=0.00035 - loss:0.150, acc:94.207, val_loss:0.213, val_acc:76.875
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 199/300 lr=0.00035 - loss:0.151, acc:93.979, val_loss:0.211, val_acc:77.500
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 200/300 lr=0.00035 - loss:0.148, acc:94.360, val_loss:0.202, val_acc:78.125
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 201/300 lr=0.00035 - loss:0.151, acc:93.979, val_loss:0.206, val_acc:76.250
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 202/300 lr=0.00030 - loss:0.146, acc:94.360, val_loss:0.204, val_acc:78.750
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 203/300 lr=0.00030 - loss:0.142, acc:95.122, val_loss:0.215, val_acc:76.875
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 204/300 lr=0.00030 - loss:0.143, acc:94.741, val_loss:0.220, val_acc:74.375
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 205/300 lr=0.00030 - loss:0.142, acc:94.817, val_loss:0.203, val_acc:79.375
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 206/300 lr=0.00030 - loss:0.140, acc:95.122, val_loss:0.186, val_acc:78.750
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 207/300 lr=0.00030 - loss:0.151, acc:93.674, val_loss:0.214, val_acc:76.250
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 208/300 lr=0.00030 - loss:0.145, acc:94.588, val_loss:0.217, val_acc:75.625
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 209/300 lr=0.00030 - loss:0.148, acc:93.902, val_loss:0.188, val_acc:78.750
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 210/300 lr=0.00030 - loss:0.150, acc:93.369, val_loss:0.188, val_acc:78.125
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 211/300 lr=0.00030 - loss:0.148, acc:94.055, val_loss:0.189, val_acc:78.750
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 212/300 lr=0.00030 - loss:0.143, acc:95.274, val_loss:0.195, val_acc:78.125
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 213/300 lr=0.00030 - loss:0.144, acc:94.360, val_loss:0.199, val_acc:80.625
# Best loss:0.204, Best accuracy:79.375, Best F1-score:0.792
# 214/300 lr=0.00030 - loss:0.141, acc:94.665, val_loss:0.222, val_acc:75.625
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 215/300 lr=0.00030 - loss:0.140, acc:95.122, val_loss:0.213, val_acc:79.375
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 216/300 lr=0.00030 - loss:0.142, acc:94.436, val_loss:0.200, val_acc:78.125
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 217/300 lr=0.00030 - loss:0.139, acc:95.503, val_loss:0.189, val_acc:80.000
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 218/300 lr=0.00030 - loss:0.136, acc:96.037, val_loss:0.188, val_acc:78.125
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 219/300 lr=0.00030 - loss:0.139, acc:94.970, val_loss:0.199, val_acc:78.125
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 220/300 lr=0.00030 - loss:0.140, acc:95.198, val_loss:0.206, val_acc:78.125
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 221/300 lr=0.00030 - loss:0.143, acc:94.512, val_loss:0.224, val_acc:73.750
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 222/300 lr=0.00026 - loss:0.141, acc:94.817, val_loss:0.188, val_acc:78.750
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 223/300 lr=0.00026 - loss:0.136, acc:96.341, val_loss:0.201, val_acc:79.375
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 224/300 lr=0.00026 - loss:0.137, acc:95.808, val_loss:0.205, val_acc:75.000
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 225/300 lr=0.00026 - loss:0.138, acc:95.122, val_loss:0.203, val_acc:78.125
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 226/300 lr=0.00026 - loss:0.137, acc:95.503, val_loss:0.194, val_acc:80.000
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 227/300 lr=0.00026 - loss:0.138, acc:94.970, val_loss:0.204, val_acc:78.750
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 228/300 lr=0.00026 - loss:0.143, acc:94.970, val_loss:0.185, val_acc:80.000
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 229/300 lr=0.00026 - loss:0.139, acc:95.046, val_loss:0.190, val_acc:78.125
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 230/300 lr=0.00026 - loss:0.137, acc:95.960, val_loss:0.204, val_acc:75.625
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 231/300 lr=0.00026 - loss:0.136, acc:95.274, val_loss:0.190, val_acc:78.750
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 232/300 lr=0.00026 - loss:0.135, acc:95.351, val_loss:0.176, val_acc:80.000
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 233/300 lr=0.00026 - loss:0.131, acc:96.570, val_loss:0.189, val_acc:78.750
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 234/300 lr=0.00026 - loss:0.134, acc:96.341, val_loss:0.185, val_acc:78.125
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 235/300 lr=0.00026 - loss:0.132, acc:96.113, val_loss:0.190, val_acc:78.750
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 236/300 lr=0.00026 - loss:0.138, acc:95.808, val_loss:0.187, val_acc:77.500
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 237/300 lr=0.00026 - loss:0.135, acc:96.341, val_loss:0.181, val_acc:81.250
# Best loss:0.199, Best accuracy:80.625, Best F1-score:0.786
# 238/300 lr=0.00026 - loss:0.134, acc:96.037, val_loss:0.185, val_acc:80.625
# Best loss:0.181, Best accuracy:81.250, Best F1-score:0.803
# 239/300 lr=0.00026 - loss:0.133, acc:95.884, val_loss:0.204, val_acc:76.875
# Best loss:0.181, Best accuracy:81.250, Best F1-score:0.803
# 240/300 lr=0.00026 - loss:0.135, acc:95.808, val_loss:0.179, val_acc:79.375
# Best loss:0.181, Best accuracy:81.250, Best F1-score:0.803
# 241/300 lr=0.00026 - loss:0.137, acc:95.732, val_loss:0.217, val_acc:77.500
# Best loss:0.181, Best accuracy:81.250, Best F1-score:0.803
# 242/300 lr=0.00022 - loss:0.136, acc:95.274, val_loss:0.185, val_acc:81.875
# Best loss:0.181, Best accuracy:81.250, Best F1-score:0.803
# 243/300 lr=0.00022 - loss:0.131, acc:96.418, val_loss:0.178, val_acc:80.000
# Best loss:0.185, Best accuracy:81.875, Best F1-score:0.815
# 244/300 lr=0.00022 - loss:0.128, acc:96.494, val_loss:0.200, val_acc:76.875
# Best loss:0.185, Best accuracy:81.875, Best F1-score:0.815
# 245/300 lr=0.00022 - loss:0.127, acc:96.723, val_loss:0.172, val_acc:79.375
# Best loss:0.185, Best accuracy:81.875, Best F1-score:0.815
# 246/300 lr=0.00022 - loss:0.125, acc:97.027, val_loss:0.181, val_acc:80.000
# Best loss:0.185, Best accuracy:81.875, Best F1-score:0.815
# 247/300 lr=0.00022 - loss:0.129, acc:96.723, val_loss:0.211, val_acc:76.875
# Best loss:0.185, Best accuracy:81.875, Best F1-score:0.815
# 248/300 lr=0.00022 - loss:0.130, acc:96.646, val_loss:0.216, val_acc:77.500
# Best loss:0.185, Best accuracy:81.875, Best F1-score:0.815
# 249/300 lr=0.00022 - loss:0.129, acc:96.723, val_loss:0.175, val_acc:81.250
# Best loss:0.185, Best accuracy:81.875, Best F1-score:0.815
# 250/300 lr=0.00022 - loss:0.130, acc:95.732, val_loss:0.193, val_acc:80.625
# Best loss:0.185, Best accuracy:81.875, Best F1-score:0.815
# 251/300 lr=0.00022 - loss:0.127, acc:96.799, val_loss:0.169, val_acc:82.500
# Best loss:0.185, Best accuracy:81.875, Best F1-score:0.815
# 252/300 lr=0.00022 - loss:0.133, acc:95.579, val_loss:0.171, val_acc:81.250
# Best loss:0.169, Best accuracy:82.500, Best F1-score:0.817
# 253/300 lr=0.00022 - loss:0.128, acc:96.951, val_loss:0.199, val_acc:78.125
# Best loss:0.169, Best accuracy:82.500, Best F1-score:0.817
# 254/300 lr=0.00022 - loss:0.126, acc:97.104, val_loss:0.193, val_acc:79.375
# Best loss:0.169, Best accuracy:82.500, Best F1-score:0.817
# 255/300 lr=0.00022 - loss:0.129, acc:96.723, val_loss:0.152, val_acc:85.000
# Best loss:0.169, Best accuracy:82.500, Best F1-score:0.817
# 256/300 lr=0.00022 - loss:0.128, acc:96.723, val_loss:0.205, val_acc:74.375
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 257/300 lr=0.00022 - loss:0.132, acc:96.189, val_loss:0.180, val_acc:81.250
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 258/300 lr=0.00022 - loss:0.131, acc:96.418, val_loss:0.165, val_acc:82.500
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 259/300 lr=0.00022 - loss:0.129, acc:96.723, val_loss:0.172, val_acc:81.875
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 260/300 lr=0.00022 - loss:0.128, acc:97.027, val_loss:0.181, val_acc:80.000
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 261/300 lr=0.00022 - loss:0.128, acc:97.104, val_loss:0.203, val_acc:78.125
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 262/300 lr=0.00019 - loss:0.132, acc:95.884, val_loss:0.166, val_acc:84.375
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 263/300 lr=0.00019 - loss:0.129, acc:96.799, val_loss:0.182, val_acc:81.875
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 264/300 lr=0.00019 - loss:0.127, acc:96.723, val_loss:0.173, val_acc:81.875
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 265/300 lr=0.00019 - loss:0.121, acc:97.332, val_loss:0.174, val_acc:80.625
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 266/300 lr=0.00019 - loss:0.124, acc:97.256, val_loss:0.185, val_acc:78.750
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 267/300 lr=0.00019 - loss:0.125, acc:96.723, val_loss:0.184, val_acc:80.000
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 268/300 lr=0.00019 - loss:0.123, acc:97.561, val_loss:0.181, val_acc:81.250
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 269/300 lr=0.00019 - loss:0.123, acc:97.104, val_loss:0.172, val_acc:81.250
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 270/300 lr=0.00019 - loss:0.126, acc:96.799, val_loss:0.198, val_acc:78.750
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 271/300 lr=0.00019 - loss:0.126, acc:96.875, val_loss:0.173, val_acc:81.250
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 272/300 lr=0.00019 - loss:0.123, acc:97.256, val_loss:0.185, val_acc:78.750
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 273/300 lr=0.00019 - loss:0.124, acc:97.409, val_loss:0.197, val_acc:79.375
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 274/300 lr=0.00019 - loss:0.129, acc:96.189, val_loss:0.173, val_acc:80.625
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 275/300 lr=0.00019 - loss:0.131, acc:96.037, val_loss:0.180, val_acc:81.875
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 276/300 lr=0.00019 - loss:0.125, acc:96.951, val_loss:0.186, val_acc:80.000
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 277/300 lr=0.00019 - loss:0.125, acc:97.104, val_loss:0.178, val_acc:80.625
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 278/300 lr=0.00019 - loss:0.122, acc:97.256, val_loss:0.170, val_acc:83.125
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 279/300 lr=0.00019 - loss:0.124, acc:97.256, val_loss:0.203, val_acc:75.625
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 280/300 lr=0.00019 - loss:0.124, acc:97.256, val_loss:0.178, val_acc:83.125
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 281/300 lr=0.00019 - loss:0.124, acc:97.256, val_loss:0.183, val_acc:77.500
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 282/300 lr=0.00017 - loss:0.123, acc:97.942, val_loss:0.183, val_acc:81.250
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 283/300 lr=0.00017 - loss:0.125, acc:97.409, val_loss:0.179, val_acc:80.625
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 284/300 lr=0.00017 - loss:0.128, acc:96.418, val_loss:0.160, val_acc:83.125
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 285/300 lr=0.00017 - loss:0.120, acc:97.942, val_loss:0.172, val_acc:81.250
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 286/300 lr=0.00017 - loss:0.120, acc:97.561, val_loss:0.196, val_acc:76.875
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 287/300 lr=0.00017 - loss:0.119, acc:98.018, val_loss:0.187, val_acc:78.750
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 288/300 lr=0.00017 - loss:0.123, acc:97.027, val_loss:0.179, val_acc:81.250
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 289/300 lr=0.00017 - loss:0.122, acc:97.485, val_loss:0.194, val_acc:79.375
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 290/300 lr=0.00017 - loss:0.122, acc:97.637, val_loss:0.193, val_acc:76.250
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 291/300 lr=0.00017 - loss:0.122, acc:97.790, val_loss:0.173, val_acc:80.000
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 292/300 lr=0.00017 - loss:0.122, acc:97.180, val_loss:0.195, val_acc:80.000
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 293/300 lr=0.00017 - loss:0.120, acc:98.018, val_loss:0.186, val_acc:79.375
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 294/300 lr=0.00017 - loss:0.124, acc:97.180, val_loss:0.168, val_acc:81.875
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 295/300 lr=0.00017 - loss:0.122, acc:97.637, val_loss:0.207, val_acc:78.750
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 296/300 lr=0.00017 - loss:0.122, acc:97.637, val_loss:0.182, val_acc:79.375
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 297/300 lr=0.00017 - loss:0.121, acc:97.256, val_loss:0.177, val_acc:81.875
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 298/300 lr=0.00017 - loss:0.120, acc:98.018, val_loss:0.192, val_acc:81.250
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 299/300 lr=0.00017 - loss:0.122, acc:97.180, val_loss:0.187, val_acc:81.250
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# 300/300 lr=0.00017 - loss:0.117, acc:98.628, val_loss:0.174, val_acc:80.000
# Best loss:0.152, Best accuracy:85.000, Best F1-score:0.846
# [*] Done - acc:85.000

# %%
end()

# %%
print(f'max:{max(fold_acc)}, min:{min(fold_acc)}, average:{sum(fold_acc)/len(fold_acc)}')
# Out:
# max:85.0, min:85.0, average:85.0

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
# Out:
# WAR(Weighted Average Recall)   : 82.99%
# UAR(Unweighted Average Recall) : 82.99%
