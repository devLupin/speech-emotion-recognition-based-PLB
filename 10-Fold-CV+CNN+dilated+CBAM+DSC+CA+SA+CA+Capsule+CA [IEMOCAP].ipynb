# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = '10-Fold dataset'
DATA_PATH = 'IEMOCAP'
CLASS_LABELS = Config.IEMOCAP_LABELS
k = 10

# No-reverse : (196,39,1)  ## CA: Channel-attention    ## SA : Self-attention 
# DSC : Depthwise-seperable CNN
model_name = '10-Fold-CV+CNN+dilated+CBAM+DSC+CA+SA+CA+Capsule+CA'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding=padding),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule]),
        Lambda(function=PrimaryCapssquash)
    ])
    
  def call(self, inputs):
    return self.conv(inputs)

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.cbam = CBAM(64) # sharing
    
    self.primarycap = PrimaryCap()
    self.spatial_attn = SpatialGate()
    
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    x = inputs
    
    cap = self.conv1(x)
    cap = cap + self.cbam(cap)
    cap = self.conv2(cap)
    cap = cap + self.cbam(cap)
    
    primarycaps = self.primarycap(cap)
    primarycaps = tf.expand_dims(primarycaps, axis=-1)
    primarycaps = primarycaps + self.spatial_attn(primarycaps)
    primarycaps = tf.squeeze(primarycaps, axis=-1)
    
    cap = primarycaps
    
    sa = self.attention([primarycaps, primarycaps, primarycaps])
    sa = self.LN(sa)
    
    sa = tf.expand_dims(sa, axis=-1)
    sa = sa + self.spatial_attn(sa)
    sa = tf.squeeze(sa, axis=-1)
    
    cap = self.lamb([cap, sa])
    cap = tf.expand_dims(cap, axis=-1)
    cap = cap + self.spatial_attn(cap)
    cap = tf.squeeze(cap, axis=-1)
    
    capsule = self.capsule(cap)
    capsule = tf.expand_dims(capsule, axis=-1)
    capsule = capsule + self.spatial_attn(capsule)
    capsule = tf.squeeze(capsule, axis=-1)
    
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1416
#
#  sequential_1 (Sequential)   (None, 46, 7, 64)         37300
#
#  cbam (CBAM)                 multiple                  4294
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  spatial_gate_1 (SpatialGate  multiple                 102
#  )
#
#  attention (Attention)       multiple                  1
#
#  layer_normalization (LayerN  multiple                 128
#  ormalization)
#
#  lambda_1 (Lambda)           multiple                  0
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  260
#
# =================================================================
# Total params: 93,677
# Trainable params: 93,099
# Non-trainable params: 578
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}_train.npy', 'rb') as f:
    X = np.load(f)
    y = np.load(f)
y = to_categorical(y,num_classes=len(CLASS_LABELS))

with open(f'{DATA_ROOT}/{DATA_PATH}_test.npy', 'rb') as f:
    X_test = np.load(f)
    y_test = np.load(f)
y_test = to_categorical(y_test,num_classes=len(CLASS_LABELS))
    
print(X.shape, y.shape, X_test.shape, y_test.shape)
# Out:
# (4978, 196, 39) (4978, 4) (553, 196, 39) (553, 4)

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_val_acc = []
fold_test_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, val) in tqdm(enumerate(kfold.split(X, y)), desc=f'Training {k}-Fold.....'):
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = X[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_val, y_val = X[val], y[val]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_val = tf.expand_dims(x_val, axis=-1)
    x_test = tf.expand_dims(X_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_val_loss = 0x3f3f3f
    best_val_acc = -1
    best_val_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_val = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        val_loss, val_acc, f1s = [], [], []
        for features, labels in batch_val:
            loss, acc, pred = test_step(model, features, labels)
            val_loss.append(loss)
            val_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1*100)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(val_loss)/len(val_loss)
        val_acc = sum(val_acc)/len(val_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_val_loss:.3f}, Best accuracy:{best_val_acc:.3f}, Best F1-score:{best_val_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_val_loss > val_loss:
            best_val_acc = val_acc
            best_val_loss = val_loss
            best_val_f1 = f1_score
            model.save_weights(h5_path)
            
            
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    
    test_acc, test_f1 = [], []
    for features, labels in batch_test:
        best_pred = model(features, training=False)
        emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(labels, axis=1))
        predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
        
        acc = tf.keras.metrics.CategoricalAccuracy()
        acc.update_state(labels, best_pred)
        accuracy = acc.result().numpy()
        test_acc.append(accuracy*100)
        
        f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
        f1_metric.update_state(labels, best_pred)
        f1 = f1_metric.result().numpy()
        test_f1.append(f1*100)
        
        
        
        
    print('*' * 80)
    print(f'[*] Done Fold-{i+1}')
    print(f'best_val_loss:{best_val_loss:.3f}, best_val_acc:{best_val_acc:.3f}, best_val_f1:{best_val_f1:.3f}')
    print(f'test_acc:{(sum(test_acc)/len(test_acc)):.3f}, test_f1:{(sum(test_f1)/len(test_f1)):.3f}')
    print('*' * 80)
    
    plt.title(f'Fold-{i+1} Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    fold_val_acc.append(best_val_acc)
    fold_test_acc.append((sum(test_acc)/len(test_acc)))
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.455, acc:42.188, val_loss:0.437, val_acc:40.799
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.432, acc:47.031, val_loss:0.411, val_acc:48.806
# Best loss:0.437, Best accuracy:40.799, Best F1-score:40.065
# 3/300 lr=0.00100 - loss:0.428, acc:46.987, val_loss:0.408, val_acc:54.362
# Best loss:0.411, Best accuracy:48.806, Best F1-score:46.339
# 4/300 lr=0.00100 - loss:0.420, acc:49.866, val_loss:0.395, val_acc:51.432
# Best loss:0.408, Best accuracy:54.362, Best F1-score:54.694
# 5/300 lr=0.00100 - loss:0.416, acc:49.888, val_loss:0.383, val_acc:55.816
# Best loss:0.395, Best accuracy:51.432, Best F1-score:49.424
# 6/300 lr=0.00100 - loss:0.408, acc:51.607, val_loss:0.376, val_acc:56.554
# Best loss:0.383, Best accuracy:55.816, Best F1-score:55.707
# 7/300 lr=0.00100 - loss:0.402, acc:53.504, val_loss:0.387, val_acc:55.621
# Best loss:0.376, Best accuracy:56.554, Best F1-score:56.389
# 8/300 lr=0.00100 - loss:0.407, acc:51.607, val_loss:0.380, val_acc:56.749
# Best loss:0.376, Best accuracy:56.554, Best F1-score:56.389
# 9/300 lr=0.00100 - loss:0.401, acc:54.308, val_loss:0.366, val_acc:59.093
# Best loss:0.376, Best accuracy:56.554, Best F1-score:56.389
# 10/300 lr=0.00100 - loss:0.393, acc:55.067, val_loss:0.362, val_acc:60.612
# Best loss:0.366, Best accuracy:59.093, Best F1-score:59.209
# 11/300 lr=0.00100 - loss:0.395, acc:54.152, val_loss:0.374, val_acc:52.951
# Best loss:0.362, Best accuracy:60.612, Best F1-score:60.800
# 12/300 lr=0.00100 - loss:0.393, acc:54.732, val_loss:0.386, val_acc:53.581
# Best loss:0.362, Best accuracy:60.612, Best F1-score:60.800
# 13/300 lr=0.00100 - loss:0.393, acc:53.549, val_loss:0.357, val_acc:57.140
# Best loss:0.362, Best accuracy:60.612, Best F1-score:60.800
# 14/300 lr=0.00100 - loss:0.386, acc:55.915, val_loss:0.359, val_acc:58.507
# Best loss:0.357, Best accuracy:57.140, Best F1-score:57.581
# 15/300 lr=0.00100 - loss:0.380, acc:57.455, val_loss:0.348, val_acc:59.049
# Best loss:0.357, Best accuracy:57.140, Best F1-score:57.581
# 16/300 lr=0.00100 - loss:0.376, acc:57.433, val_loss:0.350, val_acc:60.612
# Best loss:0.348, Best accuracy:59.049, Best F1-score:60.005
# 17/300 lr=0.00100 - loss:0.380, acc:56.830, val_loss:0.357, val_acc:58.073
# Best loss:0.348, Best accuracy:59.049, Best F1-score:60.005
# 18/300 lr=0.00100 - loss:0.381, acc:57.210, val_loss:0.348, val_acc:62.522
# Best loss:0.348, Best accuracy:59.049, Best F1-score:60.005
# 19/300 lr=0.00100 - loss:0.378, acc:57.478, val_loss:0.349, val_acc:57.878
# Best loss:0.348, Best accuracy:62.522, Best F1-score:62.405
# 20/300 lr=0.00100 - loss:0.378, acc:57.589, val_loss:0.355, val_acc:58.464
# Best loss:0.348, Best accuracy:62.522, Best F1-score:62.405
# 21/300 lr=0.00100 - loss:0.376, acc:57.991, val_loss:0.345, val_acc:60.764
# Best loss:0.348, Best accuracy:62.522, Best F1-score:62.405
# 22/300 lr=0.00100 - loss:0.367, acc:59.643, val_loss:0.348, val_acc:60.026
# Best loss:0.345, Best accuracy:60.764, Best F1-score:61.951
# 23/300 lr=0.00100 - loss:0.365, acc:60.402, val_loss:0.340, val_acc:60.026
# Best loss:0.345, Best accuracy:60.764, Best F1-score:61.951
# 24/300 lr=0.00100 - loss:0.369, acc:59.040, val_loss:0.359, val_acc:56.662
# Best loss:0.340, Best accuracy:60.026, Best F1-score:60.189
# 25/300 lr=0.00100 - loss:0.364, acc:59.732, val_loss:0.358, val_acc:56.879
# Best loss:0.340, Best accuracy:60.026, Best F1-score:60.189
# 26/300 lr=0.00100 - loss:0.366, acc:59.799, val_loss:0.336, val_acc:60.764
# Best loss:0.340, Best accuracy:60.026, Best F1-score:60.189
# 27/300 lr=0.00100 - loss:0.367, acc:59.263, val_loss:0.341, val_acc:59.201
# Best loss:0.336, Best accuracy:60.764, Best F1-score:61.006
# 28/300 lr=0.00100 - loss:0.362, acc:59.821, val_loss:0.348, val_acc:56.510
# Best loss:0.336, Best accuracy:60.764, Best F1-score:61.006
# 29/300 lr=0.00100 - loss:0.364, acc:59.598, val_loss:0.335, val_acc:64.475
# Best loss:0.336, Best accuracy:60.764, Best F1-score:61.006
# 30/300 lr=0.00100 - loss:0.360, acc:60.781, val_loss:0.332, val_acc:63.498
# Best loss:0.335, Best accuracy:64.475, Best F1-score:64.797
# 31/300 lr=0.00100 - loss:0.360, acc:61.205, val_loss:0.341, val_acc:62.565
# Best loss:0.332, Best accuracy:63.498, Best F1-score:63.608
# 32/300 lr=0.00100 - loss:0.356, acc:61.607, val_loss:0.328, val_acc:61.936
# Best loss:0.332, Best accuracy:63.498, Best F1-score:63.608
# 33/300 lr=0.00100 - loss:0.350, acc:62.121, val_loss:0.351, val_acc:57.769
# Best loss:0.328, Best accuracy:61.936, Best F1-score:62.316
# 34/300 lr=0.00100 - loss:0.351, acc:62.612, val_loss:0.343, val_acc:60.026
# Best loss:0.328, Best accuracy:61.936, Best F1-score:62.316
# 35/300 lr=0.00100 - loss:0.357, acc:60.871, val_loss:0.323, val_acc:62.522
# Best loss:0.328, Best accuracy:61.936, Best F1-score:62.316
# 36/300 lr=0.00100 - loss:0.349, acc:62.054, val_loss:0.335, val_acc:62.565
# Best loss:0.323, Best accuracy:62.522, Best F1-score:62.264
# 37/300 lr=0.00100 - loss:0.345, acc:63.214, val_loss:0.320, val_acc:62.370
# Best loss:0.323, Best accuracy:62.522, Best F1-score:62.264
# 38/300 lr=0.00100 - loss:0.341, acc:64.308, val_loss:0.336, val_acc:60.959
# Best loss:0.320, Best accuracy:62.370, Best F1-score:63.167
# 39/300 lr=0.00100 - loss:0.347, acc:62.746, val_loss:0.327, val_acc:64.128
# Best loss:0.320, Best accuracy:62.370, Best F1-score:63.167
# 40/300 lr=0.00100 - loss:0.340, acc:63.973, val_loss:0.328, val_acc:62.522
# Best loss:0.320, Best accuracy:62.370, Best F1-score:63.167
# 41/300 lr=0.00100 - loss:0.330, acc:66.116, val_loss:0.319, val_acc:62.522
# Best loss:0.320, Best accuracy:62.370, Best F1-score:63.167
# 42/300 lr=0.00100 - loss:0.339, acc:64.040, val_loss:0.318, val_acc:62.326
# Best loss:0.319, Best accuracy:62.522, Best F1-score:62.757
# 43/300 lr=0.00100 - loss:0.339, acc:64.286, val_loss:0.359, val_acc:58.984
# Best loss:0.318, Best accuracy:62.326, Best F1-score:62.857
# 44/300 lr=0.00100 - loss:0.340, acc:63.594, val_loss:0.327, val_acc:61.784
# Best loss:0.318, Best accuracy:62.326, Best F1-score:62.857
# 45/300 lr=0.00100 - loss:0.334, acc:64.643, val_loss:0.314, val_acc:63.694
# Best loss:0.318, Best accuracy:62.326, Best F1-score:62.857
# 46/300 lr=0.00100 - loss:0.333, acc:64.933, val_loss:0.324, val_acc:63.780
# Best loss:0.314, Best accuracy:63.694, Best F1-score:64.286
# 47/300 lr=0.00100 - loss:0.333, acc:65.223, val_loss:0.320, val_acc:62.522
# Best loss:0.314, Best accuracy:63.694, Best F1-score:64.286
# 48/300 lr=0.00100 - loss:0.329, acc:65.714, val_loss:0.330, val_acc:62.760
# Best loss:0.314, Best accuracy:63.694, Best F1-score:64.286
# 49/300 lr=0.00100 - loss:0.334, acc:64.576, val_loss:0.323, val_acc:64.128
# Best loss:0.314, Best accuracy:63.694, Best F1-score:64.286
# 50/300 lr=0.00100 - loss:0.324, acc:66.830, val_loss:0.337, val_acc:59.570
# Best loss:0.314, Best accuracy:63.694, Best F1-score:64.286
# 51/300 lr=0.00100 - loss:0.326, acc:66.853, val_loss:0.328, val_acc:62.326
# Best loss:0.314, Best accuracy:63.694, Best F1-score:64.286
# 52/300 lr=0.00100 - loss:0.335, acc:65.045, val_loss:0.331, val_acc:61.198
# Best loss:0.314, Best accuracy:63.694, Best F1-score:64.286
# 53/300 lr=0.00100 - loss:0.332, acc:65.179, val_loss:0.313, val_acc:63.303
# Best loss:0.314, Best accuracy:63.694, Best F1-score:64.286
# 54/300 lr=0.00100 - loss:0.320, acc:66.942, val_loss:0.325, val_acc:62.565
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 55/300 lr=0.00100 - loss:0.322, acc:67.277, val_loss:0.331, val_acc:61.632
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 56/300 lr=0.00100 - loss:0.318, acc:67.545, val_loss:0.319, val_acc:64.280
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 57/300 lr=0.00100 - loss:0.320, acc:67.768, val_loss:0.325, val_acc:63.585
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 58/300 lr=0.00100 - loss:0.311, acc:68.951, val_loss:0.330, val_acc:62.457
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 59/300 lr=0.00100 - loss:0.314, acc:68.772, val_loss:0.340, val_acc:61.241
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 60/300 lr=0.00100 - loss:0.306, acc:69.129, val_loss:0.349, val_acc:59.527
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 61/300 lr=0.00100 - loss:0.306, acc:69.397, val_loss:0.333, val_acc:61.437
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 62/300 lr=0.00086 - loss:0.306, acc:68.705, val_loss:0.331, val_acc:61.871
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 63/300 lr=0.00086 - loss:0.304, acc:69.643, val_loss:0.324, val_acc:62.999
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 64/300 lr=0.00086 - loss:0.298, acc:70.625, val_loss:0.338, val_acc:60.655
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 65/300 lr=0.00086 - loss:0.299, acc:70.357, val_loss:0.327, val_acc:62.804
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 66/300 lr=0.00086 - loss:0.302, acc:69.442, val_loss:0.335, val_acc:61.871
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 67/300 lr=0.00086 - loss:0.297, acc:71.830, val_loss:0.316, val_acc:64.171
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 68/300 lr=0.00086 - loss:0.296, acc:70.759, val_loss:0.336, val_acc:62.652
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 69/300 lr=0.00086 - loss:0.292, acc:71.585, val_loss:0.319, val_acc:64.757
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 70/300 lr=0.00086 - loss:0.292, acc:71.853, val_loss:0.336, val_acc:61.241
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 71/300 lr=0.00086 - loss:0.294, acc:71.362, val_loss:0.318, val_acc:63.585
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 72/300 lr=0.00086 - loss:0.286, acc:72.701, val_loss:0.337, val_acc:60.069
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 73/300 lr=0.00086 - loss:0.287, acc:71.741, val_loss:0.340, val_acc:61.914
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 74/300 lr=0.00086 - loss:0.286, acc:72.589, val_loss:0.346, val_acc:61.806
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 75/300 lr=0.00086 - loss:0.280, acc:73.683, val_loss:0.333, val_acc:62.999
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 76/300 lr=0.00086 - loss:0.282, acc:73.036, val_loss:0.325, val_acc:63.780
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 77/300 lr=0.00086 - loss:0.275, acc:74.375, val_loss:0.336, val_acc:63.585
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 78/300 lr=0.00086 - loss:0.279, acc:73.705, val_loss:0.326, val_acc:64.019
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 79/300 lr=0.00086 - loss:0.276, acc:73.862, val_loss:0.341, val_acc:59.288
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 80/300 lr=0.00086 - loss:0.278, acc:73.549, val_loss:0.332, val_acc:61.675
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 81/300 lr=0.00086 - loss:0.272, acc:74.509, val_loss:0.324, val_acc:62.999
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 82/300 lr=0.00074 - loss:0.270, acc:74.554, val_loss:0.328, val_acc:62.023
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 83/300 lr=0.00074 - loss:0.269, acc:74.576, val_loss:0.326, val_acc:64.865
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 84/300 lr=0.00074 - loss:0.271, acc:74.844, val_loss:0.332, val_acc:63.238
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 85/300 lr=0.00074 - loss:0.266, acc:75.290, val_loss:0.338, val_acc:62.066
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 86/300 lr=0.00074 - loss:0.262, acc:75.848, val_loss:0.344, val_acc:60.308
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 87/300 lr=0.00074 - loss:0.262, acc:76.205, val_loss:0.343, val_acc:60.655
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 88/300 lr=0.00074 - loss:0.258, acc:75.982, val_loss:0.341, val_acc:62.023
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 89/300 lr=0.00074 - loss:0.268, acc:75.000, val_loss:0.350, val_acc:61.089
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 90/300 lr=0.00074 - loss:0.260, acc:76.473, val_loss:0.334, val_acc:61.480
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 91/300 lr=0.00074 - loss:0.254, acc:77.321, val_loss:0.335, val_acc:61.480
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 92/300 lr=0.00074 - loss:0.258, acc:76.071, val_loss:0.342, val_acc:63.477
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 93/300 lr=0.00074 - loss:0.251, acc:77.277, val_loss:0.335, val_acc:62.804
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 94/300 lr=0.00074 - loss:0.251, acc:77.210, val_loss:0.344, val_acc:61.719
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 95/300 lr=0.00074 - loss:0.250, acc:77.634, val_loss:0.351, val_acc:60.742
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 96/300 lr=0.00074 - loss:0.252, acc:77.321, val_loss:0.341, val_acc:61.285
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 97/300 lr=0.00074 - loss:0.252, acc:76.987, val_loss:0.363, val_acc:58.550
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 98/300 lr=0.00074 - loss:0.242, acc:78.460, val_loss:0.340, val_acc:62.609
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 99/300 lr=0.00074 - loss:0.245, acc:78.683, val_loss:0.346, val_acc:61.523
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 100/300 lr=0.00074 - loss:0.259, acc:76.027, val_loss:0.351, val_acc:61.133
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
#
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# 300/300 lr=0.00017 - loss:0.142, acc:92.991, val_loss:0.377, val_acc:61.350
# Best loss:0.313, Best accuracy:63.303, Best F1-score:63.661
# ********************************************************************************
# [*] Done Fold-1
# best_val_loss:0.313, best_val_acc:63.303, best_val_f1:63.661
# test_acc:65.104, test_f1:64.127
# ********************************************************************************
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.458, acc:42.366, val_loss:0.435, val_acc:45.399
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.430, acc:47.277, val_loss:0.416, val_acc:46.398
# Best loss:0.435, Best accuracy:45.399, Best F1-score:41.955
# 3/300 lr=0.00100 - loss:0.422, acc:49.554, val_loss:0.409, val_acc:47.700
# Best loss:0.416, Best accuracy:46.398, Best F1-score:46.139
# 4/300 lr=0.00100 - loss:0.420, acc:48.772, val_loss:0.407, val_acc:48.503
# Best loss:0.409, Best accuracy:47.700, Best F1-score:46.481
# 5/300 lr=0.00100 - loss:0.413, acc:51.786, val_loss:0.391, val_acc:53.993
# Best loss:0.407, Best accuracy:48.503, Best F1-score:46.953
# 6/300 lr=0.00100 - loss:0.411, acc:51.004, val_loss:0.404, val_acc:48.958
# Best loss:0.391, Best accuracy:53.993, Best F1-score:53.449
# 7/300 lr=0.00100 - loss:0.404, acc:52.500, val_loss:0.388, val_acc:52.409
# Best loss:0.391, Best accuracy:53.993, Best F1-score:53.449
# 8/300 lr=0.00100 - loss:0.402, acc:53.259, val_loss:0.384, val_acc:53.407
# Best loss:0.388, Best accuracy:52.409, Best F1-score:51.721
# 9/300 lr=0.00100 - loss:0.401, acc:52.879, val_loss:0.395, val_acc:52.778
# Best loss:0.384, Best accuracy:53.407, Best F1-score:53.127
# 10/300 lr=0.00100 - loss:0.402, acc:52.366, val_loss:0.391, val_acc:51.758
# Best loss:0.384, Best accuracy:53.407, Best F1-score:53.127
# 11/300 lr=0.00100 - loss:0.401, acc:52.522, val_loss:0.380, val_acc:54.102
# Best loss:0.384, Best accuracy:53.407, Best F1-score:53.127
# 12/300 lr=0.00100 - loss:0.389, acc:56.339, val_loss:0.381, val_acc:53.885
# Best loss:0.380, Best accuracy:54.102, Best F1-score:53.915
# 13/300 lr=0.00100 - loss:0.405, acc:53.728, val_loss:0.393, val_acc:51.758
# Best loss:0.380, Best accuracy:54.102, Best F1-score:53.915
# 14/300 lr=0.00100 - loss:0.392, acc:54.978, val_loss:0.378, val_acc:52.734
# Best loss:0.380, Best accuracy:54.102, Best F1-score:53.915
# 15/300 lr=0.00100 - loss:0.393, acc:54.219, val_loss:0.398, val_acc:49.805
# Best loss:0.378, Best accuracy:52.734, Best F1-score:51.367
# 16/300 lr=0.00100 - loss:0.392, acc:53.862, val_loss:0.375, val_acc:54.883
# Best loss:0.378, Best accuracy:52.734, Best F1-score:51.367
# 17/300 lr=0.00100 - loss:0.385, acc:56.004, val_loss:0.375, val_acc:54.536
# Best loss:0.375, Best accuracy:54.883, Best F1-score:54.594
# 18/300 lr=0.00100 - loss:0.382, acc:57.567, val_loss:0.367, val_acc:56.250
# Best loss:0.375, Best accuracy:54.536, Best F1-score:53.796
# 19/300 lr=0.00100 - loss:0.384, acc:56.071, val_loss:0.367, val_acc:56.445
# Best loss:0.367, Best accuracy:56.250, Best F1-score:55.651
# 20/300 lr=0.00100 - loss:0.380, acc:56.763, val_loss:0.367, val_acc:54.883
# Best loss:0.367, Best accuracy:56.250, Best F1-score:55.651
# 21/300 lr=0.00100 - loss:0.377, acc:57.165, val_loss:0.361, val_acc:56.793
# Best loss:0.367, Best accuracy:56.250, Best F1-score:55.651
# 22/300 lr=0.00100 - loss:0.378, acc:57.589, val_loss:0.358, val_acc:57.183
# Best loss:0.361, Best accuracy:56.793, Best F1-score:56.514
# 23/300 lr=0.00100 - loss:0.371, acc:58.281, val_loss:0.363, val_acc:55.317
# Best loss:0.358, Best accuracy:57.183, Best F1-score:56.885
# 24/300 lr=0.00100 - loss:0.372, acc:57.969, val_loss:0.353, val_acc:57.183
# Best loss:0.358, Best accuracy:57.183, Best F1-score:56.885
# 25/300 lr=0.00100 - loss:0.367, acc:59.487, val_loss:0.361, val_acc:55.078
# Best loss:0.353, Best accuracy:57.183, Best F1-score:56.830
# 26/300 lr=0.00100 - loss:0.365, acc:59.665, val_loss:0.363, val_acc:53.906
# Best loss:0.353, Best accuracy:57.183, Best F1-score:56.830
# 27/300 lr=0.00100 - loss:0.367, acc:59.710, val_loss:0.376, val_acc:53.906
# Best loss:0.353, Best accuracy:57.183, Best F1-score:56.830
# 28/300 lr=0.00100 - loss:0.373, acc:59.152, val_loss:0.368, val_acc:56.293
# Best loss:0.353, Best accuracy:57.183, Best F1-score:56.830
# 29/300 lr=0.00100 - loss:0.365, acc:59.710, val_loss:0.362, val_acc:56.163
# Best loss:0.353, Best accuracy:57.183, Best F1-score:56.830
# 30/300 lr=0.00100 - loss:0.366, acc:59.933, val_loss:0.365, val_acc:54.926
# Best loss:0.353, Best accuracy:57.183, Best F1-score:56.830
# 31/300 lr=0.00100 - loss:0.362, acc:60.580, val_loss:0.355, val_acc:56.749
# Best loss:0.353, Best accuracy:57.183, Best F1-score:56.830
# 32/300 lr=0.00100 - loss:0.360, acc:61.518, val_loss:0.349, val_acc:57.921
# Best loss:0.353, Best accuracy:57.183, Best F1-score:56.830
# 33/300 lr=0.00100 - loss:0.366, acc:59.308, val_loss:0.355, val_acc:58.008
# Best loss:0.349, Best accuracy:57.921, Best F1-score:57.911
# 34/300 lr=0.00100 - loss:0.357, acc:60.915, val_loss:0.361, val_acc:55.230
# Best loss:0.349, Best accuracy:57.921, Best F1-score:57.911
# 35/300 lr=0.00100 - loss:0.364, acc:59.911, val_loss:0.346, val_acc:58.789
# Best loss:0.349, Best accuracy:57.921, Best F1-score:57.911
# 36/300 lr=0.00100 - loss:0.356, acc:61.451, val_loss:0.350, val_acc:58.659
# Best loss:0.346, Best accuracy:58.789, Best F1-score:58.626
# 37/300 lr=0.00100 - loss:0.352, acc:62.634, val_loss:0.351, val_acc:58.203
# Best loss:0.346, Best accuracy:58.789, Best F1-score:58.626
# 38/300 lr=0.00100 - loss:0.352, acc:63.058, val_loss:0.354, val_acc:56.944
# Best loss:0.346, Best accuracy:58.789, Best F1-score:58.626
# 39/300 lr=0.00100 - loss:0.354, acc:61.451, val_loss:0.363, val_acc:57.878
# Best loss:0.346, Best accuracy:58.789, Best F1-score:58.626
# 40/300 lr=0.00100 - loss:0.350, acc:62.009, val_loss:0.344, val_acc:59.484
# Best loss:0.346, Best accuracy:58.789, Best F1-score:58.626
# 41/300 lr=0.00100 - loss:0.350, acc:62.232, val_loss:0.350, val_acc:58.550
# Best loss:0.344, Best accuracy:59.484, Best F1-score:59.053
# 42/300 lr=0.00100 - loss:0.348, acc:62.612, val_loss:0.351, val_acc:57.964
# Best loss:0.344, Best accuracy:59.484, Best F1-score:59.053
# 43/300 lr=0.00100 - loss:0.347, acc:63.705, val_loss:0.347, val_acc:59.440
# Best loss:0.344, Best accuracy:59.484, Best F1-score:59.053
# 44/300 lr=0.00100 - loss:0.347, acc:63.192, val_loss:0.347, val_acc:60.221
# Best loss:0.344, Best accuracy:59.484, Best F1-score:59.053
# 45/300 lr=0.00100 - loss:0.343, acc:63.884, val_loss:0.336, val_acc:60.547
# Best loss:0.344, Best accuracy:59.484, Best F1-score:59.053
# 46/300 lr=0.00100 - loss:0.342, acc:63.839, val_loss:0.347, val_acc:57.921
# Best loss:0.336, Best accuracy:60.547, Best F1-score:60.174
# 47/300 lr=0.00100 - loss:0.341, acc:63.996, val_loss:0.343, val_acc:60.460
# Best loss:0.336, Best accuracy:60.547, Best F1-score:60.174
# 48/300 lr=0.00100 - loss:0.345, acc:64.152, val_loss:0.344, val_acc:60.894
# Best loss:0.336, Best accuracy:60.547, Best F1-score:60.174
# 49/300 lr=0.00100 - loss:0.335, acc:65.112, val_loss:0.346, val_acc:57.812
# Best loss:0.336, Best accuracy:60.547, Best F1-score:60.174
# 50/300 lr=0.00100 - loss:0.337, acc:64.375, val_loss:0.341, val_acc:60.308
# Best loss:0.336, Best accuracy:60.547, Best F1-score:60.174
# 51/300 lr=0.00100 - loss:0.337, acc:64.487, val_loss:0.349, val_acc:60.265
# Best loss:0.336, Best accuracy:60.547, Best F1-score:60.174
# 52/300 lr=0.00100 - loss:0.333, acc:65.335, val_loss:0.347, val_acc:60.699
# ...
# 199/300 lr=0.00035 - loss:0.176, acc:88.125, val_loss:0.361, val_acc:63.672
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 200/300 lr=0.00035 - loss:0.177, acc:87.545, val_loss:0.379, val_acc:60.395
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 201/300 lr=0.00035 - loss:0.179, acc:87.522, val_loss:0.365, val_acc:62.153
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 202/300 lr=0.00030 - loss:0.176, acc:88.259, val_loss:0.379, val_acc:61.176
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 203/300 lr=0.00030 - loss:0.177, acc:88.504, val_loss:0.380, val_acc:61.176
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 204/300 lr=0.00030 - loss:0.176, acc:87.545, val_loss:0.383, val_acc:60.938
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 205/300 lr=0.00030 - loss:0.173, acc:88.571, val_loss:0.376, val_acc:60.786
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 206/300 lr=0.00030 - loss:0.171, acc:88.839, val_loss:0.380, val_acc:61.914
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 207/300 lr=0.00030 - loss:0.174, acc:88.103, val_loss:0.371, val_acc:61.719
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 208/300 lr=0.00030 - loss:0.175, acc:88.393, val_loss:0.364, val_acc:62.500
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 209/300 lr=0.00030 - loss:0.172, acc:88.795, val_loss:0.375, val_acc:61.957
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
#
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 277/300 lr=0.00019 - loss:0.151, acc:91.696, val_loss:0.384, val_acc:61.176
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 278/300 lr=0.00019 - loss:0.152, acc:91.540, val_loss:0.382, val_acc:59.570
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 279/300 lr=0.00019 - loss:0.157, acc:90.580, val_loss:0.385, val_acc:61.176
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 280/300 lr=0.00019 - loss:0.153, acc:91.295, val_loss:0.382, val_acc:60.395
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 281/300 lr=0.00019 - loss:0.157, acc:90.826, val_loss:0.380, val_acc:60.395
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 282/300 lr=0.00017 - loss:0.154, acc:91.429, val_loss:0.383, val_acc:61.675
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 283/300 lr=0.00017 - loss:0.150, acc:91.719, val_loss:0.371, val_acc:61.871
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 284/300 lr=0.00017 - loss:0.151, acc:91.562, val_loss:0.382, val_acc:60.352
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 285/300 lr=0.00017 - loss:0.152, acc:91.406, val_loss:0.386, val_acc:60.981
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 286/300 lr=0.00017 - loss:0.154, acc:91.272, val_loss:0.381, val_acc:60.243
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 287/300 lr=0.00017 - loss:0.155, acc:90.804, val_loss:0.379, val_acc:60.200
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 288/300 lr=0.00017 - loss:0.152, acc:91.138, val_loss:0.381, val_acc:58.637
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 289/300 lr=0.00017 - loss:0.155, acc:90.938, val_loss:0.378, val_acc:61.719
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 290/300 lr=0.00017 - loss:0.148, acc:92.076, val_loss:0.383, val_acc:61.176
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 291/300 lr=0.00017 - loss:0.152, acc:91.496, val_loss:0.379, val_acc:61.328
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 292/300 lr=0.00017 - loss:0.149, acc:91.473, val_loss:0.373, val_acc:62.348
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 293/300 lr=0.00017 - loss:0.156, acc:90.826, val_loss:0.369, val_acc:63.086
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 294/300 lr=0.00017 - loss:0.149, acc:92.165, val_loss:0.373, val_acc:61.176
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 295/300 lr=0.00017 - loss:0.148, acc:91.920, val_loss:0.379, val_acc:61.415
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 296/300 lr=0.00017 - loss:0.150, acc:91.674, val_loss:0.373, val_acc:63.477
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 297/300 lr=0.00017 - loss:0.151, acc:91.607, val_loss:0.383, val_acc:61.719
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 298/300 lr=0.00017 - loss:0.149, acc:91.629, val_loss:0.377, val_acc:60.395
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 299/300 lr=0.00017 - loss:0.153, acc:91.585, val_loss:0.379, val_acc:63.086
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# 300/300 lr=0.00017 - loss:0.151, acc:91.272, val_loss:0.400, val_acc:57.704
# Best loss:0.312, Best accuracy:66.406, Best F1-score:66.187
# ********************************************************************************
# [*] Done Fold-8
# best_val_loss:0.312, best_val_acc:66.406, best_val_f1:66.187
# test_acc:62.905, test_f1:62.594
# ********************************************************************************
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\devLupin\현재 진행\★ 실험\10-Fold-CV+CNN+dilated+CBAM+DSC+CA+SA+CA+Capsule+CA [IEMOCAP].ipynb Cell 20 in 1
#      <a href='vscode-notebook-cell:/c%3A/Users/devLupin/%ED%98%84%EC%9E%AC%20%EC%A7%84%ED%96%89/%E2%98%85%20%EC%8B%A4%ED%97%98/10-Fold-CV%2BCNN%2Bdilated%2BCBAM%2BDSC%2BCA%2BSA%2BCA%2BCapsule%2BCA%20%5BIEMOCAP%5D.ipynb#X25sZmlsZQ%3D%3D?line=13'>14</a> os.makedirs(save_path, exist_ok=True)
#      <a href='vscode-notebook-cell:/c%3A/Users/devLupin/%ED%98%84%EC%9E%AC%20%EC%A7%84%ED%96%89/%E2%98%85%20%EC%8B%A4%ED%97%98/10-Fold-CV%2BCNN%2Bdilated%2BCBAM%2BDSC%2BCA%2BSA%2BCA%2BCapsule%2BCA%20%5BIEMOCAP%5D.ipynb#X25sZmlsZQ%3D%3D?line=14'>15</a> h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
# ---> <a href='vscode-notebook-cell:/c%3A/Users/devLupin/%ED%98%84%EC%9E%AC%20%EC%A7%84%ED%96%89/%E2%98%85%20%EC%8B%A4%ED%97%98/10-Fold-CV%2BCNN%2Bdilated%2BCBAM%2BDSC%2BCA%2BSA%2BCA%2BCapsule%2BCA%20%5BIEMOCAP%5D.ipynb#X25sZmlsZQ%3D%3D?line=16'>17</a> x_train, y_train = X[train], y[train]
#      <a href='vscode-notebook-cell:/c%3A/Users/devLupin/%ED%98%84%EC%9E%AC%20%EC%A7%84%ED%96%89/%E2%98%85%20%EC%8B%A4%ED%97%98/10-Fold-CV%2BCNN%2Bdilated%2BCBAM%2BDSC%2BCA%2BSA%2BCA%2BCapsule%2BCA%20%5BIEMOCAP%5D.ipynb#X25sZmlsZQ%3D%3D?line=17'>18</a> y_train = smooth_labels(y[train], 0.1)
#      <a href='vscode-notebook-cell:/c%3A/Users/devLupin/%ED%98%84%EC%9E%AC%20%EC%A7%84%ED%96%89/%E2%98%85%20%EC%8B%A4%ED%97%98/10-Fold-CV%2BCNN%2Bdilated%2BCBAM%2BDSC%2BCA%2BSA%2BCA%2BCapsule%2BCA%20%5BIEMOCAP%5D.ipynb#X25sZmlsZQ%3D%3D?line=19'>20</a> x_val, y_val = X[val], y[val]
#
# MemoryError: Unable to allocate 261. MiB for an array with shape (4481, 196, 39) and data type float64

# %%
end()

# %%
print('*' * 80)
print('[*] validation accuracy')
for i, val_acc in enumerate(fold_val_acc):
    print(f'    Fold-{i+1} : {val_acc}')
print(f'max:{max(fold_val_acc)}, min:{min(fold_val_acc)}, average:{sum(fold_val_acc)/len(fold_val_acc)}')
print('*' * 80)
print()

print('*' * 80)
print('[*] test accuracy')
for i, test_acc in enumerate(fold_test_acc):
    print(f'    Fold-{i+1} : {test_acc}')
print(f'max:{max(fold_test_acc)}, min:{min(fold_test_acc)}, average:{sum(fold_test_acc)/len(fold_test_acc)}')
print('*' * 80)
print()

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
