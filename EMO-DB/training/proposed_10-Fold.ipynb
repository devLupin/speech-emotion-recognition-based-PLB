# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = '10-Fold dataset'
DATA_PATH = 'EMODB'
CLASS_LABELS = Config.EMODB_LABELS
k = 10

# No-reverse : (196,39,1)  ## CA: Channel-attention    ## SA : Self-attention 
# DSC : Depthwise-seperable CNN
model_name = '10-Fold-CV+CNN+dilated+CBAM+DSC+CA+SA+CA+Capsule+CA [EMODB]'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding=padding),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule]),
        Lambda(function=PrimaryCapssquash)
    ])
    
  def call(self, inputs):
    return self.conv(inputs)

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.cbam = CBAM(64) # sharing
    
    self.primarycap = PrimaryCap()
    self.spatial_attn = SpatialGate()
    
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    x = inputs
    
    cap = self.conv1(x)
    cap = cap + self.cbam(cap)
    cap = self.conv2(cap)
    cap = cap + self.cbam(cap)
    
    primarycaps = self.primarycap(cap)
    primarycaps = tf.expand_dims(primarycaps, axis=-1)
    primarycaps = primarycaps + self.spatial_attn(primarycaps)
    primarycaps = tf.squeeze(primarycaps, axis=-1)
    
    cap = primarycaps
    
    sa = self.attention([primarycaps, primarycaps, primarycaps])
    sa = self.LN(sa)
    
    sa = tf.expand_dims(sa, axis=-1)
    sa = sa + self.spatial_attn(sa)
    sa = tf.squeeze(sa, axis=-1)
    
    cap = self.lamb([cap, sa])
    cap = tf.expand_dims(cap, axis=-1)
    cap = cap + self.spatial_attn(cap)
    cap = tf.squeeze(cap, axis=-1)
    
    capsule = self.capsule(cap)
    capsule = tf.expand_dims(capsule, axis=-1)
    capsule = capsule + self.spatial_attn(capsule)
    capsule = tf.squeeze(capsule, axis=-1)
    
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1416
#
#  sequential_1 (Sequential)   (None, 46, 7, 64)         37300
#
#  cbam (CBAM)                 multiple                  4294
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  spatial_gate_1 (SpatialGate  multiple                 102
#  )
#
#  attention (Attention)       multiple                  1
#
#  layer_normalization (LayerN  multiple                 128
#  ormalization)
#
#  lambda_1 (Lambda)           multiple                  0
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  455
#
# =================================================================
# Total params: 93,872
# Trainable params: 93,294
# Non-trainable params: 578
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}_train.npy', 'rb') as f:
    X = np.load(f)
    y = np.load(f)
y = to_categorical(y,num_classes=len(CLASS_LABELS))

with open(f'{DATA_ROOT}/{DATA_PATH}_test.npy', 'rb') as f:
    X_test = np.load(f)
    y_test = np.load(f)
y_test = to_categorical(y_test,num_classes=len(CLASS_LABELS))
    
print(X.shape, y.shape, X_test.shape, y_test.shape)
# Out:
# (482, 196, 39) (482, 7) (53, 196, 39) (53, 7)

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_val_acc = []
fold_test_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, val) in tqdm(enumerate(kfold.split(X, y)), desc=f'Training {k}-Fold.....'):
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = X[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_val, y_val = X[val], y[val]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_val = tf.expand_dims(x_val, axis=-1)
    x_test = tf.expand_dims(X_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_val_loss = 0x3f3f3f
    best_val_acc = -1
    best_val_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_val = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        val_loss, val_acc, f1s = [], [], []
        for features, labels in batch_val:
            loss, acc, pred = test_step(model, features, labels)
            val_loss.append(loss)
            val_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1*100)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(val_loss)/len(val_loss)
        val_acc = sum(val_acc)/len(val_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_val_loss:.3f}, Best accuracy:{best_val_acc:.3f}, Best F1-score:{best_val_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_val_loss > val_loss:
            best_val_acc = val_acc
            best_val_loss = val_loss
            best_val_f1 = f1_score
            model.save_weights(h5_path)
            
            
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    
    test_acc, test_f1 = [], []
    for features, labels in batch_test:
        best_pred = model(features, training=False)
        emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(labels, axis=1))
        predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
        
        acc = tf.keras.metrics.CategoricalAccuracy()
        acc.update_state(labels, best_pred)
        accuracy = acc.result().numpy()
        test_acc.append(accuracy*100)
        
        f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
        f1_metric.update_state(labels, best_pred)
        f1 = f1_metric.result().numpy()
        test_f1.append(f1*100)
        
        
        
        
    print('*' * 80)
    print(f'[*] Done Fold-{i+1}')
    print(f'best_val_loss:{best_val_loss:.3f}, best_val_acc:{best_val_acc:.3f}, best_val_f1:{best_val_f1:.3f}')
    print(f'test_acc:{(sum(test_acc)/len(test_acc)):.3f}, test_f1:{(sum(test_f1)/len(test_f1)):.3f}')
    print('*' * 80)
    
    plt.title(f'Fold-{i+1} Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    fold_val_acc.append(best_val_acc)
    fold_test_acc.append((sum(test_acc)/len(test_acc)))
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.591, acc:27.967, val_loss:0.569, val_acc:39.522
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.546, acc:39.824, val_loss:0.533, val_acc:39.522
# Best loss:0.569, Best accuracy:39.522, Best F1-score:0.271
# 3/300 lr=0.00100 - loss:0.514, acc:44.433, val_loss:0.533, val_acc:42.463
# Best loss:0.533, Best accuracy:39.522, Best F1-score:0.259
# 4/300 lr=0.00100 - loss:0.495, acc:45.076, val_loss:0.482, val_acc:54.779
# Best loss:0.533, Best accuracy:42.463, Best F1-score:0.289
# 5/300 lr=0.00100 - loss:0.475, acc:47.558, val_loss:0.488, val_acc:47.151
# Best loss:0.482, Best accuracy:54.779, Best F1-score:0.445
# 6/300 lr=0.00100 - loss:0.467, acc:48.923, val_loss:0.469, val_acc:45.588
# Best loss:0.482, Best accuracy:54.779, Best F1-score:0.445
# 7/300 lr=0.00100 - loss:0.463, acc:47.085, val_loss:0.445, val_acc:47.151
# Best loss:0.469, Best accuracy:45.588, Best F1-score:0.357
# 8/300 lr=0.00100 - loss:0.463, acc:48.503, val_loss:0.458, val_acc:51.838
# Best loss:0.445, Best accuracy:47.151, Best F1-score:0.393
# 9/300 lr=0.00100 - loss:0.441, acc:52.665, val_loss:0.441, val_acc:49.908
# Best loss:0.445, Best accuracy:47.151, Best F1-score:0.393
# 10/300 lr=0.00100 - loss:0.429, acc:53.926, val_loss:0.466, val_acc:42.831
# Best loss:0.441, Best accuracy:49.908, Best F1-score:0.437
# 11/300 lr=0.00100 - loss:0.424, acc:53.978, val_loss:0.417, val_acc:50.092
# Best loss:0.441, Best accuracy:49.908, Best F1-score:0.437
# 12/300 lr=0.00100 - loss:0.414, acc:55.987, val_loss:0.427, val_acc:46.967
# Best loss:0.417, Best accuracy:50.092, Best F1-score:0.405
# 13/300 lr=0.00100 - loss:0.416, acc:52.692, val_loss:0.413, val_acc:50.092
# Best loss:0.417, Best accuracy:50.092, Best F1-score:0.405
# 14/300 lr=0.00100 - loss:0.402, acc:57.156, val_loss:0.411, val_acc:48.529
# Best loss:0.413, Best accuracy:50.092, Best F1-score:0.403
# 15/300 lr=0.00100 - loss:0.399, acc:57.747, val_loss:0.401, val_acc:49.908
# Best loss:0.411, Best accuracy:48.529, Best F1-score:0.406
# 16/300 lr=0.00100 - loss:0.399, acc:57.799, val_loss:0.397, val_acc:50.092
# Best loss:0.401, Best accuracy:49.908, Best F1-score:0.448
# 17/300 lr=0.00100 - loss:0.384, acc:59.112, val_loss:0.392, val_acc:48.529
# Best loss:0.397, Best accuracy:50.092, Best F1-score:0.405
# 18/300 lr=0.00100 - loss:0.376, acc:60.819, val_loss:0.378, val_acc:54.412
# Best loss:0.392, Best accuracy:48.529, Best F1-score:0.431
# 19/300 lr=0.00100 - loss:0.383, acc:58.272, val_loss:0.369, val_acc:52.849
# Best loss:0.378, Best accuracy:54.412, Best F1-score:0.476
# 20/300 lr=0.00100 - loss:0.386, acc:59.808, val_loss:0.370, val_acc:55.974
# Best loss:0.369, Best accuracy:52.849, Best F1-score:0.465
# 21/300 lr=0.00100 - loss:0.378, acc:59.756, val_loss:0.365, val_acc:55.974
# Best loss:0.369, Best accuracy:52.849, Best F1-score:0.465
# 22/300 lr=0.00100 - loss:0.372, acc:63.051, val_loss:0.362, val_acc:57.353
# Best loss:0.365, Best accuracy:55.974, Best F1-score:0.478
# 23/300 lr=0.00100 - loss:0.385, acc:59.756, val_loss:0.372, val_acc:48.529
# Best loss:0.362, Best accuracy:57.353, Best F1-score:0.544
# 24/300 lr=0.00100 - loss:0.370, acc:60.649, val_loss:0.360, val_acc:58.915
# Best loss:0.362, Best accuracy:57.353, Best F1-score:0.544
# 25/300 lr=0.00100 - loss:0.366, acc:62.828, val_loss:0.380, val_acc:54.412
# Best loss:0.360, Best accuracy:58.915, Best F1-score:0.511
# 26/300 lr=0.00100 - loss:0.362, acc:60.898, val_loss:0.347, val_acc:61.673
# Best loss:0.360, Best accuracy:58.915, Best F1-score:0.511
# 27/300 lr=0.00100 - loss:0.352, acc:64.391, val_loss:0.343, val_acc:60.478
# Best loss:0.347, Best accuracy:61.673, Best F1-score:0.583
# 28/300 lr=0.00100 - loss:0.362, acc:61.791, val_loss:0.334, val_acc:63.235
# Best loss:0.343, Best accuracy:60.478, Best F1-score:0.547
# 29/300 lr=0.00100 - loss:0.354, acc:62.067, val_loss:0.334, val_acc:60.478
# Best loss:0.334, Best accuracy:63.235, Best F1-score:0.613
# 30/300 lr=0.00100 - loss:0.340, acc:66.426, val_loss:0.312, val_acc:64.982
# Best loss:0.334, Best accuracy:63.235, Best F1-score:0.613
# 31/300 lr=0.00100 - loss:0.348, acc:62.960, val_loss:0.310, val_acc:66.544
# Best loss:0.312, Best accuracy:64.982, Best F1-score:0.608
# 32/300 lr=0.00100 - loss:0.352, acc:65.336, val_loss:0.351, val_acc:57.353
# Best loss:0.310, Best accuracy:66.544, Best F1-score:0.635
# 33/300 lr=0.00100 - loss:0.348, acc:64.273, val_loss:0.319, val_acc:59.099
# Best loss:0.310, Best accuracy:66.544, Best F1-score:0.635
# 34/300 lr=0.00100 - loss:0.330, acc:68.212, val_loss:0.292, val_acc:64.982
# Best loss:0.310, Best accuracy:66.544, Best F1-score:0.635
# 35/300 lr=0.00100 - loss:0.325, acc:68.093, val_loss:0.279, val_acc:64.798
# Best loss:0.292, Best accuracy:64.982, Best F1-score:0.606
# 36/300 lr=0.00100 - loss:0.323, acc:68.238, val_loss:0.270, val_acc:75.551
# Best loss:0.279, Best accuracy:64.798, Best F1-score:0.625
# 37/300 lr=0.00100 - loss:0.317, acc:70.614, val_loss:0.278, val_acc:69.485
# Best loss:0.270, Best accuracy:75.551, Best F1-score:0.736
# 38/300 lr=0.00100 - loss:0.316, acc:69.722, val_loss:0.277, val_acc:69.485
# Best loss:0.270, Best accuracy:75.551, Best F1-score:0.736
# 39/300 lr=0.00100 - loss:0.317, acc:69.131, val_loss:0.253, val_acc:72.426
# Best loss:0.270, Best accuracy:75.551, Best F1-score:0.736
# 40/300 lr=0.00100 - loss:0.317, acc:71.337, val_loss:0.246, val_acc:76.930
# Best loss:0.253, Best accuracy:72.426, Best F1-score:0.695
# 41/300 lr=0.00100 - loss:0.313, acc:67.621, val_loss:0.241, val_acc:72.794
# Best loss:0.246, Best accuracy:76.930, Best F1-score:0.756
# 42/300 lr=0.00100 - loss:0.302, acc:71.928, val_loss:0.239, val_acc:72.610
# Best loss:0.241, Best accuracy:72.794, Best F1-score:0.704
# 43/300 lr=0.00100 - loss:0.317, acc:68.487, val_loss:0.245, val_acc:75.735
# Best loss:0.239, Best accuracy:72.610, Best F1-score:0.717
# 44/300 lr=0.00100 - loss:0.288, acc:74.383, val_loss:0.233, val_acc:73.989
# Best loss:0.239, Best accuracy:72.610, Best F1-score:0.717
# 45/300 lr=0.00100 - loss:0.285, acc:76.247, val_loss:0.221, val_acc:78.676
# Best loss:0.233, Best accuracy:73.989, Best F1-score:0.729
# 46/300 lr=0.00100 - loss:0.286, acc:73.122, val_loss:0.213, val_acc:75.551
# Best loss:0.221, Best accuracy:78.676, Best F1-score:0.750
# 47/300 lr=0.00100 - loss:0.281, acc:75.131, val_loss:0.203, val_acc:78.493
# Best loss:0.213, Best accuracy:75.551, Best F1-score:0.746
# 48/300 lr=0.00100 - loss:0.282, acc:74.632, val_loss:0.214, val_acc:77.114
# Best loss:0.203, Best accuracy:78.493, Best F1-score:0.772
# 49/300 lr=0.00100 - loss:0.266, acc:76.418, val_loss:0.209, val_acc:80.239
# Best loss:0.203, Best accuracy:78.493, Best F1-score:0.772
# 50/300 lr=0.00100 - loss:0.273, acc:74.015, val_loss:0.203, val_acc:77.298
# Best loss:0.203, Best accuracy:78.493, Best F1-score:0.772
# 51/300 lr=0.00100 - loss:0.266, acc:77.114, val_loss:0.199, val_acc:83.180
# Best loss:0.203, Best accuracy:77.298, Best F1-score:0.751
# 52/300 lr=0.00100 - loss:0.264, acc:78.256, val_loss:0.230, val_acc:69.669
# Best loss:0.199, Best accuracy:83.180, Best F1-score:0.818
# 53/300 lr=0.00100 - loss:0.278, acc:74.685, val_loss:0.196, val_acc:80.055
# Best loss:0.199, Best accuracy:83.180, Best F1-score:0.818
# 54/300 lr=0.00100 - loss:0.266, acc:74.015, val_loss:0.208, val_acc:75.735
# Best loss:0.196, Best accuracy:80.055, Best F1-score:0.780
# 55/300 lr=0.00100 - loss:0.268, acc:76.471, val_loss:0.181, val_acc:84.743
# Best loss:0.196, Best accuracy:80.055, Best F1-score:0.780
# 56/300 lr=0.00100 - loss:0.243, acc:79.267, val_loss:0.201, val_acc:75.735
# Best loss:0.181, Best accuracy:84.743, Best F1-score:0.835
# 57/300 lr=0.00100 - loss:0.246, acc:79.517, val_loss:0.182, val_acc:78.676
# Best loss:0.181, Best accuracy:84.743, Best F1-score:0.835
# 58/300 lr=0.00100 - loss:0.257, acc:77.088, val_loss:0.191, val_acc:75.735
# Best loss:0.181, Best accuracy:84.743, Best F1-score:0.835
# 59/300 lr=0.00100 - loss:0.249, acc:79.766, val_loss:0.180, val_acc:77.114
# Best loss:0.181, Best accuracy:84.743, Best F1-score:0.835
# 60/300 lr=0.00100 - loss:0.251, acc:80.016, val_loss:0.174, val_acc:81.801
# Best loss:0.180, Best accuracy:77.114, Best F1-score:0.757
# 61/300 lr=0.00100 - loss:0.255, acc:75.998, val_loss:0.205, val_acc:72.426
# Best loss:0.174, Best accuracy:81.801, Best F1-score:0.782
# 62/300 lr=0.00086 - loss:0.248, acc:79.175, val_loss:0.173, val_acc:84.743
# Best loss:0.174, Best accuracy:81.801, Best F1-score:0.782
# 63/300 lr=0.00086 - loss:0.247, acc:79.097, val_loss:0.182, val_acc:77.114
# Best loss:0.173, Best accuracy:84.743, Best F1-score:0.838
# 64/300 lr=0.00086 - loss:0.237, acc:80.607, val_loss:0.196, val_acc:74.173
# Best loss:0.173, Best accuracy:84.743, Best F1-score:0.838
# 65/300 lr=0.00086 - loss:0.237, acc:81.552, val_loss:0.170, val_acc:81.801
# Best loss:0.173, Best accuracy:84.743, Best F1-score:0.838
# 66/300 lr=0.00086 - loss:0.236, acc:82.195, val_loss:0.208, val_acc:77.298
# Best loss:0.170, Best accuracy:81.801, Best F1-score:0.785
# 67/300 lr=0.00086 - loss:0.246, acc:80.016, val_loss:0.163, val_acc:80.423
# Best loss:0.170, Best accuracy:81.801, Best F1-score:0.785
# 68/300 lr=0.00086 - loss:0.224, acc:83.364, val_loss:0.176, val_acc:77.114
# Best loss:0.163, Best accuracy:80.423, Best F1-score:0.769
# 69/300 lr=0.00086 - loss:0.240, acc:80.607, val_loss:0.189, val_acc:74.357
# Best loss:0.163, Best accuracy:80.423, Best F1-score:0.769
# 70/300 lr=0.00086 - loss:0.232, acc:81.749, val_loss:0.179, val_acc:81.801
# Best loss:0.163, Best accuracy:80.423, Best F1-score:0.769
# 71/300 lr=0.00086 - loss:0.229, acc:81.106, val_loss:0.190, val_acc:78.676
# Best loss:0.163, Best accuracy:80.423, Best F1-score:0.769
# 72/300 lr=0.00086 - loss:0.235, acc:81.329, val_loss:0.173, val_acc:78.860
# Best loss:0.163, Best accuracy:80.423, Best F1-score:0.769
# 73/300 lr=0.00086 - loss:0.223, acc:82.668, val_loss:0.193, val_acc:75.735
# Best loss:0.163, Best accuracy:80.423, Best F1-score:0.769
# 74/300 lr=0.00086 - loss:0.225, acc:82.392, val_loss:0.180, val_acc:78.860
# Best loss:0.163, Best accuracy:80.423, Best F1-score:0.769
# 75/300 lr=0.00086 - loss:0.213, acc:83.364, val_loss:0.158, val_acc:83.180
# Best loss:0.163, Best accuracy:80.423, Best F1-score:0.769
# 76/300 lr=0.00086 - loss:0.207, acc:85.320, val_loss:0.167, val_acc:81.801
# Best loss:0.130, Best accuracy:89.246, Best F1-score:0.889
# 292/300 lr=0.00017 - loss:0.106, acc:98.687, val_loss:0.141, val_acc:89.246
# Best loss:0.130, Best accuracy:89.246, Best F1-score:0.889
# 293/300 lr=0.00017 - loss:0.119, acc:97.098, val_loss:0.145, val_acc:83.180
# Best loss:0.130, Best accuracy:89.246, Best F1-score:0.889
# 294/300 lr=0.00017 - loss:0.108, acc:99.107, val_loss:0.149, val_acc:84.743
# Best loss:0.130, Best accuracy:89.246, Best F1-score:0.889
# 295/300 lr=0.00017 - loss:0.110, acc:98.464, val_loss:0.162, val_acc:83.180
# Best loss:0.130, Best accuracy:89.246, Best F1-score:0.889
# 296/300 lr=0.00017 - loss:0.108, acc:98.884, val_loss:0.155, val_acc:84.743
# Best loss:0.130, Best accuracy:89.246, Best F1-score:0.889
# 297/300 lr=0.00017 - loss:0.110, acc:98.661, val_loss:0.141, val_acc:84.743
# Best loss:0.130, Best accuracy:89.246, Best F1-score:0.889
# 298/300 lr=0.00017 - loss:0.110, acc:97.794, val_loss:0.145, val_acc:84.743
# Best loss:0.130, Best accuracy:89.246, Best F1-score:0.889
# 299/300 lr=0.00017 - loss:0.109, acc:98.438, val_loss:0.155, val_acc:83.364
# Best loss:0.130, Best accuracy:89.246, Best F1-score:0.889
# 300/300 lr=0.00017 - loss:0.108, acc:98.884, val_loss:0.158, val_acc:84.743
# Best loss:0.130, Best accuracy:89.246, Best F1-score:0.889
# ********************************************************************************
# [*] Done Fold-1
# best_val_loss:0.130, best_val_acc:89.246, best_val_f1:0.889
# test_acc:0.914, test_f1:0.917
# ********************************************************************************
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.594, acc:22.834, val_loss:0.601, val_acc:24.632
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.552, acc:39.575, val_loss:0.575, val_acc:33.640
# Best loss:0.601, Best accuracy:24.632, Best F1-score:0.155
# 3/300 lr=0.00100 - loss:0.516, acc:41.085, val_loss:0.571, val_acc:32.261
# Best loss:0.575, Best accuracy:33.640, Best F1-score:0.276
# 4/300 lr=0.00100 - loss:0.486, acc:50.433, val_loss:0.559, val_acc:36.765
# Best loss:0.571, Best accuracy:32.261, Best F1-score:0.271
# 5/300 lr=0.00100 - loss:0.471, acc:48.004, val_loss:0.518, val_acc:41.268
# Best loss:0.559, Best accuracy:36.765, Best F1-score:0.308
# 6/300 lr=0.00100 - loss:0.457, acc:48.227, val_loss:0.539, val_acc:35.202
# Best loss:0.518, Best accuracy:41.268, Best F1-score:0.361
# 7/300 lr=0.00100 - loss:0.446, acc:49.252, val_loss:0.503, val_acc:39.706
# Best loss:0.518, Best accuracy:41.268, Best F1-score:0.361
# 8/300 lr=0.00100 - loss:0.433, acc:51.103, val_loss:0.493, val_acc:42.831
# Best loss:0.503, Best accuracy:39.706, Best F1-score:0.361
# 9/300 lr=0.00100 - loss:0.426, acc:53.335, val_loss:0.488, val_acc:45.772
# Best loss:0.493, Best accuracy:42.831, Best F1-score:0.377
# 10/300 lr=0.00100 - loss:0.416, acc:53.952, val_loss:0.496, val_acc:34.007
# Best loss:0.488, Best accuracy:45.772, Best F1-score:0.400
# 11/300 lr=0.00100 - loss:0.416, acc:52.468, val_loss:0.478, val_acc:42.831
# Best loss:0.488, Best accuracy:45.772, Best F1-score:0.400
# 12/300 lr=0.00100 - loss:0.412, acc:55.173, val_loss:0.457, val_acc:48.713
# Best loss:0.478, Best accuracy:42.831, Best F1-score:0.384
# 13/300 lr=0.00100 - loss:0.415, acc:51.576, val_loss:0.460, val_acc:47.335
# Best loss:0.457, Best accuracy:48.713, Best F1-score:0.429
# 14/300 lr=0.00100 - loss:0.404, acc:56.907, val_loss:0.436, val_acc:53.401
# Best loss:0.457, Best accuracy:48.713, Best F1-score:0.429
# 15/300 lr=0.00100 - loss:0.401, acc:56.486, val_loss:0.452, val_acc:53.401
# Best loss:0.436, Best accuracy:53.401, Best F1-score:0.481
# 16/300 lr=0.00100 - loss:0.397, acc:58.351, val_loss:0.426, val_acc:57.904
# Best loss:0.436, Best accuracy:53.401, Best F1-score:0.481
# 17/300 lr=0.00100 - loss:0.385, acc:60.727, val_loss:0.414, val_acc:54.779
# Best loss:0.426, Best accuracy:57.904, Best F1-score:0.521
# 18/300 lr=0.00100 - loss:0.394, acc:58.692, val_loss:0.438, val_acc:48.897
# Best loss:0.414, Best accuracy:54.779, Best F1-score:0.498
# 19/300 lr=0.00100 - loss:0.389, acc:57.799, val_loss:0.432, val_acc:47.335
# Best loss:0.414, Best accuracy:54.779, Best F1-score:0.498
# 20/300 lr=0.00100 - loss:0.387, acc:60.334, val_loss:0.394, val_acc:56.342
# Best loss:0.414, Best accuracy:54.779, Best F1-score:0.498
# 21/300 lr=0.00100 - loss:0.377, acc:58.416, val_loss:0.418, val_acc:56.342
# Best loss:0.394, Best accuracy:56.342, Best F1-score:0.501
# 22/300 lr=0.00100 - loss:0.378, acc:59.808, val_loss:0.405, val_acc:50.460
# Best loss:0.394, Best accuracy:56.342, Best F1-score:0.501
# 23/300 lr=0.00100 - loss:0.363, acc:63.301, val_loss:0.404, val_acc:54.779
# Best loss:0.394, Best accuracy:56.342, Best F1-score:0.501
# 24/300 lr=0.00100 - loss:0.372, acc:58.390, val_loss:0.424, val_acc:41.452
# Best loss:0.394, Best accuracy:56.342, Best F1-score:0.501
# 25/300 lr=0.00100 - loss:0.360, acc:62.408, val_loss:0.392, val_acc:53.401
# Best loss:0.394, Best accuracy:56.342, Best F1-score:0.501
# 26/300 lr=0.00100 - loss:0.350, acc:65.284, val_loss:0.446, val_acc:41.452
# Best loss:0.392, Best accuracy:53.401, Best F1-score:0.502
# 27/300 lr=0.00100 - loss:0.354, acc:63.078, val_loss:0.380, val_acc:54.963
# Best loss:0.392, Best accuracy:53.401, Best F1-score:0.502
# 28/300 lr=0.00100 - loss:0.345, acc:65.783, val_loss:0.404, val_acc:53.401
# Best loss:0.380, Best accuracy:54.963, Best F1-score:0.483
# 29/300 lr=0.00100 - loss:0.347, acc:65.980, val_loss:0.367, val_acc:50.460
# Best loss:0.380, Best accuracy:54.963, Best F1-score:0.483
# 30/300 lr=0.00100 - loss:0.345, acc:63.524, val_loss:0.378, val_acc:54.963
# Best loss:0.367, Best accuracy:50.460, Best F1-score:0.471
# 31/300 lr=0.00100 - loss:0.340, acc:66.098, val_loss:0.409, val_acc:48.713
# Best loss:0.367, Best accuracy:50.460, Best F1-score:0.471
# 32/300 lr=0.00100 - loss:0.358, acc:62.408, val_loss:0.373, val_acc:56.526
# Best loss:0.367, Best accuracy:50.460, Best F1-score:0.471
# 33/300 lr=0.00100 - loss:0.336, acc:65.980, val_loss:0.364, val_acc:56.342
# Best loss:0.367, Best accuracy:50.460, Best F1-score:0.471
# 34/300 lr=0.00100 - loss:0.341, acc:65.533, val_loss:0.365, val_acc:54.779
# Best loss:0.364, Best accuracy:56.342, Best F1-score:0.552
# 35/300 lr=0.00100 - loss:0.322, acc:69.105, val_loss:0.335, val_acc:60.846
# Best loss:0.364, Best accuracy:56.342, Best F1-score:0.552
# 36/300 lr=0.00100 - loss:0.317, acc:68.632, val_loss:0.353, val_acc:54.963
# Best loss:0.335, Best accuracy:60.846, Best F1-score:0.585
# 37/300 lr=0.00100 - loss:0.320, acc:70.667, val_loss:0.334, val_acc:54.963
# Best loss:0.335, Best accuracy:60.846, Best F1-score:0.585
# 38/300 lr=0.00100 - loss:0.312, acc:72.203, val_loss:0.360, val_acc:50.460
# Best loss:0.334, Best accuracy:54.963, Best F1-score:0.519
# 39/300 lr=0.00100 - loss:0.309, acc:70.273, val_loss:0.349, val_acc:53.401
# Best loss:0.334, Best accuracy:54.963, Best F1-score:0.519
# 40/300 lr=0.00100 - loss:0.306, acc:69.997, val_loss:0.337, val_acc:56.526
# Best loss:0.334, Best accuracy:54.963, Best F1-score:0.519
# 41/300 lr=0.00100 - loss:0.313, acc:70.864, val_loss:0.322, val_acc:57.904
# Best loss:0.334, Best accuracy:54.963, Best F1-score:0.519
# 42/300 lr=0.00100 - loss:0.289, acc:74.383, val_loss:0.320, val_acc:59.467
# Best loss:0.322, Best accuracy:57.904, Best F1-score:0.553
# 43/300 lr=0.00100 - loss:0.309, acc:71.836, val_loss:0.286, val_acc:69.853
# Best loss:0.320, Best accuracy:59.467, Best F1-score:0.575
# 44/300 lr=0.00100 - loss:0.293, acc:72.348, val_loss:0.332, val_acc:59.467
# Best loss:0.286, Best accuracy:69.853, Best F1-score:0.671
# 45/300 lr=0.00100 - loss:0.286, acc:71.836, val_loss:0.314, val_acc:62.408
# Best loss:0.286, Best accuracy:69.853, Best F1-score:0.671
# 46/300 lr=0.00100 - loss:0.281, acc:75.853, val_loss:0.346, val_acc:59.467
# Best loss:0.286, Best accuracy:69.853, Best F1-score:0.671
# 47/300 lr=0.00100 - loss:0.305, acc:71.507, val_loss:0.333, val_acc:57.904
# Best loss:0.286, Best accuracy:69.853, Best F1-score:0.671
# 48/300 lr=0.00100 - loss:0.291, acc:71.809, val_loss:0.307, val_acc:59.283
# Best loss:0.286, Best accuracy:69.853, Best F1-score:0.671
# 49/300 lr=0.00100 - loss:0.276, acc:75.525, val_loss:0.303, val_acc:63.971
# Best loss:0.286, Best accuracy:69.853, Best F1-score:0.671
# 50/300 lr=0.00100 - loss:0.275, acc:75.853, val_loss:0.274, val_acc:69.669
# Best loss:0.286, Best accuracy:69.853, Best F1-score:0.671
# 51/300 lr=0.00100 - loss:0.272, acc:77.560, val_loss:0.298, val_acc:66.912
# Best loss:0.274, Best accuracy:69.669, Best F1-score:0.668
# 52/300 lr=0.00100 - loss:0.276, acc:75.775, val_loss:0.254, val_acc:71.232
# Best loss:0.274, Best accuracy:69.669, Best F1-score:0.668
# 53/300 lr=0.00100 - loss:0.271, acc:75.722, val_loss:0.248, val_acc:71.415
# Best loss:0.254, Best accuracy:71.232, Best F1-score:0.693
# 54/300 lr=0.00100 - loss:0.278, acc:74.540, val_loss:0.301, val_acc:63.971
# Best loss:0.248, Best accuracy:71.415, Best F1-score:0.688
# ...
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 185/300 lr=0.00035 - loss:0.119, acc:97.098, val_loss:0.225, val_acc:75.000
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 186/300 lr=0.00035 - loss:0.124, acc:97.321, val_loss:0.228, val_acc:73.438
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 187/300 lr=0.00035 - loss:0.120, acc:97.371, val_loss:0.207, val_acc:81.250
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 188/300 lr=0.00035 - loss:0.125, acc:95.908, val_loss:0.207, val_acc:78.125
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 189/300 lr=0.00035 - loss:0.119, acc:97.545, val_loss:0.213, val_acc:78.125
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 190/300 lr=0.00035 - loss:0.130, acc:96.032, val_loss:0.228, val_acc:75.000
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 191/300 lr=0.00035 - loss:0.123, acc:96.701, val_loss:0.232, val_acc:75.000
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 192/300 lr=0.00035 - loss:0.124, acc:96.429, val_loss:0.210, val_acc:78.125
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 193/300 lr=0.00035 - loss:0.113, acc:98.884, val_loss:0.214, val_acc:76.562
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 194/300 lr=0.00035 - loss:0.126, acc:96.652, val_loss:0.228, val_acc:76.562
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 195/300 lr=0.00035 - loss:0.122, acc:97.594, val_loss:0.214, val_acc:76.562
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 196/300 lr=0.00035 - loss:0.118, acc:97.545, val_loss:0.207, val_acc:81.250
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 197/300 lr=0.00035 - loss:0.121, acc:97.991, val_loss:0.215, val_acc:76.562
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 198/300 lr=0.00035 - loss:0.120, acc:97.098, val_loss:0.221, val_acc:79.688
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 199/300 lr=0.00035 - loss:0.120, acc:97.098, val_loss:0.200, val_acc:81.250
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 200/300 lr=0.00035 - loss:0.121, acc:97.321, val_loss:0.205, val_acc:81.250
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 201/300 lr=0.00035 - loss:0.120, acc:97.594, val_loss:0.237, val_acc:73.438
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 202/300 lr=0.00030 - loss:0.127, acc:95.982, val_loss:0.213, val_acc:81.250
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 203/300 lr=0.00030 - loss:0.126, acc:96.255, val_loss:0.194, val_acc:81.250
# Best loss:0.197, Best accuracy:79.688, Best F1-score:0.794
# 204/300 lr=0.00030 - loss:0.120, acc:97.321, val_loss:0.227, val_acc:75.000
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 205/300 lr=0.00030 - loss:0.124, acc:96.478, val_loss:0.241, val_acc:75.000
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 206/300 lr=0.00030 - loss:0.119, acc:97.768, val_loss:0.223, val_acc:78.125
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 207/300 lr=0.00030 - loss:0.122, acc:96.478, val_loss:0.209, val_acc:79.688
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 208/300 lr=0.00030 - loss:0.130, acc:96.032, val_loss:0.218, val_acc:75.000
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 209/300 lr=0.00030 - loss:0.124, acc:97.545, val_loss:0.233, val_acc:73.438
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 210/300 lr=0.00030 - loss:0.125, acc:96.875, val_loss:0.215, val_acc:76.562
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 211/300 lr=0.00030 - loss:0.117, acc:97.148, val_loss:0.203, val_acc:78.125
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 212/300 lr=0.00030 - loss:0.119, acc:96.875, val_loss:0.218, val_acc:75.000
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 213/300 lr=0.00030 - loss:0.122, acc:96.478, val_loss:0.229, val_acc:73.438
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 214/300 lr=0.00030 - loss:0.122, acc:97.098, val_loss:0.225, val_acc:73.438
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 215/300 lr=0.00030 - loss:0.121, acc:96.875, val_loss:0.216, val_acc:81.250
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 216/300 lr=0.00030 - loss:0.125, acc:96.478, val_loss:0.213, val_acc:81.250
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 217/300 lr=0.00030 - loss:0.120, acc:97.098, val_loss:0.198, val_acc:79.688
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 218/300 lr=0.00030 - loss:0.116, acc:98.214, val_loss:0.216, val_acc:79.688
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 219/300 lr=0.00030 - loss:0.111, acc:98.661, val_loss:0.225, val_acc:73.438
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 220/300 lr=0.00030 - loss:0.118, acc:97.768, val_loss:0.214, val_acc:78.125
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 221/300 lr=0.00030 - loss:0.122, acc:96.429, val_loss:0.222, val_acc:78.125
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 222/300 lr=0.00026 - loss:0.115, acc:97.371, val_loss:0.244, val_acc:73.438
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 223/300 lr=0.00026 - loss:0.120, acc:97.371, val_loss:0.227, val_acc:75.000
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 224/300 lr=0.00026 - loss:0.115, acc:97.768, val_loss:0.218, val_acc:76.562
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 225/300 lr=0.00026 - loss:0.118, acc:97.098, val_loss:0.246, val_acc:70.312
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 226/300 lr=0.00026 - loss:0.124, acc:96.205, val_loss:0.223, val_acc:76.562
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 227/300 lr=0.00026 - loss:0.128, acc:95.982, val_loss:0.244, val_acc:71.875
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 228/300 lr=0.00026 - loss:0.125, acc:95.908, val_loss:0.239, val_acc:73.438
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 229/300 lr=0.00026 - loss:0.124, acc:95.412, val_loss:0.225, val_acc:78.125
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 230/300 lr=0.00026 - loss:0.116, acc:97.768, val_loss:0.213, val_acc:75.000
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 231/300 lr=0.00026 - loss:0.124, acc:96.429, val_loss:0.242, val_acc:70.312
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
#
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 296/300 lr=0.00017 - loss:0.113, acc:97.817, val_loss:0.244, val_acc:78.125
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 297/300 lr=0.00017 - loss:0.108, acc:98.661, val_loss:0.226, val_acc:76.562
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 298/300 lr=0.00017 - loss:0.108, acc:99.107, val_loss:0.217, val_acc:75.000
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 299/300 lr=0.00017 - loss:0.112, acc:98.313, val_loss:0.227, val_acc:76.562
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# 300/300 lr=0.00017 - loss:0.112, acc:98.041, val_loss:0.233, val_acc:78.125
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.798
# ********************************************************************************
# [*] Done Fold-10
# best_val_loss:0.194, best_val_acc:81.250, best_val_f1:0.798
# test_acc:0.937, test_f1:0.936
# ********************************************************************************

# %%
end()

# %%
print('*' * 80)
print('[*] validation accuracy')
for i, val_acc in enumerate(fold_val_acc):
    print(f'    Fold-{i+1} : {val_acc}')
print(f'max:{max(fold_val_acc)}, min:{min(fold_val_acc)}, average:{sum(fold_val_acc)/len(fold_val_acc)}')
print('*' * 80)
print()

print('*' * 80)
print('[*] test accuracy')
for i, test_acc in enumerate(fold_test_acc):
    print(f'    Fold-{i+1} : {test_acc}')
print(f'max:{max(fold_test_acc)}, min:{min(fold_test_acc)}, average:{sum(fold_test_acc)/len(fold_test_acc)}')
print('*' * 80)
print()
# Out:
# ********************************************************************************
# [*] validation accuracy
#     Fold-1 : 89.24632370471954
#     Fold-2 : 87.86764740943909
#     Fold-3 : 89.0625
#     Fold-4 : 79.6875
#     Fold-5 : 75.0
#     Fold-6 : 92.1875
#     Fold-7 : 92.1875
#     Fold-8 : 90.625
#     Fold-9 : 92.1875
#     Fold-10 : 81.25
# max:92.1875, min:75.0, average:86.93014711141586
# ********************************************************************************
#
# ********************************************************************************
# [*] test accuracy
#     Fold-1 : 0.9136904776096344
#     Fold-2 : 0.8973214328289032
#     Fold-3 : 0.9449404776096344
#     Fold-4 : 0.8504464328289032
#     Fold-5 : 0.9293154776096344
#     Fold-6 : 0.9136904776096344
#     Fold-7 : 0.9055059552192688
#     Fold-8 : 0.8816964328289032
#     Fold-9 : 0.802827388048172
#     Fold-10 : 0.9367559552192688
# max:0.9449404776096344, min:0.802827388048172, average:0.8976190507411956
# ********************************************************************************

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
# Out:
# WAR(Weighted Average Recall)   : 87.85%
# UAR(Unweighted Average Recall) : 87.85%
