# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = 'TIMNET-dataset'
DATA_PATH = 'EMODB'
CLASS_LABELS = Config.EMODB_LABELS
k = 10

model_name = 'ablation study(remove spatial)'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding=padding),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule]),
        Lambda(function=PrimaryCapssquash)
    ])
    
  def call(self, inputs):
    return self.conv(inputs)

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.cbam = CBAM(64) # sharing
    
    self.primarycap = PrimaryCap()
    
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    x = inputs
    
    cap = self.conv1(x)
    cap = cap + self.cbam(cap)
    cap = self.conv2(cap)
    cap = cap + self.cbam(cap)
    
    primarycaps = self.primarycap(cap)
    cap = primarycaps
    
    sa = self.attention([primarycaps, primarycaps, primarycaps])
    sa = self.LN(sa)
    cap = self.lamb([cap, sa])
    
    capsule = self.capsule(cap)
    
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1416
#
#  sequential_1 (Sequential)   (None, 46, 7, 64)         37300
#
#  cbam (CBAM)                 multiple                  4294
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  attention (Attention)       multiple                  1
#
#  layer_normalization (LayerN  multiple                 128
#  ormalization)
#
#  lambda_1 (Lambda)           multiple                  0
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  455
#
# =================================================================
# Total params: 93,770
# Trainable params: 93,194
# Non-trainable params: 576
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}.npy', 'rb') as f:
    x = np.load(f)
    y = np.load(f)

y = to_categorical(y,num_classes=len(CLASS_LABELS))

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, test) in tqdm(enumerate(kfold.split(x, y)), desc=f'Training {k}-Fold.....'):
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = x[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_test, y_test = x[test], y[test]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_test = tf.expand_dims(x_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_test_loss = 0x3f3f3f
    best_test_acc = -1
    best_test_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        test_loss, test_acc, f1s = [], [], []
        for features, labels in batch_test:
            loss, acc, pred = test_step(model, features, labels)
            test_loss.append(loss)
            test_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(test_loss)/len(test_loss)
        val_acc = sum(test_acc)/len(test_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_test_loss:.3f}, Best accuracy:{best_test_acc:.3f}, Best F1-score:{best_test_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_test_acc < val_acc:
            best_test_acc = val_acc
            best_test_loss = val_loss
            best_test_f1 = f1_score
            model.save_weights(h5_path)
            
            
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    
    for features, labels in batch_test:
        best_pred = model(features, training=False)
        emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(labels, axis=1))
        predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
    
    
    print(f'[*] Done - acc:{best_test_acc:.3f}')
    
    plt.title(f'{i+1}-fold Loss Curve - Best acc:{best_test_acc:.3f}, Best loss:{best_test_loss:.3f}')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])

    
    save_fig_path = f'Fig/{DATA_PATH}/training/{model_name}'
    os.makedirs(save_fig_path, exist_ok=True)
    plt.savefig(f'{save_fig_path}/{i+1}-fold.PNG')
    
    plt.show()
    
    fold_acc.append(best_test_acc)
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.604, acc:23.242, val_loss:0.585, val_acc:30.824
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.573, acc:38.477, val_loss:0.550, val_acc:44.602
# Best loss:0.585, Best accuracy:30.824, Best F1-score:0.176
# 3/300 lr=0.00100 - loss:0.551, acc:38.672, val_loss:0.528, val_acc:44.602
# Best loss:0.550, Best accuracy:44.602, Best F1-score:0.320
# 4/300 lr=0.00100 - loss:0.520, acc:46.289, val_loss:0.505, val_acc:45.455
# Best loss:0.550, Best accuracy:44.602, Best F1-score:0.320
# 5/300 lr=0.00100 - loss:0.513, acc:41.797, val_loss:0.486, val_acc:47.017
# Best loss:0.505, Best accuracy:45.455, Best F1-score:0.324
# 6/300 lr=0.00100 - loss:0.487, acc:50.586, val_loss:0.477, val_acc:45.455
# Best loss:0.486, Best accuracy:47.017, Best F1-score:0.334
# 7/300 lr=0.00100 - loss:0.482, acc:51.172, val_loss:0.467, val_acc:45.455
# Best loss:0.486, Best accuracy:47.017, Best F1-score:0.334
# 8/300 lr=0.00100 - loss:0.460, acc:53.125, val_loss:0.451, val_acc:45.455
# Best loss:0.486, Best accuracy:47.017, Best F1-score:0.334
# 9/300 lr=0.00100 - loss:0.490, acc:47.852, val_loss:0.440, val_acc:49.290
# Best loss:0.486, Best accuracy:47.017, Best F1-score:0.334
# 10/300 lr=0.00100 - loss:0.464, acc:54.102, val_loss:0.440, val_acc:54.688
# Best loss:0.440, Best accuracy:49.290, Best F1-score:0.412
# 11/300 lr=0.00100 - loss:0.473, acc:47.266, val_loss:0.423, val_acc:47.727
# Best loss:0.440, Best accuracy:54.688, Best F1-score:0.473
# 12/300 lr=0.00100 - loss:0.460, acc:49.805, val_loss:0.433, val_acc:47.017
# Best loss:0.440, Best accuracy:54.688, Best F1-score:0.473
# 13/300 lr=0.00100 - loss:0.441, acc:54.297, val_loss:0.409, val_acc:55.398
# Best loss:0.440, Best accuracy:54.688, Best F1-score:0.473
# 14/300 lr=0.00100 - loss:0.456, acc:47.266, val_loss:0.402, val_acc:52.273
# Best loss:0.409, Best accuracy:55.398, Best F1-score:0.507
# 15/300 lr=0.00100 - loss:0.442, acc:50.000, val_loss:0.417, val_acc:56.250
# Best loss:0.409, Best accuracy:55.398, Best F1-score:0.507
# 16/300 lr=0.00100 - loss:0.410, acc:57.617, val_loss:0.389, val_acc:51.562
# Best loss:0.417, Best accuracy:56.250, Best F1-score:0.518
# 17/300 lr=0.00100 - loss:0.414, acc:59.766, val_loss:0.392, val_acc:54.688
# Best loss:0.417, Best accuracy:56.250, Best F1-score:0.518
# 18/300 lr=0.00100 - loss:0.433, acc:50.586, val_loss:0.390, val_acc:53.125
# Best loss:0.417, Best accuracy:56.250, Best F1-score:0.518
# 19/300 lr=0.00100 - loss:0.392, acc:58.203, val_loss:0.392, val_acc:59.375
# Best loss:0.417, Best accuracy:56.250, Best F1-score:0.518
# 20/300 lr=0.00100 - loss:0.405, acc:54.102, val_loss:0.366, val_acc:54.688
# Best loss:0.392, Best accuracy:59.375, Best F1-score:0.536
# 21/300 lr=0.00100 - loss:0.398, acc:60.547, val_loss:0.385, val_acc:57.102
# Best loss:0.392, Best accuracy:59.375, Best F1-score:0.536
# 22/300 lr=0.00100 - loss:0.400, acc:58.594, val_loss:0.365, val_acc:59.233
# Best loss:0.392, Best accuracy:59.375, Best F1-score:0.536
# 23/300 lr=0.00100 - loss:0.386, acc:59.570, val_loss:0.355, val_acc:56.250
# Best loss:0.392, Best accuracy:59.375, Best F1-score:0.536
# 24/300 lr=0.00100 - loss:0.425, acc:52.734, val_loss:0.380, val_acc:50.142
# Best loss:0.392, Best accuracy:59.375, Best F1-score:0.536
# 25/300 lr=0.00100 - loss:0.399, acc:55.469, val_loss:0.349, val_acc:64.631
# Best loss:0.392, Best accuracy:59.375, Best F1-score:0.536
# 26/300 lr=0.00100 - loss:0.392, acc:59.961, val_loss:0.349, val_acc:60.085
# Best loss:0.349, Best accuracy:64.631, Best F1-score:0.593
# 27/300 lr=0.00100 - loss:0.387, acc:60.547, val_loss:0.387, val_acc:54.830
# Best loss:0.349, Best accuracy:64.631, Best F1-score:0.593
# 28/300 lr=0.00100 - loss:0.415, acc:54.492, val_loss:0.389, val_acc:56.960
# Best loss:0.349, Best accuracy:64.631, Best F1-score:0.593
# 29/300 lr=0.00100 - loss:0.396, acc:55.469, val_loss:0.341, val_acc:62.216
# Best loss:0.349, Best accuracy:64.631, Best F1-score:0.593
# 30/300 lr=0.00100 - loss:0.389, acc:60.156, val_loss:0.348, val_acc:61.506
# Best loss:0.349, Best accuracy:64.631, Best F1-score:0.593
# 31/300 lr=0.00100 - loss:0.389, acc:60.547, val_loss:0.379, val_acc:57.102
# Best loss:0.349, Best accuracy:64.631, Best F1-score:0.593
# 32/300 lr=0.00100 - loss:0.413, acc:55.469, val_loss:0.350, val_acc:56.960
# Best loss:0.349, Best accuracy:64.631, Best F1-score:0.593
# 33/300 lr=0.00100 - loss:0.381, acc:61.914, val_loss:0.364, val_acc:59.943
# Best loss:0.349, Best accuracy:64.631, Best F1-score:0.593
# 34/300 lr=0.00100 - loss:0.392, acc:56.836, val_loss:0.333, val_acc:62.358
# Best loss:0.349, Best accuracy:64.631, Best F1-score:0.593
# 35/300 lr=0.00100 - loss:0.356, acc:64.258, val_loss:0.331, val_acc:67.756
# Best loss:0.349, Best accuracy:64.631, Best F1-score:0.593
# 36/300 lr=0.00100 - loss:0.387, acc:56.641, val_loss:0.322, val_acc:60.085
# Best loss:0.331, Best accuracy:67.756, Best F1-score:0.663
# 37/300 lr=0.00100 - loss:0.364, acc:63.672, val_loss:0.330, val_acc:68.466
# Best loss:0.331, Best accuracy:67.756, Best F1-score:0.663
# 38/300 lr=0.00100 - loss:0.384, acc:57.617, val_loss:0.317, val_acc:66.903
# Best loss:0.330, Best accuracy:68.466, Best F1-score:0.670
# 39/300 lr=0.00100 - loss:0.370, acc:62.109, val_loss:0.348, val_acc:55.540
# Best loss:0.330, Best accuracy:68.466, Best F1-score:0.670
# 40/300 lr=0.00100 - loss:0.399, acc:55.859, val_loss:0.342, val_acc:54.119
# Best loss:0.330, Best accuracy:68.466, Best F1-score:0.670
# 41/300 lr=0.00100 - loss:0.397, acc:55.859, val_loss:0.319, val_acc:66.903
# Best loss:0.330, Best accuracy:68.466, Best F1-score:0.670
# 42/300 lr=0.00100 - loss:0.381, acc:57.031, val_loss:0.306, val_acc:66.903
# Best loss:0.330, Best accuracy:68.466, Best F1-score:0.670
# 43/300 lr=0.00100 - loss:0.394, acc:60.742, val_loss:0.326, val_acc:67.045
# Best loss:0.330, Best accuracy:68.466, Best F1-score:0.670
# 44/300 lr=0.00100 - loss:0.353, acc:64.453, val_loss:0.300, val_acc:66.193
# Best loss:0.330, Best accuracy:68.466, Best F1-score:0.670
# 45/300 lr=0.00100 - loss:0.367, acc:60.938, val_loss:0.298, val_acc:72.301
# Best loss:0.330, Best accuracy:68.466, Best F1-score:0.670
# 46/300 lr=0.00100 - loss:0.362, acc:61.133, val_loss:0.327, val_acc:63.920
# Best loss:0.298, Best accuracy:72.301, Best F1-score:0.707
# 47/300 lr=0.00100 - loss:0.330, acc:70.312, val_loss:0.324, val_acc:61.648
# Best loss:0.298, Best accuracy:72.301, Best F1-score:0.707
# 48/300 lr=0.00100 - loss:0.356, acc:63.477, val_loss:0.310, val_acc:62.358
# Best loss:0.298, Best accuracy:72.301, Best F1-score:0.707
# 49/300 lr=0.00100 - loss:0.364, acc:60.547, val_loss:0.296, val_acc:67.756
# Best loss:0.298, Best accuracy:72.301, Best F1-score:0.707
# 50/300 lr=0.00100 - loss:0.318, acc:70.898, val_loss:0.296, val_acc:64.631
# Best loss:0.298, Best accuracy:72.301, Best F1-score:0.707
# 51/300 lr=0.00100 - loss:0.361, acc:63.477, val_loss:0.253, val_acc:73.864
# Best loss:0.298, Best accuracy:72.301, Best F1-score:0.707
# 52/300 lr=0.00100 - loss:0.331, acc:66.992, val_loss:0.258, val_acc:70.028
# Best loss:0.253, Best accuracy:73.864, Best F1-score:0.727
# 53/300 lr=0.00100 - loss:0.326, acc:66.406, val_loss:0.268, val_acc:73.153
# Best loss:0.253, Best accuracy:73.864, Best F1-score:0.727
# 54/300 lr=0.00100 - loss:0.315, acc:68.750, val_loss:0.277, val_acc:66.335
# Best loss:0.253, Best accuracy:73.864, Best F1-score:0.727
# 55/300 lr=0.00100 - loss:0.360, acc:62.500, val_loss:0.270, val_acc:76.136
# Best loss:0.253, Best accuracy:73.864, Best F1-score:0.727
# 56/300 lr=0.00100 - loss:0.315, acc:69.141, val_loss:0.277, val_acc:73.295
# Best loss:0.270, Best accuracy:76.136, Best F1-score:0.762
# 57/300 lr=0.00100 - loss:0.313, acc:67.969, val_loss:0.238, val_acc:75.426
# Best loss:0.270, Best accuracy:76.136, Best F1-score:0.762
# 58/300 lr=0.00100 - loss:0.343, acc:64.258, val_loss:0.263, val_acc:73.864
# Best loss:0.270, Best accuracy:76.136, Best F1-score:0.762
# 59/300 lr=0.00100 - loss:0.292, acc:75.195, val_loss:0.220, val_acc:81.534
# Best loss:0.270, Best accuracy:76.136, Best F1-score:0.762
# 60/300 lr=0.00100 - loss:0.294, acc:75.195, val_loss:0.227, val_acc:73.864
# Best loss:0.220, Best accuracy:81.534, Best F1-score:0.803
# 61/300 lr=0.00100 - loss:0.336, acc:65.625, val_loss:0.246, val_acc:79.972
# Best loss:0.220, Best accuracy:81.534, Best F1-score:0.803
# 62/300 lr=0.00086 - loss:0.291, acc:73.633, val_loss:0.248, val_acc:78.551
# Best loss:0.220, Best accuracy:81.534, Best F1-score:0.803
# 63/300 lr=0.00086 - loss:0.324, acc:66.992, val_loss:0.243, val_acc:78.551
# Best loss:0.220, Best accuracy:81.534, Best F1-score:0.803
# 64/300 lr=0.00086 - loss:0.302, acc:75.391, val_loss:0.254, val_acc:67.756
# Best loss:0.220, Best accuracy:81.534, Best F1-score:0.803
# 65/300 lr=0.00086 - loss:0.315, acc:67.383, val_loss:0.239, val_acc:71.449
# Best loss:0.220, Best accuracy:81.534, Best F1-score:0.803
# 66/300 lr=0.00086 - loss:0.321, acc:70.117, val_loss:0.215, val_acc:74.574
# Best loss:0.220, Best accuracy:81.534, Best F1-score:0.803
# 67/300 lr=0.00086 - loss:0.302, acc:67.188, val_loss:0.225, val_acc:71.449
# Best loss:0.220, Best accuracy:81.534, Best F1-score:0.803
# 68/300 lr=0.00086 - loss:0.299, acc:75.781, val_loss:0.237, val_acc:70.739
# Best loss:0.220, Best accuracy:81.534, Best F1-score:0.803
# 69/300 lr=0.00086 - loss:0.299, acc:72.266, val_loss:0.249, val_acc:74.006
# Best loss:0.220, Best accuracy:81.534, Best F1-score:0.803
# 70/300 lr=0.00086 - loss:0.293, acc:72.852, val_loss:0.259, val_acc:75.426
# Best loss:0.220, Best accuracy:81.534, Best F1-score:0.803
# 71/300 lr=0.00086 - loss:0.327, acc:68.555, val_loss:0.210, val_acc:77.699
# Best loss:0.220, Best accuracy:81.534, Best F1-score:0.803
# 72/300 lr=0.00086 - loss:0.324, acc:68.359, val_loss:0.235, val_acc:80.114
# Best loss:0.220, Best accuracy:81.534, Best F1-score:0.803
# 73/300 lr=0.00086 - loss:0.290, acc:67.578, val_loss:0.221, val_acc:81.676
# Best loss:0.220, Best accuracy:81.534, Best F1-score:0.803
# 74/300 lr=0.00086 - loss:0.315, acc:68.359, val_loss:0.259, val_acc:67.614
# Best loss:0.221, Best accuracy:81.676, Best F1-score:0.825
# 75/300 lr=0.00086 - loss:0.289, acc:73.242, val_loss:0.241, val_acc:73.153
# Best loss:0.221, Best accuracy:81.676, Best F1-score:0.825
# 76/300 lr=0.00086 - loss:0.316, acc:66.797, val_loss:0.218, val_acc:77.699
# Best loss:0.221, Best accuracy:81.676, Best F1-score:0.825
# 77/300 lr=0.00086 - loss:0.300, acc:74.414, val_loss:0.258, val_acc:66.903
# Best loss:0.221, Best accuracy:81.676, Best F1-score:0.825
# 78/300 lr=0.00086 - loss:0.285, acc:74.609, val_loss:0.206, val_acc:79.261
# Best loss:0.221, Best accuracy:81.676, Best F1-score:0.825
# 79/300 lr=0.00086 - loss:0.298, acc:71.289, val_loss:0.245, val_acc:71.733
# Best loss:0.221, Best accuracy:81.676, Best F1-score:0.825
# 80/300 lr=0.00086 - loss:0.303, acc:71.094, val_loss:0.211, val_acc:79.972
# Best loss:0.221, Best accuracy:81.676, Best F1-score:0.825
# 81/300 lr=0.00086 - loss:0.284, acc:75.000, val_loss:0.240, val_acc:73.722
# Best loss:0.221, Best accuracy:81.676, Best F1-score:0.825
# 82/300 lr=0.00074 - loss:0.275, acc:75.195, val_loss:0.216, val_acc:71.449
# Best loss:0.221, Best accuracy:81.676, Best F1-score:0.825
# 83/300 lr=0.00074 - loss:0.308, acc:69.336, val_loss:0.224, val_acc:77.841
# Best loss:0.221, Best accuracy:81.676, Best F1-score:0.825
# 84/300 lr=0.00074 - loss:0.272, acc:75.781, val_loss:0.223, val_acc:76.278
# Best loss:0.221, Best accuracy:81.676, Best F1-score:0.825
# 85/300 lr=0.00074 - loss:0.277, acc:76.953, val_loss:0.188, val_acc:83.097
# Best loss:0.221, Best accuracy:81.676, Best F1-score:0.825
# 86/300 lr=0.00074 - loss:0.265, acc:76.172, val_loss:0.210, val_acc:74.716
# Best loss:0.188, Best accuracy:83.097, Best F1-score:0.827
# 87/300 lr=0.00074 - loss:0.279, acc:71.484, val_loss:0.180, val_acc:79.261
# Best loss:0.188, Best accuracy:83.097, Best F1-score:0.827
# 88/300 lr=0.00074 - loss:0.258, acc:78.320, val_loss:0.196, val_acc:83.097
# Best loss:0.188, Best accuracy:83.097, Best F1-score:0.827
# 89/300 lr=0.00074 - loss:0.288, acc:72.070, val_loss:0.218, val_acc:80.824
# Best loss:0.188, Best accuracy:83.097, Best F1-score:0.827
# 90/300 lr=0.00074 - loss:0.252, acc:77.734, val_loss:0.207, val_acc:74.716
# Best loss:0.188, Best accuracy:83.097, Best F1-score:0.827
# 91/300 lr=0.00074 - loss:0.266, acc:75.781, val_loss:0.237, val_acc:75.426
# Best loss:0.188, Best accuracy:83.097, Best F1-score:0.827
# 92/300 lr=0.00074 - loss:0.301, acc:71.680, val_loss:0.192, val_acc:79.972
# Best loss:0.188, Best accuracy:83.097, Best F1-score:0.827
# 93/300 lr=0.00074 - loss:0.240, acc:81.836, val_loss:0.198, val_acc:71.449
# Best loss:0.188, Best accuracy:83.097, Best F1-score:0.827
# 94/300 lr=0.00074 - loss:0.257, acc:79.492, val_loss:0.177, val_acc:76.847
# Best loss:0.188, Best accuracy:83.097, Best F1-score:0.827
# 95/300 lr=0.00074 - loss:0.248, acc:78.125, val_loss:0.183, val_acc:81.534
# Best loss:0.188, Best accuracy:83.097, Best F1-score:0.827
# 96/300 lr=0.00074 - loss:0.256, acc:79.102, val_loss:0.162, val_acc:85.369
# Best loss:0.188, Best accuracy:83.097, Best F1-score:0.827
# 97/300 lr=0.00074 - loss:0.272, acc:75.195, val_loss:0.181, val_acc:79.972
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 98/300 lr=0.00074 - loss:0.242, acc:80.859, val_loss:0.188, val_acc:76.136
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 99/300 lr=0.00074 - loss:0.246, acc:80.273, val_loss:0.174, val_acc:77.699
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 100/300 lr=0.00074 - loss:0.242, acc:81.641, val_loss:0.219, val_acc:69.176
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 101/300 lr=0.00074 - loss:0.250, acc:76.172, val_loss:0.192, val_acc:81.534
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 102/300 lr=0.00064 - loss:0.277, acc:73.438, val_loss:0.191, val_acc:75.994
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 103/300 lr=0.00064 - loss:0.240, acc:80.469, val_loss:0.209, val_acc:73.864
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 104/300 lr=0.00064 - loss:0.288, acc:73.828, val_loss:0.207, val_acc:74.006
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 105/300 lr=0.00064 - loss:0.299, acc:73.438, val_loss:0.191, val_acc:81.534
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 106/300 lr=0.00064 - loss:0.246, acc:80.273, val_loss:0.179, val_acc:81.534
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 107/300 lr=0.00064 - loss:0.274, acc:75.391, val_loss:0.189, val_acc:84.659
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 108/300 lr=0.00064 - loss:0.255, acc:77.344, val_loss:0.184, val_acc:80.824
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 109/300 lr=0.00064 - loss:0.290, acc:75.391, val_loss:0.214, val_acc:71.449
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 110/300 lr=0.00064 - loss:0.250, acc:78.320, val_loss:0.216, val_acc:74.716
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 111/300 lr=0.00064 - loss:0.228, acc:81.641, val_loss:0.200, val_acc:76.136
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 112/300 lr=0.00064 - loss:0.243, acc:80.273, val_loss:0.186, val_acc:76.847
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 113/300 lr=0.00064 - loss:0.218, acc:83.594, val_loss:0.197, val_acc:79.261
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 114/300 lr=0.00064 - loss:0.216, acc:83.984, val_loss:0.183, val_acc:79.261
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 115/300 lr=0.00064 - loss:0.221, acc:82.617, val_loss:0.171, val_acc:84.659
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 116/300 lr=0.00064 - loss:0.216, acc:83.594, val_loss:0.178, val_acc:81.676
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 117/300 lr=0.00064 - loss:0.226, acc:83.008, val_loss:0.183, val_acc:76.136
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 118/300 lr=0.00064 - loss:0.222, acc:82.227, val_loss:0.173, val_acc:86.222
# Best loss:0.162, Best accuracy:85.369, Best F1-score:0.842
# 119/300 lr=0.00064 - loss:0.222, acc:84.375, val_loss:0.186, val_acc:71.591
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 120/300 lr=0.00064 - loss:0.246, acc:78.125, val_loss:0.187, val_acc:79.261
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 121/300 lr=0.00064 - loss:0.214, acc:84.375, val_loss:0.188, val_acc:79.972
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 122/300 lr=0.00055 - loss:0.220, acc:83.203, val_loss:0.184, val_acc:84.659
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 123/300 lr=0.00055 - loss:0.239, acc:77.734, val_loss:0.194, val_acc:71.591
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 124/300 lr=0.00055 - loss:0.220, acc:87.305, val_loss:0.200, val_acc:76.136
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 125/300 lr=0.00055 - loss:0.211, acc:83.594, val_loss:0.205, val_acc:76.847
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 126/300 lr=0.00055 - loss:0.229, acc:80.273, val_loss:0.185, val_acc:73.722
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 127/300 lr=0.00055 - loss:0.206, acc:85.156, val_loss:0.189, val_acc:75.426
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 128/300 lr=0.00055 - loss:0.196, acc:87.695, val_loss:0.177, val_acc:73.153
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 129/300 lr=0.00055 - loss:0.196, acc:88.281, val_loss:0.187, val_acc:77.699
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 130/300 lr=0.00055 - loss:0.215, acc:82.617, val_loss:0.178, val_acc:82.386
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 131/300 lr=0.00055 - loss:0.213, acc:86.523, val_loss:0.177, val_acc:75.426
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
#
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 261/300 lr=0.00022 - loss:0.155, acc:91.406, val_loss:0.161, val_acc:79.261
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 262/300 lr=0.00019 - loss:0.151, acc:93.164, val_loss:0.157, val_acc:79.261
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 263/300 lr=0.00019 - loss:0.150, acc:93.164, val_loss:0.155, val_acc:82.386
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 264/300 lr=0.00019 - loss:0.144, acc:94.141, val_loss:0.157, val_acc:87.784
# Best loss:0.173, Best accuracy:86.222, Best F1-score:0.849
# 265/300 lr=0.00019 - loss:0.165, acc:93.164, val_loss:0.160, val_acc:84.659
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 266/300 lr=0.00019 - loss:0.140, acc:94.922, val_loss:0.178, val_acc:76.136
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 267/300 lr=0.00019 - loss:0.160, acc:93.359, val_loss:0.173, val_acc:79.972
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 268/300 lr=0.00019 - loss:0.147, acc:93.945, val_loss:0.153, val_acc:83.097
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 269/300 lr=0.00019 - loss:0.156, acc:91.406, val_loss:0.148, val_acc:83.097
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 270/300 lr=0.00019 - loss:0.212, acc:85.742, val_loss:0.150, val_acc:81.534
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 271/300 lr=0.00019 - loss:0.141, acc:94.727, val_loss:0.166, val_acc:79.972
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 272/300 lr=0.00019 - loss:0.153, acc:93.164, val_loss:0.165, val_acc:84.659
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 273/300 lr=0.00019 - loss:0.148, acc:93.750, val_loss:0.154, val_acc:81.534
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 274/300 lr=0.00019 - loss:0.157, acc:92.383, val_loss:0.155, val_acc:79.261
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 275/300 lr=0.00019 - loss:0.142, acc:94.531, val_loss:0.154, val_acc:82.386
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 276/300 lr=0.00019 - loss:0.158, acc:92.773, val_loss:0.164, val_acc:82.386
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 277/300 lr=0.00019 - loss:0.144, acc:93.750, val_loss:0.166, val_acc:80.824
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 278/300 lr=0.00019 - loss:0.146, acc:94.531, val_loss:0.176, val_acc:79.261
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 279/300 lr=0.00019 - loss:0.147, acc:93.945, val_loss:0.188, val_acc:79.261
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 280/300 lr=0.00019 - loss:0.150, acc:92.578, val_loss:0.186, val_acc:75.426
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 281/300 lr=0.00019 - loss:0.144, acc:93.555, val_loss:0.163, val_acc:84.659
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 282/300 lr=0.00017 - loss:0.149, acc:93.555, val_loss:0.161, val_acc:82.386
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 283/300 lr=0.00017 - loss:0.140, acc:94.922, val_loss:0.159, val_acc:84.659
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 284/300 lr=0.00017 - loss:0.189, acc:86.914, val_loss:0.162, val_acc:83.097
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 285/300 lr=0.00017 - loss:0.159, acc:94.141, val_loss:0.162, val_acc:81.534
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 286/300 lr=0.00017 - loss:0.144, acc:93.750, val_loss:0.163, val_acc:83.097
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 287/300 lr=0.00017 - loss:0.140, acc:95.312, val_loss:0.166, val_acc:78.551
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 288/300 lr=0.00017 - loss:0.143, acc:93.555, val_loss:0.172, val_acc:81.534
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 289/300 lr=0.00017 - loss:0.139, acc:96.094, val_loss:0.175, val_acc:78.409
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 290/300 lr=0.00017 - loss:0.144, acc:93.164, val_loss:0.167, val_acc:81.534
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 291/300 lr=0.00017 - loss:0.144, acc:94.727, val_loss:0.162, val_acc:83.097
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 292/300 lr=0.00017 - loss:0.141, acc:94.922, val_loss:0.168, val_acc:77.699
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 293/300 lr=0.00017 - loss:0.148, acc:93.359, val_loss:0.184, val_acc:79.261
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 294/300 lr=0.00017 - loss:0.175, acc:87.305, val_loss:0.160, val_acc:82.386
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 295/300 lr=0.00017 - loss:0.146, acc:93.164, val_loss:0.157, val_acc:80.824
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 296/300 lr=0.00017 - loss:0.139, acc:94.922, val_loss:0.162, val_acc:77.699
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 297/300 lr=0.00017 - loss:0.153, acc:93.750, val_loss:0.171, val_acc:79.972
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 298/300 lr=0.00017 - loss:0.136, acc:95.898, val_loss:0.165, val_acc:82.386
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 299/300 lr=0.00017 - loss:0.144, acc:93.945, val_loss:0.158, val_acc:83.097
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# 300/300 lr=0.00017 - loss:0.140, acc:94.922, val_loss:0.166, val_acc:79.261
# Best loss:0.157, Best accuracy:87.784, Best F1-score:0.877
# [*] Done - acc:87.784
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.594, acc:26.562, val_loss:0.583, val_acc:30.682
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.565, acc:31.641, val_loss:0.558, val_acc:40.057
# Best loss:0.583, Best accuracy:30.682, Best F1-score:0.147
# 3/300 lr=0.00100 - loss:0.561, acc:36.719, val_loss:0.541, val_acc:47.727
# Best loss:0.558, Best accuracy:40.057, Best F1-score:0.277
# 4/300 lr=0.00100 - loss:0.537, acc:39.062, val_loss:0.522, val_acc:50.852
# Best loss:0.541, Best accuracy:47.727, Best F1-score:0.351
# 5/300 lr=0.00100 - loss:0.531, acc:39.844, val_loss:0.506, val_acc:49.290
# Best loss:0.522, Best accuracy:50.852, Best F1-score:0.375
# 6/300 lr=0.00100 - loss:0.521, acc:42.383, val_loss:0.490, val_acc:49.290
# Best loss:0.522, Best accuracy:50.852, Best F1-score:0.375
# 7/300 lr=0.00100 - loss:0.497, acc:47.266, val_loss:0.469, val_acc:50.852
# Best loss:0.522, Best accuracy:50.852, Best F1-score:0.375
# 8/300 lr=0.00100 - loss:0.484, acc:49.805, val_loss:0.459, val_acc:47.727
# Best loss:0.522, Best accuracy:50.852, Best F1-score:0.375
# 9/300 lr=0.00100 - loss:0.468, acc:53.125, val_loss:0.446, val_acc:50.852
# Best loss:0.522, Best accuracy:50.852, Best F1-score:0.375
# 10/300 lr=0.00100 - loss:0.457, acc:52.539, val_loss:0.441, val_acc:50.852
# Best loss:0.522, Best accuracy:50.852, Best F1-score:0.375
# 11/300 lr=0.00100 - loss:0.444, acc:53.320, val_loss:0.417, val_acc:53.125
# Best loss:0.522, Best accuracy:50.852, Best F1-score:0.375
# 12/300 lr=0.00100 - loss:0.469, acc:46.484, val_loss:0.412, val_acc:54.688
# Best loss:0.417, Best accuracy:53.125, Best F1-score:0.457
# 13/300 lr=0.00100 - loss:0.440, acc:54.102, val_loss:0.407, val_acc:48.580
# Best loss:0.412, Best accuracy:54.688, Best F1-score:0.465
# 14/300 lr=0.00100 - loss:0.451, acc:49.609, val_loss:0.393, val_acc:54.688
# Best loss:0.412, Best accuracy:54.688, Best F1-score:0.465
# 15/300 lr=0.00100 - loss:0.450, acc:50.977, val_loss:0.388, val_acc:52.415
# Best loss:0.412, Best accuracy:54.688, Best F1-score:0.465
# 16/300 lr=0.00100 - loss:0.430, acc:48.242, val_loss:0.391, val_acc:53.977
# Best loss:0.412, Best accuracy:54.688, Best F1-score:0.465
# 17/300 lr=0.00100 - loss:0.415, acc:57.617, val_loss:0.401, val_acc:46.307
# Best loss:0.412, Best accuracy:54.688, Best F1-score:0.465
# 18/300 lr=0.00100 - loss:0.431, acc:49.805, val_loss:0.388, val_acc:50.852
# Best loss:0.412, Best accuracy:54.688, Best F1-score:0.465
# 19/300 lr=0.00100 - loss:0.408, acc:57.422, val_loss:0.385, val_acc:47.017
# Best loss:0.412, Best accuracy:54.688, Best F1-score:0.465
# 20/300 lr=0.00100 - loss:0.433, acc:51.953, val_loss:0.377, val_acc:53.977
# Best loss:0.412, Best accuracy:54.688, Best F1-score:0.465
# 21/300 lr=0.00100 - loss:0.419, acc:50.195, val_loss:0.378, val_acc:48.438
# Best loss:0.412, Best accuracy:54.688, Best F1-score:0.465
# 22/300 lr=0.00100 - loss:0.439, acc:51.758, val_loss:0.365, val_acc:54.688
# Best loss:0.412, Best accuracy:54.688, Best F1-score:0.465
# 23/300 lr=0.00100 - loss:0.413, acc:53.711, val_loss:0.375, val_acc:45.455
# Best loss:0.412, Best accuracy:54.688, Best F1-score:0.465
# 24/300 lr=0.00100 - loss:0.382, acc:59.375, val_loss:0.361, val_acc:53.125
# Best loss:0.412, Best accuracy:54.688, Best F1-score:0.465
# 25/300 lr=0.00100 - loss:0.395, acc:59.961, val_loss:0.351, val_acc:57.670
# Best loss:0.412, Best accuracy:54.688, Best F1-score:0.465
# 26/300 lr=0.00100 - loss:0.385, acc:61.133, val_loss:0.353, val_acc:58.523
# Best loss:0.351, Best accuracy:57.670, Best F1-score:0.577
# 27/300 lr=0.00100 - loss:0.378, acc:61.719, val_loss:0.362, val_acc:56.250
# Best loss:0.353, Best accuracy:58.523, Best F1-score:0.577
# 28/300 lr=0.00100 - loss:0.376, acc:59.766, val_loss:0.348, val_acc:59.943
# Best loss:0.353, Best accuracy:58.523, Best F1-score:0.577
# 29/300 lr=0.00100 - loss:0.418, acc:54.883, val_loss:0.354, val_acc:54.545
# Best loss:0.348, Best accuracy:59.943, Best F1-score:0.584
# 30/300 lr=0.00100 - loss:0.374, acc:60.547, val_loss:0.343, val_acc:56.960
# Best loss:0.348, Best accuracy:59.943, Best F1-score:0.584
# 31/300 lr=0.00100 - loss:0.388, acc:62.109, val_loss:0.343, val_acc:54.688
# Best loss:0.348, Best accuracy:59.943, Best F1-score:0.584
# 32/300 lr=0.00100 - loss:0.357, acc:64.062, val_loss:0.335, val_acc:61.506
# Best loss:0.348, Best accuracy:59.943, Best F1-score:0.584
# 33/300 lr=0.00100 - loss:0.356, acc:62.109, val_loss:0.344, val_acc:55.398
# Best loss:0.335, Best accuracy:61.506, Best F1-score:0.598
# 34/300 lr=0.00100 - loss:0.351, acc:66.602, val_loss:0.315, val_acc:59.233
# Best loss:0.335, Best accuracy:61.506, Best F1-score:0.598
# 35/300 lr=0.00100 - loss:0.363, acc:60.547, val_loss:0.329, val_acc:58.523
# Best loss:0.335, Best accuracy:61.506, Best F1-score:0.598
# 36/300 lr=0.00100 - loss:0.406, acc:59.180, val_loss:0.323, val_acc:53.835
# Best loss:0.335, Best accuracy:61.506, Best F1-score:0.598
# 37/300 lr=0.00100 - loss:0.367, acc:57.422, val_loss:0.304, val_acc:63.778
# Best loss:0.335, Best accuracy:61.506, Best F1-score:0.598
# 38/300 lr=0.00100 - loss:0.386, acc:57.812, val_loss:0.297, val_acc:65.341
# Best loss:0.304, Best accuracy:63.778, Best F1-score:0.622
# 39/300 lr=0.00100 - loss:0.340, acc:66.992, val_loss:0.333, val_acc:54.688
# Best loss:0.297, Best accuracy:65.341, Best F1-score:0.644
# 40/300 lr=0.00100 - loss:0.349, acc:66.211, val_loss:0.295, val_acc:67.614
# Best loss:0.297, Best accuracy:65.341, Best F1-score:0.644
# 41/300 lr=0.00100 - loss:0.344, acc:65.820, val_loss:0.312, val_acc:60.795
# Best loss:0.295, Best accuracy:67.614, Best F1-score:0.674
# 42/300 lr=0.00100 - loss:0.347, acc:65.820, val_loss:0.303, val_acc:60.795
# Best loss:0.295, Best accuracy:67.614, Best F1-score:0.674
# 43/300 lr=0.00100 - loss:0.325, acc:69.141, val_loss:0.282, val_acc:67.614
# Best loss:0.295, Best accuracy:67.614, Best F1-score:0.674
# 44/300 lr=0.00100 - loss:0.358, acc:62.109, val_loss:0.286, val_acc:63.068
# Best loss:0.295, Best accuracy:67.614, Best F1-score:0.674
# 45/300 lr=0.00100 - loss:0.356, acc:61.133, val_loss:0.322, val_acc:55.398
# Best loss:0.295, Best accuracy:67.614, Best F1-score:0.674
# 46/300 lr=0.00100 - loss:0.360, acc:64.258, val_loss:0.276, val_acc:64.631
# Best loss:0.295, Best accuracy:67.614, Best F1-score:0.674
# 47/300 lr=0.00100 - loss:0.339, acc:69.336, val_loss:0.277, val_acc:66.903
# Best loss:0.295, Best accuracy:67.614, Best F1-score:0.674
# 48/300 lr=0.00100 - loss:0.314, acc:70.898, val_loss:0.269, val_acc:71.591
# Best loss:0.295, Best accuracy:67.614, Best F1-score:0.674
# 49/300 lr=0.00100 - loss:0.330, acc:66.406, val_loss:0.263, val_acc:65.341
# Best loss:0.269, Best accuracy:71.591, Best F1-score:0.728
# 50/300 lr=0.00100 - loss:0.303, acc:72.852, val_loss:0.283, val_acc:65.341
# Best loss:0.269, Best accuracy:71.591, Best F1-score:0.728
# 51/300 lr=0.00100 - loss:0.305, acc:72.266, val_loss:0.264, val_acc:66.193
# Best loss:0.269, Best accuracy:71.591, Best F1-score:0.728
# 52/300 lr=0.00100 - loss:0.312, acc:73.438, val_loss:0.268, val_acc:70.881
# Best loss:0.269, Best accuracy:71.591, Best F1-score:0.728
# 53/300 lr=0.00100 - loss:0.303, acc:71.875, val_loss:0.276, val_acc:71.591
# Best loss:0.269, Best accuracy:71.591, Best F1-score:0.728
# 54/300 lr=0.00100 - loss:0.326, acc:70.508, val_loss:0.245, val_acc:72.301
# Best loss:0.269, Best accuracy:71.591, Best F1-score:0.728
# 55/300 lr=0.00100 - loss:0.312, acc:73.438, val_loss:0.279, val_acc:68.466
# Best loss:0.245, Best accuracy:72.301, Best F1-score:0.733
# 56/300 lr=0.00100 - loss:0.323, acc:66.406, val_loss:0.285, val_acc:66.903
# Best loss:0.245, Best accuracy:72.301, Best F1-score:0.733
# ...
# 183/300 lr=0.00035 - loss:0.182, acc:88.086, val_loss:0.086, val_acc:91.295
# Best loss:0.085, Best accuracy:94.494, Best F1-score:0.942
# 184/300 lr=0.00035 - loss:0.159, acc:92.383, val_loss:0.098, val_acc:91.369
# Best loss:0.085, Best accuracy:94.494, Best F1-score:0.942
#
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 249/300 lr=0.00022 - loss:0.150, acc:94.141, val_loss:0.098, val_acc:89.732
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 250/300 lr=0.00022 - loss:0.138, acc:94.922, val_loss:0.095, val_acc:85.789
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 251/300 lr=0.00022 - loss:0.142, acc:94.531, val_loss:0.088, val_acc:89.732
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 252/300 lr=0.00022 - loss:0.134, acc:94.531, val_loss:0.097, val_acc:92.113
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 253/300 lr=0.00022 - loss:0.136, acc:94.922, val_loss:0.091, val_acc:88.170
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 254/300 lr=0.00022 - loss:0.142, acc:94.336, val_loss:0.096, val_acc:86.607
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 255/300 lr=0.00022 - loss:0.174, acc:90.820, val_loss:0.083, val_acc:93.676
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 256/300 lr=0.00022 - loss:0.143, acc:93.750, val_loss:0.100, val_acc:88.170
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 257/300 lr=0.00022 - loss:0.154, acc:92.969, val_loss:0.106, val_acc:84.226
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 258/300 lr=0.00022 - loss:0.140, acc:94.531, val_loss:0.103, val_acc:85.789
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 259/300 lr=0.00022 - loss:0.147, acc:94.922, val_loss:0.113, val_acc:83.408
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 260/300 lr=0.00022 - loss:0.139, acc:94.141, val_loss:0.090, val_acc:92.113
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 261/300 lr=0.00022 - loss:0.150, acc:90.820, val_loss:0.085, val_acc:92.113
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 262/300 lr=0.00019 - loss:0.137, acc:96.094, val_loss:0.106, val_acc:88.170
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 263/300 lr=0.00019 - loss:0.141, acc:93.945, val_loss:0.109, val_acc:85.789
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 264/300 lr=0.00019 - loss:0.147, acc:94.531, val_loss:0.096, val_acc:88.170
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 265/300 lr=0.00019 - loss:0.162, acc:90.625, val_loss:0.095, val_acc:88.988
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 266/300 lr=0.00019 - loss:0.157, acc:91.797, val_loss:0.105, val_acc:85.045
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 267/300 lr=0.00019 - loss:0.166, acc:91.406, val_loss:0.105, val_acc:86.607
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 268/300 lr=0.00019 - loss:0.138, acc:95.508, val_loss:0.083, val_acc:89.732
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 269/300 lr=0.00019 - loss:0.146, acc:94.922, val_loss:0.080, val_acc:94.494
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 270/300 lr=0.00019 - loss:0.147, acc:94.531, val_loss:0.092, val_acc:92.113
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 271/300 lr=0.00019 - loss:0.139, acc:95.117, val_loss:0.100, val_acc:88.170
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 272/300 lr=0.00019 - loss:0.147, acc:94.531, val_loss:0.094, val_acc:92.113
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 273/300 lr=0.00019 - loss:0.140, acc:95.312, val_loss:0.082, val_acc:92.113
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 274/300 lr=0.00019 - loss:0.145, acc:91.602, val_loss:0.097, val_acc:89.732
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 275/300 lr=0.00019 - loss:0.140, acc:94.531, val_loss:0.120, val_acc:85.789
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 276/300 lr=0.00019 - loss:0.139, acc:94.531, val_loss:0.125, val_acc:85.789
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 277/300 lr=0.00019 - loss:0.142, acc:93.750, val_loss:0.109, val_acc:85.789
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 278/300 lr=0.00019 - loss:0.153, acc:94.922, val_loss:0.088, val_acc:91.295
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 279/300 lr=0.00019 - loss:0.137, acc:95.898, val_loss:0.093, val_acc:89.732
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 280/300 lr=0.00019 - loss:0.133, acc:95.312, val_loss:0.108, val_acc:88.170
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 281/300 lr=0.00019 - loss:0.145, acc:92.969, val_loss:0.108, val_acc:85.789
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 282/300 lr=0.00017 - loss:0.152, acc:92.188, val_loss:0.102, val_acc:92.113
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 283/300 lr=0.00017 - loss:0.137, acc:94.141, val_loss:0.091, val_acc:92.113
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 284/300 lr=0.00017 - loss:0.129, acc:95.703, val_loss:0.093, val_acc:88.170
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 285/300 lr=0.00017 - loss:0.135, acc:94.727, val_loss:0.109, val_acc:84.226
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 286/300 lr=0.00017 - loss:0.136, acc:95.312, val_loss:0.103, val_acc:88.170
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 287/300 lr=0.00017 - loss:0.141, acc:94.922, val_loss:0.088, val_acc:92.113
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 288/300 lr=0.00017 - loss:0.137, acc:95.117, val_loss:0.087, val_acc:92.113
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 289/300 lr=0.00017 - loss:0.134, acc:94.727, val_loss:0.095, val_acc:89.732
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 290/300 lr=0.00017 - loss:0.141, acc:94.336, val_loss:0.103, val_acc:85.789
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 291/300 lr=0.00017 - loss:0.138, acc:95.508, val_loss:0.100, val_acc:88.170
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 292/300 lr=0.00017 - loss:0.132, acc:95.703, val_loss:0.087, val_acc:96.057
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 293/300 lr=0.00017 - loss:0.138, acc:95.703, val_loss:0.101, val_acc:89.732
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 294/300 lr=0.00017 - loss:0.134, acc:94.922, val_loss:0.112, val_acc:84.226
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 295/300 lr=0.00017 - loss:0.139, acc:95.117, val_loss:0.107, val_acc:89.732
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 296/300 lr=0.00017 - loss:0.139, acc:94.727, val_loss:0.085, val_acc:94.494
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 297/300 lr=0.00017 - loss:0.140, acc:93.555, val_loss:0.083, val_acc:92.932
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 298/300 lr=0.00017 - loss:0.134, acc:95.508, val_loss:0.096, val_acc:85.789
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 299/300 lr=0.00017 - loss:0.153, acc:91.602, val_loss:0.098, val_acc:89.732
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# 300/300 lr=0.00017 - loss:0.133, acc:95.312, val_loss:0.086, val_acc:92.113
# Best loss:0.077, Best accuracy:96.057, Best F1-score:0.957
# [*] Done - acc:96.057

# %%
end()

# %%
print(f'max:{max(fold_acc)}, min:{min(fold_acc)}, average:{sum(fold_acc)/len(fold_acc)}')
# Out:
# max:96.05654776096344, min:82.66369104385376, average:88.18046540021896

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
# Out:
# WAR(Weighted Average Recall)   : 87.11%
# UAR(Unweighted Average Recall) : 87.11%
