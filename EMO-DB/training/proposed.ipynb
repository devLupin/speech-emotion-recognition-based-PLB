# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = 'TIMNET-dataset'
DATA_PATH = 'EMODB'
CLASS_LABELS = Config.EMODB_LABELS
k = 10

# No-reverse : (196,39,1)  ## CA: Channel-attention    ## SA : Self-attention 
model_name = '(64 CNN, Last dilated)+CBAM+Depthwise-separable-Caps+CA+SA+CA+Capsule+CA'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding=padding),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule]),
        Lambda(function=PrimaryCapssquash)
    ])
    
  def call(self, inputs):
    return self.conv(inputs)

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.cbam = CBAM(64) # sharing
    
    self.primarycap = PrimaryCap()
    self.spatial_attn = SpatialGate()
    
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    x = inputs
    
    cap = self.conv1(x)
    cap = cap + self.cbam(cap)
    cap = self.conv2(cap)
    cap = cap + self.cbam(cap)
    
    primarycaps = self.primarycap(cap)
    primarycaps = tf.expand_dims(primarycaps, axis=-1)
    primarycaps = primarycaps + self.spatial_attn(primarycaps)
    primarycaps = tf.squeeze(primarycaps, axis=-1)
    
    cap = primarycaps
    
    sa = self.attention([primarycaps, primarycaps, primarycaps])
    sa = self.LN(sa)
    
    sa = tf.expand_dims(sa, axis=-1)
    sa = sa + self.spatial_attn(sa)
    sa = tf.squeeze(sa, axis=-1)
    
    cap = self.lamb([cap, sa])
    cap = tf.expand_dims(cap, axis=-1)
    cap = cap + self.spatial_attn(cap)
    cap = tf.squeeze(cap, axis=-1)
    
    capsule = self.capsule(cap)
    capsule = tf.expand_dims(capsule, axis=-1)
    capsule = capsule + self.spatial_attn(capsule)
    capsule = tf.squeeze(capsule, axis=-1)
    
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1416
#
#  sequential_1 (Sequential)   (None, 46, 7, 64)         37300
#
#  cbam (CBAM)                 multiple                  4294
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  spatial_gate_1 (SpatialGate  multiple                 102
#  )
#
#  attention (Attention)       multiple                  1
#
#  layer_normalization (LayerN  multiple                 128
#  ormalization)
#
#  lambda_1 (Lambda)           multiple                  0
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  455
#
# =================================================================
# Total params: 93,872
# Trainable params: 93,294
# Non-trainable params: 578
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}.npy', 'rb') as f:
    x = np.load(f)
    y = np.load(f)

y = to_categorical(y,num_classes=len(CLASS_LABELS))

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, test) in tqdm(enumerate(kfold.split(x, y)), desc=f'Training {k}-Fold.....'):
    # if i < 6:
    #     continue
    
    now_time = datetime.now().strftime("%m-%d-%H%M%S")
    
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = x[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_test, y_test = x[test], y[test]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_test = tf.expand_dims(x_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_test_loss = 0x3f3f3f
    best_test_acc = -1
    best_test_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        test_loss, test_acc, f1s = [], [], []
        for features, labels in batch_test:
            loss, acc, pred = test_step(model, features, labels)
            test_loss.append(loss)
            test_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(test_loss)/len(test_loss)
        val_acc = sum(test_acc)/len(test_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_test_loss:.3f}, Best accuracy:{best_test_acc:.3f}, Best F1-score:{best_test_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_test_acc < val_acc:
            best_test_acc = val_acc
            best_test_loss = val_loss
            best_test_f1 = f1_score
            model.save_weights(h5_path)
            
            
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    best_pred = model(x_test, training=False)
    emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(y_test, axis=1))
    predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
    
    
    print(f'[*] Done - acc:{best_test_acc:.3f}')
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    fold_acc.append(best_test_acc)
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.592, acc:29.883, val_loss:0.569, val_acc:38.636
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.545, acc:42.188, val_loss:0.537, val_acc:37.074
# Best loss:0.569, Best accuracy:38.636, Best F1-score:0.255
# 3/300 lr=0.00100 - loss:0.509, acc:41.797, val_loss:0.507, val_acc:43.892
# Best loss:0.569, Best accuracy:38.636, Best F1-score:0.255
# 4/300 lr=0.00100 - loss:0.476, acc:49.609, val_loss:0.478, val_acc:42.472
# Best loss:0.507, Best accuracy:43.892, Best F1-score:0.322
# 5/300 lr=0.00100 - loss:0.467, acc:46.680, val_loss:0.471, val_acc:47.017
# Best loss:0.507, Best accuracy:43.892, Best F1-score:0.322
# 6/300 lr=0.00100 - loss:0.439, acc:53.125, val_loss:0.457, val_acc:45.455
# Best loss:0.471, Best accuracy:47.017, Best F1-score:0.394
# 7/300 lr=0.00100 - loss:0.447, acc:47.852, val_loss:0.432, val_acc:44.744
# Best loss:0.471, Best accuracy:47.017, Best F1-score:0.394
# 8/300 lr=0.00100 - loss:0.419, acc:54.492, val_loss:0.415, val_acc:47.017
# Best loss:0.471, Best accuracy:47.017, Best F1-score:0.394
# 9/300 lr=0.00100 - loss:0.450, acc:51.172, val_loss:0.439, val_acc:44.034
# Best loss:0.471, Best accuracy:47.017, Best F1-score:0.394
# 10/300 lr=0.00100 - loss:0.433, acc:53.125, val_loss:0.394, val_acc:50.142
# Best loss:0.471, Best accuracy:47.017, Best F1-score:0.394
# 11/300 lr=0.00100 - loss:0.444, acc:47.656, val_loss:0.395, val_acc:43.892
# Best loss:0.394, Best accuracy:50.142, Best F1-score:0.458
# 12/300 lr=0.00100 - loss:0.437, acc:47.656, val_loss:0.388, val_acc:49.290
# Best loss:0.394, Best accuracy:50.142, Best F1-score:0.458
# 13/300 lr=0.00100 - loss:0.416, acc:57.031, val_loss:0.378, val_acc:53.835
# Best loss:0.394, Best accuracy:50.142, Best F1-score:0.458
# 14/300 lr=0.00100 - loss:0.413, acc:54.492, val_loss:0.367, val_acc:54.688
# Best loss:0.378, Best accuracy:53.835, Best F1-score:0.483
# 15/300 lr=0.00100 - loss:0.406, acc:52.148, val_loss:0.389, val_acc:56.250
# Best loss:0.367, Best accuracy:54.688, Best F1-score:0.487
# 16/300 lr=0.00100 - loss:0.384, acc:58.398, val_loss:0.352, val_acc:58.523
# Best loss:0.389, Best accuracy:56.250, Best F1-score:0.535
# 17/300 lr=0.00100 - loss:0.381, acc:60.938, val_loss:0.369, val_acc:54.688
# Best loss:0.352, Best accuracy:58.523, Best F1-score:0.553
# 18/300 lr=0.00100 - loss:0.401, acc:54.688, val_loss:0.332, val_acc:65.341
# Best loss:0.352, Best accuracy:58.523, Best F1-score:0.553
# 19/300 lr=0.00100 - loss:0.375, acc:61.719, val_loss:0.397, val_acc:48.580
# Best loss:0.332, Best accuracy:65.341, Best F1-score:0.620
# 20/300 lr=0.00100 - loss:0.386, acc:63.086, val_loss:0.321, val_acc:60.085
# Best loss:0.332, Best accuracy:65.341, Best F1-score:0.620
# 21/300 lr=0.00100 - loss:0.371, acc:62.891, val_loss:0.352, val_acc:59.943
# Best loss:0.332, Best accuracy:65.341, Best F1-score:0.620
# 22/300 lr=0.00100 - loss:0.370, acc:62.305, val_loss:0.317, val_acc:66.903
# Best loss:0.332, Best accuracy:65.341, Best F1-score:0.620
# 23/300 lr=0.00100 - loss:0.353, acc:62.500, val_loss:0.316, val_acc:63.778
# Best loss:0.317, Best accuracy:66.903, Best F1-score:0.651
# 24/300 lr=0.00100 - loss:0.377, acc:55.273, val_loss:0.302, val_acc:64.773
# Best loss:0.317, Best accuracy:66.903, Best F1-score:0.651
# 25/300 lr=0.00100 - loss:0.356, acc:65.234, val_loss:0.311, val_acc:70.739
# Best loss:0.317, Best accuracy:66.903, Best F1-score:0.651
# 26/300 lr=0.00100 - loss:0.364, acc:58.789, val_loss:0.293, val_acc:75.284
# Best loss:0.311, Best accuracy:70.739, Best F1-score:0.694
# 27/300 lr=0.00100 - loss:0.374, acc:61.133, val_loss:0.332, val_acc:59.233
# Best loss:0.293, Best accuracy:75.284, Best F1-score:0.737
# 28/300 lr=0.00100 - loss:0.392, acc:57.812, val_loss:0.298, val_acc:63.068
# Best loss:0.293, Best accuracy:75.284, Best F1-score:0.737
# 29/300 lr=0.00100 - loss:0.356, acc:64.844, val_loss:0.301, val_acc:72.159
# Best loss:0.293, Best accuracy:75.284, Best F1-score:0.737
# 30/300 lr=0.00100 - loss:0.334, acc:67.383, val_loss:0.291, val_acc:72.301
# Best loss:0.293, Best accuracy:75.284, Best F1-score:0.737
# 31/300 lr=0.00100 - loss:0.352, acc:62.695, val_loss:0.306, val_acc:69.176
# Best loss:0.293, Best accuracy:75.284, Best F1-score:0.737
# 32/300 lr=0.00100 - loss:0.329, acc:67.773, val_loss:0.272, val_acc:72.301
# Best loss:0.293, Best accuracy:75.284, Best F1-score:0.737
# 33/300 lr=0.00100 - loss:0.326, acc:66.797, val_loss:0.305, val_acc:69.176
# Best loss:0.293, Best accuracy:75.284, Best F1-score:0.737
# 34/300 lr=0.00100 - loss:0.349, acc:62.500, val_loss:0.278, val_acc:70.028
# Best loss:0.293, Best accuracy:75.284, Best F1-score:0.737
# 35/300 lr=0.00100 - loss:0.308, acc:71.875, val_loss:0.317, val_acc:66.761
# Best loss:0.293, Best accuracy:75.284, Best F1-score:0.737
# 36/300 lr=0.00100 - loss:0.320, acc:69.922, val_loss:0.257, val_acc:74.574
# Best loss:0.293, Best accuracy:75.284, Best F1-score:0.737
# 37/300 lr=0.00100 - loss:0.335, acc:71.289, val_loss:0.302, val_acc:60.795
# Best loss:0.293, Best accuracy:75.284, Best F1-score:0.737
# 38/300 lr=0.00100 - loss:0.310, acc:70.312, val_loss:0.270, val_acc:71.449
# Best loss:0.293, Best accuracy:75.284, Best F1-score:0.737
# 39/300 lr=0.00100 - loss:0.330, acc:65.625, val_loss:0.268, val_acc:71.591
# Best loss:0.293, Best accuracy:75.284, Best F1-score:0.737
# 40/300 lr=0.00100 - loss:0.362, acc:61.914, val_loss:0.304, val_acc:66.335
# Best loss:0.293, Best accuracy:75.284, Best F1-score:0.737
# 41/300 lr=0.00100 - loss:0.348, acc:65.820, val_loss:0.238, val_acc:77.699
# Best loss:0.293, Best accuracy:75.284, Best F1-score:0.737
# 42/300 lr=0.00100 - loss:0.316, acc:71.289, val_loss:0.267, val_acc:66.051
# Best loss:0.238, Best accuracy:77.699, Best F1-score:0.764
# 43/300 lr=0.00100 - loss:0.320, acc:66.992, val_loss:0.277, val_acc:70.881
# Best loss:0.238, Best accuracy:77.699, Best F1-score:0.764
# 44/300 lr=0.00100 - loss:0.327, acc:68.945, val_loss:0.253, val_acc:74.574
# Best loss:0.238, Best accuracy:77.699, Best F1-score:0.764
# 45/300 lr=0.00100 - loss:0.345, acc:63.086, val_loss:0.249, val_acc:72.301
# Best loss:0.238, Best accuracy:77.699, Best F1-score:0.764
# 46/300 lr=0.00100 - loss:0.332, acc:66.211, val_loss:0.277, val_acc:67.756
# Best loss:0.238, Best accuracy:77.699, Best F1-score:0.764
# 47/300 lr=0.00100 - loss:0.304, acc:71.484, val_loss:0.269, val_acc:71.591
# Best loss:0.238, Best accuracy:77.699, Best F1-score:0.764
# 48/300 lr=0.00100 - loss:0.326, acc:64.844, val_loss:0.266, val_acc:67.614
# Best loss:0.238, Best accuracy:77.699, Best F1-score:0.764
# 49/300 lr=0.00100 - loss:0.329, acc:67.383, val_loss:0.263, val_acc:71.591
# Best loss:0.238, Best accuracy:77.699, Best F1-score:0.764
# 50/300 lr=0.00100 - loss:0.298, acc:72.266, val_loss:0.262, val_acc:73.864
# Best loss:0.238, Best accuracy:77.699, Best F1-score:0.764
# 51/300 lr=0.00100 - loss:0.308, acc:67.383, val_loss:0.239, val_acc:74.574
# Best loss:0.238, Best accuracy:77.699, Best F1-score:0.764
# 52/300 lr=0.00100 - loss:0.275, acc:75.000, val_loss:0.240, val_acc:75.284
# Best loss:0.238, Best accuracy:77.699, Best F1-score:0.764
# 53/300 lr=0.00100 - loss:0.312, acc:66.797, val_loss:0.246, val_acc:75.426
# Best loss:0.238, Best accuracy:77.699, Best F1-score:0.764
# 54/300 lr=0.00100 - loss:0.284, acc:72.070, val_loss:0.267, val_acc:75.568
# Best loss:0.238, Best accuracy:77.699, Best F1-score:0.764
# 55/300 lr=0.00100 - loss:0.321, acc:66.211, val_loss:0.235, val_acc:79.972
# Best loss:0.238, Best accuracy:77.699, Best F1-score:0.764
# 56/300 lr=0.00100 - loss:0.288, acc:71.289, val_loss:0.262, val_acc:69.886
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 57/300 lr=0.00100 - loss:0.274, acc:76.953, val_loss:0.222, val_acc:77.699
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 58/300 lr=0.00100 - loss:0.305, acc:66.016, val_loss:0.231, val_acc:76.136
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 59/300 lr=0.00100 - loss:0.257, acc:78.516, val_loss:0.227, val_acc:74.574
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 60/300 lr=0.00100 - loss:0.277, acc:75.781, val_loss:0.218, val_acc:79.972
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 61/300 lr=0.00100 - loss:0.271, acc:75.781, val_loss:0.221, val_acc:77.699
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 62/300 lr=0.00086 - loss:0.271, acc:70.703, val_loss:0.229, val_acc:74.716
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 63/300 lr=0.00086 - loss:0.310, acc:70.703, val_loss:0.219, val_acc:74.574
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 64/300 lr=0.00086 - loss:0.273, acc:72.070, val_loss:0.227, val_acc:70.881
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 65/300 lr=0.00086 - loss:0.249, acc:77.734, val_loss:0.209, val_acc:74.574
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 66/300 lr=0.00086 - loss:0.274, acc:75.391, val_loss:0.215, val_acc:76.136
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 67/300 lr=0.00086 - loss:0.253, acc:78.711, val_loss:0.224, val_acc:72.159
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 68/300 lr=0.00086 - loss:0.259, acc:77.930, val_loss:0.220, val_acc:75.426
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 69/300 lr=0.00086 - loss:0.294, acc:74.219, val_loss:0.231, val_acc:74.574
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 70/300 lr=0.00086 - loss:0.247, acc:79.688, val_loss:0.221, val_acc:71.591
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 71/300 lr=0.00086 - loss:0.241, acc:80.859, val_loss:0.211, val_acc:75.426
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 72/300 lr=0.00086 - loss:0.252, acc:81.250, val_loss:0.206, val_acc:75.426
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 73/300 lr=0.00086 - loss:0.242, acc:80.469, val_loss:0.214, val_acc:74.574
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 74/300 lr=0.00086 - loss:0.249, acc:74.414, val_loss:0.206, val_acc:73.011
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 75/300 lr=0.00086 - loss:0.253, acc:79.297, val_loss:0.228, val_acc:75.426
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 76/300 lr=0.00086 - loss:0.259, acc:77.148, val_loss:0.195, val_acc:77.557
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 77/300 lr=0.00086 - loss:0.260, acc:79.297, val_loss:0.221, val_acc:73.722
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 78/300 lr=0.00086 - loss:0.229, acc:82.812, val_loss:0.215, val_acc:76.989
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 79/300 lr=0.00086 - loss:0.233, acc:80.469, val_loss:0.230, val_acc:75.426
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 80/300 lr=0.00086 - loss:0.239, acc:82.617, val_loss:0.224, val_acc:69.176
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 81/300 lr=0.00086 - loss:0.236, acc:80.078, val_loss:0.220, val_acc:72.301
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 82/300 lr=0.00074 - loss:0.220, acc:84.375, val_loss:0.210, val_acc:76.989
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 83/300 lr=0.00074 - loss:0.240, acc:76.367, val_loss:0.207, val_acc:72.301
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 84/300 lr=0.00074 - loss:0.241, acc:78.711, val_loss:0.235, val_acc:69.176
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 85/300 lr=0.00074 - loss:0.227, acc:82.812, val_loss:0.209, val_acc:76.278
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 86/300 lr=0.00074 - loss:0.219, acc:82.617, val_loss:0.219, val_acc:72.301
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 87/300 lr=0.00074 - loss:0.228, acc:80.469, val_loss:0.206, val_acc:78.409
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 88/300 lr=0.00074 - loss:0.218, acc:83.203, val_loss:0.212, val_acc:76.989
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 89/300 lr=0.00074 - loss:0.237, acc:80.664, val_loss:0.217, val_acc:72.301
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 90/300 lr=0.00074 - loss:0.244, acc:78.516, val_loss:0.198, val_acc:76.989
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 91/300 lr=0.00074 - loss:0.210, acc:83.398, val_loss:0.220, val_acc:76.989
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 92/300 lr=0.00074 - loss:0.226, acc:81.055, val_loss:0.216, val_acc:73.011
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 93/300 lr=0.00074 - loss:0.213, acc:84.375, val_loss:0.199, val_acc:73.864
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 94/300 lr=0.00074 - loss:0.239, acc:76.172, val_loss:0.203, val_acc:80.114
# Best loss:0.235, Best accuracy:79.972, Best F1-score:0.794
# 95/300 lr=0.00074 - loss:0.216, acc:83.203, val_loss:0.199, val_acc:79.261
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 96/300 lr=0.00074 - loss:0.220, acc:82.031, val_loss:0.211, val_acc:73.864
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 97/300 lr=0.00074 - loss:0.215, acc:83.594, val_loss:0.206, val_acc:76.278
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 98/300 lr=0.00074 - loss:0.225, acc:81.250, val_loss:0.193, val_acc:79.261
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 99/300 lr=0.00074 - loss:0.217, acc:82.227, val_loss:0.200, val_acc:77.699
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 100/300 lr=0.00074 - loss:0.211, acc:83.398, val_loss:0.235, val_acc:73.864
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 101/300 lr=0.00074 - loss:0.213, acc:84.375, val_loss:0.213, val_acc:73.011
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 102/300 lr=0.00064 - loss:0.224, acc:82.617, val_loss:0.220, val_acc:74.432
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 103/300 lr=0.00064 - loss:0.203, acc:86.523, val_loss:0.206, val_acc:79.261
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 104/300 lr=0.00064 - loss:0.204, acc:85.938, val_loss:0.226, val_acc:77.699
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 105/300 lr=0.00064 - loss:0.256, acc:77.344, val_loss:0.222, val_acc:73.153
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 106/300 lr=0.00064 - loss:0.205, acc:84.375, val_loss:0.197, val_acc:76.278
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 107/300 lr=0.00064 - loss:0.252, acc:80.078, val_loss:0.215, val_acc:73.864
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 108/300 lr=0.00064 - loss:0.199, acc:86.328, val_loss:0.197, val_acc:76.989
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 109/300 lr=0.00064 - loss:0.209, acc:84.961, val_loss:0.214, val_acc:71.591
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 110/300 lr=0.00064 - loss:0.226, acc:78.516, val_loss:0.191, val_acc:77.699
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 111/300 lr=0.00064 - loss:0.201, acc:85.742, val_loss:0.186, val_acc:80.682
# Best loss:0.203, Best accuracy:80.114, Best F1-score:0.811
# 112/300 lr=0.00064 - loss:0.209, acc:84.375, val_loss:0.215, val_acc:68.466
# Best loss:0.186, Best accuracy:80.682, Best F1-score:0.805
# 113/300 lr=0.00064 - loss:0.198, acc:85.547, val_loss:0.201, val_acc:83.097
# Best loss:0.186, Best accuracy:80.682, Best F1-score:0.805
# 114/300 lr=0.00064 - loss:0.197, acc:86.328, val_loss:0.193, val_acc:76.136
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 115/300 lr=0.00064 - loss:0.206, acc:85.742, val_loss:0.219, val_acc:71.591
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 116/300 lr=0.00064 - loss:0.185, acc:89.258, val_loss:0.203, val_acc:75.426
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 117/300 lr=0.00064 - loss:0.214, acc:78.711, val_loss:0.190, val_acc:75.426
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 118/300 lr=0.00064 - loss:0.193, acc:85.938, val_loss:0.195, val_acc:74.574
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 119/300 lr=0.00064 - loss:0.194, acc:86.328, val_loss:0.198, val_acc:76.136
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 120/300 lr=0.00064 - loss:0.207, acc:85.352, val_loss:0.179, val_acc:74.716
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 121/300 lr=0.00064 - loss:0.200, acc:85.156, val_loss:0.208, val_acc:75.426
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 122/300 lr=0.00055 - loss:0.196, acc:85.938, val_loss:0.175, val_acc:79.972
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 123/300 lr=0.00055 - loss:0.239, acc:80.078, val_loss:0.191, val_acc:76.989
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 124/300 lr=0.00055 - loss:0.199, acc:85.352, val_loss:0.203, val_acc:75.426
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 125/300 lr=0.00055 - loss:0.197, acc:86.133, val_loss:0.190, val_acc:76.989
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 126/300 lr=0.00055 - loss:0.218, acc:80.078, val_loss:0.214, val_acc:70.739
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 127/300 lr=0.00055 - loss:0.185, acc:89.258, val_loss:0.214, val_acc:77.699
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 128/300 lr=0.00055 - loss:0.199, acc:86.133, val_loss:0.207, val_acc:76.989
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 129/300 lr=0.00055 - loss:0.195, acc:87.109, val_loss:0.232, val_acc:69.318
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 130/300 lr=0.00055 - loss:0.199, acc:87.891, val_loss:0.180, val_acc:76.136
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 131/300 lr=0.00055 - loss:0.188, acc:89.453, val_loss:0.192, val_acc:79.261
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
# 132/300 lr=0.00055 - loss:0.183, acc:88.086, val_loss:0.214, val_acc:76.278
# Best loss:0.201, Best accuracy:83.097, Best F1-score:0.826
#
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 273/300 lr=0.00019 - loss:0.125, acc:97.461, val_loss:0.185, val_acc:79.261
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 274/300 lr=0.00019 - loss:0.125, acc:96.094, val_loss:0.182, val_acc:82.386
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 275/300 lr=0.00019 - loss:0.126, acc:95.898, val_loss:0.186, val_acc:82.386
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 276/300 lr=0.00019 - loss:0.133, acc:95.312, val_loss:0.192, val_acc:80.114
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 277/300 lr=0.00019 - loss:0.123, acc:96.680, val_loss:0.173, val_acc:82.386
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 278/300 lr=0.00019 - loss:0.121, acc:97.461, val_loss:0.175, val_acc:79.261
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 279/300 lr=0.00019 - loss:0.126, acc:95.898, val_loss:0.174, val_acc:82.386
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 280/300 lr=0.00019 - loss:0.124, acc:96.484, val_loss:0.174, val_acc:83.097
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 281/300 lr=0.00019 - loss:0.121, acc:96.875, val_loss:0.171, val_acc:83.097
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 282/300 lr=0.00017 - loss:0.124, acc:96.484, val_loss:0.180, val_acc:83.097
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 283/300 lr=0.00017 - loss:0.136, acc:97.656, val_loss:0.175, val_acc:80.824
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 284/300 lr=0.00017 - loss:0.128, acc:96.484, val_loss:0.177, val_acc:80.824
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 285/300 lr=0.00017 - loss:0.127, acc:96.875, val_loss:0.188, val_acc:80.824
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 286/300 lr=0.00017 - loss:0.128, acc:96.484, val_loss:0.174, val_acc:78.409
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 287/300 lr=0.00017 - loss:0.118, acc:97.656, val_loss:0.164, val_acc:81.534
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 288/300 lr=0.00017 - loss:0.143, acc:95.508, val_loss:0.169, val_acc:81.534
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 289/300 lr=0.00017 - loss:0.124, acc:96.289, val_loss:0.186, val_acc:77.699
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 290/300 lr=0.00017 - loss:0.127, acc:96.484, val_loss:0.214, val_acc:75.426
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 291/300 lr=0.00017 - loss:0.131, acc:95.117, val_loss:0.206, val_acc:73.864
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 292/300 lr=0.00017 - loss:0.125, acc:97.266, val_loss:0.165, val_acc:84.659
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 293/300 lr=0.00017 - loss:0.129, acc:95.703, val_loss:0.154, val_acc:84.659
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 294/300 lr=0.00017 - loss:0.136, acc:96.875, val_loss:0.175, val_acc:79.261
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 295/300 lr=0.00017 - loss:0.133, acc:95.312, val_loss:0.190, val_acc:76.989
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 296/300 lr=0.00017 - loss:0.130, acc:95.508, val_loss:0.169, val_acc:83.097
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 297/300 lr=0.00017 - loss:0.123, acc:96.875, val_loss:0.159, val_acc:80.824
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 298/300 lr=0.00017 - loss:0.122, acc:97.656, val_loss:0.163, val_acc:82.386
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 299/300 lr=0.00017 - loss:0.126, acc:96.680, val_loss:0.169, val_acc:86.222
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# 300/300 lr=0.00017 - loss:0.123, acc:97.656, val_loss:0.177, val_acc:84.659
# Best loss:0.164, Best accuracy:86.932, Best F1-score:0.870
# [*] Done - acc:86.932
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.580, acc:32.031, val_loss:0.539, val_acc:46.165
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.527, acc:40.820, val_loss:0.511, val_acc:46.165
# Best loss:0.539, Best accuracy:46.165, Best F1-score:0.316
# 3/300 lr=0.00100 - loss:0.525, acc:40.039, val_loss:0.478, val_acc:46.165
# Best loss:0.539, Best accuracy:46.165, Best F1-score:0.316
# 4/300 lr=0.00100 - loss:0.496, acc:41.406, val_loss:0.465, val_acc:44.602
# Best loss:0.539, Best accuracy:46.165, Best F1-score:0.316
# 5/300 lr=0.00100 - loss:0.480, acc:51.562, val_loss:0.459, val_acc:47.727
# Best loss:0.539, Best accuracy:46.165, Best F1-score:0.316
# 6/300 lr=0.00100 - loss:0.487, acc:43.164, val_loss:0.435, val_acc:49.290
# Best loss:0.459, Best accuracy:47.727, Best F1-score:0.371
# 7/300 lr=0.00100 - loss:0.464, acc:48.633, val_loss:0.401, val_acc:51.562
# Best loss:0.435, Best accuracy:49.290, Best F1-score:0.388
# 8/300 lr=0.00100 - loss:0.447, acc:51.367, val_loss:0.421, val_acc:49.290
# Best loss:0.401, Best accuracy:51.562, Best F1-score:0.452
# 9/300 lr=0.00100 - loss:0.442, acc:53.125, val_loss:0.380, val_acc:52.415
# Best loss:0.401, Best accuracy:51.562, Best F1-score:0.452
# 10/300 lr=0.00100 - loss:0.430, acc:52.539, val_loss:0.419, val_acc:50.852
# Best loss:0.380, Best accuracy:52.415, Best F1-score:0.437
# 11/300 lr=0.00100 - loss:0.428, acc:54.883, val_loss:0.376, val_acc:53.977
# Best loss:0.380, Best accuracy:52.415, Best F1-score:0.437
# 12/300 lr=0.00100 - loss:0.457, acc:50.000, val_loss:0.405, val_acc:53.125
# Best loss:0.376, Best accuracy:53.977, Best F1-score:0.507
# 13/300 lr=0.00100 - loss:0.418, acc:57.617, val_loss:0.363, val_acc:50.852
# Best loss:0.376, Best accuracy:53.977, Best F1-score:0.507
# 14/300 lr=0.00100 - loss:0.438, acc:48.047, val_loss:0.374, val_acc:53.977
# Best loss:0.376, Best accuracy:53.977, Best F1-score:0.507
# 15/300 lr=0.00100 - loss:0.443, acc:50.586, val_loss:0.355, val_acc:51.562
# Best loss:0.376, Best accuracy:53.977, Best F1-score:0.507
# 16/300 lr=0.00100 - loss:0.411, acc:55.664, val_loss:0.353, val_acc:56.250
# Best loss:0.376, Best accuracy:53.977, Best F1-score:0.507
# 17/300 lr=0.00100 - loss:0.394, acc:58.789, val_loss:0.379, val_acc:47.017
# Best loss:0.353, Best accuracy:56.250, Best F1-score:0.523
# 18/300 lr=0.00100 - loss:0.409, acc:58.594, val_loss:0.358, val_acc:52.415
# Best loss:0.353, Best accuracy:56.250, Best F1-score:0.523
# 19/300 lr=0.00100 - loss:0.380, acc:58.789, val_loss:0.367, val_acc:48.580
# Best loss:0.353, Best accuracy:56.250, Best F1-score:0.523
# 20/300 lr=0.00100 - loss:0.417, acc:54.492, val_loss:0.348, val_acc:55.398
# Best loss:0.353, Best accuracy:56.250, Best F1-score:0.523
# 21/300 lr=0.00100 - loss:0.390, acc:55.078, val_loss:0.336, val_acc:60.085
# Best loss:0.353, Best accuracy:56.250, Best F1-score:0.523
# 22/300 lr=0.00100 - loss:0.432, acc:56.836, val_loss:0.343, val_acc:59.233
# Best loss:0.336, Best accuracy:60.085, Best F1-score:0.605
# 23/300 lr=0.00100 - loss:0.389, acc:56.836, val_loss:0.351, val_acc:53.125
# Best loss:0.336, Best accuracy:60.085, Best F1-score:0.605
# 24/300 lr=0.00100 - loss:0.357, acc:64.844, val_loss:0.330, val_acc:58.523
# Best loss:0.336, Best accuracy:60.085, Best F1-score:0.605
# 25/300 lr=0.00100 - loss:0.373, acc:61.914, val_loss:0.332, val_acc:60.085
# Best loss:0.336, Best accuracy:60.085, Best F1-score:0.605
# 26/300 lr=0.00100 - loss:0.353, acc:64.062, val_loss:0.314, val_acc:63.068
# Best loss:0.336, Best accuracy:60.085, Best F1-score:0.605
# 27/300 lr=0.00100 - loss:0.361, acc:63.086, val_loss:0.308, val_acc:61.506
# Best loss:0.314, Best accuracy:63.068, Best F1-score:0.596
# 28/300 lr=0.00100 - loss:0.345, acc:64.453, val_loss:0.328, val_acc:56.960
# Best loss:0.314, Best accuracy:63.068, Best F1-score:0.596
# 29/300 lr=0.00100 - loss:0.364, acc:60.156, val_loss:0.300, val_acc:59.233
# Best loss:0.314, Best accuracy:63.068, Best F1-score:0.596
# 30/300 lr=0.00100 - loss:0.337, acc:67.969, val_loss:0.321, val_acc:64.631
# Best loss:0.314, Best accuracy:63.068, Best F1-score:0.596
# 31/300 lr=0.00100 - loss:0.356, acc:65.234, val_loss:0.298, val_acc:62.358
# Best loss:0.321, Best accuracy:64.631, Best F1-score:0.609
# 32/300 lr=0.00100 - loss:0.337, acc:66.211, val_loss:0.306, val_acc:62.358
# Best loss:0.321, Best accuracy:64.631, Best F1-score:0.609
# 33/300 lr=0.00100 - loss:0.337, acc:64.844, val_loss:0.305, val_acc:58.523
# Best loss:0.321, Best accuracy:64.631, Best F1-score:0.609
# 34/300 lr=0.00100 - loss:0.324, acc:69.531, val_loss:0.301, val_acc:64.631
# Best loss:0.321, Best accuracy:64.631, Best F1-score:0.609
# 35/300 lr=0.00100 - loss:0.339, acc:69.336, val_loss:0.307, val_acc:63.920
# Best loss:0.321, Best accuracy:64.631, Best F1-score:0.609
# 36/300 lr=0.00100 - loss:0.360, acc:63.672, val_loss:0.304, val_acc:64.631
# Best loss:0.321, Best accuracy:64.631, Best F1-score:0.609
# 37/300 lr=0.00100 - loss:0.339, acc:65.039, val_loss:0.308, val_acc:60.653
# Best loss:0.321, Best accuracy:64.631, Best F1-score:0.609
# 38/300 lr=0.00100 - loss:0.354, acc:62.109, val_loss:0.296, val_acc:66.051
# Best loss:0.321, Best accuracy:64.631, Best F1-score:0.609
# 39/300 lr=0.00100 - loss:0.320, acc:68.750, val_loss:0.326, val_acc:59.233
# Best loss:0.296, Best accuracy:66.051, Best F1-score:0.654
# 40/300 lr=0.00100 - loss:0.322, acc:68.750, val_loss:0.254, val_acc:74.574
# Best loss:0.296, Best accuracy:66.051, Best F1-score:0.654
# 41/300 lr=0.00100 - loss:0.319, acc:69.531, val_loss:0.319, val_acc:63.920
# Best loss:0.254, Best accuracy:74.574, Best F1-score:0.747
# 42/300 lr=0.00100 - loss:0.318, acc:69.336, val_loss:0.282, val_acc:63.068
# Best loss:0.254, Best accuracy:74.574, Best F1-score:0.747
# 43/300 lr=0.00100 - loss:0.317, acc:67.773, val_loss:0.279, val_acc:66.903
# Best loss:0.254, Best accuracy:74.574, Best F1-score:0.747
# 44/300 lr=0.00100 - loss:0.325, acc:71.289, val_loss:0.308, val_acc:54.688
# Best loss:0.254, Best accuracy:74.574, Best F1-score:0.747
# 45/300 lr=0.00100 - loss:0.309, acc:73.438, val_loss:0.252, val_acc:67.756
# Best loss:0.254, Best accuracy:74.574, Best F1-score:0.747
# 46/300 lr=0.00100 - loss:0.314, acc:65.820, val_loss:0.281, val_acc:62.358
# Best loss:0.254, Best accuracy:74.574, Best F1-score:0.747
# 47/300 lr=0.00100 - loss:0.285, acc:74.414, val_loss:0.257, val_acc:70.028
# Best loss:0.254, Best accuracy:74.574, Best F1-score:0.747
# 48/300 lr=0.00100 - loss:0.289, acc:73.828, val_loss:0.284, val_acc:60.795
# Best loss:0.254, Best accuracy:74.574, Best F1-score:0.747
# 49/300 lr=0.00100 - loss:0.285, acc:75.781, val_loss:0.255, val_acc:67.756
# Best loss:0.254, Best accuracy:74.574, Best F1-score:0.747
# 50/300 lr=0.00100 - loss:0.284, acc:74.414, val_loss:0.249, val_acc:70.028
# Best loss:0.254, Best accuracy:74.574, Best F1-score:0.747
# 51/300 lr=0.00100 - loss:0.263, acc:77.734, val_loss:0.234, val_acc:70.739
# Best loss:0.254, Best accuracy:74.574, Best F1-score:0.747
# 52/300 lr=0.00100 - loss:0.286, acc:69.727, val_loss:0.232, val_acc:72.301
# Best loss:0.254, Best accuracy:74.574, Best F1-score:0.747
# 53/300 lr=0.00100 - loss:0.273, acc:75.977, val_loss:0.258, val_acc:73.864
# Best loss:0.254, Best accuracy:74.574, Best F1-score:0.747
# 54/300 lr=0.00100 - loss:0.303, acc:69.727, val_loss:0.233, val_acc:73.864
# Best loss:0.254, Best accuracy:74.574, Best F1-score:0.747
# 55/300 lr=0.00100 - loss:0.280, acc:75.977, val_loss:0.291, val_acc:65.341
# Best loss:0.254, Best accuracy:74.574, Best F1-score:0.747
# 56/300 lr=0.00100 - loss:0.281, acc:73.633, val_loss:0.253, val_acc:69.318
# Best loss:0.254, Best accuracy:74.574, Best F1-score:0.747
# ...
# 183/300 lr=0.00035 - loss:0.139, acc:94.336, val_loss:0.083, val_acc:89.732
# Best loss:0.103, Best accuracy:92.932, Best F1-score:0.925
# 184/300 lr=0.00035 - loss:0.140, acc:94.922, val_loss:0.092, val_acc:87.426
# Best loss:0.103, Best accuracy:92.932, Best F1-score:0.925
# 185/300 lr=0.00035 - loss:0.134, acc:95.703, val_loss:0.124, val_acc:85.789
# Best loss:0.103, Best accuracy:92.932, Best F1-score:0.925
# 186/300 lr=0.00035 - loss:0.140, acc:95.312, val_loss:0.087, val_acc:91.369
# Best loss:0.103, Best accuracy:92.932, Best F1-score:0.925
# 187/300 lr=0.00035 - loss:0.140, acc:95.508, val_loss:0.096, val_acc:90.551
# Best loss:0.103, Best accuracy:92.932, Best F1-score:0.925
# 188/300 lr=0.00035 - loss:0.152, acc:91.992, val_loss:0.131, val_acc:81.845
# Best loss:0.103, Best accuracy:92.932, Best F1-score:0.925
# 189/300 lr=0.00035 - loss:0.134, acc:95.508, val_loss:0.094, val_acc:92.113
# Best loss:0.103, Best accuracy:92.932, Best F1-score:0.925
# 190/300 lr=0.00035 - loss:0.137, acc:94.531, val_loss:0.079, val_acc:94.494
# Best loss:0.103, Best accuracy:92.932, Best F1-score:0.925
# 191/300 lr=0.00035 - loss:0.134, acc:95.898, val_loss:0.104, val_acc:88.170
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 192/300 lr=0.00035 - loss:0.136, acc:94.727, val_loss:0.115, val_acc:84.226
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 193/300 lr=0.00035 - loss:0.148, acc:90.234, val_loss:0.092, val_acc:88.988
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 194/300 lr=0.00035 - loss:0.132, acc:95.117, val_loss:0.098, val_acc:89.807
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 195/300 lr=0.00035 - loss:0.138, acc:94.727, val_loss:0.120, val_acc:86.607
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 196/300 lr=0.00035 - loss:0.133, acc:94.727, val_loss:0.124, val_acc:81.920
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 197/300 lr=0.00035 - loss:0.130, acc:95.898, val_loss:0.117, val_acc:88.988
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 198/300 lr=0.00035 - loss:0.131, acc:95.508, val_loss:0.109, val_acc:88.988
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 199/300 lr=0.00035 - loss:0.125, acc:96.484, val_loss:0.104, val_acc:88.988
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 200/300 lr=0.00035 - loss:0.136, acc:96.094, val_loss:0.102, val_acc:86.607
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 201/300 lr=0.00035 - loss:0.134, acc:95.703, val_loss:0.094, val_acc:88.988
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 202/300 lr=0.00030 - loss:0.142, acc:92.383, val_loss:0.113, val_acc:88.170
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 203/300 lr=0.00030 - loss:0.126, acc:95.703, val_loss:0.125, val_acc:84.226
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 204/300 lr=0.00030 - loss:0.126, acc:95.898, val_loss:0.085, val_acc:90.551
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 205/300 lr=0.00030 - loss:0.132, acc:95.508, val_loss:0.098, val_acc:88.170
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 206/300 lr=0.00030 - loss:0.128, acc:96.094, val_loss:0.120, val_acc:83.408
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 207/300 lr=0.00030 - loss:0.129, acc:96.289, val_loss:0.100, val_acc:90.551
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 208/300 lr=0.00030 - loss:0.128, acc:96.094, val_loss:0.107, val_acc:86.607
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 209/300 lr=0.00030 - loss:0.147, acc:92.773, val_loss:0.116, val_acc:88.170
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 210/300 lr=0.00030 - loss:0.132, acc:96.289, val_loss:0.125, val_acc:84.226
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 211/300 lr=0.00030 - loss:0.123, acc:97.656, val_loss:0.123, val_acc:85.045
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 212/300 lr=0.00030 - loss:0.145, acc:92.773, val_loss:0.116, val_acc:85.789
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 213/300 lr=0.00030 - loss:0.129, acc:96.680, val_loss:0.121, val_acc:88.170
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 214/300 lr=0.00030 - loss:0.130, acc:95.508, val_loss:0.084, val_acc:91.369
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 215/300 lr=0.00030 - loss:0.130, acc:96.094, val_loss:0.090, val_acc:88.244
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 216/300 lr=0.00030 - loss:0.132, acc:96.289, val_loss:0.109, val_acc:88.170
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 217/300 lr=0.00030 - loss:0.131, acc:95.508, val_loss:0.100, val_acc:88.988
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
#
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 284/300 lr=0.00017 - loss:0.110, acc:98.633, val_loss:0.088, val_acc:92.113
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 285/300 lr=0.00017 - loss:0.116, acc:98.047, val_loss:0.110, val_acc:88.170
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 286/300 lr=0.00017 - loss:0.113, acc:98.047, val_loss:0.111, val_acc:86.607
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 287/300 lr=0.00017 - loss:0.114, acc:97.852, val_loss:0.094, val_acc:88.170
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 288/300 lr=0.00017 - loss:0.112, acc:98.047, val_loss:0.079, val_acc:92.113
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 289/300 lr=0.00017 - loss:0.113, acc:98.633, val_loss:0.094, val_acc:87.351
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 290/300 lr=0.00017 - loss:0.117, acc:97.852, val_loss:0.111, val_acc:86.607
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 291/300 lr=0.00017 - loss:0.117, acc:97.656, val_loss:0.093, val_acc:86.607
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 292/300 lr=0.00017 - loss:0.110, acc:98.438, val_loss:0.086, val_acc:88.988
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 293/300 lr=0.00017 - loss:0.118, acc:97.656, val_loss:0.090, val_acc:89.732
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 294/300 lr=0.00017 - loss:0.112, acc:99.023, val_loss:0.089, val_acc:90.551
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 295/300 lr=0.00017 - loss:0.115, acc:98.438, val_loss:0.078, val_acc:92.932
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 296/300 lr=0.00017 - loss:0.115, acc:98.242, val_loss:0.073, val_acc:96.057
# Best loss:0.079, Best accuracy:94.494, Best F1-score:0.944
# 297/300 lr=0.00017 - loss:0.117, acc:98.242, val_loss:0.075, val_acc:91.295
# Best loss:0.073, Best accuracy:96.057, Best F1-score:0.959
# 298/300 lr=0.00017 - loss:0.113, acc:98.047, val_loss:0.088, val_acc:88.988
# Best loss:0.073, Best accuracy:96.057, Best F1-score:0.959
# 299/300 lr=0.00017 - loss:0.117, acc:97.852, val_loss:0.082, val_acc:90.551
# Best loss:0.073, Best accuracy:96.057, Best F1-score:0.959
# 300/300 lr=0.00017 - loss:0.116, acc:98.438, val_loss:0.100, val_acc:91.369
# Best loss:0.073, Best accuracy:96.057, Best F1-score:0.959
# [*] Done - acc:96.057

# %%
end()

# %%
print(f'max:{max(fold_acc)}, min:{min(fold_acc)}, average:{sum(fold_acc)/len(fold_acc)}')
# Out:
# max:96.05654776096344, min:83.0965906381607, average:89.096320271492

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
# Out:
# WAR(Weighted Average Recall)   : 88.77%
# UAR(Unweighted Average Recall) : 88.77%
