# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = 'TIMNET-dataset'
DATA_PATH = 'EMODB'
CLASS_LABELS = Config.EMODB_LABELS
k = 10

# 캡슐로 바꾸는 부분 Depthwise-separable CNN으로, 앞단 CNN 전부 64 채널
model_name = 'RoutingConvNet(64 CNN, Last dilated)+CBAM+Depthwise-separable-Caps+SpatialAttn'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding=padding),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule], name='primarycap_reshape'),
        Lambda(function=PrimaryCapssquash, name='primarycap_squash')
    ])
    
  def call(self, inputs):
    x = self.conv(inputs)
    return x

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.cbam = CBAM(64) # sharing
    
    self.primarycap = PrimaryCap()
    self.spatial_attn = SpatialGate()
    
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    forward = inputs
    backward =tf.reverse(inputs, axis=[2])
    
    x = tf.concat([forward, backward], axis=-1)   # channel concat
    
    cap = self.conv1(x)
    cap = cap + self.cbam(cap)
    cap = self.conv2(cap)
    cap = cap + self.cbam(cap)
    
    primarycaps = self.primarycap(cap)
    primarycaps = tf.expand_dims(primarycaps, axis=-1)
    primarycaps = primarycaps + self.spatial_attn(primarycaps)
    primarycaps = tf.squeeze(primarycaps, axis=-1)
    
    cap = primarycaps
    
    sa = self.attention([primarycaps, primarycaps, primarycaps])
    sa = self.LN(sa)
    
    cap = self.lamb([cap, sa])
    
    capsule = self.capsule(cap)
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1992
#
#  sequential_1 (Sequential)   (None, 46, 7, 64)         37300
#
#  cbam (CBAM)                 multiple                  4294
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  spatial_gate_1 (SpatialGate  multiple                 102
#  )
#
#  attention (Attention)       multiple                  1
#
#  layer_normalization (LayerN  multiple                 128
#  ormalization)
#
#  lambda (Lambda)             multiple                  0
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  455
#
# =================================================================
# Total params: 94,448
# Trainable params: 93,870
# Non-trainable params: 578
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}.npy', 'rb') as f:
    x = np.load(f)
    y = np.load(f)

y = to_categorical(y,num_classes=len(CLASS_LABELS))

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, test) in tqdm(enumerate(kfold.split(x, y)), desc=f'Training {k}-Fold.....'):
    # if i < 8:
    #     continue
    
    now_time = datetime.now().strftime("%m-%d-%H%M%S")
    
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = x[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_test, y_test = x[test], y[test]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_test = tf.expand_dims(x_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_test_loss = 0x3f3f3f
    best_test_acc = -1
    best_test_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        test_loss, test_acc, f1s = [], [], []
        for features, labels in batch_test:
            loss, acc, pred = test_step(model, features, labels)
            test_loss.append(loss)
            test_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(test_loss)/len(test_loss)
        val_acc = sum(test_acc)/len(test_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_test_loss:.3f}, Best accuracy:{best_test_acc:.3f}, Best F1-score:{best_test_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_test_acc < val_acc:
            best_test_acc = val_acc
            best_test_loss = val_loss
            best_test_f1 = f1_score
            model.save_weights(h5_path)
            
            
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    best_pred = model(x_test, training=False)
    emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(y_test, axis=1))
    predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
    
    
    print(f'[*] Done - acc:{best_test_acc:.3f}')
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    fold_acc.append(best_test_acc)
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.596, acc:29.492, val_loss:0.574, val_acc:37.074
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.558, acc:40.820, val_loss:0.540, val_acc:42.472
# Best loss:0.574, Best accuracy:37.074, Best F1-score:0.242
# 3/300 lr=0.00100 - loss:0.533, acc:40.820, val_loss:0.521, val_acc:45.455
# Best loss:0.540, Best accuracy:42.472, Best F1-score:0.312
# 4/300 lr=0.00100 - loss:0.501, acc:50.977, val_loss:0.503, val_acc:44.744
# Best loss:0.521, Best accuracy:45.455, Best F1-score:0.329
# 5/300 lr=0.00100 - loss:0.497, acc:52.344, val_loss:0.491, val_acc:47.727
# Best loss:0.521, Best accuracy:45.455, Best F1-score:0.329
# 6/300 lr=0.00100 - loss:0.472, acc:53.320, val_loss:0.480, val_acc:47.017
# Best loss:0.491, Best accuracy:47.727, Best F1-score:0.407
# 7/300 lr=0.00100 - loss:0.478, acc:47.461, val_loss:0.477, val_acc:43.892
# Best loss:0.491, Best accuracy:47.727, Best F1-score:0.407
# 8/300 lr=0.00100 - loss:0.448, acc:51.367, val_loss:0.445, val_acc:53.125
# Best loss:0.491, Best accuracy:47.727, Best F1-score:0.407
# 9/300 lr=0.00100 - loss:0.475, acc:46.484, val_loss:0.453, val_acc:47.727
# Best loss:0.445, Best accuracy:53.125, Best F1-score:0.446
# 10/300 lr=0.00100 - loss:0.458, acc:55.078, val_loss:0.437, val_acc:54.688
# Best loss:0.445, Best accuracy:53.125, Best F1-score:0.446
# 11/300 lr=0.00100 - loss:0.463, acc:47.852, val_loss:0.415, val_acc:49.290
# Best loss:0.437, Best accuracy:54.688, Best F1-score:0.472
# 12/300 lr=0.00100 - loss:0.461, acc:49.023, val_loss:0.442, val_acc:45.455
# Best loss:0.437, Best accuracy:54.688, Best F1-score:0.472
# 13/300 lr=0.00100 - loss:0.420, acc:57.422, val_loss:0.405, val_acc:56.250
# Best loss:0.437, Best accuracy:54.688, Best F1-score:0.472
# 14/300 lr=0.00100 - loss:0.428, acc:50.195, val_loss:0.401, val_acc:55.398
# Best loss:0.405, Best accuracy:56.250, Best F1-score:0.505
# 15/300 lr=0.00100 - loss:0.431, acc:50.586, val_loss:0.412, val_acc:55.540
# Best loss:0.405, Best accuracy:56.250, Best F1-score:0.505
# 16/300 lr=0.00100 - loss:0.402, acc:58.789, val_loss:0.376, val_acc:59.233
# Best loss:0.405, Best accuracy:56.250, Best F1-score:0.505
# 17/300 lr=0.00100 - loss:0.402, acc:59.375, val_loss:0.385, val_acc:52.273
# Best loss:0.376, Best accuracy:59.233, Best F1-score:0.543
# 18/300 lr=0.00100 - loss:0.413, acc:55.273, val_loss:0.373, val_acc:60.085
# Best loss:0.376, Best accuracy:59.233, Best F1-score:0.543
# 19/300 lr=0.00100 - loss:0.384, acc:60.352, val_loss:0.378, val_acc:58.523
# Best loss:0.373, Best accuracy:60.085, Best F1-score:0.567
# 20/300 lr=0.00100 - loss:0.401, acc:60.547, val_loss:0.348, val_acc:65.483
# Best loss:0.373, Best accuracy:60.085, Best F1-score:0.567
# 21/300 lr=0.00100 - loss:0.385, acc:61.133, val_loss:0.374, val_acc:49.290
# Best loss:0.348, Best accuracy:65.483, Best F1-score:0.638
# 22/300 lr=0.00100 - loss:0.375, acc:64.258, val_loss:0.349, val_acc:68.466
# Best loss:0.348, Best accuracy:65.483, Best F1-score:0.638
# 23/300 lr=0.00100 - loss:0.371, acc:61.523, val_loss:0.350, val_acc:63.068
# Best loss:0.349, Best accuracy:68.466, Best F1-score:0.647
# 24/300 lr=0.00100 - loss:0.395, acc:57.422, val_loss:0.324, val_acc:67.756
# Best loss:0.349, Best accuracy:68.466, Best F1-score:0.647
# 25/300 lr=0.00100 - loss:0.377, acc:63.477, val_loss:0.345, val_acc:65.341
# Best loss:0.349, Best accuracy:68.466, Best F1-score:0.647
# 26/300 lr=0.00100 - loss:0.380, acc:61.328, val_loss:0.325, val_acc:65.341
# Best loss:0.349, Best accuracy:68.466, Best F1-score:0.647
# 27/300 lr=0.00100 - loss:0.393, acc:56.250, val_loss:0.349, val_acc:57.670
# Best loss:0.349, Best accuracy:68.466, Best F1-score:0.647
# 28/300 lr=0.00100 - loss:0.409, acc:54.883, val_loss:0.350, val_acc:60.653
# Best loss:0.349, Best accuracy:68.466, Best F1-score:0.647
# 29/300 lr=0.00100 - loss:0.367, acc:65.234, val_loss:0.321, val_acc:66.051
# Best loss:0.349, Best accuracy:68.466, Best F1-score:0.647
# 30/300 lr=0.00100 - loss:0.353, acc:63.867, val_loss:0.335, val_acc:65.341
# Best loss:0.349, Best accuracy:68.466, Best F1-score:0.647
# 31/300 lr=0.00100 - loss:0.359, acc:63.477, val_loss:0.308, val_acc:69.886
# Best loss:0.349, Best accuracy:68.466, Best F1-score:0.647
# 32/300 lr=0.00100 - loss:0.349, acc:68.359, val_loss:0.304, val_acc:67.614
# Best loss:0.308, Best accuracy:69.886, Best F1-score:0.667
# 33/300 lr=0.00100 - loss:0.350, acc:68.164, val_loss:0.294, val_acc:64.631
# Best loss:0.308, Best accuracy:69.886, Best F1-score:0.667
# 34/300 lr=0.00100 - loss:0.364, acc:60.742, val_loss:0.309, val_acc:62.358
# Best loss:0.308, Best accuracy:69.886, Best F1-score:0.667
# 35/300 lr=0.00100 - loss:0.340, acc:67.188, val_loss:0.292, val_acc:69.886
# Best loss:0.308, Best accuracy:69.886, Best F1-score:0.667
# 36/300 lr=0.00100 - loss:0.341, acc:69.531, val_loss:0.306, val_acc:63.068
# Best loss:0.308, Best accuracy:69.886, Best F1-score:0.667
# 37/300 lr=0.00100 - loss:0.350, acc:68.164, val_loss:0.299, val_acc:66.193
# Best loss:0.308, Best accuracy:69.886, Best F1-score:0.667
# 38/300 lr=0.00100 - loss:0.336, acc:65.430, val_loss:0.285, val_acc:66.051
# Best loss:0.308, Best accuracy:69.886, Best F1-score:0.667
# 39/300 lr=0.00100 - loss:0.349, acc:68.359, val_loss:0.286, val_acc:63.920
# Best loss:0.308, Best accuracy:69.886, Best F1-score:0.667
# 40/300 lr=0.00100 - loss:0.369, acc:65.820, val_loss:0.275, val_acc:69.886
# Best loss:0.308, Best accuracy:69.886, Best F1-score:0.667
# 41/300 lr=0.00100 - loss:0.352, acc:63.672, val_loss:0.259, val_acc:75.994
# Best loss:0.308, Best accuracy:69.886, Best F1-score:0.667
# 42/300 lr=0.00100 - loss:0.322, acc:73.633, val_loss:0.255, val_acc:73.722
# Best loss:0.259, Best accuracy:75.994, Best F1-score:0.742
# 43/300 lr=0.00100 - loss:0.345, acc:65.430, val_loss:0.252, val_acc:75.994
# Best loss:0.259, Best accuracy:75.994, Best F1-score:0.742
# 44/300 lr=0.00100 - loss:0.310, acc:71.094, val_loss:0.234, val_acc:75.994
# Best loss:0.259, Best accuracy:75.994, Best F1-score:0.742
# 45/300 lr=0.00100 - loss:0.340, acc:64.062, val_loss:0.267, val_acc:80.682
# Best loss:0.259, Best accuracy:75.994, Best F1-score:0.742
# 46/300 lr=0.00100 - loss:0.330, acc:72.266, val_loss:0.254, val_acc:73.011
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 47/300 lr=0.00100 - loss:0.301, acc:71.484, val_loss:0.272, val_acc:70.739
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 48/300 lr=0.00100 - loss:0.308, acc:72.852, val_loss:0.239, val_acc:75.994
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 49/300 lr=0.00100 - loss:0.319, acc:69.336, val_loss:0.233, val_acc:76.847
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 50/300 lr=0.00100 - loss:0.293, acc:75.586, val_loss:0.218, val_acc:79.972
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 51/300 lr=0.00100 - loss:0.323, acc:67.773, val_loss:0.211, val_acc:78.409
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 52/300 lr=0.00100 - loss:0.292, acc:75.977, val_loss:0.255, val_acc:68.466
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 53/300 lr=0.00100 - loss:0.303, acc:74.219, val_loss:0.242, val_acc:73.864
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 54/300 lr=0.00100 - loss:0.290, acc:72.656, val_loss:0.232, val_acc:74.574
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 55/300 lr=0.00100 - loss:0.330, acc:72.852, val_loss:0.232, val_acc:76.136
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 56/300 lr=0.00100 - loss:0.280, acc:77.539, val_loss:0.213, val_acc:76.136
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 57/300 lr=0.00100 - loss:0.267, acc:76.562, val_loss:0.214, val_acc:78.409
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 58/300 lr=0.00100 - loss:0.302, acc:71.289, val_loss:0.226, val_acc:77.557
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 59/300 lr=0.00100 - loss:0.269, acc:76.562, val_loss:0.220, val_acc:70.739
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 60/300 lr=0.00100 - loss:0.283, acc:71.484, val_loss:0.195, val_acc:78.409
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 61/300 lr=0.00100 - loss:0.261, acc:78.125, val_loss:0.220, val_acc:72.301
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 62/300 lr=0.00086 - loss:0.265, acc:77.539, val_loss:0.206, val_acc:77.699
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 63/300 lr=0.00086 - loss:0.285, acc:71.680, val_loss:0.207, val_acc:81.534
# Best loss:0.267, Best accuracy:80.682, Best F1-score:0.812
# 64/300 lr=0.00086 - loss:0.259, acc:79.102, val_loss:0.215, val_acc:72.301
# Best loss:0.207, Best accuracy:81.534, Best F1-score:0.806
# 65/300 lr=0.00086 - loss:0.256, acc:80.273, val_loss:0.200, val_acc:80.682
# Best loss:0.207, Best accuracy:81.534, Best F1-score:0.806
# 66/300 lr=0.00086 - loss:0.274, acc:73.242, val_loss:0.209, val_acc:75.284
# Best loss:0.207, Best accuracy:81.534, Best F1-score:0.806
# 67/300 lr=0.00086 - loss:0.246, acc:80.859, val_loss:0.191, val_acc:80.682
# Best loss:0.207, Best accuracy:81.534, Best F1-score:0.806
# 68/300 lr=0.00086 - loss:0.258, acc:80.664, val_loss:0.187, val_acc:79.261
# Best loss:0.207, Best accuracy:81.534, Best F1-score:0.806
# 69/300 lr=0.00086 - loss:0.243, acc:82.227, val_loss:0.225, val_acc:74.574
# Best loss:0.207, Best accuracy:81.534, Best F1-score:0.806
# 70/300 lr=0.00086 - loss:0.246, acc:80.664, val_loss:0.194, val_acc:75.426
# Best loss:0.207, Best accuracy:81.534, Best F1-score:0.806
# 71/300 lr=0.00086 - loss:0.244, acc:80.469, val_loss:0.186, val_acc:79.119
# Best loss:0.207, Best accuracy:81.534, Best F1-score:0.806
# 72/300 lr=0.00086 - loss:0.284, acc:74.609, val_loss:0.184, val_acc:80.824
# Best loss:0.207, Best accuracy:81.534, Best F1-score:0.806
# 73/300 lr=0.00086 - loss:0.237, acc:82.422, val_loss:0.183, val_acc:78.409
# Best loss:0.207, Best accuracy:81.534, Best F1-score:0.806
# 74/300 lr=0.00086 - loss:0.243, acc:81.445, val_loss:0.190, val_acc:79.119
# Best loss:0.207, Best accuracy:81.534, Best F1-score:0.806
# 75/300 lr=0.00086 - loss:0.243, acc:82.617, val_loss:0.187, val_acc:83.097
# Best loss:0.207, Best accuracy:81.534, Best F1-score:0.806
# 76/300 lr=0.00086 - loss:0.262, acc:74.414, val_loss:0.177, val_acc:79.972
# Best loss:0.187, Best accuracy:83.097, Best F1-score:0.834
# 77/300 lr=0.00086 - loss:0.240, acc:81.055, val_loss:0.197, val_acc:75.284
# Best loss:0.187, Best accuracy:83.097, Best F1-score:0.834
# 78/300 lr=0.00086 - loss:0.224, acc:85.547, val_loss:0.176, val_acc:78.409
# Best loss:0.187, Best accuracy:83.097, Best F1-score:0.834
# 79/300 lr=0.00086 - loss:0.236, acc:81.641, val_loss:0.194, val_acc:82.244
# Best loss:0.187, Best accuracy:83.097, Best F1-score:0.834
# 80/300 lr=0.00086 - loss:0.271, acc:77.734, val_loss:0.190, val_acc:78.409
# Best loss:0.187, Best accuracy:83.097, Best F1-score:0.834
# 81/300 lr=0.00086 - loss:0.240, acc:80.664, val_loss:0.205, val_acc:70.881
# Best loss:0.187, Best accuracy:83.097, Best F1-score:0.834
# 82/300 lr=0.00074 - loss:0.254, acc:78.711, val_loss:0.163, val_acc:83.807
# Best loss:0.187, Best accuracy:83.097, Best F1-score:0.834
# 83/300 lr=0.00074 - loss:0.271, acc:76.172, val_loss:0.187, val_acc:81.392
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 84/300 lr=0.00074 - loss:0.240, acc:82.422, val_loss:0.208, val_acc:74.716
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 85/300 lr=0.00074 - loss:0.232, acc:82.422, val_loss:0.185, val_acc:75.426
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 86/300 lr=0.00074 - loss:0.248, acc:76.953, val_loss:0.189, val_acc:79.261
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 87/300 lr=0.00074 - loss:0.216, acc:85.156, val_loss:0.214, val_acc:79.830
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 88/300 lr=0.00074 - loss:0.237, acc:82.227, val_loss:0.205, val_acc:76.136
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 89/300 lr=0.00074 - loss:0.223, acc:83.008, val_loss:0.204, val_acc:75.426
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 90/300 lr=0.00074 - loss:0.210, acc:85.547, val_loss:0.197, val_acc:78.409
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 91/300 lr=0.00074 - loss:0.212, acc:83.594, val_loss:0.194, val_acc:73.864
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 92/300 lr=0.00074 - loss:0.216, acc:82.617, val_loss:0.184, val_acc:75.426
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 93/300 lr=0.00074 - loss:0.206, acc:86.719, val_loss:0.179, val_acc:75.426
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 94/300 lr=0.00074 - loss:0.216, acc:83.398, val_loss:0.172, val_acc:80.824
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 95/300 lr=0.00074 - loss:0.209, acc:84.766, val_loss:0.186, val_acc:80.824
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 96/300 lr=0.00074 - loss:0.225, acc:84.375, val_loss:0.178, val_acc:74.574
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 97/300 lr=0.00074 - loss:0.224, acc:83.398, val_loss:0.187, val_acc:77.699
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 98/300 lr=0.00074 - loss:0.207, acc:85.156, val_loss:0.211, val_acc:77.699
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 99/300 lr=0.00074 - loss:0.219, acc:82.812, val_loss:0.176, val_acc:76.136
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 100/300 lr=0.00074 - loss:0.216, acc:84.180, val_loss:0.223, val_acc:73.864
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 101/300 lr=0.00074 - loss:0.227, acc:79.297, val_loss:0.192, val_acc:79.261
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 102/300 lr=0.00064 - loss:0.275, acc:75.391, val_loss:0.215, val_acc:74.432
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 103/300 lr=0.00064 - loss:0.228, acc:81.641, val_loss:0.209, val_acc:75.994
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 104/300 lr=0.00064 - loss:0.258, acc:78.125, val_loss:0.201, val_acc:77.699
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 105/300 lr=0.00064 - loss:0.263, acc:76.172, val_loss:0.201, val_acc:78.409
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 106/300 lr=0.00064 - loss:0.225, acc:82.812, val_loss:0.189, val_acc:77.557
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 107/300 lr=0.00064 - loss:0.223, acc:85.938, val_loss:0.204, val_acc:72.301
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 108/300 lr=0.00064 - loss:0.208, acc:86.133, val_loss:0.178, val_acc:76.989
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 109/300 lr=0.00064 - loss:0.238, acc:78.711, val_loss:0.197, val_acc:73.011
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 110/300 lr=0.00064 - loss:0.216, acc:83.203, val_loss:0.184, val_acc:78.409
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 111/300 lr=0.00064 - loss:0.212, acc:84.766, val_loss:0.192, val_acc:75.426
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 112/300 lr=0.00064 - loss:0.211, acc:84.766, val_loss:0.182, val_acc:75.284
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 113/300 lr=0.00064 - loss:0.208, acc:85.156, val_loss:0.183, val_acc:76.136
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 114/300 lr=0.00064 - loss:0.204, acc:85.156, val_loss:0.188, val_acc:82.244
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 115/300 lr=0.00064 - loss:0.195, acc:87.500, val_loss:0.174, val_acc:76.989
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 116/300 lr=0.00064 - loss:0.190, acc:87.305, val_loss:0.170, val_acc:79.972
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 117/300 lr=0.00064 - loss:0.207, acc:81.445, val_loss:0.175, val_acc:78.409
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 118/300 lr=0.00064 - loss:0.184, acc:89.258, val_loss:0.175, val_acc:74.574
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 119/300 lr=0.00064 - loss:0.199, acc:85.352, val_loss:0.168, val_acc:78.409
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 120/300 lr=0.00064 - loss:0.207, acc:82.031, val_loss:0.171, val_acc:82.244
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 121/300 lr=0.00064 - loss:0.217, acc:82.617, val_loss:0.171, val_acc:79.261
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 122/300 lr=0.00055 - loss:0.189, acc:87.109, val_loss:0.173, val_acc:73.864
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 123/300 lr=0.00055 - loss:0.234, acc:81.641, val_loss:0.173, val_acc:78.409
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 124/300 lr=0.00055 - loss:0.190, acc:89.258, val_loss:0.168, val_acc:80.682
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 125/300 lr=0.00055 - loss:0.182, acc:87.891, val_loss:0.178, val_acc:76.136
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 126/300 lr=0.00055 - loss:0.193, acc:86.133, val_loss:0.171, val_acc:77.699
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 127/300 lr=0.00055 - loss:0.184, acc:88.086, val_loss:0.177, val_acc:79.119
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 128/300 lr=0.00055 - loss:0.184, acc:88.281, val_loss:0.160, val_acc:83.097
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 129/300 lr=0.00055 - loss:0.199, acc:87.891, val_loss:0.181, val_acc:77.699
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 130/300 lr=0.00055 - loss:0.181, acc:88.086, val_loss:0.168, val_acc:82.244
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 131/300 lr=0.00055 - loss:0.181, acc:90.039, val_loss:0.175, val_acc:79.972
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 132/300 lr=0.00055 - loss:0.170, acc:91.016, val_loss:0.165, val_acc:79.972
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 133/300 lr=0.00055 - loss:0.172, acc:90.234, val_loss:0.165, val_acc:81.534
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 134/300 lr=0.00055 - loss:0.162, acc:91.406, val_loss:0.167, val_acc:74.574
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 135/300 lr=0.00055 - loss:0.179, acc:88.672, val_loss:0.169, val_acc:78.409
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 136/300 lr=0.00055 - loss:0.170, acc:89.258, val_loss:0.167, val_acc:80.824
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 137/300 lr=0.00055 - loss:0.167, acc:91.211, val_loss:0.150, val_acc:83.807
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 138/300 lr=0.00055 - loss:0.170, acc:90.039, val_loss:0.159, val_acc:83.807
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 139/300 lr=0.00055 - loss:0.216, acc:85.156, val_loss:0.154, val_acc:77.699
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 140/300 lr=0.00055 - loss:0.201, acc:83.594, val_loss:0.157, val_acc:78.409
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 141/300 lr=0.00055 - loss:0.163, acc:90.234, val_loss:0.158, val_acc:82.955
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 142/300 lr=0.00047 - loss:0.176, acc:89.258, val_loss:0.174, val_acc:80.682
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 143/300 lr=0.00047 - loss:0.173, acc:89.844, val_loss:0.153, val_acc:84.517
# Best loss:0.163, Best accuracy:83.807, Best F1-score:0.838
# 144/300 lr=0.00047 - loss:0.198, acc:84.766, val_loss:0.164, val_acc:82.244
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 145/300 lr=0.00047 - loss:0.166, acc:90.430, val_loss:0.177, val_acc:79.972
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 146/300 lr=0.00047 - loss:0.192, acc:88.672, val_loss:0.183, val_acc:78.409
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 147/300 lr=0.00047 - loss:0.165, acc:90.820, val_loss:0.176, val_acc:81.392
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 148/300 lr=0.00047 - loss:0.178, acc:89.844, val_loss:0.186, val_acc:79.119
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 149/300 lr=0.00047 - loss:0.176, acc:89.258, val_loss:0.177, val_acc:79.119
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 150/300 lr=0.00047 - loss:0.197, acc:88.672, val_loss:0.170, val_acc:78.409
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 151/300 lr=0.00047 - loss:0.162, acc:91.992, val_loss:0.164, val_acc:76.136
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 152/300 lr=0.00047 - loss:0.168, acc:90.234, val_loss:0.155, val_acc:79.972
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 153/300 lr=0.00047 - loss:0.165, acc:91.992, val_loss:0.157, val_acc:79.972
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 154/300 lr=0.00047 - loss:0.162, acc:91.992, val_loss:0.157, val_acc:79.261
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 155/300 lr=0.00047 - loss:0.154, acc:93.750, val_loss:0.146, val_acc:84.517
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 156/300 lr=0.00047 - loss:0.171, acc:91.211, val_loss:0.169, val_acc:78.409
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 157/300 lr=0.00047 - loss:0.172, acc:91.211, val_loss:0.172, val_acc:81.534
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 158/300 lr=0.00047 - loss:0.165, acc:91.992, val_loss:0.175, val_acc:78.409
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 159/300 lr=0.00047 - loss:0.217, acc:83.789, val_loss:0.157, val_acc:80.682
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 160/300 lr=0.00047 - loss:0.166, acc:91.016, val_loss:0.180, val_acc:81.534
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 161/300 lr=0.00047 - loss:0.175, acc:92.383, val_loss:0.161, val_acc:79.972
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 162/300 lr=0.00041 - loss:0.168, acc:91.211, val_loss:0.147, val_acc:82.955
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 163/300 lr=0.00041 - loss:0.174, acc:89.648, val_loss:0.146, val_acc:78.409
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 164/300 lr=0.00041 - loss:0.160, acc:91.602, val_loss:0.181, val_acc:76.136
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 165/300 lr=0.00041 - loss:0.163, acc:91.016, val_loss:0.161, val_acc:76.136
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 166/300 lr=0.00041 - loss:0.151, acc:92.188, val_loss:0.152, val_acc:84.517
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 167/300 lr=0.00041 - loss:0.147, acc:94.336, val_loss:0.156, val_acc:82.955
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 168/300 lr=0.00041 - loss:0.146, acc:93.750, val_loss:0.151, val_acc:80.682
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 169/300 lr=0.00041 - loss:0.193, acc:86.328, val_loss:0.153, val_acc:80.682
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 170/300 lr=0.00041 - loss:0.158, acc:92.578, val_loss:0.152, val_acc:82.244
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 171/300 lr=0.00041 - loss:0.148, acc:93.164, val_loss:0.158, val_acc:82.244
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 172/300 lr=0.00041 - loss:0.158, acc:92.578, val_loss:0.169, val_acc:79.972
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 173/300 lr=0.00041 - loss:0.154, acc:93.750, val_loss:0.153, val_acc:82.244
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 174/300 lr=0.00041 - loss:0.151, acc:92.578, val_loss:0.153, val_acc:82.955
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 175/300 lr=0.00041 - loss:0.155, acc:92.969, val_loss:0.152, val_acc:82.244
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 176/300 lr=0.00041 - loss:0.158, acc:92.773, val_loss:0.163, val_acc:79.972
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 177/300 lr=0.00041 - loss:0.151, acc:92.188, val_loss:0.160, val_acc:86.080
# Best loss:0.153, Best accuracy:84.517, Best F1-score:0.833
# 178/300 lr=0.00041 - loss:0.146, acc:93.555, val_loss:0.146, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 179/300 lr=0.00041 - loss:0.164, acc:86.719, val_loss:0.146, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 180/300 lr=0.00041 - loss:0.166, acc:87.891, val_loss:0.158, val_acc:80.682
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 181/300 lr=0.00041 - loss:0.172, acc:85.547, val_loss:0.163, val_acc:82.244
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 182/300 lr=0.00035 - loss:0.152, acc:92.578, val_loss:0.154, val_acc:79.119
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 183/300 lr=0.00035 - loss:0.147, acc:92.969, val_loss:0.156, val_acc:79.119
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 184/300 lr=0.00035 - loss:0.149, acc:94.141, val_loss:0.163, val_acc:80.682
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 185/300 lr=0.00035 - loss:0.143, acc:94.531, val_loss:0.179, val_acc:81.534
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 186/300 lr=0.00035 - loss:0.157, acc:90.820, val_loss:0.161, val_acc:82.244
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 187/300 lr=0.00035 - loss:0.150, acc:93.359, val_loss:0.147, val_acc:86.080
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 188/300 lr=0.00035 - loss:0.148, acc:93.945, val_loss:0.154, val_acc:82.244
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 189/300 lr=0.00035 - loss:0.143, acc:93.555, val_loss:0.153, val_acc:84.517
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 190/300 lr=0.00035 - loss:0.191, acc:85.938, val_loss:0.139, val_acc:83.807
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 191/300 lr=0.00035 - loss:0.167, acc:87.109, val_loss:0.147, val_acc:85.369
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 192/300 lr=0.00035 - loss:0.158, acc:92.969, val_loss:0.158, val_acc:82.244
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 193/300 lr=0.00035 - loss:0.146, acc:93.945, val_loss:0.156, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 194/300 lr=0.00035 - loss:0.174, acc:86.914, val_loss:0.146, val_acc:80.682
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 195/300 lr=0.00035 - loss:0.150, acc:94.336, val_loss:0.161, val_acc:82.244
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 196/300 lr=0.00035 - loss:0.150, acc:92.188, val_loss:0.157, val_acc:81.534
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 197/300 lr=0.00035 - loss:0.147, acc:93.555, val_loss:0.146, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 198/300 lr=0.00035 - loss:0.166, acc:87.891, val_loss:0.144, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 199/300 lr=0.00035 - loss:0.146, acc:93.555, val_loss:0.150, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 200/300 lr=0.00035 - loss:0.141, acc:94.727, val_loss:0.163, val_acc:79.119
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 201/300 lr=0.00035 - loss:0.143, acc:93.945, val_loss:0.163, val_acc:82.244
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 202/300 lr=0.00030 - loss:0.155, acc:94.531, val_loss:0.153, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 203/300 lr=0.00030 - loss:0.147, acc:95.508, val_loss:0.168, val_acc:80.682
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 204/300 lr=0.00030 - loss:0.149, acc:92.773, val_loss:0.155, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 205/300 lr=0.00030 - loss:0.143, acc:93.750, val_loss:0.146, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 206/300 lr=0.00030 - loss:0.144, acc:93.359, val_loss:0.159, val_acc:77.557
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 207/300 lr=0.00030 - loss:0.138, acc:94.727, val_loss:0.164, val_acc:76.847
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 208/300 lr=0.00030 - loss:0.139, acc:94.336, val_loss:0.150, val_acc:78.409
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 209/300 lr=0.00030 - loss:0.136, acc:95.312, val_loss:0.153, val_acc:77.557
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 210/300 lr=0.00030 - loss:0.142, acc:93.359, val_loss:0.165, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 211/300 lr=0.00030 - loss:0.137, acc:94.531, val_loss:0.156, val_acc:79.119
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 212/300 lr=0.00030 - loss:0.131, acc:96.484, val_loss:0.154, val_acc:78.409
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 213/300 lr=0.00030 - loss:0.141, acc:93.164, val_loss:0.157, val_acc:78.409
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 214/300 lr=0.00030 - loss:0.133, acc:96.094, val_loss:0.147, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 215/300 lr=0.00030 - loss:0.135, acc:94.922, val_loss:0.146, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 216/300 lr=0.00030 - loss:0.135, acc:95.312, val_loss:0.146, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 217/300 lr=0.00030 - loss:0.139, acc:94.922, val_loss:0.157, val_acc:82.244
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 218/300 lr=0.00030 - loss:0.134, acc:96.094, val_loss:0.145, val_acc:79.119
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 219/300 lr=0.00030 - loss:0.132, acc:95.898, val_loss:0.147, val_acc:84.517
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 220/300 lr=0.00030 - loss:0.142, acc:93.945, val_loss:0.150, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 221/300 lr=0.00030 - loss:0.128, acc:96.094, val_loss:0.145, val_acc:79.119
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 222/300 lr=0.00026 - loss:0.134, acc:95.312, val_loss:0.147, val_acc:79.972
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 223/300 lr=0.00026 - loss:0.136, acc:95.898, val_loss:0.164, val_acc:82.244
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 224/300 lr=0.00026 - loss:0.139, acc:95.703, val_loss:0.151, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 225/300 lr=0.00026 - loss:0.129, acc:95.898, val_loss:0.153, val_acc:78.409
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 226/300 lr=0.00026 - loss:0.134, acc:95.117, val_loss:0.169, val_acc:79.119
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 227/300 lr=0.00026 - loss:0.170, acc:88.477, val_loss:0.160, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 228/300 lr=0.00026 - loss:0.132, acc:94.922, val_loss:0.161, val_acc:79.830
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 229/300 lr=0.00026 - loss:0.136, acc:94.727, val_loss:0.163, val_acc:77.557
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 230/300 lr=0.00026 - loss:0.133, acc:96.289, val_loss:0.162, val_acc:79.119
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 231/300 lr=0.00026 - loss:0.128, acc:96.484, val_loss:0.159, val_acc:82.244
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 232/300 lr=0.00026 - loss:0.128, acc:95.898, val_loss:0.151, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 233/300 lr=0.00026 - loss:0.124, acc:96.875, val_loss:0.147, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 234/300 lr=0.00026 - loss:0.128, acc:96.484, val_loss:0.153, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 235/300 lr=0.00026 - loss:0.127, acc:96.875, val_loss:0.146, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 236/300 lr=0.00026 - loss:0.133, acc:95.508, val_loss:0.148, val_acc:84.517
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 237/300 lr=0.00026 - loss:0.131, acc:95.898, val_loss:0.158, val_acc:80.682
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 238/300 lr=0.00026 - loss:0.121, acc:97.266, val_loss:0.152, val_acc:79.119
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 239/300 lr=0.00026 - loss:0.133, acc:96.680, val_loss:0.143, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 240/300 lr=0.00026 - loss:0.133, acc:94.531, val_loss:0.156, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 241/300 lr=0.00026 - loss:0.130, acc:96.289, val_loss:0.152, val_acc:82.244
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 242/300 lr=0.00022 - loss:0.129, acc:96.094, val_loss:0.152, val_acc:79.119
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 243/300 lr=0.00022 - loss:0.130, acc:96.289, val_loss:0.155, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 244/300 lr=0.00022 - loss:0.130, acc:96.094, val_loss:0.162, val_acc:83.807
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 245/300 lr=0.00022 - loss:0.123, acc:97.461, val_loss:0.162, val_acc:79.119
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 246/300 lr=0.00022 - loss:0.123, acc:97.266, val_loss:0.153, val_acc:80.682
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 247/300 lr=0.00022 - loss:0.126, acc:96.875, val_loss:0.145, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 248/300 lr=0.00022 - loss:0.119, acc:96.680, val_loss:0.151, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 249/300 lr=0.00022 - loss:0.127, acc:96.680, val_loss:0.147, val_acc:84.517
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 250/300 lr=0.00022 - loss:0.125, acc:96.289, val_loss:0.150, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 251/300 lr=0.00022 - loss:0.144, acc:91.016, val_loss:0.145, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 252/300 lr=0.00022 - loss:0.127, acc:95.117, val_loss:0.152, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 253/300 lr=0.00022 - loss:0.125, acc:96.484, val_loss:0.148, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 254/300 lr=0.00022 - loss:0.130, acc:95.703, val_loss:0.130, val_acc:84.517
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 255/300 lr=0.00022 - loss:0.130, acc:96.094, val_loss:0.133, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 256/300 lr=0.00022 - loss:0.126, acc:96.875, val_loss:0.140, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 257/300 lr=0.00022 - loss:0.126, acc:96.289, val_loss:0.151, val_acc:84.517
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 258/300 lr=0.00022 - loss:0.124, acc:97.852, val_loss:0.154, val_acc:78.267
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 259/300 lr=0.00022 - loss:0.127, acc:96.875, val_loss:0.157, val_acc:78.267
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 260/300 lr=0.00022 - loss:0.125, acc:96.484, val_loss:0.152, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 261/300 lr=0.00022 - loss:0.131, acc:96.680, val_loss:0.148, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 262/300 lr=0.00019 - loss:0.123, acc:97.266, val_loss:0.149, val_acc:79.830
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 263/300 lr=0.00019 - loss:0.124, acc:96.875, val_loss:0.146, val_acc:79.830
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 264/300 lr=0.00019 - loss:0.122, acc:97.070, val_loss:0.145, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 265/300 lr=0.00019 - loss:0.124, acc:96.875, val_loss:0.148, val_acc:84.517
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 266/300 lr=0.00019 - loss:0.117, acc:98.438, val_loss:0.144, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 267/300 lr=0.00019 - loss:0.120, acc:97.070, val_loss:0.146, val_acc:79.830
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 268/300 lr=0.00019 - loss:0.125, acc:97.070, val_loss:0.150, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 269/300 lr=0.00019 - loss:0.120, acc:97.461, val_loss:0.155, val_acc:82.244
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 270/300 lr=0.00019 - loss:0.136, acc:91.406, val_loss:0.157, val_acc:79.119
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 271/300 lr=0.00019 - loss:0.123, acc:96.094, val_loss:0.150, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 272/300 lr=0.00019 - loss:0.128, acc:95.312, val_loss:0.145, val_acc:84.517
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 273/300 lr=0.00019 - loss:0.116, acc:97.852, val_loss:0.150, val_acc:79.119
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 274/300 lr=0.00019 - loss:0.126, acc:96.680, val_loss:0.159, val_acc:80.682
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 275/300 lr=0.00019 - loss:0.122, acc:97.461, val_loss:0.150, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 276/300 lr=0.00019 - loss:0.126, acc:98.047, val_loss:0.148, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 277/300 lr=0.00019 - loss:0.125, acc:96.680, val_loss:0.158, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 278/300 lr=0.00019 - loss:0.129, acc:96.484, val_loss:0.164, val_acc:79.830
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 279/300 lr=0.00019 - loss:0.128, acc:96.289, val_loss:0.158, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 280/300 lr=0.00019 - loss:0.119, acc:97.461, val_loss:0.162, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 281/300 lr=0.00019 - loss:0.119, acc:97.852, val_loss:0.158, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 282/300 lr=0.00017 - loss:0.126, acc:96.484, val_loss:0.158, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 283/300 lr=0.00017 - loss:0.154, acc:91.602, val_loss:0.154, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 284/300 lr=0.00017 - loss:0.117, acc:97.852, val_loss:0.148, val_acc:84.517
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 285/300 lr=0.00017 - loss:0.122, acc:96.875, val_loss:0.152, val_acc:83.807
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 286/300 lr=0.00017 - loss:0.123, acc:96.680, val_loss:0.159, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 287/300 lr=0.00017 - loss:0.124, acc:97.266, val_loss:0.151, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 288/300 lr=0.00017 - loss:0.135, acc:97.266, val_loss:0.143, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 289/300 lr=0.00017 - loss:0.121, acc:96.680, val_loss:0.146, val_acc:84.517
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 290/300 lr=0.00017 - loss:0.117, acc:98.438, val_loss:0.147, val_acc:84.517
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 291/300 lr=0.00017 - loss:0.115, acc:98.438, val_loss:0.153, val_acc:79.119
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 292/300 lr=0.00017 - loss:0.120, acc:96.875, val_loss:0.152, val_acc:79.119
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 293/300 lr=0.00017 - loss:0.121, acc:97.070, val_loss:0.154, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 294/300 lr=0.00017 - loss:0.115, acc:97.852, val_loss:0.148, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 295/300 lr=0.00017 - loss:0.123, acc:96.875, val_loss:0.147, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 296/300 lr=0.00017 - loss:0.117, acc:98.242, val_loss:0.151, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 297/300 lr=0.00017 - loss:0.116, acc:98.047, val_loss:0.147, val_acc:80.682
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 298/300 lr=0.00017 - loss:0.127, acc:96.289, val_loss:0.142, val_acc:84.517
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 299/300 lr=0.00017 - loss:0.116, acc:98.047, val_loss:0.147, val_acc:82.955
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# 300/300 lr=0.00017 - loss:0.120, acc:98.633, val_loss:0.139, val_acc:81.392
# Best loss:0.160, Best accuracy:86.080, Best F1-score:0.864
# [*] Done - acc:86.080
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.592, acc:29.688, val_loss:0.565, val_acc:45.455
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.547, acc:41.211, val_loss:0.530, val_acc:46.165
# Best loss:0.565, Best accuracy:45.455, Best F1-score:0.337
# 3/300 lr=0.00100 - loss:0.542, acc:40.234, val_loss:0.505, val_acc:47.727
# Best loss:0.530, Best accuracy:46.165, Best F1-score:0.327
# 4/300 lr=0.00100 - loss:0.520, acc:41.992, val_loss:0.483, val_acc:47.727
# Best loss:0.505, Best accuracy:47.727, Best F1-score:0.349
# 5/300 lr=0.00100 - loss:0.509, acc:52.148, val_loss:0.464, val_acc:54.688
# Best loss:0.505, Best accuracy:47.727, Best F1-score:0.349
# 6/300 lr=0.00100 - loss:0.505, acc:43.750, val_loss:0.464, val_acc:49.290
# Best loss:0.464, Best accuracy:54.688, Best F1-score:0.453
# 7/300 lr=0.00100 - loss:0.478, acc:52.539, val_loss:0.449, val_acc:50.852
# Best loss:0.464, Best accuracy:54.688, Best F1-score:0.453
# 8/300 lr=0.00100 - loss:0.467, acc:52.539, val_loss:0.441, val_acc:54.688
# Best loss:0.464, Best accuracy:54.688, Best F1-score:0.453
# 9/300 lr=0.00100 - loss:0.457, acc:53.125, val_loss:0.424, val_acc:50.852
# Best loss:0.464, Best accuracy:54.688, Best F1-score:0.453
# 10/300 lr=0.00100 - loss:0.434, acc:55.078, val_loss:0.423, val_acc:54.688
# Best loss:0.464, Best accuracy:54.688, Best F1-score:0.453
# 11/300 lr=0.00100 - loss:0.424, acc:54.297, val_loss:0.410, val_acc:51.562
# Best loss:0.464, Best accuracy:54.688, Best F1-score:0.453
# 12/300 lr=0.00100 - loss:0.449, acc:50.000, val_loss:0.417, val_acc:49.290
# Best loss:0.464, Best accuracy:54.688, Best F1-score:0.453
# 13/300 lr=0.00100 - loss:0.424, acc:53.125, val_loss:0.409, val_acc:49.290
# Best loss:0.464, Best accuracy:54.688, Best F1-score:0.453
# 14/300 lr=0.00100 - loss:0.433, acc:50.000, val_loss:0.406, val_acc:48.580
# Best loss:0.464, Best accuracy:54.688, Best F1-score:0.453
# 15/300 lr=0.00100 - loss:0.440, acc:51.562, val_loss:0.389, val_acc:53.125
# Best loss:0.464, Best accuracy:54.688, Best F1-score:0.453
# 16/300 lr=0.00100 - loss:0.411, acc:54.102, val_loss:0.393, val_acc:51.562
# Best loss:0.464, Best accuracy:54.688, Best F1-score:0.453
# 17/300 lr=0.00100 - loss:0.405, acc:60.352, val_loss:0.408, val_acc:50.142
# Best loss:0.464, Best accuracy:54.688, Best F1-score:0.453
# 18/300 lr=0.00100 - loss:0.417, acc:51.953, val_loss:0.410, val_acc:50.852
# Best loss:0.464, Best accuracy:54.688, Best F1-score:0.453
# 19/300 lr=0.00100 - loss:0.389, acc:57.617, val_loss:0.380, val_acc:56.960
# Best loss:0.464, Best accuracy:54.688, Best F1-score:0.453
# 20/300 lr=0.00100 - loss:0.413, acc:52.930, val_loss:0.386, val_acc:54.688
# Best loss:0.380, Best accuracy:56.960, Best F1-score:0.549
# 21/300 lr=0.00100 - loss:0.412, acc:58.984, val_loss:0.364, val_acc:55.398
# Best loss:0.380, Best accuracy:56.960, Best F1-score:0.549
# 22/300 lr=0.00100 - loss:0.431, acc:54.492, val_loss:0.379, val_acc:56.960
# Best loss:0.380, Best accuracy:56.960, Best F1-score:0.549
# 23/300 lr=0.00100 - loss:0.402, acc:55.078, val_loss:0.375, val_acc:54.688
# Best loss:0.380, Best accuracy:56.960, Best F1-score:0.549
# 24/300 lr=0.00100 - loss:0.372, acc:59.961, val_loss:0.366, val_acc:50.852
# Best loss:0.380, Best accuracy:56.960, Best F1-score:0.549
# 25/300 lr=0.00100 - loss:0.391, acc:60.156, val_loss:0.347, val_acc:61.506
# Best loss:0.380, Best accuracy:56.960, Best F1-score:0.549
# 26/300 lr=0.00100 - loss:0.370, acc:63.086, val_loss:0.339, val_acc:58.381
# Best loss:0.347, Best accuracy:61.506, Best F1-score:0.596
# 27/300 lr=0.00100 - loss:0.366, acc:63.281, val_loss:0.361, val_acc:53.125
# Best loss:0.347, Best accuracy:61.506, Best F1-score:0.596
# 28/300 lr=0.00100 - loss:0.359, acc:61.328, val_loss:0.338, val_acc:56.960
# Best loss:0.347, Best accuracy:61.506, Best F1-score:0.596
# 29/300 lr=0.00100 - loss:0.377, acc:57.422, val_loss:0.343, val_acc:57.670
# Best loss:0.347, Best accuracy:61.506, Best F1-score:0.596
# 30/300 lr=0.00100 - loss:0.353, acc:64.844, val_loss:0.333, val_acc:58.523
# Best loss:0.347, Best accuracy:61.506, Best F1-score:0.596
# 31/300 lr=0.00100 - loss:0.372, acc:63.867, val_loss:0.339, val_acc:59.233
# Best loss:0.347, Best accuracy:61.506, Best F1-score:0.596
# 32/300 lr=0.00100 - loss:0.348, acc:65.234, val_loss:0.333, val_acc:58.523
# Best loss:0.347, Best accuracy:61.506, Best F1-score:0.596
# 33/300 lr=0.00100 - loss:0.340, acc:68.164, val_loss:0.336, val_acc:63.068
# Best loss:0.347, Best accuracy:61.506, Best F1-score:0.596
# 34/300 lr=0.00100 - loss:0.338, acc:67.188, val_loss:0.324, val_acc:62.358
# Best loss:0.336, Best accuracy:63.068, Best F1-score:0.609
# 35/300 lr=0.00100 - loss:0.375, acc:63.477, val_loss:0.341, val_acc:56.250
# Best loss:0.336, Best accuracy:63.068, Best F1-score:0.609
# 36/300 lr=0.00100 - loss:0.362, acc:63.867, val_loss:0.330, val_acc:54.688
# Best loss:0.336, Best accuracy:63.068, Best F1-score:0.609
# 37/300 lr=0.00100 - loss:0.358, acc:61.523, val_loss:0.333, val_acc:56.250
# Best loss:0.336, Best accuracy:63.068, Best F1-score:0.609
# 38/300 lr=0.00100 - loss:0.368, acc:60.547, val_loss:0.317, val_acc:60.795
# Best loss:0.336, Best accuracy:63.068, Best F1-score:0.609
# 39/300 lr=0.00100 - loss:0.331, acc:69.141, val_loss:0.340, val_acc:56.960
# Best loss:0.336, Best accuracy:63.068, Best F1-score:0.609
# 40/300 lr=0.00100 - loss:0.357, acc:68.164, val_loss:0.324, val_acc:66.193
# Best loss:0.336, Best accuracy:63.068, Best F1-score:0.609
# 41/300 lr=0.00100 - loss:0.326, acc:67.773, val_loss:0.297, val_acc:62.358
# Best loss:0.324, Best accuracy:66.193, Best F1-score:0.625
# 42/300 lr=0.00100 - loss:0.327, acc:71.094, val_loss:0.332, val_acc:55.398
# Best loss:0.324, Best accuracy:66.193, Best F1-score:0.625
# 43/300 lr=0.00100 - loss:0.326, acc:67.383, val_loss:0.299, val_acc:63.920
# Best loss:0.324, Best accuracy:66.193, Best F1-score:0.625
# 44/300 lr=0.00100 - loss:0.331, acc:65.234, val_loss:0.311, val_acc:60.795
# Best loss:0.324, Best accuracy:66.193, Best F1-score:0.625
# 45/300 lr=0.00100 - loss:0.334, acc:70.703, val_loss:0.349, val_acc:58.523
# Best loss:0.324, Best accuracy:66.193, Best F1-score:0.625
# 46/300 lr=0.00100 - loss:0.333, acc:71.289, val_loss:0.290, val_acc:63.778
# Best loss:0.324, Best accuracy:66.193, Best F1-score:0.625
# 47/300 lr=0.00100 - loss:0.315, acc:69.336, val_loss:0.296, val_acc:59.943
# Best loss:0.324, Best accuracy:66.193, Best F1-score:0.625
# 48/300 lr=0.00100 - loss:0.310, acc:71.875, val_loss:0.344, val_acc:58.523
# Best loss:0.324, Best accuracy:66.193, Best F1-score:0.625
# 49/300 lr=0.00100 - loss:0.344, acc:62.891, val_loss:0.306, val_acc:66.193
# Best loss:0.324, Best accuracy:66.193, Best F1-score:0.625
# 50/300 lr=0.00100 - loss:0.297, acc:71.875, val_loss:0.304, val_acc:62.358
# Best loss:0.324, Best accuracy:66.193, Best F1-score:0.625
# 51/300 lr=0.00100 - loss:0.312, acc:70.898, val_loss:0.314, val_acc:56.960
# Best loss:0.324, Best accuracy:66.193, Best F1-score:0.625
# 52/300 lr=0.00100 - loss:0.308, acc:71.094, val_loss:0.318, val_acc:59.233
# Best loss:0.324, Best accuracy:66.193, Best F1-score:0.625
# 53/300 lr=0.00100 - loss:0.308, acc:69.141, val_loss:0.301, val_acc:60.795
# Best loss:0.324, Best accuracy:66.193, Best F1-score:0.625
# 54/300 lr=0.00100 - loss:0.322, acc:67.773, val_loss:0.286, val_acc:67.614
# Best loss:0.324, Best accuracy:66.193, Best F1-score:0.625
# 55/300 lr=0.00100 - loss:0.299, acc:75.586, val_loss:0.306, val_acc:63.778
# Best loss:0.286, Best accuracy:67.614, Best F1-score:0.661
# 56/300 lr=0.00100 - loss:0.290, acc:75.781, val_loss:0.313, val_acc:62.358
# Best loss:0.286, Best accuracy:67.614, Best F1-score:0.661
# ...
# 183/300 lr=0.00035 - loss:0.135, acc:94.531, val_loss:0.057, val_acc:94.494
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 184/300 lr=0.00035 - loss:0.133, acc:96.094, val_loss:0.075, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 185/300 lr=0.00035 - loss:0.145, acc:94.141, val_loss:0.079, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 186/300 lr=0.00035 - loss:0.141, acc:94.922, val_loss:0.061, val_acc:94.494
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 187/300 lr=0.00035 - loss:0.139, acc:93.945, val_loss:0.064, val_acc:94.494
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 188/300 lr=0.00035 - loss:0.145, acc:93.555, val_loss:0.072, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 189/300 lr=0.00035 - loss:0.145, acc:91.992, val_loss:0.068, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 190/300 lr=0.00035 - loss:0.138, acc:94.727, val_loss:0.065, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 191/300 lr=0.00035 - loss:0.141, acc:94.141, val_loss:0.075, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 192/300 lr=0.00035 - loss:0.136, acc:94.531, val_loss:0.080, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 193/300 lr=0.00035 - loss:0.135, acc:95.703, val_loss:0.068, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 194/300 lr=0.00035 - loss:0.128, acc:96.289, val_loss:0.061, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 195/300 lr=0.00035 - loss:0.144, acc:95.312, val_loss:0.067, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 196/300 lr=0.00035 - loss:0.137, acc:95.703, val_loss:0.066, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 197/300 lr=0.00035 - loss:0.135, acc:94.922, val_loss:0.071, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 198/300 lr=0.00035 - loss:0.134, acc:95.117, val_loss:0.069, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 199/300 lr=0.00035 - loss:0.127, acc:96.680, val_loss:0.062, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 200/300 lr=0.00035 - loss:0.138, acc:95.508, val_loss:0.064, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 201/300 lr=0.00035 - loss:0.136, acc:95.508, val_loss:0.059, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 202/300 lr=0.00030 - loss:0.141, acc:93.359, val_loss:0.078, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 203/300 lr=0.00030 - loss:0.138, acc:96.094, val_loss:0.085, val_acc:94.494
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 204/300 lr=0.00030 - loss:0.128, acc:96.680, val_loss:0.065, val_acc:94.494
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 205/300 lr=0.00030 - loss:0.129, acc:97.070, val_loss:0.057, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 206/300 lr=0.00030 - loss:0.127, acc:96.875, val_loss:0.067, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 207/300 lr=0.00030 - loss:0.136, acc:95.508, val_loss:0.059, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 208/300 lr=0.00030 - loss:0.126, acc:97.070, val_loss:0.061, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 209/300 lr=0.00030 - loss:0.134, acc:96.094, val_loss:0.073, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 210/300 lr=0.00030 - loss:0.127, acc:96.094, val_loss:0.081, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 211/300 lr=0.00030 - loss:0.125, acc:96.875, val_loss:0.075, val_acc:89.732
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 212/300 lr=0.00030 - loss:0.135, acc:96.680, val_loss:0.083, val_acc:89.732
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 213/300 lr=0.00030 - loss:0.125, acc:96.289, val_loss:0.080, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 214/300 lr=0.00030 - loss:0.124, acc:97.461, val_loss:0.074, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 215/300 lr=0.00030 - loss:0.130, acc:95.898, val_loss:0.070, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 216/300 lr=0.00030 - loss:0.134, acc:96.680, val_loss:0.087, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 217/300 lr=0.00030 - loss:0.129, acc:95.703, val_loss:0.088, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 218/300 lr=0.00030 - loss:0.130, acc:96.094, val_loss:0.076, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 219/300 lr=0.00030 - loss:0.124, acc:96.484, val_loss:0.069, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 220/300 lr=0.00030 - loss:0.132, acc:95.898, val_loss:0.082, val_acc:90.551
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 221/300 lr=0.00030 - loss:0.127, acc:96.875, val_loss:0.063, val_acc:88.988
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 222/300 lr=0.00026 - loss:0.128, acc:96.289, val_loss:0.064, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 223/300 lr=0.00026 - loss:0.129, acc:95.508, val_loss:0.078, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 224/300 lr=0.00026 - loss:0.131, acc:95.703, val_loss:0.061, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 225/300 lr=0.00026 - loss:0.129, acc:96.289, val_loss:0.064, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 226/300 lr=0.00026 - loss:0.124, acc:96.680, val_loss:0.065, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 227/300 lr=0.00026 - loss:0.125, acc:96.680, val_loss:0.065, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 228/300 lr=0.00026 - loss:0.120, acc:97.461, val_loss:0.062, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 229/300 lr=0.00026 - loss:0.125, acc:94.922, val_loss:0.062, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 230/300 lr=0.00026 - loss:0.129, acc:96.484, val_loss:0.057, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 231/300 lr=0.00026 - loss:0.121, acc:97.656, val_loss:0.059, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 232/300 lr=0.00026 - loss:0.123, acc:96.680, val_loss:0.072, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 233/300 lr=0.00026 - loss:0.126, acc:96.094, val_loss:0.071, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 234/300 lr=0.00026 - loss:0.129, acc:96.289, val_loss:0.086, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 235/300 lr=0.00026 - loss:0.116, acc:98.047, val_loss:0.094, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 236/300 lr=0.00026 - loss:0.123, acc:97.266, val_loss:0.077, val_acc:89.732
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 237/300 lr=0.00026 - loss:0.119, acc:97.852, val_loss:0.071, val_acc:90.551
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 238/300 lr=0.00026 - loss:0.122, acc:97.070, val_loss:0.073, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 239/300 lr=0.00026 - loss:0.126, acc:95.703, val_loss:0.082, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 240/300 lr=0.00026 - loss:0.123, acc:97.461, val_loss:0.075, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 241/300 lr=0.00026 - loss:0.123, acc:97.266, val_loss:0.072, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 242/300 lr=0.00022 - loss:0.141, acc:94.141, val_loss:0.090, val_acc:92.932
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 243/300 lr=0.00022 - loss:0.127, acc:97.070, val_loss:0.068, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 244/300 lr=0.00022 - loss:0.119, acc:96.680, val_loss:0.060, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 245/300 lr=0.00022 - loss:0.121, acc:97.461, val_loss:0.075, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 246/300 lr=0.00022 - loss:0.116, acc:98.242, val_loss:0.076, val_acc:90.551
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 247/300 lr=0.00022 - loss:0.115, acc:97.852, val_loss:0.065, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 248/300 lr=0.00022 - loss:0.120, acc:96.289, val_loss:0.063, val_acc:94.494
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 249/300 lr=0.00022 - loss:0.117, acc:98.438, val_loss:0.067, val_acc:94.494
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 250/300 lr=0.00022 - loss:0.118, acc:96.875, val_loss:0.064, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 251/300 lr=0.00022 - loss:0.121, acc:96.680, val_loss:0.054, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 252/300 lr=0.00022 - loss:0.118, acc:97.852, val_loss:0.057, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 253/300 lr=0.00022 - loss:0.120, acc:96.875, val_loss:0.061, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 254/300 lr=0.00022 - loss:0.120, acc:97.266, val_loss:0.062, val_acc:89.732
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 255/300 lr=0.00022 - loss:0.116, acc:97.656, val_loss:0.067, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 256/300 lr=0.00022 - loss:0.117, acc:97.852, val_loss:0.074, val_acc:94.494
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 257/300 lr=0.00022 - loss:0.115, acc:98.438, val_loss:0.059, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 258/300 lr=0.00022 - loss:0.121, acc:97.070, val_loss:0.052, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 259/300 lr=0.00022 - loss:0.123, acc:98.047, val_loss:0.060, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 260/300 lr=0.00022 - loss:0.120, acc:96.094, val_loss:0.057, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 261/300 lr=0.00022 - loss:0.119, acc:97.266, val_loss:0.062, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 262/300 lr=0.00019 - loss:0.116, acc:97.656, val_loss:0.078, val_acc:89.732
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 263/300 lr=0.00019 - loss:0.118, acc:98.047, val_loss:0.073, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 264/300 lr=0.00019 - loss:0.114, acc:98.633, val_loss:0.068, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 265/300 lr=0.00019 - loss:0.119, acc:96.680, val_loss:0.065, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 266/300 lr=0.00019 - loss:0.140, acc:94.531, val_loss:0.060, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 267/300 lr=0.00019 - loss:0.116, acc:98.242, val_loss:0.069, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 268/300 lr=0.00019 - loss:0.116, acc:98.242, val_loss:0.069, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 269/300 lr=0.00019 - loss:0.121, acc:97.070, val_loss:0.061, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 270/300 lr=0.00019 - loss:0.115, acc:98.438, val_loss:0.060, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 271/300 lr=0.00019 - loss:0.116, acc:97.852, val_loss:0.063, val_acc:92.857
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 272/300 lr=0.00019 - loss:0.113, acc:98.242, val_loss:0.060, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 273/300 lr=0.00019 - loss:0.113, acc:98.242, val_loss:0.065, val_acc:94.494
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 274/300 lr=0.00019 - loss:0.111, acc:99.023, val_loss:0.067, val_acc:94.494
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 275/300 lr=0.00019 - loss:0.117, acc:97.852, val_loss:0.074, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 276/300 lr=0.00019 - loss:0.113, acc:98.242, val_loss:0.074, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 277/300 lr=0.00019 - loss:0.114, acc:97.852, val_loss:0.063, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 278/300 lr=0.00019 - loss:0.117, acc:97.461, val_loss:0.065, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 279/300 lr=0.00019 - loss:0.116, acc:97.461, val_loss:0.075, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 280/300 lr=0.00019 - loss:0.121, acc:97.266, val_loss:0.070, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 281/300 lr=0.00019 - loss:0.117, acc:96.875, val_loss:0.065, val_acc:89.732
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 282/300 lr=0.00017 - loss:0.133, acc:95.898, val_loss:0.068, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 283/300 lr=0.00017 - loss:0.114, acc:98.242, val_loss:0.066, val_acc:92.113
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 284/300 lr=0.00017 - loss:0.123, acc:95.312, val_loss:0.063, val_acc:89.732
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 285/300 lr=0.00017 - loss:0.111, acc:99.023, val_loss:0.067, val_acc:89.732
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 286/300 lr=0.00017 - loss:0.117, acc:97.070, val_loss:0.066, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 287/300 lr=0.00017 - loss:0.114, acc:98.242, val_loss:0.064, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 288/300 lr=0.00017 - loss:0.139, acc:94.336, val_loss:0.065, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 289/300 lr=0.00017 - loss:0.116, acc:98.438, val_loss:0.066, val_acc:89.732
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 290/300 lr=0.00017 - loss:0.118, acc:97.852, val_loss:0.056, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 291/300 lr=0.00017 - loss:0.111, acc:97.852, val_loss:0.061, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 292/300 lr=0.00017 - loss:0.117, acc:97.461, val_loss:0.062, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 293/300 lr=0.00017 - loss:0.113, acc:98.242, val_loss:0.062, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 294/300 lr=0.00017 - loss:0.110, acc:98.633, val_loss:0.061, val_acc:89.732
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 295/300 lr=0.00017 - loss:0.126, acc:94.922, val_loss:0.059, val_acc:89.732
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 296/300 lr=0.00017 - loss:0.111, acc:98.828, val_loss:0.061, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 297/300 lr=0.00017 - loss:0.112, acc:97.852, val_loss:0.058, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 298/300 lr=0.00017 - loss:0.113, acc:98.438, val_loss:0.055, val_acc:96.057
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 299/300 lr=0.00017 - loss:0.116, acc:97.656, val_loss:0.061, val_acc:93.676
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# 300/300 lr=0.00017 - loss:0.115, acc:98.047, val_loss:0.075, val_acc:91.295
# Best loss:0.071, Best accuracy:98.438, Best F1-score:0.984
# [*] Done - acc:98.438

# %%
end()

# %%
print(f'max:{max(fold_acc)}, min:{min(fold_acc)}, average:{sum(fold_acc)/len(fold_acc)}')
# Out:
# max:98.4375, min:81.5340906381607, average:88.46793860197067

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
# Out:
# WAR(Weighted Average Recall)   : 87.11%
# UAR(Unweighted Average Recall) : 87.11%
