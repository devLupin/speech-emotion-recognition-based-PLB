# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = 'TIMNET-dataset'
DATA_PATH = 'RAVDESS'
CLASS_LABELS = Config.RAVDESS_LABELS
k = 10

# 64-CNN * 2(Last CNN dilation=2) - CBAM - Depthwise-seperable - Reshape - Spatial-attention - Self-attention - Capsule
# Deltas : (196,39,6)
model_name = 'Deltas+RoutingConvNet(64 CNN, Last dilated)+CBAM+Depthwise-separable-Caps+SpatialAttn'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding=padding),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule], name='primarycap_reshape'),
        Lambda(function=PrimaryCapssquash, name='primarycap_squash')
    ])
    
  def call(self, inputs):
    x = self.conv(inputs)
    return x

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.cbam = CBAM(64) # sharing
    
    self.primarycap = PrimaryCap()
    self.spatial_attn = SpatialGate()
    
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    x = inputs
    
    cap = self.conv1(x)
    cap = cap + self.cbam(cap)
    cap = self.conv2(cap)
    cap = cap + self.cbam(cap)
    
    primarycaps = self.primarycap(cap)
    primarycaps = tf.expand_dims(primarycaps, axis=-1)
    primarycaps = primarycaps + self.spatial_attn(primarycaps)
    primarycaps = tf.squeeze(primarycaps, axis=-1)
    
    cap = primarycaps
    
    sa = self.attention([primarycaps, primarycaps, primarycaps])
    sa = self.LN(sa)
    
    cap = self.lamb([cap, sa])
    
    capsule = self.capsule(cap)
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1416
#
#  sequential_1 (Sequential)   (None, 46, 7, 64)         37300
#
#  cbam (CBAM)                 multiple                  4294
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  spatial_gate_1 (SpatialGate  multiple                 102
#  )
#
#  attention (Attention)       multiple                  1
#
#  layer_normalization (LayerN  multiple                 128
#  ormalization)
#
#  lambda (Lambda)             multiple                  0
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  520
#
# =================================================================
# Total params: 93,937
# Trainable params: 93,359
# Non-trainable params: 578
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}.npy', 'rb') as f:
    x = np.load(f)
    y = np.load(f)

y = to_categorical(y,num_classes=len(CLASS_LABELS))

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, test) in tqdm(enumerate(kfold.split(x, y)), desc=f'Training {k}-Fold.....'):
    # if i < 8:
    #     continue
    
    now_time = datetime.now().strftime("%m-%d-%H%M%S")
    
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = x[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_test, y_test = x[test], y[test]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_test = tf.expand_dims(x_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_test_loss = 0x3f3f3f
    best_test_acc = -1
    best_test_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        test_loss, test_acc, f1s = [], [], []
        for features, labels in batch_test:
            loss, acc, pred = test_step(model, features, labels)
            test_loss.append(loss)
            test_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(test_loss)/len(test_loss)
        val_acc = sum(test_acc)/len(test_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_test_loss:.3f}, Best accuracy:{best_test_acc:.3f}, Best F1-score:{best_test_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_test_acc < val_acc:
            best_test_acc = val_acc
            best_test_loss = val_loss
            best_test_f1 = f1_score
            model.save_weights(h5_path)
            
            
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    best_pred = model(x_test, training=False)
    emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(y_test, axis=1))
    predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
    
    
    print(f'[*] Done - acc:{best_test_acc:.3f}')
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    fold_acc.append(best_test_acc)
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.631, acc:17.454, val_loss:0.630, val_acc:21.250
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.619, acc:22.332, val_loss:0.623, val_acc:19.375
# Best loss:0.630, Best accuracy:21.250, Best F1-score:0.138
# 3/300 lr=0.00100 - loss:0.607, acc:24.924, val_loss:0.617, val_acc:21.250
# Best loss:0.630, Best accuracy:21.250, Best F1-score:0.138
# 4/300 lr=0.00100 - loss:0.602, acc:27.058, val_loss:0.607, val_acc:26.250
# Best loss:0.630, Best accuracy:21.250, Best F1-score:0.138
# 5/300 lr=0.00100 - loss:0.594, acc:27.820, val_loss:0.596, val_acc:26.250
# Best loss:0.607, Best accuracy:26.250, Best F1-score:0.226
# 6/300 lr=0.00100 - loss:0.585, acc:30.412, val_loss:0.589, val_acc:30.625
# Best loss:0.607, Best accuracy:26.250, Best F1-score:0.226
# 7/300 lr=0.00100 - loss:0.578, acc:31.784, val_loss:0.572, val_acc:31.250
# Best loss:0.589, Best accuracy:30.625, Best F1-score:0.252
# 8/300 lr=0.00100 - loss:0.566, acc:34.909, val_loss:0.558, val_acc:35.000
# Best loss:0.572, Best accuracy:31.250, Best F1-score:0.262
# 9/300 lr=0.00100 - loss:0.563, acc:34.909, val_loss:0.571, val_acc:31.250
# Best loss:0.558, Best accuracy:35.000, Best F1-score:0.292
# 10/300 lr=0.00100 - loss:0.552, acc:36.662, val_loss:0.538, val_acc:36.250
# Best loss:0.558, Best accuracy:35.000, Best F1-score:0.292
# 11/300 lr=0.00100 - loss:0.551, acc:34.451, val_loss:0.543, val_acc:32.500
# Best loss:0.538, Best accuracy:36.250, Best F1-score:0.289
# 12/300 lr=0.00100 - loss:0.539, acc:38.948, val_loss:0.524, val_acc:36.875
# Best loss:0.538, Best accuracy:36.250, Best F1-score:0.289
# 13/300 lr=0.00100 - loss:0.540, acc:37.500, val_loss:0.531, val_acc:37.500
# Best loss:0.524, Best accuracy:36.875, Best F1-score:0.292
# 14/300 lr=0.00100 - loss:0.527, acc:40.168, val_loss:0.505, val_acc:42.500
# Best loss:0.531, Best accuracy:37.500, Best F1-score:0.314
# 15/300 lr=0.00100 - loss:0.523, acc:41.540, val_loss:0.525, val_acc:38.750
# Best loss:0.505, Best accuracy:42.500, Best F1-score:0.366
# 16/300 lr=0.00100 - loss:0.521, acc:41.387, val_loss:0.487, val_acc:45.625
# Best loss:0.505, Best accuracy:42.500, Best F1-score:0.366
# 17/300 lr=0.00100 - loss:0.512, acc:41.692, val_loss:0.475, val_acc:46.250
# Best loss:0.487, Best accuracy:45.625, Best F1-score:0.400
# 18/300 lr=0.00100 - loss:0.500, acc:43.979, val_loss:0.469, val_acc:46.875
# Best loss:0.475, Best accuracy:46.250, Best F1-score:0.415
# 19/300 lr=0.00100 - loss:0.497, acc:44.893, val_loss:0.461, val_acc:48.125
# Best loss:0.469, Best accuracy:46.875, Best F1-score:0.419
# 20/300 lr=0.00100 - loss:0.489, acc:45.884, val_loss:0.466, val_acc:43.750
# Best loss:0.461, Best accuracy:48.125, Best F1-score:0.427
# 21/300 lr=0.00100 - loss:0.481, acc:47.027, val_loss:0.467, val_acc:46.875
# Best loss:0.461, Best accuracy:48.125, Best F1-score:0.427
# 22/300 lr=0.00100 - loss:0.483, acc:44.970, val_loss:0.443, val_acc:51.250
# Best loss:0.461, Best accuracy:48.125, Best F1-score:0.427
# 23/300 lr=0.00100 - loss:0.479, acc:46.875, val_loss:0.463, val_acc:46.875
# Best loss:0.443, Best accuracy:51.250, Best F1-score:0.473
# 24/300 lr=0.00100 - loss:0.470, acc:50.305, val_loss:0.440, val_acc:51.250
# Best loss:0.443, Best accuracy:51.250, Best F1-score:0.473
# 25/300 lr=0.00100 - loss:0.468, acc:49.619, val_loss:0.442, val_acc:51.875
# Best loss:0.443, Best accuracy:51.250, Best F1-score:0.473
# 26/300 lr=0.00100 - loss:0.461, acc:49.771, val_loss:0.439, val_acc:49.375
# Best loss:0.442, Best accuracy:51.875, Best F1-score:0.459
# 27/300 lr=0.00100 - loss:0.462, acc:50.457, val_loss:0.436, val_acc:46.875
# Best loss:0.442, Best accuracy:51.875, Best F1-score:0.459
# 28/300 lr=0.00100 - loss:0.457, acc:49.314, val_loss:0.445, val_acc:47.500
# Best loss:0.442, Best accuracy:51.875, Best F1-score:0.459
# 29/300 lr=0.00100 - loss:0.453, acc:50.229, val_loss:0.425, val_acc:50.625
# Best loss:0.442, Best accuracy:51.875, Best F1-score:0.459
# 30/300 lr=0.00100 - loss:0.444, acc:53.430, val_loss:0.413, val_acc:49.375
# Best loss:0.442, Best accuracy:51.875, Best F1-score:0.459
# 31/300 lr=0.00100 - loss:0.440, acc:53.201, val_loss:0.411, val_acc:53.125
# Best loss:0.442, Best accuracy:51.875, Best F1-score:0.459
# 32/300 lr=0.00100 - loss:0.442, acc:51.982, val_loss:0.421, val_acc:47.500
# Best loss:0.411, Best accuracy:53.125, Best F1-score:0.484
# 33/300 lr=0.00100 - loss:0.436, acc:52.134, val_loss:0.396, val_acc:56.875
# Best loss:0.411, Best accuracy:53.125, Best F1-score:0.484
# 34/300 lr=0.00100 - loss:0.429, acc:53.811, val_loss:0.386, val_acc:54.375
# Best loss:0.396, Best accuracy:56.875, Best F1-score:0.539
# 35/300 lr=0.00100 - loss:0.413, acc:58.384, val_loss:0.393, val_acc:57.500
# Best loss:0.396, Best accuracy:56.875, Best F1-score:0.539
# 36/300 lr=0.00100 - loss:0.419, acc:54.954, val_loss:0.389, val_acc:54.375
# Best loss:0.393, Best accuracy:57.500, Best F1-score:0.554
# 37/300 lr=0.00100 - loss:0.423, acc:55.030, val_loss:0.381, val_acc:56.250
# Best loss:0.393, Best accuracy:57.500, Best F1-score:0.554
# 38/300 lr=0.00100 - loss:0.426, acc:53.125, val_loss:0.367, val_acc:60.625
# Best loss:0.393, Best accuracy:57.500, Best F1-score:0.554
# 39/300 lr=0.00100 - loss:0.419, acc:55.945, val_loss:0.378, val_acc:59.375
# Best loss:0.367, Best accuracy:60.625, Best F1-score:0.593
# 40/300 lr=0.00100 - loss:0.402, acc:60.213, val_loss:0.390, val_acc:56.250
# Best loss:0.367, Best accuracy:60.625, Best F1-score:0.593
# 41/300 lr=0.00100 - loss:0.405, acc:57.546, val_loss:0.388, val_acc:56.250
# Best loss:0.367, Best accuracy:60.625, Best F1-score:0.593
# 42/300 lr=0.00100 - loss:0.403, acc:56.250, val_loss:0.386, val_acc:53.750
# Best loss:0.367, Best accuracy:60.625, Best F1-score:0.593
# 43/300 lr=0.00100 - loss:0.401, acc:58.460, val_loss:0.367, val_acc:58.750
# Best loss:0.367, Best accuracy:60.625, Best F1-score:0.593
# 44/300 lr=0.00100 - loss:0.400, acc:58.689, val_loss:0.361, val_acc:58.750
# Best loss:0.367, Best accuracy:60.625, Best F1-score:0.593
# 45/300 lr=0.00100 - loss:0.394, acc:58.841, val_loss:0.343, val_acc:60.000
# Best loss:0.367, Best accuracy:60.625, Best F1-score:0.593
# 46/300 lr=0.00100 - loss:0.376, acc:62.576, val_loss:0.344, val_acc:58.750
# Best loss:0.367, Best accuracy:60.625, Best F1-score:0.593
# 47/300 lr=0.00100 - loss:0.390, acc:58.613, val_loss:0.355, val_acc:61.875
# Best loss:0.367, Best accuracy:60.625, Best F1-score:0.593
# 48/300 lr=0.00100 - loss:0.372, acc:63.720, val_loss:0.325, val_acc:65.000
# Best loss:0.355, Best accuracy:61.875, Best F1-score:0.600
# 49/300 lr=0.00100 - loss:0.374, acc:60.213, val_loss:0.335, val_acc:61.875
# Best loss:0.325, Best accuracy:65.000, Best F1-score:0.647
# 50/300 lr=0.00100 - loss:0.379, acc:61.204, val_loss:0.337, val_acc:60.625
# Best loss:0.325, Best accuracy:65.000, Best F1-score:0.647
# 51/300 lr=0.00100 - loss:0.373, acc:62.576, val_loss:0.347, val_acc:61.875
# Best loss:0.325, Best accuracy:65.000, Best F1-score:0.647
# 52/300 lr=0.00100 - loss:0.381, acc:60.290, val_loss:0.349, val_acc:59.375
# Best loss:0.325, Best accuracy:65.000, Best F1-score:0.647
# 53/300 lr=0.00100 - loss:0.362, acc:62.805, val_loss:0.335, val_acc:61.250
# Best loss:0.325, Best accuracy:65.000, Best F1-score:0.647
# 54/300 lr=0.00100 - loss:0.360, acc:64.482, val_loss:0.308, val_acc:67.500
# Best loss:0.325, Best accuracy:65.000, Best F1-score:0.647
# 55/300 lr=0.00100 - loss:0.357, acc:64.177, val_loss:0.296, val_acc:65.625
# Best loss:0.308, Best accuracy:67.500, Best F1-score:0.664
# 56/300 lr=0.00100 - loss:0.353, acc:65.015, val_loss:0.295, val_acc:65.625
# Best loss:0.308, Best accuracy:67.500, Best F1-score:0.664
# 57/300 lr=0.00100 - loss:0.360, acc:63.415, val_loss:0.326, val_acc:59.375
# Best loss:0.308, Best accuracy:67.500, Best F1-score:0.664
# 58/300 lr=0.00100 - loss:0.351, acc:64.558, val_loss:0.288, val_acc:66.875
# Best loss:0.308, Best accuracy:67.500, Best F1-score:0.664
# 59/300 lr=0.00100 - loss:0.345, acc:66.082, val_loss:0.314, val_acc:63.750
# Best loss:0.308, Best accuracy:67.500, Best F1-score:0.664
# 60/300 lr=0.00100 - loss:0.349, acc:66.921, val_loss:0.304, val_acc:68.750
# Best loss:0.308, Best accuracy:67.500, Best F1-score:0.664
# 61/300 lr=0.00100 - loss:0.351, acc:65.701, val_loss:0.305, val_acc:64.375
# Best loss:0.304, Best accuracy:68.750, Best F1-score:0.679
# 62/300 lr=0.00086 - loss:0.339, acc:66.921, val_loss:0.292, val_acc:67.500
# Best loss:0.304, Best accuracy:68.750, Best F1-score:0.679
# 63/300 lr=0.00086 - loss:0.332, acc:68.140, val_loss:0.288, val_acc:66.875
# Best loss:0.304, Best accuracy:68.750, Best F1-score:0.679
# 64/300 lr=0.00086 - loss:0.327, acc:69.360, val_loss:0.272, val_acc:68.750
# Best loss:0.304, Best accuracy:68.750, Best F1-score:0.679
# 65/300 lr=0.00086 - loss:0.334, acc:66.311, val_loss:0.275, val_acc:70.000
# Best loss:0.304, Best accuracy:68.750, Best F1-score:0.679
# 66/300 lr=0.00086 - loss:0.331, acc:66.997, val_loss:0.284, val_acc:65.000
# Best loss:0.275, Best accuracy:70.000, Best F1-score:0.694
# 67/300 lr=0.00086 - loss:0.333, acc:67.226, val_loss:0.297, val_acc:66.250
# Best loss:0.275, Best accuracy:70.000, Best F1-score:0.694
# 68/300 lr=0.00086 - loss:0.332, acc:68.826, val_loss:0.315, val_acc:61.875
# Best loss:0.275, Best accuracy:70.000, Best F1-score:0.694
# 69/300 lr=0.00086 - loss:0.332, acc:68.369, val_loss:0.287, val_acc:67.500
# Best loss:0.275, Best accuracy:70.000, Best F1-score:0.694
# 70/300 lr=0.00086 - loss:0.316, acc:69.893, val_loss:0.265, val_acc:71.875
# Best loss:0.275, Best accuracy:70.000, Best F1-score:0.694
# 71/300 lr=0.00086 - loss:0.320, acc:69.741, val_loss:0.268, val_acc:72.500
# Best loss:0.265, Best accuracy:71.875, Best F1-score:0.711
# 72/300 lr=0.00086 - loss:0.337, acc:66.463, val_loss:0.280, val_acc:67.500
# Best loss:0.268, Best accuracy:72.500, Best F1-score:0.723
# 73/300 lr=0.00086 - loss:0.333, acc:67.302, val_loss:0.284, val_acc:66.875
# Best loss:0.268, Best accuracy:72.500, Best F1-score:0.723
# 74/300 lr=0.00086 - loss:0.324, acc:68.902, val_loss:0.267, val_acc:68.125
# Best loss:0.268, Best accuracy:72.500, Best F1-score:0.723
# 75/300 lr=0.00086 - loss:0.322, acc:68.902, val_loss:0.252, val_acc:70.625
# Best loss:0.268, Best accuracy:72.500, Best F1-score:0.723
# 76/300 lr=0.00086 - loss:0.313, acc:70.655, val_loss:0.261, val_acc:69.375
# Best loss:0.268, Best accuracy:72.500, Best F1-score:0.723
# 77/300 lr=0.00086 - loss:0.305, acc:72.180, val_loss:0.271, val_acc:67.500
# Best loss:0.268, Best accuracy:72.500, Best F1-score:0.723
# 78/300 lr=0.00086 - loss:0.303, acc:71.189, val_loss:0.277, val_acc:68.750
# Best loss:0.268, Best accuracy:72.500, Best F1-score:0.723
# 79/300 lr=0.00086 - loss:0.308, acc:71.113, val_loss:0.238, val_acc:73.750
# Best loss:0.268, Best accuracy:72.500, Best F1-score:0.723
# 80/300 lr=0.00086 - loss:0.309, acc:71.265, val_loss:0.280, val_acc:65.625
# Best loss:0.238, Best accuracy:73.750, Best F1-score:0.724
# 81/300 lr=0.00086 - loss:0.309, acc:71.799, val_loss:0.261, val_acc:71.250
# Best loss:0.238, Best accuracy:73.750, Best F1-score:0.724
# 82/300 lr=0.00074 - loss:0.294, acc:74.009, val_loss:0.247, val_acc:70.000
# Best loss:0.238, Best accuracy:73.750, Best F1-score:0.724
# 83/300 lr=0.00074 - loss:0.287, acc:74.238, val_loss:0.224, val_acc:73.750
# Best loss:0.238, Best accuracy:73.750, Best F1-score:0.724
# 84/300 lr=0.00074 - loss:0.277, acc:76.524, val_loss:0.223, val_acc:73.750
# Best loss:0.238, Best accuracy:73.750, Best F1-score:0.724
# 85/300 lr=0.00074 - loss:0.280, acc:76.067, val_loss:0.236, val_acc:71.875
# Best loss:0.238, Best accuracy:73.750, Best F1-score:0.724
# 86/300 lr=0.00074 - loss:0.278, acc:76.601, val_loss:0.221, val_acc:75.625
# Best loss:0.238, Best accuracy:73.750, Best F1-score:0.724
# 87/300 lr=0.00074 - loss:0.275, acc:76.524, val_loss:0.215, val_acc:76.875
# Best loss:0.221, Best accuracy:75.625, Best F1-score:0.742
# 88/300 lr=0.00074 - loss:0.285, acc:73.095, val_loss:0.226, val_acc:73.125
# Best loss:0.215, Best accuracy:76.875, Best F1-score:0.769
# 89/300 lr=0.00074 - loss:0.286, acc:73.857, val_loss:0.244, val_acc:73.125
# Best loss:0.215, Best accuracy:76.875, Best F1-score:0.769
# 90/300 lr=0.00074 - loss:0.284, acc:74.162, val_loss:0.253, val_acc:70.625
# Best loss:0.215, Best accuracy:76.875, Best F1-score:0.769
# 91/300 lr=0.00074 - loss:0.283, acc:74.619, val_loss:0.217, val_acc:78.750
# Best loss:0.215, Best accuracy:76.875, Best F1-score:0.769
# 92/300 lr=0.00074 - loss:0.275, acc:76.143, val_loss:0.216, val_acc:76.875
# Best loss:0.217, Best accuracy:78.750, Best F1-score:0.788
# 93/300 lr=0.00074 - loss:0.264, acc:77.896, val_loss:0.227, val_acc:75.000
# Best loss:0.217, Best accuracy:78.750, Best F1-score:0.788
# 94/300 lr=0.00074 - loss:0.262, acc:77.591, val_loss:0.211, val_acc:77.500
# Best loss:0.217, Best accuracy:78.750, Best F1-score:0.788
# 95/300 lr=0.00074 - loss:0.255, acc:79.878, val_loss:0.200, val_acc:79.375
# Best loss:0.217, Best accuracy:78.750, Best F1-score:0.788
# 96/300 lr=0.00074 - loss:0.266, acc:78.125, val_loss:0.206, val_acc:78.125
# Best loss:0.200, Best accuracy:79.375, Best F1-score:0.797
# 97/300 lr=0.00074 - loss:0.258, acc:78.963, val_loss:0.210, val_acc:74.375
# Best loss:0.200, Best accuracy:79.375, Best F1-score:0.797
# 98/300 lr=0.00074 - loss:0.270, acc:76.524, val_loss:0.227, val_acc:75.000
# Best loss:0.200, Best accuracy:79.375, Best F1-score:0.797
# 99/300 lr=0.00074 - loss:0.255, acc:79.954, val_loss:0.207, val_acc:79.375
# Best loss:0.200, Best accuracy:79.375, Best F1-score:0.797
# 100/300 lr=0.00074 - loss:0.253, acc:79.649, val_loss:0.228, val_acc:77.500
# Best loss:0.200, Best accuracy:79.375, Best F1-score:0.797
# 101/300 lr=0.00074 - loss:0.250, acc:79.802, val_loss:0.218, val_acc:74.375
# Best loss:0.200, Best accuracy:79.375, Best F1-score:0.797
# 102/300 lr=0.00064 - loss:0.253, acc:78.430, val_loss:0.245, val_acc:71.875
# Best loss:0.200, Best accuracy:79.375, Best F1-score:0.797
# 103/300 lr=0.00064 - loss:0.256, acc:78.887, val_loss:0.222, val_acc:75.000
# Best loss:0.200, Best accuracy:79.375, Best F1-score:0.797
# 104/300 lr=0.00064 - loss:0.247, acc:80.412, val_loss:0.220, val_acc:76.250
# Best loss:0.200, Best accuracy:79.375, Best F1-score:0.797
# 105/300 lr=0.00064 - loss:0.236, acc:81.784, val_loss:0.207, val_acc:77.500
# Best loss:0.200, Best accuracy:79.375, Best F1-score:0.797
# 106/300 lr=0.00064 - loss:0.243, acc:81.174, val_loss:0.207, val_acc:78.125
# Best loss:0.200, Best accuracy:79.375, Best F1-score:0.797
# 107/300 lr=0.00064 - loss:0.246, acc:80.412, val_loss:0.188, val_acc:79.375
# Best loss:0.200, Best accuracy:79.375, Best F1-score:0.797
# 108/300 lr=0.00064 - loss:0.243, acc:81.098, val_loss:0.193, val_acc:80.625
# Best loss:0.200, Best accuracy:79.375, Best F1-score:0.797
# 109/300 lr=0.00064 - loss:0.230, acc:82.851, val_loss:0.194, val_acc:81.250
# Best loss:0.193, Best accuracy:80.625, Best F1-score:0.793
# 110/300 lr=0.00064 - loss:0.240, acc:81.479, val_loss:0.203, val_acc:76.250
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.814
# 111/300 lr=0.00064 - loss:0.242, acc:80.869, val_loss:0.229, val_acc:75.625
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.814
# 112/300 lr=0.00064 - loss:0.240, acc:82.317, val_loss:0.224, val_acc:74.375
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.814
# 113/300 lr=0.00064 - loss:0.247, acc:79.726, val_loss:0.191, val_acc:78.750
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.814
# 114/300 lr=0.00064 - loss:0.235, acc:81.860, val_loss:0.200, val_acc:79.375
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.814
# 115/300 lr=0.00064 - loss:0.231, acc:82.851, val_loss:0.197, val_acc:80.625
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.814
# 116/300 lr=0.00064 - loss:0.230, acc:81.936, val_loss:0.195, val_acc:76.875
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.814
# 117/300 lr=0.00064 - loss:0.238, acc:81.936, val_loss:0.216, val_acc:75.000
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.814
# 118/300 lr=0.00064 - loss:0.234, acc:82.317, val_loss:0.188, val_acc:80.000
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.814
# 119/300 lr=0.00064 - loss:0.230, acc:82.317, val_loss:0.174, val_acc:83.125
# Best loss:0.194, Best accuracy:81.250, Best F1-score:0.814
# 120/300 lr=0.00064 - loss:0.221, acc:83.841, val_loss:0.195, val_acc:79.375
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 121/300 lr=0.00064 - loss:0.228, acc:82.546, val_loss:0.194, val_acc:76.875
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 122/300 lr=0.00055 - loss:0.219, acc:84.604, val_loss:0.188, val_acc:78.750
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 123/300 lr=0.00055 - loss:0.226, acc:83.689, val_loss:0.191, val_acc:80.000
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 124/300 lr=0.00055 - loss:0.223, acc:82.927, val_loss:0.196, val_acc:77.500
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 125/300 lr=0.00055 - loss:0.218, acc:84.451, val_loss:0.172, val_acc:82.500
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 126/300 lr=0.00055 - loss:0.218, acc:83.994, val_loss:0.180, val_acc:79.375
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 127/300 lr=0.00055 - loss:0.215, acc:84.985, val_loss:0.184, val_acc:80.625
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 128/300 lr=0.00055 - loss:0.208, acc:86.280, val_loss:0.202, val_acc:78.125
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 129/300 lr=0.00055 - loss:0.212, acc:85.899, val_loss:0.195, val_acc:80.625
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 130/300 lr=0.00055 - loss:0.207, acc:86.585, val_loss:0.192, val_acc:79.375
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 131/300 lr=0.00055 - loss:0.208, acc:85.671, val_loss:0.172, val_acc:81.250
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 132/300 lr=0.00055 - loss:0.208, acc:86.128, val_loss:0.159, val_acc:83.125
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 133/300 lr=0.00055 - loss:0.203, acc:87.271, val_loss:0.168, val_acc:81.875
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 134/300 lr=0.00055 - loss:0.210, acc:84.527, val_loss:0.172, val_acc:79.375
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 135/300 lr=0.00055 - loss:0.209, acc:86.052, val_loss:0.194, val_acc:78.750
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 136/300 lr=0.00055 - loss:0.216, acc:84.909, val_loss:0.217, val_acc:75.000
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 137/300 lr=0.00055 - loss:0.212, acc:85.061, val_loss:0.180, val_acc:80.625
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 138/300 lr=0.00055 - loss:0.208, acc:86.128, val_loss:0.179, val_acc:80.625
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 139/300 lr=0.00055 - loss:0.205, acc:85.518, val_loss:0.167, val_acc:82.500
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 140/300 lr=0.00055 - loss:0.205, acc:85.518, val_loss:0.159, val_acc:82.500
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 141/300 lr=0.00055 - loss:0.207, acc:86.357, val_loss:0.173, val_acc:81.875
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 142/300 lr=0.00047 - loss:0.203, acc:87.119, val_loss:0.195, val_acc:80.000
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 143/300 lr=0.00047 - loss:0.204, acc:86.738, val_loss:0.184, val_acc:78.750
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 144/300 lr=0.00047 - loss:0.197, acc:87.576, val_loss:0.194, val_acc:79.375
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 145/300 lr=0.00047 - loss:0.197, acc:86.890, val_loss:0.188, val_acc:80.000
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 146/300 lr=0.00047 - loss:0.196, acc:87.271, val_loss:0.205, val_acc:77.500
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 147/300 lr=0.00047 - loss:0.202, acc:86.585, val_loss:0.204, val_acc:76.875
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 148/300 lr=0.00047 - loss:0.194, acc:88.338, val_loss:0.181, val_acc:82.500
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 149/300 lr=0.00047 - loss:0.197, acc:87.043, val_loss:0.164, val_acc:81.250
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 150/300 lr=0.00047 - loss:0.190, acc:88.415, val_loss:0.151, val_acc:83.750
# Best loss:0.174, Best accuracy:83.125, Best F1-score:0.834
# 151/300 lr=0.00047 - loss:0.191, acc:88.643, val_loss:0.161, val_acc:82.500
# Best loss:0.151, Best accuracy:83.750, Best F1-score:0.838
# 152/300 lr=0.00047 - loss:0.198, acc:87.119, val_loss:0.159, val_acc:81.250
# Best loss:0.151, Best accuracy:83.750, Best F1-score:0.838
# 153/300 lr=0.00047 - loss:0.185, acc:89.863, val_loss:0.156, val_acc:82.500
# Best loss:0.151, Best accuracy:83.750, Best F1-score:0.838
# 154/300 lr=0.00047 - loss:0.186, acc:88.491, val_loss:0.170, val_acc:78.125
# Best loss:0.151, Best accuracy:83.750, Best F1-score:0.838
# 155/300 lr=0.00047 - loss:0.176, acc:91.006, val_loss:0.160, val_acc:83.125
# Best loss:0.151, Best accuracy:83.750, Best F1-score:0.838
# 156/300 lr=0.00047 - loss:0.182, acc:89.939, val_loss:0.150, val_acc:85.625
# Best loss:0.151, Best accuracy:83.750, Best F1-score:0.838
# 157/300 lr=0.00047 - loss:0.178, acc:89.329, val_loss:0.166, val_acc:81.875
# Best loss:0.150, Best accuracy:85.625, Best F1-score:0.863
# 158/300 lr=0.00047 - loss:0.184, acc:89.710, val_loss:0.177, val_acc:79.375
# Best loss:0.150, Best accuracy:85.625, Best F1-score:0.863
# 159/300 lr=0.00047 - loss:0.187, acc:89.405, val_loss:0.169, val_acc:80.625
# Best loss:0.150, Best accuracy:85.625, Best F1-score:0.863
# 160/300 lr=0.00047 - loss:0.182, acc:88.872, val_loss:0.146, val_acc:83.750
# Best loss:0.150, Best accuracy:85.625, Best F1-score:0.863
# 161/300 lr=0.00047 - loss:0.183, acc:89.634, val_loss:0.145, val_acc:86.875
# Best loss:0.150, Best accuracy:85.625, Best F1-score:0.863
# 162/300 lr=0.00041 - loss:0.181, acc:89.787, val_loss:0.155, val_acc:84.375
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 163/300 lr=0.00041 - loss:0.181, acc:89.939, val_loss:0.151, val_acc:83.125
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 164/300 lr=0.00041 - loss:0.175, acc:90.701, val_loss:0.173, val_acc:77.500
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 165/300 lr=0.00041 - loss:0.177, acc:89.787, val_loss:0.170, val_acc:80.000
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 166/300 lr=0.00041 - loss:0.171, acc:90.930, val_loss:0.163, val_acc:82.500
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 167/300 lr=0.00041 - loss:0.180, acc:89.558, val_loss:0.165, val_acc:80.625
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 168/300 lr=0.00041 - loss:0.171, acc:91.311, val_loss:0.159, val_acc:81.250
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 169/300 lr=0.00041 - loss:0.177, acc:89.710, val_loss:0.193, val_acc:78.750
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 170/300 lr=0.00041 - loss:0.176, acc:89.482, val_loss:0.175, val_acc:78.750
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 171/300 lr=0.00041 - loss:0.166, acc:91.845, val_loss:0.149, val_acc:82.500
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 172/300 lr=0.00041 - loss:0.173, acc:90.549, val_loss:0.154, val_acc:82.500
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 173/300 lr=0.00041 - loss:0.180, acc:88.643, val_loss:0.165, val_acc:83.125
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 174/300 lr=0.00041 - loss:0.173, acc:91.159, val_loss:0.167, val_acc:81.250
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 175/300 lr=0.00041 - loss:0.175, acc:90.549, val_loss:0.160, val_acc:81.250
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 176/300 lr=0.00041 - loss:0.170, acc:91.235, val_loss:0.198, val_acc:78.125
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 177/300 lr=0.00041 - loss:0.173, acc:90.091, val_loss:0.169, val_acc:81.250
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 178/300 lr=0.00041 - loss:0.166, acc:91.692, val_loss:0.162, val_acc:81.250
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 179/300 lr=0.00041 - loss:0.166, acc:91.311, val_loss:0.137, val_acc:84.375
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 180/300 lr=0.00041 - loss:0.167, acc:90.930, val_loss:0.167, val_acc:82.500
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 181/300 lr=0.00041 - loss:0.171, acc:90.777, val_loss:0.169, val_acc:81.250
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 182/300 lr=0.00035 - loss:0.170, acc:90.777, val_loss:0.152, val_acc:85.000
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 183/300 lr=0.00035 - loss:0.166, acc:91.311, val_loss:0.152, val_acc:82.500
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 184/300 lr=0.00035 - loss:0.162, acc:91.997, val_loss:0.160, val_acc:81.875
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 185/300 lr=0.00035 - loss:0.167, acc:91.082, val_loss:0.156, val_acc:84.375
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 186/300 lr=0.00035 - loss:0.165, acc:91.845, val_loss:0.150, val_acc:81.875
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 187/300 lr=0.00035 - loss:0.162, acc:92.683, val_loss:0.176, val_acc:78.750
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 188/300 lr=0.00035 - loss:0.162, acc:91.845, val_loss:0.149, val_acc:83.125
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 189/300 lr=0.00035 - loss:0.172, acc:90.930, val_loss:0.154, val_acc:82.500
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 190/300 lr=0.00035 - loss:0.159, acc:92.683, val_loss:0.157, val_acc:81.250
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 191/300 lr=0.00035 - loss:0.158, acc:92.835, val_loss:0.142, val_acc:84.375
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 192/300 lr=0.00035 - loss:0.156, acc:93.369, val_loss:0.165, val_acc:81.250
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 193/300 lr=0.00035 - loss:0.160, acc:92.378, val_loss:0.145, val_acc:84.375
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 194/300 lr=0.00035 - loss:0.162, acc:92.302, val_loss:0.144, val_acc:85.625
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 195/300 lr=0.00035 - loss:0.162, acc:92.149, val_loss:0.163, val_acc:80.000
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 196/300 lr=0.00035 - loss:0.161, acc:91.997, val_loss:0.184, val_acc:80.000
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 197/300 lr=0.00035 - loss:0.161, acc:91.768, val_loss:0.152, val_acc:84.375
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 198/300 lr=0.00035 - loss:0.161, acc:92.302, val_loss:0.129, val_acc:86.875
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 199/300 lr=0.00035 - loss:0.160, acc:92.530, val_loss:0.145, val_acc:83.125
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 200/300 lr=0.00035 - loss:0.160, acc:92.607, val_loss:0.150, val_acc:83.125
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 201/300 lr=0.00035 - loss:0.158, acc:93.521, val_loss:0.145, val_acc:84.375
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 202/300 lr=0.00030 - loss:0.158, acc:92.378, val_loss:0.150, val_acc:81.875
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 203/300 lr=0.00030 - loss:0.155, acc:93.521, val_loss:0.167, val_acc:82.500
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 204/300 lr=0.00030 - loss:0.160, acc:91.845, val_loss:0.166, val_acc:81.875
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 205/300 lr=0.00030 - loss:0.158, acc:92.683, val_loss:0.147, val_acc:81.875
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 206/300 lr=0.00030 - loss:0.150, acc:93.979, val_loss:0.151, val_acc:83.750
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 207/300 lr=0.00030 - loss:0.155, acc:93.369, val_loss:0.157, val_acc:81.875
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 208/300 lr=0.00030 - loss:0.153, acc:93.902, val_loss:0.143, val_acc:84.375
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 209/300 lr=0.00030 - loss:0.159, acc:92.683, val_loss:0.177, val_acc:79.375
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 210/300 lr=0.00030 - loss:0.157, acc:92.607, val_loss:0.130, val_acc:86.250
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 211/300 lr=0.00030 - loss:0.158, acc:92.302, val_loss:0.168, val_acc:82.500
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 212/300 lr=0.00030 - loss:0.155, acc:92.607, val_loss:0.184, val_acc:78.125
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 213/300 lr=0.00030 - loss:0.150, acc:94.131, val_loss:0.147, val_acc:85.000
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 214/300 lr=0.00030 - loss:0.143, acc:94.665, val_loss:0.150, val_acc:83.125
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 215/300 lr=0.00030 - loss:0.146, acc:94.207, val_loss:0.141, val_acc:82.500
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 216/300 lr=0.00030 - loss:0.152, acc:93.521, val_loss:0.149, val_acc:82.500
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 217/300 lr=0.00030 - loss:0.152, acc:93.064, val_loss:0.151, val_acc:81.875
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 218/300 lr=0.00030 - loss:0.149, acc:93.598, val_loss:0.148, val_acc:83.125
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 219/300 lr=0.00030 - loss:0.153, acc:93.369, val_loss:0.150, val_acc:82.500
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 220/300 lr=0.00030 - loss:0.151, acc:93.445, val_loss:0.150, val_acc:83.750
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 221/300 lr=0.00030 - loss:0.150, acc:93.750, val_loss:0.137, val_acc:83.750
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 222/300 lr=0.00026 - loss:0.147, acc:94.588, val_loss:0.155, val_acc:81.875
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 223/300 lr=0.00026 - loss:0.153, acc:93.216, val_loss:0.145, val_acc:82.500
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 224/300 lr=0.00026 - loss:0.151, acc:93.598, val_loss:0.144, val_acc:83.125
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 225/300 lr=0.00026 - loss:0.153, acc:92.988, val_loss:0.159, val_acc:81.250
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 226/300 lr=0.00026 - loss:0.152, acc:93.216, val_loss:0.156, val_acc:80.625
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 227/300 lr=0.00026 - loss:0.151, acc:93.674, val_loss:0.142, val_acc:84.375
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 228/300 lr=0.00026 - loss:0.147, acc:93.902, val_loss:0.139, val_acc:83.750
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 229/300 lr=0.00026 - loss:0.146, acc:94.207, val_loss:0.166, val_acc:80.000
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 230/300 lr=0.00026 - loss:0.146, acc:94.284, val_loss:0.144, val_acc:83.125
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 231/300 lr=0.00026 - loss:0.152, acc:93.598, val_loss:0.138, val_acc:85.625
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 232/300 lr=0.00026 - loss:0.139, acc:95.351, val_loss:0.148, val_acc:84.375
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 233/300 lr=0.00026 - loss:0.139, acc:95.427, val_loss:0.145, val_acc:85.000
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 234/300 lr=0.00026 - loss:0.142, acc:94.741, val_loss:0.151, val_acc:81.875
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 235/300 lr=0.00026 - loss:0.145, acc:94.131, val_loss:0.155, val_acc:81.875
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 236/300 lr=0.00026 - loss:0.141, acc:95.046, val_loss:0.140, val_acc:85.000
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 237/300 lr=0.00026 - loss:0.144, acc:94.512, val_loss:0.144, val_acc:84.375
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 238/300 lr=0.00026 - loss:0.145, acc:94.360, val_loss:0.130, val_acc:85.625
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 239/300 lr=0.00026 - loss:0.145, acc:94.741, val_loss:0.136, val_acc:86.250
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 240/300 lr=0.00026 - loss:0.140, acc:95.046, val_loss:0.151, val_acc:83.125
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 241/300 lr=0.00026 - loss:0.139, acc:95.732, val_loss:0.155, val_acc:81.250
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 242/300 lr=0.00022 - loss:0.142, acc:94.741, val_loss:0.146, val_acc:83.125
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 243/300 lr=0.00022 - loss:0.140, acc:95.808, val_loss:0.133, val_acc:86.250
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 244/300 lr=0.00022 - loss:0.138, acc:95.655, val_loss:0.150, val_acc:82.500
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 245/300 lr=0.00022 - loss:0.144, acc:94.436, val_loss:0.163, val_acc:80.625
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 246/300 lr=0.00022 - loss:0.143, acc:94.436, val_loss:0.142, val_acc:83.125
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 247/300 lr=0.00022 - loss:0.142, acc:95.579, val_loss:0.144, val_acc:84.375
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 248/300 lr=0.00022 - loss:0.141, acc:94.893, val_loss:0.163, val_acc:80.000
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 249/300 lr=0.00022 - loss:0.140, acc:95.351, val_loss:0.143, val_acc:84.375
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 250/300 lr=0.00022 - loss:0.140, acc:94.970, val_loss:0.131, val_acc:87.500
# Best loss:0.145, Best accuracy:86.875, Best F1-score:0.870
# 251/300 lr=0.00022 - loss:0.138, acc:95.503, val_loss:0.138, val_acc:83.750
# Best loss:0.131, Best accuracy:87.500, Best F1-score:0.873
# 252/300 lr=0.00022 - loss:0.137, acc:95.732, val_loss:0.157, val_acc:81.250
# Best loss:0.131, Best accuracy:87.500, Best F1-score:0.873
# 253/300 lr=0.00022 - loss:0.141, acc:94.512, val_loss:0.161, val_acc:78.750
# Best loss:0.131, Best accuracy:87.500, Best F1-score:0.873
# 254/300 lr=0.00022 - loss:0.136, acc:95.427, val_loss:0.143, val_acc:84.375
# Best loss:0.131, Best accuracy:87.500, Best F1-score:0.873
# 255/300 lr=0.00022 - loss:0.136, acc:95.579, val_loss:0.142, val_acc:84.375
# Best loss:0.131, Best accuracy:87.500, Best F1-score:0.873
# 256/300 lr=0.00022 - loss:0.141, acc:94.970, val_loss:0.146, val_acc:85.000
# Best loss:0.131, Best accuracy:87.500, Best F1-score:0.873
# 257/300 lr=0.00022 - loss:0.137, acc:95.884, val_loss:0.138, val_acc:85.625
# Best loss:0.131, Best accuracy:87.500, Best F1-score:0.873
# 258/300 lr=0.00022 - loss:0.137, acc:95.503, val_loss:0.147, val_acc:83.125
# Best loss:0.131, Best accuracy:87.500, Best F1-score:0.873
# 259/300 lr=0.00022 - loss:0.138, acc:95.884, val_loss:0.141, val_acc:84.375
# Best loss:0.131, Best accuracy:87.500, Best F1-score:0.873
# 260/300 lr=0.00022 - loss:0.140, acc:94.970, val_loss:0.153, val_acc:81.250
# Best loss:0.131, Best accuracy:87.500, Best F1-score:0.873
# 261/300 lr=0.00022 - loss:0.134, acc:96.189, val_loss:0.136, val_acc:85.000
# Best loss:0.131, Best accuracy:87.500, Best F1-score:0.873
# 262/300 lr=0.00019 - loss:0.132, acc:95.884, val_loss:0.136, val_acc:85.625
# Best loss:0.131, Best accuracy:87.500, Best F1-score:0.873
# 263/300 lr=0.00019 - loss:0.136, acc:95.503, val_loss:0.135, val_acc:88.125
# Best loss:0.131, Best accuracy:87.500, Best F1-score:0.873
# 264/300 lr=0.00019 - loss:0.136, acc:95.655, val_loss:0.148, val_acc:83.750
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 265/300 lr=0.00019 - loss:0.131, acc:95.808, val_loss:0.132, val_acc:85.625
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 266/300 lr=0.00019 - loss:0.137, acc:95.732, val_loss:0.142, val_acc:83.750
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 267/300 lr=0.00019 - loss:0.137, acc:95.884, val_loss:0.138, val_acc:86.250
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 268/300 lr=0.00019 - loss:0.134, acc:95.960, val_loss:0.129, val_acc:84.375
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 269/300 lr=0.00019 - loss:0.136, acc:95.427, val_loss:0.135, val_acc:85.000
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 270/300 lr=0.00019 - loss:0.133, acc:95.732, val_loss:0.140, val_acc:84.375
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 271/300 lr=0.00019 - loss:0.133, acc:96.646, val_loss:0.132, val_acc:86.250
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 272/300 lr=0.00019 - loss:0.134, acc:95.960, val_loss:0.129, val_acc:86.875
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 273/300 lr=0.00019 - loss:0.131, acc:96.418, val_loss:0.141, val_acc:84.375
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 274/300 lr=0.00019 - loss:0.140, acc:95.274, val_loss:0.133, val_acc:85.625
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 275/300 lr=0.00019 - loss:0.136, acc:95.274, val_loss:0.146, val_acc:85.625
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 276/300 lr=0.00019 - loss:0.133, acc:96.418, val_loss:0.140, val_acc:84.375
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 277/300 lr=0.00019 - loss:0.139, acc:95.198, val_loss:0.125, val_acc:87.500
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 278/300 lr=0.00019 - loss:0.136, acc:95.046, val_loss:0.140, val_acc:86.250
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 279/300 lr=0.00019 - loss:0.134, acc:96.189, val_loss:0.135, val_acc:85.625
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 280/300 lr=0.00019 - loss:0.130, acc:96.951, val_loss:0.137, val_acc:83.750
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 281/300 lr=0.00019 - loss:0.133, acc:95.960, val_loss:0.143, val_acc:83.125
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 282/300 lr=0.00017 - loss:0.130, acc:96.265, val_loss:0.131, val_acc:87.500
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 283/300 lr=0.00017 - loss:0.135, acc:95.884, val_loss:0.140, val_acc:83.750
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 284/300 lr=0.00017 - loss:0.126, acc:97.256, val_loss:0.130, val_acc:86.250
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 285/300 lr=0.00017 - loss:0.129, acc:97.027, val_loss:0.141, val_acc:85.625
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 286/300 lr=0.00017 - loss:0.127, acc:96.570, val_loss:0.137, val_acc:85.000
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 287/300 lr=0.00017 - loss:0.132, acc:95.960, val_loss:0.137, val_acc:85.000
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 288/300 lr=0.00017 - loss:0.130, acc:96.418, val_loss:0.122, val_acc:87.500
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 289/300 lr=0.00017 - loss:0.132, acc:95.960, val_loss:0.127, val_acc:86.875
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 290/300 lr=0.00017 - loss:0.129, acc:96.494, val_loss:0.131, val_acc:86.875
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 291/300 lr=0.00017 - loss:0.130, acc:96.494, val_loss:0.139, val_acc:85.625
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 292/300 lr=0.00017 - loss:0.131, acc:96.646, val_loss:0.126, val_acc:86.250
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 293/300 lr=0.00017 - loss:0.126, acc:97.637, val_loss:0.128, val_acc:85.625
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 294/300 lr=0.00017 - loss:0.131, acc:96.646, val_loss:0.130, val_acc:87.500
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 295/300 lr=0.00017 - loss:0.134, acc:96.113, val_loss:0.137, val_acc:85.000
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 296/300 lr=0.00017 - loss:0.131, acc:95.884, val_loss:0.150, val_acc:84.375
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 297/300 lr=0.00017 - loss:0.131, acc:96.418, val_loss:0.128, val_acc:86.250
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 298/300 lr=0.00017 - loss:0.129, acc:96.723, val_loss:0.131, val_acc:86.875
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 299/300 lr=0.00017 - loss:0.130, acc:96.494, val_loss:0.128, val_acc:86.250
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# 300/300 lr=0.00017 - loss:0.127, acc:97.104, val_loss:0.139, val_acc:84.375
# Best loss:0.135, Best accuracy:88.125, Best F1-score:0.879
# [*] Done - acc:88.125
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.632, acc:15.701, val_loss:0.635, val_acc:21.875
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.615, acc:22.180, val_loss:0.621, val_acc:25.625
# Best loss:0.635, Best accuracy:21.875, Best F1-score:0.126
# 3/300 lr=0.00100 - loss:0.605, acc:23.704, val_loss:0.610, val_acc:31.250
# Best loss:0.621, Best accuracy:25.625, Best F1-score:0.160
# 4/300 lr=0.00100 - loss:0.596, acc:26.905, val_loss:0.612, val_acc:25.000
# Best loss:0.610, Best accuracy:31.250, Best F1-score:0.224
# 5/300 lr=0.00100 - loss:0.586, acc:29.649, val_loss:0.583, val_acc:30.625
# Best loss:0.610, Best accuracy:31.250, Best F1-score:0.224
# 6/300 lr=0.00100 - loss:0.578, acc:31.860, val_loss:0.575, val_acc:31.250
# Best loss:0.610, Best accuracy:31.250, Best F1-score:0.224
# 7/300 lr=0.00100 - loss:0.579, acc:29.268, val_loss:0.561, val_acc:35.000
# Best loss:0.610, Best accuracy:31.250, Best F1-score:0.224
# 8/300 lr=0.00100 - loss:0.568, acc:31.860, val_loss:0.552, val_acc:36.250
# Best loss:0.561, Best accuracy:35.000, Best F1-score:0.294
# 9/300 lr=0.00100 - loss:0.562, acc:32.851, val_loss:0.557, val_acc:30.625
# Best loss:0.552, Best accuracy:36.250, Best F1-score:0.294
# 10/300 lr=0.00100 - loss:0.554, acc:36.128, val_loss:0.545, val_acc:36.250
# Best loss:0.552, Best accuracy:36.250, Best F1-score:0.294
# 11/300 lr=0.00100 - loss:0.552, acc:34.985, val_loss:0.539, val_acc:39.375
# Best loss:0.552, Best accuracy:36.250, Best F1-score:0.294
# 12/300 lr=0.00100 - loss:0.544, acc:36.890, val_loss:0.574, val_acc:29.375
# Best loss:0.539, Best accuracy:39.375, Best F1-score:0.327
# 13/300 lr=0.00100 - loss:0.543, acc:35.899, val_loss:0.540, val_acc:35.000
# Best loss:0.539, Best accuracy:39.375, Best F1-score:0.327
# 14/300 lr=0.00100 - loss:0.539, acc:36.890, val_loss:0.533, val_acc:36.875
# Best loss:0.539, Best accuracy:39.375, Best F1-score:0.327
# 15/300 lr=0.00100 - loss:0.530, acc:39.710, val_loss:0.550, val_acc:34.375
# Best loss:0.539, Best accuracy:39.375, Best F1-score:0.327
# 16/300 lr=0.00100 - loss:0.518, acc:42.226, val_loss:0.539, val_acc:33.750
# Best loss:0.539, Best accuracy:39.375, Best F1-score:0.327
# 17/300 lr=0.00100 - loss:0.510, acc:43.140, val_loss:0.525, val_acc:39.375
# Best loss:0.539, Best accuracy:39.375, Best F1-score:0.327
# 18/300 lr=0.00100 - loss:0.508, acc:44.131, val_loss:0.508, val_acc:41.250
# Best loss:0.539, Best accuracy:39.375, Best F1-score:0.327
# 19/300 lr=0.00100 - loss:0.501, acc:43.445, val_loss:0.545, val_acc:30.625
# Best loss:0.508, Best accuracy:41.250, Best F1-score:0.366
# 20/300 lr=0.00100 - loss:0.497, acc:44.131, val_loss:0.496, val_acc:41.875
# Best loss:0.508, Best accuracy:41.250, Best F1-score:0.366
# 21/300 lr=0.00100 - loss:0.491, acc:44.284, val_loss:0.522, val_acc:38.125
# Best loss:0.496, Best accuracy:41.875, Best F1-score:0.366
# 22/300 lr=0.00100 - loss:0.486, acc:45.427, val_loss:0.495, val_acc:43.750
# Best loss:0.496, Best accuracy:41.875, Best F1-score:0.366
# 23/300 lr=0.00100 - loss:0.479, acc:46.723, val_loss:0.474, val_acc:44.375
# Best loss:0.495, Best accuracy:43.750, Best F1-score:0.401
# 24/300 lr=0.00100 - loss:0.480, acc:48.323, val_loss:0.513, val_acc:35.625
# Best loss:0.474, Best accuracy:44.375, Best F1-score:0.403
# 25/300 lr=0.00100 - loss:0.473, acc:48.704, val_loss:0.501, val_acc:38.125
# Best loss:0.474, Best accuracy:44.375, Best F1-score:0.403
# 26/300 lr=0.00100 - loss:0.466, acc:48.780, val_loss:0.481, val_acc:43.750
# Best loss:0.474, Best accuracy:44.375, Best F1-score:0.403
# 27/300 lr=0.00100 - loss:0.461, acc:48.933, val_loss:0.464, val_acc:46.250
# Best loss:0.474, Best accuracy:44.375, Best F1-score:0.403
# 28/300 lr=0.00100 - loss:0.464, acc:50.229, val_loss:0.506, val_acc:39.375
# Best loss:0.464, Best accuracy:46.250, Best F1-score:0.429
# 29/300 lr=0.00100 - loss:0.475, acc:47.561, val_loss:0.516, val_acc:38.125
# Best loss:0.464, Best accuracy:46.250, Best F1-score:0.429
# 30/300 lr=0.00100 - loss:0.466, acc:48.171, val_loss:0.490, val_acc:43.125
# Best loss:0.464, Best accuracy:46.250, Best F1-score:0.429
# 31/300 lr=0.00100 - loss:0.479, acc:46.875, val_loss:0.518, val_acc:37.500
# Best loss:0.464, Best accuracy:46.250, Best F1-score:0.429
# 32/300 lr=0.00100 - loss:0.460, acc:49.543, val_loss:0.455, val_acc:48.125
# Best loss:0.464, Best accuracy:46.250, Best F1-score:0.429
# 33/300 lr=0.00100 - loss:0.452, acc:51.524, val_loss:0.448, val_acc:49.375
# Best loss:0.455, Best accuracy:48.125, Best F1-score:0.443
# 34/300 lr=0.00100 - loss:0.449, acc:53.354, val_loss:0.506, val_acc:37.500
# Best loss:0.448, Best accuracy:49.375, Best F1-score:0.466
# 35/300 lr=0.00100 - loss:0.446, acc:50.991, val_loss:0.436, val_acc:49.375
# Best loss:0.448, Best accuracy:49.375, Best F1-score:0.466
# 36/300 lr=0.00100 - loss:0.455, acc:50.076, val_loss:0.500, val_acc:37.500
# Best loss:0.448, Best accuracy:49.375, Best F1-score:0.466
# 37/300 lr=0.00100 - loss:0.439, acc:53.811, val_loss:0.451, val_acc:45.625
# Best loss:0.448, Best accuracy:49.375, Best F1-score:0.466
# 38/300 lr=0.00100 - loss:0.432, acc:54.268, val_loss:0.429, val_acc:52.500
# Best loss:0.448, Best accuracy:49.375, Best F1-score:0.466
# 39/300 lr=0.00100 - loss:0.434, acc:54.116, val_loss:0.497, val_acc:35.000
# Best loss:0.429, Best accuracy:52.500, Best F1-score:0.503
# 40/300 lr=0.00100 - loss:0.427, acc:56.021, val_loss:0.458, val_acc:41.875
# Best loss:0.429, Best accuracy:52.500, Best F1-score:0.503
# 41/300 lr=0.00100 - loss:0.431, acc:54.421, val_loss:0.441, val_acc:46.250
# Best loss:0.429, Best accuracy:52.500, Best F1-score:0.503
# 42/300 lr=0.00100 - loss:0.426, acc:54.192, val_loss:0.510, val_acc:35.000
# Best loss:0.429, Best accuracy:52.500, Best F1-score:0.503
# 43/300 lr=0.00100 - loss:0.432, acc:53.430, val_loss:0.460, val_acc:41.250
# Best loss:0.429, Best accuracy:52.500, Best F1-score:0.503
# 44/300 lr=0.00100 - loss:0.431, acc:52.744, val_loss:0.443, val_acc:45.625
# Best loss:0.429, Best accuracy:52.500, Best F1-score:0.503
# 45/300 lr=0.00100 - loss:0.424, acc:54.802, val_loss:0.434, val_acc:49.375
# Best loss:0.429, Best accuracy:52.500, Best F1-score:0.503
# 46/300 lr=0.00100 - loss:0.420, acc:55.259, val_loss:0.438, val_acc:46.250
# Best loss:0.429, Best accuracy:52.500, Best F1-score:0.503
# 47/300 lr=0.00100 - loss:0.409, acc:56.479, val_loss:0.442, val_acc:46.875
# Best loss:0.429, Best accuracy:52.500, Best F1-score:0.503
# 48/300 lr=0.00100 - loss:0.398, acc:58.537, val_loss:0.499, val_acc:37.500
# Best loss:0.429, Best accuracy:52.500, Best F1-score:0.503
# 49/300 lr=0.00100 - loss:0.405, acc:56.707, val_loss:0.402, val_acc:53.750
# Best loss:0.429, Best accuracy:52.500, Best F1-score:0.503
# 50/300 lr=0.00100 - loss:0.398, acc:57.927, val_loss:0.456, val_acc:40.625
# Best loss:0.402, Best accuracy:53.750, Best F1-score:0.521
# 51/300 lr=0.00100 - loss:0.402, acc:57.546, val_loss:0.407, val_acc:50.625
# Best loss:0.402, Best accuracy:53.750, Best F1-score:0.521
# 52/300 lr=0.00100 - loss:0.397, acc:58.994, val_loss:0.412, val_acc:52.500
# Best loss:0.402, Best accuracy:53.750, Best F1-score:0.521
# 53/300 lr=0.00100 - loss:0.393, acc:58.994, val_loss:0.432, val_acc:45.625
# Best loss:0.402, Best accuracy:53.750, Best F1-score:0.521
# 54/300 lr=0.00100 - loss:0.390, acc:58.994, val_loss:0.409, val_acc:51.875
# Best loss:0.402, Best accuracy:53.750, Best F1-score:0.521
# 55/300 lr=0.00100 - loss:0.394, acc:58.689, val_loss:0.481, val_acc:38.125
# Best loss:0.402, Best accuracy:53.750, Best F1-score:0.521
# 56/300 lr=0.00100 - loss:0.388, acc:60.899, val_loss:0.384, val_acc:54.375
# Best loss:0.402, Best accuracy:53.750, Best F1-score:0.521
# ...
# 183/300 lr=0.00035 - loss:0.180, acc:89.024, val_loss:0.217, val_acc:74.375
# Best loss:0.205, Best accuracy:80.000, Best F1-score:0.790
# 184/300 lr=0.00035 - loss:0.177, acc:89.939, val_loss:0.235, val_acc:73.125
# Best loss:0.205, Best accuracy:80.000, Best F1-score:0.790
# 185/300 lr=0.00035 - loss:0.171, acc:91.159, val_loss:0.202, val_acc:76.875
# Best loss:0.205, Best accuracy:80.000, Best F1-score:0.790
# 186/300 lr=0.00035 - loss:0.170, acc:91.540, val_loss:0.213, val_acc:76.250
# Best loss:0.205, Best accuracy:80.000, Best F1-score:0.790
# 187/300 lr=0.00035 - loss:0.171, acc:90.777, val_loss:0.217, val_acc:78.750
# Best loss:0.205, Best accuracy:80.000, Best F1-score:0.790
# 188/300 lr=0.00035 - loss:0.173, acc:90.777, val_loss:0.229, val_acc:71.250
# Best loss:0.205, Best accuracy:80.000, Best F1-score:0.790
# 189/300 lr=0.00035 - loss:0.168, acc:91.387, val_loss:0.186, val_acc:81.250
# Best loss:0.205, Best accuracy:80.000, Best F1-score:0.790
# 190/300 lr=0.00035 - loss:0.167, acc:91.768, val_loss:0.226, val_acc:75.625
# Best loss:0.186, Best accuracy:81.250, Best F1-score:0.808
# 191/300 lr=0.00035 - loss:0.176, acc:90.244, val_loss:0.196, val_acc:80.000
# Best loss:0.186, Best accuracy:81.250, Best F1-score:0.808
# 192/300 lr=0.00035 - loss:0.166, acc:91.845, val_loss:0.204, val_acc:78.750
# Best loss:0.186, Best accuracy:81.250, Best F1-score:0.808
# 193/300 lr=0.00035 - loss:0.156, acc:92.530, val_loss:0.212, val_acc:78.125
# Best loss:0.186, Best accuracy:81.250, Best F1-score:0.808
# 194/300 lr=0.00035 - loss:0.169, acc:91.311, val_loss:0.249, val_acc:73.750
# Best loss:0.186, Best accuracy:81.250, Best F1-score:0.808
# 195/300 lr=0.00035 - loss:0.171, acc:90.625, val_loss:0.203, val_acc:77.500
# Best loss:0.186, Best accuracy:81.250, Best F1-score:0.808
# 196/300 lr=0.00035 - loss:0.166, acc:92.073, val_loss:0.183, val_acc:79.375
# Best loss:0.186, Best accuracy:81.250, Best F1-score:0.808
# 197/300 lr=0.00035 - loss:0.164, acc:91.616, val_loss:0.175, val_acc:83.125
# Best loss:0.186, Best accuracy:81.250, Best F1-score:0.808
# 198/300 lr=0.00035 - loss:0.164, acc:91.540, val_loss:0.205, val_acc:78.750
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 199/300 lr=0.00035 - loss:0.164, acc:92.530, val_loss:0.227, val_acc:78.125
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 200/300 lr=0.00035 - loss:0.162, acc:92.454, val_loss:0.203, val_acc:80.625
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 201/300 lr=0.00035 - loss:0.161, acc:92.835, val_loss:0.213, val_acc:77.500
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 202/300 lr=0.00030 - loss:0.159, acc:92.683, val_loss:0.195, val_acc:80.000
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 203/300 lr=0.00030 - loss:0.166, acc:91.692, val_loss:0.210, val_acc:79.375
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 204/300 lr=0.00030 - loss:0.162, acc:92.378, val_loss:0.189, val_acc:77.500
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 205/300 lr=0.00030 - loss:0.164, acc:91.845, val_loss:0.183, val_acc:82.500
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 206/300 lr=0.00030 - loss:0.162, acc:91.921, val_loss:0.187, val_acc:79.375
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 207/300 lr=0.00030 - loss:0.162, acc:92.302, val_loss:0.198, val_acc:79.375
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 208/300 lr=0.00030 - loss:0.158, acc:93.140, val_loss:0.199, val_acc:78.125
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 209/300 lr=0.00030 - loss:0.157, acc:93.293, val_loss:0.193, val_acc:78.750
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 210/300 lr=0.00030 - loss:0.163, acc:91.311, val_loss:0.200, val_acc:80.000
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 211/300 lr=0.00030 - loss:0.159, acc:92.683, val_loss:0.201, val_acc:79.375
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 212/300 lr=0.00030 - loss:0.157, acc:92.835, val_loss:0.193, val_acc:80.000
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 213/300 lr=0.00030 - loss:0.155, acc:93.064, val_loss:0.194, val_acc:79.375
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 214/300 lr=0.00030 - loss:0.153, acc:93.140, val_loss:0.168, val_acc:82.500
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 215/300 lr=0.00030 - loss:0.147, acc:94.055, val_loss:0.184, val_acc:81.250
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 216/300 lr=0.00030 - loss:0.153, acc:93.674, val_loss:0.186, val_acc:80.000
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 217/300 lr=0.00030 - loss:0.158, acc:92.226, val_loss:0.193, val_acc:80.625
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 218/300 lr=0.00030 - loss:0.161, acc:91.768, val_loss:0.168, val_acc:81.875
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 219/300 lr=0.00030 - loss:0.154, acc:93.140, val_loss:0.190, val_acc:80.000
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 220/300 lr=0.00030 - loss:0.150, acc:94.436, val_loss:0.185, val_acc:81.250
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 221/300 lr=0.00030 - loss:0.153, acc:93.369, val_loss:0.194, val_acc:80.625
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 222/300 lr=0.00026 - loss:0.153, acc:93.369, val_loss:0.197, val_acc:79.375
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 223/300 lr=0.00026 - loss:0.152, acc:93.598, val_loss:0.198, val_acc:80.625
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 224/300 lr=0.00026 - loss:0.147, acc:93.902, val_loss:0.183, val_acc:80.625
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 225/300 lr=0.00026 - loss:0.151, acc:93.369, val_loss:0.197, val_acc:81.250
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 226/300 lr=0.00026 - loss:0.149, acc:94.207, val_loss:0.172, val_acc:81.875
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 227/300 lr=0.00026 - loss:0.149, acc:93.826, val_loss:0.202, val_acc:80.000
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 228/300 lr=0.00026 - loss:0.151, acc:94.131, val_loss:0.177, val_acc:79.375
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 229/300 lr=0.00026 - loss:0.155, acc:92.454, val_loss:0.182, val_acc:79.375
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 230/300 lr=0.00026 - loss:0.144, acc:95.351, val_loss:0.199, val_acc:80.625
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 231/300 lr=0.00026 - loss:0.147, acc:93.826, val_loss:0.209, val_acc:76.875
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 232/300 lr=0.00026 - loss:0.152, acc:93.445, val_loss:0.177, val_acc:81.250
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 233/300 lr=0.00026 - loss:0.146, acc:94.741, val_loss:0.167, val_acc:83.750
# Best loss:0.175, Best accuracy:83.125, Best F1-score:0.825
# 234/300 lr=0.00026 - loss:0.149, acc:94.055, val_loss:0.194, val_acc:80.625
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 235/300 lr=0.00026 - loss:0.152, acc:93.750, val_loss:0.165, val_acc:81.875
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 236/300 lr=0.00026 - loss:0.149, acc:94.284, val_loss:0.175, val_acc:83.125
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 237/300 lr=0.00026 - loss:0.150, acc:93.598, val_loss:0.189, val_acc:78.125
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 238/300 lr=0.00026 - loss:0.145, acc:95.198, val_loss:0.184, val_acc:81.875
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 239/300 lr=0.00026 - loss:0.148, acc:93.750, val_loss:0.184, val_acc:81.875
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 240/300 lr=0.00026 - loss:0.147, acc:94.207, val_loss:0.177, val_acc:81.250
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 241/300 lr=0.00026 - loss:0.142, acc:94.970, val_loss:0.178, val_acc:83.125
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 242/300 lr=0.00022 - loss:0.147, acc:94.436, val_loss:0.172, val_acc:81.875
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 243/300 lr=0.00022 - loss:0.149, acc:93.445, val_loss:0.173, val_acc:83.125
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 244/300 lr=0.00022 - loss:0.146, acc:94.207, val_loss:0.172, val_acc:81.875
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 245/300 lr=0.00022 - loss:0.151, acc:93.369, val_loss:0.183, val_acc:81.250
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 246/300 lr=0.00022 - loss:0.144, acc:94.207, val_loss:0.166, val_acc:82.500
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 247/300 lr=0.00022 - loss:0.142, acc:95.046, val_loss:0.168, val_acc:81.875
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 248/300 lr=0.00022 - loss:0.145, acc:94.055, val_loss:0.179, val_acc:81.250
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 249/300 lr=0.00022 - loss:0.142, acc:95.046, val_loss:0.193, val_acc:80.625
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 250/300 lr=0.00022 - loss:0.141, acc:95.427, val_loss:0.174, val_acc:81.250
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 251/300 lr=0.00022 - loss:0.144, acc:94.284, val_loss:0.173, val_acc:83.125
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 252/300 lr=0.00022 - loss:0.142, acc:94.817, val_loss:0.190, val_acc:78.125
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 253/300 lr=0.00022 - loss:0.141, acc:95.198, val_loss:0.162, val_acc:81.250
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 254/300 lr=0.00022 - loss:0.147, acc:93.826, val_loss:0.166, val_acc:82.500
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 255/300 lr=0.00022 - loss:0.143, acc:94.436, val_loss:0.186, val_acc:81.250
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 256/300 lr=0.00022 - loss:0.143, acc:94.588, val_loss:0.171, val_acc:81.875
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 257/300 lr=0.00022 - loss:0.143, acc:95.046, val_loss:0.178, val_acc:81.250
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 258/300 lr=0.00022 - loss:0.138, acc:95.351, val_loss:0.175, val_acc:81.250
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 259/300 lr=0.00022 - loss:0.143, acc:94.436, val_loss:0.168, val_acc:81.875
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 260/300 lr=0.00022 - loss:0.139, acc:95.198, val_loss:0.173, val_acc:81.250
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 261/300 lr=0.00022 - loss:0.140, acc:95.655, val_loss:0.164, val_acc:83.750
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 262/300 lr=0.00019 - loss:0.144, acc:94.893, val_loss:0.183, val_acc:79.375
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 263/300 lr=0.00019 - loss:0.146, acc:94.284, val_loss:0.173, val_acc:81.875
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 264/300 lr=0.00019 - loss:0.143, acc:94.436, val_loss:0.181, val_acc:81.250
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 265/300 lr=0.00019 - loss:0.141, acc:94.665, val_loss:0.166, val_acc:81.250
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 266/300 lr=0.00019 - loss:0.147, acc:94.055, val_loss:0.206, val_acc:78.125
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 267/300 lr=0.00019 - loss:0.149, acc:93.826, val_loss:0.176, val_acc:79.375
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 268/300 lr=0.00019 - loss:0.142, acc:94.970, val_loss:0.176, val_acc:82.500
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 269/300 lr=0.00019 - loss:0.137, acc:95.198, val_loss:0.169, val_acc:81.250
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 270/300 lr=0.00019 - loss:0.138, acc:95.274, val_loss:0.178, val_acc:80.625
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 271/300 lr=0.00019 - loss:0.136, acc:95.503, val_loss:0.174, val_acc:81.875
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 272/300 lr=0.00019 - loss:0.137, acc:95.960, val_loss:0.167, val_acc:83.125
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 273/300 lr=0.00019 - loss:0.138, acc:95.427, val_loss:0.162, val_acc:83.125
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 274/300 lr=0.00019 - loss:0.133, acc:96.265, val_loss:0.164, val_acc:82.500
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 275/300 lr=0.00019 - loss:0.135, acc:95.960, val_loss:0.195, val_acc:78.125
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 276/300 lr=0.00019 - loss:0.136, acc:95.808, val_loss:0.163, val_acc:80.625
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 277/300 lr=0.00019 - loss:0.140, acc:94.741, val_loss:0.177, val_acc:81.250
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 278/300 lr=0.00019 - loss:0.134, acc:96.265, val_loss:0.168, val_acc:83.125
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 279/300 lr=0.00019 - loss:0.134, acc:96.037, val_loss:0.170, val_acc:80.000
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 280/300 lr=0.00019 - loss:0.141, acc:94.893, val_loss:0.182, val_acc:81.250
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 281/300 lr=0.00019 - loss:0.137, acc:96.037, val_loss:0.156, val_acc:83.125
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 282/300 lr=0.00017 - loss:0.145, acc:94.284, val_loss:0.183, val_acc:80.000
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 283/300 lr=0.00017 - loss:0.140, acc:95.351, val_loss:0.194, val_acc:78.750
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 284/300 lr=0.00017 - loss:0.137, acc:95.579, val_loss:0.162, val_acc:83.125
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 285/300 lr=0.00017 - loss:0.136, acc:95.503, val_loss:0.156, val_acc:85.000
# Best loss:0.167, Best accuracy:83.750, Best F1-score:0.832
# 286/300 lr=0.00017 - loss:0.134, acc:96.265, val_loss:0.169, val_acc:82.500
# Best loss:0.156, Best accuracy:85.000, Best F1-score:0.844
# 287/300 lr=0.00017 - loss:0.135, acc:95.808, val_loss:0.173, val_acc:80.625
# Best loss:0.156, Best accuracy:85.000, Best F1-score:0.844
# 288/300 lr=0.00017 - loss:0.133, acc:96.037, val_loss:0.178, val_acc:81.875
# Best loss:0.156, Best accuracy:85.000, Best F1-score:0.844
# 289/300 lr=0.00017 - loss:0.133, acc:96.113, val_loss:0.158, val_acc:83.750
# Best loss:0.156, Best accuracy:85.000, Best F1-score:0.844
# 290/300 lr=0.00017 - loss:0.133, acc:96.418, val_loss:0.179, val_acc:81.250
# Best loss:0.156, Best accuracy:85.000, Best F1-score:0.844
# 291/300 lr=0.00017 - loss:0.135, acc:95.655, val_loss:0.183, val_acc:78.750
# Best loss:0.156, Best accuracy:85.000, Best F1-score:0.844
# 292/300 lr=0.00017 - loss:0.135, acc:95.655, val_loss:0.179, val_acc:81.250
# Best loss:0.156, Best accuracy:85.000, Best F1-score:0.844
# 293/300 lr=0.00017 - loss:0.138, acc:95.655, val_loss:0.187, val_acc:80.000
# Best loss:0.156, Best accuracy:85.000, Best F1-score:0.844
# 294/300 lr=0.00017 - loss:0.136, acc:96.037, val_loss:0.178, val_acc:81.250
# Best loss:0.156, Best accuracy:85.000, Best F1-score:0.844
# 295/300 lr=0.00017 - loss:0.133, acc:96.113, val_loss:0.175, val_acc:83.125
# Best loss:0.156, Best accuracy:85.000, Best F1-score:0.844
# 296/300 lr=0.00017 - loss:0.134, acc:95.960, val_loss:0.179, val_acc:80.625
# Best loss:0.156, Best accuracy:85.000, Best F1-score:0.844
# 297/300 lr=0.00017 - loss:0.135, acc:95.579, val_loss:0.177, val_acc:80.625
# Best loss:0.156, Best accuracy:85.000, Best F1-score:0.844
# 298/300 lr=0.00017 - loss:0.131, acc:96.570, val_loss:0.164, val_acc:82.500
# Best loss:0.156, Best accuracy:85.000, Best F1-score:0.844
# 299/300 lr=0.00017 - loss:0.133, acc:96.494, val_loss:0.172, val_acc:82.500
# Best loss:0.156, Best accuracy:85.000, Best F1-score:0.844
# 300/300 lr=0.00017 - loss:0.137, acc:95.579, val_loss:0.189, val_acc:80.625
# Best loss:0.156, Best accuracy:85.000, Best F1-score:0.844
# [*] Done - acc:85.000

# %%
end()
# Out:
# Webhook status code 404: {"message": "Unknown Webhook", "code": 10015}

# %%
print(f'max:{max(fold_acc)}, min:{min(fold_acc)}, average:{sum(fold_acc)/len(fold_acc)}')
# Out:
# max:88.75, min:76.875, average:85.5

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
# Out:
# WAR(Weighted Average Recall)   : 85.03%
# UAR(Unweighted Average Recall) : 85.03%
