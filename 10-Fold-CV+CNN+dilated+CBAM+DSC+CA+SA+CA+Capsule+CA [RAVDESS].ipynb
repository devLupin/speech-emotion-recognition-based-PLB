# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D, LayerNormalization, MaxPool2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D, DepthwiseConv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = '10-Fold dataset'
DATA_PATH = 'RAVDESS'
CLASS_LABELS = Config.RAVDESS_LABELS
k = 10

# No-reverse : (196,39,1)  ## CA: Channel-attention    ## SA : Self-attention 
# DSC : Depthwise-seperable CNN
model_name = '10-Fold-CV+CNN+dilated+CBAM+DSC+CA+SA+CA+Capsule+CA'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class SpatialGate(tf.keras.Model):
  def __init__(self):
    super(SpatialGate, self).__init__()
    kernel_size = 7
    self.spatial = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', use_bias=False)
    self.bn = BatchNormalization(momentum=0.01, epsilon=1e-5)
    self.relu = Activation('relu')
    
  def call(self, x):
     avg_pool = tf.reduce_mean(x, axis=[3], keepdims=True)
     max_pool = tf.reduce_max(x, axis=[3], keepdims=True)
     x_compress = tf.concat([avg_pool,max_pool], 3)
     
     x_out = self.spatial(x_compress)
     x_out = self.bn(x_out)
     x_out = self.relu(x_out)
     
     scale = tf.math.sigmoid(x_out) # broadcasting
     return x * scale

# %%
class ChannelGate(tf.keras.Model):

  def __init__(self, gate_channels):
    super(ChannelGate, self).__init__()
    self.gate_channels = gate_channels
    self.mlp = Sequential([
        Flatten(),
        Dense(gate_channels // 2, activation='relu'),
        Dense(gate_channels, activation=None)
    ])
  def call(self, x):
    channel_att_sum = None
    
    avg_pool_layer = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    avg_pool = avg_pool_layer(x)
    avg_pool_raw = self.mlp(avg_pool)
    max_pool_layer = MaxPool2D(pool_size=(x.shape[1], x.shape[2]), strides=(x.shape[1], x.shape[2]))
    max_pool = max_pool_layer(x)
    max_pool_raw = self.mlp(max_pool)
    
    channel_att_sum = avg_pool_raw + max_pool_raw
    scale = tf.math.sigmoid(channel_att_sum)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.expand_dims(scale, axis=1)
    scale = tf.tile(scale, [1, x.shape[1], x.shape[2], 1])  # # expand_as in Pytorch
    
    return x * scale

# %%
class CBAM(tf.keras.Model):

  def __init__(self, gate_channels):
    super(CBAM, self).__init__()
    self.ChannelGate = ChannelGate(gate_channels)
    self.SpatialGate = SpatialGate()
  def call(self, x):
    x_out = self.ChannelGate(x)
    x_out = self.SpatialGate(x_out)
    return x_out

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    self.conv = Sequential([
        # depthwise-separable Conv2D
        DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding=padding),
        Conv2D(filters=dim_capsule*n_channels, kernel_size=1),
        
        Reshape(target_shape=[-1, dim_capsule]),
        Lambda(function=PrimaryCapssquash)
    ])
    
  def call(self, inputs):
    return self.conv(inputs)

# %%
class Model(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3, dilation_rate=2),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.2),
    ])
    
    self.cbam = CBAM(64) # sharing
    
    self.primarycap = PrimaryCap()
    self.spatial_attn = SpatialGate()
    
    self.attention = Attention(use_scale=True)
    self.LN = LayerNormalization()
    
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    x = inputs
    
    cap = self.conv1(x)
    cap = cap + self.cbam(cap)
    cap = self.conv2(cap)
    cap = cap + self.cbam(cap)
    
    primarycaps = self.primarycap(cap)
    primarycaps = tf.expand_dims(primarycaps, axis=-1)
    primarycaps = primarycaps + self.spatial_attn(primarycaps)
    primarycaps = tf.squeeze(primarycaps, axis=-1)
    
    cap = primarycaps
    
    sa = self.attention([primarycaps, primarycaps, primarycaps])
    sa = self.LN(sa)
    
    sa = tf.expand_dims(sa, axis=-1)
    sa = sa + self.spatial_attn(sa)
    sa = tf.squeeze(sa, axis=-1)
    
    cap = self.lamb([cap, sa])
    cap = tf.expand_dims(cap, axis=-1)
    cap = cap + self.spatial_attn(cap)
    cap = tf.squeeze(cap, axis=-1)
    
    capsule = self.capsule(cap)
    capsule = tf.expand_dims(capsule, axis=-1)
    capsule = capsule + self.spatial_attn(capsule)
    capsule = tf.squeeze(capsule, axis=-1)
    
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
model = Model(len(CLASS_LABELS))
model.build(input_shape=(None, 196, 39, 1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 97, 18, 64)        1416
#
#  sequential_1 (Sequential)   (None, 46, 7, 64)         37300
#
#  cbam (CBAM)                 multiple                  4294
#
#  primary_cap (PrimaryCap)    multiple                  25600
#
#  spatial_gate_1 (SpatialGate  multiple                 102
#  )
#
#  attention (Attention)       multiple                  1
#
#  layer_normalization (LayerN  multiple                 128
#  ormalization)
#
#  lambda_1 (Lambda)           multiple                  0
#
#  capsule (Capsule)           multiple                  24576
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           multiple                  0
#
#  dense_2 (Dense)             multiple                  520
#
# =================================================================
# Total params: 93,937
# Trainable params: 93,359
# Non-trainable params: 578
# _________________________________________________________________

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}_train.npy', 'rb') as f:
    X = np.load(f)
    y = np.load(f)
y = to_categorical(y,num_classes=len(CLASS_LABELS))

with open(f'{DATA_ROOT}/{DATA_PATH}_test.npy', 'rb') as f:
    X_test = np.load(f)
    y_test = np.load(f)
y_test = to_categorical(y_test,num_classes=len(CLASS_LABELS))
    
print(X.shape, y.shape, X_test.shape, y_test.shape)
# Out:
# (1296, 196, 39) (1296, 8) (144, 196, 39) (144, 8)

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_val_acc = []
fold_test_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)

for i, (train, val) in tqdm(enumerate(kfold.split(X, y)), desc=f'Training {k}-Fold.....'):
    if i < 7: continue
    
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{i}-fold_.h5'
    
    x_train, y_train = X[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_val, y_val = X[val], y[val]
    
    x_train = tf.expand_dims(x_train, axis=-1)
    x_val = tf.expand_dims(x_val, axis=-1)
    x_test = tf.expand_dims(X_test, axis=-1)
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = Model(len(CLASS_LABELS))
    
    best_val_loss = 0x3f3f3f
    best_val_acc = -1
    best_val_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_val = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        val_loss, val_acc, f1s = [], [], []
        for features, labels in batch_val:
            loss, acc, pred = test_step(model, features, labels)
            val_loss.append(loss)
            val_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1*100)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(val_loss)/len(val_loss)
        val_acc = sum(val_acc)/len(val_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_val_loss:.3f}, Best accuracy:{best_val_acc:.3f}, Best F1-score:{best_val_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_val_loss > val_loss:
            best_val_acc = val_acc
            best_val_loss = val_loss
            best_val_f1 = f1_score
            model.save_weights(h5_path)
            
            
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    
    model = Model(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    
    test_acc, test_f1 = [], []
    for features, labels in batch_test:
        best_pred = model(features, training=False)
        emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(labels, axis=1))
        predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
        
        acc = tf.keras.metrics.CategoricalAccuracy()
        acc.update_state(labels, best_pred)
        accuracy = acc.result().numpy()
        test_acc.append(accuracy*100)
        
        f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
        f1_metric.update_state(labels, best_pred)
        f1 = f1_metric.result().numpy()
        test_f1.append(f1*100)
        
        
        
        
    print('*' * 80)
    print(f'[*] Done Fold-{i+1}')
    print(f'best_val_loss:{best_val_loss:.3f}, best_val_acc:{best_val_acc:.3f}, best_val_f1:{best_val_f1:.3f}')
    print(f'test_acc:{(sum(test_acc)/len(test_acc)):.3f}, test_f1:{(sum(test_f1)/len(test_f1)):.3f}')
    print('*' * 80)
    
    plt.title(f'Fold-{i+1} Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    fold_val_acc.append(best_val_acc)
    fold_test_acc.append((sum(test_acc)/len(test_acc)))
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.632, acc:15.298, val_loss:0.628, val_acc:19.375
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.620, acc:19.617, val_loss:0.602, val_acc:22.500
# Best loss:0.628, Best accuracy:19.375, Best F1-score:15.002
# 3/300 lr=0.00100 - loss:0.611, acc:24.780, val_loss:0.592, val_acc:21.875
# Best loss:0.602, Best accuracy:22.500, Best F1-score:17.181
# 4/300 lr=0.00100 - loss:0.605, acc:25.118, val_loss:0.591, val_acc:25.625
# Best loss:0.592, Best accuracy:21.875, Best F1-score:17.588
# 5/300 lr=0.00100 - loss:0.594, acc:27.939, val_loss:0.565, val_acc:28.750
# Best loss:0.591, Best accuracy:25.625, Best F1-score:20.454
# 6/300 lr=0.00100 - loss:0.583, acc:28.615, val_loss:0.582, val_acc:26.875
# Best loss:0.565, Best accuracy:28.750, Best F1-score:24.017
# 7/300 lr=0.00100 - loss:0.574, acc:30.135, val_loss:0.588, val_acc:31.250
# Best loss:0.565, Best accuracy:28.750, Best F1-score:24.017
# 8/300 lr=0.00100 - loss:0.572, acc:31.909, val_loss:0.553, val_acc:28.750
# Best loss:0.565, Best accuracy:28.750, Best F1-score:24.017
# 9/300 lr=0.00100 - loss:0.562, acc:34.178, val_loss:0.605, val_acc:28.125
# Best loss:0.553, Best accuracy:28.750, Best F1-score:23.678
# 10/300 lr=0.00100 - loss:0.558, acc:32.269, val_loss:0.604, val_acc:25.625
# Best loss:0.553, Best accuracy:28.750, Best F1-score:23.678
# 11/300 lr=0.00100 - loss:0.552, acc:33.029, val_loss:0.530, val_acc:30.000
# Best loss:0.553, Best accuracy:28.750, Best F1-score:23.678
# 12/300 lr=0.00100 - loss:0.541, acc:36.132, val_loss:0.489, val_acc:48.750
# Best loss:0.530, Best accuracy:30.000, Best F1-score:24.633
# 13/300 lr=0.00100 - loss:0.533, acc:37.641, val_loss:0.512, val_acc:33.750
# Best loss:0.489, Best accuracy:48.750, Best F1-score:44.693
# 14/300 lr=0.00100 - loss:0.532, acc:37.568, val_loss:0.522, val_acc:30.625
# Best loss:0.489, Best accuracy:48.750, Best F1-score:44.693
# 15/300 lr=0.00100 - loss:0.528, acc:39.172, val_loss:0.512, val_acc:33.750
# Best loss:0.489, Best accuracy:48.750, Best F1-score:44.693
# 16/300 lr=0.00100 - loss:0.518, acc:39.921, val_loss:0.451, val_acc:53.125
# Best loss:0.489, Best accuracy:48.750, Best F1-score:44.693
# 17/300 lr=0.00100 - loss:0.514, acc:40.873, val_loss:0.462, val_acc:55.000
# Best loss:0.451, Best accuracy:53.125, Best F1-score:49.899
# 18/300 lr=0.00100 - loss:0.505, acc:41.948, val_loss:0.540, val_acc:32.500
# Best loss:0.451, Best accuracy:53.125, Best F1-score:49.899
# 19/300 lr=0.00100 - loss:0.501, acc:42.055, val_loss:0.551, val_acc:35.000
# Best loss:0.451, Best accuracy:53.125, Best F1-score:49.899
# 20/300 lr=0.00100 - loss:0.499, acc:43.046, val_loss:0.523, val_acc:31.250
# Best loss:0.451, Best accuracy:53.125, Best F1-score:49.899
# 21/300 lr=0.00100 - loss:0.486, acc:44.133, val_loss:0.511, val_acc:33.750
# Best loss:0.451, Best accuracy:53.125, Best F1-score:49.899
# 22/300 lr=0.00100 - loss:0.487, acc:45.231, val_loss:0.423, val_acc:56.875
# Best loss:0.451, Best accuracy:53.125, Best F1-score:49.899
# 23/300 lr=0.00100 - loss:0.476, acc:46.470, val_loss:0.505, val_acc:37.500
# Best loss:0.423, Best accuracy:56.875, Best F1-score:56.275
# 24/300 lr=0.00100 - loss:0.473, acc:47.945, val_loss:0.530, val_acc:39.375
# Best loss:0.423, Best accuracy:56.875, Best F1-score:56.275
# 25/300 lr=0.00100 - loss:0.470, acc:47.438, val_loss:0.451, val_acc:41.875
# Best loss:0.423, Best accuracy:56.875, Best F1-score:56.275
# 26/300 lr=0.00100 - loss:0.454, acc:50.574, val_loss:0.440, val_acc:41.250
# Best loss:0.423, Best accuracy:56.875, Best F1-score:56.275
# 27/300 lr=0.00100 - loss:0.445, acc:50.957, val_loss:0.520, val_acc:38.125
# Best loss:0.423, Best accuracy:56.875, Best F1-score:56.275
# 28/300 lr=0.00100 - loss:0.450, acc:50.417, val_loss:0.501, val_acc:38.125
# Best loss:0.423, Best accuracy:56.875, Best F1-score:56.275
# 29/300 lr=0.00100 - loss:0.454, acc:49.330, val_loss:0.520, val_acc:38.125
# Best loss:0.423, Best accuracy:56.875, Best F1-score:56.275
# 30/300 lr=0.00100 - loss:0.459, acc:47.461, val_loss:0.556, val_acc:38.750
# Best loss:0.423, Best accuracy:56.875, Best F1-score:56.275
# 31/300 lr=0.00100 - loss:0.443, acc:50.670, val_loss:0.549, val_acc:40.000
# Best loss:0.423, Best accuracy:56.875, Best F1-score:56.275
# 32/300 lr=0.00100 - loss:0.446, acc:51.971, val_loss:0.522, val_acc:42.500
# Best loss:0.423, Best accuracy:56.875, Best F1-score:56.275
# 33/300 lr=0.00100 - loss:0.439, acc:51.672, val_loss:0.498, val_acc:40.625
# Best loss:0.423, Best accuracy:56.875, Best F1-score:56.275
# 34/300 lr=0.00100 - loss:0.442, acc:51.008, val_loss:0.473, val_acc:36.250
# Best loss:0.423, Best accuracy:56.875, Best F1-score:56.275
# 35/300 lr=0.00100 - loss:0.434, acc:52.382, val_loss:0.370, val_acc:60.625
# Best loss:0.423, Best accuracy:56.875, Best F1-score:56.275
# 36/300 lr=0.00100 - loss:0.426, acc:53.153, val_loss:0.358, val_acc:62.500
# Best loss:0.370, Best accuracy:60.625, Best F1-score:60.529
# 37/300 lr=0.00100 - loss:0.428, acc:53.542, val_loss:0.392, val_acc:63.125
# Best loss:0.358, Best accuracy:62.500, Best F1-score:59.891
# 38/300 lr=0.00100 - loss:0.426, acc:53.322, val_loss:0.506, val_acc:39.375
# Best loss:0.358, Best accuracy:62.500, Best F1-score:59.891
# 39/300 lr=0.00100 - loss:0.410, acc:57.027, val_loss:0.347, val_acc:65.000
# Best loss:0.358, Best accuracy:62.500, Best F1-score:59.891
# 40/300 lr=0.00100 - loss:0.409, acc:57.016, val_loss:0.421, val_acc:38.750
# Best loss:0.347, Best accuracy:65.000, Best F1-score:62.563
# 41/300 lr=0.00100 - loss:0.401, acc:57.100, val_loss:0.424, val_acc:43.125
# Best loss:0.347, Best accuracy:65.000, Best F1-score:62.563
# 42/300 lr=0.00100 - loss:0.411, acc:55.169, val_loss:0.517, val_acc:40.000
# Best loss:0.347, Best accuracy:65.000, Best F1-score:62.563
# 43/300 lr=0.00100 - loss:0.410, acc:56.869, val_loss:0.340, val_acc:61.875
# Best loss:0.347, Best accuracy:65.000, Best F1-score:62.563
# 44/300 lr=0.00100 - loss:0.406, acc:58.125, val_loss:0.335, val_acc:63.125
# Best loss:0.340, Best accuracy:61.875, Best F1-score:58.849
# 45/300 lr=0.00100 - loss:0.406, acc:57.162, val_loss:0.442, val_acc:41.250
# Best loss:0.335, Best accuracy:63.125, Best F1-score:62.841
# 46/300 lr=0.00100 - loss:0.392, acc:58.052, val_loss:0.302, val_acc:66.250
# Best loss:0.335, Best accuracy:63.125, Best F1-score:62.841
# 47/300 lr=0.00100 - loss:0.402, acc:56.785, val_loss:0.321, val_acc:63.750
# Best loss:0.302, Best accuracy:66.250, Best F1-score:65.669
# 48/300 lr=0.00100 - loss:0.394, acc:59.245, val_loss:0.315, val_acc:63.125
# Best loss:0.302, Best accuracy:66.250, Best F1-score:65.669
# 49/300 lr=0.00100 - loss:0.379, acc:59.764, val_loss:0.340, val_acc:65.625
# Best loss:0.302, Best accuracy:66.250, Best F1-score:65.669
# 50/300 lr=0.00100 - loss:0.372, acc:61.926, val_loss:0.315, val_acc:65.625
# Best loss:0.302, Best accuracy:66.250, Best F1-score:65.669
# 51/300 lr=0.00100 - loss:0.383, acc:60.828, val_loss:0.286, val_acc:67.500
# Best loss:0.302, Best accuracy:66.250, Best F1-score:65.669
# 52/300 lr=0.00100 - loss:0.389, acc:59.369, val_loss:0.296, val_acc:67.500
# Best loss:0.286, Best accuracy:67.500, Best F1-score:66.730
# 53/300 lr=0.00100 - loss:0.388, acc:59.443, val_loss:0.332, val_acc:63.125
# Best loss:0.286, Best accuracy:67.500, Best F1-score:66.730
# 54/300 lr=0.00100 - loss:0.378, acc:61.515, val_loss:0.271, val_acc:65.000
# Best loss:0.286, Best accuracy:67.500, Best F1-score:66.730
# 55/300 lr=0.00100 - loss:0.356, acc:65.619, val_loss:0.456, val_acc:44.375
# Best loss:0.271, Best accuracy:65.000, Best F1-score:63.420
# 56/300 lr=0.00100 - loss:0.358, acc:63.964, val_loss:0.385, val_acc:42.500
# Best loss:0.271, Best accuracy:65.000, Best F1-score:63.420
# 57/300 lr=0.00100 - loss:0.366, acc:63.384, val_loss:0.324, val_acc:62.500
# Best loss:0.271, Best accuracy:65.000, Best F1-score:63.420
# 58/300 lr=0.00100 - loss:0.352, acc:64.555, val_loss:0.269, val_acc:67.500
# Best loss:0.271, Best accuracy:65.000, Best F1-score:63.420
# 59/300 lr=0.00100 - loss:0.357, acc:64.324, val_loss:0.284, val_acc:67.500
# Best loss:0.269, Best accuracy:67.500, Best F1-score:65.282
# 60/300 lr=0.00100 - loss:0.360, acc:63.891, val_loss:0.286, val_acc:67.500
# Best loss:0.269, Best accuracy:67.500, Best F1-score:65.282
# 61/300 lr=0.00100 - loss:0.345, acc:66.644, val_loss:0.268, val_acc:71.250
# Best loss:0.269, Best accuracy:67.500, Best F1-score:65.282
# 62/300 lr=0.00086 - loss:0.345, acc:65.884, val_loss:0.255, val_acc:70.000
# Best loss:0.268, Best accuracy:71.250, Best F1-score:71.026
# 63/300 lr=0.00086 - loss:0.332, acc:67.922, val_loss:0.288, val_acc:65.625
# Best loss:0.255, Best accuracy:70.000, Best F1-score:69.719
# 64/300 lr=0.00086 - loss:0.336, acc:67.995, val_loss:0.335, val_acc:63.750
# Best loss:0.255, Best accuracy:70.000, Best F1-score:69.719
# 65/300 lr=0.00086 - loss:0.353, acc:63.846, val_loss:0.395, val_acc:44.375
# Best loss:0.255, Best accuracy:70.000, Best F1-score:69.719
# 66/300 lr=0.00086 - loss:0.336, acc:66.751, val_loss:0.307, val_acc:65.000
# Best loss:0.255, Best accuracy:70.000, Best F1-score:69.719
# 67/300 lr=0.00086 - loss:0.338, acc:66.605, val_loss:0.366, val_acc:45.625
# Best loss:0.255, Best accuracy:70.000, Best F1-score:69.719
# 68/300 lr=0.00086 - loss:0.324, acc:70.045, val_loss:0.317, val_acc:67.500
# Best loss:0.255, Best accuracy:70.000, Best F1-score:69.719
# 69/300 lr=0.00086 - loss:0.320, acc:69.465, val_loss:0.261, val_acc:68.750
# Best loss:0.255, Best accuracy:70.000, Best F1-score:69.719
# 70/300 lr=0.00086 - loss:0.313, acc:71.132, val_loss:0.273, val_acc:68.750
# Best loss:0.255, Best accuracy:70.000, Best F1-score:69.719
# 71/300 lr=0.00086 - loss:0.314, acc:70.867, val_loss:0.258, val_acc:70.000
# Best loss:0.255, Best accuracy:70.000, Best F1-score:69.719
# 72/300 lr=0.00086 - loss:0.313, acc:71.239, val_loss:0.246, val_acc:71.250
# Best loss:0.255, Best accuracy:70.000, Best F1-score:69.719
# 73/300 lr=0.00086 - loss:0.301, acc:71.577, val_loss:0.265, val_acc:71.250
# Best loss:0.246, Best accuracy:71.250, Best F1-score:71.939
# 74/300 lr=0.00086 - loss:0.301, acc:72.939, val_loss:0.323, val_acc:48.750
# Best loss:0.246, Best accuracy:71.250, Best F1-score:71.939
# 75/300 lr=0.00086 - loss:0.303, acc:72.337, val_loss:0.248, val_acc:70.000
# Best loss:0.246, Best accuracy:71.250, Best F1-score:71.939
# 76/300 lr=0.00086 - loss:0.295, acc:74.302, val_loss:0.255, val_acc:73.125
# Best loss:0.246, Best accuracy:71.250, Best F1-score:71.939
# 77/300 lr=0.00086 - loss:0.308, acc:72.190, val_loss:0.267, val_acc:67.500
# Best loss:0.246, Best accuracy:71.250, Best F1-score:71.939
# 78/300 lr=0.00086 - loss:0.313, acc:71.588, val_loss:0.285, val_acc:73.125
# Best loss:0.246, Best accuracy:71.250, Best F1-score:71.939
# 79/300 lr=0.00086 - loss:0.309, acc:71.565, val_loss:0.279, val_acc:70.000
# Best loss:0.246, Best accuracy:71.250, Best F1-score:71.939
# 80/300 lr=0.00086 - loss:0.302, acc:72.264, val_loss:0.238, val_acc:74.375
# Best loss:0.246, Best accuracy:71.250, Best F1-score:71.939
# 81/300 lr=0.00086 - loss:0.296, acc:72.652, val_loss:0.224, val_acc:71.875
# Best loss:0.238, Best accuracy:74.375, Best F1-score:74.733
# 82/300 lr=0.00074 - loss:0.304, acc:72.275, val_loss:0.230, val_acc:75.000
# Best loss:0.224, Best accuracy:71.875, Best F1-score:70.384
# 83/300 lr=0.00074 - loss:0.308, acc:71.385, val_loss:0.218, val_acc:73.750
# Best loss:0.224, Best accuracy:71.875, Best F1-score:70.384
# 84/300 lr=0.00074 - loss:0.296, acc:72.928, val_loss:0.237, val_acc:71.250
# Best loss:0.218, Best accuracy:73.750, Best F1-score:72.556
# 85/300 lr=0.00074 - loss:0.289, acc:72.832, val_loss:0.224, val_acc:73.125
# Best loss:0.218, Best accuracy:73.750, Best F1-score:72.556
# 86/300 lr=0.00074 - loss:0.296, acc:72.241, val_loss:0.256, val_acc:73.125
# Best loss:0.218, Best accuracy:73.750, Best F1-score:72.556
# 87/300 lr=0.00074 - loss:0.294, acc:73.288, val_loss:0.219, val_acc:74.375
# Best loss:0.218, Best accuracy:73.750, Best F1-score:72.556
# 88/300 lr=0.00074 - loss:0.280, acc:76.318, val_loss:0.223, val_acc:72.500
# Best loss:0.218, Best accuracy:73.750, Best F1-score:72.556
# 89/300 lr=0.00074 - loss:0.272, acc:76.959, val_loss:0.214, val_acc:74.375
# Best loss:0.218, Best accuracy:73.750, Best F1-score:72.556
# 90/300 lr=0.00074 - loss:0.271, acc:76.042, val_loss:0.258, val_acc:73.750
# Best loss:0.214, Best accuracy:74.375, Best F1-score:73.995
# 91/300 lr=0.00074 - loss:0.276, acc:76.402, val_loss:0.210, val_acc:78.125
# Best loss:0.214, Best accuracy:74.375, Best F1-score:73.995
# 92/300 lr=0.00074 - loss:0.278, acc:76.306, val_loss:0.218, val_acc:73.750
# Best loss:0.210, Best accuracy:78.125, Best F1-score:77.673
# 93/300 lr=0.00074 - loss:0.274, acc:76.042, val_loss:0.207, val_acc:76.250
# Best loss:0.210, Best accuracy:78.125, Best F1-score:77.673
# 94/300 lr=0.00074 - loss:0.266, acc:77.438, val_loss:0.209, val_acc:75.625
# Best loss:0.207, Best accuracy:76.250, Best F1-score:76.028
# 95/300 lr=0.00074 - loss:0.284, acc:73.423, val_loss:0.211, val_acc:73.750
# Best loss:0.207, Best accuracy:76.250, Best F1-score:76.028
# 96/300 lr=0.00074 - loss:0.261, acc:77.680, val_loss:0.193, val_acc:78.750
# Best loss:0.207, Best accuracy:76.250, Best F1-score:76.028
# 97/300 lr=0.00074 - loss:0.256, acc:79.443, val_loss:0.207, val_acc:75.625
# Best loss:0.193, Best accuracy:78.750, Best F1-score:79.127
# 98/300 lr=0.00074 - loss:0.263, acc:77.838, val_loss:0.205, val_acc:75.000
# Best loss:0.193, Best accuracy:78.750, Best F1-score:79.127
# 99/300 lr=0.00074 - loss:0.254, acc:79.538, val_loss:0.209, val_acc:75.000
# Best loss:0.193, Best accuracy:78.750, Best F1-score:79.127
# 100/300 lr=0.00074 - loss:0.259, acc:78.536, val_loss:0.232, val_acc:75.000
# Best loss:0.193, Best accuracy:78.750, Best F1-score:79.127
# 101/300 lr=0.00074 - loss:0.256, acc:78.091, val_loss:0.240, val_acc:73.125
# Best loss:0.193, Best accuracy:78.750, Best F1-score:79.127
# 102/300 lr=0.00064 - loss:0.243, acc:80.214, val_loss:0.199, val_acc:77.500
# Best loss:0.193, Best accuracy:78.750, Best F1-score:79.127
# 103/300 lr=0.00064 - loss:0.250, acc:78.767, val_loss:0.209, val_acc:74.375
# Best loss:0.193, Best accuracy:78.750, Best F1-score:79.127
# 104/300 lr=0.00064 - loss:0.247, acc:79.792, val_loss:0.202, val_acc:78.750
# Best loss:0.193, Best accuracy:78.750, Best F1-score:79.127
# 105/300 lr=0.00064 - loss:0.252, acc:79.127, val_loss:0.203, val_acc:75.625
# Best loss:0.193, Best accuracy:78.750, Best F1-score:79.127
# 106/300 lr=0.00064 - loss:0.256, acc:78.491, val_loss:0.187, val_acc:78.750
# Best loss:0.193, Best accuracy:78.750, Best F1-score:79.127
# 107/300 lr=0.00064 - loss:0.239, acc:81.070, val_loss:0.196, val_acc:76.875
# Best loss:0.187, Best accuracy:78.750, Best F1-score:78.639
# 108/300 lr=0.00064 - loss:0.245, acc:80.467, val_loss:0.183, val_acc:79.375
# Best loss:0.187, Best accuracy:78.750, Best F1-score:78.639
# 109/300 lr=0.00064 - loss:0.241, acc:81.554, val_loss:0.223, val_acc:72.500
# Best loss:0.183, Best accuracy:79.375, Best F1-score:79.137
# 110/300 lr=0.00064 - loss:0.247, acc:80.045, val_loss:0.218, val_acc:75.000
# Best loss:0.183, Best accuracy:79.375, Best F1-score:79.137
# 111/300 lr=0.00064 - loss:0.247, acc:80.372, val_loss:0.291, val_acc:54.375
# Best loss:0.183, Best accuracy:79.375, Best F1-score:79.137
# 112/300 lr=0.00064 - loss:0.237, acc:79.527, val_loss:0.187, val_acc:78.750
# Best loss:0.183, Best accuracy:79.375, Best F1-score:79.137
# 113/300 lr=0.00064 - loss:0.238, acc:82.072, val_loss:0.199, val_acc:76.875
# Best loss:0.183, Best accuracy:79.375, Best F1-score:79.137
# 114/300 lr=0.00064 - loss:0.241, acc:81.047, val_loss:0.203, val_acc:80.000
# Best loss:0.183, Best accuracy:79.375, Best F1-score:79.137
# 115/300 lr=0.00064 - loss:0.242, acc:79.854, val_loss:0.199, val_acc:78.125
# Best loss:0.183, Best accuracy:79.375, Best F1-score:79.137
# 116/300 lr=0.00064 - loss:0.237, acc:81.396, val_loss:0.186, val_acc:79.375
# Best loss:0.183, Best accuracy:79.375, Best F1-score:79.137
# 117/300 lr=0.00064 - loss:0.228, acc:83.148, val_loss:0.216, val_acc:78.125
# Best loss:0.183, Best accuracy:79.375, Best F1-score:79.137
# 118/300 lr=0.00064 - loss:0.228, acc:82.061, val_loss:0.200, val_acc:76.250
# Best loss:0.183, Best accuracy:79.375, Best F1-score:79.137
# 119/300 lr=0.00064 - loss:0.240, acc:80.816, val_loss:0.194, val_acc:78.750
# Best loss:0.183, Best accuracy:79.375, Best F1-score:79.137
# 120/300 lr=0.00064 - loss:0.224, acc:83.423, val_loss:0.182, val_acc:80.625
# Best loss:0.183, Best accuracy:79.375, Best F1-score:79.137
# 121/300 lr=0.00064 - loss:0.225, acc:82.821, val_loss:0.188, val_acc:78.125
# Best loss:0.182, Best accuracy:80.625, Best F1-score:81.169
# 122/300 lr=0.00055 - loss:0.223, acc:83.423, val_loss:0.173, val_acc:79.375
# Best loss:0.182, Best accuracy:80.625, Best F1-score:81.169
# 123/300 lr=0.00055 - loss:0.217, acc:84.932, val_loss:0.179, val_acc:77.500
# Best loss:0.173, Best accuracy:79.375, Best F1-score:79.383
# 124/300 lr=0.00055 - loss:0.214, acc:84.752, val_loss:0.180, val_acc:80.000
# Best loss:0.173, Best accuracy:79.375, Best F1-score:79.383
# 125/300 lr=0.00055 - loss:0.220, acc:83.350, val_loss:0.204, val_acc:76.875
# Best loss:0.173, Best accuracy:79.375, Best F1-score:79.383
# 126/300 lr=0.00055 - loss:0.239, acc:80.214, val_loss:0.165, val_acc:82.500
# Best loss:0.173, Best accuracy:79.375, Best F1-score:79.383
# 127/300 lr=0.00055 - loss:0.233, acc:81.785, val_loss:0.180, val_acc:77.500
# Best loss:0.165, Best accuracy:82.500, Best F1-score:82.687
# 128/300 lr=0.00055 - loss:0.219, acc:83.530, val_loss:0.170, val_acc:80.000
# Best loss:0.165, Best accuracy:82.500, Best F1-score:82.687
# 129/300 lr=0.00055 - loss:0.212, acc:84.521, val_loss:0.175, val_acc:81.875
# Best loss:0.165, Best accuracy:82.500, Best F1-score:82.687
# 130/300 lr=0.00055 - loss:0.208, acc:85.873, val_loss:0.177, val_acc:80.625
# Best loss:0.165, Best accuracy:82.500, Best F1-score:82.687
# 131/300 lr=0.00055 - loss:0.214, acc:85.417, val_loss:0.175, val_acc:79.375
# Best loss:0.165, Best accuracy:82.500, Best F1-score:82.687
# 132/300 lr=0.00055 - loss:0.221, acc:83.530, val_loss:0.186, val_acc:77.500
# Best loss:0.165, Best accuracy:82.500, Best F1-score:82.687
# 133/300 lr=0.00055 - loss:0.223, acc:82.421, val_loss:0.188, val_acc:80.000
# Best loss:0.165, Best accuracy:82.500, Best F1-score:82.687
# 134/300 lr=0.00055 - loss:0.211, acc:84.510, val_loss:0.187, val_acc:77.500
# Best loss:0.165, Best accuracy:82.500, Best F1-score:82.687
# 135/300 lr=0.00055 - loss:0.199, acc:86.909, val_loss:0.171, val_acc:81.250
# Best loss:0.165, Best accuracy:82.500, Best F1-score:82.687
# 136/300 lr=0.00055 - loss:0.205, acc:86.548, val_loss:0.169, val_acc:82.500
# Best loss:0.165, Best accuracy:82.500, Best F1-score:82.687
# 137/300 lr=0.00055 - loss:0.196, acc:87.804, val_loss:0.184, val_acc:79.375
# Best loss:0.165, Best accuracy:82.500, Best F1-score:82.687
# 138/300 lr=0.00055 - loss:0.200, acc:86.295, val_loss:0.167, val_acc:80.000
# Best loss:0.165, Best accuracy:82.500, Best F1-score:82.687
# 139/300 lr=0.00055 - loss:0.204, acc:86.695, val_loss:0.189, val_acc:78.750
# Best loss:0.165, Best accuracy:82.500, Best F1-score:82.687
# 140/300 lr=0.00055 - loss:0.218, acc:84.544, val_loss:0.162, val_acc:83.125
# Best loss:0.165, Best accuracy:82.500, Best F1-score:82.687
# 141/300 lr=0.00055 - loss:0.214, acc:83.519, val_loss:0.160, val_acc:80.625
# Best loss:0.162, Best accuracy:83.125, Best F1-score:83.847
# 142/300 lr=0.00047 - loss:0.197, acc:86.284, val_loss:0.173, val_acc:77.500
# Best loss:0.160, Best accuracy:80.625, Best F1-score:81.862
# 143/300 lr=0.00047 - loss:0.205, acc:85.017, val_loss:0.175, val_acc:80.625
# Best loss:0.160, Best accuracy:80.625, Best F1-score:81.862
# 144/300 lr=0.00047 - loss:0.208, acc:85.282, val_loss:0.164, val_acc:82.500
# Best loss:0.160, Best accuracy:80.625, Best F1-score:81.862
# 145/300 lr=0.00047 - loss:0.207, acc:85.293, val_loss:0.195, val_acc:79.375
# Best loss:0.160, Best accuracy:80.625, Best F1-score:81.862
# 146/300 lr=0.00047 - loss:0.201, acc:86.548, val_loss:0.176, val_acc:80.000
# Best loss:0.160, Best accuracy:80.625, Best F1-score:81.862
# 147/300 lr=0.00047 - loss:0.192, acc:88.660, val_loss:0.173, val_acc:80.000
# Best loss:0.160, Best accuracy:80.625, Best F1-score:81.862
# 148/300 lr=0.00047 - loss:0.193, acc:88.322, val_loss:0.153, val_acc:81.875
# Best loss:0.160, Best accuracy:80.625, Best F1-score:81.862
# 149/300 lr=0.00047 - loss:0.188, acc:88.007, val_loss:0.166, val_acc:82.500
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 150/300 lr=0.00047 - loss:0.193, acc:87.489, val_loss:0.174, val_acc:80.000
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 151/300 lr=0.00047 - loss:0.192, acc:88.395, val_loss:0.164, val_acc:82.500
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 152/300 lr=0.00047 - loss:0.197, acc:86.802, val_loss:0.166, val_acc:80.000
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 153/300 lr=0.00047 - loss:0.191, acc:86.717, val_loss:0.163, val_acc:81.875
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 154/300 lr=0.00047 - loss:0.192, acc:87.635, val_loss:0.158, val_acc:80.625
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 155/300 lr=0.00047 - loss:0.188, acc:88.007, val_loss:0.165, val_acc:81.875
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 156/300 lr=0.00047 - loss:0.187, acc:88.480, val_loss:0.173, val_acc:80.625
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 157/300 lr=0.00047 - loss:0.184, acc:89.516, val_loss:0.165, val_acc:80.625
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 158/300 lr=0.00047 - loss:0.185, acc:88.384, val_loss:0.173, val_acc:80.000
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 159/300 lr=0.00047 - loss:0.182, acc:88.806, val_loss:0.157, val_acc:81.875
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 160/300 lr=0.00047 - loss:0.181, acc:89.105, val_loss:0.165, val_acc:81.875
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 161/300 lr=0.00047 - loss:0.189, acc:87.815, val_loss:0.157, val_acc:81.875
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 162/300 lr=0.00041 - loss:0.186, acc:88.671, val_loss:0.181, val_acc:78.125
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 163/300 lr=0.00041 - loss:0.182, acc:89.336, val_loss:0.168, val_acc:82.500
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 164/300 lr=0.00041 - loss:0.180, acc:89.651, val_loss:0.175, val_acc:81.250
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 165/300 lr=0.00041 - loss:0.178, acc:89.262, val_loss:0.163, val_acc:82.500
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 166/300 lr=0.00041 - loss:0.179, acc:89.262, val_loss:0.173, val_acc:78.125
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 167/300 lr=0.00041 - loss:0.188, acc:87.669, val_loss:0.169, val_acc:81.250
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 168/300 lr=0.00041 - loss:0.183, acc:89.178, val_loss:0.158, val_acc:83.125
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 169/300 lr=0.00041 - loss:0.180, acc:89.673, val_loss:0.182, val_acc:78.750
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 170/300 lr=0.00041 - loss:0.184, acc:88.891, val_loss:0.149, val_acc:84.375
# Best loss:0.153, Best accuracy:81.875, Best F1-score:81.919
# 171/300 lr=0.00041 - loss:0.174, acc:89.854, val_loss:0.169, val_acc:79.375
# Best loss:0.149, Best accuracy:84.375, Best F1-score:84.882
# 172/300 lr=0.00041 - loss:0.179, acc:89.938, val_loss:0.171, val_acc:78.750
# Best loss:0.149, Best accuracy:84.375, Best F1-score:84.882
# 173/300 lr=0.00041 - loss:0.171, acc:91.385, val_loss:0.172, val_acc:81.875
# Best loss:0.149, Best accuracy:84.375, Best F1-score:84.882
# 174/300 lr=0.00041 - loss:0.177, acc:90.265, val_loss:0.166, val_acc:81.875
# Best loss:0.149, Best accuracy:84.375, Best F1-score:84.882
# 175/300 lr=0.00041 - loss:0.168, acc:91.289, val_loss:0.169, val_acc:80.000
# Best loss:0.149, Best accuracy:84.375, Best F1-score:84.882
# 176/300 lr=0.00041 - loss:0.167, acc:91.278, val_loss:0.147, val_acc:82.500
# Best loss:0.149, Best accuracy:84.375, Best F1-score:84.882
# 177/300 lr=0.00041 - loss:0.170, acc:90.602, val_loss:0.152, val_acc:82.500
# Best loss:0.147, Best accuracy:82.500, Best F1-score:83.289
# 178/300 lr=0.00041 - loss:0.168, acc:91.470, val_loss:0.177, val_acc:81.875
# Best loss:0.147, Best accuracy:82.500, Best F1-score:83.289
# 179/300 lr=0.00041 - loss:0.172, acc:90.265, val_loss:0.181, val_acc:84.375
# Best loss:0.147, Best accuracy:82.500, Best F1-score:83.289
# 180/300 lr=0.00041 - loss:0.175, acc:90.276, val_loss:0.150, val_acc:81.250
# Best loss:0.147, Best accuracy:82.500, Best F1-score:83.289
# 181/300 lr=0.00041 - loss:0.180, acc:89.082, val_loss:0.175, val_acc:79.375
# Best loss:0.147, Best accuracy:82.500, Best F1-score:83.289
# 182/300 lr=0.00035 - loss:0.169, acc:91.458, val_loss:0.162, val_acc:81.875
# Best loss:0.147, Best accuracy:82.500, Best F1-score:83.289
# 183/300 lr=0.00035 - loss:0.170, acc:91.458, val_loss:0.146, val_acc:83.125
# Best loss:0.147, Best accuracy:82.500, Best F1-score:83.289
# 184/300 lr=0.00035 - loss:0.168, acc:91.351, val_loss:0.149, val_acc:83.125
# Best loss:0.146, Best accuracy:83.125, Best F1-score:83.294
# 185/300 lr=0.00035 - loss:0.168, acc:90.011, val_loss:0.171, val_acc:80.625
# Best loss:0.146, Best accuracy:83.125, Best F1-score:83.294
# 186/300 lr=0.00035 - loss:0.166, acc:92.303, val_loss:0.176, val_acc:80.625
# Best loss:0.146, Best accuracy:83.125, Best F1-score:83.294
# 187/300 lr=0.00035 - loss:0.164, acc:91.554, val_loss:0.161, val_acc:80.625
# Best loss:0.146, Best accuracy:83.125, Best F1-score:83.294
# 188/300 lr=0.00035 - loss:0.166, acc:92.303, val_loss:0.153, val_acc:83.125
# Best loss:0.146, Best accuracy:83.125, Best F1-score:83.294
# 189/300 lr=0.00035 - loss:0.158, acc:93.159, val_loss:0.160, val_acc:81.875
# Best loss:0.146, Best accuracy:83.125, Best F1-score:83.294
# 190/300 lr=0.00035 - loss:0.159, acc:92.703, val_loss:0.162, val_acc:80.625
# Best loss:0.146, Best accuracy:83.125, Best F1-score:83.294
# 191/300 lr=0.00035 - loss:0.157, acc:92.703, val_loss:0.146, val_acc:83.750
# Best loss:0.146, Best accuracy:83.125, Best F1-score:83.294
# 192/300 lr=0.00035 - loss:0.162, acc:92.303, val_loss:0.156, val_acc:82.500
# Best loss:0.146, Best accuracy:83.750, Best F1-score:84.157
# 193/300 lr=0.00035 - loss:0.152, acc:93.328, val_loss:0.171, val_acc:80.000
# Best loss:0.146, Best accuracy:83.750, Best F1-score:84.157
# 194/300 lr=0.00035 - loss:0.160, acc:92.568, val_loss:0.148, val_acc:82.500
# Best loss:0.146, Best accuracy:83.750, Best F1-score:84.157
# 195/300 lr=0.00035 - loss:0.166, acc:90.676, val_loss:0.154, val_acc:80.625
# Best loss:0.146, Best accuracy:83.750, Best F1-score:84.157
# 196/300 lr=0.00035 - loss:0.169, acc:89.916, val_loss:0.181, val_acc:78.125
# Best loss:0.146, Best accuracy:83.750, Best F1-score:84.157
# 197/300 lr=0.00035 - loss:0.173, acc:89.516, val_loss:0.143, val_acc:85.000
# Best loss:0.146, Best accuracy:83.750, Best F1-score:84.157
# 198/300 lr=0.00035 - loss:0.171, acc:90.664, val_loss:0.148, val_acc:84.375
# Best loss:0.143, Best accuracy:85.000, Best F1-score:85.191
# 199/300 lr=0.00035 - loss:0.158, acc:92.387, val_loss:0.157, val_acc:81.875
# Best loss:0.143, Best accuracy:85.000, Best F1-score:85.191
# 200/300 lr=0.00035 - loss:0.151, acc:93.750, val_loss:0.168, val_acc:80.625
# Best loss:0.143, Best accuracy:85.000, Best F1-score:85.191
# 201/300 lr=0.00035 - loss:0.164, acc:91.785, val_loss:0.158, val_acc:83.125
# Best loss:0.143, Best accuracy:85.000, Best F1-score:85.191
# 202/300 lr=0.00030 - loss:0.162, acc:92.641, val_loss:0.164, val_acc:79.375
# Best loss:0.143, Best accuracy:85.000, Best F1-score:85.191
# 203/300 lr=0.00030 - loss:0.157, acc:92.061, val_loss:0.150, val_acc:81.875
# Best loss:0.143, Best accuracy:85.000, Best F1-score:85.191
# 204/300 lr=0.00030 - loss:0.158, acc:92.303, val_loss:0.162, val_acc:82.500
# Best loss:0.143, Best accuracy:85.000, Best F1-score:85.191
# 205/300 lr=0.00030 - loss:0.153, acc:93.221, val_loss:0.148, val_acc:81.250
# Best loss:0.143, Best accuracy:85.000, Best F1-score:85.191
# 206/300 lr=0.00030 - loss:0.150, acc:93.412, val_loss:0.151, val_acc:82.500
# Best loss:0.143, Best accuracy:85.000, Best F1-score:85.191
# 207/300 lr=0.00030 - loss:0.157, acc:92.292, val_loss:0.164, val_acc:81.875
# Best loss:0.143, Best accuracy:85.000, Best F1-score:85.191
# 208/300 lr=0.00030 - loss:0.151, acc:92.894, val_loss:0.161, val_acc:80.000
# Best loss:0.143, Best accuracy:85.000, Best F1-score:85.191
# 209/300 lr=0.00030 - loss:0.151, acc:93.474, val_loss:0.141, val_acc:83.750
# Best loss:0.143, Best accuracy:85.000, Best F1-score:85.191
# 210/300 lr=0.00030 - loss:0.146, acc:94.426, val_loss:0.140, val_acc:81.875
# Best loss:0.141, Best accuracy:83.750, Best F1-score:83.953
# 211/300 lr=0.00030 - loss:0.147, acc:93.896, val_loss:0.149, val_acc:83.750
# Best loss:0.140, Best accuracy:81.875, Best F1-score:82.240
# 212/300 lr=0.00030 - loss:0.147, acc:94.679, val_loss:0.152, val_acc:83.125
# Best loss:0.140, Best accuracy:81.875, Best F1-score:82.240
# 213/300 lr=0.00030 - loss:0.151, acc:93.390, val_loss:0.162, val_acc:82.500
# Best loss:0.140, Best accuracy:81.875, Best F1-score:82.240
# 214/300 lr=0.00030 - loss:0.151, acc:94.139, val_loss:0.150, val_acc:84.375
# Best loss:0.140, Best accuracy:81.875, Best F1-score:82.240
# 215/300 lr=0.00030 - loss:0.154, acc:92.545, val_loss:0.153, val_acc:83.125
# Best loss:0.140, Best accuracy:81.875, Best F1-score:82.240
# 216/300 lr=0.00030 - loss:0.148, acc:93.666, val_loss:0.155, val_acc:81.875
# Best loss:0.140, Best accuracy:81.875, Best F1-score:82.240
# 217/300 lr=0.00030 - loss:0.148, acc:94.054, val_loss:0.170, val_acc:80.000
# Best loss:0.140, Best accuracy:81.875, Best F1-score:82.240
# 218/300 lr=0.00030 - loss:0.146, acc:94.414, val_loss:0.141, val_acc:83.750
# Best loss:0.140, Best accuracy:81.875, Best F1-score:82.240
# 219/300 lr=0.00030 - loss:0.156, acc:92.050, val_loss:0.157, val_acc:83.125
# Best loss:0.140, Best accuracy:81.875, Best F1-score:82.240
# 220/300 lr=0.00030 - loss:0.150, acc:93.463, val_loss:0.166, val_acc:81.250
# Best loss:0.140, Best accuracy:81.875, Best F1-score:82.240
# 221/300 lr=0.00030 - loss:0.154, acc:93.136, val_loss:0.145, val_acc:84.375
# Best loss:0.140, Best accuracy:81.875, Best F1-score:82.240
# 222/300 lr=0.00026 - loss:0.155, acc:92.894, val_loss:0.146, val_acc:85.000
# Best loss:0.140, Best accuracy:81.875, Best F1-score:82.240
# 223/300 lr=0.00026 - loss:0.151, acc:94.088, val_loss:0.140, val_acc:85.625
# Best loss:0.140, Best accuracy:81.875, Best F1-score:82.240
# 224/300 lr=0.00026 - loss:0.151, acc:92.618, val_loss:0.131, val_acc:84.375
# Best loss:0.140, Best accuracy:85.625, Best F1-score:86.046
# 225/300 lr=0.00026 - loss:0.140, acc:95.608, val_loss:0.149, val_acc:85.000
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 226/300 lr=0.00026 - loss:0.145, acc:94.245, val_loss:0.145, val_acc:83.125
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 227/300 lr=0.00026 - loss:0.143, acc:95.186, val_loss:0.154, val_acc:81.875
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 228/300 lr=0.00026 - loss:0.146, acc:94.161, val_loss:0.157, val_acc:83.125
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 229/300 lr=0.00026 - loss:0.141, acc:94.668, val_loss:0.153, val_acc:80.000
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 230/300 lr=0.00026 - loss:0.146, acc:94.161, val_loss:0.138, val_acc:84.375
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 231/300 lr=0.00026 - loss:0.141, acc:95.101, val_loss:0.163, val_acc:81.250
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 232/300 lr=0.00026 - loss:0.145, acc:94.488, val_loss:0.147, val_acc:81.250
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 233/300 lr=0.00026 - loss:0.143, acc:95.017, val_loss:0.146, val_acc:83.125
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 234/300 lr=0.00026 - loss:0.144, acc:94.172, val_loss:0.133, val_acc:85.625
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 235/300 lr=0.00026 - loss:0.144, acc:94.161, val_loss:0.150, val_acc:83.125
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 236/300 lr=0.00026 - loss:0.153, acc:92.894, val_loss:0.139, val_acc:83.125
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 237/300 lr=0.00026 - loss:0.146, acc:94.088, val_loss:0.148, val_acc:81.875
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 238/300 lr=0.00026 - loss:0.145, acc:94.426, val_loss:0.133, val_acc:83.125
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 239/300 lr=0.00026 - loss:0.145, acc:94.307, val_loss:0.138, val_acc:86.250
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 240/300 lr=0.00026 - loss:0.149, acc:93.485, val_loss:0.140, val_acc:84.375
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 241/300 lr=0.00026 - loss:0.142, acc:95.186, val_loss:0.150, val_acc:85.000
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 242/300 lr=0.00022 - loss:0.144, acc:94.088, val_loss:0.150, val_acc:83.750
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 243/300 lr=0.00022 - loss:0.149, acc:92.905, val_loss:0.164, val_acc:83.750
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 244/300 lr=0.00022 - loss:0.142, acc:94.245, val_loss:0.149, val_acc:83.125
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 245/300 lr=0.00022 - loss:0.137, acc:95.512, val_loss:0.146, val_acc:84.375
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 246/300 lr=0.00022 - loss:0.140, acc:94.837, val_loss:0.141, val_acc:82.500
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 247/300 lr=0.00022 - loss:0.137, acc:95.428, val_loss:0.155, val_acc:83.750
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 248/300 lr=0.00022 - loss:0.138, acc:95.270, val_loss:0.140, val_acc:82.500
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 249/300 lr=0.00022 - loss:0.141, acc:94.848, val_loss:0.154, val_acc:82.500
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 250/300 lr=0.00022 - loss:0.135, acc:95.861, val_loss:0.154, val_acc:81.250
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 251/300 lr=0.00022 - loss:0.137, acc:95.693, val_loss:0.153, val_acc:83.750
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 252/300 lr=0.00022 - loss:0.138, acc:95.861, val_loss:0.138, val_acc:83.125
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 253/300 lr=0.00022 - loss:0.136, acc:95.524, val_loss:0.142, val_acc:83.125
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 254/300 lr=0.00022 - loss:0.140, acc:94.499, val_loss:0.146, val_acc:82.500
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 255/300 lr=0.00022 - loss:0.139, acc:95.270, val_loss:0.150, val_acc:83.125
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 256/300 lr=0.00022 - loss:0.136, acc:95.670, val_loss:0.153, val_acc:81.875
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 257/300 lr=0.00022 - loss:0.137, acc:95.524, val_loss:0.158, val_acc:81.875
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 258/300 lr=0.00022 - loss:0.135, acc:95.681, val_loss:0.151, val_acc:82.500
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 259/300 lr=0.00022 - loss:0.135, acc:95.693, val_loss:0.148, val_acc:81.875
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 260/300 lr=0.00022 - loss:0.133, acc:96.019, val_loss:0.146, val_acc:84.375
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 261/300 lr=0.00022 - loss:0.139, acc:95.017, val_loss:0.149, val_acc:82.500
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 262/300 lr=0.00019 - loss:0.139, acc:95.006, val_loss:0.148, val_acc:84.375
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 263/300 lr=0.00019 - loss:0.141, acc:95.006, val_loss:0.151, val_acc:82.500
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 264/300 lr=0.00019 - loss:0.135, acc:95.524, val_loss:0.153, val_acc:82.500
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 265/300 lr=0.00019 - loss:0.133, acc:95.946, val_loss:0.137, val_acc:86.250
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 266/300 lr=0.00019 - loss:0.131, acc:96.030, val_loss:0.145, val_acc:82.500
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 267/300 lr=0.00019 - loss:0.137, acc:95.512, val_loss:0.141, val_acc:81.875
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 268/300 lr=0.00019 - loss:0.138, acc:95.574, val_loss:0.145, val_acc:83.750
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 269/300 lr=0.00019 - loss:0.133, acc:96.115, val_loss:0.149, val_acc:81.250
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 270/300 lr=0.00019 - loss:0.133, acc:95.693, val_loss:0.144, val_acc:82.500
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 271/300 lr=0.00019 - loss:0.131, acc:96.368, val_loss:0.132, val_acc:84.375
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 272/300 lr=0.00019 - loss:0.135, acc:95.524, val_loss:0.146, val_acc:82.500
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 273/300 lr=0.00019 - loss:0.139, acc:94.825, val_loss:0.150, val_acc:81.875
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 274/300 lr=0.00019 - loss:0.140, acc:94.668, val_loss:0.146, val_acc:85.000
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 275/300 lr=0.00019 - loss:0.134, acc:95.428, val_loss:0.160, val_acc:82.500
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 276/300 lr=0.00019 - loss:0.133, acc:96.104, val_loss:0.146, val_acc:85.625
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 277/300 lr=0.00019 - loss:0.130, acc:96.453, val_loss:0.141, val_acc:84.375
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 278/300 lr=0.00019 - loss:0.134, acc:96.115, val_loss:0.146, val_acc:81.250
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 279/300 lr=0.00019 - loss:0.136, acc:95.608, val_loss:0.153, val_acc:81.875
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 280/300 lr=0.00019 - loss:0.136, acc:95.850, val_loss:0.140, val_acc:82.500
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 281/300 lr=0.00019 - loss:0.133, acc:95.850, val_loss:0.127, val_acc:88.125
# Best loss:0.131, Best accuracy:84.375, Best F1-score:84.951
# 282/300 lr=0.00017 - loss:0.132, acc:95.766, val_loss:0.134, val_acc:85.625
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 283/300 lr=0.00017 - loss:0.130, acc:96.199, val_loss:0.146, val_acc:83.125
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 284/300 lr=0.00017 - loss:0.132, acc:95.850, val_loss:0.149, val_acc:83.750
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 285/300 lr=0.00017 - loss:0.132, acc:96.030, val_loss:0.145, val_acc:83.125
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 286/300 lr=0.00017 - loss:0.130, acc:96.019, val_loss:0.131, val_acc:84.375
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 287/300 lr=0.00017 - loss:0.129, acc:96.368, val_loss:0.142, val_acc:85.000
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 288/300 lr=0.00017 - loss:0.129, acc:96.441, val_loss:0.146, val_acc:83.750
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 289/300 lr=0.00017 - loss:0.133, acc:96.092, val_loss:0.132, val_acc:85.000
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 290/300 lr=0.00017 - loss:0.128, acc:96.537, val_loss:0.142, val_acc:83.750
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 291/300 lr=0.00017 - loss:0.128, acc:96.791, val_loss:0.141, val_acc:85.000
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 292/300 lr=0.00017 - loss:0.132, acc:95.777, val_loss:0.142, val_acc:81.875
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 293/300 lr=0.00017 - loss:0.131, acc:95.912, val_loss:0.149, val_acc:80.625
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 294/300 lr=0.00017 - loss:0.130, acc:96.115, val_loss:0.140, val_acc:83.125
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 295/300 lr=0.00017 - loss:0.128, acc:97.106, val_loss:0.154, val_acc:82.500
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 296/300 lr=0.00017 - loss:0.131, acc:96.622, val_loss:0.135, val_acc:85.000
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 297/300 lr=0.00017 - loss:0.127, acc:96.526, val_loss:0.157, val_acc:82.500
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 298/300 lr=0.00017 - loss:0.131, acc:96.284, val_loss:0.149, val_acc:84.375
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 299/300 lr=0.00017 - loss:0.134, acc:95.343, val_loss:0.156, val_acc:83.750
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# 300/300 lr=0.00017 - loss:0.136, acc:95.186, val_loss:0.139, val_acc:84.375
# Best loss:0.127, Best accuracy:88.125, Best F1-score:88.539
# ********************************************************************************
# [*] Done Fold-8
# best_val_loss:0.127, best_val_acc:88.125, best_val_f1:88.539
# test_acc:87.500, test_f1:87.724
# ********************************************************************************
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.631, acc:16.132, val_loss:0.625, val_acc:23.125
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.614, acc:22.247, val_loss:0.608, val_acc:23.750
# Best loss:0.625, Best accuracy:23.125, Best F1-score:15.994
# 3/300 lr=0.00100 - loss:0.600, acc:24.972, val_loss:0.579, val_acc:45.000
# Best loss:0.608, Best accuracy:23.750, Best F1-score:16.353
# 4/300 lr=0.00100 - loss:0.589, acc:27.038, val_loss:0.590, val_acc:25.625
# Best loss:0.579, Best accuracy:45.000, Best F1-score:39.077
# 5/300 lr=0.00100 - loss:0.588, acc:26.363, val_loss:0.560, val_acc:31.875
# Best loss:0.579, Best accuracy:45.000, Best F1-score:39.077
# 6/300 lr=0.00100 - loss:0.581, acc:27.905, val_loss:0.596, val_acc:28.125
# Best loss:0.560, Best accuracy:31.875, Best F1-score:28.731
# 7/300 lr=0.00100 - loss:0.580, acc:28.919, val_loss:0.597, val_acc:28.125
# Best loss:0.560, Best accuracy:31.875, Best F1-score:28.731
# 8/300 lr=0.00100 - loss:0.578, acc:28.193, val_loss:0.537, val_acc:50.000
# Best loss:0.560, Best accuracy:31.875, Best F1-score:28.731
# 9/300 lr=0.00100 - loss:0.570, acc:30.653, val_loss:0.563, val_acc:33.750
# Best loss:0.537, Best accuracy:50.000, Best F1-score:44.154
# 10/300 lr=0.00100 - loss:0.559, acc:33.249, val_loss:0.551, val_acc:26.875
# Best loss:0.537, Best accuracy:50.000, Best F1-score:44.154
# 11/300 lr=0.00100 - loss:0.552, acc:35.118, val_loss:0.488, val_acc:55.000
# Best loss:0.537, Best accuracy:50.000, Best F1-score:44.154
# 12/300 lr=0.00100 - loss:0.550, acc:35.141, val_loss:0.543, val_acc:29.375
# Best loss:0.488, Best accuracy:55.000, Best F1-score:50.760
# 13/300 lr=0.00100 - loss:0.541, acc:37.399, val_loss:0.483, val_acc:50.625
# Best loss:0.488, Best accuracy:55.000, Best F1-score:50.760
# 14/300 lr=0.00100 - loss:0.535, acc:37.821, val_loss:0.471, val_acc:50.625
# Best loss:0.483, Best accuracy:50.625, Best F1-score:48.050
# 15/300 lr=0.00100 - loss:0.531, acc:38.896, val_loss:0.511, val_acc:34.375
# Best loss:0.471, Best accuracy:50.625, Best F1-score:48.081
# 16/300 lr=0.00100 - loss:0.518, acc:40.417, val_loss:0.507, val_acc:49.375
# Best loss:0.471, Best accuracy:50.625, Best F1-score:48.081
# 17/300 lr=0.00100 - loss:0.520, acc:39.099, val_loss:0.463, val_acc:51.875
# Best loss:0.471, Best accuracy:50.625, Best F1-score:48.081
# 18/300 lr=0.00100 - loss:0.512, acc:40.895, val_loss:0.433, val_acc:59.375
# Best loss:0.463, Best accuracy:51.875, Best F1-score:47.822
# 19/300 lr=0.00100 - loss:0.497, acc:43.744, val_loss:0.430, val_acc:55.000
# Best loss:0.433, Best accuracy:59.375, Best F1-score:58.192
# 20/300 lr=0.00100 - loss:0.496, acc:43.176, val_loss:0.397, val_acc:59.375
# Best loss:0.430, Best accuracy:55.000, Best F1-score:53.498
# 21/300 lr=0.00100 - loss:0.498, acc:43.913, val_loss:0.491, val_acc:35.000
# Best loss:0.397, Best accuracy:59.375, Best F1-score:57.539
# 22/300 lr=0.00100 - loss:0.509, acc:42.140, val_loss:0.417, val_acc:53.750
# Best loss:0.397, Best accuracy:59.375, Best F1-score:57.539
# 23/300 lr=0.00100 - loss:0.490, acc:43.998, val_loss:0.406, val_acc:57.500
# Best loss:0.397, Best accuracy:59.375, Best F1-score:57.539
# 24/300 lr=0.00100 - loss:0.490, acc:45.169, val_loss:0.419, val_acc:55.625
# Best loss:0.397, Best accuracy:59.375, Best F1-score:57.539
# 25/300 lr=0.00100 - loss:0.478, acc:47.584, val_loss:0.415, val_acc:56.875
# Best loss:0.397, Best accuracy:59.375, Best F1-score:57.539
# 26/300 lr=0.00100 - loss:0.480, acc:45.856, val_loss:0.368, val_acc:63.125
# Best loss:0.397, Best accuracy:59.375, Best F1-score:57.539
# 27/300 lr=0.00100 - loss:0.462, acc:49.657, val_loss:0.397, val_acc:64.375
# Best loss:0.368, Best accuracy:63.125, Best F1-score:61.313
# 28/300 lr=0.00100 - loss:0.466, acc:47.990, val_loss:0.407, val_acc:58.750
# Best loss:0.368, Best accuracy:63.125, Best F1-score:61.313
# 29/300 lr=0.00100 - loss:0.473, acc:47.145, val_loss:0.371, val_acc:60.625
# Best loss:0.368, Best accuracy:63.125, Best F1-score:61.313
# 30/300 lr=0.00100 - loss:0.468, acc:47.905, val_loss:0.412, val_acc:56.875
# Best loss:0.368, Best accuracy:63.125, Best F1-score:61.313
# 31/300 lr=0.00100 - loss:0.455, acc:49.797, val_loss:0.381, val_acc:61.875
# Best loss:0.368, Best accuracy:63.125, Best F1-score:61.313
# 32/300 lr=0.00100 - loss:0.462, acc:48.632, val_loss:0.346, val_acc:60.625
# Best loss:0.368, Best accuracy:63.125, Best F1-score:61.313
# 33/300 lr=0.00100 - loss:0.453, acc:49.488, val_loss:0.346, val_acc:62.500
# Best loss:0.346, Best accuracy:60.625, Best F1-score:58.944
# 34/300 lr=0.00100 - loss:0.455, acc:49.944, val_loss:0.334, val_acc:63.750
# Best loss:0.346, Best accuracy:60.625, Best F1-score:58.944
# 35/300 lr=0.00100 - loss:0.442, acc:51.706, val_loss:0.351, val_acc:63.750
# Best loss:0.334, Best accuracy:63.750, Best F1-score:60.316
# 36/300 lr=0.00100 - loss:0.450, acc:49.488, val_loss:0.337, val_acc:69.375
# Best loss:0.334, Best accuracy:63.750, Best F1-score:60.316
# 37/300 lr=0.00100 - loss:0.437, acc:53.119, val_loss:0.382, val_acc:60.000
# Best loss:0.334, Best accuracy:63.750, Best F1-score:60.316
# 38/300 lr=0.00100 - loss:0.433, acc:52.686, val_loss:0.326, val_acc:61.875
# Best loss:0.334, Best accuracy:63.750, Best F1-score:60.316
# 39/300 lr=0.00100 - loss:0.452, acc:49.139, val_loss:0.342, val_acc:61.875
# Best loss:0.326, Best accuracy:61.875, Best F1-score:59.797
# 40/300 lr=0.00100 - loss:0.441, acc:50.659, val_loss:0.307, val_acc:63.750
# Best loss:0.326, Best accuracy:61.875, Best F1-score:59.797
# 41/300 lr=0.00100 - loss:0.433, acc:53.108, val_loss:0.318, val_acc:70.000
# Best loss:0.307, Best accuracy:63.750, Best F1-score:61.897
# 42/300 lr=0.00100 - loss:0.441, acc:52.179, val_loss:0.340, val_acc:63.750
# Best loss:0.307, Best accuracy:63.750, Best F1-score:61.897
# 43/300 lr=0.00100 - loss:0.417, acc:55.687, val_loss:0.328, val_acc:63.750
# Best loss:0.307, Best accuracy:63.750, Best F1-score:61.897
# 44/300 lr=0.00100 - loss:0.423, acc:54.769, val_loss:0.345, val_acc:65.000
# Best loss:0.307, Best accuracy:63.750, Best F1-score:61.897
# 45/300 lr=0.00100 - loss:0.417, acc:53.868, val_loss:0.333, val_acc:63.750
# Best loss:0.307, Best accuracy:63.750, Best F1-score:61.897
# 46/300 lr=0.00100 - loss:0.419, acc:56.436, val_loss:0.303, val_acc:65.625
# Best loss:0.307, Best accuracy:63.750, Best F1-score:61.897
# 47/300 lr=0.00100 - loss:0.412, acc:55.918, val_loss:0.346, val_acc:61.875
# Best loss:0.303, Best accuracy:65.625, Best F1-score:64.173
# 48/300 lr=0.00100 - loss:0.419, acc:53.446, val_loss:0.322, val_acc:63.125
# Best loss:0.303, Best accuracy:65.625, Best F1-score:64.173
# 49/300 lr=0.00100 - loss:0.418, acc:55.811, val_loss:0.318, val_acc:65.000
# Best loss:0.303, Best accuracy:65.625, Best F1-score:64.173
# 50/300 lr=0.00100 - loss:0.410, acc:55.940, val_loss:0.305, val_acc:64.375
# Best loss:0.303, Best accuracy:65.625, Best F1-score:64.173
# 51/300 lr=0.00100 - loss:0.400, acc:58.823, val_loss:0.284, val_acc:68.750
# Best loss:0.303, Best accuracy:65.625, Best F1-score:64.173
# 52/300 lr=0.00100 - loss:0.398, acc:58.885, val_loss:0.281, val_acc:73.125
# ...
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 186/300 lr=0.00035 - loss:0.149, acc:94.003, val_loss:0.175, val_acc:82.500
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 187/300 lr=0.00035 - loss:0.143, acc:94.848, val_loss:0.249, val_acc:58.750
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 188/300 lr=0.00035 - loss:0.156, acc:93.328, val_loss:0.239, val_acc:78.750
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 189/300 lr=0.00035 - loss:0.155, acc:92.387, val_loss:0.308, val_acc:61.250
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 190/300 lr=0.00035 - loss:0.148, acc:94.172, val_loss:0.218, val_acc:80.625
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 191/300 lr=0.00035 - loss:0.156, acc:93.221, val_loss:0.215, val_acc:80.000
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 192/300 lr=0.00035 - loss:0.154, acc:93.497, val_loss:0.206, val_acc:81.875
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 193/300 lr=0.00035 - loss:0.146, acc:94.848, val_loss:0.208, val_acc:78.125
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 194/300 lr=0.00035 - loss:0.147, acc:94.161, val_loss:0.180, val_acc:83.750
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 195/300 lr=0.00035 - loss:0.144, acc:94.172, val_loss:0.276, val_acc:58.750
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 196/300 lr=0.00035 - loss:0.148, acc:94.245, val_loss:0.226, val_acc:80.000
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 197/300 lr=0.00035 - loss:0.151, acc:93.474, val_loss:0.171, val_acc:83.750
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 198/300 lr=0.00035 - loss:0.154, acc:93.316, val_loss:0.265, val_acc:57.500
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 199/300 lr=0.00035 - loss:0.147, acc:94.341, val_loss:0.174, val_acc:82.500
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 200/300 lr=0.00035 - loss:0.148, acc:94.161, val_loss:0.210, val_acc:81.875
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 201/300 lr=0.00035 - loss:0.151, acc:93.232, val_loss:0.201, val_acc:77.500
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 202/300 lr=0.00030 - loss:0.145, acc:94.741, val_loss:0.256, val_acc:60.000
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 203/300 lr=0.00030 - loss:0.144, acc:94.150, val_loss:0.200, val_acc:82.500
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 204/300 lr=0.00030 - loss:0.150, acc:93.570, val_loss:0.271, val_acc:60.000
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 205/300 lr=0.00030 - loss:0.143, acc:94.848, val_loss:0.279, val_acc:60.625
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 206/300 lr=0.00030 - loss:0.141, acc:95.259, val_loss:0.188, val_acc:81.875
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 207/300 lr=0.00030 - loss:0.142, acc:95.079, val_loss:0.257, val_acc:62.500
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 208/300 lr=0.00030 - loss:0.137, acc:95.608, val_loss:0.280, val_acc:59.375
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 209/300 lr=0.00030 - loss:0.138, acc:95.270, val_loss:0.285, val_acc:63.125
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 210/300 lr=0.00030 - loss:0.139, acc:94.921, val_loss:0.160, val_acc:83.750
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 211/300 lr=0.00030 - loss:0.139, acc:95.597, val_loss:0.294, val_acc:64.375
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 212/300 lr=0.00030 - loss:0.141, acc:94.499, val_loss:0.273, val_acc:61.875
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 213/300 lr=0.00030 - loss:0.139, acc:95.270, val_loss:0.224, val_acc:83.125
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 214/300 lr=0.00030 - loss:0.137, acc:95.608, val_loss:0.225, val_acc:65.000
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 215/300 lr=0.00030 - loss:0.139, acc:95.259, val_loss:0.248, val_acc:60.625
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 216/300 lr=0.00030 - loss:0.140, acc:94.932, val_loss:0.193, val_acc:80.000
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 217/300 lr=0.00030 - loss:0.136, acc:95.428, val_loss:0.218, val_acc:61.875
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 218/300 lr=0.00030 - loss:0.141, acc:94.825, val_loss:0.238, val_acc:61.250
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 219/300 lr=0.00030 - loss:0.136, acc:95.693, val_loss:0.182, val_acc:80.000
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 220/300 lr=0.00030 - loss:0.135, acc:95.946, val_loss:0.270, val_acc:59.375
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 221/300 lr=0.00030 - loss:0.139, acc:94.837, val_loss:0.296, val_acc:61.250
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 222/300 lr=0.00026 - loss:0.138, acc:95.512, val_loss:0.178, val_acc:83.125
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 223/300 lr=0.00026 - loss:0.140, acc:94.752, val_loss:0.333, val_acc:64.375
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 224/300 lr=0.00026 - loss:0.137, acc:94.932, val_loss:0.257, val_acc:58.750
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 225/300 lr=0.00026 - loss:0.139, acc:94.921, val_loss:0.213, val_acc:83.750
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 226/300 lr=0.00026 - loss:0.136, acc:95.017, val_loss:0.259, val_acc:63.125
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 227/300 lr=0.00026 - loss:0.135, acc:95.777, val_loss:0.223, val_acc:63.125
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 228/300 lr=0.00026 - loss:0.129, acc:96.537, val_loss:0.188, val_acc:83.125
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 229/300 lr=0.00026 - loss:0.131, acc:96.104, val_loss:0.321, val_acc:62.500
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 230/300 lr=0.00026 - loss:0.132, acc:96.622, val_loss:0.175, val_acc:80.625
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 231/300 lr=0.00026 - loss:0.131, acc:96.188, val_loss:0.276, val_acc:65.000
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 232/300 lr=0.00026 - loss:0.130, acc:96.791, val_loss:0.330, val_acc:63.750
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 233/300 lr=0.00026 - loss:0.131, acc:96.334, val_loss:0.148, val_acc:83.750
# Best loss:0.153, Best accuracy:84.375, Best F1-score:83.761
# 234/300 lr=0.00026 - loss:0.130, acc:96.610, val_loss:0.267, val_acc:60.000
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 235/300 lr=0.00026 - loss:0.137, acc:94.730, val_loss:0.217, val_acc:83.125
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 236/300 lr=0.00026 - loss:0.132, acc:95.524, val_loss:0.249, val_acc:60.000
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 237/300 lr=0.00026 - loss:0.133, acc:95.693, val_loss:0.164, val_acc:83.125
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 238/300 lr=0.00026 - loss:0.133, acc:96.368, val_loss:0.187, val_acc:84.375
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 239/300 lr=0.00026 - loss:0.133, acc:95.946, val_loss:0.180, val_acc:83.125
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 240/300 lr=0.00026 - loss:0.138, acc:94.983, val_loss:0.166, val_acc:83.125
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 241/300 lr=0.00026 - loss:0.138, acc:94.488, val_loss:0.179, val_acc:80.000
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 242/300 lr=0.00022 - loss:0.130, acc:96.537, val_loss:0.285, val_acc:64.375
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 243/300 lr=0.00022 - loss:0.131, acc:96.453, val_loss:0.293, val_acc:62.500
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 244/300 lr=0.00022 - loss:0.132, acc:96.199, val_loss:0.187, val_acc:80.625
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 245/300 lr=0.00022 - loss:0.131, acc:96.537, val_loss:0.230, val_acc:61.875
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 246/300 lr=0.00022 - loss:0.133, acc:95.923, val_loss:0.248, val_acc:62.500
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 247/300 lr=0.00022 - loss:0.131, acc:96.453, val_loss:0.210, val_acc:63.125
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 248/300 lr=0.00022 - loss:0.136, acc:95.501, val_loss:0.267, val_acc:65.000
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 249/300 lr=0.00022 - loss:0.128, acc:96.622, val_loss:0.158, val_acc:84.375
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 250/300 lr=0.00022 - loss:0.131, acc:96.368, val_loss:0.315, val_acc:63.125
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 251/300 lr=0.00022 - loss:0.130, acc:97.044, val_loss:0.151, val_acc:85.000
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 252/300 lr=0.00022 - loss:0.130, acc:96.537, val_loss:0.219, val_acc:65.000
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 253/300 lr=0.00022 - loss:0.131, acc:96.368, val_loss:0.189, val_acc:85.000
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 254/300 lr=0.00022 - loss:0.126, acc:96.875, val_loss:0.288, val_acc:62.500
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 255/300 lr=0.00022 - loss:0.125, acc:97.106, val_loss:0.166, val_acc:85.000
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 256/300 lr=0.00022 - loss:0.127, acc:96.706, val_loss:0.169, val_acc:85.000
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 257/300 lr=0.00022 - loss:0.126, acc:97.044, val_loss:0.141, val_acc:85.000
# Best loss:0.148, Best accuracy:83.750, Best F1-score:83.253
# 258/300 lr=0.00022 - loss:0.125, acc:97.033, val_loss:0.241, val_acc:64.375
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 259/300 lr=0.00022 - loss:0.126, acc:97.128, val_loss:0.240, val_acc:64.375
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 260/300 lr=0.00022 - loss:0.129, acc:96.441, val_loss:0.266, val_acc:63.750
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 261/300 lr=0.00022 - loss:0.130, acc:96.537, val_loss:0.228, val_acc:63.125
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 262/300 lr=0.00019 - loss:0.129, acc:96.852, val_loss:0.306, val_acc:65.625
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 263/300 lr=0.00019 - loss:0.126, acc:96.622, val_loss:0.159, val_acc:81.875
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 264/300 lr=0.00019 - loss:0.123, acc:97.202, val_loss:0.279, val_acc:63.125
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 265/300 lr=0.00019 - loss:0.122, acc:97.551, val_loss:0.163, val_acc:84.375
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 266/300 lr=0.00019 - loss:0.127, acc:96.622, val_loss:0.328, val_acc:63.750
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 267/300 lr=0.00019 - loss:0.128, acc:96.864, val_loss:0.152, val_acc:83.125
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 268/300 lr=0.00019 - loss:0.127, acc:96.791, val_loss:0.302, val_acc:61.250
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 269/300 lr=0.00019 - loss:0.125, acc:96.948, val_loss:0.143, val_acc:85.625
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 270/300 lr=0.00019 - loss:0.129, acc:96.188, val_loss:0.158, val_acc:81.250
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 271/300 lr=0.00019 - loss:0.126, acc:97.128, val_loss:0.198, val_acc:83.750
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 272/300 lr=0.00019 - loss:0.122, acc:97.539, val_loss:0.191, val_acc:82.500
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 273/300 lr=0.00019 - loss:0.125, acc:97.213, val_loss:0.208, val_acc:81.875
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 274/300 lr=0.00019 - loss:0.126, acc:96.706, val_loss:0.194, val_acc:80.000
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 275/300 lr=0.00019 - loss:0.129, acc:96.188, val_loss:0.329, val_acc:60.625
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 276/300 lr=0.00019 - loss:0.124, acc:97.286, val_loss:0.181, val_acc:81.875
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 277/300 lr=0.00019 - loss:0.127, acc:96.261, val_loss:0.178, val_acc:83.125
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 278/300 lr=0.00019 - loss:0.129, acc:96.526, val_loss:0.279, val_acc:62.500
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 279/300 lr=0.00019 - loss:0.126, acc:97.202, val_loss:0.191, val_acc:81.250
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 280/300 lr=0.00019 - loss:0.127, acc:96.537, val_loss:0.168, val_acc:82.500
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 281/300 lr=0.00019 - loss:0.120, acc:97.973, val_loss:0.186, val_acc:85.000
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 282/300 lr=0.00017 - loss:0.126, acc:97.033, val_loss:0.213, val_acc:85.000
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 283/300 lr=0.00017 - loss:0.125, acc:96.706, val_loss:0.210, val_acc:81.875
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 284/300 lr=0.00017 - loss:0.124, acc:97.128, val_loss:0.207, val_acc:81.250
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 285/300 lr=0.00017 - loss:0.124, acc:97.128, val_loss:0.178, val_acc:82.500
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 286/300 lr=0.00017 - loss:0.124, acc:97.455, val_loss:0.188, val_acc:84.375
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 287/300 lr=0.00017 - loss:0.126, acc:97.213, val_loss:0.165, val_acc:84.375
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 288/300 lr=0.00017 - loss:0.123, acc:97.382, val_loss:0.256, val_acc:63.750
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 289/300 lr=0.00017 - loss:0.125, acc:96.864, val_loss:0.269, val_acc:63.750
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 290/300 lr=0.00017 - loss:0.119, acc:97.624, val_loss:0.292, val_acc:61.875
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 291/300 lr=0.00017 - loss:0.120, acc:97.889, val_loss:0.161, val_acc:85.000
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 292/300 lr=0.00017 - loss:0.121, acc:97.382, val_loss:0.291, val_acc:63.750
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 293/300 lr=0.00017 - loss:0.120, acc:97.382, val_loss:0.238, val_acc:60.625
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 294/300 lr=0.00017 - loss:0.123, acc:97.382, val_loss:0.240, val_acc:62.500
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 295/300 lr=0.00017 - loss:0.119, acc:97.624, val_loss:0.242, val_acc:62.500
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 296/300 lr=0.00017 - loss:0.121, acc:97.804, val_loss:0.184, val_acc:83.125
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 297/300 lr=0.00017 - loss:0.127, acc:96.948, val_loss:0.305, val_acc:60.625
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 298/300 lr=0.00017 - loss:0.123, acc:97.286, val_loss:0.245, val_acc:62.500
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 299/300 lr=0.00017 - loss:0.119, acc:98.215, val_loss:0.249, val_acc:63.750
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# 300/300 lr=0.00017 - loss:0.121, acc:97.708, val_loss:0.150, val_acc:85.625
# Best loss:0.141, Best accuracy:85.000, Best F1-score:84.430
# ********************************************************************************
# [*] Done Fold-10
# best_val_loss:0.141, best_val_acc:85.000, best_val_f1:84.430
# test_acc:84.375, test_f1:84.659
# ********************************************************************************

# %%
end()

# %%
print('*' * 80)
print('[*] validation accuracy')
for i, val_acc in enumerate(fold_val_acc):
    print(f'    Fold-{i+1} : {val_acc}')
print(f'max:{max(fold_val_acc)}, min:{min(fold_val_acc)}, average:{sum(fold_val_acc)/len(fold_val_acc)}')
print('*' * 80)
print()

print('*' * 80)
print('[*] test accuracy')
for i, test_acc in enumerate(fold_test_acc):
    print(f'    Fold-{i+1} : {test_acc}')
print(f'max:{max(fold_test_acc)}, min:{min(fold_test_acc)}, average:{sum(fold_test_acc)/len(fold_test_acc)}')
print('*' * 80)
print()
# Out:
# ********************************************************************************
# [*] validation accuracy
#     Fold-1 : 88.125
#     Fold-2 : 86.875
#     Fold-3 : 85.0
# max:88.125, min:85.0, average:86.66666666666667
# ********************************************************************************
#
# ********************************************************************************
# [*] test accuracy
#     Fold-1 : 87.5
#     Fold-2 : 87.5
#     Fold-3 : 84.375
# max:87.5, min:84.375, average:86.45833333333333
# ********************************************************************************

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
# Out:
# WAR(Weighted Average Recall)   : 85.96%
# UAR(Unweighted Average Recall) : 85.96%
